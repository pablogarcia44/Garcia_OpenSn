# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=565

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)

water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=565
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=565
helium.set_density('g/cm3', 0.178E-03 )


model.materials = openmc.Materials([uo2, zirconium, water,helium]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
C=[(0,0)]
E=[(1,0),(0,1),(2,0),(0,2),(3,0),(0,3),(4,0),(0,4),(5,0),(0,5),(6,0),(0,6),(7,0),(0,7),(8,0),(0,8)]
N=[(1,1),(2,1),(1,2),(3,1),(1,3)]
D=[(1,4),(4,1),(1,5),(6,1),(1,6),(7,1),(1,7),(2,2),(7,3),(3,7),(4,4),(6,4),(4,6),(7,4),(4,7),(6,6),(7,6),(6,7),(7,7),(6,3),(3,6)]
F=[(5,1),(1,5),(8,1),(1,8),(3,2),(2,3),(2,6),(6,2),(2,7),(7,2),(5,3),(3,5),(8,3),(3,8),(5,4),(4,5),(8,4),(4,8),(6,5),(5,6),(7,5),(5,7),(8,6),(6,8),(8,7),(7,8)]
FD=[(4,2),(2,4),(4,3),(3,4)]
GT=[(5,2),(8,2),(3,3),(2,5),(5,5),(8,5),(2,8),(5,8)]
IT=[(8,8)]

E_left=[]
E_full=[]
for X in E:
    E_left.append((X[0],X[1]))
    E_left.append((X[0],16-X[1]))
for X in E_left:
    E_full.append((X[0],X[1]))
    E_full.append((16-X[0],X[1]))
E_full = list(set(E_full))

C_left=[]
C_full=[]
for X in C:
    C_left.append((X[0],X[1]))
    C_left.append((X[0],16-X[1]))
for X in C_left:
    C_full.append((X[0],X[1]))
    C_full.append((16-X[0],X[1]))
C_full = list(set(C_full))

    
N_left=[]
N_full=[]
for X in N:
    N_left.append((X[0],X[1]))
    N_left.append((X[0],16-X[1]))
for X in N_left:
    N_full.append((X[0],X[1]))
    N_full.append((16-X[0],X[1]))
N_full = list(set(N_full))


D_left=[]
D_full=[]
for X in D:
    D_left.append((X[0],X[1]))
    D_left.append((X[0],16-X[1]))
for X in D_left:
    D_full.append((X[0],X[1]))
    D_full.append((16-X[0],X[1]))   
D_full = list(set(D_full))


F_left=[]
F_full=[]
for X in F:
    F_left.append((X[0],X[1]))
    F_left.append((X[0],16-X[1]))
for X in F_left:
    F_full.append((X[0],X[1]))
    F_full.append((16-X[0],X[1]))    
F_full = list(set(F_full))

FD_left=[]
FD_full=[]
for X in FD:
    FD_left.append((X[0],X[1]))
    FD_left.append((X[0],16-X[1]))
for X in FD_left:
    FD_full.append((X[0],X[1]))
    FD_full.append((16-X[0],X[1]))    
FD_full = list(set(FD_full))


GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))

# %% [markdown]
# ### Create family pincell

# %%
pincell_C=pincell('C')
pincell_E=pincell('E')
pincell_N=pincell('N')
pincell_D=pincell('D')
pincell_F=pincell('F')
pincell_FD=pincell('FD')
guide_GT=guide('GT')
guide_IT=instru('IT')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in C_full:
            A[ix][iy]=pincell_C[0]
        if (ix,iy) in E_full:
            A[ix][iy]=pincell_E[0]
        if (ix,iy) in N_full:
            A[ix][iy]=pincell_N[0]
        if (ix,iy) in D_full:
            A[ix][iy]=pincell_D[0]            
        if (ix,iy) in F_full:
            A[ix][iy]=pincell_F[0]
        if (ix,iy) in FD_full:
            A[ix][iy]=pincell_FD[0]
        if (ix,iy) in GT_full:
            A[ix][iy]=guide_GT[0]
        if (ix,iy) in IT:
            A[ix][iy]=guide_IT[0]    

# print(A)           
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()

mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_6_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=6686.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=5657.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=5665.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-05 11:48:03
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.18895
#         2/1    1.18920
#         3/1    1.18465
#         4/1    1.18316
#         5/1    1.17958
#         6/1    1.18229
#         7/1    1.17958
#         8/1    1.18327
#         9/1    1.18181
#        10/1    1.18381
#        11/1    1.18228
#        12/1    1.17984
#        13/1    1.18332
#        14/1    1.18264
#        15/1    1.19244
#        16/1    1.18015
#        17/1    1.18325
#        18/1    1.18596
#        19/1    1.17958
#        20/1    1.18979
#        21/1    1.19110
#        22/1    1.17533    1.18322 +/- 0.00789
#        23/1    1.19493    1.18712 +/- 0.00600
#        24/1    1.19861    1.19000 +/- 0.00512
#        25/1    1.18802    1.18960 +/- 0.00399
#        26/1    1.18442    1.18874 +/- 0.00337
#        27/1    1.18461    1.18815 +/- 0.00291
#        28/1    1.16646    1.18544 +/- 0.00370
#        29/1    1.17737    1.18454 +/- 0.00338
#        30/1    1.18185    1.18427 +/- 0.00304
#        31/1    1.19515    1.18526 +/- 0.00292
#        32/1    1.18798    1.18549 +/- 0.00268
#        33/1    1.17595    1.18475 +/- 0.00257
#        34/1    1.18805    1.18499 +/- 0.00239
#        35/1    1.18581    1.18504 +/- 0.00223
#        36/1    1.17996    1.18473 +/- 0.00211
#        37/1    1.19202    1.18516 +/- 0.00202
#        38/1    1.18241    1.18500 +/- 0.00191
#        39/1    1.18043    1.18476 +/- 0.00183
#        40/1    1.17313    1.18418 +/- 0.00183
#        41/1    1.19408    1.18465 +/- 0.00180
#        42/1    1.17770    1.18434 +/- 0.00175
#        43/1    1.18018    1.18415 +/- 0.00168
#        44/1    1.18658    1.18426 +/- 0.00161
#        45/1    1.17111    1.18373 +/- 0.00163
#        46/1    1.18151    1.18364 +/- 0.00157
#        47/1    1.19297    1.18399 +/- 0.00155
#        48/1    1.17405    1.18363 +/- 0.00153
#        49/1    1.18428    1.18366 +/- 0.00148
#        50/1    1.17751    1.18345 +/- 0.00145
#  Triggers unsatisfied, max unc./thresh. is 8.257652029671837 for eigenvalue
#  The estimated number of batches is 2066
#  Creating state point statepoint.00050.h5...
#        51/1    1.18627    1.18354 +/- 0.00140
#  Triggers unsatisfied, max unc./thresh. is 7.990175453491418 for eigenvalue
#  The estimated number of batches is 2000
#        52/1    1.17672    1.18333 +/- 0.00137
#  Triggers unsatisfied, max unc./thresh. is 7.647462230361879 for eigenvalue
#  The estimated number of batches is 1892
#        53/1    1.18365    1.18334 +/- 0.00133
#  Triggers unsatisfied, max unc./thresh. is 7.740358370513607 for eigenvalue
#  The estimated number of batches is 1998
#        54/1    1.18489    1.18339 +/- 0.00129
#  Triggers unsatisfied, max unc./thresh. is 7.438744322708955 for eigenvalue
#  The estimated number of batches is 1902
#        55/1    1.19468    1.18371 +/- 0.00130
#  Triggers unsatisfied, max unc./thresh. is 7.270755612782746 for eigenvalue
#  The estimated number of batches is 1871
#        56/1    1.17591    1.18349 +/- 0.00128
#  Triggers unsatisfied, max unc./thresh. is 7.205311160585165 for eigenvalue
#  The estimated number of batches is 1889
#        57/1    1.17514    1.18327 +/- 0.00126
#  Triggers unsatisfied, max unc./thresh. is 7.475838891783998 for eigenvalue
#  The estimated number of batches is 2088
#        58/1    1.17569    1.18307 +/- 0.00125
#  Triggers unsatisfied, max unc./thresh. is 7.309227542790667 for eigenvalue
#  The estimated number of batches is 2051
#        59/1    1.18921    1.18322 +/- 0.00122
#  Triggers unsatisfied, max unc./thresh. is 7.344138449974918 for eigenvalue
#  The estimated number of batches is 2124
#        60/1    1.18836    1.18335 +/- 0.00120
#  Triggers unsatisfied, max unc./thresh. is 7.372858581767439 for eigenvalue
#  The estimated number of batches is 2195
#        61/1    1.18438    1.18338 +/- 0.00117
#  Triggers unsatisfied, max unc./thresh. is 7.285097780845058 for eigenvalue
#  The estimated number of batches is 2196
#        62/1    1.17486    1.18317 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 7.143059998079996 for eigenvalue
#  The estimated number of batches is 2163
#        63/1    1.18729    1.18327 +/- 0.00114
#  Triggers unsatisfied, max unc./thresh. is 6.9797749781830944 for eigenvalue
#  The estimated number of batches is 2115
#        64/1    1.17903    1.18317 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 6.791726999529154 for eigenvalue
#  The estimated number of batches is 2050
#        65/1    1.17695    1.18304 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 6.67072772403358 for eigenvalue
#  The estimated number of batches is 2023
#        66/1    1.18777    1.18314 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 6.550659863766439 for eigenvalue
#  The estimated number of batches is 1994
#        67/1    1.18239    1.18312 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 6.591351873625052 for eigenvalue
#  The estimated number of batches is 2062
#        68/1    1.18411    1.18314 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.411145342286863 for eigenvalue
#  The estimated number of batches is 1993
#        69/1    1.18398    1.18316 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.254688383007826 for eigenvalue
#  The estimated number of batches is 1937
#        70/1    1.17289    1.18295 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.471962828670863 for eigenvalue
#  The estimated number of batches is 2115
#        71/1    1.18380    1.18297 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 6.357656042790778 for eigenvalue
#  The estimated number of batches is 2082
#        72/1    1.19020    1.18311 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 6.258438711925609 for eigenvalue
#  The estimated number of batches is 2057
#        73/1    1.18498    1.18315 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.168760716949194 for eigenvalue
#  The estimated number of batches is 2037
#        74/1    1.17293    1.18296 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.1297636589888205 for eigenvalue
#  The estimated number of batches is 2049
#        75/1    1.17718    1.18285 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.047327074346918 for eigenvalue
#  The estimated number of batches is 2032
#        76/1    1.18351    1.18286 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.958947466837534 for eigenvalue
#  The estimated number of batches is 2009
#        77/1    1.18956    1.18298 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.862825914021557 for eigenvalue
#  The estimated number of batches is 1980
#        78/1    1.17712    1.18288 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.729723425818186 for eigenvalue
#  The estimated number of batches is 1925
#        79/1    1.18171    1.18286 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.679110679215844 for eigenvalue
#  The estimated number of batches is 1923
#        80/1    1.18234    1.18285 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 5.60356524032575 for eigenvalue
#  The estimated number of batches is 1904
#        81/1    1.17785    1.18277 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.552102054107925 for eigenvalue
#  The estimated number of batches is 1901
#        82/1    1.18544    1.18281 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.60840857051064 for eigenvalue
#  The estimated number of batches is 1971
#        83/1    1.19469    1.18300 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.526815960576052 for eigenvalue
#  The estimated number of batches is 1945
#        84/1    1.18305    1.18300 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.427403427073596 for eigenvalue
#  The estimated number of batches is 1906
#        85/1    1.18408    1.18302 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.445116233394299 for eigenvalue
#  The estimated number of batches is 1948
#        86/1    1.19060    1.18313 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.370345551383383 for eigenvalue
#  The estimated number of batches is 1924
#        87/1    1.18633    1.18318 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.280251334664565 for eigenvalue
#  The estimated number of batches is 1889
#        88/1    1.17855    1.18311 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.2061199843676516 for eigenvalue
#  The estimated number of batches is 1864
#        89/1    1.18901    1.18320 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.139744238018281 for eigenvalue
#  The estimated number of batches is 1843
#        90/1    1.19523    1.18337 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.256158335366094 for eigenvalue
#  The estimated number of batches is 1954
#        91/1    1.17266    1.18322 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.2482069593453 for eigenvalue
#  The estimated number of batches is 1976
#        92/1    1.18151    1.18320 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.2177236413841115 for eigenvalue
#  The estimated number of batches is 1981
#        93/1    1.18431    1.18321 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.150446668846517 for eigenvalue
#  The estimated number of batches is 1957
#        94/1    1.18725    1.18327 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.158787071997426 for eigenvalue
#  The estimated number of batches is 1990
#        95/1    1.17313    1.18313 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.142639254118903 for eigenvalue
#  The estimated number of batches is 2004
#        96/1    1.18860    1.18320 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.118089735064794 for eigenvalue
#  The estimated number of batches is 2011
#        97/1    1.18653    1.18325 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.066280703712622 for eigenvalue
#  The estimated number of batches is 1997
#        98/1    1.18821    1.18331 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.994292200998188 for eigenvalue
#  The estimated number of batches is 1966
#        99/1    1.18588    1.18334 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.966052302891289 for eigenvalue
#  The estimated number of batches is 1969
#       100/1    1.17872    1.18328 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.905836523313519 for eigenvalue
#  The estimated number of batches is 1946
#       101/1    1.18621    1.18332 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.863847854298571 for eigenvalue
#  The estimated number of batches is 1937
#       102/1    1.18369    1.18332 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.8125007801332504 for eigenvalue
#  The estimated number of batches is 1920
#       103/1    1.18605    1.18336 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.75989938671649 for eigenvalue
#  The estimated number of batches is 1901
#       104/1    1.18494    1.18338 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.711211390442272 for eigenvalue
#  The estimated number of batches is 1885
#       105/1    1.17916    1.18333 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.663894895947671 for eigenvalue
#  The estimated number of batches is 1869
#       106/1    1.18787    1.18338 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.617279552889159 for eigenvalue
#  The estimated number of batches is 1854
#       107/1    1.19233    1.18348 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.576888786446145 for eigenvalue
#  The estimated number of batches is 1843
#       108/1    1.17812    1.18342 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.518250561123499 for eigenvalue
#  The estimated number of batches is 1817
#       109/1    1.18559    1.18345 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.467443451087457 for eigenvalue
#  The estimated number of batches is 1797
#       110/1    1.18822    1.18350 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.441571804558924 for eigenvalue
#  The estimated number of batches is 1796
#       111/1    1.18604    1.18353 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.4087964775901725 for eigenvalue
#  The estimated number of batches is 1789
#       112/1    1.18600    1.18355 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.378934867815771 for eigenvalue
#  The estimated number of batches is 1785
#       113/1    1.18523    1.18357 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.334854665105217 for eigenvalue
#  The estimated number of batches is 1768
#       114/1    1.17939    1.18353 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.291888274456653 for eigenvalue
#  The estimated number of batches is 1752
#       115/1    1.19200    1.18362 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.259829590733229 for eigenvalue
#  The estimated number of batches is 1744
#       116/1    1.18698    1.18365 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.279226202855375 for eigenvalue
#  The estimated number of batches is 1778
#       117/1    1.18923    1.18371 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.2715650220975325 for eigenvalue
#  The estimated number of batches is 1790
#       118/1    1.17213    1.18359 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.26479619299292 for eigenvalue
#  The estimated number of batches is 1803
#       119/1    1.18423    1.18360 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.236982803799365 for eigenvalue
#  The estimated number of batches is 1798
#       120/1    1.17927    1.18355 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.193812286398149 for eigenvalue
#  The estimated number of batches is 1779
#       121/1    1.18802    1.18360 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.156297756027324 for eigenvalue
#  The estimated number of batches is 1765
#       122/1    1.18272    1.18359 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.114305190707775 for eigenvalue
#  The estimated number of batches is 1747
#       123/1    1.19169    1.18367 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.117142156422595 for eigenvalue
#  The estimated number of batches is 1766
#       124/1    1.18186    1.18365 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.076105200718604 for eigenvalue
#  The estimated number of batches is 1748
#       125/1    1.17809    1.18360 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.027672791902254 for eigenvalue
#  The estimated number of batches is 1724
#       126/1    1.19340    1.18369 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.011520791687689 for eigenvalue
#  The estimated number of batches is 1726
#       127/1    1.18081    1.18366 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.9885891073113164 for eigenvalue
#  The estimated number of batches is 1723
#       128/1    1.18359    1.18366 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.9708052197816044 for eigenvalue
#  The estimated number of batches is 1723
#       129/1    1.18166    1.18364 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.935793815553139 for eigenvalue
#  The estimated number of batches is 1709
#       130/1    1.17922    1.18360 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.8942105477164253 for eigenvalue
#  The estimated number of batches is 1689
#       131/1    1.18698    1.18363 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8618402231773454 for eigenvalue
#  The estimated number of batches is 1676
#       132/1    1.18859    1.18368 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.837600696373144 for eigenvalue
#  The estimated number of batches is 1670
#       133/1    1.19329    1.18376 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8252210087288336 for eigenvalue
#  The estimated number of batches is 1674
#       134/1    1.18508    1.18378 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.790893401931035 for eigenvalue
#  The estimated number of batches is 1659
#       135/1    1.18124    1.18375 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7662381641780067 for eigenvalue
#  The estimated number of batches is 1652
#       136/1    1.18521    1.18377 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7378603200592098 for eigenvalue
#  The estimated number of batches is 1641
#       137/1    1.17645    1.18370 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7022206685129366 for eigenvalue
#  The estimated number of batches is 1624
#       138/1    1.17868    1.18366 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.679358457123986 for eigenvalue
#  The estimated number of batches is 1618
#       139/1    1.18203    1.18365 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.657637012449216 for eigenvalue
#  The estimated number of batches is 1613
#       140/1    1.19043    1.18370 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.652712643908392 for eigenvalue
#  The estimated number of batches is 1622
#       141/1    1.17992    1.18367 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6200520138528276 for eigenvalue
#  The estimated number of batches is 1606
#       142/1    1.17653    1.18361 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5815753080449397 for eigenvalue
#  The estimated number of batches is 1585
#       143/1    1.17827    1.18357 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.545672908396783 for eigenvalue
#  The estimated number of batches is 1567
#       144/1    1.17553    1.18351 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5184387186061348 for eigenvalue
#  The estimated number of batches is 1556
#       145/1    1.18037    1.18348 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.4888645742568705 for eigenvalue
#  The estimated number of batches is 1542
#       146/1    1.18912    1.18353 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5156140891879657 for eigenvalue
#  The estimated number of batches is 1578
#       147/1    1.17967    1.18350 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.4830932341857603 for eigenvalue
#  The estimated number of batches is 1561
#       148/1    1.18049    1.18347 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4671160037215385 for eigenvalue
#  The estimated number of batches is 1559
#       149/1    1.18518    1.18348 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4493148405503895 for eigenvalue
#  The estimated number of batches is 1555
#       150/1    1.18305    1.18348 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4254924917423804 for eigenvalue
#  The estimated number of batches is 1546
#       151/1    1.18566    1.18350 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4030455245008837 for eigenvalue
#  The estimated number of batches is 1538
#       152/1    1.18731    1.18353 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.394939749154435 for eigenvalue
#  The estimated number of batches is 1542
#       153/1    1.18340    1.18353 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.380724644243835 for eigenvalue
#  The estimated number of batches is 1541
#       154/1    1.17281    1.18345 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3607532326432006 for eigenvalue
#  The estimated number of batches is 1534
#       155/1    1.17669    1.18340 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3297450220265956 for eigenvalue
#  The estimated number of batches is 1517
#       156/1    1.18236    1.18339 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.333468756836555 for eigenvalue
#  The estimated number of batches is 1532
#       157/1    1.18651    1.18341 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.30955686226432 for eigenvalue
#  The estimated number of batches is 1521
#       158/1    1.18631    1.18343 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3018454846330263 for eigenvalue
#  The estimated number of batches is 1525
#       159/1    1.17870    1.18340 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2891970453828714 for eigenvalue
#  The estimated number of batches is 1524
#       160/1    1.18829    1.18343 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2687764673045936 for eigenvalue
#  The estimated number of batches is 1516
#       161/1    1.18656    1.18346 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2483229087877965 for eigenvalue
#  The estimated number of batches is 1508
#       162/1    1.17917    1.18343 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2424195309298343 for eigenvalue
#  The estimated number of batches is 1513
#       163/1    1.18241    1.18342 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.220877714406635 for eigenvalue
#  The estimated number of batches is 1504
#       164/1    1.17824    1.18338 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2183747834982825 for eigenvalue
#  The estimated number of batches is 1512
#       165/1    1.18804    1.18341 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2106734541666007 for eigenvalue
#  The estimated number of batches is 1515
#       166/1    1.18329    1.18341 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.189017485685071 for eigenvalue
#  The estimated number of batches is 1505
#       167/1    1.17452    1.18335 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.217747937906131 for eigenvalue
#  The estimated number of batches is 1543
#       168/1    1.18186    1.18334 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.19976326539273 for eigenvalue
#  The estimated number of batches is 1536
#       169/1    1.17651    1.18330 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2360661542241336 for eigenvalue
#  The estimated number of batches is 1581
#       170/1    1.17714    1.18326 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2088548473400853 for eigenvalue
#  The estimated number of batches is 1565
#       171/1    1.18587    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.189858587178462 for eigenvalue
#  The estimated number of batches is 1557
#       172/1    1.18306    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.170723879776198 for eigenvalue
#  The estimated number of batches is 1549
#       173/1    1.18334    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1620090926837405 for eigenvalue
#  The estimated number of batches is 1550
#       174/1    1.18930    1.18331 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1750343197519952 for eigenvalue
#  The estimated number of batches is 1573
#       175/1    1.17486    1.18326 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1791906862380044 for eigenvalue
#  The estimated number of batches is 1587
#       176/1    1.17622    1.18321 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.160634760913741 for eigenvalue
#  The estimated number of batches is 1579
#       177/1    1.18838    1.18324 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1439475495780975 for eigenvalue
#  The estimated number of batches is 1572
#       178/1    1.17538    1.18319 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.12633319037946 for eigenvalue
#  The estimated number of batches is 1565
#       179/1    1.17341    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0995572054518536 for eigenvalue
#  The estimated number of batches is 1548
#       180/1    1.18191    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.07913717834752 for eigenvalue
#  The estimated number of batches is 1537
#       181/1    1.19198    1.18318 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0754092210824298 for eigenvalue
#  The estimated number of batches is 1543
#       182/1    1.17599    1.18314 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.055219682105649 for eigenvalue
#  The estimated number of batches is 1533
#       183/1    1.18267    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0360500871709015 for eigenvalue
#  The estimated number of batches is 1523
#       184/1    1.18895    1.18317 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0507820953099114 for eigenvalue
#  The estimated number of batches is 1547
#       185/1    1.18434    1.18318 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.034528563686172 for eigenvalue
#  The estimated number of batches is 1540
#       186/1    1.18829    1.18321 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0228331613756403 for eigenvalue
#  The estimated number of batches is 1537
#       187/1    1.18484    1.18322 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.003925517378742 for eigenvalue
#  The estimated number of batches is 1527
#       188/1    1.17975    1.18320 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9942428885095027 for eigenvalue
#  The estimated number of batches is 1527
#       189/1    1.18035    1.18318 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9861742967659577 for eigenvalue
#  The estimated number of batches is 1528
#       190/1    1.17871    1.18315 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.97252674410205 for eigenvalue
#  The estimated number of batches is 1523
#       191/1    1.18348    1.18315 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9605905735725693 for eigenvalue
#  The estimated number of batches is 1519
#       192/1    1.18133    1.18314 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.958516868278091 for eigenvalue
#  The estimated number of batches is 1526
#       193/1    1.17409    1.18309 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.952501003180305 for eigenvalue
#  The estimated number of batches is 1529
#       194/1    1.17701    1.18306 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.943858799311607 for eigenvalue
#  The estimated number of batches is 1528
#       195/1    1.17170    1.18299 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9229680800016657 for eigenvalue
#  The estimated number of batches is 1516
#       196/1    1.18143    1.18298 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.92687103064607 for eigenvalue
#  The estimated number of batches is 1528
#       197/1    1.18983    1.18302 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.913683466577799 for eigenvalue
#  The estimated number of batches is 1523
#       198/1    1.17061    1.18295 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8933871483382094 for eigenvalue
#  The estimated number of batches is 1511
#       199/1    1.18308    1.18295 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8863466847116093 for eigenvalue
#  The estimated number of batches is 1512
#       200/1    1.17964    1.18293 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.867869251299408 for eigenvalue
#  The estimated number of batches is 1501
#       201/1    1.17850    1.18291 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8601612424239233 for eigenvalue
#  The estimated number of batches is 1501
#       202/1    1.18662    1.18293 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.845039921823472 for eigenvalue
#  The estimated number of batches is 1494
#       203/1    1.17619    1.18289 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8378335000592183 for eigenvalue
#  The estimated number of batches is 1494
#       204/1    1.17673    1.18286 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8207859323152324 for eigenvalue
#  The estimated number of batches is 1485
#       205/1    1.18568    1.18288 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8289053133330806 for eigenvalue
#  The estimated number of batches is 1501
#       206/1    1.18551    1.18289 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.829846180696441 for eigenvalue
#  The estimated number of batches is 1510
#       207/1    1.18473    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8136926177001267 for eigenvalue
#  The estimated number of batches is 1501
#       208/1    1.18283    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.800099012562982 for eigenvalue
#  The estimated number of batches is 1495
#       209/1    1.18388    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.800153729493479 for eigenvalue
#  The estimated number of batches is 1502
#       210/1    1.17962    1.18289 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7890526429661944 for eigenvalue
#  The estimated number of batches is 1498
#       211/1    1.17581    1.18285 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7728587026897475 for eigenvalue
#  The estimated number of batches is 1489
#       212/1    1.18353    1.18285 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7607342643329744 for eigenvalue
#  The estimated number of batches is 1484
#       213/1    1.17621    1.18282 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7726383521321534 for eigenvalue
#  The estimated number of batches is 1504
#       214/1    1.17808    1.18279 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7562338672194473 for eigenvalue
#  The estimated number of batches is 1494
#       215/1    1.17687    1.18276 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7460947948490473 for eigenvalue
#  The estimated number of batches is 1491
#       216/1    1.17674    1.18273 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.773685834754082 for eigenvalue
#  The estimated number of batches is 1528
#       217/1    1.18010    1.18272 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7627134366341193 for eigenvalue
#  The estimated number of batches is 1524
#       218/1    1.17819    1.18270 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.752264139530042 for eigenvalue
#  The estimated number of batches is 1520
#       219/1    1.17463    1.18266 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.754390088017055 for eigenvalue
#  The estimated number of batches is 1530
#       220/1    1.19196    1.18270 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.742633716967951 for eigenvalue
#  The estimated number of batches is 1525
#       221/1    1.19281    1.18275 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7455491509662306 for eigenvalue
#  The estimated number of batches is 1536
#       222/1    1.18753    1.18278 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.734347482062278 for eigenvalue
#  The estimated number of batches is 1531
#       223/1    1.18852    1.18281 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7258606431711705 for eigenvalue
#  The estimated number of batches is 1529
#       224/1    1.18579    1.18282 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.716746189186716 for eigenvalue
#  The estimated number of batches is 1526
#       225/1    1.18541    1.18283 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7037027788150043 for eigenvalue
#  The estimated number of batches is 1519
#       226/1    1.18070    1.18282 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7126996066145805 for eigenvalue
#  The estimated number of batches is 1536
#       227/1    1.18267    1.18282 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7071605215791967 for eigenvalue
#  The estimated number of batches is 1538
#       228/1    1.18011    1.18281 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6930857311937655 for eigenvalue
#  The estimated number of batches is 1529
#       229/1    1.18322    1.18281 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6811988810783145 for eigenvalue
#  The estimated number of batches is 1523
#       230/1    1.19363    1.18286 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7053246066746457 for eigenvalue
#  The estimated number of batches is 1557
#       231/1    1.18121    1.18285 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6940311081323665 for eigenvalue
#  The estimated number of batches is 1552
#       232/1    1.18775    1.18288 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.682074826869072 for eigenvalue
#  The estimated number of batches is 1546
#       233/1    1.18684    1.18290 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.67174157628798 for eigenvalue
#  The estimated number of batches is 1541
#       234/1    1.17905    1.18288 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6615060670772417 for eigenvalue
#  The estimated number of batches is 1536
#       235/1    1.18108    1.18287 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.664769412788832 for eigenvalue
#  The estimated number of batches is 1547
#       236/1    1.18452    1.18288 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6581449914809196 for eigenvalue
#  The estimated number of batches is 1547
#       237/1    1.18650    1.18289 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.655517580002738 for eigenvalue
#  The estimated number of batches is 1551
#       238/1    1.18315    1.18289 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.643072686416135 for eigenvalue
#  The estimated number of batches is 1543
#       239/1    1.18890    1.18292 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.63362279032967 for eigenvalue
#  The estimated number of batches is 1539
#       240/1    1.18425    1.18293 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6216077275360066 for eigenvalue
#  The estimated number of batches is 1533
#       241/1    1.19549    1.18299 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.619429412661427 for eigenvalue
#  The estimated number of batches is 1537
#       242/1    1.18398    1.18299 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6077094937724907 for eigenvalue
#  The estimated number of batches is 1530
#       243/1    1.18454    1.18300 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6092799940148987 for eigenvalue
#  The estimated number of batches is 1539
#       244/1    1.18998    1.18303 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.600360193510529 for eigenvalue
#  The estimated number of batches is 1535
#       245/1    1.18166    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6039597518526194 for eigenvalue
#  The estimated number of batches is 1546
#       246/1    1.18343    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.594245730715784 for eigenvalue
#  The estimated number of batches is 1542
#       247/1    1.18557    1.18303 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6003067006290626 for eigenvalue
#  The estimated number of batches is 1555
#       248/1    1.18102    1.18303 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.587816383099459 for eigenvalue
#  The estimated number of batches is 1547
#       249/1    1.19202    1.18307 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6075368560140286 for eigenvalue
#  The estimated number of batches is 1578
#       250/1    1.19006    1.18310 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6006044538241904 for eigenvalue
#  The estimated number of batches is 1576
#       251/1    1.18884    1.18312 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5924100619168744 for eigenvalue
#  The estimated number of batches is 1573
#       252/1    1.18000    1.18311 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.585191217473661 for eigenvalue
#  The estimated number of batches is 1571
#       253/1    1.17462    1.18307 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.575287386382138 for eigenvalue
#  The estimated number of batches is 1566
#       254/1    1.17516    1.18304 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.565952698673208 for eigenvalue
#  The estimated number of batches is 1561
#       255/1    1.17554    1.18300 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5531321969765757 for eigenvalue
#  The estimated number of batches is 1552
#       256/1    1.17206    1.18296 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5570451798490144 for eigenvalue
#  The estimated number of batches is 1564
#       257/1    1.17772    1.18294 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.55135903171066 for eigenvalue
#  The estimated number of batches is 1563
#       258/1    1.19026    1.18297 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.547365723885958 for eigenvalue
#  The estimated number of batches is 1565
#       259/1    1.19052    1.18300 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5377300171573856 for eigenvalue
#  The estimated number of batches is 1560
#       260/1    1.18846    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5379050590538386 for eigenvalue
#  The estimated number of batches is 1566
#       261/1    1.18333    1.18302 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.539232494425689 for eigenvalue
#  The estimated number of batches is 1574
#       262/1    1.17690    1.18300 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.527007177990623 for eigenvalue
#  The estimated number of batches is 1566
#       263/1    1.17997    1.18299 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5140119705604467 for eigenvalue
#  The estimated number of batches is 1556
#       264/1    1.18205    1.18298 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5019796175654463 for eigenvalue
#  The estimated number of batches is 1548
#       265/1    1.18660    1.18300 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4919211054173624 for eigenvalue
#  The estimated number of batches is 1542
#       266/1    1.17496    1.18296 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.481239838667774 for eigenvalue
#  The estimated number of batches is 1535
#       267/1    1.17081    1.18291 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.469712021955431 for eigenvalue
#  The estimated number of batches is 1527
#       268/1    1.17010    1.18286 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.457136318119776 for eigenvalue
#  The estimated number of batches is 1518
#       269/1    1.18221    1.18286 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4591667347616926 for eigenvalue
#  The estimated number of batches is 1526
#       270/1    1.17797    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.470354459944753 for eigenvalue
#  The estimated number of batches is 1546
#       271/1    1.18265    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4653943670975638 for eigenvalue
#  The estimated number of batches is 1546
#       272/1    1.18230    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.455958808088354 for eigenvalue
#  The estimated number of batches is 1540
#       273/1    1.19090    1.18287 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.446858958094113 for eigenvalue
#  The estimated number of batches is 1535
#       274/1    1.18451    1.18288 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4416118780577993 for eigenvalue
#  The estimated number of batches is 1535
#       275/1    1.17708    1.18285 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.431420282495405 for eigenvalue
#  The estimated number of batches is 1528
#       276/1    1.18797    1.18287 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.436352229056227 for eigenvalue
#  The estimated number of batches is 1540
#       277/1    1.17963    1.18286 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.429766147389358 for eigenvalue
#  The estimated number of batches is 1538
#       278/1    1.18071    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4205451989367877 for eigenvalue
#  The estimated number of batches is 1532
#       279/1    1.18173    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4157139999742765 for eigenvalue
#  The estimated number of batches is 1532
#       280/1    1.18359    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4064237496450955 for eigenvalue
#  The estimated number of batches is 1526
#       281/1    1.17434    1.18282 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.405347081722713 for eigenvalue
#  The estimated number of batches is 1531
#       282/1    1.18184    1.18281 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.396825153633248 for eigenvalue
#  The estimated number of batches is 1526
#       283/1    1.18875    1.18284 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.388855643662553 for eigenvalue
#  The estimated number of batches is 1521
#       284/1    1.17109    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3816080136270354 for eigenvalue
#  The estimated number of batches is 1518
#       285/1    1.19050    1.18282 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.376654496936456 for eigenvalue
#  The estimated number of batches is 1517
#       286/1    1.17464    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3729741977964376 for eigenvalue
#  The estimated number of batches is 1518
#       287/1    1.18520    1.18280 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.365200169199718 for eigenvalue
#  The estimated number of batches is 1514
#       288/1    1.18146    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3573096025928004 for eigenvalue
#  The estimated number of batches is 1510
#       289/1    1.18596    1.18281 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3502111180119716 for eigenvalue
#  The estimated number of batches is 1506
#       290/1    1.17985    1.18280 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3412913406317837 for eigenvalue
#  The estimated number of batches is 1501
#       291/1    1.17764    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3329054774479014 for eigenvalue
#  The estimated number of batches is 1495
#       292/1    1.18585    1.18279 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3244536402570537 for eigenvalue
#  The estimated number of batches is 1490
#       293/1    1.17713    1.18277 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.320409833350403 for eigenvalue
#  The estimated number of batches is 1490
#       294/1    1.18757    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3313004434369407 for eigenvalue
#  The estimated number of batches is 1510
#       295/1    1.17669    1.18276 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3488932441073023 for eigenvalue
#  The estimated number of batches is 1538
#       296/1    1.18925    1.18279 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.341151399078714 for eigenvalue
#  The estimated number of batches is 1533
#       297/1    1.18048    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3325774361523184 for eigenvalue
# ...
#      1584/1    1.17480    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0244897602698737 for eigenvalue
#  The estimated number of batches is 1662
#      1585/1    1.17623    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0238168498689133 for eigenvalue
#  The estimated number of batches is 1661
#      1586/1    1.18183    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0233010416720252 for eigenvalue
#  The estimated number of batches is 1660
#      1587/1    1.18061    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0228044812150574 for eigenvalue
#  The estimated number of batches is 1660
#      1588/1    1.17949    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.022169558655832 for eigenvalue
#  The estimated number of batches is 1659
#      1589/1    1.18189    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.021818236882422 for eigenvalue
#  The estimated number of batches is 1659
#      1590/1    1.18277    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214375127518989 for eigenvalue
#  The estimated number of batches is 1659
#      1591/1    1.18621    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0208109614913397 for eigenvalue
#  The estimated number of batches is 1658
#      1592/1    1.18278    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0202202850474946 for eigenvalue
#  The estimated number of batches is 1657
#      1593/1    1.18651    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0205059757732553 for eigenvalue
#  The estimated number of batches is 1659
#      1594/1    1.17708    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0207694915185552 for eigenvalue
#  The estimated number of batches is 1661
#      1595/1    1.19322    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0218370017702492 for eigenvalue
#  The estimated number of batches is 1665
#      1596/1    1.18187    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214541837569298 for eigenvalue
#  The estimated number of batches is 1665
#      1597/1    1.18209    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0208525838048792 for eigenvalue
#  The estimated number of batches is 1664
#      1598/1    1.18838    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0209917829504345 for eigenvalue
#  The estimated number of batches is 1665
#      1599/1    1.18377    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.020389061226986 for eigenvalue
#  The estimated number of batches is 1665
#      1600/1    1.19262    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0201998629135833 for eigenvalue
#  The estimated number of batches is 1665
#      1601/1    1.19531    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0199623282218144 for eigenvalue
#  The estimated number of batches is 1665
#      1602/1    1.17950    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193394885722225 for eigenvalue
#  The estimated number of batches is 1664
#      1603/1    1.18186    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193277332759405 for eigenvalue
#  The estimated number of batches is 1665
#      1604/1    1.19720    1.18270 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.019068702519521 for eigenvalue
#  The estimated number of batches is 1665
#      1605/1    1.19216    1.18271 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0186821823247687 for eigenvalue
#  The estimated number of batches is 1665
#      1606/1    1.17980    1.18271 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0180311195310203 for eigenvalue
#  The estimated number of batches is 1664
#      1607/1    1.17407    1.18270 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017933225294746 for eigenvalue
#  The estimated number of batches is 1665
#      1608/1    1.18846    1.18270 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017657180610881 for eigenvalue
#  The estimated number of batches is 1665
#      1609/1    1.19590    1.18271 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0176405504385007 for eigenvalue
#  The estimated number of batches is 1666
#      1610/1    1.18612    1.18271 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01726929122846 for eigenvalue
#  The estimated number of batches is 1666
#      1611/1    1.16787    1.18270 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01694709303681 for eigenvalue
#  The estimated number of batches is 1666
#      1612/1    1.16955    1.18270 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0171670118647513 for eigenvalue
#  The estimated number of batches is 1668
#      1613/1    1.18589    1.18270 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01764634760021 for eigenvalue
#  The estimated number of batches is 1670
#      1614/1    1.18175    1.18270 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0170134345107893 for eigenvalue
#  The estimated number of batches is 1669
#      1615/1    1.18827    1.18270 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0166943893157756 for eigenvalue
#  The estimated number of batches is 1669
#      1616/1    1.16905    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.016876269524126 for eigenvalue
#  The estimated number of batches is 1671
#      1617/1    1.17023    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0168711160465822 for eigenvalue
#  The estimated number of batches is 1672
#      1618/1    1.18091    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0164112488594508 for eigenvalue
#  The estimated number of batches is 1671
#      1619/1    1.18657    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.015830326087868 for eigenvalue
#  The estimated number of batches is 1671
#      1620/1    1.18194    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0152285652217345 for eigenvalue
#  The estimated number of batches is 1670
#      1621/1    1.18908    1.18269 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0147241984044113 for eigenvalue
#  The estimated number of batches is 1669
#      1622/1    1.17417    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0141725502326273 for eigenvalue
#  The estimated number of batches is 1668
#      1623/1    1.17107    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0139156225933024 for eigenvalue
#  The estimated number of batches is 1668
#      1624/1    1.18609    1.18268 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.013296173827925 for eigenvalue
#  The estimated number of batches is 1667
#      1625/1    1.16933    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0126501056765775 for eigenvalue
#  The estimated number of batches is 1666
#      1626/1    1.17583    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0120375404335957 for eigenvalue
#  The estimated number of batches is 1665
#      1627/1    1.18254    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0115210931703629 for eigenvalue
#  The estimated number of batches is 1665
#      1628/1    1.17355    1.18266 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0116861127157468 for eigenvalue
#  The estimated number of batches is 1666
#      1629/1    1.18914    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0110878483183139 for eigenvalue
#  The estimated number of batches is 1665
#      1630/1    1.18039    1.18266 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.010619780620481 for eigenvalue
#  The estimated number of batches is 1665
#      1631/1    1.19026    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0103141410491359 for eigenvalue
#  The estimated number of batches is 1665
#      1632/1    1.17774    1.18267 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096681351102645 for eigenvalue
#  The estimated number of batches is 1664
#      1633/1    1.17394    1.18266 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009218450348111 for eigenvalue
#  The estimated number of batches is 1663
#      1634/1    1.18079    1.18266 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0086634373544756 for eigenvalue
#  The estimated number of batches is 1663
#      1635/1    1.17959    1.18266 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0083112035001267 for eigenvalue
#  The estimated number of batches is 1662
#      1636/1    1.17817    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0080406962000061 for eigenvalue
#  The estimated number of batches is 1663
#      1637/1    1.18510    1.18266 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0075060085851795 for eigenvalue
#  The estimated number of batches is 1662
#      1638/1    1.17591    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0073984076939857 for eigenvalue
#  The estimated number of batches is 1663
#      1639/1    1.18592    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.006815189140718 for eigenvalue
#  The estimated number of batches is 1662
#      1640/1    1.17789    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0061817704036289 for eigenvalue
#  The estimated number of batches is 1661
#      1641/1    1.17309    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0060430932608677 for eigenvalue
#  The estimated number of batches is 1661
#      1642/1    1.19159    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.006333050219588 for eigenvalue
#  The estimated number of batches is 1663
#      1643/1    1.18123    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0057997653515809 for eigenvalue
#  The estimated number of batches is 1662
#      1644/1    1.18521    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0052785874814532 for eigenvalue
#  The estimated number of batches is 1662
#      1645/1    1.18615    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.005817657016032 for eigenvalue
#  The estimated number of batches is 1664
#      1646/1    1.18148    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.005202777955257 for eigenvalue
#  The estimated number of batches is 1663
#      1647/1    1.17689    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0046116485712113 for eigenvalue
#  The estimated number of batches is 1663
#      1648/1    1.18621    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0041732681628912 for eigenvalue
#  The estimated number of batches is 1662
#      1649/1    1.18204    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.005736018798231 for eigenvalue
#  The estimated number of batches is 1668
#      1650/1    1.18354    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0055019830776923 for eigenvalue
#  The estimated number of batches is 1668
#      1651/1    1.18022    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0049018983046298 for eigenvalue
#  The estimated number of batches is 1668
#      1652/1    1.17344    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0045439378155991 for eigenvalue
#  The estimated number of batches is 1667
#      1653/1    1.17346    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0041256491540027 for eigenvalue
#  The estimated number of batches is 1667
#      1654/1    1.18541    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0035279346347314 for eigenvalue
#  The estimated number of batches is 1666
#      1655/1    1.18550    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0029414904235734 for eigenvalue
#  The estimated number of batches is 1665
#      1656/1    1.18327    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0027892419076425 for eigenvalue
#  The estimated number of batches is 1666
#      1657/1    1.18941    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0022022334172966 for eigenvalue
#  The estimated number of batches is 1665
#      1658/1    1.18535    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0018052931512162 for eigenvalue
#  The estimated number of batches is 1664
#      1659/1    1.17950    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0015156655410047 for eigenvalue
#  The estimated number of batches is 1664
#      1660/1    1.18578    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0018654899491284 for eigenvalue
#  The estimated number of batches is 1667
#      1661/1    1.17179    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0014063158065625 for eigenvalue
#  The estimated number of batches is 1666
#      1662/1    1.18118    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0011144834571002 for eigenvalue
#  The estimated number of batches is 1666
#      1663/1    1.19097    1.18265 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0015134992868207 for eigenvalue
#  The estimated number of batches is 1668
#      1664/1    1.17934    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0008921315001318 for eigenvalue
#  The estimated number of batches is 1667
#      1665/1    1.18003    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000594947570731 for eigenvalue
#  The estimated number of batches is 1667
#      1666/1    1.17833    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0008829496139822 for eigenvalue
#  The estimated number of batches is 1669
#      1667/1    1.17991    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0004657526415823 for eigenvalue
#  The estimated number of batches is 1669
#      1668/1    1.18522    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0014078100159296 for eigenvalue
#  The estimated number of batches is 1673
#      1669/1    1.17294    1.18263 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0008553035043477 for eigenvalue
#  The estimated number of batches is 1672
#      1670/1    1.18159    1.18263 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000251809831769 for eigenvalue
#  The estimated number of batches is 1671
#      1671/1    1.19515    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000455999901708 for eigenvalue
#  The estimated number of batches is 1673
#      1672/1    1.18412    1.18264 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0001816043932923 for eigenvalue
#  The estimated number of batches is 1673
#      1673/1    1.17636    1.18264 +/- 0.00016
#  Triggers satisfied for batch 1673
#  Creating state point statepoint.01673.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.2578e+00 seconds
#    Reading cross sections          = 3.1684e+00 seconds
#  Total time in simulation          = 2.2009e+03 seconds
#    Time in transport only          = 2.1203e+03 seconds
#    Time in inactive batches        = 1.4039e+01 seconds
#    Time in active batches          = 2.1869e+03 seconds
#    Time synchronizing fission bank = 4.7486e+00 seconds
#      Sampling source sites         = 3.9116e+00 seconds
#      SEND/RECV source sites        = 8.3548e-01 seconds
#    Time accumulating tallies       = 7.2505e+01 seconds
#    Time writing statepoints        = 9.8537e-01 seconds
#  Total time for finalization       = 2.4314e+01 seconds
#  Total time elapsed                = 2.2288e+03 seconds
#  Calculation Rate (inactive)       = 71228.1 particles/second
#  Calculation Rate (active)         = 37793.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18261 +/- 0.00013
#  k-effective (Track-length)  = 1.18264 +/- 0.00016
#  k-effective (Absorption)    = 1.18248 +/- 0.00011
#  Combined k-effective        = 1.18253 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
