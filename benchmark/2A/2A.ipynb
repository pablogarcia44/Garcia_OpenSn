# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=565

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)

water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=565
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=565
helium.set_density('g/cm3', 0.178E-03 )


model.materials = openmc.Materials([uo2, zirconium, water,helium]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
GT=[(5,2),(8,2),(3,3),(2,5),(5,5),(8,5),(2,8),(5,8)]
IT=[(8,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))
# print(np.array(GT_full)+(1,1))

# %% [markdown]
# ### Create family pincell

# %%
pincell_1_family=pincell('pincell')
guide_1_family=guide('guide')
instru_1_family=instru('instru')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly


size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT :
            A[ix][iy]=instru_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]    

# print(A)           
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1158.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=760.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=768.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-09 14:46:43
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.18895
#         2/1    1.18920
#         3/1    1.18465
#         4/1    1.18316
#         5/1    1.17958
#         6/1    1.18229
#         7/1    1.17958
#         8/1    1.18327
#         9/1    1.18181
#        10/1    1.18381
#        11/1    1.18228
#        12/1    1.17984
#        13/1    1.18332
#        14/1    1.18264
#        15/1    1.19244
#        16/1    1.18015
#        17/1    1.18325
#        18/1    1.18596
#        19/1    1.17958
#        20/1    1.18979
#        21/1    1.19110
#        22/1    1.17533    1.18322 +/- 0.00789
#        23/1    1.19493    1.18712 +/- 0.00600
#        24/1    1.19861    1.19000 +/- 0.00512
#        25/1    1.18802    1.18960 +/- 0.00399
#        26/1    1.18442    1.18874 +/- 0.00337
#        27/1    1.18461    1.18815 +/- 0.00291
#        28/1    1.16646    1.18544 +/- 0.00370
#        29/1    1.17737    1.18454 +/- 0.00338
#        30/1    1.18185    1.18427 +/- 0.00304
#        31/1    1.19515    1.18526 +/- 0.00292
#        32/1    1.18798    1.18549 +/- 0.00268
#        33/1    1.17595    1.18475 +/- 0.00257
#        34/1    1.18805    1.18499 +/- 0.00239
#        35/1    1.18581    1.18504 +/- 0.00223
#        36/1    1.17996    1.18473 +/- 0.00211
#        37/1    1.19202    1.18516 +/- 0.00202
#        38/1    1.18241    1.18500 +/- 0.00191
#        39/1    1.18043    1.18476 +/- 0.00183
#        40/1    1.17313    1.18418 +/- 0.00183
#        41/1    1.19408    1.18465 +/- 0.00180
#        42/1    1.17770    1.18434 +/- 0.00175
#        43/1    1.18018    1.18415 +/- 0.00168
#        44/1    1.18658    1.18426 +/- 0.00161
#        45/1    1.17111    1.18373 +/- 0.00163
#        46/1    1.18151    1.18364 +/- 0.00157
#        47/1    1.19297    1.18399 +/- 0.00155
#        48/1    1.17405    1.18363 +/- 0.00153
#        49/1    1.18428    1.18366 +/- 0.00148
#        50/1    1.17751    1.18345 +/- 0.00145
#  Triggers unsatisfied, max unc./thresh. is 8.257652029184877 for eigenvalue
#  The estimated number of batches is 2066
#  Creating state point statepoint.00050.h5...
#        51/1    1.18627    1.18354 +/- 0.00140
#  Triggers unsatisfied, max unc./thresh. is 7.9901754535153415 for eigenvalue
#  The estimated number of batches is 2000
#        52/1    1.17672    1.18333 +/- 0.00137
#  Triggers unsatisfied, max unc./thresh. is 7.647462230730208 for eigenvalue
#  The estimated number of batches is 1892
#        53/1    1.18365    1.18334 +/- 0.00133
#  Triggers unsatisfied, max unc./thresh. is 7.740358370641077 for eigenvalue
#  The estimated number of batches is 1998
#        54/1    1.18489    1.18339 +/- 0.00129
#  Triggers unsatisfied, max unc./thresh. is 7.43874432263599 for eigenvalue
#  The estimated number of batches is 1902
#        55/1    1.19468    1.18371 +/- 0.00130
#  Triggers unsatisfied, max unc./thresh. is 7.270755612974791 for eigenvalue
#  The estimated number of batches is 1871
#        56/1    1.17591    1.18349 +/- 0.00128
#  Triggers unsatisfied, max unc./thresh. is 7.20531116058363 for eigenvalue
#  The estimated number of batches is 1889
#        57/1    1.17514    1.18327 +/- 0.00126
#  Triggers unsatisfied, max unc./thresh. is 7.475838892208327 for eigenvalue
#  The estimated number of batches is 2088
#        58/1    1.17569    1.18307 +/- 0.00125
#  Triggers unsatisfied, max unc./thresh. is 7.309227542690266 for eigenvalue
#  The estimated number of batches is 2051
#        59/1    1.18921    1.18322 +/- 0.00122
#  Triggers unsatisfied, max unc./thresh. is 7.344138449839244 for eigenvalue
#  The estimated number of batches is 2124
#        60/1    1.18836    1.18335 +/- 0.00120
#  Triggers unsatisfied, max unc./thresh. is 7.372858581571788 for eigenvalue
#  The estimated number of batches is 2195
#        61/1    1.18438    1.18338 +/- 0.00117
#  Triggers unsatisfied, max unc./thresh. is 7.285097780658837 for eigenvalue
#  The estimated number of batches is 2196
#        62/1    1.17486    1.18317 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 7.143059998176597 for eigenvalue
#  The estimated number of batches is 2163
#        63/1    1.18729    1.18327 +/- 0.00114
#  Triggers unsatisfied, max unc./thresh. is 6.979774978042037 for eigenvalue
#  The estimated number of batches is 2115
#        64/1    1.17903    1.18317 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 6.7917269995030445 for eigenvalue
#  The estimated number of batches is 2050
#        65/1    1.17695    1.18304 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 6.67072772381934 for eigenvalue
#  The estimated number of batches is 2023
#        66/1    1.18777    1.18314 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 6.550659863692839 for eigenvalue
#  The estimated number of batches is 1994
#        67/1    1.18239    1.18312 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 6.591351873775552 for eigenvalue
#  The estimated number of batches is 2062
#        68/1    1.18411    1.18314 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.411145342213882 for eigenvalue
#  The estimated number of batches is 1993
#        69/1    1.18398    1.18316 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.254688382936511 for eigenvalue
#  The estimated number of batches is 1937
#        70/1    1.17289    1.18295 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.471962828940105 for eigenvalue
#  The estimated number of batches is 2115
#        71/1    1.18380    1.18297 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 6.357656042776511 for eigenvalue
#  The estimated number of batches is 2082
#        72/1    1.19020    1.18311 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 6.25843871182754 for eigenvalue
#  The estimated number of batches is 2057
#        73/1    1.18498    1.18315 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.168760716803946 for eigenvalue
#  The estimated number of batches is 2037
#        74/1    1.17293    1.18296 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.129763659165022 for eigenvalue
#  The estimated number of batches is 2049
#        75/1    1.17718    1.18285 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.047327074705555 for eigenvalue
#  The estimated number of batches is 2032
#        76/1    1.18351    1.18286 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.95894746689111 for eigenvalue
#  The estimated number of batches is 2009
#        77/1    1.18956    1.18298 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.862825913900748 for eigenvalue
#  The estimated number of batches is 1980
#        78/1    1.17712    1.18288 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.729723425446372 for eigenvalue
#  The estimated number of batches is 1925
#        79/1    1.18171    1.18286 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.679110678953925 for eigenvalue
#  The estimated number of batches is 1923
#        80/1    1.18234    1.18285 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 5.603565240245169 for eigenvalue
#  The estimated number of batches is 1904
#        81/1    1.17785    1.18277 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.552102053892418 for eigenvalue
#  The estimated number of batches is 1901
#        82/1    1.18544    1.18281 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.608408570605008 for eigenvalue
#  The estimated number of batches is 1971
#        83/1    1.19469    1.18300 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.526815960134697 for eigenvalue
#  The estimated number of batches is 1945
#        84/1    1.18305    1.18300 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.427403427101679 for eigenvalue
#  The estimated number of batches is 1906
#        85/1    1.18408    1.18302 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.44511623320831 for eigenvalue
#  The estimated number of batches is 1948
#        86/1    1.19060    1.18313 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.3703455514437355 for eigenvalue
#  The estimated number of batches is 1924
#        87/1    1.18633    1.18318 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.2802513343685336 for eigenvalue
#  The estimated number of batches is 1889
#        88/1    1.17855    1.18311 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.206119984203693 for eigenvalue
#  The estimated number of batches is 1864
#        89/1    1.18901    1.18320 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.139744238394911 for eigenvalue
#  The estimated number of batches is 1843
#        90/1    1.19523    1.18337 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.256158335346288 for eigenvalue
#  The estimated number of batches is 1954
#        91/1    1.17266    1.18322 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.2482069595414815 for eigenvalue
#  The estimated number of batches is 1976
#        92/1    1.18151    1.18320 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.2177236414847235 for eigenvalue
#  The estimated number of batches is 1981
#        93/1    1.18431    1.18321 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.150446668818356 for eigenvalue
#  The estimated number of batches is 1957
#        94/1    1.18725    1.18327 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.158787071887655 for eigenvalue
#  The estimated number of batches is 1990
#        95/1    1.17313    1.18313 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.142639254130321 for eigenvalue
#  The estimated number of batches is 2004
#        96/1    1.18860    1.18320 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.118089735110138 for eigenvalue
#  The estimated number of batches is 2011
#        97/1    1.18653    1.18325 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.066280703469337 for eigenvalue
#  The estimated number of batches is 1997
#        98/1    1.18821    1.18331 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.994292201028053 for eigenvalue
#  The estimated number of batches is 1966
#        99/1    1.18588    1.18334 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.9660523029085715 for eigenvalue
#  The estimated number of batches is 1969
#       100/1    1.17872    1.18328 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.905836523431165 for eigenvalue
#  The estimated number of batches is 1946
#       101/1    1.18621    1.18332 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.86384785424273 for eigenvalue
#  The estimated number of batches is 1937
#       102/1    1.18369    1.18332 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.812500780326228 for eigenvalue
#  The estimated number of batches is 1920
#       103/1    1.18605    1.18336 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.759899386707256 for eigenvalue
#  The estimated number of batches is 1901
#       104/1    1.18494    1.18338 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.71121139061834 for eigenvalue
#  The estimated number of batches is 1885
#       105/1    1.17916    1.18333 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.663894895974282 for eigenvalue
#  The estimated number of batches is 1869
#       106/1    1.18787    1.18338 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.617279552939181 for eigenvalue
#  The estimated number of batches is 1854
#       107/1    1.19233    1.18348 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.5768887867151165 for eigenvalue
#  The estimated number of batches is 1843
#       108/1    1.17812    1.18342 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.518250561033487 for eigenvalue
#  The estimated number of batches is 1817
#       109/1    1.18559    1.18345 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.467443451031886 for eigenvalue
#  The estimated number of batches is 1797
#       110/1    1.18822    1.18350 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.441571804356771 for eigenvalue
#  The estimated number of batches is 1796
#       111/1    1.18604    1.18353 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.408796477621209 for eigenvalue
#  The estimated number of batches is 1789
#       112/1    1.18600    1.18355 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.378934867826224 for eigenvalue
#  The estimated number of batches is 1785
#       113/1    1.18523    1.18357 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.334854664966436 for eigenvalue
#  The estimated number of batches is 1768
#       114/1    1.17939    1.18353 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.2918882744919875 for eigenvalue
#  The estimated number of batches is 1752
#       115/1    1.19200    1.18362 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.259829590933011 for eigenvalue
#  The estimated number of batches is 1744
#       116/1    1.18698    1.18365 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.2792262030002854 for eigenvalue
#  The estimated number of batches is 1778
#       117/1    1.18923    1.18371 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.271565022262223 for eigenvalue
#  The estimated number of batches is 1790
#       118/1    1.17213    1.18359 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.264796193109914 for eigenvalue
#  The estimated number of batches is 1803
#       119/1    1.18423    1.18360 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.23698280405899 for eigenvalue
#  The estimated number of batches is 1798
#       120/1    1.17927    1.18355 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.193812286418759 for eigenvalue
#  The estimated number of batches is 1779
#       121/1    1.18802    1.18360 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.156297756273253 for eigenvalue
#  The estimated number of batches is 1765
#       122/1    1.18272    1.18359 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.114305190992887 for eigenvalue
#  The estimated number of batches is 1747
#       123/1    1.19169    1.18367 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.117142156469264 for eigenvalue
#  The estimated number of batches is 1766
#       124/1    1.18186    1.18365 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.076105200663767 for eigenvalue
#  The estimated number of batches is 1748
#       125/1    1.17809    1.18360 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.027672791530935 for eigenvalue
#  The estimated number of batches is 1724
#       126/1    1.19340    1.18369 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.0115207917326225 for eigenvalue
#  The estimated number of batches is 1726
#       127/1    1.18081    1.18366 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.9885891075042843 for eigenvalue
#  The estimated number of batches is 1723
#       128/1    1.18359    1.18366 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.9708052198074197 for eigenvalue
#  The estimated number of batches is 1723
#       129/1    1.18166    1.18364 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.9357938155957104 for eigenvalue
#  The estimated number of batches is 1709
#       130/1    1.17922    1.18360 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.8942105477131532 for eigenvalue
#  The estimated number of batches is 1689
#       131/1    1.18698    1.18363 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.861840223155735 for eigenvalue
#  The estimated number of batches is 1676
#       132/1    1.18859    1.18368 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.837600696556252 for eigenvalue
#  The estimated number of batches is 1670
#       133/1    1.19329    1.18376 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8252210090224925 for eigenvalue
#  The estimated number of batches is 1674
#       134/1    1.18508    1.18378 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7908934019049494 for eigenvalue
#  The estimated number of batches is 1659
#       135/1    1.18124    1.18375 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7662381643609177 for eigenvalue
#  The estimated number of batches is 1652
#       136/1    1.18521    1.18377 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7378603201466714 for eigenvalue
#  The estimated number of batches is 1641
#       137/1    1.17645    1.18370 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7022206684002756 for eigenvalue
#  The estimated number of batches is 1624
#       138/1    1.17868    1.18366 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.679358457297196 for eigenvalue
#  The estimated number of batches is 1618
#       139/1    1.18203    1.18365 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.657637012440704 for eigenvalue
#  The estimated number of batches is 1613
#       140/1    1.19043    1.18370 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.652712644094737 for eigenvalue
#  The estimated number of batches is 1622
#       141/1    1.17992    1.18367 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.620052014132326 for eigenvalue
#  The estimated number of batches is 1606
#       142/1    1.17653    1.18361 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.581575307914046 for eigenvalue
#  The estimated number of batches is 1585
#       143/1    1.17827    1.18357 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.545672908326633 for eigenvalue
#  The estimated number of batches is 1567
#       144/1    1.17553    1.18351 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.51843871873424 for eigenvalue
#  The estimated number of batches is 1556
#       145/1    1.18037    1.18348 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.4888645742702273 for eigenvalue
#  The estimated number of batches is 1542
#       146/1    1.18912    1.18353 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5156140892126833 for eigenvalue
#  The estimated number of batches is 1578
#       147/1    1.17967    1.18350 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.4830932342096537 for eigenvalue
#  The estimated number of batches is 1561
#       148/1    1.18049    1.18347 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.467116003741311 for eigenvalue
#  The estimated number of batches is 1559
#       149/1    1.18518    1.18348 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.449314840571513 for eigenvalue
#  The estimated number of batches is 1555
#       150/1    1.18305    1.18348 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.425492491685386 for eigenvalue
#  The estimated number of batches is 1546
#       151/1    1.18566    1.18350 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.403045524605048 for eigenvalue
#  The estimated number of batches is 1538
#       152/1    1.18731    1.18353 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3949397493645836 for eigenvalue
#  The estimated number of batches is 1542
#       153/1    1.18340    1.18353 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.380724644296162 for eigenvalue
#  The estimated number of batches is 1541
#       154/1    1.17281    1.18345 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3607532327431695 for eigenvalue
#  The estimated number of batches is 1534
#       155/1    1.17669    1.18340 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3297450218488023 for eigenvalue
#  The estimated number of batches is 1517
#       156/1    1.18236    1.18339 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3334687568988124 for eigenvalue
#  The estimated number of batches is 1532
#       157/1    1.18651    1.18341 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.309556862138524 for eigenvalue
#  The estimated number of batches is 1521
#       158/1    1.18631    1.18343 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.301845484639085 for eigenvalue
#  The estimated number of batches is 1525
#       159/1    1.17870    1.18340 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2891970454657957 for eigenvalue
#  The estimated number of batches is 1524
#       160/1    1.18829    1.18343 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.268776467453819 for eigenvalue
#  The estimated number of batches is 1516
#       161/1    1.18656    1.18346 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2483229086480456 for eigenvalue
#  The estimated number of batches is 1508
#       162/1    1.17917    1.18343 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.242419530866538 for eigenvalue
#  The estimated number of batches is 1513
#       163/1    1.18241    1.18342 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.220877714282139 for eigenvalue
#  The estimated number of batches is 1504
#       164/1    1.17824    1.18338 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2183747834461647 for eigenvalue
#  The estimated number of batches is 1512
#       165/1    1.18804    1.18341 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.210673454113033 for eigenvalue
#  The estimated number of batches is 1515
#       166/1    1.18329    1.18341 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.18901748583013 for eigenvalue
#  The estimated number of batches is 1505
#       167/1    1.17452    1.18335 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2177479378641256 for eigenvalue
#  The estimated number of batches is 1543
#       168/1    1.18186    1.18334 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1997632651834773 for eigenvalue
#  The estimated number of batches is 1536
#       169/1    1.17651    1.18330 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2360661542480407 for eigenvalue
#  The estimated number of batches is 1581
#       170/1    1.17714    1.18326 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.20885484735514 for eigenvalue
#  The estimated number of batches is 1565
#       171/1    1.18587    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1898585871780316 for eigenvalue
#  The estimated number of batches is 1557
#       172/1    1.18306    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1707238797109474 for eigenvalue
#  The estimated number of batches is 1549
#       173/1    1.18334    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1620090926184803 for eigenvalue
#  The estimated number of batches is 1550
#       174/1    1.18930    1.18331 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.175034319721732 for eigenvalue
#  The estimated number of batches is 1573
#       175/1    1.17486    1.18326 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1791906862388224 for eigenvalue
#  The estimated number of batches is 1587
#       176/1    1.17622    1.18321 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.160634761023154 for eigenvalue
#  The estimated number of batches is 1579
#       177/1    1.18838    1.18324 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1439475497458917 for eigenvalue
#  The estimated number of batches is 1572
#       178/1    1.17538    1.18319 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1263331906376983 for eigenvalue
#  The estimated number of batches is 1565
#       179/1    1.17341    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0995572054232694 for eigenvalue
#  The estimated number of batches is 1548
#       180/1    1.18191    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0791371783218335 for eigenvalue
#  The estimated number of batches is 1537
#       181/1    1.19198    1.18318 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.075409221200619 for eigenvalue
#  The estimated number of batches is 1543
#       182/1    1.17599    1.18314 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.05521968212432 for eigenvalue
#  The estimated number of batches is 1533
#       183/1    1.18267    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0360500871988565 for eigenvalue
#  The estimated number of batches is 1523
#       184/1    1.18895    1.18317 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0507820955044505 for eigenvalue
#  The estimated number of batches is 1547
#       185/1    1.18434    1.18318 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0345285634643653 for eigenvalue
#  The estimated number of batches is 1540
#       186/1    1.18829    1.18321 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0228331613520805 for eigenvalue
#  The estimated number of batches is 1537
#       187/1    1.18484    1.18322 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.003925517268532 for eigenvalue
#  The estimated number of batches is 1527
#       188/1    1.17975    1.18320 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.994242888336131 for eigenvalue
#  The estimated number of batches is 1527
#       189/1    1.18035    1.18318 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9861742967311167 for eigenvalue
#  The estimated number of batches is 1528
#       190/1    1.17871    1.18315 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.972526744097438 for eigenvalue
#  The estimated number of batches is 1523
#       191/1    1.18348    1.18315 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.960590573524276 for eigenvalue
#  The estimated number of batches is 1519
#       192/1    1.18133    1.18314 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9585168681186027 for eigenvalue
#  The estimated number of batches is 1526
#       193/1    1.17409    1.18309 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.952501003289239 for eigenvalue
#  The estimated number of batches is 1529
#       194/1    1.17701    1.18306 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9438587994249104 for eigenvalue
#  The estimated number of batches is 1528
#       195/1    1.17170    1.18299 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9229680800315543 for eigenvalue
#  The estimated number of batches is 1516
#       196/1    1.18143    1.18298 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9268710305921597 for eigenvalue
#  The estimated number of batches is 1528
#       197/1    1.18983    1.18302 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9136834666082163 for eigenvalue
#  The estimated number of batches is 1523
#       198/1    1.17061    1.18295 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.893387148247776 for eigenvalue
#  The estimated number of batches is 1511
#       199/1    1.18308    1.18295 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8863466846919206 for eigenvalue
#  The estimated number of batches is 1512
#       200/1    1.17964    1.18293 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8678692512916655 for eigenvalue
#  The estimated number of batches is 1501
#       201/1    1.17850    1.18291 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8601612425166807 for eigenvalue
#  The estimated number of batches is 1501
#       202/1    1.18662    1.18293 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.845039921980161 for eigenvalue
#  The estimated number of batches is 1494
#       203/1    1.17619    1.18289 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8378335000718464 for eigenvalue
#  The estimated number of batches is 1494
#       204/1    1.17673    1.18286 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.820785932254658 for eigenvalue
#  The estimated number of batches is 1485
#       205/1    1.18568    1.18288 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.828905313296308 for eigenvalue
#  The estimated number of batches is 1501
#       206/1    1.18551    1.18289 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.829846180536124 for eigenvalue
#  The estimated number of batches is 1510
#       207/1    1.18473    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.813692617638895 for eigenvalue
#  The estimated number of batches is 1501
#       208/1    1.18283    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.800099012526135 for eigenvalue
#  The estimated number of batches is 1495
#       209/1    1.18388    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8001537295009387 for eigenvalue
#  The estimated number of batches is 1502
#       210/1    1.17962    1.18289 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.789052643000284 for eigenvalue
#  The estimated number of batches is 1498
#       211/1    1.17581    1.18285 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.772858702639655 for eigenvalue
#  The estimated number of batches is 1489
#       212/1    1.18353    1.18285 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.76073426441798 for eigenvalue
#  The estimated number of batches is 1484
#       213/1    1.17621    1.18282 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.772638352212483 for eigenvalue
#  The estimated number of batches is 1504
#       214/1    1.17808    1.18279 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.756233867426622 for eigenvalue
#  The estimated number of batches is 1494
#       215/1    1.17687    1.18276 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.746094794859307 for eigenvalue
#  The estimated number of batches is 1491
#       216/1    1.17674    1.18273 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7736858346977455 for eigenvalue
#  The estimated number of batches is 1528
#       217/1    1.18010    1.18272 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7627134365973416 for eigenvalue
#  The estimated number of batches is 1524
#       218/1    1.17819    1.18270 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.752264139571377 for eigenvalue
#  The estimated number of batches is 1520
#       219/1    1.17463    1.18266 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.754390088038692 for eigenvalue
#  The estimated number of batches is 1530
#       220/1    1.19196    1.18270 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7426337168920205 for eigenvalue
#  The estimated number of batches is 1525
#       221/1    1.19281    1.18275 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7455491509173875 for eigenvalue
#  The estimated number of batches is 1536
#       222/1    1.18753    1.18278 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7343474821554397 for eigenvalue
#  The estimated number of batches is 1531
#       223/1    1.18852    1.18281 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.725860643224466 for eigenvalue
#  The estimated number of batches is 1529
#       224/1    1.18579    1.18282 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7167461890969626 for eigenvalue
#  The estimated number of batches is 1526
#       225/1    1.18541    1.18283 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.703702778940764 for eigenvalue
#  The estimated number of batches is 1519
#       226/1    1.18070    1.18282 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7126996066179436 for eigenvalue
#  The estimated number of batches is 1536
#       227/1    1.18267    1.18282 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7071605216544343 for eigenvalue
#  The estimated number of batches is 1538
#       228/1    1.18011    1.18281 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.693085731189432 for eigenvalue
#  The estimated number of batches is 1529
#       229/1    1.18322    1.18281 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6811988811595753 for eigenvalue
#  The estimated number of batches is 1523
#       230/1    1.19363    1.18286 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.705324606761665 for eigenvalue
#  The estimated number of batches is 1557
#       231/1    1.18121    1.18285 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.694031108146258 for eigenvalue
#  The estimated number of batches is 1552
#       232/1    1.18775    1.18288 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.682074826999128 for eigenvalue
#  The estimated number of batches is 1546
#       233/1    1.18684    1.18290 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.671741576249324 for eigenvalue
#  The estimated number of batches is 1541
#       234/1    1.17905    1.18288 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.661506067123904 for eigenvalue
#  The estimated number of batches is 1536
#       235/1    1.18108    1.18287 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6647694127173445 for eigenvalue
#  The estimated number of batches is 1547
#       236/1    1.18452    1.18288 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.658144991427827 for eigenvalue
#  The estimated number of batches is 1547
#       237/1    1.18650    1.18289 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.655517579945573 for eigenvalue
#  The estimated number of batches is 1551
#       238/1    1.18315    1.18289 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6430726864247567 for eigenvalue
#  The estimated number of batches is 1543
#       239/1    1.18890    1.18292 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6336227901710925 for eigenvalue
#  The estimated number of batches is 1539
#       240/1    1.18425    1.18293 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6216077276554857 for eigenvalue
#  The estimated number of batches is 1533
#       241/1    1.19549    1.18299 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.619429412702825 for eigenvalue
#  The estimated number of batches is 1537
#       242/1    1.18398    1.18299 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6077094937027576 for eigenvalue
#  The estimated number of batches is 1530
#       243/1    1.18454    1.18300 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6092799940833094 for eigenvalue
#  The estimated number of batches is 1539
#       244/1    1.18998    1.18303 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.600360193476751 for eigenvalue
#  The estimated number of batches is 1535
#       245/1    1.18166    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.603959751938169 for eigenvalue
#  The estimated number of batches is 1546
#       246/1    1.18343    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.594245730763143 for eigenvalue
#  The estimated number of batches is 1542
#       247/1    1.18557    1.18303 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6003067005886 for eigenvalue
#  The estimated number of batches is 1555
#       248/1    1.18102    1.18303 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.58781638314516 for eigenvalue
#  The estimated number of batches is 1547
#       249/1    1.19202    1.18307 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.607536856139914 for eigenvalue
#  The estimated number of batches is 1578
#       250/1    1.19006    1.18310 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.600604453948595 for eigenvalue
#  The estimated number of batches is 1576
#       251/1    1.18884    1.18312 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.592410062000271 for eigenvalue
#  The estimated number of batches is 1573
#       252/1    1.18000    1.18311 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.585191217486346 for eigenvalue
#  The estimated number of batches is 1571
#       253/1    1.17462    1.18307 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.575287386464175 for eigenvalue
#  The estimated number of batches is 1566
#       254/1    1.17516    1.18304 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5659526986415986 for eigenvalue
#  The estimated number of batches is 1561
#       255/1    1.17554    1.18300 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5531321969765592 for eigenvalue
#  The estimated number of batches is 1552
#       256/1    1.17206    1.18296 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5570451797976648 for eigenvalue
#  The estimated number of batches is 1564
#       257/1    1.17772    1.18294 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.551359031717746 for eigenvalue
#  The estimated number of batches is 1563
#       258/1    1.19026    1.18297 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5473657238543352 for eigenvalue
#  The estimated number of batches is 1565
#       259/1    1.19052    1.18300 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.53773001711785 for eigenvalue
#  The estimated number of batches is 1560
#       260/1    1.18846    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5379050590793852 for eigenvalue
#  The estimated number of batches is 1566
#       261/1    1.18333    1.18302 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5392324943244304 for eigenvalue
#  The estimated number of batches is 1574
#       262/1    1.17690    1.18300 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5270071778256376 for eigenvalue
#  The estimated number of batches is 1566
#       263/1    1.17997    1.18299 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.514011970461194 for eigenvalue
#  The estimated number of batches is 1556
#       264/1    1.18205    1.18298 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5019796175368088 for eigenvalue
#  The estimated number of batches is 1548
#       265/1    1.18660    1.18300 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4919211053129637 for eigenvalue
#  The estimated number of batches is 1542
#       266/1    1.17496    1.18296 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.481239838637327 for eigenvalue
#  The estimated number of batches is 1535
#       267/1    1.17081    1.18291 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4697120219164503 for eigenvalue
#  The estimated number of batches is 1527
#       268/1    1.17010    1.18286 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4571363181519614 for eigenvalue
#  The estimated number of batches is 1518
#       269/1    1.18221    1.18286 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.45916673467165 for eigenvalue
#  The estimated number of batches is 1526
#       270/1    1.17797    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4703544599105314 for eigenvalue
#  The estimated number of batches is 1546
#       271/1    1.18265    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4653943670044796 for eigenvalue
#  The estimated number of batches is 1546
#       272/1    1.18230    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.455958808059171 for eigenvalue
#  The estimated number of batches is 1540
#       273/1    1.19090    1.18287 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.446858958186611 for eigenvalue
#  The estimated number of batches is 1535
#       274/1    1.18451    1.18288 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4416118779638434 for eigenvalue
#  The estimated number of batches is 1535
#       275/1    1.17708    1.18285 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.431420282526104 for eigenvalue
#  The estimated number of batches is 1528
#       276/1    1.18797    1.18287 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4363522291457977 for eigenvalue
#  The estimated number of batches is 1540
#       277/1    1.17963    1.18286 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.429766147357353 for eigenvalue
#  The estimated number of batches is 1538
#       278/1    1.18071    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4205451988410145 for eigenvalue
#  The estimated number of batches is 1532
#       279/1    1.18173    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.415713999940329 for eigenvalue
#  The estimated number of batches is 1532
#       280/1    1.18359    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.406423749552548 for eigenvalue
#  The estimated number of batches is 1526
#       281/1    1.17434    1.18282 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4053470817143108 for eigenvalue
#  The estimated number of batches is 1531
#       282/1    1.18184    1.18281 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3968251537411494 for eigenvalue
#  The estimated number of batches is 1526
#       283/1    1.18875    1.18284 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3888556437075317 for eigenvalue
#  The estimated number of batches is 1521
#       284/1    1.17109    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.381608013542419 for eigenvalue
#  The estimated number of batches is 1518
#       285/1    1.19050    1.18282 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.376654496919138 for eigenvalue
#  The estimated number of batches is 1517
#       286/1    1.17464    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3729741977710836 for eigenvalue
#  The estimated number of batches is 1518
#       287/1    1.18520    1.18280 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3652001691853553 for eigenvalue
#  The estimated number of batches is 1514
#       288/1    1.18146    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3573096025735656 for eigenvalue
#  The estimated number of batches is 1510
#       289/1    1.18596    1.18281 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3502111180576457 for eigenvalue
#  The estimated number of batches is 1506
#       290/1    1.17985    1.18280 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.341291340670203 for eigenvalue
#  The estimated number of batches is 1501
#       291/1    1.17764    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3329054774310207 for eigenvalue
#  The estimated number of batches is 1495
#       292/1    1.18585    1.18279 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.324453640316201 for eigenvalue
#  The estimated number of batches is 1490
#       293/1    1.17713    1.18277 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.320409833289049 for eigenvalue
#  The estimated number of batches is 1490
#       294/1    1.18757    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3313004434434803 for eigenvalue
#  The estimated number of batches is 1510
#       295/1    1.17669    1.18276 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3488932442012156 for eigenvalue
#  The estimated number of batches is 1538
#       296/1    1.18925    1.18279 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3411513991228308 for eigenvalue
#  The estimated number of batches is 1533
#       297/1    1.18048    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.33257743596831 for eigenvalue
#  The estimated number of batches is 1528
#       298/1    1.17242    1.18274 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3273263144890763 for eigenvalue
#  The estimated number of batches is 1526
#       299/1    1.18100    1.18273 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3320160771276126 for eigenvalue
#  The estimated number of batches is 1538
#       300/1    1.18851    1.18275 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3267156083392035 for eigenvalue
#  The estimated number of batches is 1536
#       301/1    1.18143    1.18275 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3180720317513357 for eigenvalue
#  The estimated number of batches is 1530
#       302/1    1.17661    1.18273 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.310338481121355 for eigenvalue
#  The estimated number of batches is 1526
#       303/1    1.17694    1.18271 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.319503360464571 for eigenvalue
#  The estimated number of batches is 1543
#       304/1    1.17230    1.18267 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3411308148193952 for eigenvalue
#  The estimated number of batches is 1577
#       305/1    1.18872    1.18269 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.337812376283692 for eigenvalue
#  The estimated number of batches is 1578
#       306/1    1.18354    1.18270 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.330743850133098 for eigenvalue
#  The estimated number of batches is 1574
#       307/1    1.18225    1.18269 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.323990018258427 for eigenvalue
#  The estimated number of batches is 1571
#       308/1    1.18886    1.18272 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3245388468382497 for eigenvalue
#  The estimated number of batches is 1577
#       309/1    1.19059    1.18274 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.324888132248511 for eigenvalue
#  The estimated number of batches is 1583
#       310/1    1.17009    1.18270 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.352457410297288 for eigenvalue
#  The estimated number of batches is 1625
#       311/1    1.17642    1.18268 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3449747537648156 for eigenvalue
#  The estimated number of batches is 1621
#       312/1    1.17662    1.18266 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.338089942624126 for eigenvalue
#  The estimated number of batches is 1617
#       313/1    1.17217    1.18262 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3476386335464 for eigenvalue
#  The estimated number of batches is 1635
#       314/1    1.19139    1.18265 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3406512158050354 for eigenvalue
#  The estimated number of batches is 1631
#       315/1    1.18205    1.18265 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.333446233759631 for eigenvalue
#  The estimated number of batches is 1627
#       316/1    1.18320    1.18265 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.327408749421812 for eigenvalue
#  The estimated number of batches is 1624
#       317/1    1.18719    1.18267 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3231615542142117 for eigenvalue
#  The estimated number of batches is 1623
#       318/1    1.17901    1.18265 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3164085433319297 for eigenvalue
#  The estimated number of batches is 1619
#       319/1    1.18718    1.18267 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.311776156080791 for eigenvalue
#  The estimated number of batches is 1618
#       320/1    1.18890    1.18269 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.309865460660451 for eigenvalue
#  The estimated number of batches is 1621
#       321/1    1.17666    1.18267 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3172433490092286 for eigenvalue
#  The estimated number of batches is 1637
#       322/1    1.18017    1.18266 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.326239109431598 for eigenvalue
#  The estimated number of batches is 1655
#       323/1    1.16709    1.18261 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3209559729539215 for eigenvalue
#  The estimated number of batches is 1653
#       324/1    1.18517    1.18262 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.314376978652264 for eigenvalue
#  The estimated number of batches is 1649
#       325/1    1.17009    1.18258 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3276797872701263 for eigenvalue
#  The estimated number of batches is 1673
#       326/1    1.17454    1.18255 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3247729459637463 for eigenvalue
#  The estimated number of batches is 1674
#       327/1    1.18830    1.18257 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3204133497107415 for eigenvalue
#  The estimated number of batches is 1673
#       328/1    1.18109    1.18256 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.312978051130339 for eigenvalue
#  The estimated number of batches is 1668
#       329/1    1.18272    1.18256 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3046102425196184 for eigenvalue
#  The estimated number of batches is 1662
#       330/1    1.19017    1.18259 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.308056458887134 for eigenvalue
#  The estimated number of batches is 1672
#       331/1    1.18169    1.18259 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3073627860189867 for eigenvalue
#  The estimated number of batches is 1676
#       332/1    1.18180    1.18258 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3017746524263503 for eigenvalue
#  The estimated number of batches is 1674
#       333/1    1.18285    1.18258 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2938913512378885 for eigenvalue
#  The estimated number of batches is 1667
#       334/1    1.17520    1.18256 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.287245696494934 for eigenvalue
#  The estimated number of batches is 1663
#       335/1    1.18487    1.18257 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.281835831263619 for eigenvalue
#  The estimated number of batches is 1661
#       336/1    1.18128    1.18256 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2757383631879375 for eigenvalue
#  The estimated number of batches is 1657
#       337/1    1.18114    1.18256 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2713970109533634 for eigenvalue
#  The estimated number of batches is 1656
#       338/1    1.18222    1.18256 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.264568533694672 for eigenvalue
#  The estimated number of batches is 1651
#       339/1    1.17992    1.18255 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2586163386128466 for eigenvalue
#  The estimated number of batches is 1648
#       340/1    1.18068    1.18254 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.252028168913016 for eigenvalue
#  The estimated number of batches is 1643
#       341/1    1.18383    1.18255 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2441935111462743 for eigenvalue
#  The estimated number of batches is 1637
#       342/1    1.18225    1.18255 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.238716084334086 for eigenvalue
#  The estimated number of batches is 1634
#       343/1    1.18687    1.18256 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.233536990931292 for eigenvalue
#  The estimated number of batches is 1632
#       344/1    1.18106    1.18256 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2278543761348995 for eigenvalue
#  The estimated number of batches is 1629
#       345/1    1.18117    1.18255 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2197821015368246 for eigenvalue
#  The estimated number of batches is 1622
#       346/1    1.18264    1.18255 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2132084445442164 for eigenvalue
#  The estimated number of batches is 1617
#       347/1    1.18931    1.18257 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2121614165290917 for eigenvalue
#  The estimated number of batches is 1621
#       348/1    1.17963    1.18256 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2042528764017226 for eigenvalue
#  The estimated number of batches is 1614
#       349/1    1.19026    1.18259 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2042580761577266 for eigenvalue
#  The estimated number of batches is 1619
#       350/1    1.18391    1.18259 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.198204065081119 for eigenvalue
#  The estimated number of batches is 1615
#       351/1    1.19724    1.18264 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1996996958305606 for eigenvalue
#  The estimated number of batches is 1622
#       352/1    1.19373    1.18267 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1978790076669004 for eigenvalue
#  The estimated number of batches is 1624
#       353/1    1.17977    1.18266 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1905249534189126 for eigenvalue
#  The estimated number of batches is 1618
#       354/1    1.19041    1.18268 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1850683174439016 for eigenvalue
#  The estimated number of batches is 1615
#       355/1    1.18891    1.18270 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1791951408889525 for eigenvalue
#  The estimated number of batches is 1611
#       356/1    1.18451    1.18271 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1762358265434414 for eigenvalue
#  The estimated number of batches is 1612
#       357/1    1.19075    1.18273 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1719934489372847 for eigenvalue
#  The estimated number of batches is 1610
#       358/1    1.18663    1.18274 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1676336383702175 for eigenvalue
#  The estimated number of batches is 1609
#       359/1    1.18646    1.18275 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1612743171141164 for eigenvalue
#  The estimated number of batches is 1604
#       360/1    1.17716    1.18274 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1548092458755037 for eigenvalue
#  The estimated number of batches is 1599
#       361/1    1.18898    1.18276 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.149256364792829 for eigenvalue
#  The estimated number of batches is 1596
#       362/1    1.18919    1.18278 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.143809690144628 for eigenvalue
#  The estimated number of batches is 1592
#       363/1    1.18924    1.18279 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.139707261279468 for eigenvalue
#  The estimated number of batches is 1591
#       364/1    1.18403    1.18280 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.134620421859878 for eigenvalue
#  The estimated number of batches is 1588
#       365/1    1.18341    1.18280 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.1304025282695918 for eigenvalue
#  The estimated number of batches is 1586
#       366/1    1.17790    1.18279 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.1281133764864384 for eigenvalue
#  The estimated number of batches is 1587
#       367/1    1.17229    1.18275 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.1208836678934535 for eigenvalue
#  The estimated number of batches is 1581
#       368/1    1.18168    1.18275 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.1148152889377574 for eigenvalue
#  The estimated number of batches is 1577
