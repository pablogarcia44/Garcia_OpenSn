# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %% [markdown]
# def instru(index_x,index_y):
#     clad_inner_radius = openmc.ZCylinder(r=0.559)
#     clad_outer_radius = openmc.ZCylinder(r=0.605)
#     pitch = 1.26
#     left = openmc.XPlane(-pitch/2, boundary_type='transmission')
#     right = openmc.XPlane(pitch/2, boundary_type='transmission')
#     bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
#     top = openmc.YPlane(pitch/2, boundary_type='transmission')
#     clad_region = +clad_inner_radius & -clad_outer_radius
#     water_region = +left & -right & +bottom & -top & +clad_outer_radius
#     water_guide_region= -clad_inner_radius
#     water_guide = openmc.Cell(name='water_guide'+'_'+str(index_x)+'_'+str(index_y))
#     water_guide.fill = water
#     water_guide.region = water_guide_region
#     clad = openmc.Cell(name='clad_guide'+'_'+str(index_x)+'_'+str(index_y))
#     clad.fill = zirconium
#     clad.region = clad_region
#     moderator = openmc.Cell(name='moderator'+'_'+str(index_x)+'_'+str(index_y))
#     moderator.fill = water
#     moderator.region = water_region
#     u = openmc.Universe(name='u_guide'+'_'+str(index_x)+'_'+str(index_y),cells=(water_guide, clad, moderator))
#     return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create Instrument Thimble

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    instru_inner_radius = openmc.ZCylinder(0.258)
    instry_outer_radius= openmc.ZCylinder(0.382)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission') 

    
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius | -instru_inner_radius | +instry_outer_radius & -clad_inner_radius
    instru_region = +instru_inner_radius & -instry_outer_radius

    water_cell = openmc.Cell(name='water_cell'+family)
    water_cell.fill = water
    water_cell.region = water_region
    clad_cell = openmc.Cell(name='clad_cell'+family)
    clad_cell.fill = zirconium
    clad_cell.region = clad_region
    instru_cell = openmc.Cell(name='instru_cell'+family)
    instru_cell.fill = SS304
    instru_cell.region = instru_region
    
    u = openmc.Universe(name='u_guide'+family,cells=(water_cell, clad_cell, instru_cell))
    return(u,water_cell,clad_cell,instru_cell)

# %% [markdown]
# ### Mappping

# %%
GT=[(8,2),(3,3),(5,5),(2,8),(5,2),(2,5),(8,5),(5,8)]
IT=[(8,8)]


GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:09
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.18836
#         2/1    1.18519
#         3/1    1.18092
#         4/1    1.17476
#         5/1    1.18234
#         6/1    1.17652
#         7/1    1.18125
#         8/1    1.18323
#         9/1    1.17643
#        10/1    1.17805
#        11/1    1.17264
#        12/1    1.18587
#        13/1    1.17773
#        14/1    1.17787
#        15/1    1.18693
#        16/1    1.18307
#        17/1    1.18189
#        18/1    1.18463
#        19/1    1.18337
#        20/1    1.18182
#        21/1    1.17841
#        22/1    1.17968    1.17905 +/- 0.00064
#        23/1    1.17869    1.17893 +/- 0.00039
#        24/1    1.18049    1.17932 +/- 0.00048
#        25/1    1.19052    1.18156 +/- 0.00227
#        26/1    1.18964    1.18291 +/- 0.00229
#        27/1    1.18506    1.18321 +/- 0.00196
#        28/1    1.17266    1.18189 +/- 0.00215
#        29/1    1.17743    1.18140 +/- 0.00196
#        30/1    1.18668    1.18193 +/- 0.00183
#        31/1    1.18273    1.18200 +/- 0.00166
#        32/1    1.18521    1.18227 +/- 0.00154
#        33/1    1.17322    1.18157 +/- 0.00158
#        34/1    1.17807    1.18132 +/- 0.00148
#        35/1    1.18767    1.18174 +/- 0.00144
#        36/1    1.18193    1.18176 +/- 0.00135
#        37/1    1.18147    1.18174 +/- 0.00127
#        38/1    1.17948    1.18161 +/- 0.00120
#        39/1    1.18536    1.18181 +/- 0.00115
#        40/1    1.18594    1.18202 +/- 0.00111
#        41/1    1.15825    1.18089 +/- 0.00155
#        42/1    1.18569    1.18110 +/- 0.00149
#        43/1    1.17968    1.18104 +/- 0.00143
#        44/1    1.18455    1.18119 +/- 0.00138
#        45/1    1.17999    1.18114 +/- 0.00132
#        46/1    1.18075    1.18113 +/- 0.00127
#        47/1    1.18426    1.18124 +/- 0.00123
#        48/1    1.17257    1.18093 +/- 0.00122
#        49/1    1.18083    1.18093 +/- 0.00118
#        50/1    1.16471    1.18039 +/- 0.00126
#  Triggers unsatisfied, max unc./thresh. is 6.090345075160925 for eigenvalue
#  The estimated number of batches is 1133
#  Creating state point statepoint.00050.h5...
#        51/1    1.17574    1.18024 +/- 0.00123
#  Triggers unsatisfied, max unc./thresh. is 5.933368504504687 for eigenvalue
#  The estimated number of batches is 1112
#        52/1    1.18135    1.18027 +/- 0.00119
#  Triggers unsatisfied, max unc./thresh. is 5.838327466959781 for eigenvalue
#  The estimated number of batches is 1111
#        53/1    1.17516    1.18012 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 5.717704503303137 for eigenvalue
#  The estimated number of batches is 1099
#        54/1    1.18188    1.18017 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 5.503975934446178 for eigenvalue
#  The estimated number of batches is 1050
#        55/1    1.18034    1.18017 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 5.6162091841865545 for eigenvalue
#  The estimated number of batches is 1124
#        56/1    1.18408    1.18028 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 5.380772588534383 for eigenvalue
#  The estimated number of batches is 1063
#        57/1    1.18946    1.18053 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 5.284067858760565 for eigenvalue
#  The estimated number of batches is 1054
#        58/1    1.18537    1.18066 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 5.135217382462516 for eigenvalue
#  The estimated number of batches is 1023
#        59/1    1.17733    1.18057 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 5.026742591279758 for eigenvalue
#  The estimated number of batches is 1006
#        60/1    1.17425    1.18041 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 4.985835747828633 for eigenvalue
#  The estimated number of batches is 1015
#        61/1    1.17512    1.18029 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 4.9581247366704195 for eigenvalue
#  The estimated number of batches is 1028
#        62/1    1.18313    1.18035 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 4.830033525670603 for eigenvalue
#  The estimated number of batches is 1000
#        63/1    1.18501    1.18046 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 4.906537434852651 for eigenvalue
#  The estimated number of batches is 1056
#        64/1    1.17911    1.18043 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 4.828832366237193 for eigenvalue
#  The estimated number of batches is 1046
#        65/1    1.18588    1.18055 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 4.8848012387908915 for eigenvalue
#  The estimated number of batches is 1094
#        66/1    1.17983    1.18054 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.840171183122986 for eigenvalue
#  The estimated number of batches is 1098
#        67/1    1.17849    1.18049 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 4.743476343788396 for eigenvalue
#  The estimated number of batches is 1078
#        68/1    1.17405    1.18036 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.681193203671578 for eigenvalue
#  The estimated number of batches is 1072
#        69/1    1.18602    1.18047 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.794007011176974 for eigenvalue
#  The estimated number of batches is 1147
#        70/1    1.18294    1.18052 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.706796980474326 for eigenvalue
#  The estimated number of batches is 1128
#        71/1    1.19515    1.18081 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.865957625817919 for eigenvalue
#  The estimated number of batches is 1228
#        72/1    1.18510    1.18089 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.854343345400801 for eigenvalue
#  The estimated number of batches is 1246
#        73/1    1.16615    1.18061 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.755652198947109 for eigenvalue
#  The estimated number of batches is 1219
#        74/1    1.17286    1.18047 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 4.680048449780035 for eigenvalue
#  The estimated number of batches is 1203
#        75/1    1.18150    1.18049 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.598576462614492 for eigenvalue
#  The estimated number of batches is 1184
#        76/1    1.18069    1.18049 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 4.524065530702042 for eigenvalue
#  The estimated number of batches is 1167
#        77/1    1.18522    1.18058 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.497220787540885 for eigenvalue
#  The estimated number of batches is 1173
#        78/1    1.18206    1.18060 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.427557076507245 for eigenvalue
#  The estimated number of batches is 1157
#        79/1    1.17991    1.18059 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 4.358439079527556 for eigenvalue
#  The estimated number of batches is 1141
#        80/1    1.17436    1.18049 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.2916267994166954 for eigenvalue
#  The estimated number of batches is 1126
#        81/1    1.17431    1.18038 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.32103327701054 for eigenvalue
#  The estimated number of batches is 1159
#        82/1    1.18558    1.18047 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.24363420964696 for eigenvalue
#  The estimated number of batches is 1137
#        83/1    1.17823    1.18043 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.228042964780135 for eigenvalue
#  The estimated number of batches is 1147
#        84/1    1.18137    1.18045 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.253526618969635 for eigenvalue
#  The estimated number of batches is 1178
#        85/1    1.17303    1.18033 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.337319300520766 for eigenvalue
#  The estimated number of batches is 1243
#        86/1    1.17974    1.18032 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.366758902940041 for eigenvalue
#  The estimated number of batches is 1279
#        87/1    1.17733    1.18028 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.319386372860356 for eigenvalue
#  The estimated number of batches is 1271
#        88/1    1.18555    1.18036 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.289645086872527 for eigenvalue
#  The estimated number of batches is 1272
#        89/1    1.17944    1.18034 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.266821009742223 for eigenvalue
#  The estimated number of batches is 1277
#        90/1    1.17653    1.18029 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.380654289671794 for eigenvalue
#  The estimated number of batches is 1364
#        91/1    1.17599    1.18023 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.32810188537786 for eigenvalue
#  The estimated number of batches is 1351
#        92/1    1.17353    1.18014 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.300828383884269 for eigenvalue
#  The estimated number of batches is 1352
#        93/1    1.18531    1.18021 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.244815794534199 for eigenvalue
#  The estimated number of batches is 1336
#        94/1    1.19084    1.18035 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.300674009030512 for eigenvalue
#  The estimated number of batches is 1389
#        95/1    1.18057    1.18035 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.289362848670986 for eigenvalue
#  The estimated number of batches is 1400
#        96/1    1.17789    1.18032 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.232461300473746 for eigenvalue
#  The estimated number of batches is 1382
#        97/1    1.17698    1.18028 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.179506213313332 for eigenvalue
#  The estimated number of batches is 1366
#        98/1    1.18628    1.18035 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.124254660604578 for eigenvalue
#  The estimated number of batches is 1347
#        99/1    1.18127    1.18037 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.073017000577098 for eigenvalue
#  The estimated number of batches is 1331
#       100/1    1.17928    1.18035 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.021331336482267 for eigenvalue
#  The estimated number of batches is 1314
#       101/1    1.18183    1.18037 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.975437049970556 for eigenvalue
#  The estimated number of batches is 1301
#       102/1    1.17911    1.18036 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.933166587300807 for eigenvalue
#  The estimated number of batches is 1289
#       103/1    1.17740    1.18032 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.8980121607067773 for eigenvalue
#  The estimated number of batches is 1282
#       104/1    1.17597    1.18027 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.911387103954165 for eigenvalue
#  The estimated number of batches is 1306
#       105/1    1.17900    1.18025 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.9024800656730667 for eigenvalue
#  The estimated number of batches is 1315
#       106/1    1.17591    1.18020 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.8597695775587075 for eigenvalue
#  The estimated number of batches is 1302
#       107/1    1.18913    1.18031 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.8259613154813823 for eigenvalue
#  The estimated number of batches is 1294
#       108/1    1.19743    1.18050 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.056535197098289 for eigenvalue
#  The estimated number of batches is 1469
#       109/1    1.19062    1.18061 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.005942732333852 for eigenvalue
#  The estimated number of batches is 1449
#       110/1    1.16934    1.18049 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.131644427881651 for eigenvalue
#  The estimated number of batches is 1557
#       111/1    1.17553    1.18043 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.115357849445324 for eigenvalue
#  The estimated number of batches is 1562
#       112/1    1.18999    1.18054 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.06708998432735 for eigenvalue
#  The estimated number of batches is 1542
#       113/1    1.18060    1.18054 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.032409516598933 for eigenvalue
#  The estimated number of batches is 1533
#       114/1    1.18666    1.18060 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.024688625378086 for eigenvalue
#  The estimated number of batches is 1543
#       115/1    1.17510    1.18055 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.076375026823645 for eigenvalue
#  The estimated number of batches is 1599
#       116/1    1.17632    1.18050 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.041718066674639 for eigenvalue
#  The estimated number of batches is 1589
#       117/1    1.17699    1.18047 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.00377158224674 for eigenvalue
#  The estimated number of batches is 1575
#       118/1    1.17379    1.18040 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.006149015596115 for eigenvalue
#  The estimated number of batches is 1593
#       119/1    1.18063    1.18040 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.966486170279665 for eigenvalue
#  The estimated number of batches is 1578
#       120/1    1.17905    1.18039 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.9271353675929004 for eigenvalue
#  The estimated number of batches is 1563
#       121/1    1.17711    1.18035 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.9109333079267663 for eigenvalue
#  The estimated number of batches is 1565
#       122/1    1.17308    1.18028 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.9091436998528897 for eigenvalue
#  The estimated number of batches is 1579
#       123/1    1.18801    1.18036 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.870093712537702 for eigenvalue
#  The estimated number of batches is 1563
#       124/1    1.18203    1.18037 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.850938967837853 for eigenvalue
#  The estimated number of batches is 1563
#       125/1    1.17855    1.18036 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.816485677399405 for eigenvalue
#  The estimated number of batches is 1550
#       126/1    1.18529    1.18040 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8010341860852592 for eigenvalue
#  The estimated number of batches is 1552
#       127/1    1.18284    1.18043 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7836242025541003 for eigenvalue
#  The estimated number of batches is 1552
#       128/1    1.17699    1.18039 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7522258539245064 for eigenvalue
#  The estimated number of batches is 1541
#       129/1    1.17940    1.18038 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.71784160764067 for eigenvalue
#  The estimated number of batches is 1527
#       130/1    1.19258    1.18050 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.799479473070789 for eigenvalue
#  The estimated number of batches is 1608
#       131/1    1.18049    1.18050 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.764285271208144 for eigenvalue
#  The estimated number of batches is 1593
#       132/1    1.17201    1.18042 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.739755926173481 for eigenvalue
#  The estimated number of batches is 1587
#       133/1    1.17116    1.18034 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7304084948839695 for eigenvalue
#  The estimated number of batches is 1593
#       134/1    1.18817    1.18041 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.700513611604082 for eigenvalue
#  The estimated number of batches is 1582
#       135/1    1.17851    1.18039 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.669073655409963 for eigenvalue
#  The estimated number of batches is 1569
#       136/1    1.18311    1.18041 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.636924803667069 for eigenvalue
#  The estimated number of batches is 1555
#       137/1    1.16598    1.18029 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.6203202073019702 for eigenvalue
#  The estimated number of batches is 1554
#       138/1    1.18064    1.18029 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5893216560958425 for eigenvalue
#  The estimated number of batches is 1541
#       139/1    1.15799    1.18011 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6121232865453123 for eigenvalue
#  The estimated number of batches is 1573
#       140/1    1.18597    1.18015 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.619284887644544 for eigenvalue
#  The estimated number of batches is 1592
#       141/1    1.18129    1.18016 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.6045996709855697 for eigenvalue
#  The estimated number of batches is 1593
#       142/1    1.18518    1.18021 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.5731596001801837 for eigenvalue
#  The estimated number of batches is 1578
#       143/1    1.18238    1.18022 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.5450142172565378 for eigenvalue
#  The estimated number of batches is 1566
#       144/1    1.18641    1.18027 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5150842313112785 for eigenvalue
#  The estimated number of batches is 1553
#       145/1    1.17523    1.18023 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.49321447975623 for eigenvalue
#  The estimated number of batches is 1546
#       146/1    1.18343    1.18026 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.4733513632504738 for eigenvalue
#  The estimated number of batches is 1541
#       147/1    1.17286    1.18020 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5143787806404463 for eigenvalue
#  The estimated number of batches is 1589
#       148/1    1.17621    1.18017 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4917856650969967 for eigenvalue
#  The estimated number of batches is 1581
#       149/1    1.19090    1.18025 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4746289654592086 for eigenvalue
#  The estimated number of batches is 1578
#       150/1    1.18647    1.18030 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.448709440212336 for eigenvalue
#  The estimated number of batches is 1567
#       151/1    1.18413    1.18033 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4249172238411707 for eigenvalue
#  The estimated number of batches is 1557
#       152/1    1.17441    1.18028 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.415303389898943 for eigenvalue
#  The estimated number of batches is 1560
#       153/1    1.18652    1.18033 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.394747304866555 for eigenvalue
#  The estimated number of batches is 1553
#       154/1    1.18055    1.18033 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.373202211397267 for eigenvalue
#  The estimated number of batches is 1545
#       155/1    1.17750    1.18031 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3515769918489977 for eigenvalue
#  The estimated number of batches is 1537
#       156/1    1.18148    1.18032 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3313122897824408 for eigenvalue
#  The estimated number of batches is 1530
#       157/1    1.17116    1.18025 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.311262133558036 for eigenvalue
#  The estimated number of batches is 1523
#       158/1    1.18675    1.18030 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.311612590110945 for eigenvalue
#  The estimated number of batches is 1534
#       159/1    1.17681    1.18027 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.2906879297359586 for eigenvalue
#  The estimated number of batches is 1526
#       160/1    1.18178    1.18029 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2668796521939156 for eigenvalue
#  The estimated number of batches is 1515
#       161/1    1.18348    1.18031 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2452242197551113 for eigenvalue
#  The estimated number of batches is 1505
#       162/1    1.17244    1.18025 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2270182613321956 for eigenvalue
#  The estimated number of batches is 1499
#       163/1    1.17860    1.18024 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.208953009761147 for eigenvalue
#  The estimated number of batches is 1493
#       164/1    1.17972    1.18024 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.1891935371347437 for eigenvalue
#  The estimated number of batches is 1485
#       165/1    1.19536    1.18034 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.207538197758743 for eigenvalue
#  The estimated number of batches is 1512
#       166/1    1.18036    1.18034 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.1920623074122956 for eigenvalue
#  The estimated number of batches is 1508
#       167/1    1.18756    1.18039 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.176718648971485 for eigenvalue
#  The estimated number of batches is 1504
#       168/1    1.17922    1.18038 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.1759251929534926 for eigenvalue
#  The estimated number of batches is 1513
#       169/1    1.17931    1.18038 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.169406634464165 for eigenvalue
#  The estimated number of batches is 1517
#       170/1    1.18723    1.18042 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1496741364291916 for eigenvalue
#  The estimated number of batches is 1509
#       171/1    1.17143    1.18036 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.143515683562959 for eigenvalue
#  The estimated number of batches is 1513
#       172/1    1.17354    1.18032 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1241052465801955 for eigenvalue
#  The estimated number of batches is 1504
#       173/1    1.18205    1.18033 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.112913436004681 for eigenvalue
#  The estimated number of batches is 1503
#       174/1    1.18341    1.18035 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1147218602146967 for eigenvalue
#  The estimated number of batches is 1515
#       175/1    1.17465    1.18031 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.0985995709276803 for eigenvalue
#  The estimated number of batches is 1509
#       176/1    1.18412    1.18034 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.087885819305046 for eigenvalue
#  The estimated number of batches is 1508
#       177/1    1.17041    1.18027 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.0705969671098394 for eigenvalue
#  The estimated number of batches is 1501
#       178/1    1.18896    1.18033 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.0582477862921125 for eigenvalue
#  The estimated number of batches is 1498
#       179/1    1.17462    1.18029 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.0427024134151606 for eigenvalue
#  The estimated number of batches is 1493
#       180/1    1.18252    1.18031 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.044989425539108 for eigenvalue
#  The estimated number of batches is 1504
#       181/1    1.18552    1.18034 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.024433871369071 for eigenvalue
#  The estimated number of batches is 1493
#       182/1    1.18463    1.18036 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.007447476243877 for eigenvalue
#  The estimated number of batches is 1486
#       183/1    1.17569    1.18034 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0060461028036074 for eigenvalue
#  The estimated number of batches is 1493
#       184/1    1.18989    1.18039 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.990167098437718 for eigenvalue
#  The estimated number of batches is 1487
#       185/1    1.17133    1.18034 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.973065705690187 for eigenvalue
#  The estimated number of batches is 1479
#       186/1    1.17086    1.18028 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.97269131871415 for eigenvalue
#  The estimated number of batches is 1487
#       187/1    1.19191    1.18035 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.95705598868066 for eigenvalue
#  The estimated number of batches is 1481
#       188/1    1.18246    1.18036 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.9397121049495096 for eigenvalue
#  The estimated number of batches is 1472
#       189/1    1.17477    1.18033 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.9277949680091524 for eigenvalue
#  The estimated number of batches is 1469
#       190/1    1.17741    1.18031 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.932114340690382 for eigenvalue
#  The estimated number of batches is 1482
#       191/1    1.17819    1.18030 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9760860734337884 for eigenvalue
#  The estimated number of batches is 1535
#       192/1    1.18561    1.18033 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9597450712570588 for eigenvalue
#  The estimated number of batches is 1527
#       193/1    1.18279    1.18035 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9968032844164347 for eigenvalue
#  The estimated number of batches is 1574
#       194/1    1.18207    1.18036 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.986949961539915 for eigenvalue
#  The estimated number of batches is 1573
#       195/1    1.17787    1.18034 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9694655289346263 for eigenvalue
#  The estimated number of batches is 1564
#       196/1    1.18456    1.18037 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9503948407909335 for eigenvalue
#  The estimated number of batches is 1553
#       197/1    1.18711    1.18040 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9333996891529304 for eigenvalue
#  The estimated number of batches is 1544
#       198/1    1.18931    1.18045 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9153777292244865 for eigenvalue
#  The estimated number of batches is 1533
#       199/1    1.17945    1.18045 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.90938371389296 for eigenvalue
#  The estimated number of batches is 1536
#       200/1    1.18558    1.18048 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.8987443966005735 for eigenvalue
#  The estimated number of batches is 1533
#       201/1    1.18818    1.18052 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.8864129462529697 for eigenvalue
#  The estimated number of batches is 1528
#       202/1    1.17090    1.18047 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.8715555806445585 for eigenvalue
#  The estimated number of batches is 1521
#       203/1    1.18167    1.18047 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.860041094313451 for eigenvalue
#  The estimated number of batches is 1517
#       204/1    1.18149    1.18048 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8457723316503998 for eigenvalue
#  The estimated number of batches is 1511
#       205/1    1.19009    1.18053 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.831107490504349 for eigenvalue
#  The estimated number of batches is 1503
#       206/1    1.17700    1.18051 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.829803444710152 for eigenvalue
#  The estimated number of batches is 1510
#       207/1    1.18412    1.18053 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.812069239711447 for eigenvalue
#  The estimated number of batches is 1499
#       208/1    1.18832    1.18057 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.805918290138448 for eigenvalue
#  The estimated number of batches is 1501
#       209/1    1.18425    1.18059 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.7904948545278505 for eigenvalue
#  The estimated number of batches is 1492
#       210/1    1.17770    1.18058 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8024365679845986 for eigenvalue
#  The estimated number of batches is 1513
#       211/1    1.17613    1.18055 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.787343333235713 for eigenvalue
#  The estimated number of batches is 1504
#       212/1    1.17751    1.18054 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.771967968284993 for eigenvalue
#  The estimated number of batches is 1496
#       213/1    1.18834    1.18058 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7826342117335696 for eigenvalue
#  The estimated number of batches is 1515
#       214/1    1.17067    1.18053 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.769750144627296 for eigenvalue
#  The estimated number of batches is 1509
#       215/1    1.18577    1.18055 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.755044344229064 for eigenvalue
#  The estimated number of batches is 1501
#       216/1    1.17520    1.18053 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7653911020618582 for eigenvalue
#  The estimated number of batches is 1519
#       217/1    1.17795    1.18051 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.752052255010516 for eigenvalue
#  The estimated number of batches is 1513
#       218/1    1.20033    1.18061 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.754322165226634 for eigenvalue
#  The estimated number of batches is 1523
#       219/1    1.17003    1.18056 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7414230535818116 for eigenvalue
#  The estimated number of batches is 1516
#       220/1    1.18193    1.18057 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7326747169822907 for eigenvalue
#  The estimated number of batches is 1514
#       221/1    1.19178    1.18062 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.726713082934652 for eigenvalue
#  The estimated number of batches is 1515
#       222/1    1.17328    1.18059 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.714003943163928 for eigenvalue
#  The estimated number of batches is 1508
#       223/1    1.18466    1.18061 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7061202900687165 for eigenvalue
#  The estimated number of batches is 1507
#       224/1    1.19007    1.18065 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7002639765437992 for eigenvalue
#  The estimated number of batches is 1508
#       225/1    1.18697    1.18068 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.6855630852744516 for eigenvalue
#  The estimated number of batches is 1499
#       226/1    1.18759    1.18072 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.686473106652281 for eigenvalue
#  The estimated number of batches is 1507
#       227/1    1.17818    1.18071 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.677203429559286 for eigenvalue
#  The estimated number of batches is 1504
#       228/1    1.18952    1.18075 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.6690178290726743 for eigenvalue
#  The estimated number of batches is 1502
#       229/1    1.17943    1.18074 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6561600027249854 for eigenvalue
#  The estimated number of batches is 1495
#       230/1    1.18603    1.18077 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6529644059844704 for eigenvalue
#  The estimated number of batches is 1499
#       231/1    1.18282    1.18078 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6491338530037845 for eigenvalue
#  The estimated number of batches is 1501
#       232/1    1.18260    1.18079 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6401599443386883 for eigenvalue
#  The estimated number of batches is 1498
#       233/1    1.17942    1.18078 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6314521445899066 for eigenvalue
#  The estimated number of batches is 1495
#       234/1    1.17347    1.18074 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.620535253618944 for eigenvalue
#  The estimated number of batches is 1490
#       235/1    1.17919    1.18074 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6076341396108615 for eigenvalue
#  The estimated number of batches is 1482
#       236/1    1.17408    1.18071 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6035286272454607 for eigenvalue
#  The estimated number of batches is 1485
#       237/1    1.19845    1.18079 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6145897637108177 for eigenvalue
#  The estimated number of batches is 1504
#       238/1    1.18085    1.18079 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.609432653547517 for eigenvalue
#  The estimated number of batches is 1505
#       239/1    1.17799    1.18078 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6136579041582317 for eigenvalue
#  The estimated number of batches is 1517
#       240/1    1.18415    1.18079 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6016365479132912 for eigenvalue
#  The estimated number of batches is 1510
#       241/1    1.18820    1.18082 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.602022649761293 for eigenvalue
#  The estimated number of batches is 1517
#       242/1    1.18700    1.18085 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.607643818464382 for eigenvalue
#  The estimated number of batches is 1530
#       243/1    1.18582    1.18087 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.5994132142497324 for eigenvalue
#  The estimated number of batches is 1527
#       244/1    1.18655    1.18090 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.608128748324962 for eigenvalue
#  The estimated number of batches is 1544
#       245/1    1.18266    1.18091 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6164604301826855 for eigenvalue
#  The estimated number of batches is 1561
#       246/1    1.18227    1.18091 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6045778791946357 for eigenvalue
#  The estimated number of batches is 1554
#       247/1    1.17162    1.18087 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6032377260514488 for eigenvalue
#  The estimated number of batches is 1559
#       248/1    1.17208    1.18083 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.593646277670357 for eigenvalue
#  The estimated number of batches is 1554
#       249/1    1.16893    1.18078 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.5821520372706113 for eigenvalue
#  The estimated number of batches is 1547
#       250/1    1.17609    1.18076 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.57438797872098 for eigenvalue
#  The estimated number of batches is 1545
#       251/1    1.18196    1.18077 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5837151294157255 for eigenvalue
#  The estimated number of batches is 1563
#       252/1    1.17764    1.18075 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.596816472871507 for eigenvalue
#  The estimated number of batches is 1585
#       253/1    1.18595    1.18078 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.585495912903906 for eigenvalue
#  The estimated number of batches is 1578
#       254/1    1.19042    1.18082 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.57867230071443 for eigenvalue
#  The estimated number of batches is 1576
#       255/1    1.17495    1.18079 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5704215700363378 for eigenvalue
#  The estimated number of batches is 1573
#       256/1    1.18469    1.18081 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.562862221916145 for eigenvalue
#  The estimated number of batches is 1571
#       257/1    1.18135    1.18081 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.553838018081488 for eigenvalue
#  The estimated number of batches is 1566
#       258/1    1.17950    1.18081 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5488914233440605 for eigenvalue
#  The estimated number of batches is 1567
#       259/1    1.19224    1.18085 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.544634108856166 for eigenvalue
#  The estimated number of batches is 1568
#       260/1    1.17359    1.18082 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5396987363232646 for eigenvalue
#  The estimated number of batches is 1569
#       261/1    1.17678    1.18081 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5299690632964307 for eigenvalue
#  The estimated number of batches is 1563
#       262/1    1.17632    1.18079 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.518915670821498 for eigenvalue
#  The estimated number of batches is 1556
#       263/1    1.17963    1.18078 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.508818856608258 for eigenvalue
#  The estimated number of batches is 1550
#       264/1    1.18354    1.18079 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4989800116409007 for eigenvalue
#  The estimated number of batches is 1544
#       265/1    1.16614    1.18073 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5008868194629255 for eigenvalue
#  The estimated number of batches is 1553
#       266/1    1.17375    1.18071 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5034651869646134 for eigenvalue
#  The estimated number of batches is 1562
#       267/1    1.18959    1.18074 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5054873276016343 for eigenvalue
#  The estimated number of batches is 1571
#       268/1    1.17763    1.18073 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4956361262371844 for eigenvalue
#  The estimated number of batches is 1565
#       269/1    1.19303    1.18078 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.487708441929601 for eigenvalue
#  The estimated number of batches is 1561
#       270/1    1.18148    1.18078 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4786651098483654 for eigenvalue
#  The estimated number of batches is 1556
#       271/1    1.18564    1.18080 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.469633898303455 for eigenvalue
#  The estimated number of batches is 1551
#       272/1    1.18146    1.18080 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4600063934787597 for eigenvalue
#  The estimated number of batches is 1546
#       273/1    1.17663    1.18079 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.457447593569611 for eigenvalue
#  The estimated number of batches is 1548
#       274/1    1.18467    1.18080 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4628985569451127 for eigenvalue
#  The estimated number of batches is 1561
#       275/1    1.17539    1.18078 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4538195492613055 for eigenvalue
#  The estimated number of batches is 1556
#       276/1    1.18431    1.18080 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.445090221347873 for eigenvalue
#  The estimated number of batches is 1551
#       277/1    1.18769    1.18082 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.436513510524475 for eigenvalue
#  The estimated number of batches is 1546
#       278/1    1.17638    1.18080 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4282814355140165 for eigenvalue
#  The estimated number of batches is 1542
#       279/1    1.18760    1.18083 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.422403698914982 for eigenvalue
#  The estimated number of batches is 1540
#       280/1    1.18061    1.18083 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4128217009425046 for eigenvalue
#  The estimated number of batches is 1534
#       281/1    1.18891    1.18086 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4168788417031584 for eigenvalue
#  The estimated number of batches is 1545
#       282/1    1.17111    1.18082 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4072043862325985 for eigenvalue
#  The estimated number of batches is 1539
#       283/1    1.17067    1.18079 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.409259115796066 for eigenvalue
#  The estimated number of batches is 1547
#       284/1    1.18615    1.18081 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.400861612046934 for eigenvalue
#  The estimated number of batches is 1542
#       285/1    1.18494    1.18082 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.396902443667923 for eigenvalue
#  The estimated number of batches is 1543
#       286/1    1.17730    1.18081 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3917204038055977 for eigenvalue
#  The estimated number of batches is 1542
#       287/1    1.18656    1.18083 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.385063032178007 for eigenvalue
#  The estimated number of batches is 1539
#       288/1    1.18506    1.18085 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3762946841919677 for eigenvalue
#  The estimated number of batches is 1534
#       289/1    1.17577    1.18083 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3672256185781695 for eigenvalue
#  The estimated number of batches is 1528
#       290/1    1.18054    1.18083 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3588266316154707 for eigenvalue
#  The estimated number of batches is 1523
#       291/1    1.18819    1.18085 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.368449538021781 for eigenvalue
#  The estimated number of batches is 1541
#       292/1    1.17763    1.18084 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.377779358589214 for eigenvalue
#  The estimated number of batches is 1558
#       293/1    1.18723    1.18086 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.374028872634896 for eigenvalue
#  The estimated number of batches is 1559
#       294/1    1.17539    1.18084 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.367721330258822 for eigenvalue
#  The estimated number of batches is 1557
#       295/1    1.18058    1.18084 +/- 0.00039
# ...
#  The estimated number of batches is 1726
#       623/1    1.19480    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.682687422971917 for eigenvalue
#  The estimated number of batches is 1728
#       624/1    1.17815    1.18102 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6800882004288058 for eigenvalue
#  The estimated number of batches is 1725
#       625/1    1.19251    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6775343024274152 for eigenvalue
#  The estimated number of batches is 1723
#       626/1    1.17976    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.675862312632201 for eigenvalue
#  The estimated number of batches is 1722
#       627/1    1.17411    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6743024612080466 for eigenvalue
#  The estimated number of batches is 1722
#       628/1    1.17896    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6714843188500812 for eigenvalue
#  The estimated number of batches is 1719
#       629/1    1.18023    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6690634744089388 for eigenvalue
#  The estimated number of batches is 1717
#       630/1    1.19506    1.18105 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6686963880306254 for eigenvalue
#  The estimated number of batches is 1719
#       631/1    1.18517    1.18106 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6660488355643448 for eigenvalue
#  The estimated number of batches is 1716
#       632/1    1.16189    1.18102 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.666660940518426 for eigenvalue
#  The estimated number of batches is 1720
#       633/1    1.17890    1.18102 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6642839509687495 for eigenvalue
#  The estimated number of batches is 1718
#       634/1    1.19471    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6624238000011544 for eigenvalue
#  The estimated number of batches is 1717
#       635/1    1.17593    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6602482136562806 for eigenvalue
#  The estimated number of batches is 1716
#       636/1    1.17761    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.657863037431197 for eigenvalue
#  The estimated number of batches is 1714
#       637/1    1.18038    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.655093969704227 for eigenvalue
#  The estimated number of batches is 1711
#       638/1    1.17699    1.18102 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6569341142680816 for eigenvalue
#  The estimated number of batches is 1717
#       639/1    1.18111    1.18102 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.657055205152157 for eigenvalue
#  The estimated number of batches is 1720
#       640/1    1.18640    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.654521349270595 for eigenvalue
#  The estimated number of batches is 1718
#       641/1    1.17901    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6534287448906042 for eigenvalue
#  The estimated number of batches is 1718
#       642/1    1.18346    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6509125891359888 for eigenvalue
#  The estimated number of batches is 1716
#       643/1    1.18424    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6494689135559464 for eigenvalue
#  The estimated number of batches is 1716
#       644/1    1.17199    1.18102 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6467337864250675 for eigenvalue
#  The estimated number of batches is 1713
#       645/1    1.19113    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6442547053035428 for eigenvalue
#  The estimated number of batches is 1710
#       646/1    1.17278    1.18102 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6425016853033256 for eigenvalue
#  The estimated number of batches is 1709
#       647/1    1.18468    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6396184514745094 for eigenvalue
#  The estimated number of batches is 1706
#       648/1    1.18545    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6372781772395222 for eigenvalue
#  The estimated number of batches is 1704
#       649/1    1.17735    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6390870547071763 for eigenvalue
#  The estimated number of batches is 1710
#       650/1    1.18054    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.636642003426629 for eigenvalue
#  The estimated number of batches is 1708
#       651/1    1.18887    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6340469985659603 for eigenvalue
#  The estimated number of batches is 1705
#       652/1    1.17755    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.631463040766177 for eigenvalue
#  The estimated number of batches is 1703
#       653/1    1.17207    1.18102 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6307496002171546 for eigenvalue
#  The estimated number of batches is 1704
#       654/1    1.18254    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6296576921534527 for eigenvalue
#  The estimated number of batches is 1704
#       655/1    1.18497    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6274898535555555 for eigenvalue
#  The estimated number of batches is 1702
#       656/1    1.18507    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6255782776822947 for eigenvalue
#  The estimated number of batches is 1701
#       657/1    1.18015    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.623813722228944 for eigenvalue
#  The estimated number of batches is 1700
#       658/1    1.17369    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6229474134801072 for eigenvalue
#  The estimated number of batches is 1701
#       659/1    1.18327    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6209456910430482 for eigenvalue
#  The estimated number of batches is 1699
#       660/1    1.18512    1.18104 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6189163306731975 for eigenvalue
#  The estimated number of batches is 1698
#       661/1    1.17590    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6165426901340993 for eigenvalue
#  The estimated number of batches is 1696
#       662/1    1.18050    1.18103 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.614527197386081 for eigenvalue
#  The estimated number of batches is 1694
#       663/1    1.17147    1.18101 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6118688047229563 for eigenvalue
#  The estimated number of batches is 1691
#       664/1    1.17446    1.18100 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6110594442236486 for eigenvalue
#  The estimated number of batches is 1692
#       665/1    1.16965    1.18098 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6098258522778728 for eigenvalue
#  The estimated number of batches is 1692
#       666/1    1.18115    1.18098 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6075326027737147 for eigenvalue
#  The estimated number of batches is 1690
#       667/1    1.18422    1.18099 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6063537958192955 for eigenvalue
#  The estimated number of batches is 1690
#       668/1    1.17496    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.6039360255909163 for eigenvalue
#  The estimated number of batches is 1688
#       669/1    1.18161    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.6021409920645935 for eigenvalue
#  The estimated number of batches is 1686
#       670/1    1.18095    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5995609939484545 for eigenvalue
#  The estimated number of batches is 1684
#       671/1    1.18096    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5976724201836658 for eigenvalue
#  The estimated number of batches is 1682
#       672/1    1.18416    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5956397436616294 for eigenvalue
#  The estimated number of batches is 1681
#       673/1    1.18629    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5937333603281696 for eigenvalue
#  The estimated number of batches is 1679
#       674/1    1.18054    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5936862372086573 for eigenvalue
#  The estimated number of batches is 1682
#       675/1    1.17164    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5927873540578084 for eigenvalue
#  The estimated number of batches is 1682
#       676/1    1.18426    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5929636300568577 for eigenvalue
#  The estimated number of batches is 1685
#       677/1    1.18783    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5906483889212433 for eigenvalue
#  The estimated number of batches is 1683
#       678/1    1.18800    1.18100 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.590786475442672 for eigenvalue
#  The estimated number of batches is 1686
#       679/1    1.16839    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5903521067708668 for eigenvalue
#  The estimated number of batches is 1687
#       680/1    1.18414    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5888047155970038 for eigenvalue
#  The estimated number of batches is 1687
#       681/1    1.18177    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5865608485061937 for eigenvalue
#  The estimated number of batches is 1684
#       682/1    1.17650    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5842137661098215 for eigenvalue
#  The estimated number of batches is 1682
#       683/1    1.17908    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.581820244902921 for eigenvalue
#  The estimated number of batches is 1679
#       684/1    1.18323    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5794437166127644 for eigenvalue
#  The estimated number of batches is 1677
#       685/1    1.17823    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5770204091484563 for eigenvalue
#  The estimated number of batches is 1674
#       686/1    1.18765    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.574793051104136 for eigenvalue
#  The estimated number of batches is 1672
#       687/1    1.18268    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5743079890558316 for eigenvalue
#  The estimated number of batches is 1674
#       688/1    1.18623    1.18100 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.572884846361922 for eigenvalue
#  The estimated number of batches is 1673
#       689/1    1.18899    1.18101 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5713264896464096 for eigenvalue
#  The estimated number of batches is 1672
#       690/1    1.17265    1.18100 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5727772197789873 for eigenvalue
#  The estimated number of batches is 1678
#       691/1    1.16904    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.572464950238137 for eigenvalue
#  The estimated number of batches is 1680
#       692/1    1.18360    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5712382899414574 for eigenvalue
#  The estimated number of batches is 1680
#       693/1    1.18441    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.568933554329754 for eigenvalue
#  The estimated number of batches is 1677
#       694/1    1.18017    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5666519263913121 for eigenvalue
#  The estimated number of batches is 1675
#       695/1    1.18090    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5644251454159934 for eigenvalue
#  The estimated number of batches is 1673
#       696/1    1.18710    1.18100 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5627503092839767 for eigenvalue
#  The estimated number of batches is 1671
#       697/1    1.18684    1.18101 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.560602317371666 for eigenvalue
#  The estimated number of batches is 1669
#       698/1    1.18061    1.18101 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5601199705306026 for eigenvalue
#  The estimated number of batches is 1671
#       699/1    1.17064    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5580745697685952 for eigenvalue
#  The estimated number of batches is 1669
#       700/1    1.17981    1.18099 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5560900224560317 for eigenvalue
#  The estimated number of batches is 1667
#       701/1    1.17285    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5627146198224693 for eigenvalue
#  The estimated number of batches is 1684
#       702/1    1.18199    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5611048042332434 for eigenvalue
#  The estimated number of batches is 1683
#       703/1    1.18106    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.558918568627015 for eigenvalue
#  The estimated number of batches is 1680
#       704/1    1.17748    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.557066106508193 for eigenvalue
#  The estimated number of batches is 1679
#       705/1    1.18005    1.18097 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5548438542685192 for eigenvalue
#  The estimated number of batches is 1677
#       706/1    1.17489    1.18097 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5529391368330148 for eigenvalue
#  The estimated number of batches is 1675
#       707/1    1.17484    1.18096 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.551901972355404 for eigenvalue
#  The estimated number of batches is 1675
#       708/1    1.17798    1.18095 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5506442361257573 for eigenvalue
#  The estimated number of batches is 1675
#       709/1    1.16543    1.18093 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5493424571610852 for eigenvalue
#  The estimated number of batches is 1674
#       710/1    1.18423    1.18093 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5471634299254138 for eigenvalue
#  The estimated number of batches is 1672
#       711/1    1.19187    1.18095 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5489239831278918 for eigenvalue
#  The estimated number of batches is 1678
#       712/1    1.18880    1.18096 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.547366882740988 for eigenvalue
#  The estimated number of batches is 1677
#       713/1    1.19144    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.546787792494415 for eigenvalue
#  The estimated number of batches is 1679
#       714/1    1.17674    1.18097 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5446581624662294 for eigenvalue
#  The estimated number of batches is 1676
#       715/1    1.18595    1.18098 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.542492501705648 for eigenvalue
#  The estimated number of batches is 1674
#       716/1    1.18532    1.18098 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5413192864190897 for eigenvalue
#  The estimated number of batches is 1674
#       717/1    1.18202    1.18099 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5392522883907438 for eigenvalue
#  The estimated number of batches is 1672
#       718/1    1.18033    1.18098 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5370479566920632 for eigenvalue
#  The estimated number of batches is 1670
#       719/1    1.16532    1.18096 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5373241791037489 for eigenvalue
#  The estimated number of batches is 1672
