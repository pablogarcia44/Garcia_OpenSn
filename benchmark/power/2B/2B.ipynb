# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)

water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.661)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.178E-03 )


model.materials = openmc.Materials([uo2, zirconium, water,helium]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
GT=[(5,2),(8,2),(3,3),(2,5),(5,5),(8,5),(2,8),(5,8)]
IT=[(8,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))
print(np.array(GT_full)+(1,1))
# Out:
# [[ 4 14]
#  [12  3]
#  [12  6]
#  [12  9]
#  [ 3  6]
#  [12 15]
#  [ 3 12]
#  [12 12]
#  [ 3  9]
#  [ 4  4]
#  [ 9  3]
#  [ 9  6]
#  [ 9 12]
#  [ 9 15]
#  [14 14]
#  [15  6]
#  [15 12]
#  [ 6  3]
#  [15  9]
#  [ 6  6]
#  [ 6 12]
#  [ 6  9]
#  [ 6 15]
#  [14  4]]

# %% [markdown]
# ### Create family pincell

# %%
pincell_1_family=pincell('pincell')
guide_1_family=guide('guide')
instru_1_family=instru('instru')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly


size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT :
            A[ix][iy]=instru_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]    

# print(A)           
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:40
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.17762
#         2/1    1.17864
#         3/1    1.18974
#         4/1    1.18141
#         5/1    1.19237
#         6/1    1.18129
#         7/1    1.19379
#         8/1    1.18852
#         9/1    1.19209
#        10/1    1.18415
#        11/1    1.18307
#        12/1    1.17635
#        13/1    1.17895
#        14/1    1.17946
#        15/1    1.17387
#        16/1    1.18499
#        17/1    1.18483
#        18/1    1.18518
#        19/1    1.18419
#        20/1    1.18518
#        21/1    1.19565
#        22/1    1.18220    1.18893 +/- 0.00673
#        23/1    1.17908    1.18564 +/- 0.00509
#        24/1    1.18894    1.18647 +/- 0.00369
#        25/1    1.18357    1.18589 +/- 0.00292
#        26/1    1.19082    1.18671 +/- 0.00252
#        27/1    1.18200    1.18604 +/- 0.00223
#        28/1    1.17877    1.18513 +/- 0.00214
#        29/1    1.17469    1.18397 +/- 0.00221
#        30/1    1.18301    1.18387 +/- 0.00198
#        31/1    1.19365    1.18476 +/- 0.00200
#        32/1    1.19055    1.18525 +/- 0.00189
#        33/1    1.17551    1.18450 +/- 0.00189
#        34/1    1.17780    1.18402 +/- 0.00182
#        35/1    1.17425    1.18337 +/- 0.00181
#        36/1    1.19342    1.18400 +/- 0.00181
#        37/1    1.17725    1.18360 +/- 0.00174
#        38/1    1.19453    1.18421 +/- 0.00175
#        39/1    1.18967    1.18449 +/- 0.00168
#        40/1    1.18556    1.18455 +/- 0.00160
#        41/1    1.18976    1.18480 +/- 0.00154
#        42/1    1.17745    1.18446 +/- 0.00150
#        43/1    1.18289    1.18439 +/- 0.00144
#        44/1    1.18492    1.18442 +/- 0.00138
#        45/1    1.17806    1.18416 +/- 0.00135
#        46/1    1.17965    1.18399 +/- 0.00131
#        47/1    1.17535    1.18367 +/- 0.00130
#        48/1    1.17857    1.18349 +/- 0.00126
#        49/1    1.17230    1.18310 +/- 0.00128
#        50/1    1.18725    1.18324 +/- 0.00124
#  Triggers unsatisfied, max unc./thresh. is 5.921082415298627 for eigenvalue
#  The estimated number of batches is 1072
#  Creating state point statepoint.00050.h5...
#        51/1    1.19204    1.18352 +/- 0.00123
#  Triggers unsatisfied, max unc./thresh. is 5.698192982868466 for eigenvalue
#  The estimated number of batches is 1027
#        52/1    1.18009    1.18342 +/- 0.00120
#  Triggers unsatisfied, max unc./thresh. is 5.888667796383441 for eigenvalue
#  The estimated number of batches is 1130
#        53/1    1.16603    1.18289 +/- 0.00128
#  Triggers unsatisfied, max unc./thresh. is 5.856429262843126 for eigenvalue
#  The estimated number of batches is 1152
#        54/1    1.18036    1.18281 +/- 0.00124
#  Triggers unsatisfied, max unc./thresh. is 5.68057494326964 for eigenvalue
#  The estimated number of batches is 1118
#        55/1    1.18789    1.18296 +/- 0.00121
#  Triggers unsatisfied, max unc./thresh. is 5.502093416636272 for eigenvalue
#  The estimated number of batches is 1080
#        56/1    1.18070    1.18290 +/- 0.00118
#  Triggers unsatisfied, max unc./thresh. is 5.406958795101474 for eigenvalue
#  The estimated number of batches is 1073
#        57/1    1.17861    1.18278 +/- 0.00115
#  Triggers unsatisfied, max unc./thresh. is 5.272940735256108 for eigenvalue
#  The estimated number of batches is 1049
#        58/1    1.18773    1.18291 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 5.430031922438533 for eigenvalue
#  The estimated number of batches is 1141
#        59/1    1.18774    1.18303 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 5.273843970045364 for eigenvalue
#  The estimated number of batches is 1105
#        60/1    1.18424    1.18306 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 5.195652654270042 for eigenvalue
#  The estimated number of batches is 1100
#        61/1    1.18703    1.18316 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 5.119574635632965 for eigenvalue
#  The estimated number of batches is 1095
#        62/1    1.18285    1.18315 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 5.010663302606805 for eigenvalue
#  The estimated number of batches is 1075
#        63/1    1.18156    1.18312 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 4.89854805139922 for eigenvalue
#  The estimated number of batches is 1052
#        64/1    1.17537    1.18294 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 5.0902616693192595 for eigenvalue
#  The estimated number of batches is 1161
#        65/1    1.18048    1.18289 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 5.2419100212265874 for eigenvalue
#  The estimated number of batches is 1257
#        66/1    1.18214    1.18287 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 5.225284148439626 for eigenvalue
#  The estimated number of batches is 1276
#        67/1    1.19097    1.18304 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.11322349814588 for eigenvalue
#  The estimated number of batches is 1249
#        68/1    1.19130    1.18321 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.032986789912402 for eigenvalue
#  The estimated number of batches is 1236
#        69/1    1.18797    1.18331 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 4.95842364372611 for eigenvalue
#  The estimated number of batches is 1225
#        70/1    1.19310    1.18351 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.0857878563869185 for eigenvalue
#  The estimated number of batches is 1314
#        71/1    1.19311    1.18370 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.102694494228357 for eigenvalue
#  The estimated number of batches is 1348
#        72/1    1.19011    1.18382 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.005465901873397 for eigenvalue
#  The estimated number of batches is 1323
#        73/1    1.17365    1.18363 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 4.891423262673137 for eigenvalue
#  The estimated number of batches is 1289
#        74/1    1.19320    1.18380 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 4.818219424160906 for eigenvalue
#  The estimated number of batches is 1274
#        75/1    1.18111    1.18376 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.724191328580614 for eigenvalue
#  The estimated number of batches is 1248
#        76/1    1.17488    1.18360 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.667218991129661 for eigenvalue
#  The estimated number of batches is 1240
#        77/1    1.17028    1.18336 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 4.651825450201431 for eigenvalue
#  The estimated number of batches is 1254
#        78/1    1.18316    1.18336 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.5588140194226705 for eigenvalue
#  The estimated number of batches is 1226
#        79/1    1.17508    1.18322 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.501150103286674 for eigenvalue
#  The estimated number of batches is 1216
#        80/1    1.18207    1.18320 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 4.437200014471317 for eigenvalue
#  The estimated number of batches is 1202
#        81/1    1.19046    1.18332 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.377296353861722 for eigenvalue
#  The estimated number of batches is 1189
#        82/1    1.20001    1.18359 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.51632938063151 for eigenvalue
#  The estimated number of batches is 1285
#        83/1    1.18047    1.18354 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.444041787100204 for eigenvalue
#  The estimated number of batches is 1265
#        84/1    1.18720    1.18360 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.379780579440682 for eigenvalue
#  The estimated number of batches is 1248
#        85/1    1.19220    1.18373 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.365659464292838 for eigenvalue
#  The estimated number of batches is 1259
#        86/1    1.19360    1.18388 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.3447865237668495 for eigenvalue
#  The estimated number of batches is 1266
#        87/1    1.18989    1.18397 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.2982259346773715 for eigenvalue
#  The estimated number of batches is 1258
#        88/1    1.18675    1.18401 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 4.23879678758507 for eigenvalue
#  The estimated number of batches is 1242
#        89/1    1.18311    1.18400 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.284932421286428 for eigenvalue
#  The estimated number of batches is 1287
#        90/1    1.17414    1.18385 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.236220174596706 for eigenvalue
#  The estimated number of batches is 1277
#        91/1    1.18029    1.18380 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 4.326660155602345 for eigenvalue
#  The estimated number of batches is 1350
#        92/1    1.17457    1.18368 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.31194215028396 for eigenvalue
#  The estimated number of batches is 1359
#        93/1    1.17417    1.18355 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.253670909784171 for eigenvalue
#  The estimated number of batches is 1341
#        94/1    1.17893    1.18348 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 4.209370535205521 for eigenvalue
#  The estimated number of batches is 1332
#        95/1    1.18181    1.18346 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.180396336218794 for eigenvalue
#  The estimated number of batches is 1331
#        96/1    1.19702    1.18364 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 4.114841964272657 for eigenvalue
#  The estimated number of batches is 1307
#        97/1    1.18868    1.18371 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.1425934450469954 for eigenvalue
#  The estimated number of batches is 1342
#        98/1    1.19091    1.18380 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.107596759390587 for eigenvalue
#  The estimated number of batches is 1337
#        99/1    1.18006    1.18375 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.048926720975164 for eigenvalue
#  The estimated number of batches is 1316
#       100/1    1.19400    1.18388 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.002538917635061 for eigenvalue
#  The estimated number of batches is 1302
#       101/1    1.18087    1.18384 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 3.9857470682943315 for eigenvalue
#  The estimated number of batches is 1307
#       102/1    1.18510    1.18386 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 3.9550531537678904 for eigenvalue
#  The estimated number of batches is 1303
#       103/1    1.17106    1.18370 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.030870575144429 for eigenvalue
#  The estimated number of batches is 1369
#       104/1    1.19338    1.18382 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.3061335332708595 for eigenvalue
#  The estimated number of batches is 1578
#       105/1    1.18827    1.18387 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.28599251180283 for eigenvalue
#  The estimated number of batches is 1582
#       106/1    1.18759    1.18391 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.232899049470462 for eigenvalue
#  The estimated number of batches is 1561
#       107/1    1.18504    1.18393 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.188331430651879 for eigenvalue
#  The estimated number of batches is 1547
#       108/1    1.17951    1.18388 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.237643214541255 for eigenvalue
#  The estimated number of batches is 1601
#       109/1    1.19014    1.18395 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.215417210532247 for eigenvalue
#  The estimated number of batches is 1602
#       110/1    1.16890    1.18378 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.369672647180978 for eigenvalue
#  The estimated number of batches is 1739
#       111/1    1.17905    1.18373 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.3269754383044745 for eigenvalue
#  The estimated number of batches is 1724
#       112/1    1.18462    1.18374 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.281372377746781 for eigenvalue
#  The estimated number of batches is 1707
#       113/1    1.19077    1.18381 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.284542974659733 for eigenvalue
#  The estimated number of batches is 1728
#       114/1    1.18095    1.18378 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.293048477710282 for eigenvalue
#  The estimated number of batches is 1753
#       115/1    1.18144    1.18376 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.268049291392867 for eigenvalue
#  The estimated number of batches is 1751
#       116/1    1.18615    1.18378 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.232087715160274 for eigenvalue
#  The estimated number of batches is 1740
#       117/1    1.18655    1.18381 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.194753648475595 for eigenvalue
#  The estimated number of batches is 1727
#       118/1    1.18184    1.18379 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.171726198086332 for eigenvalue
#  The estimated number of batches is 1726
#       119/1    1.18715    1.18382 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.227592313094476 for eigenvalue
#  The estimated number of batches is 1790
#       120/1    1.17584    1.18375 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.193502695900883 for eigenvalue
#  The estimated number of batches is 1779
#       121/1    1.17891    1.18370 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.148351738391722 for eigenvalue
#  The estimated number of batches is 1759
#       122/1    1.20008    1.18386 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.267539959839953 for eigenvalue
#  The estimated number of batches is 1878
#       123/1    1.19136    1.18393 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.249638594162988 for eigenvalue
#  The estimated number of batches is 1881
#       124/1    1.19584    1.18405 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.214154239522521 for eigenvalue
#  The estimated number of batches is 1867
#       125/1    1.17773    1.18398 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.183946088850812 for eigenvalue
#  The estimated number of batches is 1859
#       126/1    1.18377    1.18398 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.147697285591934 for eigenvalue
#  The estimated number of batches is 1844
#       127/1    1.18216    1.18397 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.1126605456105985 for eigenvalue
#  The estimated number of batches is 1830
#       128/1    1.18364    1.18396 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.076636987748043 for eigenvalue
#  The estimated number of batches is 1815
#       129/1    1.18639    1.18399 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.103051235008247 for eigenvalue
#  The estimated number of batches is 1856
#       130/1    1.18171    1.18396 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.080879013027325 for eigenvalue
#  The estimated number of batches is 1852
#       131/1    1.18790    1.18400 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.044948896476241 for eigenvalue
#  The estimated number of batches is 1837
#       132/1    1.17246    1.18390 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.065707975542344 for eigenvalue
#  The estimated number of batches is 1872
#       133/1    1.18335    1.18389 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.028618467162613 for eigenvalue
#  The estimated number of batches is 1854
#       134/1    1.18633    1.18391 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.004928989003458 for eigenvalue
#  The estimated number of batches is 1849
#       135/1    1.17627    1.18385 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.9816496870942246 for eigenvalue
#  The estimated number of batches is 1844
#       136/1    1.19178    1.18392 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.035250174390305 for eigenvalue
#  The estimated number of batches is 1909
#       137/1    1.18248    1.18390 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.006485822692009 for eigenvalue
#  The estimated number of batches is 1899
#       138/1    1.18193    1.18389 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.973358776351389 for eigenvalue
#  The estimated number of batches is 1883
#       139/1    1.18166    1.18387 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.9666508941175795 for eigenvalue
#  The estimated number of batches is 1893
#       140/1    1.17863    1.18382 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.933596834446079 for eigenvalue
#  The estimated number of batches is 1877
#       141/1    1.18689    1.18385 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.9018943292174986 for eigenvalue
#  The estimated number of batches is 1863
#       142/1    1.18302    1.18384 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.866762822869884 for eigenvalue
#  The estimated number of batches is 1845
#       143/1    1.18251    1.18383 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.835721437512333 for eigenvalue
#  The estimated number of batches is 1830
#       144/1    1.17289    1.18374 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.809064738699511 for eigenvalue
#  The estimated number of batches is 1820
#       145/1    1.18382    1.18374 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.7802922981601026 for eigenvalue
#  The estimated number of batches is 1807
#       146/1    1.17398    1.18367 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.757011382766661 for eigenvalue
#  The estimated number of batches is 1799
#       147/1    1.17689    1.18361 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.761621128176267 for eigenvalue
#  The estimated number of batches is 1818
#       148/1    1.17531    1.18355 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.7329617397018047 for eigenvalue
#  The estimated number of batches is 1804
#       149/1    1.18170    1.18353 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.7045850772259517 for eigenvalue
#  The estimated number of batches is 1791
#       150/1    1.18692    1.18356 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.7191537346310453 for eigenvalue
#  The estimated number of batches is 1819
#       151/1    1.18082    1.18354 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7008952219080027 for eigenvalue
#  The estimated number of batches is 1815
#       152/1    1.17676    1.18349 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6724446708795706 for eigenvalue
#  The estimated number of batches is 1801
#       153/1    1.17931    1.18346 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6570557803391353 for eigenvalue
#  The estimated number of batches is 1799
#       154/1    1.18713    1.18348 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.6593747785964434 for eigenvalue
#  The estimated number of batches is 1815
#       155/1    1.19643    1.18358 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6371668722245443 for eigenvalue
#  The estimated number of batches is 1806
#       156/1    1.17638    1.18353 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6764414104880645 for eigenvalue
#  The estimated number of batches is 1859
#       157/1    1.16502    1.18339 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.7290308663110396 for eigenvalue
#  The estimated number of batches is 1926
#       158/1    1.18299    1.18339 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7002043395327577 for eigenvalue
#  The estimated number of batches is 1910
#       159/1    1.17805    1.18335 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.675371768425183 for eigenvalue
#  The estimated number of batches is 1898
#       160/1    1.18976    1.18340 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.652284032196325 for eigenvalue
#  The estimated number of batches is 1888
#       161/1    1.18299    1.18339 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.6304310685363763 for eigenvalue
#  The estimated number of batches is 1879
#       162/1    1.18264    1.18339 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.6108469665593743 for eigenvalue
#  The estimated number of batches is 1872
#       163/1    1.18622    1.18341 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.584570123137301 for eigenvalue
#  The estimated number of batches is 1858
#       164/1    1.18670    1.18343 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.563264283993176 for eigenvalue
#  The estimated number of batches is 1849
#       165/1    1.17834    1.18340 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5552830374357764 for eigenvalue
#  The estimated number of batches is 1853
#       166/1    1.18322    1.18339 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5313756074401823 for eigenvalue
#  The estimated number of batches is 1841
#       167/1    1.17249    1.18332 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5110824429160603 for eigenvalue
#  The estimated number of batches is 1833
#       168/1    1.18684    1.18334 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5028043524441563 for eigenvalue
#  The estimated number of batches is 1836
#       169/1    1.18823    1.18338 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4808830130937216 for eigenvalue
#  The estimated number of batches is 1826
#       170/1    1.19731    1.18347 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.470642291968935 for eigenvalue
#  The estimated number of batches is 1827
#       171/1    1.18816    1.18350 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4542056019956218 for eigenvalue
#  The estimated number of batches is 1822
#       172/1    1.18711    1.18352 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4311872231008875 for eigenvalue
#  The estimated number of batches is 1810
#       173/1    1.18769    1.18355 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.41200157213525 for eigenvalue
#  The estimated number of batches is 1802
#       174/1    1.18078    1.18353 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3921604592448547 for eigenvalue
#  The estimated number of batches is 1793
#       175/1    1.18661    1.18355 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.370957434460879 for eigenvalue
#  The estimated number of batches is 1782
#       176/1    1.17715    1.18351 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3622914887267914 for eigenvalue
#  The estimated number of batches is 1784
#       177/1    1.18111    1.18350 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3450426792558057 for eigenvalue
#  The estimated number of batches is 1777
#       178/1    1.18272    1.18349 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.329563232162246 for eigenvalue
#  The estimated number of batches is 1772
#       179/1    1.18161    1.18348 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.327005238018611 for eigenvalue
#  The estimated number of batches is 1780
#       180/1    1.18435    1.18349 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3075168729080926 for eigenvalue
#  The estimated number of batches is 1771
#       181/1    1.17896    1.18346 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2873774734431565 for eigenvalue
#  The estimated number of batches is 1760
#       182/1    1.18970    1.18350 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2786068612230097 for eigenvalue
#  The estimated number of batches is 1762
#       183/1    1.17513    1.18344 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.274496045211013 for eigenvalue
#  The estimated number of batches is 1768
#       184/1    1.18567    1.18346 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.286235054409212 for eigenvalue
#  The estimated number of batches is 1792
#       185/1    1.18001    1.18344 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.267140228894672 for eigenvalue
#  The estimated number of batches is 1782
#       186/1    1.18778    1.18346 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.255712872544743 for eigenvalue
#  The estimated number of batches is 1780
#       187/1    1.19151    1.18351 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2373890442144657 for eigenvalue
#  The estimated number of batches is 1771
#       188/1    1.18699    1.18353 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2203932675096834 for eigenvalue
#  The estimated number of batches is 1763
#       189/1    1.18459    1.18354 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.201587885578237 for eigenvalue
#  The estimated number of batches is 1753
#       190/1    1.18173    1.18353 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.182379549887841 for eigenvalue
#  The estimated number of batches is 1742
#       191/1    1.19283    1.18358 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1666106621154078 for eigenvalue
#  The estimated number of batches is 1735
#       192/1    1.18709    1.18360 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1516572261570945 for eigenvalue
#  The estimated number of batches is 1729
#       193/1    1.19660    1.18368 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.19723149984314 for eigenvalue
#  The estimated number of batches is 1789
#       194/1    1.18402    1.18368 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.179896944985999 for eigenvalue
#  The estimated number of batches is 1780
#       195/1    1.18537    1.18369 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1694562389912724 for eigenvalue
#  The estimated number of batches is 1778
#       196/1    1.19398    1.18375 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1870445428703538 for eigenvalue
#  The estimated number of batches is 1808
#       197/1    1.19320    1.18380 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1713833858804965 for eigenvalue
#  The estimated number of batches is 1801
#       198/1    1.18338    1.18380 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1536415651728475 for eigenvalue
#  The estimated number of batches is 1791
#       199/1    1.18254    1.18379 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1792624654701087 for eigenvalue
#  The estimated number of batches is 1830
#       200/1    1.18730    1.18381 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1627766849136605 for eigenvalue
#  The estimated number of batches is 1821
#       201/1    1.17545    1.18377 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1459901165789503 for eigenvalue
#  The estimated number of batches is 1812
#       202/1    1.19122    1.18381 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1357656630285877 for eigenvalue
#  The estimated number of batches is 1810
#       203/1    1.20452    1.18392 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1942408609211004 for eigenvalue
#  The estimated number of batches is 1888
#       204/1    1.18285    1.18391 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.178476729138767 for eigenvalue
#  The estimated number of batches is 1879
#       205/1    1.18053    1.18390 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1640637037189325 for eigenvalue
#  The estimated number of batches is 1873
#       206/1    1.17542    1.18385 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1464543867226893 for eigenvalue
#  The estimated number of batches is 1862
#       207/1    1.18920    1.18388 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1306181544614 for eigenvalue
#  The estimated number of batches is 1853
#       208/1    1.18078    1.18386 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.130464859678932 for eigenvalue
#  The estimated number of batches is 1863
#       209/1    1.19060    1.18390 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.115029741722194 for eigenvalue
#  The estimated number of batches is 1854
#       210/1    1.18269    1.18389 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.098606273559687 for eigenvalue
#  The estimated number of batches is 1845
#       211/1    1.17974    1.18387 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0904838308643634 for eigenvalue
#  The estimated number of batches is 1845
#       212/1    1.17428    1.18382 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.073698428894502 for eigenvalue
#  The estimated number of batches is 1834
#       213/1    1.18184    1.18381 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0573644856249205 for eigenvalue
#  The estimated number of batches is 1825
#       214/1    1.18702    1.18383 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0751223170529265 for eigenvalue
#  The estimated number of batches is 1855
#       215/1    1.16922    1.18375 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.096543899898822 for eigenvalue
#  The estimated number of batches is 1890
#       216/1    1.18110    1.18374 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0802730258034217 for eigenvalue
#  The estimated number of batches is 1880
#       217/1    1.19743    1.18381 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.137587344803806 for eigenvalue
#  The estimated number of batches is 1960
#       218/1    1.17679    1.18377 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1216052064460387 for eigenvalue
#  The estimated number of batches is 1950
#       219/1    1.19291    1.18382 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1105135860444184 for eigenvalue
#  The estimated number of batches is 1946
#       220/1    1.19193    1.18386 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1006707900833748 for eigenvalue
#  The estimated number of batches is 1943
#       221/1    1.17871    1.18383 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0866172947593857 for eigenvalue
#  The estimated number of batches is 1935
#       222/1    1.19821    1.18390 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0782418797232105 for eigenvalue
#  The estimated number of batches is 1935
#       223/1    1.19305    1.18395 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0658633540700952 for eigenvalue
#  The estimated number of batches is 1929
#       224/1    1.19383    1.18400 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.054396272461178 for eigenvalue
#  The estimated number of batches is 1924
#       225/1    1.18819    1.18402 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.051881488644879 for eigenvalue
#  The estimated number of batches is 1930
#       226/1    1.19263    1.18406 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.048620791361015 for eigenvalue
#  The estimated number of batches is 1935
#       227/1    1.17757    1.18403 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0399868473514977 for eigenvalue
#  The estimated number of batches is 1933
#       228/1    1.18241    1.18402 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.027910387448539 for eigenvalue
#  The estimated number of batches is 1927
#       229/1    1.17607    1.18398 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0128122685416443 for eigenvalue
#  The estimated number of batches is 1918
#       230/1    1.18316    1.18398 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.004096971770628 for eigenvalue
#  The estimated number of batches is 1916
#       231/1    1.19158    1.18401 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0010031354380384 for eigenvalue
#  The estimated number of batches is 1921
#       232/1    1.17829    1.18399 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9981175461672627 for eigenvalue
#  The estimated number of batches is 1926
#       233/1    1.17905    1.18396 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9834813313308457 for eigenvalue
#  The estimated number of batches is 1916
#       234/1    1.18738    1.18398 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.974261412988968 for eigenvalue
#  The estimated number of batches is 1914
#       235/1    1.19967    1.18405 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.000326141151312 for eigenvalue
#  The estimated number of batches is 1956
#       236/1    1.18883    1.18408 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.986535766880669 for eigenvalue
#  The estimated number of batches is 1947
#       237/1    1.17537    1.18404 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.975267419529308 for eigenvalue
#  The estimated number of batches is 1941
#       238/1    1.17855    1.18401 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9688102599785107 for eigenvalue
#  The estimated number of batches is 1942
#       239/1    1.17324    1.18396 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.973154999836964 for eigenvalue
#  The estimated number of batches is 1956
#       240/1    1.16852    1.18389 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.987412999064339 for eigenvalue
#  The estimated number of batches is 1984
#       241/1    1.18864    1.18391 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9865827566970107 for eigenvalue
#  The estimated number of batches is 1992
#       242/1    1.18363    1.18391 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.978686667632435 for eigenvalue
#  The estimated number of batches is 1990
#       243/1    1.18124    1.18390 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9652108012863927 for eigenvalue
#  The estimated number of batches is 1981
#       244/1    1.18888    1.18392 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9523981453669528 for eigenvalue
#  The estimated number of batches is 1973
#       245/1    1.18857    1.18394 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.941100774747212 for eigenvalue
#  The estimated number of batches is 1967
#       246/1    1.19030    1.18397 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.930134367371279 for eigenvalue
#  The estimated number of batches is 1961
#       247/1    1.18907    1.18399 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9191155625806737 for eigenvalue
#  The estimated number of batches is 1955
#       248/1    1.18099    1.18398 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9130740872445458 for eigenvalue
#  The estimated number of batches is 1955
#       249/1    1.17834    1.18395 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9204733146291106 for eigenvalue
#  The estimated number of batches is 1974
#       250/1    1.18598    1.18396 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9080697649282885 for eigenvalue
#  The estimated number of batches is 1966
#       251/1    1.18160    1.18395 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8953929744794844 for eigenvalue
#  The estimated number of batches is 1957
#       252/1    1.17739    1.18392 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8889022207272634 for eigenvalue
#  The estimated number of batches is 1957
#       253/1    1.18477    1.18393 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8765644403426194 for eigenvalue
#  The estimated number of batches is 1948
#       254/1    1.17884    1.18391 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.865599881112936 for eigenvalue
#  The estimated number of batches is 1942
#       255/1    1.18409    1.18391 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8537864023957855 for eigenvalue
#  The estimated number of batches is 1934
#       256/1    1.17292    1.18386 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8407813568531926 for eigenvalue
#  The estimated number of batches is 1925
#       257/1    1.18122    1.18385 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8286126130361287 for eigenvalue
#  The estimated number of batches is 1917
#       258/1    1.18361    1.18385 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8186143258098286 for eigenvalue
#  The estimated number of batches is 1911
#       259/1    1.18835    1.18387 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.807004309127998 for eigenvalue
#  The estimated number of batches is 1904
#       260/1    1.18207    1.18386 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.795981129718976 for eigenvalue
#  The estimated number of batches is 1897
#       261/1    1.17382    1.18382 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7900908740024093 for eigenvalue
#  The estimated number of batches is 1897
#       262/1    1.17560    1.18378 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.778438185749235 for eigenvalue
#  The estimated number of batches is 1889
#       263/1    1.19038    1.18381 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.767193642723554 for eigenvalue
#  The estimated number of batches is 1881
#       264/1    1.18201    1.18380 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7573079980025916 for eigenvalue
#  The estimated number of batches is 1876
#       265/1    1.17636    1.18377 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.751416107691496 for eigenvalue
#  The estimated number of batches is 1875
#       266/1    1.18475    1.18378 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7403329684462854 for eigenvalue
#  The estimated number of batches is 1868
#       267/1    1.18390    1.18378 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7350743388953362 for eigenvalue
#  The estimated number of batches is 1868
#       268/1    1.19063    1.18381 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.724504666422763 for eigenvalue
#  The estimated number of batches is 1861
#       269/1    1.19025    1.18383 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7155655113980957 for eigenvalue
#  The estimated number of batches is 1857
#       270/1    1.18900    1.18385 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.70672727713101 for eigenvalue
#  The estimated number of batches is 1852
#       271/1    1.17297    1.18381 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7032899174263125 for eigenvalue
#  The estimated number of batches is 1855
#       272/1    1.17752    1.18378 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6922316647421387 for eigenvalue
#  The estimated number of batches is 1847
#       273/1    1.18297    1.18378 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6815187278458317 for eigenvalue
#  The estimated number of batches is 1840
#       274/1    1.18705    1.18379 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.672540772831091 for eigenvalue
#  The estimated number of batches is 1835
#       275/1    1.18221    1.18379 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6621425482894643 for eigenvalue
#  The estimated number of batches is 1828
#       276/1    1.19043    1.18381 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.652658051166116 for eigenvalue
#  The estimated number of batches is 1822
#       277/1    1.18299    1.18381 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.663882789397361 for eigenvalue
#  The estimated number of batches is 1844
#       278/1    1.18387    1.18381 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.653960609357864 for eigenvalue
#  The estimated number of batches is 1838
#       279/1    1.19194    1.18384 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.65657441232301 for eigenvalue
#  The estimated number of batches is 1848
#       280/1    1.17833    1.18382 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6614742124041513 for eigenvalue
#  The estimated number of batches is 1862
#       281/1    1.18436    1.18382 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6629734894324333 for eigenvalue
#  The estimated number of batches is 1871
#       282/1    1.18271    1.18382 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.653250778276471 for eigenvalue
#  The estimated number of batches is 1865
#       283/1    1.17373    1.18378 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6456050096840977 for eigenvalue
#  The estimated number of batches is 1861
#       284/1    1.17457    1.18375 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6431645173943474 for eigenvalue
#  The estimated number of batches is 1865
#       285/1    1.18873    1.18376 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.636849561554061 for eigenvalue
#  The estimated number of batches is 1863
#       286/1    1.18675    1.18378 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.627261744661438 for eigenvalue
#  The estimated number of batches is 1857
#       287/1    1.18493    1.18378 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.629109756505512 for eigenvalue
#  The estimated number of batches is 1866
#       288/1    1.18258    1.18378 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6196205199586053 for eigenvalue
#  The estimated number of batches is 1860
#       289/1    1.18734    1.18379 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.610199858841659 for eigenvalue
#  The estimated number of batches is 1853
#       290/1    1.17819    1.18377 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.600332041057141 for eigenvalue
#  The estimated number of batches is 1846
#       291/1    1.17726    1.18374 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.59294966121452 for eigenvalue
#  The estimated number of batches is 1843
#       292/1    1.18363    1.18374 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5833978036345715 for eigenvalue
#  The estimated number of batches is 1836
#       293/1    1.17798    1.18372 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5795618904612723 for eigenvalue
#  The estimated number of batches is 1837
#       294/1    1.18752    1.18374 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5798732568624927 for eigenvalue
#  The estimated number of batches is 1844
#       295/1    1.18410    1.18374 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5786544815187398 for eigenvalue
#  The estimated number of batches is 1849
#       296/1    1.18679    1.18375 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5693066222412986 for eigenvalue
#  The estimated number of batches is 1842
#       297/1    1.19399    1.18379 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.563485041464367 for eigenvalue
#  The estimated number of batches is 1841
#       298/1    1.17711    1.18376 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5551635209821155 for eigenvalue
#  The estimated number of batches is 1836
#       299/1    1.17433    1.18373 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5519095881226 for eigenvalue
#  The estimated number of batches is 1837
#       300/1    1.18216    1.18372 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.542816797836645 for eigenvalue
# ...
#  The estimated number of batches is 1724
#       671/1    1.19403    1.18389 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6168691143904756 for eigenvalue
#  The estimated number of batches is 1722
#       672/1    1.19468    1.18391 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6146661440878125 for eigenvalue
#  The estimated number of batches is 1720
#       673/1    1.19141    1.18392 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6133009631077189 for eigenvalue
#  The estimated number of batches is 1720
#       674/1    1.17746    1.18391 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.611842998000187 for eigenvalue
#  The estimated number of batches is 1720
#       675/1    1.18213    1.18391 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6121637129356194 for eigenvalue
#  The estimated number of batches is 1723
#       676/1    1.18104    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6096986502759543 for eigenvalue
#  The estimated number of batches is 1720
#       677/1    1.18287    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6075063710531674 for eigenvalue
#  The estimated number of batches is 1718
#       678/1    1.19338    1.18392 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6053371120212545 for eigenvalue
#  The estimated number of batches is 1716
#       679/1    1.17107    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6030004818800436 for eigenvalue
#  The estimated number of batches is 1714
#       680/1    1.18295    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.6010225797967463 for eigenvalue
#  The estimated number of batches is 1712
#       681/1    1.18745    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5994959132894604 for eigenvalue
#  The estimated number of batches is 1712
#       682/1    1.18712    1.18391 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.597862282822153 for eigenvalue
#  The estimated number of batches is 1711
#       683/1    1.18155    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5963557306250837 for eigenvalue
#  The estimated number of batches is 1710
#       684/1    1.18976    1.18391 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5944750132755532 for eigenvalue
#  The estimated number of batches is 1709
#       685/1    1.17367    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5921562982244146 for eigenvalue
#  The estimated number of batches is 1706
#       686/1    1.17807    1.18389 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5897067445388746 for eigenvalue
#  The estimated number of batches is 1704
#       687/1    1.18260    1.18389 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5882985487409027 for eigenvalue
#  The estimated number of batches is 1703
#       688/1    1.18980    1.18389 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5860183724294377 for eigenvalue
#  The estimated number of batches is 1701
#       689/1    1.18771    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5840405692264699 for eigenvalue
#  The estimated number of batches is 1699
#       690/1    1.18921    1.18391 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5819225702073405 for eigenvalue
#  The estimated number of batches is 1697
#       691/1    1.18832    1.18391 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.57964168817106 for eigenvalue
#  The estimated number of batches is 1695
#       692/1    1.19647    1.18393 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5821827107940039 for eigenvalue
#  The estimated number of batches is 1703
#       693/1    1.18954    1.18394 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5814576955707405 for eigenvalue
#  The estimated number of batches is 1704
#       694/1    1.17209    1.18392 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5804684099137554 for eigenvalue
#  The estimated number of batches is 1704
#       695/1    1.18313    1.18392 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5782880051506583 for eigenvalue
#  The estimated number of batches is 1702
#       696/1    1.18989    1.18393 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.576179886362414 for eigenvalue
#  The estimated number of batches is 1700
#       697/1    1.17131    1.18391 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5751190375335056 for eigenvalue
#  The estimated number of batches is 1700
#       698/1    1.17668    1.18390 +/- 0.00026
#  Triggers unsatisfied, max unc./thresh. is 1.5730097934456317 for eigenvalue
#  The estimated number of batches is 1698
#       699/1    1.18381    1.18390 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5707234558294703 for eigenvalue
#  The estimated number of batches is 1696
#       700/1    1.18208    1.18390 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5686966433891567 for eigenvalue
#  The estimated number of batches is 1694
#       701/1    1.18321    1.18390 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.566618922524038 for eigenvalue
#  The estimated number of batches is 1692
#       702/1    1.18799    1.18390 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5693460778831174 for eigenvalue
#  The estimated number of batches is 1700
#       703/1    1.19023    1.18391 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5675511525492951 for eigenvalue
#  The estimated number of batches is 1699
#       704/1    1.18456    1.18391 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.566846351232669 for eigenvalue
#  The estimated number of batches is 1700
#       705/1    1.17401    1.18390 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5650920139641316 for eigenvalue
#  The estimated number of batches is 1698
#       706/1    1.20272    1.18393 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5635068345292533 for eigenvalue
#  The estimated number of batches is 1697
#       707/1    1.18307    1.18393 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.561217563282954 for eigenvalue
#  The estimated number of batches is 1695
#       708/1    1.17751    1.18392 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5626693572160562 for eigenvalue
#  The estimated number of batches is 1701
#       709/1    1.17918    1.18391 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5615889530638731 for eigenvalue
#  The estimated number of batches is 1701
#       710/1    1.17922    1.18390 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5617940432806572 for eigenvalue
#  The estimated number of batches is 1704
#       711/1    1.17656    1.18389 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5629783752795572 for eigenvalue
#  The estimated number of batches is 1709
#       712/1    1.17767    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5628610406534176 for eigenvalue
#  The estimated number of batches is 1711
#       713/1    1.18854    1.18389 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5611260938878164 for eigenvalue
#  The estimated number of batches is 1709
#       714/1    1.16995    1.18387 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5608042735617276 for eigenvalue
#  The estimated number of batches is 1711
#       715/1    1.19053    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.558715294890693 for eigenvalue
#  The estimated number of batches is 1709
#       716/1    1.18027    1.18387 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5582214503595957 for eigenvalue
#  The estimated number of batches is 1710
#       717/1    1.19192    1.18389 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5565668348879687 for eigenvalue
#  The estimated number of batches is 1709
#       718/1    1.17869    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5546911188562202 for eigenvalue
#  The estimated number of batches is 1708
#       719/1    1.18152    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5531405102692786 for eigenvalue
#  The estimated number of batches is 1707
#       720/1    1.18628    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5509433524540892 for eigenvalue
#  The estimated number of batches is 1704
#       721/1    1.18274    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.548765967431446 for eigenvalue
#  The estimated number of batches is 1702
#       722/1    1.18506    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5472244439746254 for eigenvalue
#  The estimated number of batches is 1701
#       723/1    1.19105    1.18389 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5455641384536138 for eigenvalue
#  The estimated number of batches is 1700
#       724/1    1.18004    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5449589749966617 for eigenvalue
#  The estimated number of batches is 1701
#       725/1    1.17700    1.18387 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5427339585968574 for eigenvalue
#  The estimated number of batches is 1698
#       726/1    1.17620    1.18386 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5408453501545802 for eigenvalue
#  The estimated number of batches is 1697
#       727/1    1.18258    1.18386 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5387852835096554 for eigenvalue
#  The estimated number of batches is 1695
#       728/1    1.17447    1.18385 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.537156136848066 for eigenvalue
#  The estimated number of batches is 1693
#       729/1    1.18843    1.18385 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5350127717691413 for eigenvalue
#  The estimated number of batches is 1691
#       730/1    1.18869    1.18386 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.533519989950472 for eigenvalue
#  The estimated number of batches is 1690
#       731/1    1.18458    1.18386 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5315267820233218 for eigenvalue
#  The estimated number of batches is 1688
#       732/1    1.18790    1.18387 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5295373225687663 for eigenvalue
#  The estimated number of batches is 1686
#       733/1    1.18385    1.18387 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.527370200828214 for eigenvalue
#  The estimated number of batches is 1684
#       734/1    1.18263    1.18387 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5254293667198056 for eigenvalue
#  The estimated number of batches is 1682
#       735/1    1.17543    1.18385 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5231893018316982 for eigenvalue
#  The estimated number of batches is 1679
#       736/1    1.18713    1.18386 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5211764869809639 for eigenvalue
#  The estimated number of batches is 1677
#       737/1    1.18084    1.18385 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5209278702171167 for eigenvalue
#  The estimated number of batches is 1679
#       738/1    1.18882    1.18386 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5193590748527823 for eigenvalue
#  The estimated number of batches is 1678
#       739/1    1.18792    1.18387 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5199341136906823 for eigenvalue
#  The estimated number of batches is 1682
#       740/1    1.18650    1.18387 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.51974786743477 for eigenvalue
#  The estimated number of batches is 1683
#       741/1    1.17925    1.18386 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.519480676173434 for eigenvalue
#  The estimated number of batches is 1685
#       742/1    1.19320    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5190934183628553 for eigenvalue
#  The estimated number of batches is 1687
#       743/1    1.19222    1.18389 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.520693449895062 for eigenvalue
#  The estimated number of batches is 1692
#       744/1    1.18064    1.18388 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5191327174675435 for eigenvalue
#  The estimated number of batches is 1691
#       745/1    1.18453    1.18389 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5177859881332074 for eigenvalue
#  The estimated number of batches is 1691
#       746/1    1.19606    1.18390 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5173691617005365 for eigenvalue
#  The estimated number of batches is 1692
#       747/1    1.19383    1.18392 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5157800506290044 for eigenvalue
#  The estimated number of batches is 1691
#       748/1    1.18943    1.18392 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.5137979709339013 for eigenvalue
#  The estimated number of batches is 1689
#       749/1    1.18092    1.18392 +/- 0.00025
#  Triggers unsatisfied, max unc./thresh. is 1.511657181359049 for eigenvalue
#  The estimated number of batches is 1686
#       750/1    1.18153    1.18392 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5097133812179455 for eigenvalue
#  The estimated number of batches is 1684
#       751/1    1.17750    1.18391 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5081663241163061 for eigenvalue
#  The estimated number of batches is 1683
#       752/1    1.18979    1.18392 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5086534429722576 for eigenvalue
#  The estimated number of batches is 1687
#       753/1    1.18934    1.18392 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5076228521816946 for eigenvalue
#  The estimated number of batches is 1687
#       754/1    1.18521    1.18392 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5056300553317288 for eigenvalue
#  The estimated number of batches is 1684
#       755/1    1.18429    1.18392 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5035883302118007 for eigenvalue
#  The estimated number of batches is 1682
#       756/1    1.19133    1.18394 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5016588285528096 for eigenvalue
#  The estimated number of batches is 1680
#       757/1    1.18016    1.18393 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4995593370608826 for eigenvalue
#  The estimated number of batches is 1678
#       758/1    1.17252    1.18391 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4989949660518709 for eigenvalue
#  The estimated number of batches is 1679
#       759/1    1.17860    1.18391 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.496931041910292 for eigenvalue
#  The estimated number of batches is 1676
#       760/1    1.19171    1.18392 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.498108896744914 for eigenvalue
#  The estimated number of batches is 1681
#       761/1    1.19471    1.18393 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4976176773013148 for eigenvalue
#  The estimated number of batches is 1682
#       762/1    1.18438    1.18393 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4958613191173245 for eigenvalue
#  The estimated number of batches is 1681
#       763/1    1.18471    1.18393 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4945211502354891 for eigenvalue
#  The estimated number of batches is 1680
#       764/1    1.17750    1.18393 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4925079427250056 for eigenvalue
#  The estimated number of batches is 1678
#       765/1    1.18616    1.18393 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.490546520396573 for eigenvalue
#  The estimated number of batches is 1676
#       766/1    1.17542    1.18392 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.491322725008141 for eigenvalue
#  The estimated number of batches is 1680
#       767/1    1.18617    1.18392 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4895618064104201 for eigenvalue
#  The estimated number of batches is 1678
