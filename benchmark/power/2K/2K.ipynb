# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2_low = openmc.Material(name='uo2_low')
uo2_low.add_nuclide('U234', 6.11864E-06, 'ao')
uo2_low.add_nuclide('U235', 7.18132E-04, 'ao')
uo2_low.add_nuclide('U236', 3.29861E-06, 'ao')
uo2_low.add_nuclide('U238', 2.21546E-02, 'ao')
uo2_low.add_nuclide('O16', 4.57642E-02, 'ao')
uo2_low.set_density('g/cm3', 10.257 )
uo2_low.temperature=600

uo2_high = openmc.Material(name='uo2_high')
uo2_high.add_nuclide('U234', 7.21203E-06, 'ao')
uo2_high.add_nuclide('U235', 8.33952E-04, 'ao')
uo2_high.add_nuclide('U236', 3.82913E-06, 'ao')
uo2_high.add_nuclide('U238', 2.20384E-02, 'ao')
uo2_high.add_nuclide('O16', 4.57669E-02, 'ao')
uo2_high.set_density('g/cm3', 10.257 )
uo2_high.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2_high,uo2_low, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell_high(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2_high
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %%
def pincell_low(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2_low
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]
F_low=[(8,7),(7,8),(0,0),(1,0),(0,1),(2,0),(0,2),(1,1)]



PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

F_low_left=[]
F_low_full=[]
for X in F_low:
    F_low_left.append((X[0],X[1]))
    F_low_left.append((X[0],16-X[1]))
for X in F_low_left:
    F_low_full.append((X[0],X[1]))
    F_low_full.append((16-X[0],X[1]))    
F_low_full = list(set(F_low_full))

# %%
pincell_low_1_family=pincell_low('pincell_low_1_family')
pincell_high_1_family=pincell_high('pincell_high_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in F_low_full:
            A[ix][iy]=pincell_low_1_family[0]
        else:
            A[ix][iy]=pincell_high_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-12 17:32:03
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.02062
#         2/1    1.02054
#         3/1    1.02031
#         4/1    1.01636
#         5/1    1.02178
#         6/1    1.01978
#         7/1    1.02728
#         8/1    1.02495
#         9/1    1.01699
#        10/1    1.01931
#        11/1    1.01777
#        12/1    1.01396
#        13/1    1.02442
#        14/1    1.01509
#        15/1    1.02574
#        16/1    1.01535
#        17/1    1.01969
#        18/1    1.01169
#        19/1    1.02092
#        20/1    1.02981
#        21/1    1.01484
#        22/1    1.01598    1.01541 +/- 0.00057
#        23/1    1.02165    1.01749 +/- 0.00211
#        24/1    1.02955    1.02050 +/- 0.00336
#        25/1    1.02017    1.02044 +/- 0.00261
#        26/1    1.02906    1.02187 +/- 0.00257
#        27/1    1.02412    1.02219 +/- 0.00219
#        28/1    1.01902    1.02180 +/- 0.00194
#        29/1    1.03190    1.02292 +/- 0.00205
#        30/1    1.02441    1.02307 +/- 0.00184
#        31/1    1.02619    1.02335 +/- 0.00169
#        32/1    1.01160    1.02237 +/- 0.00182
#        33/1    1.02204    1.02235 +/- 0.00168
#        34/1    1.02471    1.02252 +/- 0.00156
#        35/1    1.02319    1.02256 +/- 0.00146
#        36/1    1.01404    1.02203 +/- 0.00146
#        37/1    1.02207    1.02203 +/- 0.00137
#        38/1    1.01865    1.02184 +/- 0.00131
#        39/1    1.02177    1.02184 +/- 0.00124
#        40/1    1.01381    1.02144 +/- 0.00124
#        41/1    1.02886    1.02179 +/- 0.00123
#        42/1    1.01798    1.02162 +/- 0.00119
#        43/1    1.01965    1.02153 +/- 0.00114
#        44/1    1.03618    1.02214 +/- 0.00125
#        45/1    1.01685    1.02193 +/- 0.00122
#        46/1    1.00740    1.02137 +/- 0.00130
#        47/1    1.01942    1.02130 +/- 0.00125
#        48/1    1.02439    1.02141 +/- 0.00121
#        49/1    1.02118    1.02140 +/- 0.00117
#        50/1    1.01996    1.02135 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 8.394127914282965 for eigenvalue
#  The estimated number of batches is 2134
#  Creating state point statepoint.00050.h5...
#        51/1    1.01471    1.02114 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 8.234461603245974 for eigenvalue
#  The estimated number of batches is 2122
#        52/1    1.02062    1.02112 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 7.960956318366686 for eigenvalue
#  The estimated number of batches is 2049
#        53/1    1.01892    1.02106 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 7.794521376127802 for eigenvalue
#  The estimated number of batches is 2025
#        54/1    1.02338    1.02113 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 7.6955199332613535 for eigenvalue
#  The estimated number of batches is 2034
#        55/1    1.02157    1.02114 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 7.468974537192212 for eigenvalue
#  The estimated number of batches is 1973
#        56/1    1.02970    1.02138 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 7.46748744904234 for eigenvalue
#  The estimated number of batches is 2028
#        57/1    1.01280    1.02114 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 7.469746223508715 for eigenvalue
#  The estimated number of batches is 2085
#        58/1    1.02267    1.02118 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 7.2887613381043 for eigenvalue
#  The estimated number of batches is 2039
#        59/1    1.02406    1.02126 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 7.146595618686177 for eigenvalue
#  The estimated number of batches is 2012
#        60/1    1.01826    1.02118 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.933542864111244 for eigenvalue
#  The estimated number of batches is 1943
#        61/1    1.00160    1.02071 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 6.90028293163237 for eigenvalue
#  The estimated number of batches is 1973
#        62/1    1.01321    1.02053 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.8001052549157395 for eigenvalue
#  The estimated number of batches is 1963
#        63/1    1.02071    1.02053 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 6.645149117595461 for eigenvalue
#  The estimated number of batches is 1919
#        64/1    1.01913    1.02050 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 6.648160613223486 for eigenvalue
#  The estimated number of batches is 1965
#        65/1    1.01475    1.02037 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.521379333040641 for eigenvalue
#  The estimated number of batches is 1934
#        66/1    1.02427    1.02046 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 6.407825968507716 for eigenvalue
#  The estimated number of batches is 1909
#        67/1    1.02643    1.02058 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.328127452484196 for eigenvalue
#  The estimated number of batches is 1903
#        68/1    1.02288    1.02063 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 6.204272830324894 for eigenvalue
#  The estimated number of batches is 1868
#        69/1    1.02799    1.02078 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 6.218576885340509 for eigenvalue
#  The estimated number of batches is 1915
#        70/1    1.01797    1.02073 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 6.077087499341002 for eigenvalue
#  The estimated number of batches is 1867
#        71/1    1.01489    1.02061 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 6.039763282054659 for eigenvalue
#  The estimated number of batches is 1881
#        72/1    1.02579    1.02071 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.027697968132184 for eigenvalue
#  The estimated number of batches is 1910
#        73/1    1.02322    1.02076 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.919550996617512 for eigenvalue
#  The estimated number of batches is 1878
#        74/1    1.02731    1.02088 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.858665603419227 for eigenvalue
#  The estimated number of batches is 1874
#        75/1    1.01935    1.02085 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.765053343794561 for eigenvalue
#  The estimated number of batches is 1848
#        76/1    1.01245    1.02070 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.639810560199284 for eigenvalue
#  The estimated number of batches is 1802
#        77/1    1.01668    1.02063 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.530343557135512 for eigenvalue
#  The estimated number of batches is 1764
#        78/1    1.02710    1.02074 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.473692740229152 for eigenvalue
#  The estimated number of batches is 1758
#        79/1    1.01507    1.02065 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.547791383927106 for eigenvalue
#  The estimated number of batches is 1836
#        80/1    1.01873    1.02061 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.4376854916078665 for eigenvalue
#  The estimated number of batches is 1795
#        81/1    1.02579    1.02070 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.3688846939180435 for eigenvalue
#  The estimated number of batches is 1779
#        82/1    1.02353    1.02074 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.296690926240281 for eigenvalue
#  The estimated number of batches is 1760
#        83/1    1.00995    1.02057 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.174434270862869 for eigenvalue
#  The estimated number of batches is 1707
#        84/1    1.02180    1.02059 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.116786100213257 for eigenvalue
#  The estimated number of batches is 1696
#        85/1    1.02072    1.02059 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.055143850691069 for eigenvalue
#  The estimated number of batches is 1682
#        86/1    1.00954    1.02043 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.969960810606771 for eigenvalue
#  The estimated number of batches is 1651
#        87/1    1.02483    1.02049 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.970212558687338 for eigenvalue
#  The estimated number of batches is 1676
#        88/1    1.01857    1.02046 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.897655944956649 for eigenvalue
#  The estimated number of batches is 1652
#        89/1    1.02183    1.02048 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.846751041196202 for eigenvalue
#  The estimated number of batches is 1641
#        90/1    1.01064    1.02034 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.921799562099111 for eigenvalue
#  The estimated number of batches is 1716
#        91/1    1.01637    1.02029 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.849361439511594 for eigenvalue
#  The estimated number of batches is 1690
#        92/1    1.01069    1.02015 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.829175067739137 for eigenvalue
#  The estimated number of batches is 1700
#        93/1    1.01642    1.02010 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.763436020739785 for eigenvalue
#  The estimated number of batches is 1677
#        94/1    1.01675    1.02006 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.7447497746130765 for eigenvalue
#  The estimated number of batches is 1686
#        95/1    1.00947    1.01992 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.7146262842286895 for eigenvalue
#  The estimated number of batches is 1688
#        96/1    1.02232    1.01995 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.651864562893243 for eigenvalue
#  The estimated number of batches is 1665
#        97/1    1.01161    1.01984 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.620236725036851 for eigenvalue
#  The estimated number of batches is 1664
#        98/1    1.01819    1.01982 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.56704980923374 for eigenvalue
#  The estimated number of batches is 1647
#        99/1    1.02344    1.01986 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.544068127897399 for eigenvalue
#  The estimated number of batches is 1652
#       100/1    1.01986    1.01986 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.486843490717217 for eigenvalue
#  The estimated number of batches is 1631
#       101/1    1.01537    1.01981 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.430436464969548 for eigenvalue
#  The estimated number of batches is 1610
#       102/1    1.00859    1.01967 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.379093594788347 for eigenvalue
#  The estimated number of batches is 1593
#       103/1    1.02006    1.01968 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.325172747681434 for eigenvalue
#  The estimated number of batches is 1573
#       104/1    1.02017    1.01968 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.272273474206543 for eigenvalue
#  The estimated number of batches is 1554
#       105/1    1.01602    1.01964 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.231582144113899 for eigenvalue
#  The estimated number of batches is 1543
#       106/1    1.02105    1.01966 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.1858646890989055 for eigenvalue
#  The estimated number of batches is 1527
#       107/1    1.02027    1.01966 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.2060592687828935 for eigenvalue
#  The estimated number of batches is 1560
#       108/1    1.01140    1.01957 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.16985421497861 for eigenvalue
#  The estimated number of batches is 1551
#       109/1    1.02430    1.01962 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.141277008853139 for eigenvalue
#  The estimated number of batches is 1547
#       110/1    1.01773    1.01960 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.100546505050771 for eigenvalue
#  The estimated number of batches is 1534
#       111/1    1.02356    1.01965 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.076272500939116 for eigenvalue
#  The estimated number of batches is 1533
#       112/1    1.02462    1.01970 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.036245727371713 for eigenvalue
#  The estimated number of batches is 1519
#       113/1    1.01746    1.01968 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.009126718744902 for eigenvalue
#  The estimated number of batches is 1515
#       114/1    1.01939    1.01967 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.968968809252904 for eigenvalue
#  The estimated number of batches is 1501
#       115/1    1.02087    1.01968 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.930156327409627 for eigenvalue
#  The estimated number of batches is 1488
#       116/1    1.02036    1.01969 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.894324469735455 for eigenvalue
#  The estimated number of batches is 1476
#       117/1    1.02908    1.01979 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8419638149139725 for eigenvalue
#  The estimated number of batches is 1452
#       118/1    1.01570    1.01975 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.804053346986755 for eigenvalue
#  The estimated number of batches is 1439
#       119/1    1.02349    1.01978 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7729328126579835 for eigenvalue
#  The estimated number of batches is 1430
#       120/1    1.03293    1.01992 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7712306265953948 for eigenvalue
#  The estimated number of batches is 1443
#       121/1    1.02237    1.01994 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7359137682680736 for eigenvalue
#  The estimated number of batches is 1430
#       122/1    1.01624    1.01990 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7033664166535494 for eigenvalue
#  The estimated number of batches is 1419
#       123/1    1.02690    1.01997 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.6661557350822163 for eigenvalue
#  The estimated number of batches is 1405
#       124/1    1.01756    1.01995 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.6312632770932614 for eigenvalue
#  The estimated number of batches is 1392
#       125/1    1.01706    1.01992 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.606380562524667 for eigenvalue
#  The estimated number of batches is 1386
#       126/1    1.02297    1.01995 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.573899546059645 for eigenvalue
#  The estimated number of batches is 1374
#       127/1    1.02189    1.01997 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.54091120134321 for eigenvalue
#  The estimated number of batches is 1362
#       128/1    1.02240    1.01999 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5633685355741473 for eigenvalue
#  The estimated number of batches is 1392
#       129/1    1.01896    1.01998 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5322717036118907 for eigenvalue
#  The estimated number of batches is 1380
#       130/1    1.01926    1.01997 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.503991470784605 for eigenvalue
#  The estimated number of batches is 1371
#       131/1    1.01859    1.01996 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.476846326438856 for eigenvalue
#  The estimated number of batches is 1362
#       132/1    1.02139    1.01997 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4573319283418296 for eigenvalue
#  The estimated number of batches is 1359
#       133/1    1.02258    1.02000 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.426632179633522 for eigenvalue
#  The estimated number of batches is 1347
#       134/1    1.02284    1.02002 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.455778646048831 for eigenvalue
#  The estimated number of batches is 1382
#       135/1    1.02412    1.02006 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4598103520399044 for eigenvalue
#  The estimated number of batches is 1397
#       136/1    1.01996    1.02006 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4325113122928412 for eigenvalue
#  The estimated number of batches is 1387
#       137/1    1.01851    1.02004 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4142595063505268 for eigenvalue
#  The estimated number of batches is 1384
#       138/1    1.02639    1.02010 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3861308825762007 for eigenvalue
#  The estimated number of batches is 1373
#       139/1    1.01727    1.02007 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3568673800762086 for eigenvalue
#  The estimated number of batches is 1361
#       140/1    1.02495    1.02012 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3287546847827247 for eigenvalue
#  The estimated number of batches is 1350
#       141/1    1.02224    1.02013 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.301623254284838 for eigenvalue
#  The estimated number of batches is 1339
#       142/1    1.02359    1.02016 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2904946849779457 for eigenvalue
#  The estimated number of batches is 1341
#       143/1    1.02169    1.02017 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.262566828558901 for eigenvalue
#  The estimated number of batches is 1330
#       144/1    1.02422    1.02021 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.254563676646527 for eigenvalue
#  The estimated number of batches is 1334
#       145/1    1.01810    1.02019 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2299652729766777 for eigenvalue
#  The estimated number of batches is 1325
#       146/1    1.02575    1.02023 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.216978586436647 for eigenvalue
#  The estimated number of batches is 1324
#       147/1    1.01757    1.02021 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.210153190403123 for eigenvalue
#  The estimated number of batches is 1329
#       148/1    1.01974    1.02021 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2202229603898043 for eigenvalue
#  The estimated number of batches is 1348
#       149/1    1.02248    1.02023 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.199723635971126 for eigenvalue
#  The estimated number of batches is 1341
#       150/1    1.02773    1.02028 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1784485509826923 for eigenvalue
#  The estimated number of batches is 1334
#       151/1    1.01309    1.02023 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1737392510502738 for eigenvalue
#  The estimated number of batches is 1340
#       152/1    1.02299    1.02025 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.15286026622725 for eigenvalue
#  The estimated number of batches is 1333
#       153/1    1.01652    1.02022 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1309353572174836 for eigenvalue
#  The estimated number of batches is 1324
#       154/1    1.02079    1.02023 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.107158621069739 for eigenvalue
#  The estimated number of batches is 1314
#       155/1    1.01714    1.02020 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.089633797601299 for eigenvalue
#  The estimated number of batches is 1309
#       156/1    1.02389    1.02023 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.084874517362303 for eigenvalue
#  The estimated number of batches is 1315
#       157/1    1.01796    1.02021 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.063069961524443 for eigenvalue
#  The estimated number of batches is 1306
#       158/1    1.03176    1.02030 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0761501504059354 for eigenvalue
#  The estimated number of batches is 1326
#       159/1    1.01368    1.02025 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0543700876882722 for eigenvalue
#  The estimated number of batches is 1317
#       160/1    1.02813    1.02031 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0683621561619807 for eigenvalue
#  The estimated number of batches is 1339
#       161/1    1.02094    1.02031 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0505790836857303 for eigenvalue
#  The estimated number of batches is 1333
#       162/1    1.02064    1.02031 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0374946196651345 for eigenvalue
#  The estimated number of batches is 1331
#       163/1    1.01389    1.02027 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0165732680475785 for eigenvalue
#  The estimated number of batches is 1322
#       164/1    1.00729    1.02018 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0514391034059685 for eigenvalue
#  The estimated number of batches is 1361
#       165/1    1.01951    1.02017 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0292707304664606 for eigenvalue
#  The estimated number of batches is 1351
#       166/1    1.02214    1.02019 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.010279675691775 for eigenvalue
#  The estimated number of batches is 1344
#       167/1    1.01970    1.02018 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9927803915885725 for eigenvalue
#  The estimated number of batches is 1337
#       168/1    1.03321    1.02027 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.060633502920172 for eigenvalue
#  The estimated number of batches is 1407
#       169/1    1.01664    1.02025 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0616173281281025 for eigenvalue
#  The estimated number of batches is 1417
#       170/1    1.02698    1.02029 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0424382894012663 for eigenvalue
#  The estimated number of batches is 1409
#       171/1    1.01621    1.02027 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.018610341555215 for eigenvalue
#  The estimated number of batches is 1396
#       172/1    1.01387    1.02022 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.035212801020962 for eigenvalue
#  The estimated number of batches is 1421
#       173/1    1.01525    1.02019 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0268950643230186 for eigenvalue
#  The estimated number of batches is 1422
#       174/1    1.02488    1.02022 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0125132257109346 for eigenvalue
#  The estimated number of batches is 1418
#       175/1    1.01967    1.02022 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0053795446638754 for eigenvalue
#  The estimated number of batches is 1421
#       176/1    1.02088    1.02022 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0135118920104307 for eigenvalue
#  The estimated number of batches is 1437
#       177/1    1.01912    1.02021 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.997033683884879 for eigenvalue
#  The estimated number of batches is 1431
#       178/1    1.02227    1.02023 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9818577532911372 for eigenvalue
#  The estimated number of batches is 1425
#       179/1    1.01216    1.02018 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.966510523765347 for eigenvalue
#  The estimated number of batches is 1420
#       180/1    1.02638    1.02022 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9468110805351446 for eigenvalue
#  The estimated number of batches is 1410
#       181/1    1.02173    1.02023 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9335296037831404 for eigenvalue
#  The estimated number of batches is 1406
#       182/1    1.01343    1.02018 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.939023593103966 for eigenvalue
#  The estimated number of batches is 1420
#       183/1    1.02267    1.02020 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9238619008082236 for eigenvalue
#  The estimated number of batches is 1414
#       184/1    1.01583    1.02017 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.907542228897011 for eigenvalue
#  The estimated number of batches is 1407
#       185/1    1.01748    1.02016 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.894519142602047 for eigenvalue
#  The estimated number of batches is 1403
#       186/1    1.02232    1.02017 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8871758257742277 for eigenvalue
#  The estimated number of batches is 1404
#       187/1    1.01654    1.02015 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.87364394804633 for eigenvalue
#  The estimated number of batches is 1400
#       188/1    1.01355    1.02011 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8635817374292523 for eigenvalue
#  The estimated number of batches is 1398
#       189/1    1.02184    1.02012 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.852950707666577 for eigenvalue
#  The estimated number of batches is 1396
#       190/1    1.01322    1.02008 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.835507904432818 for eigenvalue
#  The estimated number of batches is 1387
#       191/1    1.02926    1.02013 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.835462144815158 for eigenvalue
#  The estimated number of batches is 1395
#       192/1    1.02737    1.02017 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8238291508455022 for eigenvalue
#  The estimated number of batches is 1392
#       193/1    1.02817    1.02022 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8116437410764767 for eigenvalue
#  The estimated number of batches is 1388
#       194/1    1.03259    1.02029 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8132523230660764 for eigenvalue
#  The estimated number of batches is 1398
#       195/1    1.03621    1.02038 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.854761051018738 for eigenvalue
#  The estimated number of batches is 1447
#       196/1    1.02002    1.02038 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8441012157437244 for eigenvalue
#  The estimated number of batches is 1444
#       197/1    1.02383    1.02040 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8334706060171593 for eigenvalue
#  The estimated number of batches is 1442
#       198/1    1.02270    1.02041 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8282996658911963 for eigenvalue
#  The estimated number of batches is 1444
#       199/1    1.02341    1.02043 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8227944357986274 for eigenvalue
#  The estimated number of batches is 1447
#       200/1    1.03072    1.02049 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8068945409200357 for eigenvalue
#  The estimated number of batches is 1439
#       201/1    1.01391    1.02045 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7981428840243137 for eigenvalue
#  The estimated number of batches is 1438
#       202/1    1.01698    1.02043 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7836979482477324 for eigenvalue
#  The estimated number of batches is 1431
#       203/1    1.01378    1.02039 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.796122695145179 for eigenvalue
#  The estimated number of batches is 1451
#       204/1    1.01255    1.02035 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.787496377050668 for eigenvalue
#  The estimated number of batches is 1450
#       205/1    1.01451    1.02032 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7743301183257008 for eigenvalue
#  The estimated number of batches is 1444
#       206/1    1.01951    1.02032 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7702684074781954 for eigenvalue
#  The estimated number of batches is 1448
#       207/1    1.01558    1.02029 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7548493261692633 for eigenvalue
#  The estimated number of batches is 1440
#       208/1    1.01525    1.02026 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.741092223196715 for eigenvalue
#  The estimated number of batches is 1433
#       209/1    1.01343    1.02023 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7306504781560186 for eigenvalue
#  The estimated number of batches is 1430
#       210/1    1.02026    1.02023 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7167923108392347 for eigenvalue
#  The estimated number of batches is 1423
#       211/1    1.01748    1.02021 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.723555247615131 for eigenvalue
#  The estimated number of batches is 1437
#       212/1    1.01903    1.02021 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7219792996262027 for eigenvalue
#  The estimated number of batches is 1443
#       213/1    1.03168    1.02027 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7214869677603226 for eigenvalue
#  The estimated number of batches is 1450
#       214/1    1.02349    1.02028 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.720020199493489 for eigenvalue
#  The estimated number of batches is 1456
#       215/1    1.01612    1.02026 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.728315666532575 for eigenvalue
#  The estimated number of batches is 1472
#       216/1    1.01756    1.02025 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7158921127774804 for eigenvalue
#  The estimated number of batches is 1466
#       217/1    1.02655    1.02028 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.714710012121641 for eigenvalue
#  The estimated number of batches is 1472
#       218/1    1.01883    1.02027 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7010301719889487 for eigenvalue
#  The estimated number of batches is 1465
#       219/1    1.01418    1.02024 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.691411926140057 for eigenvalue
#  The estimated number of batches is 1462
#       220/1    1.01146    1.02020 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6776918644340744 for eigenvalue
#  The estimated number of batches is 1455
#       221/1    1.02065    1.02020 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.669206330395673 for eigenvalue
#  The estimated number of batches is 1453
#       222/1    1.01507    1.02017 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6549955119003097 for eigenvalue
#  The estimated number of batches is 1444
#       223/1    1.02107    1.02018 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6433448498679852 for eigenvalue
#  The estimated number of batches is 1439
#       224/1    1.01599    1.02016 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6297388202533565 for eigenvalue
#  The estimated number of batches is 1431
#       225/1    1.01923    1.02015 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.616727990545052 for eigenvalue
#  The estimated number of batches is 1424
#       226/1    1.02961    1.02020 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6517840515497464 for eigenvalue
#  The estimated number of batches is 1469
#       227/1    1.01610    1.02018 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.642032200699422 for eigenvalue
#  The estimated number of batches is 1465
#       228/1    1.02146    1.02019 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.633967331032048 for eigenvalue
#  The estimated number of batches is 1464
#       229/1    1.01546    1.02016 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.624947729478727 for eigenvalue
#  The estimated number of batches is 1461
#       230/1    1.02240    1.02017 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6452337547174474 for eigenvalue
#  The estimated number of batches is 1490
#       231/1    1.02807    1.02021 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6325303079251183 for eigenvalue
#  The estimated number of batches is 1483
#       232/1    1.01414    1.02018 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.621082777567362 for eigenvalue
#  The estimated number of batches is 1477
#       233/1    1.01590    1.02016 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6168089313592646 for eigenvalue
#  The estimated number of batches is 1479
#       234/1    1.02243    1.02017 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.609869339660165 for eigenvalue
#  The estimated number of batches is 1478
#       235/1    1.02291    1.02019 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.597330442967114 for eigenvalue
#  The estimated number of batches is 1471
#       236/1    1.01748    1.02017 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.590503856542714 for eigenvalue
#  The estimated number of batches is 1470
#       237/1    1.03264    1.02023 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.617194597404789 for eigenvalue
#  The estimated number of batches is 1507
#       238/1    1.02053    1.02023 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6061217917716037 for eigenvalue
#  The estimated number of batches is 1501
#       239/1    1.02124    1.02024 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5934937914523677 for eigenvalue
#  The estimated number of batches is 1494
#       240/1    1.02288    1.02025 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.586979119681282 for eigenvalue
#  The estimated number of batches is 1493
#       241/1    1.03161    1.02030 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5829135151827676 for eigenvalue
#  The estimated number of batches is 1495
#       242/1    1.01587    1.02028 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5712143607943663 for eigenvalue
#  The estimated number of batches is 1488
#       243/1    1.00621    1.02022 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5624655314153744 for eigenvalue
#  The estimated number of batches is 1485
#       244/1    1.02583    1.02024 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.551130026091349 for eigenvalue
#  The estimated number of batches is 1478
#       245/1    1.01937    1.02024 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5425239635062873 for eigenvalue
#  The estimated number of batches is 1475
#       246/1    1.02392    1.02025 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5310754112461615 for eigenvalue
#  The estimated number of batches is 1468
#       247/1    1.03009    1.02030 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5195781863066524 for eigenvalue
#  The estimated number of batches is 1462
#       248/1    1.01836    1.02029 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5227676988792105 for eigenvalue
#  The estimated number of batches is 1472
#       249/1    1.01525    1.02027 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.521969926936449 for eigenvalue
#  The estimated number of batches is 1477
#       250/1    1.01385    1.02024 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5152800213485103 for eigenvalue
#  The estimated number of batches is 1476
#       251/1    1.01679    1.02022 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5062844694087842 for eigenvalue
#  The estimated number of batches is 1472
#       252/1    1.01512    1.02020 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.502292091577534 for eigenvalue
#  The estimated number of batches is 1473
#       253/1    1.02048    1.02020 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4921084254784667 for eigenvalue
#  The estimated number of batches is 1468
#       254/1    1.01832    1.02020 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.505360304675963 for eigenvalue
#  The estimated number of batches is 1489
#       255/1    1.01539    1.02018 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4949346038116804 for eigenvalue
#  The estimated number of batches is 1483
#       256/1    1.01550    1.02016 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4846044246065793 for eigenvalue
#  The estimated number of batches is 1477
#       257/1    1.02317    1.02017 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4858999382491596 for eigenvalue
#  The estimated number of batches is 1485
#       258/1    1.01581    1.02015 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.476134666358554 for eigenvalue
#  The estimated number of batches is 1480
#       259/1    1.00842    1.02010 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4931849925850185 for eigenvalue
#  The estimated number of batches is 1506
#       260/1    1.02162    1.02011 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.482803735523712 for eigenvalue
#  The estimated number of batches is 1500
#       261/1    1.02248    1.02012 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4752147268453495 for eigenvalue
#  The estimated number of batches is 1497
#       262/1    1.02306    1.02013 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4650024911708193 for eigenvalue
#  The estimated number of batches is 1491
#       263/1    1.02246    1.02014 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.454633360048409 for eigenvalue
#  The estimated number of batches is 1485
#       264/1    1.01684    1.02013 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4601932808629665 for eigenvalue
#  The estimated number of batches is 1497
#       265/1    1.00482    1.02006 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4729887100943952 for eigenvalue
#  The estimated number of batches is 1519
#       266/1    1.02411    1.02008 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.462997435234513 for eigenvalue
#  The estimated number of batches is 1513
#       267/1    1.01620    1.02006 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4543520907244356 for eigenvalue
#  The estimated number of batches is 1508
#       268/1    1.01355    1.02004 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4524173921966543 for eigenvalue
#  The estimated number of batches is 1512
#       269/1    1.02173    1.02004 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4444294521810472 for eigenvalue
#  The estimated number of batches is 1508
#       270/1    1.01577    1.02003 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.434555402254156 for eigenvalue
#  The estimated number of batches is 1502
#       271/1    1.01887    1.02002 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4268188691859853 for eigenvalue
#  The estimated number of batches is 1499
#       272/1    1.01418    1.02000 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.421299228517679 for eigenvalue
#  The estimated number of batches is 1498
#       273/1    1.03242    1.02005 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4124636595291378 for eigenvalue
#  The estimated number of batches is 1493
#       274/1    1.02264    1.02006 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4055571333854404 for eigenvalue
#  The estimated number of batches is 1490
#       275/1    1.02020    1.02006 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3973741243226128 for eigenvalue
#  The estimated number of batches is 1486
#       276/1    1.02667    1.02009 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3981723398118278 for eigenvalue
#  The estimated number of batches is 1493
#       277/1    1.02096    1.02009 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.389347691946071 for eigenvalue
#  The estimated number of batches is 1488
#       278/1    1.01681    1.02008 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3803132556121476 for eigenvalue
#  The estimated number of batches is 1482
#       279/1    1.01338    1.02005 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.38291128021595 for eigenvalue
#  The estimated number of batches is 1491
#       280/1    1.01988    1.02005 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3763512655089296 for eigenvalue
#  The estimated number of batches is 1489
#       281/1    1.01701    1.02004 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.367625962649631 for eigenvalue
#  The estimated number of batches is 1484
#       282/1    1.02556    1.02006 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3622824130013713 for eigenvalue
#  The estimated number of batches is 1483
#       283/1    1.02329    1.02007 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3533750664782036 for eigenvalue
#  The estimated number of batches is 1477
#       284/1    1.01287    1.02004 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.344572181709487 for eigenvalue
#  The estimated number of batches is 1472
#       285/1    1.02224    1.02005 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3361244447588634 for eigenvalue
#  The estimated number of batches is 1467
#       286/1    1.01987    1.02005 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.337758927680562 for eigenvalue
#  The estimated number of batches is 1474
#       287/1    1.02451    1.02007 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.374883767196866 for eigenvalue
#  The estimated number of batches is 1526
#       288/1    1.02575    1.02009 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.368979869892142 for eigenvalue
#  The estimated number of batches is 1525
#       289/1    1.01381    1.02007 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3789118156283853 for eigenvalue
#  The estimated number of batches is 1543
#       290/1    1.02043    1.02007 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.37093018296688 for eigenvalue
#  The estimated number of batches is 1538
#       291/1    1.01252    1.02004 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.363359012344984 for eigenvalue
#  The estimated number of batches is 1534
#       292/1    1.02395    1.02005 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3564429855692643 for eigenvalue
#  The estimated number of batches is 1531
#       293/1    1.02654    1.02008 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3481655905531733 for eigenvalue
#  The estimated number of batches is 1526
#       294/1    1.01546    1.02006 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.345169660012935 for eigenvalue
#  The estimated number of batches is 1527
#       295/1    1.02441    1.02008 +/- 0.00034
# ...
#      1457/1    1.02396    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0203352211017611 for eigenvalue
#  The estimated number of batches is 1517
#      1458/1    1.02222    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0196322414982384 for eigenvalue
#  The estimated number of batches is 1516
#      1459/1    1.02024    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0194810541138402 for eigenvalue
#  The estimated number of batches is 1516
#      1460/1    1.02396    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0187848072762244 for eigenvalue
#  The estimated number of batches is 1515
#      1461/1    1.01436    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.018625362295432 for eigenvalue
#  The estimated number of batches is 1516
#      1462/1    1.00523    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0183963538506138 for eigenvalue
#  The estimated number of batches is 1516
#      1463/1    1.02940    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0177715590438918 for eigenvalue
#  The estimated number of batches is 1515
#      1464/1    1.03669    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.018030113835054 for eigenvalue
#  The estimated number of batches is 1517
#      1465/1    1.01781    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.017570847773645 for eigenvalue
#  The estimated number of batches is 1517
#      1466/1    1.00193    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0197967034523325 for eigenvalue
#  The estimated number of batches is 1524
#      1467/1    1.01590    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0196291002252302 for eigenvalue
#  The estimated number of batches is 1525
#      1468/1    1.01278    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0192054359755203 for eigenvalue
#  The estimated number of batches is 1525
#      1469/1    1.01811    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0185052687854326 for eigenvalue
#  The estimated number of batches is 1524
#      1470/1    1.01706    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0178087194934855 for eigenvalue
#  The estimated number of batches is 1523
#      1471/1    1.02337    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0184321588273313 for eigenvalue
#  The estimated number of batches is 1525
#      1472/1    1.01514    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.017922722583337 for eigenvalue
#  The estimated number of batches is 1525
#      1473/1    1.02340    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0176184374620292 for eigenvalue
#  The estimated number of batches is 1525
#      1474/1    1.01770    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0169129797847622 for eigenvalue
#  The estimated number of batches is 1524
#      1475/1    1.02374    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0168669669379684 for eigenvalue
#  The estimated number of batches is 1525
#      1476/1    1.02130    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0165492478270237 for eigenvalue
#  The estimated number of batches is 1525
#      1477/1    1.01728    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0161750440867345 for eigenvalue
#  The estimated number of batches is 1525
#      1478/1    1.01920    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0155477553783159 for eigenvalue
#  The estimated number of batches is 1524
#      1479/1    1.02367    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0148951624883775 for eigenvalue
#  The estimated number of batches is 1523
#      1480/1    1.02114    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0142244392520683 for eigenvalue
#  The estimated number of batches is 1522
#      1481/1    1.01917    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0135718094453325 for eigenvalue
#  The estimated number of batches is 1521
#      1482/1    1.00826    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0137229308890334 for eigenvalue
#  The estimated number of batches is 1523
#      1483/1    1.01082    1.01991 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0135388507084278 for eigenvalue
#  The estimated number of batches is 1523
#      1484/1    1.02259    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.013102074257927 for eigenvalue
#  The estimated number of batches is 1523
#      1485/1    1.01958    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0124822322769418 for eigenvalue
#  The estimated number of batches is 1522
#      1486/1    1.01943    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0121199290892526 for eigenvalue
#  The estimated number of batches is 1522
#      1487/1    1.01536    1.01991 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0119975951991285 for eigenvalue
#  The estimated number of batches is 1523
#      1488/1    1.01681    1.01991 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0119648757212112 for eigenvalue
#  The estimated number of batches is 1524
#      1489/1    1.02725    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0116533697811443 for eigenvalue
#  The estimated number of batches is 1524
#      1490/1    1.03334    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.013384834082068 for eigenvalue
#  The estimated number of batches is 1530
#      1491/1    1.00945    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.013036190653558 for eigenvalue
#  The estimated number of batches is 1530
#      1492/1    1.02575    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0128464735525313 for eigenvalue
#  The estimated number of batches is 1531
#      1493/1    1.02336    1.01992 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.012754415124964 for eigenvalue
#  The estimated number of batches is 1531
#      1494/1    1.02393    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0129832869024484 for eigenvalue
#  The estimated number of batches is 1533
#      1495/1    1.02129    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0125689489648144 for eigenvalue
#  The estimated number of batches is 1533
#      1496/1    1.01788    1.01993 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0118759832719764 for eigenvalue
#  The estimated number of batches is 1532
#      1497/1    1.03758    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0124530552344864 for eigenvalue
#  The estimated number of batches is 1535
#      1498/1    1.02292    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.012729458282855 for eigenvalue
#  The estimated number of batches is 1536
#      1499/1    1.01830    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0120700518158638 for eigenvalue
#  The estimated number of batches is 1535
#      1500/1    1.02286    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0119867741109174 for eigenvalue
#  The estimated number of batches is 1536
#      1501/1    1.02382    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.011654648191914 for eigenvalue
#  The estimated number of batches is 1536
#      1502/1    1.01144    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0109614508623892 for eigenvalue
#  The estimated number of batches is 1535
#      1503/1    1.02419    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0103062481856382 for eigenvalue
#  The estimated number of batches is 1534
#      1504/1    1.02008    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0096806624262833 for eigenvalue
#  The estimated number of batches is 1533
#      1505/1    1.01651    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.009095734674398 for eigenvalue
#  The estimated number of batches is 1533
#      1506/1    1.02426    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0086135359126094 for eigenvalue
#  The estimated number of batches is 1532
#      1507/1    1.02121    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0080322154370869 for eigenvalue
#  The estimated number of batches is 1531
#      1508/1    1.02207    1.01994 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0073606575587042 for eigenvalue
#  The estimated number of batches is 1530
#      1509/1    1.02435    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0068361855468209 for eigenvalue
#  The estimated number of batches is 1530
#      1510/1    1.02785    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0075891687502527 for eigenvalue
#  The estimated number of batches is 1533
#      1511/1    1.02764    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0100461039899828 for eigenvalue
#  The estimated number of batches is 1542
#      1512/1    1.00821    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0111557587885747 for eigenvalue
#  The estimated number of batches is 1546
#      1513/1    1.01789    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.010540676475664 for eigenvalue
#  The estimated number of batches is 1545
#      1514/1    1.01836    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0102030169729004 for eigenvalue
#  The estimated number of batches is 1545
#      1515/1    1.01920    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0095246038557006 for eigenvalue
#  The estimated number of batches is 1544
#      1516/1    1.01977    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0091261306600467 for eigenvalue
#  The estimated number of batches is 1544
#      1517/1    1.02697    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0086229455359166 for eigenvalue
#  The estimated number of batches is 1543
#      1518/1    1.01624    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0084585233717842 for eigenvalue
#  The estimated number of batches is 1544
#      1519/1    1.01828    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.007792471527052 for eigenvalue
#  The estimated number of batches is 1543
#      1520/1    1.02033    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0072215752728146 for eigenvalue
#  The estimated number of batches is 1542
#      1521/1    1.02764    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0077426353696064 for eigenvalue
#  The estimated number of batches is 1545
#      1522/1    1.02042    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0071535018276978 for eigenvalue
#  The estimated number of batches is 1544
#      1523/1    1.02442    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0066000685835788 for eigenvalue
#  The estimated number of batches is 1543
#      1524/1    1.02646    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0068534991368672 for eigenvalue
#  The estimated number of batches is 1545
#      1525/1    1.02430    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0062055355625805 for eigenvalue
#  The estimated number of batches is 1544
#      1526/1    1.02095    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0055698730827531 for eigenvalue
#  The estimated number of batches is 1543
#      1527/1    1.02007    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.005628070858471 for eigenvalue
#  The estimated number of batches is 1545
#      1528/1    1.02403    1.01997 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0050168810099913 for eigenvalue
#  The estimated number of batches is 1544
#      1529/1    1.00787    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0043762403360665 for eigenvalue
#  The estimated number of batches is 1543
#      1530/1    1.01772    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0037157839961695 for eigenvalue
#  The estimated number of batches is 1542
#      1531/1    1.01690    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0030421441950057 for eigenvalue
#  The estimated number of batches is 1541
#      1532/1    1.02587    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0036365078427416 for eigenvalue
#  The estimated number of batches is 1544
#      1533/1    1.01632    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0037191697842107 for eigenvalue
#  The estimated number of batches is 1545
#      1534/1    1.02269    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.003108099829239 for eigenvalue
#  The estimated number of batches is 1544
#      1535/1    1.02089    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0025176677441534 for eigenvalue
#  The estimated number of batches is 1543
#      1536/1    1.01864    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0020360908924768 for eigenvalue
#  The estimated number of batches is 1543
#      1537/1    1.01800    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0014652808479079 for eigenvalue
#  The estimated number of batches is 1542
#      1538/1    1.01593    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0008575973621794 for eigenvalue
#  The estimated number of batches is 1541
#      1539/1    1.00683    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0019214723361534 for eigenvalue
#  The estimated number of batches is 1545
#      1540/1    1.02191    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0014491665287053 for eigenvalue
#  The estimated number of batches is 1545
#      1541/1    1.02658    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.001255704319341 for eigenvalue
#  The estimated number of batches is 1545
#      1542/1    1.02031    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0006016187432827 for eigenvalue
#  The estimated number of batches is 1544
#      1543/1    1.01933    1.01995 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0000811765142334 for eigenvalue
#  The estimated number of batches is 1544
#      1544/1    1.02992    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0008836414235196 for eigenvalue
#  The estimated number of batches is 1547
#      1545/1    1.01719    1.01996 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0002215158473466 for eigenvalue
#  The estimated number of batches is 1546
#      1546/1    1.02883    1.01996 +/- 0.00015
#  Triggers satisfied for batch 1546
#  Creating state point statepoint.01546.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.8481e+01 seconds
#    Reading cross sections          = 6.7553e+01 seconds
#  Total time in simulation          = 2.2738e+04 seconds
#    Time in transport only          = 2.2678e+04 seconds
#    Time in inactive batches        = 1.7367e+02 seconds
#    Time in active batches          = 2.2565e+04 seconds
#    Time synchronizing fission bank = 1.4795e+01 seconds
#      Sampling source sites         = 1.1669e+01 seconds
#      SEND/RECV source sites        = 3.1241e+00 seconds
#    Time accumulating tallies       = 3.8976e+01 seconds
#    Time writing statepoints        = 2.2614e-02 seconds
#  Total time for finalization       = 3.9175e-02 seconds
#  Total time elapsed                = 2.2807e+04 seconds
#  Calculation Rate (inactive)       = 5757.9 particles/second
#  Calculation Rate (active)         = 3381.38 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.01992 +/- 0.00013
#  k-effective (Track-length)  = 1.01996 +/- 0.00015
#  k-effective (Absorption)    = 1.01984 +/- 0.00012
#  Combined k-effective        = 1.01988 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
