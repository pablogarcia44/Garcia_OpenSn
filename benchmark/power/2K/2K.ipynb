# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2_low = openmc.Material(name='uo2_low')
uo2_low.add_nuclide('U234', 6.11864E-06, 'ao')
uo2_low.add_nuclide('U235', 7.18132E-04, 'ao')
uo2_low.add_nuclide('U236', 3.29861E-06, 'ao')
uo2_low.add_nuclide('U238', 2.21546E-02, 'ao')
uo2_low.add_nuclide('O16', 4.57642E-02, 'ao')
uo2_low.set_density('g/cm3', 10.257 )
uo2_low.temperature=600

uo2_high = openmc.Material(name='uo2_high')
uo2_high.add_nuclide('U234', 7.21203E-06, 'ao')
uo2_high.add_nuclide('U235', 8.33952E-04, 'ao')
uo2_high.add_nuclide('U236', 3.82913E-06, 'ao')
uo2_high.add_nuclide('U238', 2.20384E-02, 'ao')
uo2_high.add_nuclide('O16', 4.57669E-02, 'ao')
uo2_high.set_density('g/cm3', 10.257 )
uo2_high.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2_high,uo2_low, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell_high(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2_high
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %%
def pincell_low(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2_low
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]
F_low=[(8,7),(7,8),(0,0),(1,0),(0,1),(2,0),(0,2),(1,1)]



PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

F_low_left=[]
F_low_full=[]
for X in F_low:
    F_low_left.append((X[0],X[1]))
    F_low_left.append((X[0],16-X[1]))
for X in F_low_left:
    F_low_full.append((X[0],X[1]))
    F_low_full.append((16-X[0],X[1]))    
F_low_full = list(set(F_low_full))

# %%
pincell_low_1_family=pincell_low('pincell_low_1_family')
pincell_high_1_family=pincell_high('pincell_high_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in F_low_full:
            A[ix][iy]=pincell_low_1_family[0]
        else:
            A[ix][iy]=pincell_high_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:01
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.00658
#         2/1    1.02073
#         3/1    1.02166
#         4/1    1.00921
#         5/1    1.01996
#         6/1    1.01206
#         7/1    1.01378
#         8/1    1.01967
#         9/1    1.01055
#        10/1    1.02481
#        11/1    1.02488
#        12/1    1.00234
#        13/1    1.01947
#        14/1    1.02393
#        15/1    1.02015
#        16/1    1.02185
#        17/1    1.01945
#        18/1    1.00749
#        19/1    1.01405
#        20/1    1.02420
#        21/1    1.01093
#        22/1    1.02143    1.01618 +/- 0.00525
#        23/1    1.00646    1.01294 +/- 0.00444
#        24/1    1.01494    1.01344 +/- 0.00318
#        25/1    1.02262    1.01528 +/- 0.00307
#        26/1    1.00871    1.01418 +/- 0.00274
#        27/1    1.01760    1.01467 +/- 0.00236
#        28/1    1.01209    1.01435 +/- 0.00207
#        29/1    1.01627    1.01456 +/- 0.00184
#        30/1    1.01643    1.01475 +/- 0.00166
#        31/1    1.01000    1.01432 +/- 0.00156
#        32/1    1.02195    1.01495 +/- 0.00156
#        33/1    1.01555    1.01500 +/- 0.00143
#        34/1    1.00469    1.01426 +/- 0.00152
#        35/1    1.00964    1.01395 +/- 0.00145
#        36/1    1.02157    1.01443 +/- 0.00143
#        37/1    1.00953    1.01414 +/- 0.00138
#        38/1    1.01163    1.01400 +/- 0.00131
#        39/1    1.02057    1.01435 +/- 0.00128
#        40/1    1.00163    1.01371 +/- 0.00137
#        41/1    1.00919    1.01350 +/- 0.00132
#        42/1    1.00072    1.01291 +/- 0.00139
#        43/1    1.01450    1.01298 +/- 0.00133
#        44/1    1.02155    1.01334 +/- 0.00132
#        45/1    1.01933    1.01358 +/- 0.00129
#        46/1    1.01608    1.01368 +/- 0.00124
#        47/1    1.01407    1.01369 +/- 0.00120
#        48/1    1.00304    1.01331 +/- 0.00121
#        49/1    1.01074    1.01322 +/- 0.00118
#        50/1    1.01350    1.01323 +/- 0.00114
#  Triggers unsatisfied, max unc./thresh. is 6.538058829760808 for eigenvalue
#  The estimated number of batches is 1303
#  Creating state point statepoint.00050.h5...
#        51/1    1.01111    1.01316 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 6.382369421296139 for eigenvalue
#  The estimated number of batches is 1283
#        52/1    1.02244    1.01345 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 6.502661467105994 for eigenvalue
#  The estimated number of batches is 1374
#        53/1    1.01974    1.01364 +/- 0.00109
#  Triggers unsatisfied, max unc./thresh. is 6.295536106897619 for eigenvalue
#  The estimated number of batches is 1328
#        54/1    1.02189    1.01389 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 5.980286785443922 for eigenvalue
#  The estimated number of batches is 1236
#        55/1    1.01016    1.01378 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 5.840173038652153 for eigenvalue
#  The estimated number of batches is 1214
#        56/1    1.02486    1.01409 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 5.575578965176183 for eigenvalue
#  The estimated number of batches is 1140
#        57/1    1.01755    1.01418 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 5.4321705631283494 for eigenvalue
#  The estimated number of batches is 1112
#        58/1    1.01845    1.01429 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 5.291259622124996 for eigenvalue
#  The estimated number of batches is 1084
#        59/1    1.00869    1.01415 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 5.229581399468544 for eigenvalue
#  The estimated number of batches is 1087
#        60/1    1.00465    1.01391 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 5.1577257294488295 for eigenvalue
#  The estimated number of batches is 1085
#        61/1    1.01237    1.01387 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 5.25055566169 for eigenvalue
#  The estimated number of batches is 1151
#        62/1    1.00556    1.01368 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 5.173615318468639 for eigenvalue
#  The estimated number of batches is 1145
#        63/1    1.01842    1.01379 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 5.05502784427087 for eigenvalue
#  The estimated number of batches is 1119
#        64/1    1.00315    1.01354 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 5.11032025379653 for eigenvalue
#  The estimated number of batches is 1170
#        65/1    1.01914    1.01367 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 4.957634181762338 for eigenvalue
#  The estimated number of batches is 1127
#        66/1    1.01820    1.01377 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 4.9318073015558035 for eigenvalue
#  The estimated number of batches is 1139
#        67/1    1.01714    1.01384 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 4.935228805421991 for eigenvalue
#  The estimated number of batches is 1165
#        68/1    1.02046    1.01398 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 4.788776615408322 for eigenvalue
#  The estimated number of batches is 1121
#        69/1    1.00773    1.01385 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.860158746121956 for eigenvalue
#  The estimated number of batches is 1178
#        70/1    1.02530    1.01408 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 4.933450603479901 for eigenvalue
#  The estimated number of batches is 1237
#        71/1    1.01613    1.01412 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.886533966798612 for eigenvalue
#  The estimated number of batches is 1238
#        72/1    1.01425    1.01412 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.853001858870138 for eigenvalue
#  The estimated number of batches is 1245
#        73/1    1.01359    1.01411 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.767705828217247 for eigenvalue
#  The estimated number of batches is 1225
#        74/1    1.02182    1.01425 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 4.6989003601878325 for eigenvalue
#  The estimated number of batches is 1213
#        75/1    1.02203    1.01440 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 4.585337551200181 for eigenvalue
#  The estimated number of batches is 1177
#        76/1    1.02047    1.01450 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.4962570998178455 for eigenvalue
#  The estimated number of batches is 1153
#        77/1    1.00950    1.01442 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 4.430159006564898 for eigenvalue
#  The estimated number of batches is 1139
#        78/1    1.01812    1.01448 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.347095908047347 for eigenvalue
#  The estimated number of batches is 1117
#        79/1    1.02420    1.01464 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.388755433935306 for eigenvalue
#  The estimated number of batches is 1157
#        80/1    1.01633    1.01467 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 4.313216403867864 for eigenvalue
#  The estimated number of batches is 1137
#        81/1    1.01210    1.01463 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.2356907802547425 for eigenvalue
#  The estimated number of batches is 1115
#        82/1    1.00695    1.01451 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.261823837312129 for eigenvalue
#  The estimated number of batches is 1147
#        83/1    1.02393    1.01466 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.2129631336462054 for eigenvalue
#  The estimated number of batches is 1139
#        84/1    1.01887    1.01472 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.168815195607511 for eigenvalue
#  The estimated number of batches is 1133
#        85/1    1.01923    1.01479 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.098571432755738 for eigenvalue
#  The estimated number of batches is 1112
#        86/1    1.01065    1.01473 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.113188033401409 for eigenvalue
#  The estimated number of batches is 1137
#        87/1    1.01457    1.01473 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.085201404953004 for eigenvalue
#  The estimated number of batches is 1139
#        88/1    1.01881    1.01479 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.072646398060118 for eigenvalue
#  The estimated number of batches is 1148
#        89/1    1.02104    1.01488 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.007235069427891 for eigenvalue
#  The estimated number of batches is 1128
#        90/1    1.02330    1.01500 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 3.9597242651042155 for eigenvalue
#  The estimated number of batches is 1118
#        91/1    1.01215    1.01496 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 3.905098139960769 for eigenvalue
#  The estimated number of batches is 1103
#        92/1    1.01915    1.01502 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 3.8454273624508826 for eigenvalue
#  The estimated number of batches is 1085
#        93/1    1.02407    1.01514 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 3.798178367596438 for eigenvalue
#  The estimated number of batches is 1074
#        94/1    1.02133    1.01522 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.135237411679741 for eigenvalue
#  The estimated number of batches is 1286
#        95/1    1.00179    1.01504 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.3985028684612235 for eigenvalue
#  The estimated number of batches is 1472
#        96/1    1.01027    1.01498 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.339643660264862 for eigenvalue
#  The estimated number of batches is 1452
#        97/1    1.01875    1.01503 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.287367973772784 for eigenvalue
#  The estimated number of batches is 1436
#        98/1    1.01436    1.01502 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.25222604326528 for eigenvalue
#  The estimated number of batches is 1431
#        99/1    1.02391    1.01513 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.183402712766718 for eigenvalue
#  The estimated number of batches is 1403
#       100/1    1.02164    1.01522 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.123415130258052 for eigenvalue
#  The estimated number of batches is 1381
#       101/1    1.01289    1.01519 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.096938141877973 for eigenvalue
#  The estimated number of batches is 1380
#       102/1    1.01719    1.01521 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.056742375797726 for eigenvalue
#  The estimated number of batches is 1370
#       103/1    1.02062    1.01528 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.0290122767139085 for eigenvalue
#  The estimated number of batches is 1368
#       104/1    1.01405    1.01526 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 3.990293864506514 for eigenvalue
#  The estimated number of batches is 1358
#       105/1    1.02141    1.01533 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 3.984560519930121 for eigenvalue
#  The estimated number of batches is 1370
#       106/1    1.01810    1.01537 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 3.9372574113499947 for eigenvalue
#  The estimated number of batches is 1354
#       107/1    1.01934    1.01541 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 3.9270571103871004 for eigenvalue
#  The estimated number of batches is 1362
#       108/1    1.01454    1.01540 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.884250547850138 for eigenvalue
#  The estimated number of batches is 1348
#       109/1    1.02256    1.01548 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.8961861293887936 for eigenvalue
#  The estimated number of batches is 1372
#       110/1    1.01819    1.01551 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.881293834888236 for eigenvalue
#  The estimated number of batches is 1376
#       111/1    1.01372    1.01549 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.849782728345949 for eigenvalue
#  The estimated number of batches is 1369
#       112/1    1.01986    1.01554 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.837805034276785 for eigenvalue
#  The estimated number of batches is 1376
#       113/1    1.00766    1.01546 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.8424160187413032 for eigenvalue
#  The estimated number of batches is 1394
#       114/1    1.03160    1.01563 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.9213917376005445 for eigenvalue
#  The estimated number of batches is 1466
#       115/1    1.01521    1.01562 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.8883462360714027 for eigenvalue
#  The estimated number of batches is 1457
#       116/1    1.01424    1.01561 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.897553645634995 for eigenvalue
#  The estimated number of batches is 1479
#       117/1    1.00513    1.01550 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.867031266951563 for eigenvalue
#  The estimated number of batches is 1471
#       118/1    1.00974    1.01544 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.8341993425453897 for eigenvalue
#  The estimated number of batches is 1461
#       119/1    1.02359    1.01552 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.8065843229862053 for eigenvalue
#  The estimated number of batches is 1455
#       120/1    1.01632    1.01553 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.763173520348509 for eigenvalue
#  The estimated number of batches is 1437
#       121/1    1.02271    1.01560 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.8035401831489684 for eigenvalue
#  The estimated number of batches is 1482
#       122/1    1.02431    1.01569 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.761763977440135 for eigenvalue
#  The estimated number of batches is 1464
#       123/1    1.01497    1.01568 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.7329009587875577 for eigenvalue
#  The estimated number of batches is 1456
#       124/1    1.01312    1.01566 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.729801082175134 for eigenvalue
#  The estimated number of batches is 1467
#       125/1    1.00428    1.01555 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.7391712494423013 for eigenvalue
#  The estimated number of batches is 1489
#       126/1    1.02017    1.01559 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.7108677681819144 for eigenvalue
#  The estimated number of batches is 1480
#       127/1    1.01694    1.01560 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.692218865492611 for eigenvalue
#  The estimated number of batches is 1479
#       128/1    1.01361    1.01559 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.6685090973514347 for eigenvalue
#  The estimated number of batches is 1474
#       129/1    1.01129    1.01555 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.6369290352121575 for eigenvalue
#  The estimated number of batches is 1462
#       130/1    1.01443    1.01554 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.643040573542442 for eigenvalue
#  The estimated number of batches is 1480
#       131/1    1.01629    1.01554 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6096921398370405 for eigenvalue
#  The estimated number of batches is 1467
#       132/1    1.01655    1.01555 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.578595741073873 for eigenvalue
#  The estimated number of batches is 1455
#       133/1    1.02320    1.01562 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.595922702919473 for eigenvalue
#  The estimated number of batches is 1482
#       134/1    1.01123    1.01558 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.568342015054346 for eigenvalue
#  The estimated number of batches is 1472
#       135/1    1.01623    1.01559 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.536450323514519 for eigenvalue
#  The estimated number of batches is 1459
#       136/1    1.00709    1.01551 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.514866258899937 for eigenvalue
#  The estimated number of batches is 1454
#       137/1    1.02440    1.01559 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.4983806865060623 for eigenvalue
#  The estimated number of batches is 1452
#       138/1    1.01666    1.01560 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.462199561775151 for eigenvalue
#  The estimated number of batches is 1435
#       139/1    1.02621    1.01569 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.43095866947111 for eigenvalue
#  The estimated number of batches is 1421
#       140/1    1.01230    1.01566 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.404234826248787 for eigenvalue
#  The estimated number of batches is 1411
#       141/1    1.02253    1.01572 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.3898756742352765 for eigenvalue
#  The estimated number of batches is 1411
#       142/1    1.01662    1.01572 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.3643292087185057 for eigenvalue
#  The estimated number of batches is 1401
#       143/1    1.02167    1.01577 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.33391923279399 for eigenvalue
#  The estimated number of batches is 1388
#       144/1    1.01394    1.01576 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3038062158827355 for eigenvalue
#  The estimated number of batches is 1374
#       145/1    1.02007    1.01579 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.2886457048074402 for eigenvalue
#  The estimated number of batches is 1372
#       146/1    1.01706    1.01580 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.294540655610832 for eigenvalue
#  The estimated number of batches is 1388
#       147/1    1.01094    1.01576 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.2937794935682203 for eigenvalue
#  The estimated number of batches is 1398
#       148/1    1.02681    1.01585 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3672389757753094 for eigenvalue
#  The estimated number of batches is 1472
#       149/1    1.02773    1.01594 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3450773426180893 for eigenvalue
#  The estimated number of batches is 1464
#       150/1    1.01265    1.01592 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3414486469499836 for eigenvalue
#  The estimated number of batches is 1472
#       151/1    1.02443    1.01598 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.325750156120198 for eigenvalue
#  The estimated number of batches is 1469
#       152/1    1.01679    1.01599 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.326877058014396 for eigenvalue
#  The estimated number of batches is 1481
#       153/1    1.01021    1.01594 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3172492893113117 for eigenvalue
#  The estimated number of batches is 1484
#       154/1    1.02980    1.01605 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.306686573702569 for eigenvalue
#  The estimated number of batches is 1486
#       155/1    1.01315    1.01603 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.2955015844582216 for eigenvalue
#  The estimated number of batches is 1487
#       156/1    1.02012    1.01606 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.2977053275344557 for eigenvalue
#  The estimated number of batches is 1499
#       157/1    1.01979    1.01608 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2902625486074073 for eigenvalue
#  The estimated number of batches is 1504
#       158/1    1.01985    1.01611 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3018971467256013 for eigenvalue
#  The estimated number of batches is 1525
#       159/1    1.01160    1.01608 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2810168624214 for eigenvalue
#  The estimated number of batches is 1517
#       160/1    1.01466    1.01607 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3100230335004808 for eigenvalue
#  The estimated number of batches is 1554
#       161/1    1.02128    1.01611 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2923805642372557 for eigenvalue
#  The estimated number of batches is 1549
#       162/1    1.02424    1.01616 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2714283274606464 for eigenvalue
#  The estimated number of batches is 1540
#       163/1    1.01941    1.01619 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.281112483708978 for eigenvalue
#  The estimated number of batches is 1560
#       164/1    1.01864    1.01620 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2819676033782224 for eigenvalue
#  The estimated number of batches is 1572
#       165/1    1.02110    1.01624 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2674098945801777 for eigenvalue
#  The estimated number of batches is 1569
#       166/1    1.00766    1.01618 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3036773197789993 for eigenvalue
#  The estimated number of batches is 1614
#       167/1    1.01045    1.01614 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2847343853026496 for eigenvalue
#  The estimated number of batches is 1607
#       168/1    1.01895    1.01616 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.260348390858076 for eigenvalue
#  The estimated number of batches is 1594
#       169/1    1.01276    1.01613 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2385404132802744 for eigenvalue
#  The estimated number of batches is 1583
#       170/1    1.01461    1.01612 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2251558798937863 for eigenvalue
#  The estimated number of batches is 1581
#       171/1    1.02135    1.01616 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2038741724535678 for eigenvalue
#  The estimated number of batches is 1570
#       172/1    1.01352    1.01614 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.188648526318185 for eigenvalue
#  The estimated number of batches is 1566
#       173/1    1.00976    1.01610 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.177541236126067 for eigenvalue
#  The estimated number of batches is 1565
#       174/1    1.01320    1.01608 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2487283320712943 for eigenvalue
#  The estimated number of batches is 1646
#       175/1    1.01682    1.01609 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.232299279333485 for eigenvalue
#  The estimated number of batches is 1640
#       176/1    1.00912    1.01604 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.225633346438964 for eigenvalue
#  The estimated number of batches is 1644
#       177/1    1.01603    1.01604 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2065422621554696 for eigenvalue
#  The estimated number of batches is 1635
#       178/1    1.01649    1.01604 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.191150356486928 for eigenvalue
#  The estimated number of batches is 1629
#       179/1    1.01975    1.01607 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.175168997185429 for eigenvalue
#  The estimated number of batches is 1623
#       180/1    1.02399    1.01612 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.156105456677175 for eigenvalue
#  The estimated number of batches is 1614
#       181/1    1.01665    1.01612 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.137447155778827 for eigenvalue
#  The estimated number of batches is 1605
#       182/1    1.01839    1.01613 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1286318817564456 for eigenvalue
#  The estimated number of batches is 1606
#       183/1    1.01807    1.01615 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1084442526381384 for eigenvalue
#  The estimated number of batches is 1595
#       184/1    1.01692    1.01615 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.091602746619706 for eigenvalue
#  The estimated number of batches is 1588
#       185/1    1.02251    1.01619 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.074274003181778 for eigenvalue
#  The estimated number of batches is 1580
#       186/1    1.02282    1.01623 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.06061095340031 for eigenvalue
#  The estimated number of batches is 1575
#       187/1    1.01048    1.01619 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.045185481646899 for eigenvalue
#  The estimated number of batches is 1569
#       188/1    1.01810    1.01621 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0338390433342903 for eigenvalue
#  The estimated number of batches is 1567
#       189/1    1.01991    1.01623 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.01595391537473 for eigenvalue
#  The estimated number of batches is 1558
#       190/1    1.01670    1.01623 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.003870435682571 for eigenvalue
#  The estimated number of batches is 1554
#       191/1    1.02316    1.01627 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9965363936774296 for eigenvalue
#  The estimated number of batches is 1556
#       192/1    1.01036    1.01624 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0283335094179233 for eigenvalue
#  The estimated number of batches is 1598
#       193/1    1.02083    1.01626 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0157840638633875 for eigenvalue
#  The estimated number of batches is 1594
#       194/1    1.00348    1.01619 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.022553681858396 for eigenvalue
#  The estimated number of batches is 1610
#       195/1    1.01857    1.01620 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.00802108595152 for eigenvalue
#  The estimated number of batches is 1604
#       196/1    1.02191    1.01624 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9941702450548813 for eigenvalue
#  The estimated number of batches is 1598
#       197/1    1.01564    1.01623 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9782732290035794 for eigenvalue
#  The estimated number of batches is 1591
#       198/1    1.01978    1.01625 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9632492030718334 for eigenvalue
#  The estimated number of batches is 1583
#       199/1    1.01119    1.01622 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9448409370262345 for eigenvalue
#  The estimated number of batches is 1573
#       200/1    1.01073    1.01619 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9278682969903653 for eigenvalue
#  The estimated number of batches is 1564
#       201/1    1.01445    1.01618 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9122415242694526 for eigenvalue
#  The estimated number of batches is 1556
#       202/1    1.02241    1.01622 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8992983674502146 for eigenvalue
#  The estimated number of batches is 1550
#       203/1    1.01325    1.01620 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8976200739332127 for eigenvalue
#  The estimated number of batches is 1557
#       204/1    1.01205    1.01618 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.878739981591846 for eigenvalue
#  The estimated number of batches is 1545
#       205/1    1.01037    1.01615 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8943465989233075 for eigenvalue
#  The estimated number of batches is 1570
#       206/1    1.01776    1.01616 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.879279251652508 for eigenvalue
#  The estimated number of batches is 1562
#       207/1    1.03437    1.01625 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8977041351744983 for eigenvalue
#  The estimated number of batches is 1591
#       208/1    1.01804    1.01626 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9009823209019636 for eigenvalue
#  The estimated number of batches is 1603
#       209/1    1.01265    1.01624 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.885940694497542 for eigenvalue
#  The estimated number of batches is 1595
#       210/1    1.01725    1.01625 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8794084834561042 for eigenvalue
#  The estimated number of batches is 1596
#       211/1    1.01029    1.01622 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8673123464462775 for eigenvalue
#  The estimated number of batches is 1591
#       212/1    1.01482    1.01621 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8602760745853026 for eigenvalue
#  The estimated number of batches is 1591
#       213/1    1.02402    1.01625 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.860404250841387 for eigenvalue
#  The estimated number of batches is 1600
#       214/1    1.00985    1.01622 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.865185030573874 for eigenvalue
#  The estimated number of batches is 1613
#       215/1    1.01659    1.01622 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8527368130316986 for eigenvalue
#  The estimated number of batches is 1607
#       216/1    1.02206    1.01625 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8462711493927326 for eigenvalue
#  The estimated number of batches is 1608
#       217/1    1.00941    1.01622 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.838829985266281 for eigenvalue
#  The estimated number of batches is 1608
#       218/1    1.01105    1.01619 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.823789609407237 for eigenvalue
#  The estimated number of batches is 1599
#       219/1    1.01291    1.01617 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8087726184547526 for eigenvalue
#  The estimated number of batches is 1590
#       220/1    1.00828    1.01613 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7974732463102208 for eigenvalue
#  The estimated number of batches is 1586
#       221/1    1.02076    1.01616 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.792546284804769 for eigenvalue
#  The estimated number of batches is 1588
#       222/1    1.01694    1.01616 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7785617273879795 for eigenvalue
#  The estimated number of batches is 1580
#       223/1    1.01078    1.01613 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7638257143151916 for eigenvalue
#  The estimated number of batches is 1571
#       224/1    1.02553    1.01618 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7782345206325965 for eigenvalue
#  The estimated number of batches is 1595
#       225/1    1.02243    1.01621 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7722085157650547 for eigenvalue
#  The estimated number of batches is 1596
#       226/1    1.01961    1.01623 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7663867568382456 for eigenvalue
#  The estimated number of batches is 1597
#       227/1    1.00505    1.01617 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7667968680684227 for eigenvalue
#  The estimated number of batches is 1605
#       228/1    1.01994    1.01619 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7565132464148 for eigenvalue
#  The estimated number of batches is 1601
#       229/1    1.01675    1.01619 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.744005216818886 for eigenvalue
#  The estimated number of batches is 1594
#       230/1    1.01604    1.01619 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7325500892517316 for eigenvalue
#  The estimated number of batches is 1589
#       231/1    1.01229    1.01617 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7302673885237416 for eigenvalue
#  The estimated number of batches is 1593
#       232/1    1.00841    1.01614 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.732581649987749 for eigenvalue
#  The estimated number of batches is 1604
#       233/1    1.02786    1.01619 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.723232169996666 for eigenvalue
#  The estimated number of batches is 1600
#       234/1    1.01492    1.01619 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.711768760296502 for eigenvalue
#  The estimated number of batches is 1594
#       235/1    1.00928    1.01616 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7042382620062546 for eigenvalue
#  The estimated number of batches is 1593
#       236/1    1.01152    1.01613 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6934016147120383 for eigenvalue
#  The estimated number of batches is 1587
#       237/1    1.01668    1.01614 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.683030163804787 for eigenvalue
#  The estimated number of batches is 1583
#       238/1    1.02314    1.01617 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.694790070711917 for eigenvalue
#  The estimated number of batches is 1604
#       239/1    1.01854    1.01618 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.684093342292048 for eigenvalue
#  The estimated number of batches is 1598
#       240/1    1.00934    1.01615 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.680057800134803 for eigenvalue
#  The estimated number of batches is 1601
#       241/1    1.01782    1.01616 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6739524209765824 for eigenvalue
#  The estimated number of batches is 1601
#       242/1    1.02229    1.01618 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6716746197062733 for eigenvalue
#  The estimated number of batches is 1605
#       243/1    1.02011    1.01620 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6696946116975453 for eigenvalue
#  The estimated number of batches is 1610
#       244/1    1.01756    1.01621 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.660379087074649 for eigenvalue
#  The estimated number of batches is 1606
#       245/1    1.02178    1.01623 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.652293123796567 for eigenvalue
#  The estimated number of batches is 1603
#       246/1    1.01154    1.01621 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.639981904841603 for eigenvalue
#  The estimated number of batches is 1596
#       247/1    1.01617    1.01621 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6365166568564864 for eigenvalue
#  The estimated number of batches is 1598
#       248/1    1.02219    1.01624 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6279632652525975 for eigenvalue
#  The estimated number of batches is 1595
#       249/1    1.01763    1.01624 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.616917487173306 for eigenvalue
#  The estimated number of batches is 1589
#       250/1    1.00856    1.01621 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.60525273516892 for eigenvalue
#  The estimated number of batches is 1582
#       251/1    1.02062    1.01623 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5954173370690956 for eigenvalue
#  The estimated number of batches is 1577
#       252/1    1.01918    1.01624 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.585059173641008 for eigenvalue
#  The estimated number of batches is 1571
#       253/1    1.01629    1.01624 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.577776591490094 for eigenvalue
#  The estimated number of batches is 1569
#       254/1    1.02218    1.01627 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.570386915196886 for eigenvalue
#  The estimated number of batches is 1567
#       255/1    1.00908    1.01624 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.558829289990377 for eigenvalue
#  The estimated number of batches is 1559
#       256/1    1.01246    1.01622 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5593463180898466 for eigenvalue
#  The estimated number of batches is 1566
#       257/1    1.01642    1.01622 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.562359893658361 for eigenvalue
#  The estimated number of batches is 1577
#       258/1    1.01359    1.01621 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5639246984987984 for eigenvalue
#  The estimated number of batches is 1585
#       259/1    1.02082    1.01623 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.556155649621834 for eigenvalue
#  The estimated number of batches is 1582
#       260/1    1.02424    1.01626 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5487629026687326 for eigenvalue
#  The estimated number of batches is 1580
#       261/1    1.01271    1.01625 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5375223881533575 for eigenvalue
#  The estimated number of batches is 1572
#       262/1    1.02284    1.01628 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5282389966699417 for eigenvalue
#  The estimated number of batches is 1567
#       263/1    1.01142    1.01626 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5171770372833246 for eigenvalue
#  The estimated number of batches is 1560
#       264/1    1.01237    1.01624 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5123885557271106 for eigenvalue
#  The estimated number of batches is 1561
#       265/1    1.00993    1.01621 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.505127805355499 for eigenvalue
#  The estimated number of batches is 1558
#       266/1    1.01395    1.01620 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5025154519820236 for eigenvalue
#  The estimated number of batches is 1561
#       267/1    1.01244    1.01619 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4928583529347783 for eigenvalue
#  The estimated number of batches is 1555
#       268/1    1.01889    1.01620 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5076048945548686 for eigenvalue
#  The estimated number of batches is 1580
#       269/1    1.02150    1.01622 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5074882952684456 for eigenvalue
#  The estimated number of batches is 1586
#       270/1    1.01406    1.01621 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4978566773309225 for eigenvalue
#  The estimated number of batches is 1580
#       271/1    1.00990    1.01619 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4925055200175947 for eigenvalue
#  The estimated number of batches is 1580
#       272/1    1.01228    1.01617 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.481874057306485 for eigenvalue
#  The estimated number of batches is 1573
#       273/1    1.01421    1.01616 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4784589005482824 for eigenvalue
#  The estimated number of batches is 1575
#       274/1    1.01647    1.01617 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.47170687941485 for eigenvalue
#  The estimated number of batches is 1572
#       275/1    1.00967    1.01614 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.466335805097459 for eigenvalue
#  The estimated number of batches is 1572
#       276/1    1.01326    1.01613 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4568361890369044 for eigenvalue
#  The estimated number of batches is 1566
#       277/1    1.01391    1.01612 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.447077576889243 for eigenvalue
#  The estimated number of batches is 1559
#       278/1    1.01927    1.01613 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4395008753861958 for eigenvalue
#  The estimated number of batches is 1556
#       279/1    1.01406    1.01612 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4303655190326894 for eigenvalue
#  The estimated number of batches is 1550
#       280/1    1.01652    1.01613 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.427528399539716 for eigenvalue
#  The estimated number of batches is 1553
#       281/1    1.01212    1.01611 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.41980047479932 for eigenvalue
#  The estimated number of batches is 1549
#       282/1    1.02398    1.01614 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.430012215350729 for eigenvalue
#  The estimated number of batches is 1568
#       283/1    1.01448    1.01613 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4210907116947884 for eigenvalue
#  The estimated number of batches is 1562
#       284/1    1.01401    1.01613 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4160661891373456 for eigenvalue
#  The estimated number of batches is 1562
#       285/1    1.02057    1.01614 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.408255340993969 for eigenvalue
#  The estimated number of batches is 1557
#       286/1    1.01723    1.01615 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4001079991757277 for eigenvalue
#  The estimated number of batches is 1553
#       287/1    1.02092    1.01617 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.392596297959179 for eigenvalue
#  The estimated number of batches is 1549
#       288/1    1.00989    1.01614 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.397613174942488 for eigenvalue
#  The estimated number of batches is 1561
#       289/1    1.01481    1.01614 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3967731493972595 for eigenvalue
#  The estimated number of batches is 1566
#       290/1    1.01990    1.01615 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3882566904847553 for eigenvalue
#  The estimated number of batches is 1561
#       291/1    1.00858    1.01612 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3808543626040573 for eigenvalue
#  The estimated number of batches is 1557
#       292/1    1.01176    1.01611 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3716103730772384 for eigenvalue
#  The estimated number of batches is 1550
#       293/1    1.01735    1.01611 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3632280383680606 for eigenvalue
#  The estimated number of batches is 1545
#       294/1    1.01478    1.01611 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.354798087778465 for eigenvalue
#  The estimated number of batches is 1540
#       295/1    1.01766    1.01611 +/- 0.00034
# ...
#  Triggers unsatisfied, max unc./thresh. is 1.685885848717349 for eigenvalue
#  The estimated number of batches is 1615
#       582/1    1.01177    1.01591 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.682899020420825 for eigenvalue
#  The estimated number of batches is 1612
#       583/1    1.02219    1.01592 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6818003299133475 for eigenvalue
#  The estimated number of batches is 1613
#       584/1    1.01756    1.01593 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6792022169917997 for eigenvalue
#  The estimated number of batches is 1611
#       585/1    1.01016    1.01592 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.676284863781898 for eigenvalue
#  The estimated number of batches is 1608
#       586/1    1.01528    1.01591 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6733888368142176 for eigenvalue
#  The estimated number of batches is 1605
#       587/1    1.02039    1.01592 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6704838763551277 for eigenvalue
#  The estimated number of batches is 1603
#       588/1    1.01443    1.01592 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6678337144369897 for eigenvalue
#  The estimated number of batches is 1600
#       589/1    1.01101    1.01591 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6663435099096688 for eigenvalue
#  The estimated number of batches is 1600
#       590/1    1.02770    1.01593 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6644582218021267 for eigenvalue
#  The estimated number of batches is 1600
#       591/1    1.02746    1.01595 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6635720625940487 for eigenvalue
#  The estimated number of batches is 1601
#       592/1    1.01361    1.01595 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6606533800475014 for eigenvalue
#  The estimated number of batches is 1598
#       593/1    1.02297    1.01596 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6578569362154818 for eigenvalue
#  The estimated number of batches is 1595
#       594/1    1.02076    1.01597 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.657791465614607 for eigenvalue
#  The estimated number of batches is 1598
#       595/1    1.01394    1.01597 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6556161987961515 for eigenvalue
#  The estimated number of batches is 1597
#       596/1    1.00788    1.01595 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.653990329670997 for eigenvalue
#  The estimated number of batches is 1596
#       597/1    1.01879    1.01596 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6577347282785282 for eigenvalue
#  The estimated number of batches is 1606
#       598/1    1.02323    1.01597 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6553339591584078 for eigenvalue
#  The estimated number of batches is 1604
#       599/1    1.01751    1.01597 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6524514197763356 for eigenvalue
#  The estimated number of batches is 1602
#       600/1    1.02129    1.01598 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.650892840212822 for eigenvalue
#  The estimated number of batches is 1601
#       601/1    1.01021    1.01597 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6535467302328295 for eigenvalue
#  The estimated number of batches is 1609
#       602/1    1.00967    1.01596 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.653603578556962 for eigenvalue
#  The estimated number of batches is 1612
#       603/1    1.00870    1.01595 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.650756683538426 for eigenvalue
#  The estimated number of batches is 1609
#       604/1    1.01622    1.01595 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.648755171631999 for eigenvalue
#  The estimated number of batches is 1608
#       605/1    1.02364    1.01596 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.646200937579361 for eigenvalue
#  The estimated number of batches is 1606
#       606/1    1.01986    1.01597 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6454601909692141 for eigenvalue
#  The estimated number of batches is 1607
#       607/1    1.02115    1.01598 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6427935085394505 for eigenvalue
#  The estimated number of batches is 1605
#       608/1    1.00501    1.01596 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.640314332915474 for eigenvalue
#  The estimated number of batches is 1603
#       609/1    1.00850    1.01595 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6386205163221255 for eigenvalue
#  The estimated number of batches is 1602
#       610/1    1.01193    1.01594 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6366153403012573 for eigenvalue
#  The estimated number of batches is 1601
#       611/1    1.01133    1.01593 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6351913998563383 for eigenvalue
#  The estimated number of batches is 1601
#       612/1    1.01194    1.01592 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6324770273420797 for eigenvalue
#  The estimated number of batches is 1598
#       613/1    1.00094    1.01590 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.629813660388179 for eigenvalue
#  The estimated number of batches is 1596
#       614/1    1.01307    1.01589 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6271001420485303 for eigenvalue
#  The estimated number of batches is 1593
#       615/1    1.01749    1.01590 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6244641273798426 for eigenvalue
#  The estimated number of batches is 1591
#       616/1    1.00930    1.01589 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6218179222869802 for eigenvalue
#  The estimated number of batches is 1588
#       617/1    1.01933    1.01589 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6192042330677183 for eigenvalue
#  The estimated number of batches is 1586
#       618/1    1.02267    1.01590 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6170185863220081 for eigenvalue
#  The estimated number of batches is 1584
#       619/1    1.00824    1.01589 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6153074748435348 for eigenvalue
#  The estimated number of batches is 1583
#       620/1    1.02312    1.01590 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.6127031154557367 for eigenvalue
#  The estimated number of batches is 1581
#       621/1    1.01022    1.01589 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.611887438781592 for eigenvalue
#  The estimated number of batches is 1582
#       622/1    1.01481    1.01589 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6094037520410798 for eigenvalue
#  The estimated number of batches is 1580
#       623/1    1.02226    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6091959028279696 for eigenvalue
#  The estimated number of batches is 1582
#       624/1    1.02036    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6071975276737631 for eigenvalue
#  The estimated number of batches is 1581
#       625/1    1.01764    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6054566491309907 for eigenvalue
#  The estimated number of batches is 1580
#       626/1    1.01699    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6028609696615443 for eigenvalue
#  The estimated number of batches is 1577
#       627/1    1.01898    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6014949114969748 for eigenvalue
#  The estimated number of batches is 1577
#       628/1    1.00989    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6016003411667128 for eigenvalue
#  The estimated number of batches is 1580
#       629/1    1.01231    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5990318898781026 for eigenvalue
#  The estimated number of batches is 1578
#       630/1    1.02480    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5966734543241523 for eigenvalue
#  The estimated number of batches is 1576
#       631/1    0.99875    1.01589 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6031567550148131 for eigenvalue
#  The estimated number of batches is 1591
#       632/1    1.02884    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6059377223972982 for eigenvalue
#  The estimated number of batches is 1599
#       633/1    1.01057    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6058394732644488 for eigenvalue
#  The estimated number of batches is 1601
#       634/1    1.01145    1.01589 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6044791751598793 for eigenvalue
#  The estimated number of batches is 1601
#       635/1    1.01658    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6021482343770013 for eigenvalue
#  The estimated number of batches is 1599
#       636/1    1.01265    1.01589 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.6006725469083065 for eigenvalue
#  The estimated number of batches is 1599
#       637/1    1.02086    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5981204396916402 for eigenvalue
#  The estimated number of batches is 1596
#       638/1    1.01650    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.595988686376328 for eigenvalue
#  The estimated number of batches is 1595
#       639/1    1.02157    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5934815987799134 for eigenvalue
#  The estimated number of batches is 1592
#       640/1    1.02367    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5913272260642464 for eigenvalue
#  The estimated number of batches is 1591
#       641/1    1.01511    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.588895200657843 for eigenvalue
#  The estimated number of batches is 1588
#       642/1    1.01556    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.587017201948048 for eigenvalue
#  The estimated number of batches is 1587
#       643/1    1.01392    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5858307735534423 for eigenvalue
#  The estimated number of batches is 1587
#       644/1    1.01415    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5831896874720373 for eigenvalue
#  The estimated number of batches is 1585
#       645/1    1.01426    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5810255088870844 for eigenvalue
#  The estimated number of batches is 1583
#       646/1    1.01895    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5794000523107 for eigenvalue
#  The estimated number of batches is 1582
#       647/1    1.00377    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5791388114335445 for eigenvalue
#  The estimated number of batches is 1584
#       648/1    1.02195    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5765748214853996 for eigenvalue
#  The estimated number of batches is 1581
#       649/1    1.01012    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.574813601592355 for eigenvalue
#  The estimated number of batches is 1580
#       650/1    1.01085    1.01589 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5722867403760024 for eigenvalue
#  The estimated number of batches is 1578
#       651/1    1.01132    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.572579535241143 for eigenvalue
#  The estimated number of batches is 1581
#       652/1    1.01765    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5703981289991782 for eigenvalue
#  The estimated number of batches is 1579
#       653/1    1.01031    1.01587 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5679293576730857 for eigenvalue
#  The estimated number of batches is 1577
#       654/1    1.01373    1.01587 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5677315308952071 for eigenvalue
#  The estimated number of batches is 1579
#       655/1    1.01874    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5668485771086844 for eigenvalue
#  The estimated number of batches is 1579
#       656/1    1.01245    1.01587 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5643885574389054 for eigenvalue
#  The estimated number of batches is 1577
#       657/1    1.00735    1.01586 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5619912818781212 for eigenvalue
#  The estimated number of batches is 1575
#       658/1    1.02677    1.01587 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5596994459786888 for eigenvalue
#  The estimated number of batches is 1573
#       659/1    1.02178    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.557930879731356 for eigenvalue
#  The estimated number of batches is 1571
#       660/1    1.01636    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.556179292466414 for eigenvalue
#  The estimated number of batches is 1570
#       661/1    1.01403    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5537726742351374 for eigenvalue
#  The estimated number of batches is 1568
#       662/1    1.01016    1.01587 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5520099396839655 for eigenvalue
#  The estimated number of batches is 1567
#       663/1    1.00814    1.01586 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.554829896811766 for eigenvalue
#  The estimated number of batches is 1575
#       664/1    1.02451    1.01587 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5545398470192655 for eigenvalue
#  The estimated number of batches is 1577
#       665/1    1.02018    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5525732224698983 for eigenvalue
#  The estimated number of batches is 1575
#       666/1    1.01552    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5505722007929956 for eigenvalue
#  The estimated number of batches is 1574
#       667/1    1.02151    1.01589 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.54916277813898 for eigenvalue
#  The estimated number of batches is 1573
#       668/1    1.01204    1.01588 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5469189271288954 for eigenvalue
#  The estimated number of batches is 1571
#       669/1    1.02409    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5453619169593038 for eigenvalue
#  The estimated number of batches is 1570
#       670/1    1.01867    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.543629056986412 for eigenvalue
#  The estimated number of batches is 1569
#       671/1    1.02096    1.01591 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5443952247604953 for eigenvalue
#  The estimated number of batches is 1573
#       672/1    1.02094    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5420754492093374 for eigenvalue
#  The estimated number of batches is 1571
#       673/1    1.01615    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5399390430490845 for eigenvalue
#  The estimated number of batches is 1569
#       674/1    1.00895    1.01590 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.539793908906131 for eigenvalue
#  The estimated number of batches is 1571
#       675/1    1.02483    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.538386013986522 for eigenvalue
#  The estimated number of batches is 1571
#       676/1    1.01544    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5376063789931471 for eigenvalue
#  The estimated number of batches is 1571
#       677/1    1.01857    1.01592 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5352873988997715 for eigenvalue
#  The estimated number of batches is 1569
#       678/1    1.01536    1.01592 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5331636395476065 for eigenvalue
#  The estimated number of batches is 1567
