# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=565

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)

water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=565
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=565
helium.set_density('g/cm3', 0.178E-03 )


model.materials = openmc.Materials([uo2, zirconium, water,helium]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
GT=[(5,2),(8,2),(3,3),(2,5),(5,5),(8,5),(2,8),(5,8)]
IT=[(8,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))
# print(np.array(GT_full)+(1,1))

# %% [markdown]
# ### Create family pincell

# %%
pincell_1_family=pincell('pincell')
guide_1_family=guide('guide')
instru_1_family=instru('instru')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly


size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT :
            A[ix][iy]=instru_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]    

# print(A)           
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:44
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.18895
#         2/1    1.18920
#         3/1    1.18465
#         4/1    1.18316
#         5/1    1.17958
#         6/1    1.18229
#         7/1    1.17958
#         8/1    1.18327
#         9/1    1.18181
#        10/1    1.18381
#        11/1    1.18228
#        12/1    1.17984
#        13/1    1.18332
#        14/1    1.18264
#        15/1    1.19244
#        16/1    1.18015
#        17/1    1.18325
#        18/1    1.18596
#        19/1    1.17958
#        20/1    1.18979
#        21/1    1.19110
#        22/1    1.17533    1.18322 +/- 0.00789
#        23/1    1.19493    1.18712 +/- 0.00600
#        24/1    1.19861    1.19000 +/- 0.00512
#        25/1    1.18802    1.18960 +/- 0.00399
#        26/1    1.18442    1.18874 +/- 0.00337
#        27/1    1.18461    1.18815 +/- 0.00291
#        28/1    1.16646    1.18544 +/- 0.00370
#        29/1    1.17737    1.18454 +/- 0.00338
#        30/1    1.18185    1.18427 +/- 0.00304
#        31/1    1.19515    1.18526 +/- 0.00292
#        32/1    1.18798    1.18549 +/- 0.00268
#        33/1    1.17595    1.18475 +/- 0.00257
#        34/1    1.18805    1.18499 +/- 0.00239
#        35/1    1.18581    1.18504 +/- 0.00223
#        36/1    1.17996    1.18473 +/- 0.00211
#        37/1    1.19202    1.18516 +/- 0.00202
#        38/1    1.18241    1.18500 +/- 0.00191
#        39/1    1.18043    1.18476 +/- 0.00183
#        40/1    1.17313    1.18418 +/- 0.00183
#        41/1    1.19408    1.18465 +/- 0.00180
#        42/1    1.17770    1.18434 +/- 0.00175
#        43/1    1.18018    1.18415 +/- 0.00168
#        44/1    1.18658    1.18426 +/- 0.00161
#        45/1    1.17111    1.18373 +/- 0.00163
#        46/1    1.18151    1.18364 +/- 0.00157
#        47/1    1.19297    1.18399 +/- 0.00155
#        48/1    1.17405    1.18363 +/- 0.00153
#        49/1    1.18428    1.18366 +/- 0.00148
#        50/1    1.17751    1.18345 +/- 0.00145
#  Triggers unsatisfied, max unc./thresh. is 8.257652029036826 for eigenvalue
#  The estimated number of batches is 2066
#  Creating state point statepoint.00050.h5...
#        51/1    1.18627    1.18354 +/- 0.00140
#  Triggers unsatisfied, max unc./thresh. is 7.990175453726834 for eigenvalue
#  The estimated number of batches is 2000
#        52/1    1.17672    1.18333 +/- 0.00137
#  Triggers unsatisfied, max unc./thresh. is 7.647462230650833 for eigenvalue
#  The estimated number of batches is 1892
#        53/1    1.18365    1.18334 +/- 0.00133
#  Triggers unsatisfied, max unc./thresh. is 7.740358370752513 for eigenvalue
#  The estimated number of batches is 1998
#        54/1    1.18489    1.18339 +/- 0.00129
#  Triggers unsatisfied, max unc./thresh. is 7.4387443229011625 for eigenvalue
#  The estimated number of batches is 1902
#        55/1    1.19468    1.18371 +/- 0.00130
#  Triggers unsatisfied, max unc./thresh. is 7.270755612875704 for eigenvalue
#  The estimated number of batches is 1871
#        56/1    1.17591    1.18349 +/- 0.00128
#  Triggers unsatisfied, max unc./thresh. is 7.205311160551839 for eigenvalue
#  The estimated number of batches is 1889
#        57/1    1.17514    1.18327 +/- 0.00126
#  Triggers unsatisfied, max unc./thresh. is 7.4758388920576175 for eigenvalue
#  The estimated number of batches is 2088
#        58/1    1.17569    1.18307 +/- 0.00125
#  Triggers unsatisfied, max unc./thresh. is 7.309227542722969 for eigenvalue
#  The estimated number of batches is 2051
#        59/1    1.18921    1.18322 +/- 0.00122
#  Triggers unsatisfied, max unc./thresh. is 7.344138450010314 for eigenvalue
#  The estimated number of batches is 2124
#        60/1    1.18836    1.18335 +/- 0.00120
#  Triggers unsatisfied, max unc./thresh. is 7.372858581633359 for eigenvalue
#  The estimated number of batches is 2195
#        61/1    1.18438    1.18338 +/- 0.00117
#  Triggers unsatisfied, max unc./thresh. is 7.28509778072338 for eigenvalue
#  The estimated number of batches is 2196
#        62/1    1.17486    1.18317 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 7.14305999795016 for eigenvalue
#  The estimated number of batches is 2163
#        63/1    1.18729    1.18327 +/- 0.00114
#  Triggers unsatisfied, max unc./thresh. is 6.979774978205505 for eigenvalue
#  The estimated number of batches is 2115
#        64/1    1.17903    1.18317 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 6.791726999648518 for eigenvalue
#  The estimated number of batches is 2050
#        65/1    1.17695    1.18304 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 6.670727724031093 for eigenvalue
#  The estimated number of batches is 2023
#        66/1    1.18777    1.18314 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 6.550659863535198 for eigenvalue
#  The estimated number of batches is 1994
#        67/1    1.18239    1.18312 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 6.591351873795421 for eigenvalue
#  The estimated number of batches is 2062
#        68/1    1.18411    1.18314 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.411145342580431 for eigenvalue
#  The estimated number of batches is 1993
#        69/1    1.18398    1.18316 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.254688382937777 for eigenvalue
#  The estimated number of batches is 1937
#        70/1    1.17289    1.18295 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.4719628289578655 for eigenvalue
#  The estimated number of batches is 2115
#        71/1    1.18380    1.18297 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 6.357656043009432 for eigenvalue
#  The estimated number of batches is 2082
#        72/1    1.19020    1.18311 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 6.258438711818335 for eigenvalue
#  The estimated number of batches is 2057
#        73/1    1.18498    1.18315 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.168760716962916 for eigenvalue
#  The estimated number of batches is 2037
#        74/1    1.17293    1.18296 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.129763658845603 for eigenvalue
#  The estimated number of batches is 2049
#        75/1    1.17718    1.18285 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.047327074450915 for eigenvalue
#  The estimated number of batches is 2032
#        76/1    1.18351    1.18286 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.958947466714831 for eigenvalue
#  The estimated number of batches is 2009
#        77/1    1.18956    1.18298 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.8628259137894645 for eigenvalue
#  The estimated number of batches is 1980
#        78/1    1.17712    1.18288 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.729723425493937 for eigenvalue
#  The estimated number of batches is 1925
#        79/1    1.18171    1.18286 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.679110679260633 for eigenvalue
#  The estimated number of batches is 1923
#        80/1    1.18234    1.18285 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 5.603565240078471 for eigenvalue
#  The estimated number of batches is 1904
#        81/1    1.17785    1.18277 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.552102053860473 for eigenvalue
#  The estimated number of batches is 1901
#        82/1    1.18544    1.18281 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.608408570139359 for eigenvalue
#  The estimated number of batches is 1971
#        83/1    1.19469    1.18300 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.526815960100699 for eigenvalue
#  The estimated number of batches is 1945
#        84/1    1.18305    1.18300 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.4274034272423695 for eigenvalue
#  The estimated number of batches is 1906
#        85/1    1.18408    1.18302 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.445116233349107 for eigenvalue
#  The estimated number of batches is 1948
#        86/1    1.19060    1.18313 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.370345551455668 for eigenvalue
#  The estimated number of batches is 1924
#        87/1    1.18633    1.18318 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.28025133451053 for eigenvalue
#  The estimated number of batches is 1889
#        88/1    1.17855    1.18311 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.206119984091295 for eigenvalue
#  The estimated number of batches is 1864
#        89/1    1.18901    1.18320 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.139744238061694 for eigenvalue
#  The estimated number of batches is 1843
#        90/1    1.19523    1.18337 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.256158335426077 for eigenvalue
#  The estimated number of batches is 1954
#        91/1    1.17266    1.18322 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.2482069593932055 for eigenvalue
#  The estimated number of batches is 1976
#        92/1    1.18151    1.18320 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.217723641358647 for eigenvalue
#  The estimated number of batches is 1981
#        93/1    1.18431    1.18321 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.150446668863241 for eigenvalue
#  The estimated number of batches is 1957
#        94/1    1.18725    1.18327 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.158787071923233 for eigenvalue
#  The estimated number of batches is 1990
#        95/1    1.17313    1.18313 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.142639253982611 for eigenvalue
#  The estimated number of batches is 2004
#        96/1    1.18860    1.18320 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.118089734831345 for eigenvalue
#  The estimated number of batches is 2011
#        97/1    1.18653    1.18325 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.066280703488465 for eigenvalue
#  The estimated number of batches is 1997
#        98/1    1.18821    1.18331 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.994292200860151 for eigenvalue
#  The estimated number of batches is 1966
#        99/1    1.18588    1.18334 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.966052302869204 for eigenvalue
#  The estimated number of batches is 1969
#       100/1    1.17872    1.18328 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.905836523361799 for eigenvalue
#  The estimated number of batches is 1946
#       101/1    1.18621    1.18332 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.863847854213243 for eigenvalue
#  The estimated number of batches is 1937
#       102/1    1.18369    1.18332 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.812500779943305 for eigenvalue
#  The estimated number of batches is 1920
#       103/1    1.18605    1.18336 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.759899386769652 for eigenvalue
#  The estimated number of batches is 1901
#       104/1    1.18494    1.18338 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.711211390427357 for eigenvalue
#  The estimated number of batches is 1885
#       105/1    1.17916    1.18333 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.663894895995267 for eigenvalue
#  The estimated number of batches is 1869
#       106/1    1.18787    1.18338 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.617279553002227 for eigenvalue
#  The estimated number of batches is 1854
#       107/1    1.19233    1.18348 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.576888786644788 for eigenvalue
#  The estimated number of batches is 1843
#       108/1    1.17812    1.18342 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.518250561012211 for eigenvalue
#  The estimated number of batches is 1817
#       109/1    1.18559    1.18345 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.467443451044087 for eigenvalue
#  The estimated number of batches is 1797
#       110/1    1.18822    1.18350 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.4415718044467125 for eigenvalue
#  The estimated number of batches is 1796
#       111/1    1.18604    1.18353 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.408796477493923 for eigenvalue
#  The estimated number of batches is 1789
#       112/1    1.18600    1.18355 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.378934867712496 for eigenvalue
#  The estimated number of batches is 1785
#       113/1    1.18523    1.18357 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.334854665039556 for eigenvalue
#  The estimated number of batches is 1768
#       114/1    1.17939    1.18353 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.29188827445638 for eigenvalue
#  The estimated number of batches is 1752
#       115/1    1.19200    1.18362 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.259829590953582 for eigenvalue
#  The estimated number of batches is 1744
#       116/1    1.18698    1.18365 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.279226202930845 for eigenvalue
#  The estimated number of batches is 1778
#       117/1    1.18923    1.18371 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.271565022107078 for eigenvalue
#  The estimated number of batches is 1790
#       118/1    1.17213    1.18359 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.264796192951828 for eigenvalue
#  The estimated number of batches is 1803
#       119/1    1.18423    1.18360 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.236982803966696 for eigenvalue
#  The estimated number of batches is 1798
#       120/1    1.17927    1.18355 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.193812286247033 for eigenvalue
#  The estimated number of batches is 1779
#       121/1    1.18802    1.18360 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.156297756295272 for eigenvalue
#  The estimated number of batches is 1765
#       122/1    1.18272    1.18359 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.114305190834522 for eigenvalue
#  The estimated number of batches is 1747
#       123/1    1.19169    1.18367 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.1171421563275565 for eigenvalue
#  The estimated number of batches is 1766
#       124/1    1.18186    1.18365 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.076105200743508 for eigenvalue
#  The estimated number of batches is 1748
#       125/1    1.17809    1.18360 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.027672791782449 for eigenvalue
#  The estimated number of batches is 1724
#       126/1    1.19340    1.18369 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.011520791564722 for eigenvalue
#  The estimated number of batches is 1726
#       127/1    1.18081    1.18366 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.9885891072852564 for eigenvalue
#  The estimated number of batches is 1723
#       128/1    1.18359    1.18366 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.9708052198343964 for eigenvalue
#  The estimated number of batches is 1723
#       129/1    1.18166    1.18364 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.935793815545113 for eigenvalue
#  The estimated number of batches is 1709
#       130/1    1.17922    1.18360 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.8942105476219684 for eigenvalue
#  The estimated number of batches is 1689
#       131/1    1.18698    1.18363 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.861840223009407 for eigenvalue
#  The estimated number of batches is 1676
#       132/1    1.18859    1.18368 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.837600696331356 for eigenvalue
#  The estimated number of batches is 1670
#       133/1    1.19329    1.18376 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.8252210089120844 for eigenvalue
#  The estimated number of batches is 1674
#       134/1    1.18508    1.18378 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.79089340192134 for eigenvalue
#  The estimated number of batches is 1659
#       135/1    1.18124    1.18375 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7662381641661136 for eigenvalue
#  The estimated number of batches is 1652
#       136/1    1.18521    1.18377 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.737860320040533 for eigenvalue
#  The estimated number of batches is 1641
#       137/1    1.17645    1.18370 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7022206683041774 for eigenvalue
#  The estimated number of batches is 1624
#       138/1    1.17868    1.18366 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.679358457103527 for eigenvalue
#  The estimated number of batches is 1618
#       139/1    1.18203    1.18365 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.657637012542244 for eigenvalue
#  The estimated number of batches is 1613
#       140/1    1.19043    1.18370 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.652712644081649 for eigenvalue
#  The estimated number of batches is 1622
#       141/1    1.17992    1.18367 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.620052013934153 for eigenvalue
#  The estimated number of batches is 1606
#       142/1    1.17653    1.18361 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.581575307931075 for eigenvalue
#  The estimated number of batches is 1585
#       143/1    1.17827    1.18357 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.545672908298815 for eigenvalue
#  The estimated number of batches is 1567
#       144/1    1.17553    1.18351 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5184387185995187 for eigenvalue
#  The estimated number of batches is 1556
#       145/1    1.18037    1.18348 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.4888645742270037 for eigenvalue
#  The estimated number of batches is 1542
#       146/1    1.18912    1.18353 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5156140892736123 for eigenvalue
#  The estimated number of batches is 1578
#       147/1    1.17967    1.18350 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.4830932342663226 for eigenvalue
#  The estimated number of batches is 1561
#       148/1    1.18049    1.18347 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.467116003786587 for eigenvalue
#  The estimated number of batches is 1559
#       149/1    1.18518    1.18348 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.449314840477159 for eigenvalue
#  The estimated number of batches is 1555
#       150/1    1.18305    1.18348 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4254924918482845 for eigenvalue
#  The estimated number of batches is 1546
#       151/1    1.18566    1.18350 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.403045524597656 for eigenvalue
#  The estimated number of batches is 1538
#       152/1    1.18731    1.18353 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.394939749244988 for eigenvalue
#  The estimated number of batches is 1542
#       153/1    1.18340    1.18353 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.380724644366285 for eigenvalue
#  The estimated number of batches is 1541
#       154/1    1.17281    1.18345 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.360753232659161 for eigenvalue
#  The estimated number of batches is 1534
#       155/1    1.17669    1.18340 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3297450219191194 for eigenvalue
#  The estimated number of batches is 1517
#       156/1    1.18236    1.18339 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3334687569595 for eigenvalue
#  The estimated number of batches is 1532
#       157/1    1.18651    1.18341 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.309556862128005 for eigenvalue
#  The estimated number of batches is 1521
#       158/1    1.18631    1.18343 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.301845484499582 for eigenvalue
#  The estimated number of batches is 1525
#       159/1    1.17870    1.18340 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2891970455390593 for eigenvalue
#  The estimated number of batches is 1524
#       160/1    1.18829    1.18343 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2687764673750674 for eigenvalue
#  The estimated number of batches is 1516
#       161/1    1.18656    1.18346 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2483229085816516 for eigenvalue
#  The estimated number of batches is 1508
#       162/1    1.17917    1.18343 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.242419531005401 for eigenvalue
#  The estimated number of batches is 1513
#       163/1    1.18241    1.18342 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2208777142324965 for eigenvalue
#  The estimated number of batches is 1504
#       164/1    1.17824    1.18338 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2183747835408054 for eigenvalue
#  The estimated number of batches is 1512
#       165/1    1.18804    1.18341 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.210673454064135 for eigenvalue
#  The estimated number of batches is 1515
#       166/1    1.18329    1.18341 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.189017485767797 for eigenvalue
#  The estimated number of batches is 1505
#       167/1    1.17452    1.18335 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.217747937958596 for eigenvalue
#  The estimated number of batches is 1543
#       168/1    1.18186    1.18334 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1997632653021943 for eigenvalue
#  The estimated number of batches is 1536
#       169/1    1.17651    1.18330 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2360661542055214 for eigenvalue
#  The estimated number of batches is 1581
#       170/1    1.17714    1.18326 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2088548473352865 for eigenvalue
#  The estimated number of batches is 1565
#       171/1    1.18587    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.189858587201666 for eigenvalue
#  The estimated number of batches is 1557
#       172/1    1.18306    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1707238798649704 for eigenvalue
#  The estimated number of batches is 1549
#       173/1    1.18334    1.18327 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.162009092682797 for eigenvalue
#  The estimated number of batches is 1550
#       174/1    1.18930    1.18331 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.175034319822495 for eigenvalue
#  The estimated number of batches is 1573
#       175/1    1.17486    1.18326 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.179190686268001 for eigenvalue
#  The estimated number of batches is 1587
#       176/1    1.17622    1.18321 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1606347609275867 for eigenvalue
#  The estimated number of batches is 1579
#       177/1    1.18838    1.18324 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1439475496426814 for eigenvalue
#  The estimated number of batches is 1572
#       178/1    1.17538    1.18319 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.126333190533504 for eigenvalue
#  The estimated number of batches is 1565
#       179/1    1.17341    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0995572054436966 for eigenvalue
#  The estimated number of batches is 1548
#       180/1    1.18191    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.079137178401335 for eigenvalue
#  The estimated number of batches is 1537
#       181/1    1.19198    1.18318 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0754092209384747 for eigenvalue
#  The estimated number of batches is 1543
#       182/1    1.17599    1.18314 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.055219682108808 for eigenvalue
#  The estimated number of batches is 1533
#       183/1    1.18267    1.18313 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.036050086939244 for eigenvalue
#  The estimated number of batches is 1523
#       184/1    1.18895    1.18317 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.050782095412918 for eigenvalue
#  The estimated number of batches is 1547
#       185/1    1.18434    1.18318 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.034528563466101 for eigenvalue
#  The estimated number of batches is 1540
#       186/1    1.18829    1.18321 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0228331613449724 for eigenvalue
#  The estimated number of batches is 1537
#       187/1    1.18484    1.18322 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.003925517248634 for eigenvalue
#  The estimated number of batches is 1527
#       188/1    1.17975    1.18320 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9942428883732424 for eigenvalue
#  The estimated number of batches is 1527
#       189/1    1.18035    1.18318 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9861742967091347 for eigenvalue
#  The estimated number of batches is 1528
#       190/1    1.17871    1.18315 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.972526744070615 for eigenvalue
#  The estimated number of batches is 1523
#       191/1    1.18348    1.18315 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9605905736491698 for eigenvalue
#  The estimated number of batches is 1519
#       192/1    1.18133    1.18314 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.958516868073167 for eigenvalue
#  The estimated number of batches is 1526
#       193/1    1.17409    1.18309 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9525010032174435 for eigenvalue
#  The estimated number of batches is 1529
#       194/1    1.17701    1.18306 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.943858799165848 for eigenvalue
#  The estimated number of batches is 1528
#       195/1    1.17170    1.18299 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.922968079948607 for eigenvalue
#  The estimated number of batches is 1516
#       196/1    1.18143    1.18298 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.926871030609812 for eigenvalue
#  The estimated number of batches is 1528
#       197/1    1.18983    1.18302 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.913683466573561 for eigenvalue
#  The estimated number of batches is 1523
#       198/1    1.17061    1.18295 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8933871483558486 for eigenvalue
#  The estimated number of batches is 1511
#       199/1    1.18308    1.18295 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8863466848118646 for eigenvalue
#  The estimated number of batches is 1512
#       200/1    1.17964    1.18293 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.86786925136488 for eigenvalue
#  The estimated number of batches is 1501
#       201/1    1.17850    1.18291 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.860161242523703 for eigenvalue
#  The estimated number of batches is 1501
#       202/1    1.18662    1.18293 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.845039921817067 for eigenvalue
#  The estimated number of batches is 1494
#       203/1    1.17619    1.18289 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8378334999206785 for eigenvalue
#  The estimated number of batches is 1494
#       204/1    1.17673    1.18286 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.820785932171635 for eigenvalue
#  The estimated number of batches is 1485
#       205/1    1.18568    1.18288 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.828905313328881 for eigenvalue
#  The estimated number of batches is 1501
#       206/1    1.18551    1.18289 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.829846180549594 for eigenvalue
#  The estimated number of batches is 1510
#       207/1    1.18473    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8136926176904713 for eigenvalue
#  The estimated number of batches is 1501
#       208/1    1.18283    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.800099012347722 for eigenvalue
#  The estimated number of batches is 1495
#       209/1    1.18388    1.18290 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.800153729471686 for eigenvalue
#  The estimated number of batches is 1502
#       210/1    1.17962    1.18289 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.789052642891223 for eigenvalue
#  The estimated number of batches is 1498
#       211/1    1.17581    1.18285 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.772858702516877 for eigenvalue
#  The estimated number of batches is 1489
#       212/1    1.18353    1.18285 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7607342644015893 for eigenvalue
#  The estimated number of batches is 1484
#       213/1    1.17621    1.18282 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7726383522079954 for eigenvalue
#  The estimated number of batches is 1504
#       214/1    1.17808    1.18279 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.756233867298505 for eigenvalue
#  The estimated number of batches is 1494
#       215/1    1.17687    1.18276 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7460947946969987 for eigenvalue
#  The estimated number of batches is 1491
#       216/1    1.17674    1.18273 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7736858347875333 for eigenvalue
#  The estimated number of batches is 1528
#       217/1    1.18010    1.18272 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7627134366121453 for eigenvalue
#  The estimated number of batches is 1524
#       218/1    1.17819    1.18270 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.752264139450234 for eigenvalue
#  The estimated number of batches is 1520
#       219/1    1.17463    1.18266 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.754390087994861 for eigenvalue
#  The estimated number of batches is 1530
#       220/1    1.19196    1.18270 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.742633717000248 for eigenvalue
#  The estimated number of batches is 1525
#       221/1    1.19281    1.18275 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.745549150897603 for eigenvalue
#  The estimated number of batches is 1536
#       222/1    1.18753    1.18278 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7343474821293747 for eigenvalue
#  The estimated number of batches is 1531
#       223/1    1.18852    1.18281 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7258606430588994 for eigenvalue
#  The estimated number of batches is 1529
#       224/1    1.18579    1.18282 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.716746189206445 for eigenvalue
#  The estimated number of batches is 1526
#       225/1    1.18541    1.18283 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7037027788821826 for eigenvalue
#  The estimated number of batches is 1519
#       226/1    1.18070    1.18282 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7126996065220634 for eigenvalue
#  The estimated number of batches is 1536
#       227/1    1.18267    1.18282 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7071605216053145 for eigenvalue
#  The estimated number of batches is 1538
#       228/1    1.18011    1.18281 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.693085731190312 for eigenvalue
#  The estimated number of batches is 1529
#       229/1    1.18322    1.18281 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6811988810268046 for eigenvalue
#  The estimated number of batches is 1523
#       230/1    1.19363    1.18286 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7053246066797123 for eigenvalue
#  The estimated number of batches is 1557
#       231/1    1.18121    1.18285 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.694031108080945 for eigenvalue
#  The estimated number of batches is 1552
#       232/1    1.18775    1.18288 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.68207482697074 for eigenvalue
#  The estimated number of batches is 1546
#       233/1    1.18684    1.18290 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6717415762274435 for eigenvalue
#  The estimated number of batches is 1541
#       234/1    1.17905    1.18288 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6615060670822217 for eigenvalue
#  The estimated number of batches is 1536
#       235/1    1.18108    1.18287 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6647694128656614 for eigenvalue
#  The estimated number of batches is 1547
#       236/1    1.18452    1.18288 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.658144991491247 for eigenvalue
#  The estimated number of batches is 1547
#       237/1    1.18650    1.18289 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.65551758018642 for eigenvalue
#  The estimated number of batches is 1551
#       238/1    1.18315    1.18289 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6430726864014806 for eigenvalue
#  The estimated number of batches is 1543
#       239/1    1.18890    1.18292 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.633622790231565 for eigenvalue
#  The estimated number of batches is 1539
#       240/1    1.18425    1.18293 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6216077275487075 for eigenvalue
#  The estimated number of batches is 1533
#       241/1    1.19549    1.18299 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.619429412620375 for eigenvalue
#  The estimated number of batches is 1537
#       242/1    1.18398    1.18299 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.607709493679548 for eigenvalue
#  The estimated number of batches is 1530
#       243/1    1.18454    1.18300 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6092799941429425 for eigenvalue
#  The estimated number of batches is 1539
#       244/1    1.18998    1.18303 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6003601934943177 for eigenvalue
#  The estimated number of batches is 1535
#       245/1    1.18166    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6039597519561384 for eigenvalue
#  The estimated number of batches is 1546
#       246/1    1.18343    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5942457306825024 for eigenvalue
#  The estimated number of batches is 1542
#       247/1    1.18557    1.18303 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6003067005514744 for eigenvalue
#  The estimated number of batches is 1555
#       248/1    1.18102    1.18303 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5878163831474956 for eigenvalue
#  The estimated number of batches is 1547
#       249/1    1.19202    1.18307 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.607536856025772 for eigenvalue
#  The estimated number of batches is 1578
#       250/1    1.19006    1.18310 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6006044539062523 for eigenvalue
#  The estimated number of batches is 1576
#       251/1    1.18884    1.18312 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.592410061994594 for eigenvalue
#  The estimated number of batches is 1573
#       252/1    1.18000    1.18311 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5851912174489455 for eigenvalue
#  The estimated number of batches is 1571
#       253/1    1.17462    1.18307 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.575287386350693 for eigenvalue
#  The estimated number of batches is 1566
#       254/1    1.17516    1.18304 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5659526985703933 for eigenvalue
#  The estimated number of batches is 1561
#       255/1    1.17554    1.18300 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.553132196935622 for eigenvalue
#  The estimated number of batches is 1552
#       256/1    1.17206    1.18296 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5570451797475435 for eigenvalue
#  The estimated number of batches is 1564
#       257/1    1.17772    1.18294 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5513590316069337 for eigenvalue
#  The estimated number of batches is 1563
#       258/1    1.19026    1.18297 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5473657236999396 for eigenvalue
#  The estimated number of batches is 1565
#       259/1    1.19052    1.18300 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.537730017081447 for eigenvalue
#  The estimated number of batches is 1560
#       260/1    1.18846    1.18302 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5379050590143595 for eigenvalue
#  The estimated number of batches is 1566
#       261/1    1.18333    1.18302 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.539232494360026 for eigenvalue
#  The estimated number of batches is 1574
#       262/1    1.17690    1.18300 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.52700717792481 for eigenvalue
#  The estimated number of batches is 1566
#       263/1    1.17997    1.18299 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5140119705709574 for eigenvalue
#  The estimated number of batches is 1556
#       264/1    1.18205    1.18298 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5019796174411657 for eigenvalue
#  The estimated number of batches is 1548
#       265/1    1.18660    1.18300 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4919211053483097 for eigenvalue
#  The estimated number of batches is 1542
#       266/1    1.17496    1.18296 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4812398386096213 for eigenvalue
#  The estimated number of batches is 1535
#       267/1    1.17081    1.18291 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.469712021821714 for eigenvalue
#  The estimated number of batches is 1527
#       268/1    1.17010    1.18286 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.45713631812584 for eigenvalue
#  The estimated number of batches is 1518
#       269/1    1.18221    1.18286 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4591667346291572 for eigenvalue
#  The estimated number of batches is 1526
#       270/1    1.17797    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.470354459815854 for eigenvalue
#  The estimated number of batches is 1546
#       271/1    1.18265    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.46539436688439 for eigenvalue
#  The estimated number of batches is 1546
#       272/1    1.18230    1.18284 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4559588080034 for eigenvalue
#  The estimated number of batches is 1540
#       273/1    1.19090    1.18287 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.446858958004406 for eigenvalue
#  The estimated number of batches is 1535
#       274/1    1.18451    1.18288 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4416118779708387 for eigenvalue
#  The estimated number of batches is 1535
#       275/1    1.17708    1.18285 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4314202824696243 for eigenvalue
#  The estimated number of batches is 1528
#       276/1    1.18797    1.18287 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4363522289738606 for eigenvalue
#  The estimated number of batches is 1540
#       277/1    1.17963    1.18286 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4297661473013807 for eigenvalue
#  The estimated number of batches is 1538
#       278/1    1.18071    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4205451988471998 for eigenvalue
#  The estimated number of batches is 1532
#       279/1    1.18173    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.415713999957537 for eigenvalue
#  The estimated number of batches is 1532
#       280/1    1.18359    1.18285 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4064237495049356 for eigenvalue
#  The estimated number of batches is 1526
#       281/1    1.17434    1.18282 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4053470816022497 for eigenvalue
#  The estimated number of batches is 1531
#       282/1    1.18184    1.18281 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.396825153636452 for eigenvalue
#  The estimated number of batches is 1526
#       283/1    1.18875    1.18284 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3888556436036743 for eigenvalue
#  The estimated number of batches is 1521
#       284/1    1.17109    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3816080136210487 for eigenvalue
#  The estimated number of batches is 1518
#       285/1    1.19050    1.18282 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.376654496891716 for eigenvalue
#  The estimated number of batches is 1517
#       286/1    1.17464    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3729741977004486 for eigenvalue
#  The estimated number of batches is 1518
#       287/1    1.18520    1.18280 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3652001691688227 for eigenvalue
#  The estimated number of batches is 1514
#       288/1    1.18146    1.18279 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3573096025617124 for eigenvalue
#  The estimated number of batches is 1510
#       289/1    1.18596    1.18281 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3502111180441756 for eigenvalue
#  The estimated number of batches is 1506
#       290/1    1.17985    1.18280 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.341291340598589 for eigenvalue
#  The estimated number of batches is 1501
#       291/1    1.17764    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.332905477351986 for eigenvalue
#  The estimated number of batches is 1495
#       292/1    1.18585    1.18279 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.32445364023456 for eigenvalue
#  The estimated number of batches is 1490
#       293/1    1.17713    1.18277 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.320409833331491 for eigenvalue
#  The estimated number of batches is 1490
#       294/1    1.18757    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.331300443491413 for eigenvalue
#  The estimated number of batches is 1510
#       295/1    1.17669    1.18276 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.348893244141658 for eigenvalue
#  The estimated number of batches is 1538
#       296/1    1.18925    1.18279 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3411513991624155 for eigenvalue
#  The estimated number of batches is 1533
#       297/1    1.18048    1.18278 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3325774361208285 for eigenvalue
#  The estimated number of batches is 1528
#       298/1    1.17242    1.18274 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.327326314469404 for eigenvalue
#  The estimated number of batches is 1526
#       299/1    1.18100    1.18273 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3320160769922387 for eigenvalue
#  The estimated number of batches is 1538
#       300/1    1.18851    1.18275 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.326715608373008 for eigenvalue
# ...
#  The estimated number of batches is 1546
#       691/1    1.18241    1.18275 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5079626691903782 for eigenvalue
#  The estimated number of batches is 1546
#       692/1    1.17954    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.506366606323802 for eigenvalue
#  The estimated number of batches is 1545
#       693/1    1.18592    1.18275 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5058360557999986 for eigenvalue
#  The estimated number of batches is 1547
#       694/1    1.17842    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5037623289015027 for eigenvalue
#  The estimated number of batches is 1545
#       695/1    1.18402    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5015742810717367 for eigenvalue
#  The estimated number of batches is 1542
#       696/1    1.16725    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5048423735544787 for eigenvalue
#  The estimated number of batches is 1551
#       697/1    1.18391    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5042628794395554 for eigenvalue
#  The estimated number of batches is 1552
#       698/1    1.17799    1.18271 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.50297854360133 for eigenvalue
#  The estimated number of batches is 1552
#       699/1    1.18908    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5028989238484551 for eigenvalue
#  The estimated number of batches is 1554
#       700/1    1.18385    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5009901310710034 for eigenvalue
#  The estimated number of batches is 1553
#       701/1    1.17740    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5021251534181101 for eigenvalue
#  The estimated number of batches is 1557
#       702/1    1.17367    1.18270 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.500631191765479 for eigenvalue
#  The estimated number of batches is 1556
#       703/1    1.18038    1.18270 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4983779239626982 for eigenvalue
#  The estimated number of batches is 1554
#       704/1    1.17308    1.18269 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5027368834130579 for eigenvalue
#  The estimated number of batches is 1565
#       705/1    1.18647    1.18269 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.5010161334782044 for eigenvalue
#  The estimated number of batches is 1564
#       706/1    1.18637    1.18270 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4993228513054908 for eigenvalue
#  The estimated number of batches is 1563
#       707/1    1.18494    1.18270 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.497344209214548 for eigenvalue
#  The estimated number of batches is 1561
#       708/1    1.18150    1.18270 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4955371631703978 for eigenvalue
#  The estimated number of batches is 1559
#       709/1    1.17246    1.18268 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.495069282205807 for eigenvalue
#  The estimated number of batches is 1561
#       710/1    1.19090    1.18269 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4934854518699827 for eigenvalue
#  The estimated number of batches is 1560
#       711/1    1.18577    1.18270 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4928171029060278 for eigenvalue
#  The estimated number of batches is 1560
#       712/1    1.18724    1.18271 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4934152045677258 for eigenvalue
#  The estimated number of batches is 1564
#       713/1    1.19129    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4924923655151494 for eigenvalue
#  The estimated number of batches is 1564
#       714/1    1.18793    1.18273 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4904667703184906 for eigenvalue
#  The estimated number of batches is 1562
#       715/1    1.19029    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4885113659579834 for eigenvalue
#  The estimated number of batches is 1560
#       716/1    1.18383    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4867450933963475 for eigenvalue
#  The estimated number of batches is 1559
#       717/1    1.18753    1.18275 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4851503767321208 for eigenvalue
#  The estimated number of batches is 1558
#       718/1    1.18438    1.18275 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4844704453037947 for eigenvalue
#  The estimated number of batches is 1559
#       719/1    1.17903    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4822697030976917 for eigenvalue
#  The estimated number of batches is 1556
#       720/1    1.17618    1.18273 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4802756441131641 for eigenvalue
#  The estimated number of batches is 1554
#       721/1    1.16969    1.18271 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4779423203888518 for eigenvalue
#  The estimated number of batches is 1552
#       722/1    1.18561    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4771975850852639 for eigenvalue
#  The estimated number of batches is 1552
#       723/1    1.18574    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.47520022753484 for eigenvalue
#  The estimated number of batches is 1550
#       724/1    1.19468    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.474650899254043 for eigenvalue
#  The estimated number of batches is 1551
#       725/1    1.17907    1.18273 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.472469008126688 for eigenvalue
#  The estimated number of batches is 1549
#       726/1    1.18936    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4738722386547816 for eigenvalue
#  The estimated number of batches is 1554
#       727/1    1.18151    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4717561191591828 for eigenvalue
#  The estimated number of batches is 1552
#       728/1    1.18407    1.18274 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4710788820787817 for eigenvalue
#  The estimated number of batches is 1553
#       729/1    1.18663    1.18275 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4691428342401773 for eigenvalue
#  The estimated number of batches is 1551
#       730/1    1.16866    1.18273 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4706931033571689 for eigenvalue
#  The estimated number of batches is 1556
#       731/1    1.17488    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.468803424192739 for eigenvalue
#  The estimated number of batches is 1554
#       732/1    1.18955    1.18273 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.468760507689516 for eigenvalue
#  The estimated number of batches is 1556
#       733/1    1.17534    1.18272 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.473089802848878 for eigenvalue
#  The estimated number of batches is 1568
#       734/1    1.17501    1.18271 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4730627470463185 for eigenvalue
#  The estimated number of batches is 1570
#       735/1    1.17506    1.18270 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.471307148297122 for eigenvalue
#  The estimated number of batches is 1568
#       736/1    1.16807    1.18268 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4706356192361079 for eigenvalue
#  The estimated number of batches is 1569
#       737/1    1.18582    1.18268 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4700789170554498 for eigenvalue
#  The estimated number of batches is 1570
#       738/1    1.19320    1.18269 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4709074046598842 for eigenvalue
#  The estimated number of batches is 1574
#       739/1    1.18020    1.18269 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4693078734472238 for eigenvalue
#  The estimated number of batches is 1573
#       740/1    1.17734    1.18268 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4677857392301439 for eigenvalue
#  The estimated number of batches is 1572
#       741/1    1.18651    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4659642342767323 for eigenvalue
#  The estimated number of batches is 1570
#       742/1    1.18526    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4650807291299008 for eigenvalue
#  The estimated number of batches is 1570
#       743/1    1.18281    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4630863835256702 for eigenvalue
#  The estimated number of batches is 1568
#       744/1    1.17951    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4611459787943515 for eigenvalue
#  The estimated number of batches is 1566
#       745/1    1.18598    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4606118604831266 for eigenvalue
#  The estimated number of batches is 1567
#       746/1    1.18180    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4592670261642846 for eigenvalue
#  The estimated number of batches is 1566
#       747/1    1.18756    1.18270 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4578673035735057 for eigenvalue
#  The estimated number of batches is 1566
#       748/1    1.18858    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.458535738041194 for eigenvalue
#  The estimated number of batches is 1569
#       749/1    1.18550    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.457096494059235 for eigenvalue
#  The estimated number of batches is 1568
#       750/1    1.17970    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4557061236107947 for eigenvalue
#  The estimated number of batches is 1567
#       751/1    1.18176    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4577277887081708 for eigenvalue
#  The estimated number of batches is 1574
#       752/1    1.17381    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4559311113845412 for eigenvalue
#  The estimated number of batches is 1572
#       753/1    1.17423    1.18268 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4598570960074155 for eigenvalue
#  The estimated number of batches is 1583
#       754/1    1.17699    1.18267 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4577722907813278 for eigenvalue
#  The estimated number of batches is 1580
#       755/1    1.18859    1.18268 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4559190358532923 for eigenvalue
#  The estimated number of batches is 1578
#       756/1    1.17928    1.18268 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4541922223087107 for eigenvalue
#  The estimated number of batches is 1577
#       757/1    1.18185    1.18268 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4533391142890089 for eigenvalue
#  The estimated number of batches is 1577
#       758/1    1.19308    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4561006506442644 for eigenvalue
#  The estimated number of batches is 1585
#       759/1    1.18717    1.18270 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4541974401481428 for eigenvalue
#  The estimated number of batches is 1583
#       760/1    1.19132    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4524154707422678 for eigenvalue
#  The estimated number of batches is 1582
#       761/1    1.18046    1.18270 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4505187487132452 for eigenvalue
#  The estimated number of batches is 1580
#       762/1    1.18700    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4486591188218292 for eigenvalue
#  The estimated number of batches is 1578
#       763/1    1.17515    1.18270 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4465276943120893 for eigenvalue
#  The estimated number of batches is 1575
#       764/1    1.18221    1.18270 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.446932530325311 for eigenvalue
#  The estimated number of batches is 1578
#       765/1    1.18261    1.18270 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4464377280546352 for eigenvalue
#  The estimated number of batches is 1579
#       766/1    1.17980    1.18270 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.446686733560403 for eigenvalue
#  The estimated number of batches is 1582
#       767/1    1.18153    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4455340062755713 for eigenvalue
#  The estimated number of batches is 1581
#       768/1    1.17651    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.44762684290135 for eigenvalue
#  The estimated number of batches is 1588
#       769/1    1.17198    1.18267 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4457084804583422 for eigenvalue
#  The estimated number of batches is 1586
#       770/1    1.18686    1.18268 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.443975869606574 for eigenvalue
#  The estimated number of batches is 1584
#       771/1    1.17497    1.18267 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4464915930434643 for eigenvalue
#  The estimated number of batches is 1592
#       772/1    1.18964    1.18268 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.44470533081971 for eigenvalue
#  The estimated number of batches is 1590
#       773/1    1.19569    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4457101767326146 for eigenvalue
#  The estimated number of batches is 1594
#       774/1    1.18211    1.18269 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4444325270918619 for eigenvalue
#  The estimated number of batches is 1594
#       775/1    1.19054    1.18270 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4436876924393405 for eigenvalue
#  The estimated number of batches is 1594
#       776/1    1.19051    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4419445599611231 for eigenvalue
#  The estimated number of batches is 1592
#       777/1    1.18537    1.18272 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4401843589969319 for eigenvalue
#  The estimated number of batches is 1591
#       778/1    1.17772    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4381868198049559 for eigenvalue
#  The estimated number of batches is 1588
#       779/1    1.18090    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4365055478502442 for eigenvalue
#  The estimated number of batches is 1587
#       780/1    1.18328    1.18271 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4356756020724852 for eigenvalue
#  The estimated number of batches is 1587
#       781/1    1.19085    1.18272 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4342568878572575 for eigenvalue
#  The estimated number of batches is 1586
#       782/1    1.18390    1.18272 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4325185402690896 for eigenvalue
#  The estimated number of batches is 1584
#       783/1    1.18914    1.18273 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4307672683588293 for eigenvalue
#  The estimated number of batches is 1582
#       784/1    1.18105    1.18273 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4312630579568013 for eigenvalue
#  The estimated number of batches is 1586
#       785/1    1.19498    1.18274 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4360823981348654 for eigenvalue
#  The estimated number of batches is 1598
#       786/1    1.18670    1.18275 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4351926630894754 for eigenvalue
#  The estimated number of batches is 1598
#       787/1    1.18295    1.18275 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4337971711858462 for eigenvalue
#  The estimated number of batches is 1597
