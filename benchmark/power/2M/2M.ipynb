# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600

coat_mat = openmc.Material(name="coat_mat")
coat_mat.add_nuclide('B10',2.16410E-02, 'ao')
coat_mat.add_nuclide('B11',1.96824E-02, 'ao')
coat_mat.add_nuclide('Zr90',1.06304E-02, 'ao')
coat_mat.add_nuclide('Zr91',2.31824E-03, 'ao')
coat_mat.add_nuclide('Zr92',3.54348E-03, 'ao')
coat_mat.add_nuclide('Zr94',3.59100E-03, 'ao')
coat_mat.add_nuclide('Zr96',5.78528E-04, 'ao')
coat_mat.temperature=600
coat_mat.set_density('g/cm3', 3.85)

model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304,coat_mat]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell_ifba(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    coat_outer_radius = openmc.ZCylinder(r=0.4106)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    coat_region = +fuel_outer_radius & -coat_outer_radius
    gap_region = +coat_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    coat = openmc.Cell(name='coat'+'_'+family)
    coat.fill = coat_mat
    coat.region = coat_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator,coat))
    return(u,fuel,gap,clad,moderator,coat)

# %%
def pincell_normal(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
GT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]
IFBAT=[(0,0),(4,0),(0,4),(7,0),(0,7),(2,1),(1,2),(5,1),(1,5),(8,1),(1,8),(3,2),(2,3),(4,2),(2,4),(6,2),(2,6),(7,2),(2,7),(4,3),(3,4),(5,3),(3,5),(8,3),(3,8),(5,4),(4,5),(8,4),(4,8),(6,5),(5,6),(7,5),(5,7),(8,6),(6,8),(8,7),(7,8)]


GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))


IFBAT_left=[]
IFBAT_full=[]
for X in IFBAT:
    IFBAT_left.append((X[0],X[1]))
    IFBAT_left.append((X[0],16-X[1]))
for X in IFBAT_left:
    IFBAT_full.append((X[0],X[1]))
    IFBAT_full.append((16-X[0],X[1]))    
IFBAT_full = list(set(IFBAT_full))

# %% [markdown]
# ### Define assembly

# %%
pincell_1_family=pincell_normal('normal')
ifba_1_family=pincell_ifba('ifba')
guide_1_family=guide('guide')
instru_1_family=instru('instru')

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full :
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in IFBAT_full:
            A[ix][iy]=ifba_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water
rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:14:55
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron
#  The estimated number of batches is 1437
#        52/1    0.93808    0.93957 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 6.526778882893503 for eigenvalue
#  The estimated number of batches is 1384
#        53/1    0.92587    0.93915 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 6.968954387915842 for eigenvalue
#  The estimated number of batches is 1623
#        54/1    0.93305    0.93897 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.830384963491285 for eigenvalue
#  The estimated number of batches is 1607
#        55/1    0.93431    0.93884 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 7.104993765344645 for eigenvalue
#  The estimated number of batches is 1787
#        56/1    0.93530    0.93874 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 7.138244864840785 for eigenvalue
#  The estimated number of batches is 1855
#        57/1    0.93325    0.93859 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.942779020292471 for eigenvalue
#  The estimated number of batches is 1804
#        58/1    0.93307    0.93845 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 6.795729897456335 for eigenvalue
#  The estimated number of batches is 1775
#        59/1    0.94937    0.93873 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 6.627869640377605 for eigenvalue
#  The estimated number of batches is 1734
#        60/1    0.94901    0.93898 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 6.611279988471907 for eigenvalue
#  The estimated number of batches is 1769
#        61/1    0.93823    0.93897 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 6.4415991507083605 for eigenvalue
#  The estimated number of batches is 1722
#        62/1    0.94444    0.93910 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.4210302014259035 for eigenvalue
#  The estimated number of batches is 1752
#        63/1    0.93967    0.93911 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.2874534237937505 for eigenvalue
#  The estimated number of batches is 1720
#        64/1    0.94733    0.93930 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.4252183864591155 for eigenvalue
#  The estimated number of batches is 1837
#        65/1    0.94778    0.93948 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.298490579029054 for eigenvalue
#  The estimated number of batches is 1806
#        66/1    0.94545    0.93961 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 6.176901623183637 for eigenvalue
#  The estimated number of batches is 1776
#        67/1    0.93717    0.93956 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 6.031085780544027 for eigenvalue
#  The estimated number of batches is 1730
#        68/1    0.93453    0.93946 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.926670419415404 for eigenvalue
#  The estimated number of batches is 1707
#        69/1    0.93442    0.93935 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.801480149357859 for eigenvalue
#  The estimated number of batches is 1670
#        70/1    0.94011    0.93937 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.7282115762561725 for eigenvalue
#  The estimated number of batches is 1661
#        71/1    0.93997    0.93938 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.634716012520829 for eigenvalue
#  The estimated number of batches is 1640
#        72/1    0.94225    0.93944 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.53512483218531 for eigenvalue
#  The estimated number of batches is 1614
#        73/1    0.94030    0.93945 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.440411486670045 for eigenvalue
#  The estimated number of batches is 1589
#        74/1    0.94077    0.93948 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.347721763703815 for eigenvalue
#  The estimated number of batches is 1565
#        75/1    0.94007    0.93949 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.27752508457232 for eigenvalue
#  The estimated number of batches is 1552
#        76/1    0.93555    0.93942 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.180109997448018 for eigenvalue
#  The estimated number of batches is 1523
#        77/1    0.94182    0.93946 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.170006631850046 for eigenvalue
#  The estimated number of batches is 1544
#        78/1    0.94363    0.93953 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.077644490425786 for eigenvalue
#  The estimated number of batches is 1516
#        79/1    0.94511    0.93963 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.0038979866750095 for eigenvalue
#  The estimated number of batches is 1498
#        80/1    0.93234    0.93951 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.988545460816101 for eigenvalue
#  The estimated number of batches is 1514
#        81/1    0.93893    0.93950 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.965300879609655 for eigenvalue
#  The estimated number of batches is 1524
#        82/1    0.93153    0.93937 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.882237198183502 for eigenvalue
#  The estimated number of batches is 1498
#        83/1    0.93745    0.93934 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.801106640767109 for eigenvalue
#  The estimated number of batches is 1473
#        84/1    0.94246    0.93939 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.772406151802715 for eigenvalue
#  The estimated number of batches is 1478
#        85/1    0.94504    0.93947 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.743734471955008 for eigenvalue
#  The estimated number of batches is 1483
#        86/1    0.94512    0.93956 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.6844104874790595 for eigenvalue
#  The estimated number of batches is 1469
#        87/1    0.94750    0.93968 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.674439985721548 for eigenvalue
#  The estimated number of batches is 1484
#        88/1    0.94261    0.93972 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.61368390627979 for eigenvalue
#  The estimated number of batches is 1468
#        89/1    0.93457    0.93965 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.542557913603827 for eigenvalue
#       109/1    0.94741    0.93977 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.847134114610835 for eigenvalue
#  The estimated number of batches is 1338
#       110/1    0.94184    0.93979 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8291029859639147 for eigenvalue
#  The estimated number of batches is 1340
#       111/1    0.93406    0.93973 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.818179036200312 for eigenvalue
#  The estimated number of batches is 1347
#       112/1    0.93325    0.93966 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8040096873274907 for eigenvalue
#  The estimated number of batches is 1352
#       113/1    0.93780    0.93964 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7560500223176323 for eigenvalue
#  The estimated number of batches is 1333
#       114/1    0.93796    0.93962 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.71196359775057 for eigenvalue
#  The estimated number of batches is 1316
#       115/1    0.92940    0.93951 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7068375603637875 for eigenvalue
#  The estimated number of batches is 1326
#       116/1    0.92892    0.93940 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.6857185792902816 for eigenvalue
#  The estimated number of batches is 1325
#       117/1    0.93815    0.93939 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6487996042144952 for eigenvalue
#  The estimated number of batches is 1312
#       118/1    0.94006    0.93940 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.610414506780678 for eigenvalue
#  The estimated number of batches is 1298
#       119/1    0.95029    0.93951 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6366622928995618 for eigenvalue
#  The estimated number of batches is 1330
#       120/1    0.93829    0.93949 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.604544485843948 for eigenvalue
#  The estimated number of batches is 1320
#       121/1    0.93929    0.93949 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5975864515482816 for eigenvalue
#  The estimated number of batches is 1328
#       122/1    0.92871    0.93939 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.654238804580386 for eigenvalue
#  The estimated number of batches is 1383
#       123/1    0.94267    0.93942 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.624323284063269 for eigenvalue
#  The estimated number of batches is 1373
#       124/1    0.93307    0.93936 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5819181206674564 for eigenvalue
#  The estimated number of batches is 1355
#       125/1    0.94041    0.93937 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.544839731712499 for eigenvalue
#  The estimated number of batches is 1340
#       126/1    0.94685    0.93944 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.573417821087308 for eigenvalue
#  The estimated number of batches is 1374
#       127/1    0.93391    0.93939 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.577391244902078 for eigenvalue
#  The estimated number of batches is 1390
#       128/1    0.93126    0.93931 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5635210599791605 for eigenvalue
#  The estimated number of batches is 1392
#       129/1    0.94722    0.93938 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5255915893413374 for eigenvalue
#  The estimated number of batches is 1375
#       130/1    0.93589    0.93935 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4912939324235834 for eigenvalue
#  The estimated number of batches is 1361
#       131/1    0.94599    0.93941 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.460339871481646 for eigenvalue
#  The estimated number of batches is 1350
#       132/1    0.93677    0.93939 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.428342246548902 for eigenvalue
#  The estimated number of batches is 1337
#       133/1    0.93538    0.93935 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.40925310412829 for eigenvalue
#  The estimated number of batches is 1334
#       134/1    0.94273    0.93938 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.380742437557385 for eigenvalue
#  The estimated number of batches is 1323
#       135/1    0.94113    0.93940 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.362896409644076 for eigenvalue
#  The estimated number of batches is 1321
#       136/1    0.94488    0.93944 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.333115375987893 for eigenvalue
#  The estimated number of batches is 1309
#       137/1    0.93520    0.93941 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3223981961553735 for eigenvalue
#  The estimated number of batches is 1312
#       138/1    0.94511    0.93946 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3207893669092092 for eigenvalue
#  The estimated number of batches is 1322
#       139/1    0.94245    0.93948 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.29569250432033 for eigenvalue
#  The estimated number of batches is 1313
#       140/1    0.94604    0.93954 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2680323226212526 for eigenvalue
#  The estimated number of batches is 1302
#       141/1    0.92963    0.93945 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2442591252859487 for eigenvalue
#  The estimated number of batches is 1294
#       142/1    0.93245    0.93940 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2731125249430697 for eigenvalue
#  The estimated number of batches is 1328
#       143/1    0.93889    0.93939 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.257633839581604 for eigenvalue
#  The estimated number of batches is 1326
#       144/1    0.94691    0.93945 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2665106236425534 for eigenvalue
#  The estimated number of batches is 1344
#       145/1    0.93539    0.93942 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.3036350661810294 for eigenvalue
#  The estimated number of batches is 1385
#       146/1    0.93310    0.93937 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.267526272831091 for eigenvalue
#  The estimated number of batches is 1366
#       147/1    0.93368    0.93933 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2344001714382506 for eigenvalue
#  The estimated number of batches is 1349
#       148/1    0.93596    0.93930 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2197659894106385 for eigenvalue
#  The estimated number of batches is 1347
#       149/1    0.93966    0.93930 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2023687088018282 for eigenvalue
#  The estimated number of batches is 1343
#       150/1    0.93422    0.93926 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2553508236577753 for eigenvalue
#  The estimated number of batches is 1398
#       151/1    0.93989    0.93927 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.236235768144176 for eigenvalue
#  The estimated number of batches is 1392
#       152/1    0.93575    0.93924 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2177903372613916 for eigenvalue
#  The estimated number of batches is 1387
#       153/1    0.94735    0.93930 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2303051028367147 for eigenvalue
#  The estimated number of batches is 1408
#       154/1    0.93832    0.93930 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2107498720434102 for eigenvalue
#  The estimated number of batches is 1402
#       155/1    0.94403    0.93933 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.183494067178197 for eigenvalue
#  The estimated number of batches is 1389
#       156/1    0.94514    0.93937 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1575420110761874 for eigenvalue
#  The estimated number of batches is 1376
#       157/1    0.94001    0.93938 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1319357623675526 for eigenvalue
#  The estimated number of batches is 1364
#       158/1    0.93148    0.93932 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1356138678301817 for eigenvalue
#  The estimated number of batches is 1377
#       159/1    0.94361    0.93935 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1192298322710217 for eigenvalue
#  The estimated number of batches is 1373
#       160/1    0.93812    0.93934 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.104433647483775 for eigenvalue
#  The estimated number of batches is 1370
#       161/1    0.93758    0.93933 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0821508542769727 for eigenvalue
#  The estimated number of batches is 1360
#       162/1    0.93837    0.93932 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0647009853889458 for eigenvalue
#  The estimated number of batches is 1354
#       163/1    0.94619    0.93937 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.045131379750927 for eigenvalue
#  The estimated number of batches is 1347
#       164/1    0.93018    0.93931 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0263932546657655 for eigenvalue
#  The estimated number of batches is 1339
#       165/1    0.93349    0.93927 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.006620275628452 for eigenvalue
#  The estimated number of batches is 1331
#       166/1    0.94014    0.93927 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9982375272653843 for eigenvalue
#  The estimated number of batches is 1333
#       167/1    0.94425    0.93931 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.982500451408502 for eigenvalue
#  The estimated number of batches is 1328
#       168/1    0.94168    0.93932 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9672543886911917 for eigenvalue
#  The estimated number of batches is 1324
#       169/1    0.93773    0.93931 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.9478439976295223 for eigenvalue
#  The estimated number of batches is 1315
#       170/1    0.93847    0.93931 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.931351030545008 for eigenvalue
#  The estimated number of batches is 1309
#       171/1    0.94326    0.93933 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9191833187066245 for eigenvalue
#  The estimated number of batches is 1307
#       172/1    0.94611    0.93938 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9237260979093156 for eigenvalue
#  The estimated number of batches is 1320
#       173/1    0.93359    0.93934 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9156753785948637 for eigenvalue
#  The estimated number of batches is 1321
#       174/1    0.94452    0.93937 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.900506885422427 for eigenvalue
#  The estimated number of batches is 1316
#       175/1    0.94220    0.93939 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.884900973237645 for eigenvalue
#  The estimated number of batches is 1311
#       176/1    0.94257    0.93941 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8687505396456205 for eigenvalue
#  The estimated number of batches is 1304
#       177/1    0.93283    0.93937 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8517946805715657 for eigenvalue
#  The estimated number of batches is 1297
#       178/1    0.94596    0.93941 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8486913149979594 for eigenvalue
#  The estimated number of batches is 1303
#       179/1    0.93056    0.93936 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8677944285783283 for eigenvalue
#  The estimated number of batches is 1328
#       180/1    0.93232    0.93931 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8537972556862807 for eigenvalue
#  The estimated number of batches is 1324
#       181/1    0.93918    0.93931 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8367085600081534 for eigenvalue
#  The estimated number of batches is 1316
#       182/1    0.94131    0.93932 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8213824326351085 for eigenvalue
#  The estimated number of batches is 1310
#       183/1    0.93966    0.93933 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8054113196813355 for eigenvalue
#  The estimated number of batches is 1303
#       184/1    0.94522    0.93936 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.829484312482661 for eigenvalue
#  The estimated number of batches is 1323
#       242/1    0.93602    0.93919 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4177087543140834 for eigenvalue
#  The estimated number of batches is 1318
#       243/1    0.93585    0.93917 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4095211541369976 for eigenvalue
#  The estimated number of batches is 1315
#       244/1    0.94001    0.93917 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4001565892818504 for eigenvalue
#  The estimated number of batches is 1311
#       245/1    0.94404    0.93920 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3899673834081008 for eigenvalue
#  The estimated number of batches is 1306
#       246/1    0.93833    0.93919 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.38059048977626 for eigenvalue
#  The estimated number of batches is 1301
#       247/1    0.94286    0.93921 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3732508633787988 for eigenvalue
#  The estimated number of batches is 1299
#       248/1    0.93655    0.93920 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3724775720544953 for eigenvalue
#  The estimated number of batches is 1304
#       249/1    0.94501    0.93922 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3720234225379544 for eigenvalue
#  The estimated number of batches is 1309
#       250/1    0.94680    0.93925 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.371212617622463 for eigenvalue
#  The estimated number of batches is 1314
#       251/1    0.94120    0.93926 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.361347450242787 for eigenvalue
#  The estimated number of batches is 1309
#       252/1    0.93585    0.93925 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.352731352337951 for eigenvalue
#  The estimated number of batches is 1305
#       253/1    0.94445    0.93927 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.348889275259138 for eigenvalue
#  The estimated number of batches is 1306
#       254/1    0.94058    0.93928 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3430918744108453 for eigenvalue
#  The estimated number of batches is 1305
#       255/1    0.94051    0.93928 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.333988894751372 for eigenvalue
#  The estimated number of batches is 1301
#       256/1    0.94449    0.93930 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3274052990100667 for eigenvalue
#  The estimated number of batches is 1299
#       257/1    0.93512    0.93929 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.32007620879474 for eigenvalue
#  The estimated number of batches is 1296
#       258/1    0.93753    0.93928 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3108742584901347 for eigenvalue
#  The estimated number of batches is 1291
#       259/1    0.94396    0.93930 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.305335799147604 for eigenvalue
#  The estimated number of batches is 1291
#       260/1    0.92924    0.93926 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3159675011711074 for eigenvalue
#  The estimated number of batches is 1308
#       261/1    0.93712    0.93925 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3089264015816484 for eigenvalue
#  The estimated number of batches is 1305
#       262/1    0.94058    0.93925 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.306239578492481 for eigenvalue
#  The estimated number of batches is 1308
#       263/1    0.93574    0.93924 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3037802096728273 for eigenvalue
#  The estimated number of batches is 1310
#       264/1    0.93239    0.93921 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2946106196103635 for eigenvalue
#  The estimated number of batches is 1305
#       265/1    0.93702    0.93920 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.284858774881499 for eigenvalue
#  The estimated number of batches is 1300
#       266/1    0.93978    0.93920 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2845027428423528 for eigenvalue
#  The estimated number of batches is 1304
#       267/1    0.94170    0.93921 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2753900386277475 for eigenvalue
#  The estimated number of batches is 1299
#       268/1    0.94145    0.93922 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2685877542523953 for eigenvalue
#  The estimated number of batches is 1297
#       269/1    0.93283    0.93920 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2635062140568656 for eigenvalue
#  The estimated number of batches is 1296
#       270/1    0.93645    0.93919 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.255381147917193 for eigenvalue
#  The estimated number of batches is 1292
#       271/1    0.93454    0.93917 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2476365615827296 for eigenvalue
#  The estimated number of batches is 1289
#       272/1    0.94632    0.93920 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2480868602498494 for eigenvalue
#  The estimated number of batches is 1294
#       273/1    0.93169    0.93917 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.24781948411712 for eigenvalue
#  The estimated number of batches is 1299
#       274/1    0.93665    0.93916 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2391834392245324 for eigenvalue
#  The estimated number of batches is 1294
#       275/1    0.93847    0.93915 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.235524437715383 for eigenvalue
#  The estimated number of batches is 1295
#       276/1    0.93253    0.93913 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2364582486479425 for eigenvalue
#  The estimated number of batches is 1301
#       277/1    0.93799    0.93912 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2403011803102415 for eigenvalue
#  The estimated number of batches is 1310
#       278/1    0.93718    0.93912 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.233487215738579 for eigenvalue
#  The estimated number of batches is 1308
#       279/1    0.94190    0.93913 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.224364549327527 for eigenvalue
#  The estimated number of batches is 1302
#       280/1    0.94268    0.93914 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.223101240322708 for eigenvalue
#  The estimated number of batches is 1305
#       281/1    0.94703    0.93917 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.221051915941205 for eigenvalue
#  The estimated number of batches is 1308
#       282/1    0.93505    0.93916 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.220867694476657 for eigenvalue
#  The estimated number of batches is 1313
#       283/1    0.93910    0.93915 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2154585675633274 for eigenvalue
#  The estimated number of batches is 1311
#       284/1    0.93360    0.93913 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.210282783755063 for eigenvalue
#  The estimated number of batches is 1310
#       285/1    0.93759    0.93913 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.205280199533922 for eigenvalue
#  The estimated number of batches is 1309
#       286/1    0.93427    0.93911 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.206235843332676 for eigenvalue
#  The estimated number of batches is 1315
#       287/1    0.94174    0.93912 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.199125703747953 for eigenvalue
#  The estimated number of batches is 1312
#       288/1    0.94582    0.93914 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.190798227616982 for eigenvalue
#  The estimated number of batches is 1307
#       289/1    0.94107    0.93915 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1825931961195093 for eigenvalue
#  The estimated number of batches is 1302
#       290/1    0.94313    0.93917 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1768887636291625 for eigenvalue
#  The estimated number of batches is 1300
#       291/1    0.93279    0.93914 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1688158910696944 for eigenvalue
#  The estimated number of batches is 1295
#       292/1    0.94370    0.93916 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1602495389256338 for eigenvalue
#  The estimated number of batches is 1290
#       293/1    0.94113    0.93917 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1623385502029153 for eigenvalue
#  The estimated number of batches is 1297
#       294/1    0.92875    0.93913 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.1634673402096047 for eigenvalue
#  The estimated number of batches is 1303
#       295/1    0.94201    0.93914 +/- 0.00032
# ...
#  Triggers unsatisfied, max unc./thresh. is 1.459337035042242 for eigenvalue
#  The estimated number of batches is 1315
#       629/1    0.94154    0.93909 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4569650911827985 for eigenvalue
#  The estimated number of batches is 1313
#       630/1    0.93936    0.93909 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.455066938153696 for eigenvalue
#  The estimated number of batches is 1312
#       631/1    0.94098    0.93910 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4526657162723051 for eigenvalue
#  The estimated number of batches is 1310
#       632/1    0.94123    0.93910 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4508937186817124 for eigenvalue
#  The estimated number of batches is 1309
#       633/1    0.93780    0.93910 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.450299899753901 for eigenvalue
#  The estimated number of batches is 1310
#       634/1    0.94513    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4487881161242917 for eigenvalue
#  The estimated number of batches is 1309
#       635/1    0.94314    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.446719344336678 for eigenvalue
#  The estimated number of batches is 1308
#       636/1    0.93849    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4444855602516027 for eigenvalue
#  The estimated number of batches is 1306
#       637/1    0.93762    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4421639885184885 for eigenvalue
#  The estimated number of batches is 1304
#       638/1    0.94158    0.93912 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.440275720062171 for eigenvalue
#  The estimated number of batches is 1302
#       639/1    0.93884    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4379208205816858 for eigenvalue
#  The estimated number of batches is 1300
#       640/1    0.93609    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.435939000009112 for eigenvalue
#  The estimated number of batches is 1299
#       641/1    0.93958    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4339171665512545 for eigenvalue
#  The estimated number of batches is 1297
#       642/1    0.94060    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.431708035960415 for eigenvalue
#  The estimated number of batches is 1295
#       643/1    0.93213    0.93910 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4337800930217395 for eigenvalue
#  The estimated number of batches is 1301
#       644/1    0.94498    0.93911 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4318745606170955 for eigenvalue
#  The estimated number of batches is 1300
#       645/1    0.93585    0.93911 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4296757200390877 for eigenvalue
#  The estimated number of batches is 1298
#       646/1    0.94879    0.93912 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4288085220321862 for eigenvalue
#  The estimated number of batches is 1298
#       647/1    0.94698    0.93913 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4287637325334404 for eigenvalue
#  The estimated number of batches is 1300
#       648/1    0.93733    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4265338455797882 for eigenvalue
#  The estimated number of batches is 1298
#       649/1    0.93565    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4246101893057401 for eigenvalue
#  The estimated number of batches is 1297
#       650/1    0.94796    0.93914 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4248310026830147 for eigenvalue
#  The estimated number of batches is 1299
#       651/1    0.93787    0.93914 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.425638974254357 for eigenvalue
#  The estimated number of batches is 1303
#       652/1    0.94675    0.93915 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4242287445819959 for eigenvalue
#  The estimated number of batches is 1302
#       653/1    0.92700    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4248407671532959 for eigenvalue
#  The estimated number of batches is 1306
#       654/1    0.93980    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4232773361589484 for eigenvalue
#  The estimated number of batches is 1305
#       655/1    0.93903    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4213121440721546 for eigenvalue
#  The estimated number of batches is 1303
#       656/1    0.94204    0.93914 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4232098704988263 for eigenvalue
#  The estimated number of batches is 1309
#       657/1    0.93970    0.93914 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4210771597387504 for eigenvalue
#  The estimated number of batches is 1307
#       658/1    0.93533    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.418878522467236 for eigenvalue
#  The estimated number of batches is 1305
#       659/1    0.93658    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.41730688214223 for eigenvalue
#  The estimated number of batches is 1304
#       660/1    0.94599    0.93914 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.415188142983387 for eigenvalue
#  The estimated number of batches is 1302
#       661/1    0.93094    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4156819449794809 for eigenvalue
#  The estimated number of batches is 1305
#       662/1    0.93220    0.93911 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4146184889363635 for eigenvalue
#  The estimated number of batches is 1305
#       663/1    0.94513    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.414966489332844 for eigenvalue
#  The estimated number of batches is 1308
#       664/1    0.94275    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4127815461032212 for eigenvalue
#  The estimated number of batches is 1306
#       665/1    0.93378    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4109889723149671 for eigenvalue
#  The estimated number of batches is 1305
#       666/1    0.94413    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4093189579586265 for eigenvalue
#  The estimated number of batches is 1304
#       667/1    0.94118    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4074558335901866 for eigenvalue
#  The estimated number of batches is 1302
#       668/1    0.93799    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4067652438370788 for eigenvalue
#  The estimated number of batches is 1303
#       669/1    0.93320    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4051866497629864 for eigenvalue
#  The estimated number of batches is 1302
#       670/1    0.94603    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4044071246136987 for eigenvalue
#  The estimated number of batches is 1303
#       671/1    0.93677    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4023296491560424 for eigenvalue
#  The estimated number of batches is 1301
#       672/1    0.93382    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.40051247197187 for eigenvalue
#  The estimated number of batches is 1299
#       673/1    0.93875    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.399487283048762 for eigenvalue
#  The estimated number of batches is 1299
#       674/1    0.94193    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3984612245574826 for eigenvalue
#  The estimated number of batches is 1300
#       675/1    0.93119    0.93911 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3991968100152081 for eigenvalue
#  The estimated number of batches is 1303
#       676/1    0.94285    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3973193770017278 for eigenvalue
#  The estimated number of batches is 1301
#       677/1    0.94433    0.93913 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3952026849551316 for eigenvalue
#  The estimated number of batches is 1299
#       678/1    0.93741    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.393586799525973 for eigenvalue
#  The estimated number of batches is 1298
#       679/1    0.93479    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3914418925422882 for eigenvalue
#  The estimated number of batches is 1296
#       680/1    0.93195    0.93910 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3970897285289265 for eigenvalue
#  The estimated number of batches is 1309
#       681/1    0.94027    0.93911 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3956093006580237 for eigenvalue
#  The estimated number of batches is 1308
#       682/1    0.93980    0.93911 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.393606285252606 for eigenvalue
#  The estimated number of batches is 1306
#       683/1    0.94531    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3940212029880785 for eigenvalue
#  The estimated number of batches is 1309
#       684/1    0.93324    0.93911 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.392723677320658 for eigenvalue
#  The estimated number of batches is 1308
#       685/1    0.93529    0.93910 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.390639840891747 for eigenvalue
#  The estimated number of batches is 1307
#       686/1    0.93343    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3905049641814278 for eigenvalue
#  The estimated number of batches is 1308
#       687/1    0.94344    0.93910 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3886798846178985 for eigenvalue
#  The estimated number of batches is 1307
#       688/1    0.92571    0.93908 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3866381455341348 for eigenvalue
#  The estimated number of batches is 1305
#       689/1    0.93973    0.93908 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.385113956737463 for eigenvalue
#  The estimated number of batches is 1304
#       690/1    0.94494    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3851641057834956 for eigenvalue
#  The estimated number of batches is 1306
#       691/1    0.93351    0.93908 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3831692666970943 for eigenvalue
#  The estimated number of batches is 1304
#       692/1    0.94095    0.93908 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3834619982167486 for eigenvalue
#  The estimated number of batches is 1307
#       693/1    0.94640    0.93910 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.381677525267746 for eigenvalue
#  The estimated number of batches is 1305
#       694/1    0.93213    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.379677272166666 for eigenvalue
#  The estimated number of batches is 1303
#       695/1    0.93548    0.93908 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3789281304982028 for eigenvalue
#  The estimated number of batches is 1304
#       696/1    0.93731    0.93908 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3769153431958236 for eigenvalue
#  The estimated number of batches is 1302
#       697/1    0.94152    0.93908 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3768709006576674 for eigenvalue
#  The estimated number of batches is 1304
#       698/1    0.93874    0.93908 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3748376576300814 for eigenvalue
#  The estimated number of batches is 1302
#       699/1    0.94596    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3728378006322184 for eigenvalue
#  The estimated number of batches is 1300
#       700/1    0.93657    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3709052328043667 for eigenvalue
#  The estimated number of batches is 1298
#       701/1    0.94381    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3696955235688282 for eigenvalue
#  The estimated number of batches is 1298
#       702/1    0.93657    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3679769349668973 for eigenvalue
#  The estimated number of batches is 1297
#       703/1    0.94085    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3662435875405625 for eigenvalue
#  The estimated number of batches is 1295
#       704/1    0.94737    0.93910 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3664198054717354 for eigenvalue
#  The estimated number of batches is 1298
#       705/1    0.94092    0.93911 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3660974183670116 for eigenvalue
#  The estimated number of batches is 1299
#       706/1    0.94553    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3650150401721683 for eigenvalue
#  The estimated number of batches is 1299
#       707/1    0.93886    0.93912 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3640965399083984 for eigenvalue
#  The estimated number of batches is 1299
#       708/1    0.93765    0.93911 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3622421961920386 for eigenvalue
#  The estimated number of batches is 1297
#       709/1    0.93138    0.93910 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3604639894355104 for eigenvalue
#  The estimated number of batches is 1296
#       710/1    0.93765    0.93910 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3585033999342078 for eigenvalue
#  The estimated number of batches is 1294
#       711/1    0.93279    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3569768737428711 for eigenvalue
#  The estimated number of batches is 1293
#       712/1    0.93998    0.93909 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3554105982322218 for eigenvalue
#  The estimated number of batches is 1292
#       713/1    0.93822    0.93909 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3541264510658828 for eigenvalue
#  The estimated number of batches is 1291
#       714/1    0.94119    0.93909 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.352848459510685 for eigenvalue
#  The estimated number of batches is 1291
#       715/1    0.93144    0.93908 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3579380867755695 for eigenvalue
#  The estimated number of batches is 1302
#       716/1    0.93581    0.93908 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3560103071453329 for eigenvalue
#  The estimated number of batches is 1300
#       717/1    0.94142    0.93908 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3562548433280075 for eigenvalue
#  The estimated number of batches is 1303
#       718/1    0.94237    0.93909 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.354284767737532 for eigenvalue
#  The estimated number of batches is 1301
#       719/1    0.94261    0.93909 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3528436645112751 for eigenvalue
#  The estimated number of batches is 1300
#       720/1    0.93540    0.93909 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3509760037142688 for eigenvalue
#  The estimated number of batches is 1298
#       721/1    0.94479    0.93910 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3508919897181595 for eigenvalue
#  The estimated number of batches is 1300
#       722/1    0.94102    0.93910 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3491310042703266 for eigenvalue
#  The estimated number of batches is 1298
#       723/1    0.93855    0.93910 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.347339066109158 for eigenvalue
#  The estimated number of batches is 1297
#       724/1    0.93781    0.93910 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.348350160053041 for eigenvalue
#  The estimated number of batches is 1300
#       725/1    0.94613    0.93911 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3493380082441115 for eigenvalue
#  The estimated number of batches is 1304
