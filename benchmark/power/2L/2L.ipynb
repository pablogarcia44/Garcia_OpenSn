# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600

coat_mat = openmc.Material(name="coat_mat")
coat_mat.add_nuclide('B10',2.16410E-02, 'ao')
coat_mat.add_nuclide('B11',1.96824E-02, 'ao')
coat_mat.add_nuclide('Zr90',1.06304E-02, 'ao')
coat_mat.add_nuclide('Zr91',2.31824E-03, 'ao')
coat_mat.add_nuclide('Zr92',3.54348E-03, 'ao')
coat_mat.add_nuclide('Zr94',3.59100E-03, 'ao')
coat_mat.add_nuclide('Zr96',5.78528E-04, 'ao')
coat_mat.temperature=600
coat_mat.set_density('g/cm3', 3.85)

model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304,coat_mat]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell_ifba(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    coat_outer_radius = openmc.ZCylinder(r=0.4106)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    coat_region = +fuel_outer_radius & -coat_outer_radius
    gap_region = +coat_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    coat = openmc.Cell(name='coat'+'_'+family)
    coat.fill = coat_mat
    coat.region = coat_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator,coat))
    return(u,fuel,gap,clad,moderator,coat)

# %%
def pincell_normal(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
GT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]
IFBAT=[(0,0),(2,2),(6,6),(5,1),(1,5),(8,1),(1,8),(4,2),(2,4),(7,2),(2,7),(4,3),(3,4),(5,3),(3,5),(5,4),(4,5),(8,4),(4,8),(7,5),(5,7),(8,7),(7,8)]


GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))


IFBAT_left=[]
IFBAT_full=[]
for X in IFBAT:
    IFBAT_left.append((X[0],X[1]))
    IFBAT_left.append((X[0],16-X[1]))
for X in IFBAT_left:
    IFBAT_full.append((X[0],X[1]))
    IFBAT_full.append((16-X[0],X[1]))    
IFBAT_full = list(set(IFBAT_full))

# %% [markdown]
# ### Define assembly

# %%
pincell_1_family=pincell_normal('normal')
ifba_1_family=pincell_ifba('ifba')
guide_1_family=guide('guide')
instru_1_family=instru('instru')

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full :
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in IFBAT_full:
            A[ix][iy]=ifba_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:14:58
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.02208
#         2/1    1.01715
#         3/1    1.01257
#         4/1    1.01487
#         5/1    1.02337
#         6/1    1.01987
#         7/1    1.00829
#         8/1    1.01961
#         9/1    1.01333
#        10/1    1.02069
#        11/1    1.02506
#        12/1    1.01627
#        13/1    1.01900
#        14/1    1.02198
#        15/1    1.01634
#        16/1    1.01939
#        17/1    1.02111
#        18/1    1.01834
#        19/1    1.00917
#        20/1    1.00892
#        21/1    1.01895
#        22/1    1.02738    1.02316 +/- 0.00422
#        23/1    1.01597    1.02077 +/- 0.00342
#        24/1    1.01410    1.01910 +/- 0.00293
#        25/1    1.01490    1.01826 +/- 0.00242
#        26/1    1.02865    1.01999 +/- 0.00263
#        27/1    1.01314    1.01901 +/- 0.00243
#        28/1    1.01824    1.01892 +/- 0.00211
#        29/1    1.02045    1.01909 +/- 0.00186
#        30/1    1.02857    1.02003 +/- 0.00192
#        31/1    1.01118    1.01923 +/- 0.00191
#        32/1    1.02086    1.01937 +/- 0.00175
#        33/1    1.01252    1.01884 +/- 0.00169
#        34/1    1.01544    1.01860 +/- 0.00159
#        35/1    1.02020    1.01870 +/- 0.00148
#        36/1    1.01595    1.01853 +/- 0.00140
#        37/1    1.02031    1.01864 +/- 0.00132
#        38/1    1.02077    1.01875 +/- 0.00125
#        39/1    1.01977    1.01881 +/- 0.00118
#        40/1    1.02247    1.01899 +/- 0.00113
#        41/1    1.01491    1.01880 +/- 0.00110
#        42/1    1.02271    1.01898 +/- 0.00106
#        43/1    1.03173    1.01953 +/- 0.00116
#        44/1    1.01877    1.01950 +/- 0.00111
#        45/1    1.02329    1.01965 +/- 0.00107
#        46/1    1.01956    1.01965 +/- 0.00103
#        47/1    1.01976    1.01965 +/- 0.00099
#        48/1    1.02549    1.01986 +/- 0.00098
#        49/1    1.01805    1.01980 +/- 0.00095
#        50/1    1.02044    1.01982 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 6.3627459731137925 for eigenvalue
#  The estimated number of batches is 1235
#  Creating state point statepoint.00050.h5...
#        51/1    1.02690    1.02005 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 6.15508251252833 for eigenvalue
#  The estimated number of batches is 1195
#        52/1    1.02977    1.02035 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 6.006044214870662 for eigenvalue
#  The estimated number of batches is 1175
#        53/1    1.01455    1.02017 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.8226723589011 for eigenvalue
#  The estimated number of batches is 1139
#        54/1    1.01952    1.02016 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.615826846904195 for eigenvalue
#  The estimated number of batches is 1093
#        55/1    1.02136    1.02019 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.479232189094692 for eigenvalue
#  The estimated number of batches is 1071
#        56/1    1.01407    1.02002 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.318849389398149 for eigenvalue
#  The estimated number of batches is 1039
#        57/1    1.01865    1.01998 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.275729585514756 for eigenvalue
#  The estimated number of batches is 1050
#        58/1    1.01728    1.01991 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.154608217726737 for eigenvalue
#  The estimated number of batches is 1030
#        59/1    1.02103    1.01994 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.997470906228693 for eigenvalue
#  The estimated number of batches is 995
#        60/1    1.02326    1.02002 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.909844911788971 for eigenvalue
#  The estimated number of batches is 985
#        61/1    1.02017    1.02003 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.807024515791028 for eigenvalue
#  The estimated number of batches is 968
#        62/1    1.01099    1.01981 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.692671471094393 for eigenvalue
#  The estimated number of batches is 945
#        63/1    1.02065    1.01983 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.588590134717244 for eigenvalue
#  The estimated number of batches is 926
#        64/1    1.02579    1.01997 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.476646872468605 for eigenvalue
#  The estimated number of batches is 902
#        65/1    1.02091    1.01999 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.381466861362374 for eigenvalue
#  The estimated number of batches is 884
#        66/1    1.02300    1.02005 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.377245673396961 for eigenvalue
#  The estimated number of batches is 902
#        67/1    1.02032    1.02006 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.332162574677777 for eigenvalue
#  The estimated number of batches is 903
#        68/1    1.01117    1.01987 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.605533955579112 for eigenvalue
#  The estimated number of batches is 1039
#        69/1    1.02861    1.02005 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.578898964775576 for eigenvalue
#  The estimated number of batches is 1048
#        70/1    1.02896    1.02023 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.696733587519291 for eigenvalue
#  The estimated number of batches is 1123
#        71/1    1.01649    1.02016 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.662564135735947 for eigenvalue
#  The estimated number of batches is 1129
#        72/1    1.01726    1.02010 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.648994105836229 for eigenvalue
#  The estimated number of batches is 1144
#        73/1    1.01598    1.02002 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.571945977956338 for eigenvalue
#  The estimated number of batches is 1128
#        74/1    1.01409    1.01991 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.5286907930261915 for eigenvalue
#  The estimated number of batches is 1128
#        75/1    1.01469    1.01982 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.458693084878272 for eigenvalue
#  The estimated number of batches is 1114
#        76/1    1.02075    1.01984 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.38185895297706 for eigenvalue
#  The estimated number of batches is 1096
#        77/1    1.02365    1.01990 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.3115814894249755 for eigenvalue
#  The estimated number of batches is 1080
#        78/1    1.01626    1.01984 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.231373680512704 for eigenvalue
#  The estimated number of batches is 1059
#        79/1    1.02665    1.01995 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.158156814307616 for eigenvalue
#  The estimated number of batches is 1041
#        80/1    1.02001    1.01996 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.091126677304288 for eigenvalue
#  The estimated number of batches is 1025
#        81/1    1.01507    1.01988 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.028014491562919 for eigenvalue
#  The estimated number of batches is 1010
#        82/1    1.01616    1.01982 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.981487883852694 for eigenvalue
#  The estimated number of batches is 1003
#        83/1    1.01931    1.01981 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.937714540508486 for eigenvalue
#  The estimated number of batches is 997
#        84/1    1.01877    1.01979 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.073661757868126 for eigenvalue
#  The estimated number of batches is 1083
#        85/1    1.01822    1.01977 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.003995489391762 for eigenvalue
#  The estimated number of batches is 1063
#        86/1    1.01696    1.01972 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.9492253438640574 for eigenvalue
#  The estimated number of batches is 1050
#        87/1    1.01821    1.01970 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.9756137308635915 for eigenvalue
#  The estimated number of batches is 1079
#        88/1    1.02678    1.01981 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.044959321045226 for eigenvalue
#  The estimated number of batches is 1133
#        89/1    1.01131    1.01968 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.006549572581003 for eigenvalue
#  The estimated number of batches is 1128
#        90/1    1.02358    1.01974 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.9636949121291325 for eigenvalue
#  The estimated number of batches is 1120
#        91/1    1.02532    1.01982 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.911216974906087 for eigenvalue
#  The estimated number of batches is 1107
#        92/1    1.02018    1.01982 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.864820454615912 for eigenvalue
#  The estimated number of batches is 1096
#        93/1    1.01590    1.01977 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8082882905917255 for eigenvalue
#  The estimated number of batches is 1079
#        94/1    1.00955    1.01963 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.797519185395773 for eigenvalue
#  The estimated number of batches is 1088
#        95/1    1.02363    1.01968 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7642902538454033 for eigenvalue
#  The estimated number of batches is 1083
#        96/1    1.02176    1.01971 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.715515653527612 for eigenvalue
#  The estimated number of batches is 1070
#        97/1    1.01913    1.01970 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7063709713820834 for eigenvalue
#  The estimated number of batches is 1078
#        98/1    1.02432    1.01976 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6648124508575846 for eigenvalue
#  The estimated number of batches is 1068
#        99/1    1.01505    1.01970 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.6317910825887902 for eigenvalue
#  The estimated number of batches is 1063
#       100/1    1.02309    1.01975 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.6446678846053633 for eigenvalue
#  The estimated number of batches is 1083
#       101/1    1.01570    1.01970 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.596901668193738 for eigenvalue
#  The estimated number of batches is 1068
#       102/1    1.02124    1.01971 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.7309796367579655 for eigenvalue
#  The estimated number of batches is 1162
#       103/1    1.01953    1.01971 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.6957759653279743 for eigenvalue
#  The estimated number of batches is 1154
#       104/1    1.01775    1.01969 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.651967886533716 for eigenvalue
#  The estimated number of batches is 1141
#       105/1    1.02126    1.01971 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.6146085939334816 for eigenvalue
#  The estimated number of batches is 1131
#       106/1    1.01162    1.01961 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.5727936347065032 for eigenvalue
#  The estimated number of batches is 1118
#       107/1    1.02345    1.01966 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.533992540125864 for eigenvalue
#  The estimated number of batches is 1107
#       108/1    1.01361    1.01959 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.5878679905852966 for eigenvalue
#  The estimated number of batches is 1153
#       109/1    1.02800    1.01968 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.5494606311872356 for eigenvalue
#  The estimated number of batches is 1142
#       110/1    1.01799    1.01966 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.540114800924413 for eigenvalue
#  The estimated number of batches is 1148
#       111/1    1.02319    1.01970 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.523898639249707 for eigenvalue
#  The estimated number of batches is 1151
#       112/1    1.00993    1.01960 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.5513968186340534 for eigenvalue
#  The estimated number of batches is 1181
#       113/1    1.01290    1.01953 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.52876607407584 for eigenvalue
#  The estimated number of batches is 1179
#       114/1    1.02448    1.01958 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.5073019802084406 for eigenvalue
#  The estimated number of batches is 1177
#       115/1    1.01413    1.01952 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.5026736117088624 for eigenvalue
#  The estimated number of batches is 1186
#       116/1    1.01970    1.01952 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.5266803094599184 for eigenvalue
#  The estimated number of batches is 1214
#       117/1    1.01048    1.01943 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.5222310343889154 for eigenvalue
#  The estimated number of batches is 1224
#       118/1    1.01068    1.01934 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.5464103322448803 for eigenvalue
#  The estimated number of batches is 1253
#       119/1    1.01748    1.01932 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.5222213401055993 for eigenvalue
#  The estimated number of batches is 1249
#       120/1    1.02312    1.01936 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.5054704009105473 for eigenvalue
#  The estimated number of batches is 1249
#       121/1    1.02076    1.01937 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.470794652768006 for eigenvalue
#  The estimated number of batches is 1237
#       122/1    1.01150    1.01930 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.4619180676452923 for eigenvalue
#  The estimated number of batches is 1243
#       123/1    1.01307    1.01924 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.4300909588834245 for eigenvalue
#  The estimated number of batches is 1232
#       124/1    1.00805    1.01913 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.4286345639994127 for eigenvalue
#  The estimated number of batches is 1243
#       125/1    1.01597    1.01910 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.3972656375960475 for eigenvalue
#  The estimated number of batches is 1232
#       126/1    1.01044    1.01902 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.398987604636567 for eigenvalue
#  The estimated number of batches is 1245
#       127/1    1.02388    1.01906 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.398940418878645 for eigenvalue
#  The estimated number of batches is 1257
#       128/1    1.02199    1.01909 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.3920484752778473 for eigenvalue
#  The estimated number of batches is 1263
#       129/1    1.00965    1.01900 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.4453002988600687 for eigenvalue
#  The estimated number of batches is 1314
#       130/1    1.02645    1.01907 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.425735289560964 for eigenvalue
#  The estimated number of batches is 1311
#       131/1    1.01654    1.01905 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.406743494655876 for eigenvalue
#  The estimated number of batches is 1309
#       132/1    1.01543    1.01901 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.389492170051395 for eigenvalue
#  The estimated number of batches is 1307
#       133/1    1.01621    1.01899 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.3607220660325887 for eigenvalue
#  The estimated number of batches is 1297
#       134/1    1.02906    1.01908 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.338872619492018 for eigenvalue
#  The estimated number of batches is 1291
#       135/1    1.02561    1.01913 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.3094960288276645 for eigenvalue
#  The estimated number of batches is 1280
#       136/1    1.01840    1.01913 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2821179708322745 for eigenvalue
#  The estimated number of batches is 1270
#       137/1    1.02058    1.01914 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2520134170511086 for eigenvalue
#  The estimated number of batches is 1258
#       138/1    1.01447    1.01910 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.278593996956068 for eigenvalue
#  The estimated number of batches is 1289
#       139/1    1.01393    1.01906 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.314366302027862 for eigenvalue
#  The estimated number of batches is 1328
#       140/1    1.02852    1.01914 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2846180266471565 for eigenvalue
#  The estimated number of batches is 1315
#       141/1    1.02392    1.01918 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.294791229509391 for eigenvalue
#  The estimated number of batches is 1334
#       142/1    1.01714    1.01916 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.2695975656296516 for eigenvalue
#  The estimated number of batches is 1325
#       143/1    1.02334    1.01919 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.2402946765082157 for eigenvalue
#  The estimated number of batches is 1312
#       144/1    1.02989    1.01928 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.2294846072591765 for eigenvalue
#  The estimated number of batches is 1314
#       145/1    1.01882    1.01928 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.204609020315415 for eigenvalue
#  The estimated number of batches is 1304
#       146/1    1.02536    1.01932 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.181281857873528 for eigenvalue
#  The estimated number of batches is 1296
#       147/1    1.01576    1.01930 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.237101610516122 for eigenvalue
#  The estimated number of batches is 1351
#       148/1    1.01929    1.01930 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.214540026861661 for eigenvalue
#  The estimated number of batches is 1343
#       149/1    1.00983    1.01922 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.190444799390738 for eigenvalue
#  The estimated number of batches is 1334
#       150/1    1.02932    1.01930 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.205237251422841 for eigenvalue
#  The estimated number of batches is 1356
#       151/1    1.02763    1.01936 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1834078034983255 for eigenvalue
#  The estimated number of batches is 1348
#       152/1    1.02219    1.01939 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1660356671394068 for eigenvalue
#  The estimated number of batches is 1344
#       153/1    1.00823    1.01930 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.138856169355051 for eigenvalue
#  The estimated number of batches is 1331
#       154/1    1.01463    1.01927 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.12262163991608 for eigenvalue
#  The estimated number of batches is 1327
#       155/1    1.02817    1.01933 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.116342429293353 for eigenvalue
#  The estimated number of batches is 1332
#       156/1    1.01633    1.01931 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1001821117078285 for eigenvalue
#  The estimated number of batches is 1328
#       157/1    1.00894    1.01923 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.07691575271898 for eigenvalue
#  The estimated number of batches is 1318
#       158/1    1.02924    1.01931 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.089065847743169 for eigenvalue
#  The estimated number of batches is 1337
#       159/1    1.01966    1.01931 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0685847172919045 for eigenvalue
#  The estimated number of batches is 1329
#       160/1    1.01989    1.01931 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.051048857440496 for eigenvalue
#  The estimated number of batches is 1324
#       161/1    1.01271    1.01927 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0802397829231123 for eigenvalue
#  The estimated number of batches is 1358
#       162/1    1.01565    1.01924 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0637456449213265 for eigenvalue
#  The estimated number of batches is 1353
#       163/1    1.01393    1.01920 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0455248572401605 for eigenvalue
#  The estimated number of batches is 1347
#       164/1    1.02187    1.01922 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.025487322565208 for eigenvalue
#  The estimated number of batches is 1339
#       165/1    1.02182    1.01924 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.008953056773914 for eigenvalue
#  The estimated number of batches is 1333
#       166/1    1.01694    1.01923 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.99683564910497 for eigenvalue
#  The estimated number of batches is 1332
#       167/1    1.01145    1.01917 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0098178967085087 for eigenvalue
#  The estimated number of batches is 1352
#       168/1    1.01364    1.01913 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.990254479518312 for eigenvalue
#  The estimated number of batches is 1344
#       169/1    1.02094    1.01915 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.992902311923559 for eigenvalue
#  The estimated number of batches is 1355
#       170/1    1.02133    1.01916 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9829873020052418 for eigenvalue
#  The estimated number of batches is 1355
#       171/1    1.01905    1.01916 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.962016573397559 for eigenvalue
#  The estimated number of batches is 1345
#       172/1    1.01500    1.01913 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9462591829506435 for eigenvalue
#  The estimated number of batches is 1340
#       173/1    1.01545    1.01911 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9286540000595735 for eigenvalue
#  The estimated number of batches is 1333
#       174/1    1.01680    1.01909 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.933467835060778 for eigenvalue
#  The estimated number of batches is 1346
#       175/1    1.01418    1.01906 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.91596413908425 for eigenvalue
#  The estimated number of batches is 1338
#       176/1    1.02134    1.01908 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9045008530298997 for eigenvalue
#  The estimated number of batches is 1337
#       177/1    1.02075    1.01909 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.888944168764416 for eigenvalue
#  The estimated number of batches is 1331
#       178/1    1.01457    1.01906 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8715014684577023 for eigenvalue
#  The estimated number of batches is 1323
#       179/1    1.02749    1.01911 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8977793245252963 for eigenvalue
#  The estimated number of batches is 1356
#       180/1    1.02027    1.01912 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8813144707151723 for eigenvalue
#  The estimated number of batches is 1349
#       181/1    1.03067    1.01919 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8840226398138733 for eigenvalue
#  The estimated number of batches is 1360
#       182/1    1.01271    1.01915 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8664835894266134 for eigenvalue
#  The estimated number of batches is 1352
#       183/1    1.01882    1.01915 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.853493123258377 for eigenvalue
#  The estimated number of batches is 1348
#       184/1    1.01842    1.01914 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8503062359554963 for eigenvalue
#  The estimated number of batches is 1353
#       185/1    1.01705    1.01913 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8472849186036 for eigenvalue
#  The estimated number of batches is 1358
#       186/1    1.01470    1.01911 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.833493654869344 for eigenvalue
#  The estimated number of batches is 1353
#       187/1    1.03004    1.01917 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8161249967655824 for eigenvalue
#  The estimated number of batches is 1345
#       188/1    1.02203    1.01919 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.805199292028248 for eigenvalue
#  The estimated number of batches is 1343
#       189/1    1.01770    1.01918 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7877004238789884 for eigenvalue
#  The estimated number of batches is 1334
#       190/1    1.01563    1.01916 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7726797720700924 for eigenvalue
#  The estimated number of batches is 1327
#       191/1    1.02476    1.01919 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7630724523562455 for eigenvalue
#  The estimated number of batches is 1326
#       192/1    1.01415    1.01916 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.749436426420679 for eigenvalue
#  The estimated number of batches is 1321
#       193/1    1.03227    1.01924 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.753580235887243 for eigenvalue
#  The estimated number of batches is 1332
#       194/1    1.00833    1.01917 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.830632820106685 for eigenvalue
#  The estimated number of batches is 1415
#       195/1    1.01936    1.01918 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8394580698135483 for eigenvalue
#  The estimated number of batches is 1431
#       196/1    1.01550    1.01915 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8332874845592575 for eigenvalue
#  The estimated number of batches is 1433
#       197/1    1.01013    1.01910 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.816834090790816 for eigenvalue
#  The estimated number of batches is 1425
#       198/1    1.02192    1.01912 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.805359875361799 for eigenvalue
#  The estimated number of batches is 1421
#       199/1    1.01625    1.01910 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7956630093583392 for eigenvalue
#  The estimated number of batches is 1420
#       200/1    1.00890    1.01905 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.791554647760204 for eigenvalue
#  The estimated number of batches is 1423
#       201/1    1.02166    1.01906 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7747830399762834 for eigenvalue
#  The estimated number of batches is 1414
#       202/1    1.02379    1.01909 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7592177484090588 for eigenvalue
#  The estimated number of batches is 1406
#       203/1    1.02314    1.01911 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.745817832724803 for eigenvalue
#  The estimated number of batches is 1400
#       204/1    1.01767    1.01910 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7330938523582327 for eigenvalue
#  The estimated number of batches is 1395
#       205/1    1.02041    1.01911 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7178065302139416 for eigenvalue
#  The estimated number of batches is 1387
#       206/1    1.01764    1.01910 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7046424218856258 for eigenvalue
#  The estimated number of batches is 1381
#       207/1    1.01230    1.01906 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.709171383459031 for eigenvalue
#  The estimated number of batches is 1393
#       208/1    1.02193    1.01908 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7013016256072886 for eigenvalue
#  The estimated number of batches is 1392
#       209/1    1.01173    1.01904 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.684068323996588 for eigenvalue
#  The estimated number of batches is 1382
#       210/1    1.02470    1.01907 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6882275400937843 for eigenvalue
#  The estimated number of batches is 1394
#       211/1    1.02194    1.01909 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.691896495552974 for eigenvalue
#  The estimated number of batches is 1405
#       212/1    1.01658    1.01907 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6759761656637933 for eigenvalue
#  The estimated number of batches is 1395
#       213/1    1.01808    1.01907 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.662272887916715 for eigenvalue
#  The estimated number of batches is 1388
#       214/1    1.01629    1.01905 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6489460478219957 for eigenvalue
#  The estimated number of batches is 1382
#       215/1    1.01213    1.01902 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.638978760507084 for eigenvalue
#  The estimated number of batches is 1379
#       216/1    1.03209    1.01908 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6352922806775165 for eigenvalue
#  The estimated number of batches is 1382
#       217/1    1.02130    1.01910 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.624701298228525 for eigenvalue
#  The estimated number of batches is 1378
#       218/1    1.02663    1.01913 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.61769934977446 for eigenvalue
#  The estimated number of batches is 1377
#       219/1    1.01990    1.01914 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.609882457697115 for eigenvalue
#  The estimated number of batches is 1376
#       220/1    1.02367    1.01916 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5982635679052013 for eigenvalue
#  The estimated number of batches is 1371
#       221/1    1.01463    1.01914 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5849551730499054 for eigenvalue
#  The estimated number of batches is 1364
#       222/1    1.00957    1.01909 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5964286014857243 for eigenvalue
#  The estimated number of batches is 1382
#       223/1    1.02854    1.01914 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6063229749452352 for eigenvalue
#  The estimated number of batches is 1399
#       224/1    1.01227    1.01910 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.592767375846213 for eigenvalue
#  The estimated number of batches is 1392
#       225/1    1.01887    1.01910 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5863305674240253 for eigenvalue
#  The estimated number of batches is 1392
#       226/1    1.02179    1.01912 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5849025011977282 for eigenvalue
#  The estimated number of batches is 1397
#       227/1    1.01877    1.01911 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5823107195715593 for eigenvalue
#  The estimated number of batches is 1401
#       228/1    1.01304    1.01908 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5958901167690547 for eigenvalue
#  The estimated number of batches is 1422
#       229/1    1.01492    1.01906 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5896233069208976 for eigenvalue
#  The estimated number of batches is 1422
#       230/1    1.01217    1.01903 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5881128545273686 for eigenvalue
#  The estimated number of batches is 1427
#       231/1    1.02115    1.01904 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5758728061744933 for eigenvalue
#  The estimated number of batches is 1421
#       232/1    1.01952    1.01904 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5736706470959545 for eigenvalue
#  The estimated number of batches is 1425
#       233/1    1.02517    1.01907 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.563513985742973 for eigenvalue
#  The estimated number of batches is 1420
#       234/1    1.01773    1.01907 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.568340989615692 for eigenvalue
#  The estimated number of batches is 1432
#       235/1    1.01728    1.01906 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5576578037590374 for eigenvalue
#  The estimated number of batches is 1427
#       236/1    1.01945    1.01906 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5461078022327364 for eigenvalue
#  The estimated number of batches is 1421
#       237/1    1.01550    1.01904 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5349739901521033 for eigenvalue
#  The estimated number of batches is 1415
#       238/1    1.01706    1.01903 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.523700669551914 for eigenvalue
#  The estimated number of batches is 1409
#       239/1    1.02759    1.01907 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5139995206100916 for eigenvalue
#  The estimated number of batches is 1405
#       240/1    1.01593    1.01906 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5035187287599734 for eigenvalue
#  The estimated number of batches is 1399
#       241/1    1.02239    1.01907 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4928417950501323 for eigenvalue
#  The estimated number of batches is 1394
#       242/1    1.02261    1.01909 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.481369123113314 for eigenvalue
#  The estimated number of batches is 1387
#       243/1    1.02292    1.01911 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4761746143946057 for eigenvalue
#  The estimated number of batches is 1388
#       244/1    1.01019    1.01907 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4787201975830504 for eigenvalue
#  The estimated number of batches is 1397
#       245/1    1.01511    1.01905 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5058485061448397 for eigenvalue
#  The estimated number of batches is 1433
#       246/1    1.02357    1.01907 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5067690760095687 for eigenvalue
#  The estimated number of batches is 1441
#       247/1    1.02080    1.01908 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.496083106073977 for eigenvalue
#  The estimated number of batches is 1435
#       248/1    1.00976    1.01904 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4910498775777503 for eigenvalue
#  The estimated number of batches is 1435
#       249/1    1.01133    1.01900 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4818629710844764 for eigenvalue
#  The estimated number of batches is 1431
#       250/1    1.01640    1.01899 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.473034883999656 for eigenvalue
#  The estimated number of batches is 1427
#       251/1    1.01756    1.01899 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4646482493030026 for eigenvalue
#  The estimated number of batches is 1424
#       252/1    1.02271    1.01900 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4562126303275478 for eigenvalue
#  The estimated number of batches is 1420
#       253/1    1.02058    1.01901 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4457842661147753 for eigenvalue
#  The estimated number of batches is 1414
#       254/1    1.01792    1.01900 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4372249781999002 for eigenvalue
#  The estimated number of batches is 1410
#       255/1    1.02421    1.01903 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.427279054576655 for eigenvalue
#  The estimated number of batches is 1405
#       256/1    1.02724    1.01906 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.416890808828977 for eigenvalue
#  The estimated number of batches is 1399
#       257/1    1.02013    1.01906 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4066404097732117 for eigenvalue
#  The estimated number of batches is 1393
#       258/1    1.01400    1.01904 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3965679521338448 for eigenvalue
#  The estimated number of batches is 1387
#       259/1    1.02410    1.01906 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.38666898699078 for eigenvalue
#  The estimated number of batches is 1382
#       260/1    1.02015    1.01907 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.377971251140383 for eigenvalue
#  The estimated number of batches is 1378
#       261/1    1.02586    1.01910 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.368416639127176 for eigenvalue
#  The estimated number of batches is 1372
#       262/1    1.01786    1.01909 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.362417982327717 for eigenvalue
#  The estimated number of batches is 1371
#       263/1    1.02680    1.01912 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.359509973951725 for eigenvalue
#  The estimated number of batches is 1373
#       264/1    1.03001    1.01917 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.355788524166885 for eigenvalue
#  The estimated number of batches is 1375
#       265/1    1.01192    1.01914 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.36461070093832 for eigenvalue
#  The estimated number of batches is 1390
#       266/1    1.02631    1.01917 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.359583349985088 for eigenvalue
#  The estimated number of batches is 1390
#       267/1    1.02447    1.01919 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.350499668044791 for eigenvalue
#  The estimated number of batches is 1385
#       268/1    1.01883    1.01919 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3413479140759867 for eigenvalue
#  The estimated number of batches is 1380
#       269/1    1.02890    1.01923 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3326618644591086 for eigenvalue
#  The estimated number of batches is 1375
#       270/1    1.00756    1.01918 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.323503589639486 for eigenvalue
#  The estimated number of batches is 1370
#       271/1    1.02295    1.01920 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.314744313869609 for eigenvalue
#  The estimated number of batches is 1365
#       272/1    1.01454    1.01918 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3075783416512388 for eigenvalue
#  The estimated number of batches is 1362
#       273/1    1.01678    1.01917 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2986558968699784 for eigenvalue
#  The estimated number of batches is 1357
#       274/1    1.02613    1.01920 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.290955227421408 for eigenvalue
#  The estimated number of batches is 1354
#       275/1    1.01801    1.01919 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.29021952178392 for eigenvalue
#  The estimated number of batches is 1358
#       276/1    1.01519    1.01917 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2872480229916037 for eigenvalue
#  The estimated number of batches is 1360
#       277/1    1.02837    1.01921 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.280250315019117 for eigenvalue
#  The estimated number of batches is 1357
#       278/1    1.01147    1.01918 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.273710488252083 for eigenvalue
#  The estimated number of batches is 1354
#       279/1    1.02664    1.01921 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.287147165301034 for eigenvalue
#  The estimated number of batches is 1375
#       280/1    1.02508    1.01923 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.278931758018117 for eigenvalue
#  The estimated number of batches is 1371
#       281/1    1.02357    1.01925 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2720035401118404 for eigenvalue
#  The estimated number of batches is 1368
#       282/1    1.02132    1.01926 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2637926341713808 for eigenvalue
#  The estimated number of batches is 1363
#       283/1    1.02325    1.01927 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.25617498129332 for eigenvalue
#  The estimated number of batches is 1359
#       284/1    1.02509    1.01929 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.252203597707276 for eigenvalue
#  The estimated number of batches is 1360
#       285/1    1.01324    1.01927 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2500685444033337 for eigenvalue
#  The estimated number of batches is 1362
#       286/1    1.01632    1.01926 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.241374840401893 for eigenvalue
#  The estimated number of batches is 1357
#       287/1    1.01879    1.01926 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.2330097626803527 for eigenvalue
#  The estimated number of batches is 1352
#       288/1    1.01976    1.01926 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2258267298821313 for eigenvalue
#  The estimated number of batches is 1348
#       289/1    1.02741    1.01929 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.221868223073317 for eigenvalue
#  The estimated number of batches is 1348
#       290/1    1.02516    1.01931 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.223128712246449 for eigenvalue
#  The estimated number of batches is 1355
#       291/1    1.02398    1.01933 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2177174520755396 for eigenvalue
#  The estimated number of batches is 1353
#       292/1    1.02276    1.01934 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.2147650513946475 for eigenvalue
#  The estimated number of batches is 1355
#       293/1    1.01700    1.01933 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.206571180756138 for eigenvalue
#  The estimated number of batches is 1350
#       294/1    1.01622    1.01932 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.198646476112879 for eigenvalue
#  The estimated number of batches is 1345
#       295/1    1.01291    1.01930 +/- 0.00033
# ...
#  Triggers unsatisfied, max unc./thresh. is 1.497529876097084 for eigenvalue
#  The estimated number of batches is 1386
#       630/1    1.01616    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.49527666847117 for eigenvalue
#  The estimated number of batches is 1384
#       631/1    1.02183    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4928226358452306 for eigenvalue
#  The estimated number of batches is 1382
#       632/1    1.02010    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.490661755640097 for eigenvalue
#  The estimated number of batches is 1380
#       633/1    1.02166    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4894341114337453 for eigenvalue
#  The estimated number of batches is 1380
#       634/1    1.01521    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4883152500021428 for eigenvalue
#  The estimated number of batches is 1381
#       635/1    1.02142    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4861654908564503 for eigenvalue
#  The estimated number of batches is 1379
#       636/1    1.01776    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4842071370668208 for eigenvalue
#  The estimated number of batches is 1377
#       637/1    1.02200    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.48205339216228 for eigenvalue
#  The estimated number of batches is 1376
#       638/1    1.02305    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4864878183314272 for eigenvalue
#  The estimated number of batches is 1386
#       639/1    1.02042    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4848831144731445 for eigenvalue
#  The estimated number of batches is 1385
#       640/1    1.02306    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4830590072800078 for eigenvalue
#  The estimated number of batches is 1384
#       641/1    1.02397    1.01930 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4810332071305663 for eigenvalue
#  The estimated number of batches is 1383
#       642/1    1.01806    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.479567074087434 for eigenvalue
#  The estimated number of batches is 1382
#       643/1    1.01163    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.477009241021084 for eigenvalue
#  The estimated number of batches is 1380
#       644/1    1.02001    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.474636533352735 for eigenvalue
#  The estimated number of batches is 1377
#       645/1    1.01886    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4723241875290745 for eigenvalue
#  The estimated number of batches is 1375
#       646/1    1.02219    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.471479596263517 for eigenvalue
#  The estimated number of batches is 1376
#       647/1    1.01766    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.469968060383874 for eigenvalue
#  The estimated number of batches is 1375
#       648/1    1.01880    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4676252935777279 for eigenvalue
#  The estimated number of batches is 1373
#       649/1    1.01432    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4651491925666833 for eigenvalue
#  The estimated number of batches is 1371
#       650/1    1.02659    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4666946063150172 for eigenvalue
#  The estimated number of batches is 1376
#       651/1    1.01643    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4653155034815157 for eigenvalue
#  The estimated number of batches is 1375
#       652/1    1.01907    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4631327773856218 for eigenvalue
#  The estimated number of batches is 1373
#       653/1    1.01230    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4666605553224736 for eigenvalue
#  The estimated number of batches is 1382
#       654/1    1.01984    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4649541572335711 for eigenvalue
#  The estimated number of batches is 1381
#       655/1    1.02005    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4634953224801526 for eigenvalue
#  The estimated number of batches is 1381
#       656/1    1.02358    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4653952621343846 for eigenvalue
#  The estimated number of batches is 1386
#       657/1    1.01031    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4681354085583949 for eigenvalue
#  The estimated number of batches is 1394
#       658/1    1.02125    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4659885644150268 for eigenvalue
#  The estimated number of batches is 1392
#       659/1    1.02813    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4643386507130356 for eigenvalue
#  The estimated number of batches is 1391
#       660/1    1.01153    1.01927 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.46476444389186 for eigenvalue
#  The estimated number of batches is 1394
#       661/1    1.03029    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4642635710818683 for eigenvalue
#  The estimated number of batches is 1395
#       662/1    1.02184    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4629849245417088 for eigenvalue
#  The estimated number of batches is 1395
#       663/1    1.01948    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.461032111655558 for eigenvalue
#  The estimated number of batches is 1393
#       664/1    1.01999    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.460090003303081 for eigenvalue
#  The estimated number of batches is 1393
#       665/1    1.01811    1.01929 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4577108809387533 for eigenvalue
#  The estimated number of batches is 1391
#       666/1    1.01039    1.01928 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4562387220787008 for eigenvalue
#  The estimated number of batches is 1390
#       667/1    1.02038    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4543563152185983 for eigenvalue
#  The estimated number of batches is 1389
#       668/1    1.02809    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4526658616293047 for eigenvalue
#  The estimated number of batches is 1388
#       669/1    1.01505    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.452793293323293 for eigenvalue
#  The estimated number of batches is 1390
#       670/1    1.01631    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4505355618263536 for eigenvalue
#  The estimated number of batches is 1388
#       671/1    1.01774    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4484424516145258 for eigenvalue
#  The estimated number of batches is 1386
#       672/1    1.01987    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4483901820125462 for eigenvalue
#  The estimated number of batches is 1388
#       673/1    1.02289    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.44645354684222 for eigenvalue
#  The estimated number of batches is 1387
#       674/1    1.01260    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4439869365126845 for eigenvalue
#  The estimated number of batches is 1384
#       675/1    1.01662    1.01927 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4437680410563376 for eigenvalue
#  The estimated number of batches is 1386
#       676/1    1.01995    1.01927 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4421043916188572 for eigenvalue
#  The estimated number of batches is 1385
#       677/1    1.02238    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4406132501407165 for eigenvalue
#  The estimated number of batches is 1384
#       678/1    1.02342    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4416035066411448 for eigenvalue
#  The estimated number of batches is 1388
#       679/1    1.03073    1.01930 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4498562712384475 for eigenvalue
#  The estimated number of batches is 1406
#       680/1    1.01060    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4481926416823425 for eigenvalue
#  The estimated number of batches is 1405
#       681/1    1.02162    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.446635107611901 for eigenvalue
#  The estimated number of batches is 1404
#       682/1    1.01812    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.447880003847286 for eigenvalue
#  The estimated number of batches is 1408
#       683/1    1.01821    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4456340154936758 for eigenvalue
#  The estimated number of batches is 1406
#       684/1    1.01744    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.444709494811156 for eigenvalue
#  The estimated number of batches is 1406
#       685/1    1.02252    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4433031400003598 for eigenvalue
#  The estimated number of batches is 1406
#       686/1    1.02209    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4433274743459528 for eigenvalue
#  The estimated number of batches is 1408
#       687/1    1.01627    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4412958695064513 for eigenvalue
#  The estimated number of batches is 1406
#       688/1    1.01644    1.01929 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.439093872698398 for eigenvalue
#  The estimated number of batches is 1404
#       689/1    1.01772    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.438335638294488 for eigenvalue
#  The estimated number of batches is 1405
#       690/1    1.01895    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4369826716408174 for eigenvalue
#  The estimated number of batches is 1404
#       691/1    1.01440    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.435170670168929 for eigenvalue
#  The estimated number of batches is 1403
#       692/1    1.02471    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4335609173446107 for eigenvalue
#  The estimated number of batches is 1402
#       693/1    1.01525    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4313920507933284 for eigenvalue
#  The estimated number of batches is 1399
#       694/1    1.01913    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4292571065571973 for eigenvalue
#  The estimated number of batches is 1397
#       695/1    1.01971    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4287674152798477 for eigenvalue
#  The estimated number of batches is 1398
#       696/1    1.01626    1.01927 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4267343291514476 for eigenvalue
#  The estimated number of batches is 1397
#       697/1    1.02477    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4247307676883654 for eigenvalue
#  The estimated number of batches is 1395
#       698/1    1.01494    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4225565648702154 for eigenvalue
#  The estimated number of batches is 1393
#       699/1    1.01450    1.01927 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4221719387044194 for eigenvalue
#  The estimated number of batches is 1394
#       700/1    1.01885    1.01927 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4200142758218766 for eigenvalue
#  The estimated number of batches is 1392
#       701/1    1.02665    1.01928 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4200288702174948 for eigenvalue
#  The estimated number of batches is 1394
#       702/1    1.00607    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4224169515487968 for eigenvalue
#  The estimated number of batches is 1400
#       703/1    1.01901    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4203314384807717 for eigenvalue
#  The estimated number of batches is 1398
#       704/1    1.01853    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.418281972213541 for eigenvalue
#  The estimated number of batches is 1396
#       705/1    1.02148    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4162636434545386 for eigenvalue
#  The estimated number of batches is 1394
#       706/1    1.01969    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.414199728979857 for eigenvalue
#  The estimated number of batches is 1392
#       707/1    1.01916    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4123099279571456 for eigenvalue
#  The estimated number of batches is 1391
#       708/1    1.02263    1.01927 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4104898446820469 for eigenvalue
#  The estimated number of batches is 1389
#       709/1    1.01678    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4085950516512409 for eigenvalue
#  The estimated number of batches is 1388
#       710/1    1.01548    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4070006508900743 for eigenvalue
#  The estimated number of batches is 1386
#       711/1    1.02416    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4068037988936408 for eigenvalue
#  The estimated number of batches is 1388
#       712/1    1.01552    1.01926 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4095919538041801 for eigenvalue
#  The estimated number of batches is 1395
#       713/1    1.01463    1.01925 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4075053775280864 for eigenvalue
#  The estimated number of batches is 1393
#       714/1    1.01526    1.01925 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.407453374464628 for eigenvalue
#  The estimated number of batches is 1395
#       715/1    1.01599    1.01924 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4066876590660917 for eigenvalue
#  The estimated number of batches is 1396
#       716/1    1.01931    1.01924 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4046334252097488 for eigenvalue
#  The estimated number of batches is 1394
#       717/1    1.01133    1.01923 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4058409019019 for eigenvalue
#  The estimated number of batches is 1398
#       718/1    1.00366    1.01921 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4064936653186713 for eigenvalue
#  The estimated number of batches is 1401
#       719/1    1.01742    1.01921 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.404530344502662 for eigenvalue
#  The estimated number of batches is 1399
#       720/1    1.02373    1.01921 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4056117960059191 for eigenvalue
#  The estimated number of batches is 1404
#       721/1    1.01311    1.01920 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.403534919310716 for eigenvalue
#  The estimated number of batches is 1401
#       722/1    1.02070    1.01921 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4015998615893144 for eigenvalue
#  The estimated number of batches is 1400
#       723/1    1.01656    1.01920 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4012722964997186 for eigenvalue
#  The estimated number of batches is 1401
#       724/1    1.02632    1.01921 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4001293192026318 for eigenvalue
#  The estimated number of batches is 1401
#       725/1    1.01374    1.01920 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3980495750267614 for eigenvalue
#  The estimated number of batches is 1398
#       726/1    1.01918    1.01920 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3976856371170594 for eigenvalue
#  The estimated number of batches is 1400
