# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]


PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %% [markdown]
# ### Define assembly

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family 
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0] 
            
            
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:25
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.96489
#         2/1    0.97424
#         3/1    0.96439
#         4/1    0.97774
#         5/1    0.98172
#         6/1    0.96343
#         7/1    0.97283
#         8/1    0.97495
#         9/1    0.97881
#        10/1    0.97289
#        11/1    0.97942
#        12/1    0.96334
#        13/1    0.97536
#        14/1    0.97458
#        15/1    0.97091
#        16/1    0.96808
#        17/1    0.97052
#        18/1    0.96377
#        19/1    0.97593
#        20/1    0.96183
#        21/1    0.97247
#        22/1    0.97981    0.97614 +/- 0.00367
#        23/1    0.97816    0.97681 +/- 0.00222
#        24/1    0.97582    0.97657 +/- 0.00159
#        25/1    0.97198    0.97565 +/- 0.00154
#        26/1    0.97381    0.97534 +/- 0.00129
#        27/1    0.97855    0.97580 +/- 0.00118
#        28/1    0.97167    0.97528 +/- 0.00115
#        29/1    0.96675    0.97433 +/- 0.00139
#        30/1    0.97836    0.97474 +/- 0.00130
#        31/1    0.96846    0.97417 +/- 0.00131
#        32/1    0.97417    0.97417 +/- 0.00120
#        33/1    0.96801    0.97369 +/- 0.00120
#        34/1    0.97724    0.97395 +/- 0.00114
#        35/1    0.96583    0.97341 +/- 0.00119
#        36/1    0.98438    0.97409 +/- 0.00131
#        37/1    0.97298    0.97403 +/- 0.00123
#        38/1    0.97222    0.97393 +/- 0.00116
#        39/1    0.96942    0.97369 +/- 0.00113
#        40/1    0.97154    0.97358 +/- 0.00107
#        41/1    0.97149    0.97348 +/- 0.00103
#        42/1    0.96971    0.97331 +/- 0.00099
#        43/1    0.97811    0.97352 +/- 0.00097
#        44/1    0.96938    0.97335 +/- 0.00095
#        45/1    0.97734    0.97351 +/- 0.00092
#        46/1    0.97613    0.97361 +/- 0.00089
#        47/1    0.96697    0.97336 +/- 0.00089
#        48/1    0.96613    0.97310 +/- 0.00090
#        49/1    0.97911    0.97331 +/- 0.00089
#        50/1    0.97783    0.97346 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 7.378178157368897 for eigenvalue
#  The estimated number of batches is 1654
#  Creating state point statepoint.00050.h5...
#        51/1    0.97073    0.97337 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 7.169931971776299 for eigenvalue
#  The estimated number of batches is 1614
#        52/1    0.97182    0.97332 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 6.957316940712399 for eigenvalue
#  The estimated number of batches is 1569
#        53/1    0.97760    0.97345 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 6.90157216622686 for eigenvalue
#  The estimated number of batches is 1592
#        54/1    0.97713    0.97356 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 6.801894876045924 for eigenvalue
#  The estimated number of batches is 1594
#        55/1    0.97494    0.97360 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 6.6947980437597225 for eigenvalue
#  The estimated number of batches is 1589
#        56/1    0.97577    0.97366 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 6.560995233750902 for eigenvalue
#  The estimated number of batches is 1570
#        57/1    0.96194    0.97335 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.375418081820528 for eigenvalue
#  The estimated number of batches is 1524
#        58/1    0.96789    0.97320 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 6.147376774157605 for eigenvalue
#  The estimated number of batches is 1457
#        59/1    0.96317    0.97294 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 6.282311072501143 for eigenvalue
#  The estimated number of batches is 1560
#        60/1    0.97084    0.97289 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 6.163630571300593 for eigenvalue
#  The estimated number of batches is 1540
#        61/1    0.97782    0.97301 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 6.092600890420634 for eigenvalue
#  The estimated number of batches is 1542
#        62/1    0.96978    0.97294 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.976597631506055 for eigenvalue
#  The estimated number of batches is 1521
#        63/1    0.97406    0.97296 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.856033202742811 for eigenvalue
#  The estimated number of batches is 1495
#        64/1    0.98110    0.97315 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 6.258984256280921 for eigenvalue
#  The estimated number of batches is 1744
#        65/1    0.96878    0.97305 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 6.078359456375907 for eigenvalue
#  The estimated number of batches is 1683
#        66/1    0.97950    0.97319 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 6.197401200023531 for eigenvalue
#  The estimated number of batches is 1787
#        67/1    0.97029    0.97313 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.9944383925948745 for eigenvalue
#  The estimated number of batches is 1709
#        68/1    0.97233    0.97311 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.9573492651491025 for eigenvalue
#  The estimated number of batches is 1724
#        69/1    0.97285    0.97311 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.920832770361914 for eigenvalue
#  The estimated number of batches is 1738
#        70/1    0.97378    0.97312 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.857944927538702 for eigenvalue
#  The estimated number of batches is 1736
#        71/1    0.97290    0.97311 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.939049167965745 for eigenvalue
#  The estimated number of batches is 1819
#        72/1    0.96680    0.97299 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 6.0640407954699835 for eigenvalue
#  The estimated number of batches is 1933
#        73/1    0.97788    0.97309 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 6.063348130905757 for eigenvalue
#  The estimated number of batches is 1969
#        74/1    0.97433    0.97311 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.962458860667281 for eigenvalue
#  The estimated number of batches is 1940
#        75/1    0.97400    0.97312 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.866183147617654 for eigenvalue
#  The estimated number of batches is 1913
#        76/1    0.97659    0.97319 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 5.799679219158321 for eigenvalue
#  The estimated number of batches is 1904
#        77/1    0.97298    0.97318 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.784350376503876 for eigenvalue
#  The estimated number of batches is 1928
#        78/1    0.97093    0.97314 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 5.629383672486812 for eigenvalue
#  The estimated number of batches is 1859
#        79/1    0.97197    0.97312 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 5.5502559149869715 for eigenvalue
#  The estimated number of batches is 1838
#        80/1    0.96749    0.97303 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 5.423841560999526 for eigenvalue
#  The estimated number of batches is 1786
#        81/1    0.97336    0.97304 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 5.33959688234565 for eigenvalue
#  The estimated number of batches is 1760
#        82/1    0.97274    0.97303 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 5.3565466046521655 for eigenvalue
#  The estimated number of batches is 1799
#        83/1    0.96408    0.97289 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 5.187682089060896 for eigenvalue
#  The estimated number of batches is 1716
#        84/1    0.96768    0.97281 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 5.067009152958687 for eigenvalue
#  The estimated number of batches is 1664
#        85/1    0.96971    0.97276 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 5.026387072848907 for eigenvalue
#  The estimated number of batches is 1663
#        86/1    0.98187    0.97290 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 5.065380492466574 for eigenvalue
#  The estimated number of batches is 1714
#        87/1    0.96986    0.97285 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.948261893616002 for eigenvalue
#  The estimated number of batches is 1661
#        88/1    0.96909    0.97280 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.858470806876214 for eigenvalue
#  The estimated number of batches is 1626
#        89/1    0.97318    0.97280 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.800077481533709 for eigenvalue
#  The estimated number of batches is 1610
#        90/1    0.97535    0.97284 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.7518397093696185 for eigenvalue
#  The estimated number of batches is 1601
#        91/1    0.97221    0.97283 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.683548309551244 for eigenvalue
#  The estimated number of batches is 1578
#        92/1    0.96081    0.97266 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.64601349154787 for eigenvalue
#  The estimated number of batches is 1575
#        93/1    0.96729    0.97259 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.594460979991041 for eigenvalue
#  The estimated number of batches is 1561
#        94/1    0.96628    0.97250 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.525716379923695 for eigenvalue
#  The estimated number of batches is 1536
#        95/1    0.96920    0.97246 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.439181718336303 for eigenvalue
#  The estimated number of batches is 1498
#        96/1    0.97454    0.97249 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.422660979946462 for eigenvalue
#  The estimated number of batches is 1507
#        97/1    0.97218    0.97248 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.367410976207811 for eigenvalue
#  The estimated number of batches is 1489
#        98/1    0.97207    0.97248 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.304977478131673 for eigenvalue
#  The estimated number of batches is 1466
#        99/1    0.97819    0.97255 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.277167420698937 for eigenvalue
#  The estimated number of batches is 1466
#       100/1    0.97139    0.97254 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.221835680881534 for eigenvalue
#  The estimated number of batches is 1446
#       101/1    0.97167    0.97253 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.164544588667237 for eigenvalue
#  The estimated number of batches is 1425
#       102/1    0.96821    0.97247 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.16121310856541 for eigenvalue
#  The estimated number of batches is 1440
#       103/1    0.96352    0.97236 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.171061358402587 for eigenvalue
#  The estimated number of batches is 1465
#       104/1    0.96356    0.97226 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.135794954438262 for eigenvalue
#  The estimated number of batches is 1457
#       105/1    0.97628    0.97231 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.104098945323513 for eigenvalue
#  The estimated number of batches is 1452
#       106/1    0.97405    0.97233 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 4.053952472017288 for eigenvalue
#  The estimated number of batches is 1434
#       107/1    0.97300    0.97234 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 4.012679221087643 for eigenvalue
#  The estimated number of batches is 1421
#       108/1    0.96945    0.97230 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.951667863152338 for eigenvalue
#  The estimated number of batches is 1395
#       109/1    0.97513    0.97233 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.920362810055559 for eigenvalue
#  The estimated number of batches is 1388
#       110/1    0.96805    0.97229 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.8716207845532433 for eigenvalue
#  The estimated number of batches is 1370
#       111/1    0.97377    0.97230 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.832969967922803 for eigenvalue
#  The estimated number of batches is 1357
#       112/1    0.97974    0.97238 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.8247348639120013 for eigenvalue
#  The estimated number of batches is 1366
#       113/1    0.97666    0.97243 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.8380419373927994 for eigenvalue
#  The estimated number of batches is 1390
#       114/1    0.97176    0.97242 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.7950385598504752 for eigenvalue
#  The estimated number of batches is 1374
#       115/1    0.97419    0.97244 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.7860968730624425 for eigenvalue
#  The estimated number of batches is 1382
#       116/1    0.97704    0.97249 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.7928369220608444 for eigenvalue
#  The estimated number of batches is 1402
#       117/1    0.96718    0.97243 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.7452227327596286 for eigenvalue
#  The estimated number of batches is 1381
#       118/1    0.96595    0.97237 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.6991844113732797 for eigenvalue
#  The estimated number of batches is 1362
#       119/1    0.97485    0.97239 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.6672222217080415 for eigenvalue
#  The estimated number of batches is 1352
#       120/1    0.97117    0.97238 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.6281812919418117 for eigenvalue
#  The estimated number of batches is 1337
#       121/1    0.96709    0.97233 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.579952149225156 for eigenvalue
#  The estimated number of batches is 1315
#       122/1    0.97884    0.97239 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.576194516955773 for eigenvalue
#  The estimated number of batches is 1325
#       123/1    0.96727    0.97234 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.5484481104621985 for eigenvalue
#  The estimated number of batches is 1317
#       124/1    0.97099    0.97233 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.513816860088703 for eigenvalue
#  The estimated number of batches is 1305
#       125/1    0.97250    0.97233 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.498290786107204 for eigenvalue
#  The estimated number of batches is 1305
#       126/1    0.96833    0.97229 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.4588674112094666 for eigenvalue
#  The estimated number of batches is 1289
#       127/1    0.97152    0.97229 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.4263624565419484 for eigenvalue
#  The estimated number of batches is 1277
#       128/1    0.96668    0.97223 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.415134835545254 for eigenvalue
#  The estimated number of batches is 1280
#       129/1    0.96931    0.97221 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3877141717698067 for eigenvalue
#  The estimated number of batches is 1271
#       130/1    0.97350    0.97222 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.364748881877313 for eigenvalue
#  The estimated number of batches is 1266
#       131/1    0.96400    0.97215 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3261978096428946 for eigenvalue
#  The estimated number of batches is 1249
#       132/1    0.96450    0.97208 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.323336402388185 for eigenvalue
#  The estimated number of batches is 1257
#       133/1    0.97464    0.97210 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2949434366276047 for eigenvalue
#  The estimated number of batches is 1247
#       134/1    0.96802    0.97206 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.267375406909338 for eigenvalue
#  The estimated number of batches is 1238
#       135/1    0.97218    0.97207 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2667573180217153 for eigenvalue
#  The estimated number of batches is 1248
#       136/1    0.96992    0.97205 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.243237936880455 for eigenvalue
#  The estimated number of batches is 1241
#       137/1    0.97241    0.97205 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2129872620261386 for eigenvalue
#  The estimated number of batches is 1228
#       138/1    0.97231    0.97205 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.214974137451316 for eigenvalue
#  The estimated number of batches is 1240
#       139/1    0.96442    0.97199 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.232140101633485 for eigenvalue
#  The estimated number of batches is 1264
#       140/1    0.97594    0.97202 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.21267021168952 for eigenvalue
#  The estimated number of batches is 1259
#       141/1    0.97019    0.97201 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.205365860110382 for eigenvalue
#  The estimated number of batches is 1264
#       142/1    0.97328    0.97202 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1816813453402033 for eigenvalue
#  The estimated number of batches is 1256
#       143/1    0.98085    0.97209 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.17673773320346 for eigenvalue
#  The estimated number of batches is 1262
#       144/1    0.96964    0.97207 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1465656808922295 for eigenvalue
#  The estimated number of batches is 1248
#       145/1    0.97228    0.97207 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.126544753514176 for eigenvalue
#  The estimated number of batches is 1242
#       146/1    0.98018    0.97213 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.190983637239922 for eigenvalue
#  The estimated number of batches is 1303
#       147/1    0.97880    0.97219 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.178508530503706 for eigenvalue
#  The estimated number of batches is 1304
#       148/1    0.96427    0.97212 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1637136688283114 for eigenvalue
#  The estimated number of batches is 1302
#       149/1    0.97439    0.97214 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1395284996966737 for eigenvalue
#  The estimated number of batches is 1292
#       150/1    0.97471    0.97216 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1258203464108476 for eigenvalue
#  The estimated number of batches is 1291
#       151/1    0.97094    0.97215 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.114709097793677 for eigenvalue
#  The estimated number of batches is 1291
#       152/1    0.97816    0.97220 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1010583974197314 for eigenvalue
#  The estimated number of batches is 1290
#       153/1    0.96626    0.97215 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.106071322893606 for eigenvalue
#  The estimated number of batches is 1304
#       154/1    0.97328    0.97216 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.088365911433409 for eigenvalue
#  The estimated number of batches is 1299
#       155/1    0.96066    0.97208 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0918614707804504 for eigenvalue
#  The estimated number of batches is 1311
#       156/1    0.97758    0.97212 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0878489489837935 for eigenvalue
#  The estimated number of batches is 1317
#       157/1    0.97556    0.97214 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0715096283739585 for eigenvalue
#  The estimated number of batches is 1313
#       158/1    0.97494    0.97216 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.052015297200131 for eigenvalue
#  The estimated number of batches is 1306
#       159/1    0.96937    0.97214 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.046837265831173 for eigenvalue
#  The estimated number of batches is 1311
#       160/1    0.97378    0.97215 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.047118728859294 for eigenvalue
#  The estimated number of batches is 1320
#       161/1    0.98022    0.97221 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0490926263333873 for eigenvalue
#  The estimated number of batches is 1331
#       162/1    0.97987    0.97227 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0471413347287646 for eigenvalue
#  The estimated number of batches is 1339
#       163/1    0.97462    0.97228 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0287085042538227 for eigenvalue
#  The estimated number of batches is 1332
#       164/1    0.98014    0.97234 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0198057132833442 for eigenvalue
#  The estimated number of batches is 1334
#       165/1    0.97580    0.97236 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.005031990620014 for eigenvalue
#  The estimated number of batches is 1330
#       166/1    0.97231    0.97236 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.981393171012664 for eigenvalue
#  The estimated number of batches is 1318
#       167/1    0.97213    0.97236 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9604764964761814 for eigenvalue
#  The estimated number of batches is 1309
#       168/1    0.96897    0.97234 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9385247831873484 for eigenvalue
#  The estimated number of batches is 1298
#       169/1    0.97701    0.97237 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9426608637567147 for eigenvalue
#  The estimated number of batches is 1311
#       170/1    0.97201    0.97236 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.9241045728620096 for eigenvalue
#  The estimated number of batches is 1303
#       171/1    0.97505    0.97238 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.905904886701735 for eigenvalue
#  The estimated number of batches is 1296
#       172/1    0.97132    0.97238 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8965263057597133 for eigenvalue
#  The estimated number of batches is 1296
#       173/1    0.96445    0.97232 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.921593242277379 for eigenvalue
#  The estimated number of batches is 1326
#       174/1    0.98229    0.97239 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.919302538060332 for eigenvalue
#  The estimated number of batches is 1333
#       175/1    0.97115    0.97238 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.898850463011876 for eigenvalue
#  The estimated number of batches is 1323
#       176/1    0.96304    0.97232 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.891601968454246 for eigenvalue
#  The estimated number of batches is 1325
#       177/1    0.97222    0.97232 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8733003704368167 for eigenvalue
#  The estimated number of batches is 1317
#       178/1    0.97231    0.97232 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.855285984970737 for eigenvalue
#  The estimated number of batches is 1309
#       179/1    0.98110    0.97238 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8609614869056026 for eigenvalue
#  The estimated number of batches is 1322
#       180/1    0.97915    0.97242 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.852987096408159 for eigenvalue
#  The estimated number of batches is 1323
#       181/1    0.96297    0.97236 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8873777131711496 for eigenvalue
#  The estimated number of batches is 1363
#       182/1    0.98079    0.97241 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.877209094840382 for eigenvalue
#  The estimated number of batches is 1362
#       183/1    0.97371    0.97242 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8609946512502065 for eigenvalue
#  The estimated number of batches is 1355
#       184/1    0.97138    0.97241 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.843095840172795 for eigenvalue
#  The estimated number of batches is 1346
#       185/1    0.97465    0.97243 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.828112175588779 for eigenvalue
#  The estimated number of batches is 1340
#       186/1    0.97571    0.97245 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8135607039975787 for eigenvalue
#  The estimated number of batches is 1335
#       187/1    0.96391    0.97239 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.808449437873291 for eigenvalue
#  The estimated number of batches is 1338
#       188/1    0.97569    0.97241 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8217571176851517 for eigenvalue
#  The estimated number of batches is 1358
#       189/1    0.96806    0.97239 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8146014490498263 for eigenvalue
#  The estimated number of batches is 1359
#       190/1    0.97132    0.97238 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.7971148602964964 for eigenvalue
#  The estimated number of batches is 1351
#       191/1    0.97946    0.97242 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.7909167931069763 for eigenvalue
#  The estimated number of batches is 1352
#       192/1    0.97758    0.97245 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.7804905141083025 for eigenvalue
#  The estimated number of batches is 1350
#       193/1    0.96775    0.97243 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.761948587254381 for eigenvalue
#  The estimated number of batches is 1340
#       194/1    0.96606    0.97239 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.7470039410687397 for eigenvalue
#  The estimated number of batches is 1334
#       195/1    0.96982    0.97238 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.7287009527900583 for eigenvalue
#  The estimated number of batches is 1324
#       196/1    0.97456    0.97239 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.7154180498415186 for eigenvalue
#  The estimated number of batches is 1318
#       197/1    0.97202    0.97239 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6997898802510134 for eigenvalue
#  The estimated number of batches is 1311
#       198/1    0.96964    0.97237 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.685365798603214 for eigenvalue
#  The estimated number of batches is 1304
#       199/1    0.95931    0.97230 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.672223729361065 for eigenvalue
#  The estimated number of batches is 1299
#       200/1    0.96656    0.97227 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.657106341810647 for eigenvalue
#  The estimated number of batches is 1291
#       201/1    0.97079    0.97226 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.640992229734689 for eigenvalue
#  The estimated number of batches is 1283
#       202/1    0.96987    0.97224 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.635781089865473 for eigenvalue
#  The estimated number of batches is 1285
#       203/1    0.98187    0.97230 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6524747236514212 for eigenvalue
#  The estimated number of batches is 1308
#       204/1    0.97095    0.97229 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6373651137261622 for eigenvalue
#  The estimated number of batches is 1300
#       205/1    0.96278    0.97224 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.650303928571197 for eigenvalue
#  The estimated number of batches is 1320
#       206/1    0.97782    0.97227 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.642045038652016 for eigenvalue
#  The estimated number of batches is 1319
#       207/1    0.97595    0.97229 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.629344039487221 for eigenvalue
#  The estimated number of batches is 1313
#       208/1    0.97516    0.97230 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6173066561009146 for eigenvalue
#  The estimated number of batches is 1308
#       209/1    0.96813    0.97228 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.603186138485044 for eigenvalue
#  The estimated number of batches is 1301
#       210/1    0.97135    0.97228 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.590877818225389 for eigenvalue
#  The estimated number of batches is 1296
#       211/1    0.97136    0.97227 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5929142033335846 for eigenvalue
#  The estimated number of batches is 1305
#       212/1    0.97358    0.97228 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5806212223313105 for eigenvalue
#  The estimated number of batches is 1299
#       213/1    0.97659    0.97230 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5741844780888017 for eigenvalue
#  The estimated number of batches is 1299
#       214/1    0.96380    0.97226 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5571579791008046 for eigenvalue
#  The estimated number of batches is 1289
#       215/1    0.96378    0.97221 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.557391110504026 for eigenvalue
#  The estimated number of batches is 1296
#       216/1    0.98097    0.97226 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.550137555500811 for eigenvalue
#  The estimated number of batches is 1295
#       217/1    0.96525    0.97222 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5738942790748287 for eigenvalue
#  The estimated number of batches is 1326
#       218/1    0.97458    0.97223 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.562251734708224 for eigenvalue
#  The estimated number of batches is 1320
#       219/1    0.97979    0.97227 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.567617821713193 for eigenvalue
#  The estimated number of batches is 1332
#       220/1    0.96904    0.97226 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.557906996582585 for eigenvalue
#  The estimated number of batches is 1329
#       221/1    0.97338    0.97226 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.546577909448721 for eigenvalue
#  The estimated number of batches is 1324
#       222/1    0.97079    0.97225 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.536095176662113 for eigenvalue
#  The estimated number of batches is 1320
#       223/1    0.97475    0.97227 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5252209492080584 for eigenvalue
#  The estimated number of batches is 1315
#       224/1    0.97534    0.97228 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5189429934235585 for eigenvalue
#  The estimated number of batches is 1315
#       225/1    0.97373    0.97229 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.507970856514786 for eigenvalue
#  The estimated number of batches is 1310
#       226/1    0.97704    0.97231 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.505340150348193 for eigenvalue
#  The estimated number of batches is 1314
#       227/1    0.97046    0.97230 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4924489963123673 for eigenvalue
#  The estimated number of batches is 1306
#       228/1    0.97817    0.97233 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.510065473515138 for eigenvalue
#  The estimated number of batches is 1331
#       229/1    0.97269    0.97233 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5022755833048596 for eigenvalue
#  The estimated number of batches is 1329
#       230/1    0.96691    0.97231 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.496054884644354 for eigenvalue
#  The estimated number of batches is 1329
#       231/1    0.97053    0.97230 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4836960217009043 for eigenvalue
#  The estimated number of batches is 1322
#       232/1    0.97639    0.97232 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.475267974956842 for eigenvalue
#  The estimated number of batches is 1319
#       233/1    0.97404    0.97233 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4642259853960033 for eigenvalue
#  The estimated number of batches is 1314
#       234/1    0.96532    0.97229 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4582019283211096 for eigenvalue
#  The estimated number of batches is 1314
#       235/1    0.97091    0.97229 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.449250226100998 for eigenvalue
#  The estimated number of batches is 1310
#       236/1    0.97246    0.97229 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.45639344577708 for eigenvalue
#  The estimated number of batches is 1324
#       237/1    0.97360    0.97229 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.44776547260637 for eigenvalue
#  The estimated number of batches is 1321
#       238/1    0.97231    0.97229 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.446195343502531 for eigenvalue
#  The estimated number of batches is 1325
#       239/1    0.97058    0.97229 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.433287538008681 for eigenvalue
#  The estimated number of batches is 1317
#       240/1    0.97081    0.97228 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.42196613999593 for eigenvalue
#  The estimated number of batches is 1311
#       241/1    0.97557    0.97229 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4131849370070366 for eigenvalue
#  The estimated number of batches is 1307
#       242/1    0.98455    0.97235 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4291648443312357 for eigenvalue
#  The estimated number of batches is 1330
#       243/1    0.96619    0.97232 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.420606332669996 for eigenvalue
#  The estimated number of batches is 1327
#       244/1    0.97194    0.97232 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.413132048569119 for eigenvalue
#  The estimated number of batches is 1325
#       245/1    0.97309    0.97232 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.405899738085614 for eigenvalue
#  The estimated number of batches is 1323
#       246/1    0.97117    0.97232 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.403317310282035 for eigenvalue
#  The estimated number of batches is 1326
#       247/1    0.96854    0.97230 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3926758571282205 for eigenvalue
#  The estimated number of batches is 1320
#       248/1    0.98205    0.97234 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4196830644370086 for eigenvalue
#  The estimated number of batches is 1355
#       249/1    0.97672    0.97236 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.42205283772182 for eigenvalue
#  The estimated number of batches is 1364
#       250/1    0.97301    0.97237 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4151779285962007 for eigenvalue
#  The estimated number of batches is 1362
#       251/1    0.97184    0.97236 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.409660905552148 for eigenvalue
#  The estimated number of batches is 1362
#       252/1    0.96224    0.97232 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.406732815439263 for eigenvalue
#  The estimated number of batches is 1364
#       253/1    0.96522    0.97229 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.409768551115078 for eigenvalue
#  The estimated number of batches is 1374
#       254/1    0.97066    0.97228 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3983268838500473 for eigenvalue
#  The estimated number of batches is 1366
#       255/1    0.98229    0.97233 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.394137592560861 for eigenvalue
#  The estimated number of batches is 1367
#       256/1    0.97212    0.97232 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.385263842370514 for eigenvalue
#  The estimated number of batches is 1363
#       257/1    0.97544    0.97234 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3771898111265886 for eigenvalue
#  The estimated number of batches is 1360
#       258/1    0.96679    0.97231 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.364399629310625 for eigenvalue
#  The estimated number of batches is 1351
#       259/1    0.97128    0.97231 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3581231880347575 for eigenvalue
#  The estimated number of batches is 1350
#       260/1    0.96402    0.97228 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.35229091714454 for eigenvalue
#  The estimated number of batches is 1348
#       261/1    0.96034    0.97223 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3467903544757456 for eigenvalue
#  The estimated number of batches is 1348
#       262/1    0.96216    0.97218 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3358285804470573 for eigenvalue
#  The estimated number of batches is 1341
#       263/1    0.96343    0.97215 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3248463001247015 for eigenvalue
#  The estimated number of batches is 1334
#       264/1    0.97006    0.97214 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3160227469906722 for eigenvalue
#  The estimated number of batches is 1329
#       265/1    0.96729    0.97212 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.310550898336938 for eigenvalue
#  The estimated number of batches is 1328
#       266/1    0.97083    0.97211 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3036099467473035 for eigenvalue
#  The estimated number of batches is 1326
#       267/1    0.96700    0.97209 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.291729994189174 for eigenvalue
#  The estimated number of batches is 1318
#       268/1    0.96519    0.97207 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.28299227359885 for eigenvalue
#  The estimated number of batches is 1313
#       269/1    0.97939    0.97210 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2847505821569074 for eigenvalue
#  The estimated number of batches is 1320
#       270/1    0.97353    0.97210 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2765174556025367 for eigenvalue
#  The estimated number of batches is 1316
#       271/1    0.96930    0.97209 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2667033601017446 for eigenvalue
#  The estimated number of batches is 1310
#       272/1    0.97675    0.97211 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2594553732831533 for eigenvalue
#  The estimated number of batches is 1307
#       273/1    0.96332    0.97207 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2630251320426473 for eigenvalue
#  The estimated number of batches is 1316
#       274/1    0.97989    0.97210 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.261096418922339 for eigenvalue
#  The estimated number of batches is 1319
#       275/1    0.97323    0.97211 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2551386243353937 for eigenvalue
#  The estimated number of batches is 1317
#       276/1    0.97459    0.97212 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.2471240640628123 for eigenvalue
#  The estimated number of batches is 1313
#       277/1    0.97312    0.97212 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.244719273667373 for eigenvalue
#  The estimated number of batches is 1315
#       278/1    0.97655    0.97214 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2404602689237008 for eigenvalue
#  The estimated number of batches is 1316
#       279/1    0.96841    0.97213 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2356553727512085 for eigenvalue
#  The estimated number of batches is 1315
#       280/1    0.97497    0.97214 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2276926618081077 for eigenvalue
#  The estimated number of batches is 1311
#       281/1    0.97891    0.97216 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.22689465757009 for eigenvalue
#  The estimated number of batches is 1315
#       282/1    0.97755    0.97218 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2266858204359004 for eigenvalue
#  The estimated number of batches is 1320
#       283/1    0.97699    0.97220 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.222836454993591 for eigenvalue
#  The estimated number of batches is 1320
#       284/1    0.97174    0.97220 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2149532409969805 for eigenvalue
#  The estimated number of batches is 1316
#       285/1    0.96614    0.97218 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2076745351654576 for eigenvalue
#  The estimated number of batches is 1312
#       286/1    0.97778    0.97220 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2078146989247545 for eigenvalue
#  The estimated number of batches is 1317
#       287/1    0.96532    0.97217 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.199759163880846 for eigenvalue
#  The estimated number of batches is 1312
#       288/1    0.96789    0.97216 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.1962682232955135 for eigenvalue
#  The estimated number of batches is 1313
#       289/1    0.98009    0.97219 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.190241423076697 for eigenvalue
#  The estimated number of batches is 1311
#       290/1    0.96486    0.97216 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.188634908391428 for eigenvalue
#  The estimated number of batches is 1314
#       291/1    0.95390    0.97209 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.1915396104068163 for eigenvalue
#  The estimated number of batches is 1322
#       292/1    0.98116    0.97212 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.201241525542374 for eigenvalue
#  The estimated number of batches is 1338
#       293/1    0.96772    0.97211 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.193127176081534 for eigenvalue
#  The estimated number of batches is 1334
#       294/1    0.97103    0.97210 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.184860123106051 for eigenvalue
#  The estimated number of batches is 1328
#       295/1    0.96958    0.97210 +/- 0.00031
# ...
#  The estimated number of batches is 1358
#       596/1    0.97753    0.97202 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5242511339876796 for eigenvalue
#  The estimated number of batches is 1359
#       597/1    0.96794    0.97202 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5217806986372582 for eigenvalue
#  The estimated number of batches is 1357
#       598/1    0.96838    0.97201 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5195227881616633 for eigenvalue
#  The estimated number of batches is 1355
#       599/1    0.97015    0.97201 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5170491711181697 for eigenvalue
#  The estimated number of batches is 1353
#       600/1    0.98107    0.97202 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5210966619778992 for eigenvalue
#  The estimated number of batches is 1362
#       601/1    0.97627    0.97203 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5187867834457276 for eigenvalue
#  The estimated number of batches is 1361
#       602/1    0.96771    0.97202 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5166801538492718 for eigenvalue
#  The estimated number of batches is 1359
#       603/1    0.98390    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5155484361634737 for eigenvalue
#  The estimated number of batches is 1360
#       604/1    0.97034    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5131743648336489 for eigenvalue
#  The estimated number of batches is 1358
#       605/1    0.97687    0.97205 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5108707194797744 for eigenvalue
#  The estimated number of batches is 1356
#       606/1    0.96988    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5082179718141233 for eigenvalue
#  The estimated number of batches is 1353
#       607/1    0.96992    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5068500720792306 for eigenvalue
#  The estimated number of batches is 1353
#       608/1    0.97369    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5059610670978978 for eigenvalue
#  The estimated number of batches is 1354
#       609/1    0.97256    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5042182042487349 for eigenvalue
#  The estimated number of batches is 1353
#       610/1    0.97522    0.97205 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5018374691423184 for eigenvalue
#  The estimated number of batches is 1351
#       611/1    0.96491    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.5028230151515243 for eigenvalue
#  The estimated number of batches is 1355
#       612/1    0.97457    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.500437699435339 for eigenvalue
#  The estimated number of batches is 1353
#       613/1    0.96681    0.97203 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4976899584322065 for eigenvalue
#  The estimated number of batches is 1351
#       614/1    0.96782    0.97203 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4951768437058939 for eigenvalue
#  The estimated number of batches is 1348
#       615/1    0.96840    0.97202 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.492785528943397 for eigenvalue
#  The estimated number of batches is 1346
#       616/1    0.97874    0.97203 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4910085903037011 for eigenvalue
#  The estimated number of batches is 1345
#       617/1    0.96655    0.97202 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.489167040203437 for eigenvalue
#  The estimated number of batches is 1344
#       618/1    0.97751    0.97203 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4870768663929206 for eigenvalue
#  The estimated number of batches is 1343
#       619/1    0.97030    0.97203 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4844485582262594 for eigenvalue
#  The estimated number of batches is 1340
#       620/1    0.97587    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4821974401030718 for eigenvalue
#  The estimated number of batches is 1339
#       621/1    0.97684    0.97204 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4806777679110483 for eigenvalue
#  The estimated number of batches is 1338
#       622/1    0.96768    0.97204 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.478065750300835 for eigenvalue
#  The estimated number of batches is 1336
#       623/1    0.97283    0.97204 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4757490924019716 for eigenvalue
#  The estimated number of batches is 1334
#       624/1    0.97792    0.97205 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.473823735239225 for eigenvalue
#  The estimated number of batches is 1332
#       625/1    0.96831    0.97204 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4731971681941087 for eigenvalue
#  The estimated number of batches is 1334
#       626/1    0.98198    0.97206 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4712015922293227 for eigenvalue
#  The estimated number of batches is 1332
#       627/1    0.97243    0.97206 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.469737447074167 for eigenvalue
#  The estimated number of batches is 1332
#       628/1    0.98571    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.468830908179371 for eigenvalue
#  The estimated number of batches is 1332
#       629/1    0.96821    0.97207 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4694322488007587 for eigenvalue
#  The estimated number of batches is 1335
#       630/1    0.97113    0.97207 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.470565127760443 for eigenvalue
#  The estimated number of batches is 1340
#       631/1    0.97991    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.468899838320902 for eigenvalue
#  The estimated number of batches is 1339
#       632/1    0.97666    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.468430384351192 for eigenvalue
#  The estimated number of batches is 1340
#       633/1    0.97570    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4664338888971562 for eigenvalue
#  The estimated number of batches is 1339
#       634/1    0.96184    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4643389353721146 for eigenvalue
#  The estimated number of batches is 1337
#       635/1    0.97481    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4622977923038578 for eigenvalue
#  The estimated number of batches is 1336
#       636/1    0.96597    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4596575543607162 for eigenvalue
#  The estimated number of batches is 1333
#       637/1    0.96983    0.97207 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4587370682577308 for eigenvalue
#  The estimated number of batches is 1333
#       638/1    0.98099    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.458844713965187 for eigenvalue
#  The estimated number of batches is 1336
#       639/1    0.97159    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4566192258063673 for eigenvalue
#  The estimated number of batches is 1334
#       640/1    0.97890    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4551864273602308 for eigenvalue
#  The estimated number of batches is 1333
#       641/1    0.97237    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.453876458005622 for eigenvalue
#  The estimated number of batches is 1333
#       642/1    0.97522    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4522358800539727 for eigenvalue
#  The estimated number of batches is 1332
#       643/1    0.97757    0.97211 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4524889985413443 for eigenvalue
#  The estimated number of batches is 1335
#       644/1    0.96725    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4523160124122996 for eigenvalue
#  The estimated number of batches is 1337
#       645/1    0.96199    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4531016056733679 for eigenvalue
#  The estimated number of batches is 1340
#       646/1    0.96906    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4510679302834035 for eigenvalue
#  The estimated number of batches is 1339
#       647/1    0.97182    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4490132013575052 for eigenvalue
#  The estimated number of batches is 1337
#       648/1    0.96925    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4466154915541027 for eigenvalue
#  The estimated number of batches is 1335
#       649/1    0.97600    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4450314120885914 for eigenvalue
#  The estimated number of batches is 1334
#       650/1    0.97026    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4426301398680832 for eigenvalue
#  The estimated number of batches is 1332
#       651/1    0.97649    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4406766816120482 for eigenvalue
#  The estimated number of batches is 1330
#       652/1    0.96880    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4387434961885144 for eigenvalue
#  The estimated number of batches is 1329
#       653/1    0.97758    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.436862778220292 for eigenvalue
#  The estimated number of batches is 1327
#       654/1    0.97244    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4355275746476153 for eigenvalue
#  The estimated number of batches is 1327
#       655/1    0.97423    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4333780019203028 for eigenvalue
#  The estimated number of batches is 1325
#       656/1    0.97253    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.431902125253528 for eigenvalue
#  The estimated number of batches is 1325
#       657/1    0.97235    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4314216565209814 for eigenvalue
#  The estimated number of batches is 1326
#       658/1    0.97388    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4292957806470796 for eigenvalue
#  The estimated number of batches is 1324
#       659/1    0.97501    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4291034153438795 for eigenvalue
#  The estimated number of batches is 1326
#       660/1    0.97276    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4276977515058766 for eigenvalue
#  The estimated number of batches is 1325
#       661/1    0.97162    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.425562880726957 for eigenvalue
#  The estimated number of batches is 1323
#       662/1    0.97126    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4233178869085652 for eigenvalue
#  The estimated number of batches is 1321
#       663/1    0.96425    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4217314714435803 for eigenvalue
#  The estimated number of batches is 1320
#       664/1    0.96771    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4218157542252945 for eigenvalue
#  The estimated number of batches is 1322
#       665/1    0.97228    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4196133620687386 for eigenvalue
#  The estimated number of batches is 1320
#       666/1    0.96580    0.97207 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4217015284576295 for eigenvalue
#  The estimated number of batches is 1326
#       667/1    0.97580    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.419754392053208 for eigenvalue
#  The estimated number of batches is 1325
#       668/1    0.96432    0.97207 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4180849748540136 for eigenvalue
#  The estimated number of batches is 1324
#       669/1    0.98456    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4170526780989259 for eigenvalue
#  The estimated number of batches is 1324
#       670/1    0.97286    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4150497873577317 for eigenvalue
#  The estimated number of batches is 1322
#       671/1    0.97915    0.97210 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4139614623368106 for eigenvalue
#  The estimated number of batches is 1322
#       672/1    0.96711    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4127621387799083 for eigenvalue
#  The estimated number of batches is 1322
#       673/1    0.96832    0.97209 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4109692558881766 for eigenvalue
#  The estimated number of batches is 1321
#       674/1    0.96423    0.97207 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.410672728946642 for eigenvalue
#  The estimated number of batches is 1322
#       675/1    0.96568    0.97206 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4087660301946907 for eigenvalue
#  The estimated number of batches is 1320
#       676/1    0.98010    0.97208 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.410284612432801 for eigenvalue
#  The estimated number of batches is 1325
#       677/1    0.97013    0.97207 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4080898959417432 for eigenvalue
#  The estimated number of batches is 1323
#       678/1    0.96633    0.97206 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.407271855862012 for eigenvalue
#  The estimated number of batches is 1324
#       679/1    0.96527    0.97205 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4091189526469077 for eigenvalue
#  The estimated number of batches is 1329
#       680/1    0.97272    0.97206 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4074640743343982 for eigenvalue
#  The estimated number of batches is 1328
#       681/1    0.96455    0.97204 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4049899773664907 for eigenvalue
#  The estimated number of batches is 1325
#       682/1    0.97037    0.97204 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.4032517348974833 for eigenvalue
#  The estimated number of batches is 1324
#       683/1    0.97706    0.97205 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.404467253429099 for eigenvalue
#  The estimated number of batches is 1328
#       684/1    0.96823    0.97204 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.403042273110535 for eigenvalue
#  The estimated number of batches is 1328
#       685/1    0.96814    0.97204 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4008226706548572 for eigenvalue
#  The estimated number of batches is 1325
#       686/1    0.97145    0.97204 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3992288336566563 for eigenvalue
#  The estimated number of batches is 1324
#       687/1    0.97157    0.97204 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.397429453206649 for eigenvalue
#  The estimated number of batches is 1323
#       688/1    0.96904    0.97203 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3952440230590275 for eigenvalue
#  The estimated number of batches is 1321
#       689/1    0.96931    0.97203 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.394234361976125 for eigenvalue
#  The estimated number of batches is 1321
#       690/1    0.97786    0.97204 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3924393388401162 for eigenvalue
#  The estimated number of batches is 1320
#       691/1    0.97313    0.97204 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3904776723860506 for eigenvalue
#  The estimated number of batches is 1318
#       692/1    0.97363    0.97204 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.3884680166590049 for eigenvalue
#  The estimated number of batches is 1316
