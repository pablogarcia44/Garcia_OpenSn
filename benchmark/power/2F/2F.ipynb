# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]


PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %% [markdown]
# ### Define assembly

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0] 
            
            
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-12 17:31:24
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.97132
#         2/1    0.97888
#         3/1    0.97923
#         4/1    0.96887
#         5/1    0.97566
#         6/1    0.97782
#         7/1    0.97584
#         8/1    0.97608
#         9/1    0.97702
#        10/1    0.97489
#        11/1    0.96868
#        12/1    0.97575
#        13/1    0.97427
#        14/1    0.97767
#        15/1    0.97660
#        16/1    0.97192
#        17/1    0.98379
#        18/1    0.97646
#        19/1    0.97435
#        20/1    0.97133
#        21/1    0.97162
#        22/1    0.97510    0.97336 +/- 0.00174
#        23/1    0.97619    0.97430 +/- 0.00138
#        24/1    0.97291    0.97396 +/- 0.00103
#        25/1    0.97412    0.97399 +/- 0.00080
#        26/1    0.97305    0.97383 +/- 0.00067
#        27/1    0.97727    0.97432 +/- 0.00075
#        28/1    0.97584    0.97451 +/- 0.00068
#        29/1    0.96835    0.97383 +/- 0.00091
#        30/1    0.97333    0.97378 +/- 0.00081
#        31/1    0.97311    0.97372 +/- 0.00074
#        32/1    0.97461    0.97379 +/- 0.00068
#        33/1    0.96728    0.97329 +/- 0.00080
#        34/1    0.97191    0.97319 +/- 0.00075
#        35/1    0.97672    0.97343 +/- 0.00073
#        36/1    0.97079    0.97326 +/- 0.00071
#        37/1    0.96916    0.97302 +/- 0.00071
#        38/1    0.97439    0.97310 +/- 0.00067
#        39/1    0.97052    0.97296 +/- 0.00065
#        40/1    0.97889    0.97326 +/- 0.00068
#        41/1    0.97244    0.97322 +/- 0.00065
#        42/1    0.97046    0.97309 +/- 0.00063
#        43/1    0.97589    0.97321 +/- 0.00062
#        44/1    0.97477    0.97328 +/- 0.00059
#        45/1    0.97702    0.97343 +/- 0.00059
#        46/1    0.97782    0.97360 +/- 0.00059
#        47/1    0.98258    0.97393 +/- 0.00066
#        48/1    0.97566    0.97399 +/- 0.00064
#        49/1    0.97348    0.97397 +/- 0.00062
#        50/1    0.97601    0.97404 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 5.6461456966499695 for eigenvalue
#  The estimated number of batches is 977
#  Creating state point statepoint.00050.h5...
#        51/1    0.97057    0.97393 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 5.637677039308445 for eigenvalue
#  The estimated number of batches is 1006
#        52/1    0.96473    0.97364 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.706513607662078 for eigenvalue
#  The estimated number of batches is 1063
#        53/1    0.97390    0.97365 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.612959108543926 for eigenvalue
#  The estimated number of batches is 1060
#        54/1    0.98214    0.97390 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.518523851713803 for eigenvalue
#  The estimated number of batches is 1056
#        55/1    0.97696    0.97399 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.237472222145068 for eigenvalue
#  The estimated number of batches is 981
#        56/1    0.97587    0.97404 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.256418132757894 for eigenvalue
#  The estimated number of batches is 1015
#        57/1    0.97807    0.97415 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.136849061544436 for eigenvalue
#  The estimated number of batches is 997
#        58/1    0.97405    0.97415 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.99399865755706 for eigenvalue
#  The estimated number of batches is 968
#        59/1    0.96769    0.97398 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.999370584373797 for eigenvalue
#  The estimated number of batches is 995
#        60/1    0.97925    0.97411 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.876978792463264 for eigenvalue
#  The estimated number of batches is 972
#        61/1    0.97920    0.97424 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.695287882336412 for eigenvalue
#  The estimated number of batches is 924
#        62/1    0.98531    0.97450 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.205013803101925 for eigenvalue
#  The estimated number of batches is 1158
#        63/1    0.98412    0.97472 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.013386681879741 for eigenvalue
#  The estimated number of batches is 1101
#        64/1    0.97858    0.97481 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.9299303945795865 for eigenvalue
#  The estimated number of batches is 1090
#        65/1    0.97547    0.97483 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.798571693830531 for eigenvalue
#  The estimated number of batches is 1057
#        66/1    0.97330    0.97479 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.721036641720921 for eigenvalue
#  The estimated number of batches is 1046
#        67/1    0.97465    0.97479 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.629552087170686 for eigenvalue
#  The estimated number of batches is 1028
#        68/1    0.96930    0.97468 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.694314115776758 for eigenvalue
#  The estimated number of batches is 1078
#        69/1    0.98128    0.97481 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.850769987138994 for eigenvalue
#  The estimated number of batches is 1173
#        70/1    0.97779    0.97487 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.873711409455125 for eigenvalue
#  The estimated number of batches is 1208
#        71/1    0.97469    0.97487 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.808965982068195 for eigenvalue
#  The estimated number of batches is 1200
#        72/1    0.98365    0.97504 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.889133900995592 for eigenvalue
#  The estimated number of batches is 1263
#        73/1    0.97564    0.97505 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.793600091635935 for eigenvalue
#  The estimated number of batches is 1238
#        74/1    0.97691    0.97508 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.71358785057215 for eigenvalue
#  The estimated number of batches is 1220
#        75/1    0.98527    0.97527 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.677132951292972 for eigenvalue
#  The estimated number of batches is 1224
#        76/1    0.97111    0.97519 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.597443770734858 for eigenvalue
#  The estimated number of batches is 1204
#        77/1    0.97493    0.97519 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.582817636169918 for eigenvalue
#  The estimated number of batches is 1218
#        78/1    0.98244    0.97531 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.489942934455655 for eigenvalue
#  The estimated number of batches is 1190
#        79/1    0.97192    0.97526 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.489632050469859 for eigenvalue
#  The estimated number of batches is 1210
#        80/1    0.97171    0.97520 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.424336214131698 for eigenvalue
#  The estimated number of batches is 1195
#        81/1    0.97364    0.97517 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.354780194213886 for eigenvalue
#  The estimated number of batches is 1177
#        82/1    0.97978    0.97525 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.328983273055207 for eigenvalue
#  The estimated number of batches is 1182
#        83/1    0.97388    0.97522 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.264855674064077 for eigenvalue
#  The estimated number of batches is 1166
#        84/1    0.98934    0.97544 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.393985096537995 for eigenvalue
#  The estimated number of batches is 1256
#        85/1    0.96978    0.97536 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.37342735317804 for eigenvalue
#  The estimated number of batches is 1264
#        86/1    0.97267    0.97532 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.325654049834335 for eigenvalue
#  The estimated number of batches is 1255
#        87/1    0.97165    0.97526 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.266661479286875 for eigenvalue
#  The estimated number of batches is 1240
#        88/1    0.98034    0.97534 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.213498067364603 for eigenvalue
#  The estimated number of batches is 1228
#        89/1    0.97595    0.97535 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.187956206846472 for eigenvalue
#  The estimated number of batches is 1231
#        90/1    0.97596    0.97535 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.136432571159035 for eigenvalue
#  The estimated number of batches is 1218
#        91/1    0.98204    0.97545 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.253330173243865 for eigenvalue
#  The estimated number of batches is 1305
#        92/1    0.97387    0.97543 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.21268500069102 for eigenvalue
#  The estimated number of batches is 1298
#        93/1    0.96475    0.97528 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.165666309301328 for eigenvalue
#  The estimated number of batches is 1287
#        94/1    0.97389    0.97526 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.12047356242673 for eigenvalue
#  The estimated number of batches is 1277
#        95/1    0.97179    0.97521 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.0717787224150195 for eigenvalue
#  The estimated number of batches is 1264
#        96/1    0.97678    0.97524 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.013922025936623 for eigenvalue
#  The estimated number of batches is 1245
#        97/1    0.97135    0.97519 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.975980109528184 for eigenvalue
#  The estimated number of batches is 1238
#        98/1    0.98758    0.97534 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.076665288959985 for eigenvalue
#  The estimated number of batches is 1317
#        99/1    0.97546    0.97535 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.024686927334074 for eigenvalue
#  The estimated number of batches is 1300
#       100/1    0.97495    0.97534 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9763816054365693 for eigenvalue
#  The estimated number of batches is 1285
#       101/1    0.98315    0.97544 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9305689733237945 for eigenvalue
#  The estimated number of batches is 1272
#       102/1    0.97106    0.97538 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9512011656190844 for eigenvalue
#  The estimated number of batches is 1301
#       103/1    0.97016    0.97532 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.928287067682099 for eigenvalue
#  The estimated number of batches is 1301
#       104/1    0.97137    0.97527 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8852953246219926 for eigenvalue
#  The estimated number of batches is 1289
#       105/1    0.97991    0.97533 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.874397158381103 for eigenvalue
#  The estimated number of batches is 1296
#       106/1    0.98806    0.97548 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9134572183497305 for eigenvalue
#  The estimated number of batches is 1338
#       107/1    0.97257    0.97544 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.902341208366067 for eigenvalue
#  The estimated number of batches is 1345
#       108/1    0.97202    0.97540 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9327303144135866 for eigenvalue
#  The estimated number of batches is 1382
#       109/1    0.98000    0.97546 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.889981206149564 for eigenvalue
#  The estimated number of batches is 1367
#       110/1    0.96721    0.97536 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9366129292123153 for eigenvalue
#  The estimated number of batches is 1415
#       111/1    0.98677    0.97549 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.907990428234254 for eigenvalue
#  The estimated number of batches is 1410
#       112/1    0.99178    0.97567 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.024062188159201 for eigenvalue
#  The estimated number of batches is 1510
#       113/1    0.96987    0.97560 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.9814833537777785 for eigenvalue
#  The estimated number of batches is 1495
#       114/1    0.97250    0.97557 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.940045506578749 for eigenvalue
#  The estimated number of batches is 1480
#       115/1    0.96687    0.97548 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.9403909222959315 for eigenvalue
#  The estimated number of batches is 1496
#       116/1    0.98069    0.97553 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.909412217624925 for eigenvalue
#  The estimated number of batches is 1488
#       117/1    0.97089    0.97549 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.87516083159988 for eigenvalue
#  The estimated number of batches is 1477
#       118/1    0.97404    0.97547 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.841703369768895 for eigenvalue
#  The estimated number of batches is 1467
#       119/1    0.96599    0.97538 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.828942741354329 for eigenvalue
#  The estimated number of batches is 1472
#       120/1    0.97607    0.97538 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.792159047947194 for eigenvalue
#  The estimated number of batches is 1459
#       121/1    0.97957    0.97542 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.8126502775124744 for eigenvalue
#  The estimated number of batches is 1489
#       122/1    0.97054    0.97538 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.7919435571624263 for eigenvalue
#  The estimated number of batches is 1487
#       123/1    0.96639    0.97529 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8170809518138387 for eigenvalue
#  The estimated number of batches is 1521
#       124/1    0.97722    0.97531 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.7872497696376772 for eigenvalue
#  The estimated number of batches is 1512
#       125/1    0.98523    0.97540 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8365887206603086 for eigenvalue
#  The estimated number of batches is 1566
#       126/1    0.97481    0.97540 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8314271157196216 for eigenvalue
#  The estimated number of batches is 1577
#       127/1    0.97062    0.97535 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8079650739512587 for eigenvalue
#  The estimated number of batches is 1572
#       128/1    0.98174    0.97541 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.825414990176186 for eigenvalue
#  The estimated number of batches is 1601
#       129/1    0.97281    0.97539 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.7919068486402003 for eigenvalue
#  The estimated number of batches is 1588
#       130/1    0.97539    0.97539 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7637656076298334 for eigenvalue
#  The estimated number of batches is 1579
#       131/1    0.98002    0.97543 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7313539847681327 for eigenvalue
#  The estimated number of batches is 1566
#       132/1    0.97296    0.97541 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.699566355374078 for eigenvalue
#  The estimated number of batches is 1553
#       133/1    0.97555    0.97541 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.670135909239193 for eigenvalue
#  The estimated number of batches is 1543
#       134/1    0.96827    0.97535 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.658600213902749 for eigenvalue
#  The estimated number of batches is 1546
#       135/1    0.97428    0.97534 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.663403006171583 for eigenvalue
#  The estimated number of batches is 1564
#       136/1    0.96917    0.97528 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6409083121205583 for eigenvalue
#  The estimated number of batches is 1558
#       137/1    0.97672    0.97529 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6649753908285034 for eigenvalue
#  The estimated number of batches is 1592
#       138/1    0.98903    0.97541 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6482916782689583 for eigenvalue
#  The estimated number of batches is 1591
#       139/1    0.97606    0.97542 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.616207429397435 for eigenvalue
#  The estimated number of batches is 1577
#       140/1    0.97339    0.97540 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.5853953639648886 for eigenvalue
#  The estimated number of batches is 1563
#       141/1    0.97609    0.97541 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.5720462713552705 for eigenvalue
#  The estimated number of batches is 1564
#       142/1    0.97529    0.97540 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.5470580453778933 for eigenvalue
#  The estimated number of batches is 1555
#       143/1    0.97458    0.97540 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.52059784701367 for eigenvalue
#  The estimated number of batches is 1545
#       144/1    0.98582    0.97548 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.616938406081722 for eigenvalue
#  The estimated number of batches is 1643
#       145/1    0.96977    0.97544 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.6151846519090594 for eigenvalue
#  The estimated number of batches is 1654
#       146/1    0.97835    0.97546 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.6014459294519496 for eigenvalue
#  The estimated number of batches is 1655
#       147/1    0.98109    0.97550 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5748176106856175 for eigenvalue
#  The estimated number of batches is 1643
#       148/1    0.97635    0.97551 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5598472237019734 for eigenvalue
#  The estimated number of batches is 1643
#       149/1    0.97231    0.97549 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5349974939945628 for eigenvalue
#  The estimated number of batches is 1633
#       150/1    0.98146    0.97553 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5059693107668424 for eigenvalue
#  The estimated number of batches is 1618
#       151/1    0.97303    0.97551 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.4799076796419808 for eigenvalue
#  The estimated number of batches is 1607
#       152/1    0.99131    0.97563 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5041132366912637 for eigenvalue
#  The estimated number of batches is 1641
#       153/1    0.97956    0.97566 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5221636320906287 for eigenvalue
#  The estimated number of batches is 1670
#       154/1    0.97541    0.97566 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5058992220252234 for eigenvalue
#  The estimated number of batches is 1668
#       155/1    0.97131    0.97563 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.4806617637418533 for eigenvalue
#  The estimated number of batches is 1656
#       156/1    0.97651    0.97563 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.4603547058085535 for eigenvalue
#  The estimated number of batches is 1649
#       157/1    0.97151    0.97560 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4354096837400463 for eigenvalue
#  The estimated number of batches is 1637
#       158/1    0.97305    0.97559 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4112293161518363 for eigenvalue
#  The estimated number of batches is 1626
#       159/1    0.97478    0.97558 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.403625292596016 for eigenvalue
#  The estimated number of batches is 1631
#       160/1    0.98078    0.97562 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.3884555567773984 for eigenvalue
#  The estimated number of batches is 1628
#       161/1    0.98280    0.97567 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.3664394805876463 for eigenvalue
#  The estimated number of batches is 1618
#       162/1    0.98139    0.97571 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3434870660418476 for eigenvalue
#  The estimated number of batches is 1608
#       163/1    0.96956    0.97566 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.338107098101248 for eigenvalue
#  The estimated number of batches is 1614
#       164/1    0.97865    0.97569 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3445709097831973 for eigenvalue
#  The estimated number of batches is 1631
#       165/1    0.97796    0.97570 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3208450452333436 for eigenvalue
#  The estimated number of batches is 1620
#       166/1    0.98488    0.97576 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3159316344212986 for eigenvalue
#  The estimated number of batches is 1626
#       167/1    0.98039    0.97580 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.307683780205107 for eigenvalue
#  The estimated number of batches is 1629
#       168/1    0.97633    0.97580 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2855200941599914 for eigenvalue
#  The estimated number of batches is 1618
#       169/1    0.97933    0.97582 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2628154422295252 for eigenvalue
#  The estimated number of batches is 1607
#       170/1    0.96836    0.97577 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.246150647519736 for eigenvalue
#  The estimated number of batches is 1601
#       171/1    0.97121    0.97574 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2264881447562144 for eigenvalue
#  The estimated number of batches is 1592
#       172/1    0.97968    0.97577 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2093546941428563 for eigenvalue
#  The estimated number of batches is 1586
#       173/1    0.97756    0.97578 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1890915625361185 for eigenvalue
#  The estimated number of batches is 1577
#       174/1    0.98324    0.97583 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.180405449867563 for eigenvalue
#  The estimated number of batches is 1578
#       175/1    0.97045    0.97579 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1656203763829076 for eigenvalue
#  The estimated number of batches is 1574
#       176/1    0.96891    0.97575 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1560889525265314 for eigenvalue
#  The estimated number of batches is 1574
#       177/1    0.97140    0.97572 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1363002503855304 for eigenvalue
#  The estimated number of batches is 1565
#       178/1    0.97929    0.97575 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.118307563773626 for eigenvalue
#  The estimated number of batches is 1557
#       179/1    0.96487    0.97568 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1794343821565363 for eigenvalue
#  The estimated number of batches is 1628
#       180/1    0.97371    0.97566 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1616318823842007 for eigenvalue
#  The estimated number of batches is 1620
#       181/1    0.97870    0.97568 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1460442327323137 for eigenvalue
#  The estimated number of batches is 1614
#       182/1    0.98217    0.97572 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.126361176870662 for eigenvalue
#  The estimated number of batches is 1604
#       183/1    0.97299    0.97571 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1142826634959184 for eigenvalue
#  The estimated number of batches is 1601
#       184/1    0.97479    0.97570 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1021208322772726 for eigenvalue
#  The estimated number of batches is 1599
#       185/1    0.97788    0.97571 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.085296893893012 for eigenvalue
#  The estimated number of batches is 1591
#       186/1    0.97940    0.97574 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0808008541388454 for eigenvalue
#  The estimated number of batches is 1596
#       187/1    0.98142    0.97577 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0608049532682675 for eigenvalue
#  The estimated number of batches is 1585
#       188/1    0.97887    0.97579 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.05089073633662 for eigenvalue
#  The estimated number of batches is 1584
#       189/1    0.98985    0.97587 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.043799672808078 for eigenvalue
#  The estimated number of batches is 1586
#       190/1    0.97538    0.97587 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0260908480675544 for eigenvalue
#  The estimated number of batches is 1577
#       191/1    0.98116    0.97590 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.019288677003989 for eigenvalue
#  The estimated number of batches is 1579
#       192/1    0.96704    0.97585 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0113633367077433 for eigenvalue
#  The estimated number of batches is 1580
#       193/1    0.97832    0.97586 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9936349507862783 for eigenvalue
#  The estimated number of batches is 1571
#       194/1    0.98311    0.97590 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9911141025328116 for eigenvalue
#  The estimated number of batches is 1577
#       195/1    0.97263    0.97589 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9853216420044397 for eigenvalue
#  The estimated number of batches is 1580
#       196/1    0.97799    0.97590 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9810358698192907 for eigenvalue
#  The estimated number of batches is 1585
#       197/1    0.97305    0.97588 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9708100698639694 for eigenvalue
#  The estimated number of batches is 1583
#       198/1    0.96598    0.97583 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.960788636915062 for eigenvalue
#  The estimated number of batches is 1581
#       199/1    0.97566    0.97583 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.949692414133628 for eigenvalue
#  The estimated number of batches is 1578
#       200/1    0.97801    0.97584 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.93466737690921 for eigenvalue
#  The estimated number of batches is 1571
#       201/1    0.97135    0.97581 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9202294393940904 for eigenvalue
#  The estimated number of batches is 1564
#       202/1    0.96657    0.97576 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.914767293120355 for eigenvalue
#  The estimated number of batches is 1567
#       203/1    0.97935    0.97578 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.903746687182636 for eigenvalue
#  The estimated number of batches is 1564
#       204/1    0.97371    0.97577 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8887044303756073 for eigenvalue
#  The estimated number of batches is 1556
#       205/1    0.97845    0.97578 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.876343670719992 for eigenvalue
#  The estimated number of batches is 1551
#       206/1    0.96812    0.97574 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.871951104964588 for eigenvalue
#  The estimated number of batches is 1555
#       207/1    0.96878    0.97571 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8853275119263686 for eigenvalue
#  The estimated number of batches is 1577
#       208/1    0.97964    0.97573 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8699904434060204 for eigenvalue
#  The estimated number of batches is 1569
#       209/1    0.99077    0.97581 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8790742248529635 for eigenvalue
#  The estimated number of batches is 1587
#       210/1    0.97602    0.97581 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8648081987422147 for eigenvalue
#  The estimated number of batches is 1580
#       211/1    0.97487    0.97580 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.853269490530157 for eigenvalue
#  The estimated number of batches is 1575
#       212/1    0.98145    0.97583 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8396958978234874 for eigenvalue
#  The estimated number of batches is 1569
#       213/1    0.98476    0.97588 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8321907663072876 for eigenvalue
#  The estimated number of batches is 1569
#       214/1    0.97471    0.97587 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.818103759919729 for eigenvalue
#  The estimated number of batches is 1561
#       215/1    0.96820    0.97583 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.823484082403481 for eigenvalue
#  The estimated number of batches is 1575
#       216/1    0.97550    0.97583 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8113849118785046 for eigenvalue
#  The estimated number of batches is 1570
#       217/1    0.97592    0.97583 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7994330230545543 for eigenvalue
#  The estimated number of batches is 1564
#       218/1    0.97699    0.97584 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7845735256622044 for eigenvalue
#  The estimated number of batches is 1556
#       219/1    0.97286    0.97582 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7732404149655543 for eigenvalue
#  The estimated number of batches is 1551
#       220/1    0.97500    0.97582 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7588983471968125 for eigenvalue
#  The estimated number of batches is 1543
#       221/1    0.97699    0.97582 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.744821720185187 for eigenvalue
#  The estimated number of batches is 1535
#       222/1    0.97031    0.97580 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7424984513798614 for eigenvalue
#  The estimated number of batches is 1540
#       223/1    0.96968    0.97577 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7296672400714352 for eigenvalue
#  The estimated number of batches is 1533
#       224/1    0.97846    0.97578 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.715601269009518 for eigenvalue
#  The estimated number of batches is 1525
#       225/1    0.97521    0.97578 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7082647063123257 for eigenvalue
#  The estimated number of batches is 1524
#       226/1    0.97844    0.97579 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.694789845888474 for eigenvalue
#  The estimated number of batches is 1516
#       227/1    0.97676    0.97580 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.691045074450013 for eigenvalue
#  The estimated number of batches is 1520
#       228/1    0.97863    0.97581 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.677404541600248 for eigenvalue
#  The estimated number of batches is 1512
#       229/1    0.97553    0.97581 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6690709749189017 for eigenvalue
#  The estimated number of batches is 1509
#       230/1    0.97162    0.97579 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6573595053664567 for eigenvalue
#  The estimated number of batches is 1503
#       231/1    0.97496    0.97578 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6568354641227625 for eigenvalue
#  The estimated number of batches is 1510
#       232/1    0.97590    0.97578 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6446995062961 for eigenvalue
#  The estimated number of batches is 1503
#       233/1    0.96894    0.97575 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6614068007228853 for eigenvalue
#  The estimated number of batches is 1529
#       234/1    0.98054    0.97577 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.650030509738121 for eigenvalue
#  The estimated number of batches is 1523
#       235/1    0.97573    0.97577 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6374267390647197 for eigenvalue
#  The estimated number of batches is 1516
#       236/1    0.96901    0.97574 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6355438376517824 for eigenvalue
#  The estimated number of batches is 1521
#       237/1    0.98478    0.97578 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.634636828098435 for eigenvalue
#  The estimated number of batches is 1527
#       238/1    0.97598    0.97579 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.622705600028644 for eigenvalue
#  The estimated number of batches is 1520
#       239/1    0.98293    0.97582 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.610344402602361 for eigenvalue
#  The estimated number of batches is 1513
#       240/1    0.97586    0.97582 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5979337339356854 for eigenvalue
#  The estimated number of batches is 1505
#       241/1    0.97727    0.97582 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.599781438781107 for eigenvalue
#  The estimated number of batches is 1514
#       242/1    0.98648    0.97587 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6044870837282965 for eigenvalue
#  The estimated number of batches is 1526
#       243/1    0.97818    0.97588 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.592616901999903 for eigenvalue
#  The estimated number of batches is 1519
#       244/1    0.96411    0.97583 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.594190289291172 for eigenvalue
#  The estimated number of batches is 1528
#       245/1    0.97511    0.97583 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5830852602628873 for eigenvalue
#  The estimated number of batches is 1522
#       246/1    0.97425    0.97582 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5731361964299735 for eigenvalue
#  The estimated number of batches is 1517
#       247/1    0.99126    0.97589 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.567399148211175 for eigenvalue
#  The estimated number of batches is 1517
#       248/1    0.97491    0.97588 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5562440693402726 for eigenvalue
#  The estimated number of batches is 1510
#       249/1    0.96754    0.97585 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.549377822062576 for eigenvalue
#  The estimated number of batches is 1509
#       250/1    0.97514    0.97584 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.538027280176262 for eigenvalue
#  The estimated number of batches is 1502
#       251/1    0.97870    0.97586 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5298613234680953 for eigenvalue
#  The estimated number of batches is 1499
#       252/1    0.98587    0.97590 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5191077460462576 for eigenvalue
#  The estimated number of batches is 1493
#       253/1    0.97772    0.97591 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5092547692771063 for eigenvalue
#  The estimated number of batches is 1488
#       254/1    0.98081    0.97593 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5006561548364608 for eigenvalue
#  The estimated number of batches is 1484
#       255/1    0.97205    0.97591 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4921867017775683 for eigenvalue
#  The estimated number of batches is 1480
#       256/1    0.97078    0.97589 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4816960270679087 for eigenvalue
#  The estimated number of batches is 1474
#       257/1    0.97246    0.97588 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.472718198872854 for eigenvalue
#  The estimated number of batches is 1470
#       258/1    0.97055    0.97585 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4807745211956354 for eigenvalue
#  The estimated number of batches is 1485
#       259/1    0.98727    0.97590 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4777827815360007 for eigenvalue
#  The estimated number of batches is 1488
#       260/1    0.97638    0.97590 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4679418352091074 for eigenvalue
#  The estimated number of batches is 1482
#       261/1    0.97267    0.97589 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4632342117893375 for eigenvalue
#  The estimated number of batches is 1483
#       262/1    0.97527    0.97589 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.454159649323904 for eigenvalue
#  The estimated number of batches is 1478
#       263/1    0.96980    0.97586 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4560030388846843 for eigenvalue
#  The estimated number of batches is 1486
#       264/1    0.98086    0.97588 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4481142825203137 for eigenvalue
#  The estimated number of batches is 1483
#       265/1    0.97496    0.97588 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4414446658842883 for eigenvalue
#  The estimated number of batches is 1481
#       266/1    0.98284    0.97591 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4355447994155908 for eigenvalue
#  The estimated number of batches is 1480
#       267/1    0.97355    0.97590 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.426186302439607 for eigenvalue
#  The estimated number of batches is 1474
#       268/1    0.97649    0.97590 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4187864822328122 for eigenvalue
#  The estimated number of batches is 1471
#       269/1    0.97898    0.97591 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.431034678022898 for eigenvalue
#  The estimated number of batches is 1492
#       270/1    0.97188    0.97590 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.443689243444412 for eigenvalue
#  The estimated number of batches is 1513
#       271/1    0.96723    0.97586 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.436814510092931 for eigenvalue
#  The estimated number of batches is 1511
#       272/1    0.97225    0.97585 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4306829119804347 for eigenvalue
#  The estimated number of batches is 1509
#       273/1    0.97059    0.97583 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.423005408785996 for eigenvalue
#  The estimated number of batches is 1506
#       274/1    0.96675    0.97579 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4198494078318316 for eigenvalue
#  The estimated number of batches is 1508
#       275/1    0.97203    0.97578 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4103033293177667 for eigenvalue
#  The estimated number of batches is 1502
#       276/1    0.96975    0.97575 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4011694173813747 for eigenvalue
#  The estimated number of batches is 1496
#       277/1    0.98262    0.97578 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3925530154743044 for eigenvalue
#  The estimated number of batches is 1492
#       278/1    0.97441    0.97577 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3836425342800434 for eigenvalue
#  The estimated number of batches is 1486
#       279/1    0.98384    0.97581 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.376386666471865 for eigenvalue
#  The estimated number of batches is 1483
#       280/1    0.97014    0.97578 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3781764436788784 for eigenvalue
#  The estimated number of batches is 1491
#       281/1    0.97452    0.97578 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3822338323702166 for eigenvalue
#  The estimated number of batches is 1502
#       282/1    0.97386    0.97577 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.373164644461137 for eigenvalue
#  The estimated number of batches is 1496
#       283/1    0.98434    0.97580 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.36400739323769 for eigenvalue
#  The estimated number of batches is 1490
#       284/1    0.98517    0.97584 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3799106857466987 for eigenvalue
#  The estimated number of batches is 1516
#       285/1    0.97471    0.97584 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.372239956929737 for eigenvalue
#  The estimated number of batches is 1512
#       286/1    0.97611    0.97584 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.36852312822335 for eigenvalue
#  The estimated number of batches is 1513
#       287/1    0.98466    0.97587 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3612105478118104 for eigenvalue
#  The estimated number of batches is 1509
#       288/1    0.97669    0.97587 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3552415030980303 for eigenvalue
#  The estimated number of batches is 1507
#       289/1    0.97510    0.97587 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.346632220533921 for eigenvalue
#  The estimated number of batches is 1502
#       290/1    0.97935    0.97588 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3405589587081947 for eigenvalue
#  The estimated number of batches is 1500
#       291/1    0.97904    0.97589 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.336350242026649 for eigenvalue
#  The estimated number of batches is 1500
#       292/1    0.97722    0.97590 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3424444827083155 for eigenvalue
#  The estimated number of batches is 1513
#       293/1    0.96712    0.97587 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3340142823544188 for eigenvalue
#  The estimated number of batches is 1508
#       294/1    0.97662    0.97587 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3301250138886647 for eigenvalue
#  The estimated number of batches is 1508
#       295/1    0.97940    0.97588 +/- 0.00033
# ...
#  Triggers unsatisfied, max unc./thresh. is 1.0673813606335423 for eigenvalue
#  The estimated number of batches is 1551
#      1364/1    0.96961    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.066862586903688 for eigenvalue
#  The estimated number of batches is 1550
#      1365/1    0.97209    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0661161128255383 for eigenvalue
#  The estimated number of batches is 1549
#      1366/1    0.97900    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.065422335667821 for eigenvalue
#  The estimated number of batches is 1548
#      1367/1    0.98047    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0649817521010485 for eigenvalue
#  The estimated number of batches is 1548
#      1368/1    0.97467    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0650689953299346 for eigenvalue
#  The estimated number of batches is 1550
#      1369/1    0.97765    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.06432184666428 for eigenvalue
#  The estimated number of batches is 1549
#      1370/1    0.96974    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0635369557599312 for eigenvalue
#  The estimated number of batches is 1547
#      1371/1    0.97243    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0636588947988936 for eigenvalue
#  The estimated number of batches is 1549
#      1372/1    0.97318    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0632442236226674 for eigenvalue
#  The estimated number of batches is 1549
#      1373/1    0.97198    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.063151922773062 for eigenvalue
#  The estimated number of batches is 1550
#      1374/1    0.97161    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.062425589003366 for eigenvalue
#  The estimated number of batches is 1549
#      1375/1    0.98485    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.062003094350903 for eigenvalue
#  The estimated number of batches is 1549
#      1376/1    0.98371    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0612956550547592 for eigenvalue
#  The estimated number of batches is 1548
#      1377/1    0.97456    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0608071729104294 for eigenvalue
#  The estimated number of batches is 1548
#      1378/1    0.97652    0.97589 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0601509654451349 for eigenvalue
#  The estimated number of batches is 1547
#      1379/1    0.96769    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.061456657916276 for eigenvalue
#  The estimated number of batches is 1552
#      1380/1    0.96947    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0607904842798799 for eigenvalue
#  The estimated number of batches is 1551
#      1381/1    0.97623    0.97588 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0600054192697603 for eigenvalue
#  The estimated number of batches is 1550
#      1382/1    0.96772    0.97587 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0608868517511818 for eigenvalue
#  The estimated number of batches is 1553
#      1383/1    0.97686    0.97587 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0601137445534399 for eigenvalue
#  The estimated number of batches is 1552
#      1384/1    0.97592    0.97587 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0594208791327095 for eigenvalue
#  The estimated number of batches is 1551
#      1385/1    0.96459    0.97586 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.059462415219186 for eigenvalue
#  The estimated number of batches is 1553
#      1386/1    0.96680    0.97586 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0591545754276437 for eigenvalue
#  The estimated number of batches is 1553
#      1387/1    0.97104    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0583821611640873 for eigenvalue
#  The estimated number of batches is 1552
#      1388/1    0.97857    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0578272623284668 for eigenvalue
#  The estimated number of batches is 1551
#      1389/1    0.97930    0.97586 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0573529004008677 for eigenvalue
#  The estimated number of batches is 1551
#      1390/1    0.96713    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0571328571265894 for eigenvalue
#  The estimated number of batches is 1552
#      1391/1    0.97872    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0563839916841513 for eigenvalue
#  The estimated number of batches is 1550
#      1392/1    0.97086    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0563403201834314 for eigenvalue
#  The estimated number of batches is 1551
#      1393/1    0.97639    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0555920405023842 for eigenvalue
#  The estimated number of batches is 1550
#      1394/1    0.98162    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0548211196775996 for eigenvalue
#  The estimated number of batches is 1549
#      1395/1    0.96162    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0562497177250876 for eigenvalue
#  The estimated number of batches is 1555
#      1396/1    0.97031    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0555132716803175 for eigenvalue
#  The estimated number of batches is 1554
#      1397/1    0.97657    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0549247255688754 for eigenvalue
#  The estimated number of batches is 1553
#      1398/1    0.97015    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0543095276065595 for eigenvalue
#  The estimated number of batches is 1552
#      1399/1    0.98750    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.053792333156022 for eigenvalue
#  The estimated number of batches is 1552
#      1400/1    0.97157    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0536968773226825 for eigenvalue
#  The estimated number of batches is 1553
#      1401/1    0.97189    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0530108006597383 for eigenvalue
#  The estimated number of batches is 1552
#      1402/1    0.98180    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.052360433356109 for eigenvalue
#  The estimated number of batches is 1551
#      1403/1    0.97279    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.051786765160227 for eigenvalue
#  The estimated number of batches is 1550
#      1404/1    0.97470    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0510670365555943 for eigenvalue
#  The estimated number of batches is 1549
#      1405/1    0.97010    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0503379384080043 for eigenvalue
#  The estimated number of batches is 1548
#      1406/1    0.97995    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0515073036790983 for eigenvalue
#  The estimated number of batches is 1553
#      1407/1    0.98103    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0507507332334642 for eigenvalue
#  The estimated number of batches is 1552
#      1408/1    0.96911    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0499658436569372 for eigenvalue
#  The estimated number of batches is 1551
#      1409/1    0.97779    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0492253484963374 for eigenvalue
#  The estimated number of batches is 1550
#      1410/1    0.97730    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0484974897886497 for eigenvalue
#  The estimated number of batches is 1549
#      1411/1    0.97240    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0477532300159982 for eigenvalue
#  The estimated number of batches is 1548
#      1412/1    0.97592    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0471086191367727 for eigenvalue
#  The estimated number of batches is 1547
#      1413/1    0.97818    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.047312415899884 for eigenvalue
#  The estimated number of batches is 1548
#      1414/1    0.96964    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0466879247185017 for eigenvalue
#  The estimated number of batches is 1548
#      1415/1    0.97978    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0463289064492485 for eigenvalue
#  The estimated number of batches is 1548
#      1416/1    0.97513    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0456102942011642 for eigenvalue
#  The estimated number of batches is 1547
#      1417/1    0.97047    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.045403842724902 for eigenvalue
#  The estimated number of batches is 1547
#      1418/1    0.97625    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.045121016993043 for eigenvalue
#  The estimated number of batches is 1548
#      1419/1    0.98202    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0444646553988637 for eigenvalue
#  The estimated number of batches is 1547
#      1420/1    0.97734    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.043865560398355 for eigenvalue
#  The estimated number of batches is 1546
#      1421/1    0.98267    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0433124129232438 for eigenvalue
#  The estimated number of batches is 1545
#      1422/1    0.96539    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0429359967742036 for eigenvalue
#  The estimated number of batches is 1545
#      1423/1    0.98184    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0422747132207517 for eigenvalue
#  The estimated number of batches is 1545
#      1424/1    0.98264    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0419699521335373 for eigenvalue
#  The estimated number of batches is 1545
#      1425/1    0.98045    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0412439168025556 for eigenvalue
#  The estimated number of batches is 1544
#      1426/1    0.97409    0.97585 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0406176641160068 for eigenvalue
#  The estimated number of batches is 1543
#      1427/1    0.96570    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0410789978575916 for eigenvalue
#  The estimated number of batches is 1545
#      1428/1    0.96722    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0407421391370955 for eigenvalue
#  The estimated number of batches is 1546
#      1429/1    0.97724    0.97584 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.040195268597253 for eigenvalue
#  The estimated number of batches is 1545
#      1430/1    0.96979    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0400941499203584 for eigenvalue
#  The estimated number of batches is 1546
#      1431/1    0.97668    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.039586014365396 for eigenvalue
#  The estimated number of batches is 1545
#      1432/1    0.97727    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0388878265385457 for eigenvalue
#  The estimated number of batches is 1544
#      1433/1    0.96000    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0396867595525277 for eigenvalue
#  The estimated number of batches is 1548
#      1434/1    0.97976    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0391365727178699 for eigenvalue
#  The estimated number of batches is 1547
#      1435/1    0.98022    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0398324458073924 for eigenvalue
#  The estimated number of batches is 1550
#      1436/1    0.96950    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0398249714065504 for eigenvalue
#  The estimated number of batches is 1552
#      1437/1    0.98371    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0391324122202266 for eigenvalue
#  The estimated number of batches is 1551
#      1438/1    0.97165    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0385453390892854 for eigenvalue
#  The estimated number of batches is 1550
#      1439/1    0.97424    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0378987986258799 for eigenvalue
#  The estimated number of batches is 1549
#      1440/1    0.97948    0.97583 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0373243488678294 for eigenvalue
#  The estimated number of batches is 1548
#      1441/1    0.96873    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0368744268905152 for eigenvalue
#  The estimated number of batches is 1548
#      1442/1    0.97858    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0361562336560748 for eigenvalue
#  The estimated number of batches is 1547
#      1443/1    0.96999    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.035581026300078 for eigenvalue
#  The estimated number of batches is 1547
#      1444/1    0.97283    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.03557677079942 for eigenvalue
#  The estimated number of batches is 1548
#      1445/1    0.97550    0.97582 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0349882574544946 for eigenvalue
#  The estimated number of batches is 1547
#      1446/1    0.97123    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0342814702464513 for eigenvalue
#  The estimated number of batches is 1546
#      1447/1    0.97555    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.033560275856224 for eigenvalue
#  The estimated number of batches is 1545
#      1448/1    0.97631    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0328101486303884 for eigenvalue
#  The estimated number of batches is 1544
#      1449/1    0.97843    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0321107341422777 for eigenvalue
#  The estimated number of batches is 1543
#      1450/1    0.98653    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0314560530028116 for eigenvalue
#  The estimated number of batches is 1542
#      1451/1    0.97496    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0311549826530797 for eigenvalue
#  The estimated number of batches is 1542
#      1452/1    0.97444    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.030540632032166 for eigenvalue
#  The estimated number of batches is 1541
#      1453/1    0.97898    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.029992232769425 for eigenvalue
#  The estimated number of batches is 1541
#      1454/1    0.97601    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.029286203056791 for eigenvalue
#  The estimated number of batches is 1540
#      1455/1    0.97215    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0287670471390309 for eigenvalue
#  The estimated number of batches is 1539
#      1456/1    0.98079    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0289431920980805 for eigenvalue
#  The estimated number of batches is 1541
#      1457/1    0.97144    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0283018068288898 for eigenvalue
#  The estimated number of batches is 1540
#      1458/1    0.97609    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0276166619251468 for eigenvalue
#  The estimated number of batches is 1539
#      1459/1    0.98058    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.026877361471167 for eigenvalue
#  The estimated number of batches is 1538
#      1460/1    0.97640    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.026193528797321 for eigenvalue
#  The estimated number of batches is 1537
