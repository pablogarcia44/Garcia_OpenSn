# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %% [markdown]
# def instru(index_x,index_y):
#     clad_inner_radius = openmc.ZCylinder(r=0.559)
#     clad_outer_radius = openmc.ZCylinder(r=0.605)
#     pitch = 1.26
#     left = openmc.XPlane(-pitch/2, boundary_type='transmission')
#     right = openmc.XPlane(pitch/2, boundary_type='transmission')
#     bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
#     top = openmc.YPlane(pitch/2, boundary_type='transmission')
#     clad_region = +clad_inner_radius & -clad_outer_radius
#     water_region = +left & -right & +bottom & -top & +clad_outer_radius
#     water_guide_region= -clad_inner_radius
#     water_guide = openmc.Cell(name='water_guide'+'_'+str(index_x)+'_'+str(index_y))
#     water_guide.fill = water
#     water_guide.region = water_guide_region
#     clad = openmc.Cell(name='clad_guide'+'_'+str(index_x)+'_'+str(index_y))
#     clad.fill = zirconium
#     clad.region = clad_region
#     moderator = openmc.Cell(name='moderator'+'_'+str(index_x)+'_'+str(index_y))
#     moderator.fill = water
#     moderator.region = water_region
#     u = openmc.Universe(name='u_guide'+'_'+str(index_x)+'_'+str(index_y),cells=(water_guide, clad, moderator))
#     return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create Instrument Thimble

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    instru_inner_radius = openmc.ZCylinder(0.258)
    instry_outer_radius= openmc.ZCylinder(0.382)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission') 

    
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius | -instru_inner_radius | +instry_outer_radius & -clad_inner_radius
    instru_region = +instru_inner_radius & -instry_outer_radius

    water_cell = openmc.Cell(name='water_cell'+family)
    water_cell.fill = water
    water_cell.region = water_region
    clad_cell = openmc.Cell(name='clad_cell'+family)
    clad_cell.fill = zirconium
    clad_cell.region = clad_region
    instru_cell = openmc.Cell(name='instru_cell'+family)
    instru_cell.fill = SS304
    instru_cell.region = instru_region
    
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_cell, clad_cell, instru_cell))
    return(u,water_cell,clad_cell,instru_cell)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]

PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Create power tally

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=553.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=3.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=11.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:06
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.96345
#         2/1    0.96857
#         3/1    0.97880
#         4/1    0.97603
#         5/1    0.97014
#         6/1    0.96924
#         7/1    0.97934
#         8/1    0.97297
#         9/1    0.96955
#        10/1    0.96872
#        11/1    0.96889
#        12/1    0.96747
#        13/1    0.96627
#        14/1    0.98005
#        15/1    0.97003
#        16/1    0.97435
#        17/1    0.96754
#        18/1    0.96509
#        19/1    0.98296
#        20/1    0.97451
#        21/1    0.96843
#        22/1    0.97004    0.96923 +/- 0.00081
#        23/1    0.97765    0.97204 +/- 0.00284
#        24/1    0.96493    0.97026 +/- 0.00268
#        25/1    0.97531    0.97127 +/- 0.00231
#        26/1    0.96567    0.97034 +/- 0.00211
#        27/1    0.97975    0.97168 +/- 0.00223
#        28/1    0.97474    0.97207 +/- 0.00197
#        29/1    0.96524    0.97131 +/- 0.00189
#        30/1    0.97564    0.97174 +/- 0.00175
#        31/1    0.96646    0.97126 +/- 0.00165
#        32/1    0.97625    0.97168 +/- 0.00157
#        33/1    0.97185    0.97169 +/- 0.00144
#        34/1    0.97170    0.97169 +/- 0.00133
#        35/1    0.96926    0.97153 +/- 0.00125
#        36/1    0.96949    0.97140 +/- 0.00118
#        37/1    0.97666    0.97171 +/- 0.00115
#        38/1    0.96976    0.97160 +/- 0.00109
#        39/1    0.97153    0.97160 +/- 0.00103
#        40/1    0.97328    0.97168 +/- 0.00098
#        41/1    0.98026    0.97209 +/- 0.00102
#        42/1    0.96661    0.97184 +/- 0.00100
#        43/1    0.97224    0.97186 +/- 0.00096
#        44/1    0.97540    0.97201 +/- 0.00093
#        45/1    0.97661    0.97219 +/- 0.00091
#        46/1    0.96958    0.97209 +/- 0.00088
#        47/1    0.97726    0.97228 +/- 0.00087
#        48/1    0.99077    0.97294 +/- 0.00107
#        49/1    0.97047    0.97286 +/- 0.00103
#        50/1    0.97071    0.97279 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 9.065262449422109 for eigenvalue
#  The estimated number of batches is 2486
#  Creating state point statepoint.00050.h5...
#        51/1    0.96994    0.97269 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 8.724589510271521 for eigenvalue
#  The estimated number of batches is 2380
#        52/1    0.97246    0.97269 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 8.44644862914431 for eigenvalue
#  The estimated number of batches is 2303
#        53/1    0.96910    0.97258 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 8.176491675526854 for eigenvalue
#  The estimated number of batches is 2227
#        54/1    0.96591    0.97238 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 8.050952627797118 for eigenvalue
#  The estimated number of batches is 2224
#        55/1    0.97568    0.97248 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 7.891044313645275 for eigenvalue
#  The estimated number of batches is 2200
#        56/1    0.97062    0.97242 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 7.789531337678073 for eigenvalue
#  The estimated number of batches is 2205
#        57/1    0.95287    0.97190 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 7.943747249137597 for eigenvalue
#  The estimated number of batches is 2355
#        58/1    0.97952    0.97210 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 7.784260178134093 for eigenvalue
#  The estimated number of batches is 2323
#        59/1    0.97628    0.97220 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 7.605124936610354 for eigenvalue
#  The estimated number of batches is 2276
#        60/1    0.97586    0.97229 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 7.420125216318813 for eigenvalue
#  The estimated number of batches is 2223
#        61/1    0.97081    0.97226 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 7.227522750792726 for eigenvalue
#  The estimated number of batches is 2162
#        62/1    0.97186    0.97225 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 7.068954440500115 for eigenvalue
#  The estimated number of batches is 2119
#        63/1    0.97066    0.97221 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 6.922561083963013 for eigenvalue
#  The estimated number of batches is 2081
#        64/1    0.97813    0.97235 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 6.803152467537157 for eigenvalue
#  The estimated number of batches is 2057
#        65/1    0.97696    0.97245 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.6933801889051745 for eigenvalue
#  The estimated number of batches is 2037
#        66/1    0.98210    0.97266 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 6.678172060227905 for eigenvalue
#  The estimated number of batches is 2072
#        67/1    0.97365    0.97268 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.5618734620579735 for eigenvalue
#  The estimated number of batches is 2044
#        68/1    0.96624    0.97255 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 6.659976200479975 for eigenvalue
#  The estimated number of batches is 2150
#        69/1    0.97704    0.97264 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 6.5720914690557555 for eigenvalue
#  The estimated number of batches is 2137
#        70/1    0.96584    0.97250 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 6.449553910158729 for eigenvalue
#  The estimated number of batches is 2100
#        71/1    0.98750    0.97280 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.471726751920421 for eigenvalue
#  The estimated number of batches is 2157
#        72/1    0.97057    0.97275 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 6.342585041157638 for eigenvalue
#  The estimated number of batches is 2112
#        73/1    0.98526    0.97299 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.278197065505841 for eigenvalue
#  The estimated number of batches is 2110
#        74/1    0.97463    0.97302 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.20582688128391 for eigenvalue
#  The estimated number of batches is 2100
#        75/1    0.97344    0.97303 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 6.111367137241702 for eigenvalue
#  The estimated number of batches is 2075
#        76/1    0.97618    0.97308 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 6.073285904659903 for eigenvalue
#  The estimated number of batches is 2086
#        77/1    0.97307    0.97308 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.065227307914632 for eigenvalue
#  The estimated number of batches is 2117
#        78/1    0.96599    0.97296 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.129173539170303 for eigenvalue
#  The estimated number of batches is 2199
#        79/1    0.97235    0.97295 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 6.05187431175733 for eigenvalue
#  The estimated number of batches is 2181
#        80/1    0.96881    0.97288 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.914792368899609 for eigenvalue
#  The estimated number of batches is 2120
#        81/1    0.96709    0.97279 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.809300982120287 for eigenvalue
#  The estimated number of batches is 2079
#        82/1    0.98203    0.97294 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.7833691797521185 for eigenvalue
#  The estimated number of batches is 2094
#        83/1    0.97285    0.97293 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.693587020672425 for eigenvalue
#  The estimated number of batches is 2063
#        84/1    0.97069    0.97290 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.625386276884984 for eigenvalue
#  The estimated number of batches is 2046
#        85/1    0.96022    0.97270 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.644964207910513 for eigenvalue
#  The estimated number of batches is 2092
#        86/1    0.96810    0.97263 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.5597896024437 for eigenvalue
#  The estimated number of batches is 2061
#        87/1    0.97389    0.97265 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.509696077867062 for eigenvalue
#  The estimated number of batches is 2054
#        88/1    0.97179    0.97264 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.4030426292281195 for eigenvalue
#  The estimated number of batches is 2006
#        89/1    0.98173    0.97277 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.349304085362094 for eigenvalue
#  The estimated number of batches is 1995
#        90/1    0.97000    0.97273 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.463990563603333 for eigenvalue
#  The estimated number of batches is 2110
#        91/1    0.97807    0.97281 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.404022163941469 for eigenvalue
#  The estimated number of batches is 2094
#        92/1    0.97208    0.97280 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.414488885557744 for eigenvalue
#  The estimated number of batches is 2131
#        93/1    0.97496    0.97283 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.418004759876744 for eigenvalue
#  The estimated number of batches is 2163
#        94/1    0.97616    0.97287 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.363435646582933 for eigenvalue
#  The estimated number of batches is 2149
#        95/1    0.97771    0.97294 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.304979166417384 for eigenvalue
#  The estimated number of batches is 2131
#        96/1    0.97044    0.97290 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.270618461883271 for eigenvalue
#  The estimated number of batches is 2132
#        97/1    0.97777    0.97297 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.231160046967461 for eigenvalue
#  The estimated number of batches is 2128
#        98/1    0.96359    0.97285 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.197037747058201 for eigenvalue
#  The estimated number of batches is 2127
#        99/1    0.97260    0.97284 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 5.133595706401975 for eigenvalue
#  The estimated number of batches is 2102
#       100/1    0.96843    0.97279 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 5.10521820399046 for eigenvalue
#  The estimated number of batches is 2106
#       101/1    0.96265    0.97266 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 5.172108415652929 for eigenvalue
#  The estimated number of batches is 2187
#       102/1    0.97026    0.97263 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.133316248761759 for eigenvalue
#  The estimated number of batches is 2181
#       103/1    0.96578    0.97255 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.053810678731873 for eigenvalue
#  The estimated number of batches is 2140
#       104/1    0.96664    0.97248 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.963406446768989 for eigenvalue
#  The estimated number of batches is 2090
#       105/1    0.97744    0.97254 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.9232954635310735 for eigenvalue
#  The estimated number of batches is 2081
#       106/1    0.97424    0.97256 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.874500753804469 for eigenvalue
#  The estimated number of batches is 2064
#       107/1    0.96952    0.97252 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.8415616744317305 for eigenvalue
#  The estimated number of batches is 2060
#       108/1    0.96588    0.97245 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.8491489045395255 for eigenvalue
#  The estimated number of batches is 2090
#       109/1    0.97337    0.97246 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.80780318020128 for eigenvalue
#  The estimated number of batches is 2078
#       110/1    0.97628    0.97250 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.762213121626122 for eigenvalue
#  The estimated number of batches is 2062
#       111/1    0.96938    0.97247 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.701916914624155 for eigenvalue
#  The estimated number of batches is 2032
#       112/1    0.97061    0.97245 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.639120964706391 for eigenvalue
#  The estimated number of batches is 2000
#       113/1    0.97145    0.97244 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.6025003635653094 for eigenvalue
#  The estimated number of batches is 1991
#       114/1    0.98042    0.97252 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.594126041451895 for eigenvalue
#  The estimated number of batches is 2004
#       115/1    0.97057    0.97250 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.564100386400341 for eigenvalue
#  The estimated number of batches is 1999
#       116/1    0.97722    0.97255 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.558327048141755 for eigenvalue
#  The estimated number of batches is 2015
#       117/1    0.97497    0.97257 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.5241759311131915 for eigenvalue
#  The estimated number of batches is 2006
#       118/1    0.98289    0.97268 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.536421082355353 for eigenvalue
#  The estimated number of batches is 2037
#       119/1    0.97113    0.97266 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.496040518765316 for eigenvalue
#  The estimated number of batches is 2022
#       120/1    0.97628    0.97270 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.459554129528052 for eigenvalue
#  The estimated number of batches is 2009
#       121/1    0.96867    0.97266 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.406546932003963 for eigenvalue
#  The estimated number of batches is 1982
#       122/1    0.96176    0.97255 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.369660697865093 for eigenvalue
#  The estimated number of batches is 1968
#       123/1    0.97143    0.97254 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.3303552913588135 for eigenvalue
#  The estimated number of batches is 1952
#       124/1    0.97747    0.97259 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.287924775946016 for eigenvalue
#  The estimated number of batches is 1933
#       125/1    0.97159    0.97258 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.263271255019794 for eigenvalue
#  The estimated number of batches is 1929
#       126/1    0.98136    0.97266 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.270508118406471 for eigenvalue
#  The estimated number of batches is 1954
#       127/1    0.97670    0.97270 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.240741631160672 for eigenvalue
#  The estimated number of batches is 1945
#       128/1    0.97985    0.97277 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.210887493639182 for eigenvalue
#  The estimated number of batches is 1936
#       129/1    0.97481    0.97279 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.173024133277726 for eigenvalue
#  The estimated number of batches is 1919
#       130/1    0.96346    0.97270 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.185516767196701 for eigenvalue
#  The estimated number of batches is 1948
#       131/1    0.97690    0.97274 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.160470032381008 for eigenvalue
#  The estimated number of batches is 1942
#       132/1    0.96566    0.97268 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.12970086407973 for eigenvalue
#  The estimated number of batches is 1931
#       133/1    0.97843    0.97273 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.132827493065872 for eigenvalue
#  The estimated number of batches is 1951
#       134/1    0.96037    0.97262 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.0840707322553715 for eigenvalue
#  The estimated number of batches is 1922
#       135/1    0.98139    0.97269 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.068124619835375 for eigenvalue
#  The estimated number of batches is 1924
#       136/1    0.97556    0.97272 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.040846320495702 for eigenvalue
#  The estimated number of batches is 1915
#       137/1    0.97633    0.97275 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.029433215354458 for eigenvalue
#  The estimated number of batches is 1920
#       138/1    0.96971    0.97272 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9953805793407473 for eigenvalue
#  The estimated number of batches is 1904
#       139/1    0.96821    0.97269 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.950598442843456 for eigenvalue
#  The estimated number of batches is 1878
#       140/1    0.96759    0.97264 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.929444966673861 for eigenvalue
#  The estimated number of batches is 1873
#       141/1    0.96989    0.97262 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8929194941858425 for eigenvalue
#  The estimated number of batches is 1854
#       142/1    0.97232    0.97262 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8646162240604824 for eigenvalue
#  The estimated number of batches is 1843
#       143/1    0.97734    0.97266 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8591661598581415 for eigenvalue
#  The estimated number of batches is 1852
#       144/1    0.97289    0.97266 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.831656164081814 for eigenvalue
#  The estimated number of batches is 1841
#       145/1    0.96646    0.97261 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.8118490379626357 for eigenvalue
#  The estimated number of batches is 1837
#       146/1    0.96658    0.97256 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.779430631760735 for eigenvalue
#  The estimated number of batches is 1820
#       147/1    0.97062    0.97255 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7496336118256717 for eigenvalue
#  The estimated number of batches is 1806
#       148/1    0.97325    0.97255 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.743569696318887 for eigenvalue
#  The estimated number of batches is 1814
#       149/1    0.97014    0.97253 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.717511293475454 for eigenvalue
#  The estimated number of batches is 1803
#       150/1    0.97893    0.97258 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6842631198613254 for eigenvalue
#  The estimated number of batches is 1785
#       151/1    0.98035    0.97264 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.679735067000769 for eigenvalue
#  The estimated number of batches is 1794
#       152/1    0.98043    0.97270 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.679256007531841 for eigenvalue
#  The estimated number of batches is 1807
#       153/1    0.97152    0.97269 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6413958319330875 for eigenvalue
#  The estimated number of batches is 1784
#       154/1    0.96793    0.97266 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6199363305169108 for eigenvalue
#  The estimated number of batches is 1776
#       155/1    0.97443    0.97267 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.598351810724042 for eigenvalue
#  The estimated number of batches is 1768
#       156/1    0.97102    0.97266 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.660496808045036 for eigenvalue
#  The estimated number of batches is 1843
#       157/1    0.97554    0.97268 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.6427656466258815 for eigenvalue
#  The estimated number of batches is 1838
#       158/1    0.97185    0.97267 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.609761944074757 for eigenvalue
#  The estimated number of batches is 1819
#       159/1    0.97432    0.97268 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5837779662326787 for eigenvalue
#  The estimated number of batches is 1806
#       160/1    0.97809    0.97272 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.606235247387053 for eigenvalue
#  The estimated number of batches is 1841
#       161/1    0.96920    0.97270 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5748473234718414 for eigenvalue
#  The estimated number of batches is 1822
#       162/1    0.96523    0.97265 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.551810383155338 for eigenvalue
#  The estimated number of batches is 1812
#       163/1    0.96905    0.97262 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.520733696653327 for eigenvalue
#  The estimated number of batches is 1793
#       164/1    0.97201    0.97262 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4928163866799613 for eigenvalue
#  The estimated number of batches is 1777
#       165/1    0.97584    0.97264 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.477074602708401 for eigenvalue
#  The estimated number of batches is 1774
#       166/1    0.96220    0.97257 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.482382268145838 for eigenvalue
#  The estimated number of batches is 1791
#       167/1    0.97065    0.97255 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4506670519291216 for eigenvalue
#  The estimated number of batches is 1771
#       168/1    0.98142    0.97261 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.451866980879103 for eigenvalue
#  The estimated number of batches is 1784
#       169/1    0.96966    0.97259 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4359247146598584 for eigenvalue
#  The estimated number of batches is 1780
#       170/1    0.96941    0.97257 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.416867277985522 for eigenvalue
#  The estimated number of batches is 1772
#       171/1    0.96608    0.97253 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4132524689908874 for eigenvalue
#  The estimated number of batches is 1780
#       172/1    0.97116    0.97252 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3981208593652945 for eigenvalue
#  The estimated number of batches is 1776
#       173/1    0.96900    0.97250 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.373352242058688 for eigenvalue
#  The estimated number of batches is 1762
#       174/1    0.97654    0.97252 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3809847150679504 for eigenvalue
#  The estimated number of batches is 1781
#       175/1    0.97052    0.97251 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3588484273440256 for eigenvalue
#  The estimated number of batches is 1769
#       176/1    0.98164    0.97257 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3701644167570817 for eigenvalue
#  The estimated number of batches is 1792
#       177/1    0.97555    0.97259 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3574835772303215 for eigenvalue
#  The estimated number of batches is 1790
#       178/1    0.97386    0.97260 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3418115815638436 for eigenvalue
#  The estimated number of batches is 1785
#       179/1    0.97479    0.97261 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.369967851524355 for eigenvalue
#  The estimated number of batches is 1826
#       180/1    0.97354    0.97262 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3489660053369112 for eigenvalue
#  The estimated number of batches is 1815
#       181/1    0.97518    0.97263 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.333178188686265 for eigenvalue
#  The estimated number of batches is 1809
#       182/1    0.97169    0.97263 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.314080569545155 for eigenvalue
#  The estimated number of batches is 1800
#       183/1    0.96959    0.97261 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.309335432504668 for eigenvalue
#  The estimated number of batches is 1806
#       184/1    0.96914    0.97259 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.294697510710042 for eigenvalue
#  The estimated number of batches is 1801
#       185/1    0.96408    0.97254 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.281835580786129 for eigenvalue
#  The estimated number of batches is 1798
#       186/1    0.96813    0.97251 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2595851803032794 for eigenvalue
#  The estimated number of batches is 1784
#       187/1    0.97897    0.97255 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2471577662779083 for eigenvalue
#  The estimated number of batches is 1781
#       188/1    0.96868    0.97252 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.2251886899753135 for eigenvalue
#  The estimated number of batches is 1768
#       189/1    0.97205    0.97252 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.2106773351993425 for eigenvalue
#  The estimated number of batches is 1763
#       190/1    0.96783    0.97249 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.2012054210234857 for eigenvalue
#  The estimated number of batches is 1763
#       191/1    0.97451    0.97251 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1849059817875687 for eigenvalue
#  The estimated number of batches is 1755
#       192/1    0.97244    0.97251 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1795076839720586 for eigenvalue
#  The estimated number of batches is 1759
#       193/1    0.97753    0.97253 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.170853761382504 for eigenvalue
#  The estimated number of batches is 1760
#       194/1    0.98218    0.97259 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1697759368986986 for eigenvalue
#  The estimated number of batches is 1769
#       195/1    0.97134    0.97258 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1493955731207586 for eigenvalue
#  The estimated number of batches is 1756
#       196/1    0.96918    0.97256 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.123171212884388 for eigenvalue
#  The estimated number of batches is 1737
#       197/1    0.97235    0.97256 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.106398776420145 for eigenvalue
#  The estimated number of batches is 1728
#       198/1    0.97858    0.97260 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.113720730567161 for eigenvalue
#  The estimated number of batches is 1746
#       199/1    0.97084    0.97259 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.135541924858848 for eigenvalue
#  The estimated number of batches is 1780
#       200/1    0.97139    0.97258 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.1358122415243885 for eigenvalue
#  The estimated number of batches is 1790
#       201/1    0.97726    0.97261 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.1178887796732893 for eigenvalue
#  The estimated number of batches is 1780
#       202/1    0.97272    0.97261 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.1017199716834694 for eigenvalue
#  The estimated number of batches is 1771
#       203/1    0.97324    0.97261 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.081973894456948 for eigenvalue
#  The estimated number of batches is 1759
#       204/1    0.97647    0.97263 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0685294862039845 for eigenvalue
#  The estimated number of batches is 1753
#       205/1    0.97469    0.97264 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.052447506917607 for eigenvalue
#  The estimated number of batches is 1744
#       206/1    0.96992    0.97263 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.059627197653325 for eigenvalue
#  The estimated number of batches is 1762
#       207/1    0.97788    0.97266 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.0600642424253603 for eigenvalue
#  The estimated number of batches is 1772
#       208/1    0.97196    0.97265 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.0462161939111048 for eigenvalue
#  The estimated number of batches is 1765
#       209/1    0.97636    0.97267 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.0337635081882413 for eigenvalue
#  The estimated number of batches is 1760
#       210/1    0.97237    0.97267 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.0164323888721425 for eigenvalue
#  The estimated number of batches is 1749
#       211/1    0.97725    0.97269 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.0023863251956837 for eigenvalue
#  The estimated number of batches is 1742
#       212/1    0.96362    0.97265 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.99069897601088 for eigenvalue
#  The estimated number of batches is 1738
#       213/1    0.97461    0.97266 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.979040164911308 for eigenvalue
#  The estimated number of batches is 1733
#       214/1    0.96913    0.97264 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.9732940637013154 for eigenvalue
#  The estimated number of batches is 1736
#       215/1    0.96135    0.97258 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.9598541992212235 for eigenvalue
#  The estimated number of batches is 1729
#       216/1    0.96970    0.97257 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.944629096472963 for eigenvalue
#  The estimated number of batches is 1720
#       217/1    0.97205    0.97256 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.9317920099504597 for eigenvalue
#  The estimated number of batches is 1714
#       218/1    0.96891    0.97254 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.9177817567223565 for eigenvalue
#  The estimated number of batches is 1706
#       219/1    0.96858    0.97252 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.922131565461373 for eigenvalue
#  The estimated number of batches is 1720
#       220/1    0.97150    0.97252 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9095090700141184 for eigenvalue
#  The estimated number of batches is 1714
#       221/1    0.97532    0.97253 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8942019507521253 for eigenvalue
#  The estimated number of batches is 1704
#       222/1    0.97834    0.97256 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8799411777047355 for eigenvalue
#  The estimated number of batches is 1696
#       223/1    0.97291    0.97256 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8775437938543 for eigenvalue
#  The estimated number of batches is 1701
#       224/1    0.96989    0.97255 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.859101328500898 for eigenvalue
#  The estimated number of batches is 1688
#       225/1    0.96982    0.97254 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.84743330213698 for eigenvalue
#  The estimated number of batches is 1683
#       226/1    0.97517    0.97255 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.833795137568928 for eigenvalue
#  The estimated number of batches is 1675
#       227/1    0.97114    0.97254 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.819867572042218 for eigenvalue
#  The estimated number of batches is 1666
#       228/1    0.96090    0.97249 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.818595396509966 for eigenvalue
#  The estimated number of batches is 1673
#       229/1    0.96315    0.97244 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.813097818984786 for eigenvalue
#  The estimated number of batches is 1674
#       230/1    0.97748    0.97247 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8035920005212973 for eigenvalue
#  The estimated number of batches is 1671
#       231/1    0.97211    0.97246 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.7967956000807934 for eigenvalue
#  The estimated number of batches is 1671
#       232/1    0.97200    0.97246 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7983366825267373 for eigenvalue
#  The estimated number of batches is 1681
#       233/1    0.96931    0.97245 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.782727356603942 for eigenvalue
#  The estimated number of batches is 1670
#       234/1    0.97655    0.97247 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7766713071102007 for eigenvalue
#  The estimated number of batches is 1670
#       235/1    0.97343    0.97247 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.765756828841108 for eigenvalue
#  The estimated number of batches is 1665
#       236/1    0.97060    0.97246 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.750107036726813 for eigenvalue
#  The estimated number of batches is 1654
#       237/1    0.97341    0.97247 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.740130703671575 for eigenvalue
#  The estimated number of batches is 1650
#       238/1    0.97531    0.97248 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.734590459507076 for eigenvalue
#  The estimated number of batches is 1651
#       239/1    0.97059    0.97247 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7196794308286143 for eigenvalue
#  The estimated number of batches is 1640
#       240/1    0.97012    0.97246 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7071162828718704 for eigenvalue
#  The estimated number of batches is 1633
#       241/1    0.96898    0.97245 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6961940022248987 for eigenvalue
#  The estimated number of batches is 1627
#       242/1    0.97618    0.97246 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.688268274597142 for eigenvalue
#  The estimated number of batches is 1625
#       243/1    0.96731    0.97244 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6767296181659876 for eigenvalue
#  The estimated number of batches is 1618
#       244/1    0.96506    0.97241 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6726043137836775 for eigenvalue
#  The estimated number of batches is 1620
#       245/1    0.97699    0.97243 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.660624063482153 for eigenvalue
#  The estimated number of batches is 1613
#       246/1    0.97422    0.97243 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.653400179038024 for eigenvalue
#  The estimated number of batches is 1612
#       247/1    0.96645    0.97241 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6490067338127425 for eigenvalue
#  The estimated number of batches is 1613
#       248/1    0.96202    0.97236 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.644202364630863 for eigenvalue
#  The estimated number of batches is 1615
#       249/1    0.97193    0.97236 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6338646631059848 for eigenvalue
#  The estimated number of batches is 1609
#       250/1    0.97235    0.97236 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.623604023441706 for eigenvalue
#  The estimated number of batches is 1604
#       251/1    0.96457    0.97233 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.612555927279291 for eigenvalue
#  The estimated number of batches is 1597
#       252/1    0.96559    0.97230 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.6014320489302465 for eigenvalue
#  The estimated number of batches is 1591
#       253/1    0.97420    0.97231 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.594961568541211 for eigenvalue
#  The estimated number of batches is 1589
#       254/1    0.97202    0.97230 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5867980382466547 for eigenvalue
#  The estimated number of batches is 1586
#       255/1    0.97794    0.97233 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.594999027703622 for eigenvalue
#  The estimated number of batches is 1603
#       256/1    0.97120    0.97232 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5841999374039473 for eigenvalue
#  The estimated number of batches is 1597
#       257/1    0.97334    0.97233 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.572705035608093 for eigenvalue
#  The estimated number of batches is 1589
#       258/1    0.96137    0.97228 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5848653437463573 for eigenvalue
#  The estimated number of batches is 1611
#       259/1    0.97440    0.97229 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.580463318696125 for eigenvalue
#  The estimated number of batches is 1612
#       260/1    0.96924    0.97228 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.575172151921293 for eigenvalue
#  The estimated number of batches is 1612
#       261/1    0.97575    0.97229 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5648363978887865 for eigenvalue
#  The estimated number of batches is 1606
#       262/1    0.96780    0.97227 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5580399605756403 for eigenvalue
#  The estimated number of batches is 1604
#       263/1    0.96973    0.97226 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.547206561182144 for eigenvalue
#  The estimated number of batches is 1597
#       264/1    0.97147    0.97226 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.536348016748596 for eigenvalue
#  The estimated number of batches is 1590
#       265/1    0.97424    0.97227 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.528120364208613 for eigenvalue
#  The estimated number of batches is 1586
#       266/1    0.97656    0.97229 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5211089275549434 for eigenvalue
#  The estimated number of batches is 1584
#       267/1    0.97036    0.97228 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5112938657384363 for eigenvalue
#  The estimated number of batches is 1578
#       268/1    0.96670    0.97226 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5201905065214985 for eigenvalue
#  The estimated number of batches is 1596
#       269/1    0.97570    0.97227 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.511816496344054 for eigenvalue
#  The estimated number of batches is 1591
#       270/1    0.96657    0.97225 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.529992207504781 for eigenvalue
#  The estimated number of batches is 1621
#       271/1    0.96453    0.97222 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.529018044114955 for eigenvalue
#  The estimated number of batches is 1626
#       272/1    0.97584    0.97223 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5202740289892502 for eigenvalue
#  The estimated number of batches is 1621
#       273/1    0.97034    0.97222 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.514675151639633 for eigenvalue
#  The estimated number of batches is 1620
#       274/1    0.98047    0.97226 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5234175398940444 for eigenvalue
#  The estimated number of batches is 1638
#       275/1    0.96675    0.97223 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.514758080350552 for eigenvalue
#  The estimated number of batches is 1633
#       276/1    0.97726    0.97225 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.515540918545522 for eigenvalue
#  The estimated number of batches is 1640
#       277/1    0.97406    0.97226 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.506140246564404 for eigenvalue
#  The estimated number of batches is 1635
#       278/1    0.97547    0.97227 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.499180382870381 for eigenvalue
#  The estimated number of batches is 1632
#       279/1    0.97658    0.97229 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5022239124065186 for eigenvalue
#  The estimated number of batches is 1642
#       280/1    0.97059    0.97228 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.494981024481785 for eigenvalue
#  The estimated number of batches is 1639
#       281/1    0.97388    0.97229 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4849134729975995 for eigenvalue
#  The estimated number of batches is 1632
#       282/1    0.97133    0.97229 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4790749382505113 for eigenvalue
#  The estimated number of batches is 1631
#       283/1    0.96187    0.97225 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4821162078315266 for eigenvalue
#  The estimated number of batches is 1641
#       284/1    0.97407    0.97225 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.479475936348897 for eigenvalue
#  The estimated number of batches is 1644
#       285/1    0.97564    0.97227 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4713202329742563 for eigenvalue
#  The estimated number of batches is 1639
#       286/1    0.97413    0.97227 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.463039440305926 for eigenvalue
#  The estimated number of batches is 1634
#       287/1    0.96917    0.97226 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.472485702291895 for eigenvalue
#  The estimated number of batches is 1653
#       288/1    0.96344    0.97223 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4708191005409654 for eigenvalue
#  The estimated number of batches is 1657
#       289/1    0.97376    0.97223 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4646372995251076 for eigenvalue
#  The estimated number of batches is 1655
#       290/1    0.96103    0.97219 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4541157593979372 for eigenvalue
#  The estimated number of batches is 1647
#       291/1    0.98596    0.97224 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4740607368801983 for eigenvalue
#  The estimated number of batches is 1679
#       292/1    0.97281    0.97224 +/- 0.00032
# ...
#  The estimated number of batches is 1474
#       723/1    0.96994    0.97188 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4368286762410172 for eigenvalue
#  The estimated number of batches is 1472
#       724/1    0.96678    0.97187 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4374397135128136 for eigenvalue
#  The estimated number of batches is 1475
#       725/1    0.97062    0.97187 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4354420097519118 for eigenvalue
#  The estimated number of batches is 1473
#       726/1    0.96499    0.97186 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4346885836518148 for eigenvalue
#  The estimated number of batches is 1474
#       727/1    0.97862    0.97187 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4333390110321471 for eigenvalue
#  The estimated number of batches is 1473
#       728/1    0.97044    0.97187 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4321231703225024 for eigenvalue
#  The estimated number of batches is 1473
#       729/1    0.97435    0.97187 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4300392191486067 for eigenvalue
#  The estimated number of batches is 1470
#       730/1    0.97145    0.97187 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4281799138213944 for eigenvalue
#  The estimated number of batches is 1469
#       731/1    0.96602    0.97186 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4271938849223924 for eigenvalue
#  The estimated number of batches is 1469
#       732/1    0.96499    0.97185 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4275116258704856 for eigenvalue
#  The estimated number of batches is 1471
#       733/1    0.97074    0.97185 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4255885152097285 for eigenvalue
#  The estimated number of batches is 1470
#       734/1    0.97389    0.97185 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4235770796916123 for eigenvalue
#  The estimated number of batches is 1467
#       735/1    0.96477    0.97184 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4218354055276912 for eigenvalue
#  The estimated number of batches is 1466
#       736/1    0.97462    0.97185 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.41995842932925 for eigenvalue
#  The estimated number of batches is 1464
#       737/1    0.96029    0.97183 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4187950933604658 for eigenvalue
#  The estimated number of batches is 1464
#       738/1    0.97126    0.97183 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4189258908458804 for eigenvalue
#  The estimated number of batches is 1466
#       739/1    0.97419    0.97183 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4171663635975833 for eigenvalue
#  The estimated number of batches is 1465
#       740/1    0.98084    0.97185 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4150112775868235 for eigenvalue
#  The estimated number of batches is 1462
#       741/1    0.97308    0.97185 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4129243478028086 for eigenvalue
#  The estimated number of batches is 1460
#       742/1    0.97375    0.97185 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4111403103834397 for eigenvalue
#  The estimated number of batches is 1458
#       743/1    0.97892    0.97186 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.409588104282899 for eigenvalue
#  The estimated number of batches is 1457
#       744/1    0.97080    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.408175481474417 for eigenvalue
#  The estimated number of batches is 1456
#       745/1    0.97228    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4064208765818784 for eigenvalue
#  The estimated number of batches is 1455
#       746/1    0.97416    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4044821649943613 for eigenvalue
#  The estimated number of batches is 1453
#       747/1    0.97313    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4025653577376476 for eigenvalue
#  The estimated number of batches is 1451
#       748/1    0.97890    0.97187 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.40187565141551 for eigenvalue
#  The estimated number of batches is 1451
#       749/1    0.96524    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.401717989346675 for eigenvalue
#  The estimated number of batches is 1453
#       750/1    0.97330    0.97187 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4026992799501277 for eigenvalue
#  The estimated number of batches is 1457
#       751/1    0.96623    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4026369600959705 for eigenvalue
#  The estimated number of batches is 1459
#       752/1    0.97011    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4008429967679694 for eigenvalue
#  The estimated number of batches is 1457
#       753/1    0.96531    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3990859320539686 for eigenvalue
#  The estimated number of batches is 1455
#       754/1    0.97708    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.39740334358659 for eigenvalue
#  The estimated number of batches is 1454
#       755/1    0.96782    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.395899391352506 for eigenvalue
#  The estimated number of batches is 1453
#       756/1    0.97020    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3944191266536832 for eigenvalue
#  The estimated number of batches is 1452
#       757/1    0.97821    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3924850709417085 for eigenvalue
#  The estimated number of batches is 1450
#       758/1    0.96691    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.390739030179445 for eigenvalue
#  The estimated number of batches is 1448
#       759/1    0.97575    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3894399996274605 for eigenvalue
#  The estimated number of batches is 1447
#       760/1    0.96227    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3899257865353203 for eigenvalue
#  The estimated number of batches is 1450
#       761/1    0.98393    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3883421737181358 for eigenvalue
#  The estimated number of batches is 1449
#       762/1    0.96858    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3864099056294594 for eigenvalue
#  The estimated number of batches is 1447
#       763/1    0.96706    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3851789572628046 for eigenvalue
#  The estimated number of batches is 1446
#       764/1    0.97568    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3844814615798677 for eigenvalue
#  The estimated number of batches is 1447
#       765/1    0.96924    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3835578934944475 for eigenvalue
#  The estimated number of batches is 1447
#       766/1    0.97452    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3815303959089946 for eigenvalue
#  The estimated number of batches is 1444
#       767/1    0.97048    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3797512106081518 for eigenvalue
#  The estimated number of batches is 1443
#       768/1    0.97975    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3783339770866834 for eigenvalue
#  The estimated number of batches is 1442
#       769/1    0.97631    0.97187 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3764642609197895 for eigenvalue
#  The estimated number of batches is 1440
#       770/1    0.97100    0.97187 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3753346600353953 for eigenvalue
#  The estimated number of batches is 1439
#       771/1    0.96886    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.380912284064649 for eigenvalue
#  The estimated number of batches is 1453
#       772/1    0.96800    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3807183270649728 for eigenvalue
#  The estimated number of batches is 1454
#       773/1    0.96505    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.380195442931108 for eigenvalue
#  The estimated number of batches is 1455
#       774/1    0.96685    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3784856828300731 for eigenvalue
#  The estimated number of batches is 1453
#       775/1    0.97919    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3774484173852346 for eigenvalue
#  The estimated number of batches is 1453
#       776/1    0.97642    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3755838819752209 for eigenvalue
#  The estimated number of batches is 1451
#       777/1    0.97826    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3746617593004042 for eigenvalue
#  The estimated number of batches is 1451
#       778/1    0.97236    0.97187 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3731047434744972 for eigenvalue
#  The estimated number of batches is 1450
#       779/1    0.96722    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.372297720903708 for eigenvalue
#  The estimated number of batches is 1450
#       780/1    0.96560    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3705879236189604 for eigenvalue
#  The estimated number of batches is 1448
#       781/1    0.97614    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.369122536832997 for eigenvalue
#  The estimated number of batches is 1447
#       782/1    0.97538    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.367360090920607 for eigenvalue
#  The estimated number of batches is 1445
#       783/1    0.96916    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3656648118715773 for eigenvalue
#  The estimated number of batches is 1444
#       784/1    0.97054    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3644214853525771 for eigenvalue
#  The estimated number of batches is 1443
#       785/1    0.97034    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3627141793934145 for eigenvalue
#  The estimated number of batches is 1441
#       786/1    0.96980    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.361194145578472 for eigenvalue
#  The estimated number of batches is 1440
#       787/1    0.97690    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3607596443867915 for eigenvalue
#  The estimated number of batches is 1441
#       788/1    0.97129    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3590835665741674 for eigenvalue
#  The estimated number of batches is 1439
#       789/1    0.97745    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3601290300837598 for eigenvalue
#  The estimated number of batches is 1443
#       790/1    0.97426    0.97187 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3599425691278677 for eigenvalue
#  The estimated number of batches is 1445
#       791/1    0.96619    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3583259292694978 for eigenvalue
#  The estimated number of batches is 1443
#       792/1    0.96721    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3591910201940656 for eigenvalue
#  The estimated number of batches is 1447
#       793/1    0.96329    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3601738676405837 for eigenvalue
#  The estimated number of batches is 1451
#       794/1    0.96756    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.360324057864416 for eigenvalue
#  The estimated number of batches is 1453
#       795/1    0.97735    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.362181871071553 for eigenvalue
#  The estimated number of batches is 1459
#       796/1    0.96918    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.361004272835493 for eigenvalue
#  The estimated number of batches is 1458
#       797/1    0.96741    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3602503028460844 for eigenvalue
#  The estimated number of batches is 1458
#       798/1    0.96859    0.97183 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3590605866833156 for eigenvalue
#  The estimated number of batches is 1458
#       799/1    0.97343    0.97183 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3580142149277783 for eigenvalue
#  The estimated number of batches is 1457
#       800/1    0.97187    0.97183 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3565874908518205 for eigenvalue
#  The estimated number of batches is 1456
#       801/1    0.97098    0.97183 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.356484550054115 for eigenvalue
#  The estimated number of batches is 1458
#       802/1    0.97584    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3551534585154412 for eigenvalue
#  The estimated number of batches is 1457
#       803/1    0.97381    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3539663419158046 for eigenvalue
#  The estimated number of batches is 1456
#       804/1    0.96511    0.97183 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3527311141766978 for eigenvalue
#  The estimated number of batches is 1455
#       805/1    0.97000    0.97183 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3519351181510182 for eigenvalue
#  The estimated number of batches is 1455
#       806/1    0.97939    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3525727203873414 for eigenvalue
#  The estimated number of batches is 1458
#       807/1    0.97496    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3514934270671453 for eigenvalue
#  The estimated number of batches is 1458
#       808/1    0.97972    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3496640585910826 for eigenvalue
#  The estimated number of batches is 1456
#       809/1    0.98353    0.97187 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3504139043232175 for eigenvalue
#  The estimated number of batches is 1459
#       810/1    0.96073    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3522250738479398 for eigenvalue
#  The estimated number of batches is 1465
#       811/1    0.96237    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3506747435505566 for eigenvalue
#  The estimated number of batches is 1464
#       812/1    0.97664    0.97185 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.350240106993457 for eigenvalue
#  The estimated number of batches is 1464
#       813/1    0.96451    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3515456417886018 for eigenvalue
#  The estimated number of batches is 1469
#       814/1    0.97541    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3501415794357055 for eigenvalue
#  The estimated number of batches is 1468
#       815/1    0.97349    0.97184 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3486448035141352 for eigenvalue
#  The estimated number of batches is 1466
#       816/1    0.98304    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3482704590814794 for eigenvalue
#  The estimated number of batches is 1467
#       817/1    0.97530    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3484335652199217 for eigenvalue
#  The estimated number of batches is 1470
#       818/1    0.97281    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3470568408511974 for eigenvalue
#  The estimated number of batches is 1469
#       819/1    0.96558    0.97186 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3456374642846827 for eigenvalue
#  The estimated number of batches is 1467
