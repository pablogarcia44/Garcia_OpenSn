# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %% [markdown]
# def instru(index_x,index_y):
#     clad_inner_radius = openmc.ZCylinder(r=0.559)
#     clad_outer_radius = openmc.ZCylinder(r=0.605)
#     pitch = 1.26
#     left = openmc.XPlane(-pitch/2, boundary_type='transmission')
#     right = openmc.XPlane(pitch/2, boundary_type='transmission')
#     bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
#     top = openmc.YPlane(pitch/2, boundary_type='transmission')
#     clad_region = +clad_inner_radius & -clad_outer_radius
#     water_region = +left & -right & +bottom & -top & +clad_outer_radius
#     water_guide_region= -clad_inner_radius
#     water_guide = openmc.Cell(name='water_guide'+'_'+str(index_x)+'_'+str(index_y))
#     water_guide.fill = water
#     water_guide.region = water_guide_region
#     clad = openmc.Cell(name='clad_guide'+'_'+str(index_x)+'_'+str(index_y))
#     clad.fill = zirconium
#     clad.region = clad_region
#     moderator = openmc.Cell(name='moderator'+'_'+str(index_x)+'_'+str(index_y))
#     moderator.fill = water
#     moderator.region = water_region
#     u = openmc.Universe(name='u_guide'+'_'+str(index_x)+'_'+str(index_y),cells=(water_guide, clad, moderator))
#     return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create Instrument Thimble

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    instru_inner_radius = openmc.ZCylinder(0.258)
    instry_outer_radius= openmc.ZCylinder(0.382)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission') 

    
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius | -instru_inner_radius | +instry_outer_radius & -clad_inner_radius
    instru_region = +instru_inner_radius & -instry_outer_radius

    water_cell = openmc.Cell(name='water_cell'+family)
    water_cell.fill = water
    water_cell.region = water_region
    clad_cell = openmc.Cell(name='clad_cell'+family)
    clad_cell.fill = zirconium
    clad_cell.region = clad_region
    instru_cell = openmc.Cell(name='instru_cell'+family)
    instru_cell.fill = SS304
    instru_cell.region = instru_region
    
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_cell, clad_cell, instru_cell))
    return(u,water_cell,clad_cell,instru_cell)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]

PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Create power tally

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=477.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=3.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=11.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-12 17:31:55
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.97047
#         2/1    0.97829
#         3/1    0.97525
#         4/1    0.97769
#         5/1    0.96897
#         6/1    0.97372
#         7/1    0.96925
#         8/1    0.98379
#         9/1    0.97302
#        10/1    0.96705
#        11/1    0.97690
#        12/1    0.97546
#        13/1    0.98041
#        14/1    0.98130
#        15/1    0.96905
#        16/1    0.97861
#        17/1    0.97785
#        18/1    0.98301
#        19/1    0.96335
#        20/1    0.97743
#        21/1    0.98793
#        22/1    0.97888    0.98341 +/- 0.00452
#        23/1    0.98663    0.98448 +/- 0.00282
#        24/1    0.97982    0.98332 +/- 0.00231
#        25/1    0.98372    0.98340 +/- 0.00179
#        26/1    0.98284    0.98331 +/- 0.00147
#        27/1    0.97879    0.98266 +/- 0.00140
#        28/1    0.96968    0.98104 +/- 0.00202
#        29/1    0.97496    0.98036 +/- 0.00191
#        30/1    0.97417    0.97974 +/- 0.00182
#        31/1    0.96656    0.97855 +/- 0.00203
#        32/1    0.97881    0.97857 +/- 0.00186
#        33/1    0.97221    0.97808 +/- 0.00178
#        34/1    0.97160    0.97762 +/- 0.00171
#        35/1    0.97518    0.97745 +/- 0.00160
#        36/1    0.96959    0.97696 +/- 0.00157
#        37/1    0.97385    0.97678 +/- 0.00149
#        38/1    0.97581    0.97672 +/- 0.00141
#        39/1    0.97634    0.97670 +/- 0.00133
#        40/1    0.98626    0.97718 +/- 0.00135
#        41/1    0.96854    0.97677 +/- 0.00135
#        42/1    0.97835    0.97684 +/- 0.00129
#        43/1    0.98441    0.97717 +/- 0.00127
#        44/1    0.96709    0.97675 +/- 0.00129
#        45/1    0.99378    0.97743 +/- 0.00141
#        46/1    0.97898    0.97749 +/- 0.00136
#        47/1    0.98889    0.97791 +/- 0.00137
#        48/1    0.98112    0.97803 +/- 0.00133
#        49/1    0.97151    0.97780 +/- 0.00130
#        50/1    0.98258    0.97796 +/- 0.00127
#  Triggers unsatisfied, max unc./thresh. is 7.228077663534114 for eigenvalue
#  The estimated number of batches is 1588
#  Creating state point statepoint.00050.h5...
#        51/1    0.98281    0.97812 +/- 0.00124
#  Triggers unsatisfied, max unc./thresh. is 7.152982439627193 for eigenvalue
#  The estimated number of batches is 1607
#        52/1    0.97944    0.97816 +/- 0.00120
#  Triggers unsatisfied, max unc./thresh. is 7.059943009957855 for eigenvalue
#  The estimated number of batches is 1615
#        53/1    0.97889    0.97818 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 6.845246917980074 for eigenvalue
#  The estimated number of batches is 1567
#        54/1    0.97486    0.97809 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 6.628998061792737 for eigenvalue
#  The estimated number of batches is 1515
#        55/1    0.96979    0.97785 +/- 0.00112
#  Triggers unsatisfied, max unc./thresh. is 6.5459948959242675 for eigenvalue
#  The estimated number of batches is 1520
#        56/1    0.97635    0.97781 +/- 0.00109
#  Triggers unsatisfied, max unc./thresh. is 6.352732160224795 for eigenvalue
#  The estimated number of batches is 1473
#        57/1    0.97321    0.97768 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 6.62980155398777 for eigenvalue
#  The estimated number of batches is 1647
#        58/1    0.98406    0.97785 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 6.470922450806961 for eigenvalue
#  The estimated number of batches is 1612
#        59/1    0.97268    0.97772 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.418089183308802 for eigenvalue
#  The estimated number of batches is 1627
#        60/1    0.97313    0.97760 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 6.401046319888809 for eigenvalue
#  The estimated number of batches is 1659
#        61/1    0.98150    0.97770 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 6.2611252453690405 for eigenvalue
#  The estimated number of batches is 1628
#        62/1    0.97957    0.97774 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.138922225658301 for eigenvalue
#  The estimated number of batches is 1603
#        63/1    0.97977    0.97779 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.047762969958518 for eigenvalue
#  The estimated number of batches is 1593
#        64/1    0.97618    0.97775 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.849991375967236 for eigenvalue
#  The estimated number of batches is 1526
#        65/1    0.97399    0.97767 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 5.73156413948796 for eigenvalue
#  The estimated number of batches is 1499
#        66/1    0.98399    0.97781 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.70791743553652 for eigenvalue
#  The estimated number of batches is 1519
#        67/1    0.97995    0.97785 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.650264417075827 for eigenvalue
#  The estimated number of batches is 1521
#        68/1    0.96859    0.97766 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 5.622795848518396 for eigenvalue
#  The estimated number of batches is 1538
#        69/1    0.97660    0.97764 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.5268336463715135 for eigenvalue
#  The estimated number of batches is 1517
#        70/1    0.97411    0.97757 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.415114843308042 for eigenvalue
#  The estimated number of batches is 1487
#        71/1    0.98244    0.97766 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.36651402309017 for eigenvalue
#  The estimated number of batches is 1489
#        72/1    0.97679    0.97765 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.313435210126305 for eigenvalue
#  The estimated number of batches is 1489
#        73/1    0.98365    0.97776 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.417897280926385 for eigenvalue
#  The estimated number of batches is 1576
#        74/1    0.96639    0.97755 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.328998439498729 for eigenvalue
#  The estimated number of batches is 1554
#        75/1    0.98102    0.97761 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.417535889197218 for eigenvalue
#  The estimated number of batches is 1635
#        76/1    0.97386    0.97755 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.3513001199061145 for eigenvalue
#  The estimated number of batches is 1624
#        77/1    0.97219    0.97745 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.471992907362504 for eigenvalue
#  The estimated number of batches is 1727
#        78/1    0.97933    0.97748 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.4194505336888525 for eigenvalue
#  The estimated number of batches is 1724
#        79/1    0.98270    0.97757 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.416719696207911 for eigenvalue
#  The estimated number of batches is 1752
#        80/1    0.97607    0.97755 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.306010862186118 for eigenvalue
#  The estimated number of batches is 1710
#        81/1    0.97419    0.97749 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.22874612982962 for eigenvalue
#  The estimated number of batches is 1688
#        82/1    0.97072    0.97738 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.286301971058784 for eigenvalue
#  The estimated number of batches is 1753
#        83/1    0.97153    0.97729 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.2505275869119625 for eigenvalue
#  The estimated number of batches is 1757
#        84/1    0.97647    0.97728 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.171245974459449 for eigenvalue
#  The estimated number of batches is 1732
#        85/1    0.97363    0.97722 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.120002807645239 for eigenvalue
#  The estimated number of batches is 1724
#        86/1    0.98358    0.97732 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.045026813650552 for eigenvalue
#  The estimated number of batches is 1700
#        87/1    0.98031    0.97736 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.976227649513836 for eigenvalue
#  The estimated number of batches is 1680
#        88/1    0.97849    0.97738 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.912670495323054 for eigenvalue
#  The estimated number of batches is 1662
#        89/1    0.97104    0.97729 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.955927885108652 for eigenvalue
#  The estimated number of batches is 1715
#        90/1    0.97519    0.97726 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.90718916897809 for eigenvalue
#  The estimated number of batches is 1706
#        91/1    0.97314    0.97720 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.972874185607779 for eigenvalue
#  The estimated number of batches is 1776
#        92/1    0.97718    0.97720 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.919862927492882 for eigenvalue
#  The estimated number of batches is 1763
#        93/1    0.97595    0.97718 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.8505097589359165 for eigenvalue
#  The estimated number of batches is 1738
#        94/1    0.97210    0.97711 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.7599806888646 for eigenvalue
#  The estimated number of batches is 1697
#        95/1    0.98571    0.97723 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.726148751544401 for eigenvalue
#  The estimated number of batches is 1696
#        96/1    0.97553    0.97721 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.717836404304297 for eigenvalue
#  The estimated number of batches is 1712
#        97/1    0.98011    0.97724 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.661257341269862 for eigenvalue
#  The estimated number of batches is 1694
#        98/1    0.97949    0.97727 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.60559043830556 for eigenvalue
#  The estimated number of batches is 1675
#        99/1    0.96820    0.97716 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.523096956045798 for eigenvalue
#  The estimated number of batches is 1637
#       100/1    0.96264    0.97698 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.428508560182418 for eigenvalue
#  The estimated number of batches is 1589
#       101/1    0.97229    0.97692 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.362201140781785 for eigenvalue
#  The estimated number of batches is 1562
#       102/1    0.97548    0.97690 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.302031005383651 for eigenvalue
#  The estimated number of batches is 1538
#       103/1    0.97818    0.97692 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.254014369960471 for eigenvalue
#  The estimated number of batches is 1523
#       104/1    0.96787    0.97681 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.252723839807416 for eigenvalue
#  The estimated number of batches is 1540
#       105/1    0.97991    0.97684 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.20812346552107 for eigenvalue
#  The estimated number of batches is 1526
#       106/1    0.96761    0.97674 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.149166849738697 for eigenvalue
#  The estimated number of batches is 1501
#       107/1    0.97635    0.97673 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.115428647503746 for eigenvalue
#  The estimated number of batches is 1494
#       108/1    0.97648    0.97673 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.067316951699558 for eigenvalue
#  The estimated number of batches is 1476
#       109/1    0.97345    0.97669 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.01796833522471 for eigenvalue
#  The estimated number of batches is 1457
#       110/1    0.98046    0.97673 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.9771043972257383 for eigenvalue
#  The estimated number of batches is 1444
#       111/1    0.98220    0.97679 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.980510439051129 for eigenvalue
#  The estimated number of batches is 1462
#       112/1    0.97732    0.97680 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.942400324956621 for eigenvalue
#  The estimated number of batches is 1450
#       113/1    0.98315    0.97687 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.9175294080291607 for eigenvalue
#  The estimated number of batches is 1448
#       114/1    0.98130    0.97692 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.9025695354625753 for eigenvalue
#  The estimated number of batches is 1452
#       115/1    0.97482    0.97689 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.8769750333701105 for eigenvalue
#  The estimated number of batches is 1448
#       116/1    0.97536    0.97688 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.85691783591612 for eigenvalue
#  The estimated number of batches is 1449
#       117/1    0.97133    0.97682 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8379818278757845 for eigenvalue
#  The estimated number of batches is 1449
#       118/1    0.97649    0.97682 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.8202674781710173 for eigenvalue
#  The estimated number of batches is 1451
#       119/1    0.96593    0.97671 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8463259433459935 for eigenvalue
#  The estimated number of batches is 1485
#       120/1    0.97320    0.97667 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8095803256070258 for eigenvalue
#  The estimated number of batches is 1472
#       121/1    0.97676    0.97667 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.776683687305537 for eigenvalue
#  The estimated number of batches is 1461
#       122/1    0.97955    0.97670 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.7577533910279386 for eigenvalue
#  The estimated number of batches is 1461
#       123/1    0.97806    0.97671 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.7224332398561475 for eigenvalue
#  The estimated number of batches is 1448
#       124/1    0.98264    0.97677 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.6943580009560626 for eigenvalue
#  The estimated number of batches is 1440
#       125/1    0.96306    0.97664 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7680883860588965 for eigenvalue
#  The estimated number of batches is 1511
#       126/1    0.98149    0.97669 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.775122133879194 for eigenvalue
#  The estimated number of batches is 1531
#       127/1    0.98599    0.97677 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7851763958929463 for eigenvalue
#  The estimated number of batches is 1554
#       128/1    0.96638    0.97668 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7583119358830426 for eigenvalue
#  The estimated number of batches is 1546
#       129/1    0.98884    0.97679 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7409829426939902 for eigenvalue
#  The estimated number of batches is 1546
#       130/1    0.95900    0.97663 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.752712850818337 for eigenvalue
#  The estimated number of batches is 1570
#       131/1    0.97723    0.97663 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7191103690587104 for eigenvalue
#  The estimated number of batches is 1556
#       132/1    0.97639    0.97663 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7036052534710997 for eigenvalue
#  The estimated number of batches is 1557
#       133/1    0.97245    0.97659 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.682795537766705 for eigenvalue
#  The estimated number of batches is 1553
#       134/1    0.98845    0.97670 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7413909127732716 for eigenvalue
#  The estimated number of batches is 1616
#       135/1    0.97987    0.97673 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.713927324316694 for eigenvalue
#  The estimated number of batches is 1607
#       136/1    0.97785    0.97673 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6938753270876097 for eigenvalue
#  The estimated number of batches is 1603
#       137/1    0.98047    0.97677 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.688464495002524 for eigenvalue
#  The estimated number of batches is 1612
#       138/1    0.97252    0.97673 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6631099108340868 for eigenvalue
#  The estimated number of batches is 1604
#       139/1    0.96964    0.97667 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.6272161482926175 for eigenvalue
#  The estimated number of batches is 1586
#       140/1    0.97328    0.97664 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.595935074857226 for eigenvalue
#  The estimated number of batches is 1572
#       141/1    0.97849    0.97666 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5722735704629365 for eigenvalue
#  The estimated number of batches is 1565
#       142/1    0.97501    0.97664 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.541823407357054 for eigenvalue
#  The estimated number of batches is 1551
#       143/1    0.97089    0.97660 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.535639236258199 for eigenvalue
#  The estimated number of batches is 1558
#       144/1    0.97808    0.97661 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5086661769271306 for eigenvalue
#  The estimated number of batches is 1547
#       145/1    0.98495    0.97668 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4969868521898864 for eigenvalue
#  The estimated number of batches is 1549
#       146/1    0.97002    0.97662 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4682603821121094 for eigenvalue
#  The estimated number of batches is 1536
#       147/1    0.97235    0.97659 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.482797156041836 for eigenvalue
#  The estimated number of batches is 1561
#       148/1    0.97190    0.97655 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4549828491341414 for eigenvalue
#  The estimated number of batches is 1548
#       149/1    0.97189    0.97652 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.429319698304765 for eigenvalue
#  The estimated number of batches is 1538
#       150/1    0.97699    0.97652 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.403212326916736 for eigenvalue
#  The estimated number of batches is 1526
#       151/1    0.97772    0.97653 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.400362565094065 for eigenvalue
#  The estimated number of batches is 1535
#       152/1    0.98342    0.97658 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.377250050569756 for eigenvalue
#  The estimated number of batches is 1526
#       153/1    0.98110    0.97662 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3572092375253244 for eigenvalue
#  The estimated number of batches is 1520
#       154/1    0.98253    0.97666 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.369530867618075 for eigenvalue
#  The estimated number of batches is 1542
#       155/1    0.97755    0.97667 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3493271150059942 for eigenvalue
#  The estimated number of batches is 1535
#       156/1    0.97055    0.97662 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3258343867049147 for eigenvalue
#  The estimated number of batches is 1525
#       157/1    0.98152    0.97666 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.304354575968539 for eigenvalue
#  The estimated number of batches is 1516
#       158/1    0.96984    0.97661 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.3032520117151276 for eigenvalue
#  The estimated number of batches is 1526
#       159/1    0.97453    0.97659 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2809379972321633 for eigenvalue
#  The estimated number of batches is 1517
#       160/1    0.97843    0.97661 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2654961721276297 for eigenvalue
#  The estimated number of batches is 1513
#       161/1    0.97077    0.97657 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.314740290200729 for eigenvalue
#  The estimated number of batches is 1570
#       162/1    0.97800    0.97658 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.3014946979813122 for eigenvalue
#  The estimated number of batches is 1568
#       163/1    0.97673    0.97658 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.278704503557911 for eigenvalue
#  The estimated number of batches is 1558
#       164/1    0.97099    0.97654 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2555443533287605 for eigenvalue
#  The estimated number of batches is 1547
#       165/1    0.98048    0.97656 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2414681365958047 for eigenvalue
#  The estimated number of batches is 1544
#       166/1    0.96448    0.97648 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2150845706830204 for eigenvalue
#  The estimated number of batches is 1530
#       167/1    0.97583    0.97648 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.193731819317228 for eigenvalue
#  The estimated number of batches is 1520
#       168/1    0.97907    0.97650 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.178119955548572 for eigenvalue
#  The estimated number of batches is 1515
#       169/1    0.97479    0.97648 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1579471160313344 for eigenvalue
#  The estimated number of batches is 1506
#       170/1    0.98064    0.97651 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1375244740536634 for eigenvalue
#  The estimated number of batches is 1497
#       171/1    0.97995    0.97653 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.135698433679022 for eigenvalue
#  The estimated number of batches is 1505
#       172/1    0.98310    0.97658 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1282627738324034 for eigenvalue
#  The estimated number of batches is 1508
#       173/1    0.97657    0.97658 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1100302844734653 for eigenvalue
#  The estimated number of batches is 1500
#       174/1    0.97250    0.97655 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0989579351344707 for eigenvalue
#  The estimated number of batches is 1499
#       175/1    0.98364    0.97660 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.145747868805175 for eigenvalue
#  The estimated number of batches is 1554
#       176/1    0.97615    0.97659 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.1251128553777825 for eigenvalue
#  The estimated number of batches is 1544
#       177/1    0.98144    0.97662 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.1063220899279993 for eigenvalue
#  The estimated number of batches is 1535
#       178/1    0.97543    0.97662 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0865631002868654 for eigenvalue
#  The estimated number of batches is 1526
#       179/1    0.97399    0.97660 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.130666376677743 for eigenvalue
#  The estimated number of batches is 1579
#       180/1    0.97042    0.97656 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1248745762717727 for eigenvalue
#  The estimated number of batches is 1583
#       181/1    0.98136    0.97659 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1070210969124674 for eigenvalue
#  The estimated number of batches is 1575
#       182/1    0.96267    0.97651 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.109308340038459 for eigenvalue
#  The estimated number of batches is 1587
#       183/1    0.97551    0.97650 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.093940682627051 for eigenvalue
#  The estimated number of batches is 1581
#       184/1    0.97607    0.97650 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.076067660039669 for eigenvalue
#  The estimated number of batches is 1572
#       185/1    0.96524    0.97643 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0849432376036416 for eigenvalue
#  The estimated number of batches is 1591
#       186/1    0.97463    0.97642 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0656869225672594 for eigenvalue
#  The estimated number of batches is 1581
#       187/1    0.97536    0.97641 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.058830900151298 for eigenvalue
#  The estimated number of batches is 1583
#       188/1    0.97342    0.97639 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.04552016327423 for eigenvalue
#  The estimated number of batches is 1579
#       189/1    0.97494    0.97639 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.034859315569915 for eigenvalue
#  The estimated number of batches is 1577
#       190/1    0.97044    0.97635 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0160451931771095 for eigenvalue
#  The estimated number of batches is 1567
#       191/1    0.97193    0.97632 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.011935857192652 for eigenvalue
#  The estimated number of batches is 1572
#       192/1    0.98448    0.97637 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9986051973103445 for eigenvalue
#  The estimated number of batches is 1567
#       193/1    0.97480    0.97636 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.988533634093433 for eigenvalue
#  The estimated number of batches is 1566
#       194/1    0.97578    0.97636 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9729129371494376 for eigenvalue
#  The estimated number of batches is 1558
#       195/1    0.97454    0.97635 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9676376254388237 for eigenvalue
#  The estimated number of batches is 1562
#       196/1    0.97094    0.97632 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.974023465356553 for eigenvalue
#  The estimated number of batches is 1577
#       197/1    0.97672    0.97632 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9633020445598497 for eigenvalue
#  The estimated number of batches is 1575
#       198/1    0.96741    0.97627 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9527674328979696 for eigenvalue
#  The estimated number of batches is 1572
#       199/1    0.97147    0.97624 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9338384621920945 for eigenvalue
#  The estimated number of batches is 1561
#       200/1    0.97224    0.97622 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9163433855356518 for eigenvalue
#  The estimated number of batches is 1551
#       201/1    0.98039    0.97624 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.902418738001801 for eigenvalue
#  The estimated number of batches is 1545
#       202/1    0.97999    0.97626 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8881052877924334 for eigenvalue
#  The estimated number of batches is 1539
#       203/1    0.98432    0.97631 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.912774762125584 for eigenvalue
#  The estimated number of batches is 1573
#       204/1    0.97847    0.97632 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.898503642037008 for eigenvalue
#  The estimated number of batches is 1566
#       205/1    0.97251    0.97630 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8920054767535204 for eigenvalue
#  The estimated number of batches is 1568
#       206/1    0.97067    0.97627 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8749397257973013 for eigenvalue
#  The estimated number of batches is 1558
#       207/1    0.96551    0.97621 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9086687904971944 for eigenvalue
#  The estimated number of batches is 1603
#       208/1    0.98878    0.97628 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.920858582930167 for eigenvalue
#  The estimated number of batches is 1624
#       209/1    0.97780    0.97629 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9058048583503893 for eigenvalue
#  The estimated number of batches is 1616
#       210/1    0.96817    0.97624 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9062887099015917 for eigenvalue
#  The estimated number of batches is 1625
#       211/1    0.97997    0.97626 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.895464290785517 for eigenvalue
#  The estimated number of batches is 1622
#       212/1    0.98142    0.97629 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8816910115205907 for eigenvalue
#  The estimated number of batches is 1615
#       213/1    0.97282    0.97627 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.897551672491575 for eigenvalue
#  The estimated number of batches is 1641
#       214/1    0.97378    0.97626 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.881341221680504 for eigenvalue
#  The estimated number of batches is 1631
#       215/1    0.98074    0.97628 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.879280722715364 for eigenvalue
#  The estimated number of batches is 1637
#       216/1    0.98648    0.97634 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.866569435121018 for eigenvalue
#  The estimated number of batches is 1631
#       217/1    0.97332    0.97632 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8519550868971164 for eigenvalue
#  The estimated number of batches is 1623
#       218/1    0.96881    0.97628 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.83819529142382 for eigenvalue
#  The estimated number of batches is 1615
#       219/1    0.97524    0.97628 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.831630986924023 for eigenvalue
#  The estimated number of batches is 1616
#       220/1    0.97869    0.97629 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8210319367618646 for eigenvalue
#  The estimated number of batches is 1612
#       221/1    0.97753    0.97629 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.807058511986569 for eigenvalue
#  The estimated number of batches is 1604
#       222/1    0.97485    0.97629 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7934656130606306 for eigenvalue
#  The estimated number of batches is 1597
#       223/1    0.97209    0.97627 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.793855402767803 for eigenvalue
#  The estimated number of batches is 1605
#       224/1    0.97616    0.97627 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.807175674601054 for eigenvalue
#  The estimated number of batches is 1628
#       225/1    0.97250    0.97625 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.793946312325902 for eigenvalue
#  The estimated number of batches is 1621
#       226/1    0.98580    0.97629 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.793386111822189 for eigenvalue
#  The estimated number of batches is 1628
#       227/1    0.97965    0.97631 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.781146212496083 for eigenvalue
#  The estimated number of batches is 1622
#       228/1    0.97358    0.97630 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.767895395081297 for eigenvalue
#  The estimated number of batches is 1614
#       229/1    0.97945    0.97631 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.75518148184609 for eigenvalue
#  The estimated number of batches is 1607
#       230/1    0.97376    0.97630 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7427384865568287 for eigenvalue
#  The estimated number of batches is 1600
#       231/1    0.98030    0.97632 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.73191716659221 for eigenvalue
#  The estimated number of batches is 1595
#       232/1    0.98069    0.97634 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7361107871991814 for eigenvalue
#  The estimated number of batches is 1608
#       233/1    0.97310    0.97632 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7298675768917753 for eigenvalue
#  The estimated number of batches is 1608
#       234/1    0.98188    0.97635 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.71821174351215 for eigenvalue
#  The estimated number of batches is 1602
#       235/1    0.97933    0.97636 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.706322728963368 for eigenvalue
#  The estimated number of batches is 1595
#       236/1    0.98361    0.97640 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7005357004821726 for eigenvalue
#  The estimated number of batches is 1596
#       237/1    0.97346    0.97638 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.687068168350677 for eigenvalue
#  The estimated number of batches is 1587
#       238/1    0.97469    0.97638 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.676555516760033 for eigenvalue
#  The estimated number of batches is 1582
#       239/1    0.97717    0.97638 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6660187774842767 for eigenvalue
#  The estimated number of batches is 1577
#       240/1    0.98482    0.97642 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.678695812317325 for eigenvalue
#  The estimated number of batches is 1599
#       241/1    0.97772    0.97642 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6675881269183064 for eigenvalue
#  The estimated number of batches is 1593
#       242/1    0.98264    0.97645 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.659635021943285 for eigenvalue
#  The estimated number of batches is 1591
#       243/1    0.97917    0.97646 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6509932949526607 for eigenvalue
#  The estimated number of batches is 1588
#       244/1    0.96682    0.97642 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6508507969060715 for eigenvalue
#  The estimated number of batches is 1595
#       245/1    0.96931    0.97639 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.644262448275952 for eigenvalue
#  The estimated number of batches is 1594
#       246/1    0.97783    0.97640 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.639433989859333 for eigenvalue
#  The estimated number of batches is 1595
#       247/1    0.97350    0.97638 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6344519614559325 for eigenvalue
#  The estimated number of batches is 1596
#       248/1    0.97862    0.97639 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6236494679629505 for eigenvalue
#  The estimated number of batches is 1590
#       249/1    0.97260    0.97638 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6121211828382846 for eigenvalue
#  The estimated number of batches is 1583
#       250/1    0.97393    0.97637 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.600091431433832 for eigenvalue
#  The estimated number of batches is 1575
#       251/1    0.96700    0.97633 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5998458428428157 for eigenvalue
#  The estimated number of batches is 1582
#       252/1    0.97141    0.97630 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5892099562442024 for eigenvalue
#  The estimated number of batches is 1576
#       253/1    0.97050    0.97628 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5775916052560297 for eigenvalue
#  The estimated number of batches is 1569
#       254/1    0.97707    0.97628 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5672001236936013 for eigenvalue
#  The estimated number of batches is 1563
#       255/1    0.97865    0.97629 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.55703008265489 for eigenvalue
#  The estimated number of batches is 1557
#       256/1    0.98967    0.97635 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5541797122907184 for eigenvalue
#  The estimated number of batches is 1560
#       257/1    0.97915    0.97636 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5501004567859473 for eigenvalue
#  The estimated number of batches is 1562
#       258/1    0.98605    0.97640 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.543574020305501 for eigenvalue
#  The estimated number of batches is 1560
#       259/1    0.98047    0.97642 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.540451964706402 for eigenvalue
#  The estimated number of batches is 1563
#       260/1    0.98620    0.97646 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5494113156310925 for eigenvalue
#  The estimated number of batches is 1580
#       261/1    0.97443    0.97645 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5422603563636623 for eigenvalue
#  The estimated number of batches is 1578
#       262/1    0.97812    0.97646 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5323317182752207 for eigenvalue
#  The estimated number of batches is 1572
#       263/1    0.97129    0.97644 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5267683413734017 for eigenvalue
#  The estimated number of batches is 1572
#       264/1    0.96914    0.97641 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5150134238907182 for eigenvalue
#  The estimated number of batches is 1564
#       265/1    0.97759    0.97641 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.505799003852814 for eigenvalue
#  The estimated number of batches is 1559
#       266/1    0.96982    0.97639 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.501146285477438 for eigenvalue
#  The estimated number of batches is 1559
#       267/1    0.97917    0.97640 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4915886809244516 for eigenvalue
#  The estimated number of batches is 1554
#       268/1    0.97467    0.97639 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4841404556651656 for eigenvalue
#  The estimated number of batches is 1551
#       269/1    0.97922    0.97640 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.477541135118964 for eigenvalue
#  The estimated number of batches is 1549
#       270/1    0.97444    0.97639 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4692615294310074 for eigenvalue
#  The estimated number of batches is 1545
#       271/1    0.97907    0.97640 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.461286241969504 for eigenvalue
#  The estimated number of batches is 1541
#       272/1    0.98070    0.97642 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4527154057092386 for eigenvalue
#  The estimated number of batches is 1536
#       273/1    0.97958    0.97643 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.44547140783 for eigenvalue
#  The estimated number of batches is 1534
#       274/1    0.97328    0.97642 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4396240417062915 for eigenvalue
#  The estimated number of batches is 1532
#       275/1    0.96243    0.97637 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4516997552861355 for eigenvalue
#  The estimated number of batches is 1553
#       276/1    0.98054    0.97638 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4433781910072376 for eigenvalue
#  The estimated number of batches is 1549
#       277/1    0.97137    0.97636 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4329497012463763 for eigenvalue
#  The estimated number of batches is 1542
#       278/1    0.96651    0.97632 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.442950110897903 for eigenvalue
#  The estimated number of batches is 1560
#       279/1    0.97861    0.97633 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.434396333745921 for eigenvalue
#  The estimated number of batches is 1555
#       280/1    0.97423    0.97633 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.424670720874841 for eigenvalue
#  The estimated number of batches is 1549
#       281/1    0.98361    0.97635 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4303318682014696 for eigenvalue
#  The estimated number of batches is 1562
#       282/1    0.97783    0.97636 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4219660323678673 for eigenvalue
#  The estimated number of batches is 1557
#       283/1    0.98365    0.97639 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.41391207004816 for eigenvalue
#  The estimated number of batches is 1553
#       284/1    0.97404    0.97638 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.408992305930608 for eigenvalue
#  The estimated number of batches is 1553
#       285/1    0.97396    0.97637 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3996718390336085 for eigenvalue
#  The estimated number of batches is 1546
#       286/1    0.98186    0.97639 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3943951448107677 for eigenvalue
#  The estimated number of batches is 1546
#       287/1    0.97233    0.97637 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.389796468704966 for eigenvalue
#  The estimated number of batches is 1545
#       288/1    0.97611    0.97637 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.386632246160645 for eigenvalue
#  The estimated number of batches is 1547
#       289/1    0.97027    0.97635 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.380022251642175 for eigenvalue
#  The estimated number of batches is 1544
#       290/1    0.97528    0.97635 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3762532443333173 for eigenvalue
#  The estimated number of batches is 1545
#       291/1    0.97745    0.97635 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3680231624806005 for eigenvalue
#  The estimated number of batches is 1540
#       292/1    0.96899    0.97632 +/- 0.00034
# ...
#      1425/1    0.97630    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0300161396904288 for eigenvalue
#  The estimated number of batches is 1511
#      1426/1    0.97185    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.030269512913769 for eigenvalue
#  The estimated number of batches is 1513
#      1427/1    0.97290    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.029546389259151 for eigenvalue
#  The estimated number of batches is 1512
#      1428/1    0.97492    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0289370264949005 for eigenvalue
#  The estimated number of batches is 1511
#      1429/1    0.97580    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0285145778226215 for eigenvalue
#  The estimated number of batches is 1511
#      1430/1    0.98289    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0278006280704386 for eigenvalue
#  The estimated number of batches is 1510
#      1431/1    0.97333    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0272375433112662 for eigenvalue
#  The estimated number of batches is 1509
#      1432/1    0.98815    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.029199498716531 for eigenvalue
#  The estimated number of batches is 1516
#      1433/1    0.97796    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0287891472851436 for eigenvalue
#  The estimated number of batches is 1516
#      1434/1    0.98438    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.028737139824463 for eigenvalue
#  The estimated number of batches is 1517
#      1435/1    0.97089    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0296761631629643 for eigenvalue
#  The estimated number of batches is 1521
#      1436/1    0.97195    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.028962500887018 for eigenvalue
#  The estimated number of batches is 1520
#      1437/1    0.97234    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0284070295970558 for eigenvalue
#  The estimated number of batches is 1519
#      1438/1    0.97857    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0279708806325645 for eigenvalue
#  The estimated number of batches is 1519
#      1439/1    0.97866    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0274172597390256 for eigenvalue
#  The estimated number of batches is 1518
#      1440/1    0.97452    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0269692451057184 for eigenvalue
#  The estimated number of batches is 1518
#      1441/1    0.96859    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0265043151517956 for eigenvalue
#  The estimated number of batches is 1518
#      1442/1    0.97966    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.025795299573528 for eigenvalue
#  The estimated number of batches is 1517
#      1443/1    0.97026    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.025210260680034 for eigenvalue
#  The estimated number of batches is 1516
#      1444/1    0.96905    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0249054172660514 for eigenvalue
#  The estimated number of batches is 1516
#      1445/1    0.97291    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0242085785980437 for eigenvalue
#  The estimated number of batches is 1515
#      1446/1    0.97173    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0243822837224972 for eigenvalue
#  The estimated number of batches is 1517
#      1447/1    0.98130    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0246225246480127 for eigenvalue
#  The estimated number of batches is 1519
#      1448/1    0.97221    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0242367775602603 for eigenvalue
#  The estimated number of batches is 1519
#      1449/1    0.97737    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.023523013006703 for eigenvalue
#  The estimated number of batches is 1518
#      1450/1    0.97494    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0234130639497048 for eigenvalue
#  The estimated number of batches is 1518
#      1451/1    0.97383    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0227757249596012 for eigenvalue
#  The estimated number of batches is 1517
#      1452/1    0.97955    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0224449484742828 for eigenvalue
#  The estimated number of batches is 1518
#      1453/1    0.97504    0.97591 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0218268603809475 for eigenvalue
#  The estimated number of batches is 1517
#      1454/1    0.98807    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.021523671344949 for eigenvalue
#  The estimated number of batches is 1517
#      1455/1    0.97151    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.020904457912488 for eigenvalue
#  The estimated number of batches is 1516
#      1456/1    0.97885    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0204102767211098 for eigenvalue
#  The estimated number of batches is 1516
#      1457/1    0.96901    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.019713837479689 for eigenvalue
#  The estimated number of batches is 1515
#      1458/1    0.97603    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0195188824815837 for eigenvalue
#  The estimated number of batches is 1515
#      1459/1    0.98186    0.97592 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0201510724097609 for eigenvalue
#  The estimated number of batches is 1518
#      1460/1    0.98574    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0207406570855486 for eigenvalue
#  The estimated number of batches is 1521
#      1461/1    0.98120    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0200446291262875 for eigenvalue
#  The estimated number of batches is 1520
#      1462/1    0.96969    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0194737050195453 for eigenvalue
#  The estimated number of batches is 1519
#      1463/1    0.98601    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0191276818179569 for eigenvalue
#  The estimated number of batches is 1519
#      1464/1    0.97960    0.97593 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.018435965287421 for eigenvalue
#  The estimated number of batches is 1518
#      1465/1    0.98432    0.97594 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.017972448853108 for eigenvalue
#  The estimated number of batches is 1518
#      1466/1    0.97452    0.97594 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0172646203655749 for eigenvalue
#  The estimated number of batches is 1517
#      1467/1    0.97471    0.97594 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0167715982359873 for eigenvalue
#  The estimated number of batches is 1516
#      1468/1    0.97757    0.97594 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0161496167305974 for eigenvalue
#  The estimated number of batches is 1516
#      1469/1    0.98521    0.97595 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0167719267349355 for eigenvalue
#  The estimated number of batches is 1519
#      1470/1    0.98564    0.97595 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0164904266105872 for eigenvalue
#  The estimated number of batches is 1519
#      1471/1    0.97206    0.97595 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0157821590289295 for eigenvalue
#  The estimated number of batches is 1518
#      1472/1    0.98869    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0167587623759784 for eigenvalue
#  The estimated number of batches is 1522
#      1473/1    0.97790    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.016479500993241 for eigenvalue
#  The estimated number of batches is 1522
#      1474/1    0.98513    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0167530759644365 for eigenvalue
#  The estimated number of batches is 1524
#      1475/1    0.97190    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0160712039696906 for eigenvalue
#  The estimated number of batches is 1523
#      1476/1    0.97204    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0155053599865675 for eigenvalue
#  The estimated number of batches is 1522
#      1477/1    0.98415    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0150813072736857 for eigenvalue
#  The estimated number of batches is 1522
#      1478/1    0.97834    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0164463277320746 for eigenvalue
#  The estimated number of batches is 1527
#      1479/1    0.98041    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0159249036363167 for eigenvalue
#  The estimated number of batches is 1526
#      1480/1    0.97446    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.015302828052637 for eigenvalue
#  The estimated number of batches is 1526
#      1481/1    0.97848    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.014686175593943 for eigenvalue
#  The estimated number of batches is 1525
#      1482/1    0.97885    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0140027861803167 for eigenvalue
#  The estimated number of batches is 1524
#      1483/1    0.96854    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0133016861865258 for eigenvalue
#  The estimated number of batches is 1523
#      1484/1    0.97460    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.012702384747969 for eigenvalue
#  The estimated number of batches is 1522
#      1485/1    0.97124    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0126826804629852 for eigenvalue
#  The estimated number of batches is 1523
#      1486/1    0.97743    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0122006400717443 for eigenvalue
#  The estimated number of batches is 1522
#      1487/1    0.97304    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0117725988117334 for eigenvalue
#  The estimated number of batches is 1522
#      1488/1    0.98132    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0120680121086951 for eigenvalue
#  The estimated number of batches is 1524
#      1489/1    0.97449    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0113760193061951 for eigenvalue
#  The estimated number of batches is 1523
#      1490/1    0.96881    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0108304146276665 for eigenvalue
#  The estimated number of batches is 1523
#      1491/1    0.98208    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0101567285209168 for eigenvalue
#  The estimated number of batches is 1522
#      1492/1    0.97226    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0095323182502516 for eigenvalue
#  The estimated number of batches is 1521
#      1493/1    0.97690    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.008945152681923 for eigenvalue
#  The estimated number of batches is 1520
#      1494/1    0.97187    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0084156742989752 for eigenvalue
#  The estimated number of batches is 1519
#      1495/1    0.96736    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0078998134569173 for eigenvalue
#  The estimated number of batches is 1519
#      1496/1    0.97228    0.97595 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0072158770737178 for eigenvalue
#  The estimated number of batches is 1518
#      1497/1    0.97978    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0067507001004834 for eigenvalue
#  The estimated number of batches is 1518
#      1498/1    0.97354    0.97595 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0069587757517575 for eigenvalue
#  The estimated number of batches is 1519
#      1499/1    0.98338    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0067584148417166 for eigenvalue
#  The estimated number of batches is 1520
#      1500/1    0.97988    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0065942234010585 for eigenvalue
#  The estimated number of batches is 1520
#      1501/1    0.97625    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0059181276372673 for eigenvalue
#  The estimated number of batches is 1519
#      1502/1    0.98271    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0059162220283253 for eigenvalue
#  The estimated number of batches is 1520
#      1503/1    0.97600    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0052831965673255 for eigenvalue
#  The estimated number of batches is 1519
#      1504/1    0.97545    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0046041330974642 for eigenvalue
#  The estimated number of batches is 1518
#      1505/1    0.97808    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.004486191461543 for eigenvalue
#  The estimated number of batches is 1519
#      1506/1    0.97643    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0038167333329417 for eigenvalue
#  The estimated number of batches is 1518
#      1507/1    0.97498    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0031421695004088 for eigenvalue
#  The estimated number of batches is 1517
#      1508/1    0.97147    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.002807098737633 for eigenvalue
#  The estimated number of batches is 1517
#      1509/1    0.97291    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0021654935560287 for eigenvalue
#  The estimated number of batches is 1516
#      1510/1    0.97729    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0015262895435009 for eigenvalue
#  The estimated number of batches is 1515
#      1511/1    0.97863    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.000872579847876 for eigenvalue
#  The estimated number of batches is 1514
#      1512/1    0.97310    0.97596 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0007478358572544 for eigenvalue
#  The estimated number of batches is 1515
#      1513/1    0.98160    0.97597 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0003724818611242 for eigenvalue
#  The estimated number of batches is 1515
#      1514/1    0.97836    0.97597 +/- 0.00015
#  Triggers satisfied for batch 1514
#  Creating state point statepoint.01514.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.4432e+01 seconds
#    Reading cross sections          = 6.3762e+01 seconds
#  Total time in simulation          = 2.3771e+04 seconds
#    Time in transport only          = 2.3556e+04 seconds
#    Time in inactive batches        = 1.7538e+02 seconds
#    Time in active batches          = 2.3595e+04 seconds
#    Time synchronizing fission bank = 1.1495e+01 seconds
#      Sampling source sites         = 8.7175e+00 seconds
#      SEND/RECV source sites        = 2.7757e+00 seconds
#    Time accumulating tallies       = 1.9493e+02 seconds
#    Time writing statepoints        = 3.7820e+00 seconds
#  Total time for finalization       = 1.3232e+01 seconds
#  Total time elapsed                = 2.3850e+04 seconds
#  Calculation Rate (inactive)       = 5701.92 particles/second
#  Calculation Rate (active)         = 3165.88 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.97594 +/- 0.00013
#  k-effective (Track-length)  = 0.97597 +/- 0.00015
#  k-effective (Absorption)    = 0.97590 +/- 0.00012
#  Combined k-effective        = 0.97592 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
