# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600

coat_mat = openmc.Material(name="coat_mat")
coat_mat.add_nuclide('B10',2.16410E-02, 'ao')
coat_mat.add_nuclide('B11',1.96824E-02, 'ao')
coat_mat.add_nuclide('Zr90',1.06304E-02, 'ao')
coat_mat.add_nuclide('Zr91',2.31824E-03, 'ao')
coat_mat.add_nuclide('Zr92',3.54348E-03, 'ao')
coat_mat.add_nuclide('Zr94',3.59100E-03, 'ao')
coat_mat.add_nuclide('Zr96',5.78528E-04, 'ao')
coat_mat.temperature=600
coat_mat.set_density('g/cm3', 3.85)

poison_mat = openmc.Material(name="poison_mat")
poison_mat.add_nuclide('B10',2.98553E-03, 'ao')
poison_mat.add_nuclide('B11',1.21192E-02, 'ao')
poison_mat.add_nuclide('C0',3.77001E-03, 'ao')
poison_mat.add_nuclide('O16',5.85563E-02, 'ao')
poison_mat.add_nuclide('Al27',3.90223E-02, 'ao')
poison_mat.temperature=600
poison_mat.set_density('g/cm3', 3.65)


model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304,coat_mat,poison_mat]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell_ifba(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    coat_outer_radius = openmc.ZCylinder(r=0.4106)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    coat_region = +fuel_outer_radius & -coat_outer_radius
    gap_region = +coat_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    coat = openmc.Cell(name='coat'+'_'+family)
    coat.fill = coat_mat
    coat.region = coat_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator,coat))
    return(u,fuel,gap,clad,moderator,coat)

# %%
def pincell_normal(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create WABA Tube

# %%
def waba_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.286)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.339)
    Poison_Inner_Radius= openmc.ZCylinder(r= 0.353)
    Poison_Outer_Radius= openmc.ZCylinder(r= 0.404)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.418)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    poison_region= +Poison_Inner_Radius & -Poison_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius| -Inner_Tube_Inner_Radius
    guide_region = +guide_inner_radius & -guide_outer_radius
    clad_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Poison_Inner_Radius |  +Poison_Outer_Radius & - Cladding_Inner_Radius 
     
    clad_cell = openmc.Cell(name='clad_cell'+'_'+family)
    clad_cell.fill = zirconium
    clad_cell.region = clad_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    poison_cell = openmc.Cell(name='poison_cell'+'_'+family)
    poison_cell.fill = poison_mat
    poison_cell.region = poison_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u'+'_'+family,cells=(clad_cell,gap_cell,poison_cell,guide_cell,water_cell))
    return(u,clad_cell,gap_cell,poison_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
GT=[(5,5)]
IFBAT=[(0,0),(5,1),(1,5),(8,1),(1,8),(3,2),(2,3),(4,2),(2,4),(6,2),(2,6),(7,2),(2,7),(4,3),(3,4),(5,3),(3,5),(8,3),(3,8),(5,4),(4,5),(8,4),(4,8),(6,5),(5,6),(7,5),(5,7),(8,6),(6,8),(8,7),(7,8)]
WABAT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(2,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))


IFBAT_left=[]
IFBAT_full=[]
for X in IFBAT:
    IFBAT_left.append((X[0],X[1]))
    IFBAT_left.append((X[0],16-X[1]))
for X in IFBAT_left:
    IFBAT_full.append((X[0],X[1]))
    IFBAT_full.append((16-X[0],X[1]))    
IFBAT_full = list(set(IFBAT_full))

WABAT_left=[]
WABAT_full=[]
for X in WABAT:
    WABAT_left.append((X[0],X[1]))
    WABAT_left.append((X[0],16-X[1]))
for X in WABAT_left:
    WABAT_full.append((X[0],X[1]))
    WABAT_full.append((16-X[0],X[1]))    
WABAT_full = list(set(WABAT_full))

# %%
pincell_1_family=pincell_normal('normal')
ifba_1_family=pincell_ifba('ifba')
guide_1_family=guide('guide')
instru_1_family=instru('instru')
waba_1_family=waba_pin('waba')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full :
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in IFBAT_full:
            A[ix][iy]=ifba_1_family[0]
        elif (ix,iy) in WABAT_full:
            A[ix][iy]=waba_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:14:52
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading Al27 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Al27.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.86008
#         2/1    0.87336
#         3/1    0.86467
#         4/1    0.87023
#         5/1    0.87252
#         6/1    0.86667
#         7/1    0.87085
#         8/1    0.85799
#         9/1    0.86850
#        10/1    0.85793
#        11/1    0.87399
#        12/1    0.86853
#        13/1    0.86729
#        14/1    0.86975
#        15/1    0.86986
#        16/1    0.87284
#        17/1    0.86567
#        18/1    0.87312
#        19/1    0.86256
#        20/1    0.86064
#        21/1    0.86741
#        22/1    0.86287    0.86514 +/- 0.00227
#        23/1    0.86281    0.86437 +/- 0.00152
#        24/1    0.87219    0.86632 +/- 0.00223
#        25/1    0.86839    0.86673 +/- 0.00178
#        26/1    0.86923    0.86715 +/- 0.00151
#        27/1    0.86256    0.86649 +/- 0.00143
#        28/1    0.86377    0.86615 +/- 0.00129
#        29/1    0.86755    0.86631 +/- 0.00115
#        30/1    0.86822    0.86650 +/- 0.00104
#        31/1    0.87020    0.86684 +/- 0.00100
#        32/1    0.85998    0.86627 +/- 0.00108
#        33/1    0.86320    0.86603 +/- 0.00102
#        34/1    0.86739    0.86613 +/- 0.00095
#        35/1    0.87370    0.86663 +/- 0.00102
#        36/1    0.86425    0.86648 +/- 0.00096
#        37/1    0.86452    0.86637 +/- 0.00091
#        38/1    0.87134    0.86664 +/- 0.00090
#        39/1    0.87130    0.86689 +/- 0.00089
#        40/1    0.87294    0.86719 +/- 0.00090
#        41/1    0.86403    0.86704 +/- 0.00087
#        42/1    0.86627    0.86701 +/- 0.00083
#        43/1    0.87091    0.86718 +/- 0.00081
#        44/1    0.86961    0.86728 +/- 0.00078
#        45/1    0.86670    0.86725 +/- 0.00075
#        46/1    0.87746    0.86765 +/- 0.00082
#        47/1    0.87485    0.86791 +/- 0.00083
#        48/1    0.86933    0.86796 +/- 0.00080
#        49/1    0.86758    0.86795 +/- 0.00078
#        50/1    0.86835    0.86796 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.999090525669918 for eigenvalue
#  The estimated number of batches is 1100
#  Creating state point statepoint.00050.h5...
#        51/1    0.86382    0.86783 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.804578533409961 for eigenvalue
#  The estimated number of batches is 1065
#        52/1    0.86790    0.86783 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.72276662198908 for eigenvalue
#  The estimated number of batches is 1069
#        53/1    0.86172    0.86765 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.6105848270215635 for eigenvalue
#  The estimated number of batches is 1059
#        54/1    0.87563    0.86788 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.764476578197691 for eigenvalue
#  The estimated number of batches is 1150
#        55/1    0.87546    0.86810 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.901509641985106 for eigenvalue
#  The estimated number of batches is 1239
#        56/1    0.86659    0.86806 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.798818217951518 for eigenvalue
#  The estimated number of batches is 1231
#        57/1    0.86942    0.86809 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.833591093702214 for eigenvalue
#  The estimated number of batches is 1280
#        58/1    0.86665    0.86806 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.708992127515177 for eigenvalue
#  The estimated number of batches is 1259
#        59/1    0.86481    0.86797 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.594033136101165 for eigenvalue
#  The estimated number of batches is 1241
#        60/1    0.86972    0.86802 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 5.508010735928168 for eigenvalue
#  The estimated number of batches is 1234
#        61/1    0.87197    0.86811 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.580815599464722 for eigenvalue
#  The estimated number of batches is 1297
#        62/1    0.86456    0.86803 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.5214686926795675 for eigenvalue
#  The estimated number of batches is 1301
#        63/1    0.86531    0.86796 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 5.453363475377878 for eigenvalue
#  The estimated number of batches is 1299
#        64/1    0.86838    0.86797 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 5.336343683819672 for eigenvalue
#  The estimated number of batches is 1273
#        65/1    0.86679    0.86795 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 5.233386643769517 for eigenvalue
#  The estimated number of batches is 1253
#        66/1    0.86785    0.86795 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 5.17848412385234 for eigenvalue
#  The estimated number of batches is 1254
#        67/1    0.86097    0.86780 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 5.251796221339353 for eigenvalue
#  The estimated number of batches is 1317
#        68/1    0.87163    0.86788 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 5.0112116800185795 for eigenvalue
#  The estimated number of batches is 1226
#        69/1    0.87401    0.86800 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.9768279448366854 for eigenvalue
#  The estimated number of batches is 1234
#        70/1    0.87523    0.86815 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.947803727862668 for eigenvalue
#  The estimated number of batches is 1245
#        71/1    0.86839    0.86815 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.888154500443659 for eigenvalue
#  The estimated number of batches is 1239
#        72/1    0.86314    0.86806 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.901847599510321 for eigenvalue
#  The estimated number of batches is 1270
#        73/1    0.86838    0.86806 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.7981920990549325 for eigenvalue
#  The estimated number of batches is 1241
#        74/1    0.87373    0.86817 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.7745600045620655 for eigenvalue
#  The estimated number of batches is 1252
#        75/1    0.86065    0.86803 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.782117741538997 for eigenvalue
#  The estimated number of batches is 1278
#        76/1    0.86814    0.86803 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.716939622253787 for eigenvalue
#  The estimated number of batches is 1266
#        77/1    0.86768    0.86803 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.643129192593641 for eigenvalue
#  The estimated number of batches is 1249
#        78/1    0.87413    0.86813 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.657238688427052 for eigenvalue
#  The estimated number of batches is 1279
#        79/1    0.87268    0.86821 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.591492768505667 for eigenvalue
#  The estimated number of batches is 1264
#        80/1    0.86810    0.86821 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.535034990090288 for eigenvalue
#  The estimated number of batches is 1254
#        81/1    0.86553    0.86816 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.466435155488138 for eigenvalue
#  The estimated number of batches is 1237
#        82/1    0.86629    0.86813 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.404780966368297 for eigenvalue
#  The estimated number of batches is 1223
#        83/1    0.86499    0.86808 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.348253934079668 for eigenvalue
#  The estimated number of batches is 1212
#        84/1    0.87300    0.86816 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.3721897344678675 for eigenvalue
#  The estimated number of batches is 1244
#        85/1    0.87369    0.86824 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.30946041789063 for eigenvalue
#  The estimated number of batches is 1228
#        86/1    0.86281    0.86816 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 4.3034950683190285 for eigenvalue
#  The estimated number of batches is 1243
#        87/1    0.86832    0.86816 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 4.234655616451391 for eigenvalue
#  The estimated number of batches is 1222
#        88/1    0.87116    0.86821 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 4.269066405442735 for eigenvalue
#  The estimated number of batches is 1260
#        89/1    0.86896    0.86822 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 4.195533210953856 for eigenvalue
#  The estimated number of batches is 1235
#        90/1    0.87284    0.86828 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 4.203225998963609 for eigenvalue
#  The estimated number of batches is 1257
#        91/1    0.87712    0.86841 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 4.104956158706243 for eigenvalue
#  The estimated number of batches is 1217
#        92/1    0.87514    0.86850 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 4.086283874823704 for eigenvalue
#  The estimated number of batches is 1223
#        93/1    0.87036    0.86853 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 4.058371693490909 for eigenvalue
#  The estimated number of batches is 1223
#        94/1    0.86598    0.86849 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 4.043599532631608 for eigenvalue
#  The estimated number of batches is 1230
#        95/1    0.86392    0.86843 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 4.062084759517559 for eigenvalue
#  The estimated number of batches is 1258
#        96/1    0.87650    0.86854 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 4.093370281442945 for eigenvalue
#  The estimated number of batches is 1294
#        97/1    0.86480    0.86849 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 4.134792247076222 for eigenvalue
#  The estimated number of batches is 1337
#        98/1    0.87243    0.86854 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 4.083775061899501 for eigenvalue
#  The estimated number of batches is 1321
#        99/1    0.86782    0.86853 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 4.035556193373555 for eigenvalue
#  The estimated number of batches is 1307
#       100/1    0.87587    0.86862 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 4.014260944983605 for eigenvalue
#  The estimated number of batches is 1310
#       101/1    0.87153    0.86866 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.9812032243047253 for eigenvalue
#  The estimated number of batches is 1304
#       102/1    0.86597    0.86863 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.9366657223675268 for eigenvalue
#  The estimated number of batches is 1291
#       103/1    0.86768    0.86862 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.8935283307562223 for eigenvalue
#  The estimated number of batches is 1279
#       104/1    0.87136    0.86865 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.8394339478343826 for eigenvalue
#  The estimated number of batches is 1259
#       105/1    0.86953    0.86866 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.8108143253380304 for eigenvalue
#  The estimated number of batches is 1255
#       106/1    0.86729    0.86864 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.770156622437061 for eigenvalue
#  The estimated number of batches is 1243
#       107/1    0.86856    0.86864 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.72756732803388 for eigenvalue
#  The estimated number of batches is 1229
#       108/1    0.87562    0.86872 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.7063593524509617 for eigenvalue
#  The estimated number of batches is 1229
#       109/1    0.86471    0.86868 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.677305585067805 for eigenvalue
#  The estimated number of batches is 1224
#       110/1    0.87414    0.86874 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.729426491360959 for eigenvalue
#  The estimated number of batches is 1272
#       111/1    0.87360    0.86879 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.7286935003507846 for eigenvalue
#  The estimated number of batches is 1286
#       112/1    0.86779    0.86878 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.690965340533132 for eigenvalue
#  The estimated number of batches is 1274
#       113/1    0.87297    0.86882 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.66663461483212 for eigenvalue
#  The estimated number of batches is 1271
#       114/1    0.87841    0.86893 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.648847457987235 for eigenvalue
#  The estimated number of batches is 1272
#       115/1    0.87181    0.86896 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.6381976974780756 for eigenvalue
#  The estimated number of batches is 1278
#       116/1    0.86940    0.86896 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.6013488291322413 for eigenvalue
#  The estimated number of batches is 1266
#       117/1    0.87130    0.86899 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.565263970420766 for eigenvalue
#  The estimated number of batches is 1253
#       118/1    0.86451    0.86894 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.5492214067421775 for eigenvalue
#  The estimated number of batches is 1255
#       119/1    0.87025    0.86895 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.5341148876451416 for eigenvalue
#  The estimated number of batches is 1257
#       120/1    0.86378    0.86890 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.520381719700236 for eigenvalue
#  The estimated number of batches is 1260
#       121/1    0.87296    0.86894 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.5034079960264854 for eigenvalue
#  The estimated number of batches is 1260
#       122/1    0.85761    0.86883 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.5884737526007995 for eigenvalue
#  The estimated number of batches is 1334
#       123/1    0.87281    0.86887 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.5714620963050105 for eigenvalue
#  The estimated number of batches is 1334
#       124/1    0.87109    0.86889 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.55239404211665 for eigenvalue
#  The estimated number of batches is 1333
#       125/1    0.86520    0.86885 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.5316452821749222 for eigenvalue
#  The estimated number of batches is 1330
#       126/1    0.87478    0.86891 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.4989442061795857 for eigenvalue
#  The estimated number of batches is 1318
#       127/1    0.86878    0.86891 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.4684506880717287 for eigenvalue
#  The estimated number of batches is 1308
#       128/1    0.87039    0.86892 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.4304597174599336 for eigenvalue
#  The estimated number of batches is 1291
#       129/1    0.87122    0.86894 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.4069459664430877 for eigenvalue
#  The estimated number of batches is 1286
#       130/1    0.86712    0.86893 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.387077853417515 for eigenvalue
#  The estimated number of batches is 1282
#       131/1    0.86631    0.86890 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.373062222390977 for eigenvalue
#  The estimated number of batches is 1283
#       132/1    0.87240    0.86894 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.422073969714695 for eigenvalue
#  The estimated number of batches is 1332
#       133/1    0.86900    0.86894 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.3942653789656188 for eigenvalue
#  The estimated number of batches is 1322
#       134/1    0.87081    0.86895 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.3851013686200915 for eigenvalue
#  The estimated number of batches is 1327
#       135/1    0.87461    0.86900 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.3588267805254315 for eigenvalue
#  The estimated number of batches is 1318
#       136/1    0.87264    0.86903 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.323591396566399 for eigenvalue
#  The estimated number of batches is 1302
#       137/1    0.86888    0.86903 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.298395316508447 for eigenvalue
#  The estimated number of batches is 1293
#       138/1    0.87788    0.86911 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.3043288075648025 for eigenvalue
#  The estimated number of batches is 1309
#       139/1    0.86377    0.86906 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.299714917158929 for eigenvalue
#  The estimated number of batches is 1316
#       140/1    0.86576    0.86903 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.2739627563580544 for eigenvalue
#  The estimated number of batches is 1307
#       141/1    0.86640    0.86901 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.251112012021383 for eigenvalue
#  The estimated number of batches is 1299
#       142/1    0.86719    0.86900 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.232396140456259 for eigenvalue
#  The estimated number of batches is 1295
#       143/1    0.87258    0.86903 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.2430818519120193 for eigenvalue
#  The estimated number of batches is 1314
#       144/1    0.86342    0.86898 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.2498178777817626 for eigenvalue
#  The estimated number of batches is 1330
#       145/1    0.87303    0.86901 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.2177625402093137 for eigenvalue
#  The estimated number of batches is 1315
#       146/1    0.86393    0.86897 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.1978648656264506 for eigenvalue
#  The estimated number of batches is 1309
#       147/1    0.86619    0.86895 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.1773126900937285 for eigenvalue
#  The estimated number of batches is 1303
#       148/1    0.87394    0.86899 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 3.160314249969588 for eigenvalue
#  The estimated number of batches is 1299
#       149/1    0.86762    0.86898 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 3.1429204514281945 for eigenvalue
#  The estimated number of batches is 1295
#       150/1    0.86714    0.86897 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 3.119662217734324 for eigenvalue
#  The estimated number of batches is 1286
#       151/1    0.87129    0.86898 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 3.092213490575519 for eigenvalue
#  The estimated number of batches is 1273
#       152/1    0.86949    0.86899 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 3.0682337336682903 for eigenvalue
#  The estimated number of batches is 1263
#       153/1    0.87129    0.86900 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 3.050237868295134 for eigenvalue
#  The estimated number of batches is 1258
#       154/1    0.87725    0.86907 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 3.0310589075721928 for eigenvalue
#  The estimated number of batches is 1252
#       155/1    0.87045    0.86908 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 3.008114709553115 for eigenvalue
#  The estimated number of batches is 1242
#       156/1    0.86582    0.86905 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.9889051174189634 for eigenvalue
#  The estimated number of batches is 1235
#       157/1    0.86425    0.86902 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.981040519424887 for eigenvalue
#  The estimated number of batches is 1238
#       158/1    0.87054    0.86903 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.9656003886193507 for eigenvalue
#  The estimated number of batches is 1234
#       159/1    0.87244    0.86905 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.9452324631233053 for eigenvalue
#  The estimated number of batches is 1226
#       160/1    0.87169    0.86907 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.9255380897182213 for eigenvalue
#  The estimated number of batches is 1219
#       161/1    0.87205    0.86909 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.903339070186914 for eigenvalue
#  The estimated number of batches is 1209
#       162/1    0.87216    0.86911 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.8838523404573166 for eigenvalue
#  The estimated number of batches is 1201
#       163/1    0.86912    0.86911 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.863035520718451 for eigenvalue
#  The estimated number of batches is 1193
#       164/1    0.86628    0.86910 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.853018570575578 for eigenvalue
#  The estimated number of batches is 1193
#       165/1    0.86761    0.86908 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.841665670147949 for eigenvalue
#  The estimated number of batches is 1191
#       166/1    0.86997    0.86909 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.8210635575872485 for eigenvalue
#  The estimated number of batches is 1182
#       167/1    0.87265    0.86912 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.8092383595876442 for eigenvalue
#  The estimated number of batches is 1181
#       168/1    0.86446    0.86908 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.8121857517821063 for eigenvalue
#  The estimated number of batches is 1191
#       169/1    0.86362    0.86905 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.8027463195270337 for eigenvalue
#  The estimated number of batches is 1191
#       170/1    0.86764    0.86904 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.7852530684380556 for eigenvalue
#  The estimated number of batches is 1184
#       171/1    0.86764    0.86903 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.7764593018097212 for eigenvalue
#  The estimated number of batches is 1185
#       172/1    0.87088    0.86904 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.754853561623711 for eigenvalue
#  The estimated number of batches is 1174
#       173/1    0.87689    0.86909 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.7442070368510185 for eigenvalue
#  The estimated number of batches is 1173
#       174/1    0.87350    0.86912 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.729055903806326 for eigenvalue
#  The estimated number of batches is 1167
#       175/1    0.86891    0.86912 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.7119534980762916 for eigenvalue
#  The estimated number of batches is 1160
#       176/1    0.87009    0.86913 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.692763167052466 for eigenvalue
#  The estimated number of batches is 1152
#       177/1    0.86376    0.86909 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.692490170115224 for eigenvalue
#  The estimated number of batches is 1159
#       178/1    0.86763    0.86908 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.6824629140405585 for eigenvalue
#  The estimated number of batches is 1157
#       179/1    0.87645    0.86913 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.6651941188149664 for eigenvalue
#  The estimated number of batches is 1150
#       180/1    0.86824    0.86912 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.6502491319149026 for eigenvalue
#  The estimated number of batches is 1144
#       181/1    0.87226    0.86914 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.634511050895073 for eigenvalue
#  The estimated number of batches is 1138
#       182/1    0.86554    0.86912 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.619994040586363 for eigenvalue
#  The estimated number of batches is 1133
#       183/1    0.87032    0.86913 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.605809277430304 for eigenvalue
#  The estimated number of batches is 1127
#       184/1    0.87731    0.86918 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.6013837707035377 for eigenvalue
#  The estimated number of batches is 1130
#       185/1    0.86817    0.86917 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5895655709962004 for eigenvalue
#  The estimated number of batches is 1127
#       186/1    0.87045    0.86918 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.576176617361972 for eigenvalue
#  The estimated number of batches is 1122
#       187/1    0.86243    0.86914 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5862675381843268 for eigenvalue
#  The estimated number of batches is 1138
#       188/1    0.87213    0.86916 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.582244001466657 for eigenvalue
#  The estimated number of batches is 1141
#       189/1    0.86654    0.86914 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5703705219684125 for eigenvalue
#  The estimated number of batches is 1137
#       190/1    0.87206    0.86916 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5585778993984984 for eigenvalue
#  The estimated number of batches is 1133
#       191/1    0.87124    0.86917 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.5840190546455775 for eigenvalue
#  The estimated number of batches is 1162
#       192/1    0.87210    0.86919 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.5674296565500208 for eigenvalue
#  The estimated number of batches is 1154
#       193/1    0.87221    0.86920 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.5566276997786828 for eigenvalue
#  The estimated number of batches is 1151
#       194/1    0.87006    0.86921 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.5435755048578095 for eigenvalue
#  The estimated number of batches is 1146
#       195/1    0.87369    0.86924 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.5315621826807626 for eigenvalue
#  The estimated number of batches is 1142
#       196/1    0.87772    0.86928 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.537347024078168 for eigenvalue
#  The estimated number of batches is 1154
#       197/1    0.86297    0.86925 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.5495856905227194 for eigenvalue
#  The estimated number of batches is 1171
#       198/1    0.86645    0.86923 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.537996600667548 for eigenvalue
#  The estimated number of batches is 1167
#       199/1    0.87378    0.86926 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.5282361491494085 for eigenvalue
#  The estimated number of batches is 1165
#       200/1    0.87125    0.86927 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.5183199866812096 for eigenvalue
#  The estimated number of batches is 1162
#       201/1    0.87082    0.86928 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.5089043092327836 for eigenvalue
#  The estimated number of batches is 1160
#       202/1    0.86665    0.86926 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.4966925345079503 for eigenvalue
#  The estimated number of batches is 1155
#       203/1    0.86902    0.86926 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.4828853666467445 for eigenvalue
#  The estimated number of batches is 1149
#       204/1    0.86809    0.86925 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.4685198037166787 for eigenvalue
#  The estimated number of batches is 1142
#       205/1    0.87745    0.86930 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.4587171301487096 for eigenvalue
#  The estimated number of batches is 1139
#       206/1    0.86598    0.86928 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.449997442789278 for eigenvalue
#  The estimated number of batches is 1137
#       207/1    0.86552    0.86926 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.4395826314962066 for eigenvalue
#  The estimated number of batches is 1133
#       208/1    0.86947    0.86926 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.4296870732406033 for eigenvalue
#  The estimated number of batches is 1130
#       209/1    0.86961    0.86926 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.416222544926609 for eigenvalue
#  The estimated number of batches is 1124
#       210/1    0.85985    0.86921 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.429476889925291 for eigenvalue
#  The estimated number of batches is 1142
#       211/1    0.86266    0.86918 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.415854029744009 for eigenvalue
#  The estimated number of batches is 1135
#       212/1    0.87000    0.86918 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.4047965998601457 for eigenvalue
#  The estimated number of batches is 1131
#       213/1    0.86665    0.86917 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3983412565818445 for eigenvalue
#  The estimated number of batches is 1131
#       214/1    0.86347    0.86914 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3929131970919233 for eigenvalue
#  The estimated number of batches is 1131
#       215/1    0.87367    0.86917 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3813134211094273 for eigenvalue
#  The estimated number of batches is 1126
#       216/1    0.87120    0.86918 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.3682802754242576 for eigenvalue
#  The estimated number of batches is 1120
#       217/1    0.86505    0.86915 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.357510578503033 for eigenvalue
#  The estimated number of batches is 1115
#       218/1    0.87555    0.86919 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.371431008460378 for eigenvalue
#  The estimated number of batches is 1134
#       219/1    0.87151    0.86920 +/- 0.00030
#  Triggers unsatisfied, max unc./thresh. is 2.361085621687664 for eigenvalue
#  The estimated number of batches is 1130
#       220/1    0.86957    0.86920 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.350006261634344 for eigenvalue
#  The estimated number of batches is 1125
#       221/1    0.87509    0.86923 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3446836565023266 for eigenvalue
#  The estimated number of batches is 1126
#       222/1    0.87197    0.86924 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.342017745628337 for eigenvalue
#  The estimated number of batches is 1128
#       223/1    0.86672    0.86923 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3310858837730084 for eigenvalue
#  The estimated number of batches is 1124
#       224/1    0.86725    0.86922 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3260349709337156 for eigenvalue
#  The estimated number of batches is 1124
#       225/1    0.86539    0.86920 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.314871465042627 for eigenvalue
#  The estimated number of batches is 1119
#       226/1    0.87237    0.86922 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.305998517514643 for eigenvalue
#  The estimated number of batches is 1116
#       227/1    0.85825    0.86916 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3331649968202415 for eigenvalue
#  The estimated number of batches is 1147
#       228/1    0.87507    0.86919 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3223760004328398 for eigenvalue
#  The estimated number of batches is 1142
#       229/1    0.86244    0.86916 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.318993182561385 for eigenvalue
#  The estimated number of batches is 1144
#       230/1    0.87341    0.86918 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.311815741612035 for eigenvalue
#  The estimated number of batches is 1143
#       231/1    0.87009    0.86919 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3029147184059866 for eigenvalue
#  The estimated number of batches is 1140
#       232/1    0.86534    0.86917 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3045770024272665 for eigenvalue
#  The estimated number of batches is 1146
#       233/1    0.86235    0.86914 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3048388712237386 for eigenvalue
#  The estimated number of batches is 1152
#       234/1    0.87630    0.86917 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.3156950290402865 for eigenvalue
#  The estimated number of batches is 1168
#       235/1    0.87026    0.86917 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.304869585887405 for eigenvalue
#  The estimated number of batches is 1163
#       236/1    0.87365    0.86919 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.294351493409426 for eigenvalue
#  The estimated number of batches is 1158
#       237/1    0.87184    0.86921 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2920557441781266 for eigenvalue
#  The estimated number of batches is 1161
#       238/1    0.86104    0.86917 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2879967386874154 for eigenvalue
#  The estimated number of batches is 1162
#       239/1    0.86624    0.86916 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.2777271751006567 for eigenvalue
#  The estimated number of batches is 1157
#       240/1    0.86549    0.86914 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.274657777886184 for eigenvalue
#  The estimated number of batches is 1159
#       241/1    0.86841    0.86914 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.27082687777736 for eigenvalue
#  The estimated number of batches is 1160
#       242/1    0.87995    0.86918 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.288896787815724 for eigenvalue
#  The estimated number of batches is 1184
#       243/1    0.86907    0.86918 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.280982988609334 for eigenvalue
#  The estimated number of batches is 1181
#       244/1    0.87306    0.86920 +/- 0.00029
#  Triggers unsatisfied, max unc./thresh. is 2.272813655636616 for eigenvalue
#  The estimated number of batches is 1178
#       245/1    0.86705    0.86919 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.266174360420894 for eigenvalue
#  The estimated number of batches is 1176
#       246/1    0.87006    0.86920 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.256266552001944 for eigenvalue
#  The estimated number of batches is 1171
#       247/1    0.87293    0.86921 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.2487644051993083 for eigenvalue
#  The estimated number of batches is 1168
#       248/1    0.86709    0.86920 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.2383862580712632 for eigenvalue
#  The estimated number of batches is 1163
#       249/1    0.87791    0.86924 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.251430521774513 for eigenvalue
#  The estimated number of batches is 1181
#       250/1    0.86508    0.86922 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.245463689249276 for eigenvalue
#  The estimated number of batches is 1180
#       251/1    0.86524    0.86921 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.2354971300135573 for eigenvalue
#  The estimated number of batches is 1175
#       252/1    0.86249    0.86918 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.25400938905416 for eigenvalue
#  The estimated number of batches is 1199
#       253/1    0.87157    0.86919 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.24556439704476 for eigenvalue
#  The estimated number of batches is 1195
#       254/1    0.86606    0.86917 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.240907321381158 for eigenvalue
#  The estimated number of batches is 1196
#       255/1    0.86739    0.86917 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.2310062229404344 for eigenvalue
#  The estimated number of batches is 1190
#       256/1    0.86850    0.86916 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.2254656990742165 for eigenvalue
#  The estimated number of batches is 1189
#       257/1    0.87073    0.86917 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.216876008669989 for eigenvalue
#  The estimated number of batches is 1185
#       258/1    0.87246    0.86918 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.208288674659039 for eigenvalue
#  The estimated number of batches is 1181
#       259/1    0.87188    0.86920 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1998012710603128 for eigenvalue
#  The estimated number of batches is 1177
#       260/1    0.87403    0.86922 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.192699947961386 for eigenvalue
#  The estimated number of batches is 1174
#       261/1    0.86748    0.86921 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1843606027227835 for eigenvalue
#  The estimated number of batches is 1170
#       262/1    0.85964    0.86917 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1847906038529845 for eigenvalue
#  The estimated number of batches is 1176
#       263/1    0.87607    0.86920 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.192920756221273 for eigenvalue
#  The estimated number of batches is 1189
#       264/1    0.87881    0.86924 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1890962617991834 for eigenvalue
#  The estimated number of batches is 1190
#       265/1    0.86879    0.86923 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.180262399207517 for eigenvalue
#  The estimated number of batches is 1185
#       266/1    0.86871    0.86923 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1710650177445467 for eigenvalue
#  The estimated number of batches is 1180
#       267/1    0.86342    0.86921 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1650077316779677 for eigenvalue
#  The estimated number of batches is 1178
#       268/1    0.85930    0.86917 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.175831087598877 for eigenvalue
#  The estimated number of batches is 1195
#       269/1    0.86311    0.86914 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1673826045249154 for eigenvalue
#  The estimated number of batches is 1190
#       270/1    0.86600    0.86913 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1594642803385162 for eigenvalue
#  The estimated number of batches is 1186
#       271/1    0.87524    0.86916 +/- 0.00028
#  Triggers unsatisfied, max unc./thresh. is 2.1578643736457437 for eigenvalue
#  The estimated number of batches is 1189
#       272/1    0.86813    0.86915 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.15124189058333 for eigenvalue
#  The estimated number of batches is 1187
#       273/1    0.86853    0.86915 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1444221934771073 for eigenvalue
#  The estimated number of batches is 1184
#       274/1    0.86778    0.86914 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.135631071989211 for eigenvalue
#  The estimated number of batches is 1179
#       275/1    0.87492    0.86917 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1348152801837914 for eigenvalue
#  The estimated number of batches is 1183
#       276/1    0.87237    0.86918 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.127421480331299 for eigenvalue
#  The estimated number of batches is 1179
#       277/1    0.87072    0.86919 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.127103848038437 for eigenvalue
#  The estimated number of batches is 1183
#       278/1    0.87277    0.86920 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1203688628725215 for eigenvalue
#  The estimated number of batches is 1180
#       279/1    0.86519    0.86918 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1138781113823124 for eigenvalue
#  The estimated number of batches is 1178
#       280/1    0.87240    0.86920 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.110712113685128 for eigenvalue
#  The estimated number of batches is 1179
#       281/1    0.86912    0.86920 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.103972766223109 for eigenvalue
#  The estimated number of batches is 1176
#       282/1    0.87621    0.86922 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.117423240824071 for eigenvalue
#  The estimated number of batches is 1195
#       283/1    0.88026    0.86926 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1191960997103916 for eigenvalue
#  The estimated number of batches is 1202
#       284/1    0.86961    0.86927 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.111403122101733 for eigenvalue
#  The estimated number of batches is 1197
#       285/1    0.86319    0.86924 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.11793654647837 for eigenvalue
#  The estimated number of batches is 1209
#       286/1    0.86792    0.86924 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1105648082368837 for eigenvalue
#  The estimated number of batches is 1205
#       287/1    0.86353    0.86922 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1102725644349634 for eigenvalue
#  The estimated number of batches is 1210
#       288/1    0.86694    0.86921 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.1022220230628856 for eigenvalue
#  The estimated number of batches is 1205
#       289/1    0.86693    0.86920 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0948360407315483 for eigenvalue
#  The estimated number of batches is 1201
#       290/1    0.87705    0.86923 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0926026497156696 for eigenvalue
#  The estimated number of batches is 1203
#       291/1    0.87218    0.86924 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0867993142013788 for eigenvalue
#  The estimated number of batches is 1201
#       292/1    0.87116    0.86925 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.083910014883295 for eigenvalue
#  The estimated number of batches is 1202
#       293/1    0.87711    0.86928 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0850680663043413 for eigenvalue
#  The estimated number of batches is 1207
#       294/1    0.86343    0.86925 +/- 0.00027
#  Triggers unsatisfied, max unc./thresh. is 2.0771124277893738 for eigenvalue
#  The estimated number of batches is 1203
# ...
#  The estimated number of batches is 1236
#       476/1    0.87523    0.86950 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6347884057469038 for eigenvalue
#  The estimated number of batches is 1239
#       477/1    0.87143    0.86950 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6327578960668951 for eigenvalue
#  The estimated number of batches is 1239
#       478/1    0.87217    0.86951 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6324250558784326 for eigenvalue
#  The estimated number of batches is 1241
#       479/1    0.87194    0.86951 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6290393522098057 for eigenvalue
#  The estimated number of batches is 1239
#       480/1    0.86599    0.86951 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6271230827022585 for eigenvalue
#  The estimated number of batches is 1238
#       481/1    0.86950    0.86951 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6235659090348367 for eigenvalue
#  The estimated number of batches is 1236
#       482/1    0.86644    0.86950 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6223865559191086 for eigenvalue
#  The estimated number of batches is 1237
#       483/1    0.87570    0.86951 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6193022722822275 for eigenvalue
#  The estimated number of batches is 1235
#       484/1    0.86898    0.86951 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6165331409152774 for eigenvalue
#  The estimated number of batches is 1233
#       485/1    0.86420    0.86950 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.6127181294578148 for eigenvalue
#  The estimated number of batches is 1230
#       486/1    0.87949    0.86952 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6099898934803196 for eigenvalue
#  The estimated number of batches is 1228
#       487/1    0.87294    0.86953 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6092602153398676 for eigenvalue
#  The estimated number of batches is 1230
#       488/1    0.86755    0.86952 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.605708099994881 for eigenvalue
#  The estimated number of batches is 1227
#       489/1    0.87978    0.86955 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.6094167882235162 for eigenvalue
#  The estimated number of batches is 1235
#       490/1    0.86974    0.86955 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.606039991713612 for eigenvalue
#  The estimated number of batches is 1233
#       491/1    0.87005    0.86955 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.6027429686766161 for eigenvalue
#  The estimated number of batches is 1230
#       492/1    0.86957    0.86955 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.600524396454364 for eigenvalue
#  The estimated number of batches is 1230
#       493/1    0.86723    0.86954 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5970223937098242 for eigenvalue
#  The estimated number of batches is 1227
#       494/1    0.87263    0.86955 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.596070568092896 for eigenvalue
#  The estimated number of batches is 1228
#       495/1    0.86726    0.86954 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.592474419582184 for eigenvalue
#  The estimated number of batches is 1225
#       496/1    0.87291    0.86955 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5894370482619085 for eigenvalue
#  The estimated number of batches is 1223
#       497/1    0.87421    0.86956 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.587129465545597 for eigenvalue
#  The estimated number of batches is 1222
#       498/1    0.87033    0.86956 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5849968367166258 for eigenvalue
#  The estimated number of batches is 1221
#       499/1    0.87320    0.86957 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5841752932814634 for eigenvalue
#  The estimated number of batches is 1223
#       500/1    0.86590    0.86956 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5805355805542354 for eigenvalue
#  The estimated number of batches is 1220
#       501/1    0.87278    0.86957 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5776431222855536 for eigenvalue
#  The estimated number of batches is 1218
#       502/1    0.87284    0.86958 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5749956399919618 for eigenvalue
#  The estimated number of batches is 1216
#       503/1    0.87406    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5728810133842897 for eigenvalue
#  The estimated number of batches is 1215
#       504/1    0.87296    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5699174729209169 for eigenvalue
#  The estimated number of batches is 1213
#       505/1    0.86424    0.86958 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5667982537185634 for eigenvalue
#  The estimated number of batches is 1211
#       506/1    0.86761    0.86958 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5635030484299886 for eigenvalue
#  The estimated number of batches is 1209
#       507/1    0.87107    0.86958 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.560370926653097 for eigenvalue
#  The estimated number of batches is 1206
#       508/1    0.87732    0.86960 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5594110190117416 for eigenvalue
#  The estimated number of batches is 1207
#       509/1    0.87134    0.86960 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5563102265231117 for eigenvalue
#  The estimated number of batches is 1205
#       510/1    0.86452    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5527858306315194 for eigenvalue
#  The estimated number of batches is 1202
#       511/1    0.87081    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.549767311837574 for eigenvalue
#  The estimated number of batches is 1200
#       512/1    0.86621    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5474675338790203 for eigenvalue
#  The estimated number of batches is 1199
#       513/1    0.86834    0.86958 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5455635189202197 for eigenvalue
#  The estimated number of batches is 1198
#       514/1    0.86648    0.86958 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.542523184065921 for eigenvalue
#  The estimated number of batches is 1196
#       515/1    0.87693    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5421498422528868 for eigenvalue
#  The estimated number of batches is 1198
#       516/1    0.86599    0.86958 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5430181243472472 for eigenvalue
#  The estimated number of batches is 1201
#       517/1    0.87136    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5413379680873889 for eigenvalue
#  The estimated number of batches is 1201
#       518/1    0.86901    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.538440803543316 for eigenvalue
#  The estimated number of batches is 1199
#       519/1    0.86720    0.86958 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5351217928296383 for eigenvalue
#  The estimated number of batches is 1196
#       520/1    0.87560    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.536519334757908 for eigenvalue
#  The estimated number of batches is 1201
#       521/1    0.87252    0.86960 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.533726630614102 for eigenvalue
#  The estimated number of batches is 1199
#       522/1    0.87180    0.86960 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5310876057730802 for eigenvalue
#  The estimated number of batches is 1197
#       523/1    0.87173    0.86961 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5351597537092374 for eigenvalue
#  The estimated number of batches is 1206
#       524/1    0.86117    0.86959 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.535342159978446 for eigenvalue
#  The estimated number of batches is 1209
#       525/1    0.87188    0.86960 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5331323692956407 for eigenvalue
#  The estimated number of batches is 1207
#       526/1    0.86336    0.86958 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5353786138308596 for eigenvalue
#  The estimated number of batches is 1213
#       527/1    0.86372    0.86957 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5320935888122744 for eigenvalue
#  The estimated number of batches is 1211
#       528/1    0.87252    0.86958 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5302614619145292 for eigenvalue
#  The estimated number of batches is 1210
#       529/1    0.86844    0.86958 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.527272132363941 for eigenvalue
#  The estimated number of batches is 1208
#       530/1    0.86782    0.86957 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.524557447243865 for eigenvalue
#  The estimated number of batches is 1206
#       531/1    0.87274    0.86958 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5218423286398344 for eigenvalue
#  The estimated number of batches is 1204
#       532/1    0.86691    0.86957 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5187912603576783 for eigenvalue
#  The estimated number of batches is 1202
#       533/1    0.86984    0.86957 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.51587346871786 for eigenvalue
#  The estimated number of batches is 1199
#       534/1    0.86074    0.86956 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5138919043815435 for eigenvalue
#  The estimated number of batches is 1199
#       535/1    0.87183    0.86956 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5110603593923737 for eigenvalue
#  The estimated number of batches is 1196
#       536/1    0.87354    0.86957 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5096485728891997 for eigenvalue
#  The estimated number of batches is 1196
#       537/1    0.86945    0.86957 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5074279247105664 for eigenvalue
#  The estimated number of batches is 1195
#       538/1    0.86627    0.86956 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5059905839675323 for eigenvalue
#  The estimated number of batches is 1195
#       539/1    0.86460    0.86955 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.503048961109157 for eigenvalue
#  The estimated number of batches is 1193
#       540/1    0.87355    0.86956 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5017048112929599 for eigenvalue
#  The estimated number of batches is 1193
#       541/1    0.87437    0.86957 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5008719850691836 for eigenvalue
#  The estimated number of batches is 1194
#       542/1    0.87450    0.86958 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5042870936740116 for eigenvalue
#  The estimated number of batches is 1202
#       543/1    0.86390    0.86957 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5051636396098893 for eigenvalue
#  The estimated number of batches is 1205
#       544/1    0.85848    0.86955 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.516778956353898 for eigenvalue
#  The estimated number of batches is 1226
#       545/1    0.87372    0.86955 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5213707100061507 for eigenvalue
#  The estimated number of batches is 1236
#       546/1    0.87205    0.86956 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5191521620489103 for eigenvalue
#  The estimated number of batches is 1234
#       547/1    0.86562    0.86955 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5163767750824138 for eigenvalue
#  The estimated number of batches is 1232
#       548/1    0.86621    0.86955 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5146070804088558 for eigenvalue
#  The estimated number of batches is 1232
#       549/1    0.86588    0.86954 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5116141120190831 for eigenvalue
#  The estimated number of batches is 1229
#       550/1    0.86887    0.86954 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5099571454936105 for eigenvalue
#  The estimated number of batches is 1229
#       551/1    0.86816    0.86953 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5072257153518436 for eigenvalue
#  The estimated number of batches is 1227
#       552/1    0.86344    0.86952 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5044229910347142 for eigenvalue
#  The estimated number of batches is 1225
#       553/1    0.86190    0.86951 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5013712506015906 for eigenvalue
#  The estimated number of batches is 1222
#       554/1    0.86957    0.86951 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4994961429769575 for eigenvalue
#  The estimated number of batches is 1221
#       555/1    0.86900    0.86951 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4968945177638164 for eigenvalue
#  The estimated number of batches is 1219
#       556/1    0.86880    0.86951 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4956503965260506 for eigenvalue
#  The estimated number of batches is 1220
#       557/1    0.86676    0.86950 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4928251702407784 for eigenvalue
#  The estimated number of batches is 1217
#       558/1    0.87211    0.86951 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4927213506021684 for eigenvalue
#  The estimated number of batches is 1219
#       559/1    0.87192    0.86951 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4902470839223545 for eigenvalue
#  The estimated number of batches is 1218
#       560/1    0.86683    0.86951 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.487381613514512 for eigenvalue
#  The estimated number of batches is 1215
#       561/1    0.86698    0.86950 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4850420537478202 for eigenvalue
#  The estimated number of batches is 1214
#       562/1    0.86083    0.86949 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4883723280466592 for eigenvalue
#  The estimated number of batches is 1221
#       563/1    0.87022    0.86949 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4856502591141265 for eigenvalue
#  The estimated number of batches is 1219
#       564/1    0.87064    0.86949 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4829705534458237 for eigenvalue
#  The estimated number of batches is 1217
#       565/1    0.86999    0.86949 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.48091420581686 for eigenvalue
#  The estimated number of batches is 1216
#       566/1    0.86434    0.86948 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.479084660574989 for eigenvalue
#  The estimated number of batches is 1215
#       567/1    0.86147    0.86947 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4760251736739562 for eigenvalue
#  The estimated number of batches is 1212
#       568/1    0.86075    0.86945 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4787120056223049 for eigenvalue
#  The estimated number of batches is 1219
#       569/1    0.86672    0.86944 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4758363358609579 for eigenvalue
#  The estimated number of batches is 1216
#       570/1    0.87347    0.86945 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4742653561353636 for eigenvalue
#  The estimated number of batches is 1216
#       571/1    0.86399    0.86944 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.471905159949743 for eigenvalue
#  The estimated number of batches is 1214
#       572/1    0.86719    0.86944 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4699601313884156 for eigenvalue
#  The estimated number of batches is 1213
