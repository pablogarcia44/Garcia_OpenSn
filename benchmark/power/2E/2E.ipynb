# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create Pyrex Tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
GT=[(8,2),(3,3),(5,5),(2,8)]
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))

PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %% [markdown]
# ### Create family pincell

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT :
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]    

#print(A)           
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
print(model.geometry.get_all_material_cells().values())
# Out:
# dict_values([Cell
# 	ID             =	1
# 	Name           =	fuel_pincell_1_family
# 	Fill           =	Material 1
# 	Region         =	-1
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	3
# 	Name           =	clad_pincell_1_family
# 	Fill           =	Material 2
# 	Region         =	(2 -3)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	4
# 	Name           =	moderator_pincell_1_family
# 	Fill           =	Material 3
# 	Region         =	(4 -5 6 -7 3)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	2
# 	Name           =	gap_pincell_1_family
# 	Fill           =	Material 4
# 	Region         =	(1 -2)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	11
# 	Name           =	steel_cell_pyrex_1_family
# 	Fill           =	Material 6
# 	Region         =	((26 -27) | (22 -23))
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	12
# 	Name           =	gap_cell_pyrex_1_family
# 	Fill           =	Material 4
# 	Region         =	((23 -24) | (25 -26) | -22)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	13
# 	Name           =	pyrex_cell_pyrex_1_family
# 	Fill           =	Material 5
# 	Region         =	(24 -25)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	15
# 	Name           =	guide_cell_pyrex_1_family
# 	Fill           =	Material 2
# 	Region         =	(20 -21)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	14
# 	Name           =	water_cell_pyrex_1_family
# 	Fill           =	Material 3
# 	Region         =	((28 -29 30 -31 21) | (27 -20))
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	5
# 	Name           =	water_guide_1_family
# 	Fill           =	Material 3
# 	Region         =	-8
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	6
# 	Name           =	clad_guide_1_family
# 	Fill           =	Material 2
# 	Region         =	(8 -9)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	7
# 	Name           =	moderator_guide_1_family
# 	Fill           =	Material 3
# 	Region         =	(10 -11 12 -13 9)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	8
# 	Name           =	water_guide_instru_1_family
# 	Fill           =	Material 3
# 	Region         =	-14
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	9
# 	Name           =	clad_guide_instru_1_family
# 	Fill           =	Material 2
# 	Region         =	(14 -15)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	10
# 	Name           =	moderator_instru_1_family
# 	Fill           =	Material 3
# 	Region         =	(16 -17 18 -19 15)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	16
# 	Name           =	water_outside
# 	Fill           =	Material 3
# 	Region         =	None
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ])

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-12 17:31:05
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.07602
#         2/1    1.07152
#         3/1    1.06804
#         4/1    1.07296
#         5/1    1.06657
#         6/1    1.06666
#         7/1    1.06398
#         8/1    1.07986
#         9/1    1.07038
#        10/1    1.07422
#        11/1    1.07271
#        12/1    1.06256
#        13/1    1.07582
#        14/1    1.07430
#        15/1    1.07732
#        16/1    1.06107
#        17/1    1.07039
#        18/1    1.06101
#        19/1    1.07697
#        20/1    1.07646
#        21/1    1.07469
#        22/1    1.07714    1.07591 +/- 0.00122
#        23/1    1.07436    1.07540 +/- 0.00088
#        24/1    1.08104    1.07681 +/- 0.00154
#        25/1    1.06703    1.07485 +/- 0.00229
#        26/1    1.07074    1.07417 +/- 0.00199
#        27/1    1.05731    1.07176 +/- 0.00294
#        28/1    1.06857    1.07136 +/- 0.00258
#        29/1    1.06860    1.07105 +/- 0.00229
#        30/1    1.07467    1.07142 +/- 0.00208
#        31/1    1.06423    1.07076 +/- 0.00199
#        32/1    1.06653    1.07041 +/- 0.00185
#        33/1    1.06950    1.07034 +/- 0.00171
#        34/1    1.07037    1.07034 +/- 0.00158
#        35/1    1.07113    1.07040 +/- 0.00147
#        36/1    1.07827    1.07089 +/- 0.00146
#        37/1    1.06552    1.07057 +/- 0.00141
#        38/1    1.06558    1.07029 +/- 0.00136
#        39/1    1.06852    1.07020 +/- 0.00129
#        40/1    1.06448    1.06991 +/- 0.00125
#        41/1    1.05939    1.06941 +/- 0.00129
#        42/1    1.07300    1.06958 +/- 0.00124
#        43/1    1.06946    1.06957 +/- 0.00119
#        44/1    1.07473    1.06979 +/- 0.00116
#        45/1    1.06295    1.06951 +/- 0.00114
#        46/1    1.07045    1.06955 +/- 0.00110
#        47/1    1.07336    1.06969 +/- 0.00107
#        48/1    1.06816    1.06964 +/- 0.00103
#        49/1    1.06669    1.06953 +/- 0.00100
#        50/1    1.07137    1.06959 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 5.65283300963784 for eigenvalue
#  The estimated number of batches is 979
#  Creating state point statepoint.00050.h5...
#        51/1    1.07351    1.06972 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.8483880296183175 for eigenvalue
#  The estimated number of batches is 1081
#        52/1    1.06699    1.06964 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.636733733637096 for eigenvalue
#  The estimated number of batches is 1037
#        53/1    1.06476    1.06949 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.454844796426956 for eigenvalue
#  The estimated number of batches is 1002
#        54/1    1.06696    1.06941 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.319863508106928 for eigenvalue
#  The estimated number of batches is 983
#        55/1    1.06972    1.06942 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.2394437304593495 for eigenvalue
#  The estimated number of batches is 981
#        56/1    1.07107    1.06947 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.081849709374454 for eigenvalue
#  The estimated number of batches is 950
#        57/1    1.07537    1.06963 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.051228767557449 for eigenvalue
#  The estimated number of batches is 965
#        58/1    1.07660    1.06981 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.249115879368991 for eigenvalue
#  The estimated number of batches is 1068
#        59/1    1.06718    1.06974 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.210087337003458 for eigenvalue
#  The estimated number of batches is 1079
#        60/1    1.07623    1.06991 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.424023440292613 for eigenvalue
#  The estimated number of batches is 1197
#        61/1    1.06829    1.06987 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.306406841886045 for eigenvalue
#  The estimated number of batches is 1175
#        62/1    1.07520    1.06999 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.457386235291169 for eigenvalue
#  The estimated number of batches is 1271
#        63/1    1.07997    1.07023 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.4422565648261445 for eigenvalue
#  The estimated number of batches is 1294
#        64/1    1.07255    1.07028 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.362961898235391 for eigenvalue
#  The estimated number of batches is 1286
#        65/1    1.07414    1.07036 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.266055631617891 for eigenvalue
#  The estimated number of batches is 1268
#        66/1    1.06992    1.07035 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.149591825569256 for eigenvalue
#  The estimated number of batches is 1240
#        67/1    1.06889    1.07032 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.043732152881788 for eigenvalue
#  The estimated number of batches is 1216
#        68/1    1.07075    1.07033 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.984677654064104 for eigenvalue
#  The estimated number of batches is 1213
#        69/1    1.06715    1.07027 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.083871949052606 for eigenvalue
#  The estimated number of batches is 1287
#        70/1    1.06518    1.07017 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.019369184495111 for eigenvalue
#  The estimated number of batches is 1280
#        71/1    1.07037    1.07017 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.962039190352103 for eigenvalue
#  The estimated number of batches is 1276
#        72/1    1.06224    1.07002 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.180528915497685 for eigenvalue
#  The estimated number of batches is 1416
#        73/1    1.07172    1.07005 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.090518974722968 for eigenvalue
#  The estimated number of batches is 1394
#        74/1    1.07377    1.07012 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 5.0788997258475765 for eigenvalue
#  The estimated number of batches is 1413
#        75/1    1.07370    1.07018 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.066287938298306 for eigenvalue
#  The estimated number of batches is 1432
#        76/1    1.06307    1.07006 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.915559489173485 for eigenvalue
#  The estimated number of batches is 1374
#        77/1    1.07825    1.07020 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.8726851843105825 for eigenvalue
#  The estimated number of batches is 1374
#        78/1    1.06358    1.07009 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.830122526957239 for eigenvalue
#  The estimated number of batches is 1374
#        79/1    1.06450    1.06999 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.765269623024238 for eigenvalue
#  The estimated number of batches is 1360
#        80/1    1.06219    1.06986 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.730832759267177 for eigenvalue
#  The estimated number of batches is 1363
#        81/1    1.07988    1.07003 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.79995964680116 for eigenvalue
#  The estimated number of batches is 1426
#        82/1    1.07648    1.07013 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.738973152780673 for eigenvalue
#  The estimated number of batches is 1413
#        83/1    1.06747    1.07009 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.675758953510013 for eigenvalue
#  The estimated number of batches is 1398
#        84/1    1.05875    1.06991 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.597976596925332 for eigenvalue
#  The estimated number of batches is 1374
#        85/1    1.07591    1.07000 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.580929572751439 for eigenvalue
#  The estimated number of batches is 1385
#        86/1    1.06335    1.06990 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.562498064868025 for eigenvalue
#  The estimated number of batches is 1394
#        87/1    1.06956    1.06990 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.481024873097854 for eigenvalue
#  The estimated number of batches is 1366
#        88/1    1.07334    1.06995 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.498867556526272 for eigenvalue
#  The estimated number of batches is 1397
#        89/1    1.07046    1.06995 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.436701825755068 for eigenvalue
#  The estimated number of batches is 1379
#        90/1    1.07218    1.06999 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.371329841057712 for eigenvalue
#  The estimated number of batches is 1358
#        91/1    1.06883    1.06997 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.435280364187888 for eigenvalue
#  The estimated number of batches is 1417
#        92/1    1.07290    1.07001 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.3794811269550795 for eigenvalue
#  The estimated number of batches is 1401
#        93/1    1.06659    1.06996 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.351311474727334 for eigenvalue
#  The estimated number of batches is 1403
#        94/1    1.06576    1.06991 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.400698467508799 for eigenvalue
#  The estimated number of batches is 1454
#        95/1    1.06730    1.06987 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.424152241842191 for eigenvalue
#  The estimated number of batches is 1488
#        96/1    1.06212    1.06977 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.425976246552713 for eigenvalue
#  The estimated number of batches is 1509
#        97/1    1.07848    1.06988 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.516547275923927 for eigenvalue
#  The estimated number of batches is 1591
#        98/1    1.06608    1.06983 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.45150851990478 for eigenvalue
#  The estimated number of batches is 1566
#        99/1    1.07077    1.06985 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.399766199846833 for eigenvalue
#  The estimated number of batches is 1550
#       100/1    1.06217    1.06975 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.38540834191507 for eigenvalue
#  The estimated number of batches is 1559
#       101/1    1.07405    1.06980 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.340200131935148 for eigenvalue
#  The estimated number of batches is 1546
#       102/1    1.06984    1.06980 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.287249522139166 for eigenvalue
#  The estimated number of batches is 1528
#       103/1    1.06926    1.06980 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.2345963332632985 for eigenvalue
#  The estimated number of batches is 1509
#       104/1    1.06896    1.06979 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.183774879343233 for eigenvalue
#  The estimated number of batches is 1491
#       105/1    1.08038    1.06991 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.370421638066861 for eigenvalue
#  The estimated number of batches is 1644
#       106/1    1.07151    1.06993 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.335887447111425 for eigenvalue
#  The estimated number of batches is 1637
#       107/1    1.07187    1.06995 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.312260173975751 for eigenvalue
#  The estimated number of batches is 1638
#       108/1    1.06467    1.06989 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.288147193314035 for eigenvalue
#  The estimated number of batches is 1639
#       109/1    1.06644    1.06985 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.23352372819023 for eigenvalue
#  The estimated number of batches is 1616
#       110/1    1.06614    1.06981 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.185349869650808 for eigenvalue
#  The estimated number of batches is 1597
#       111/1    1.07270    1.06984 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.1531086930874395 for eigenvalue
#  The estimated number of batches is 1590
#       112/1    1.06861    1.06983 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.11087702564692 for eigenvalue
#  The estimated number of batches is 1575
#       113/1    1.06519    1.06978 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.070887388175722 for eigenvalue
#  The estimated number of batches is 1562
#       114/1    1.07282    1.06981 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.032393470852881 for eigenvalue
#  The estimated number of batches is 1549
#       115/1    1.06930    1.06981 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.9898198369539832 for eigenvalue
#  The estimated number of batches is 1533
#       116/1    1.05957    1.06970 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.955123046728536 for eigenvalue
#  The estimated number of batches is 1522
#       117/1    1.07530    1.06976 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.9224580531478064 for eigenvalue
#  The estimated number of batches is 1513
#       118/1    1.07499    1.06981 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.937520797814499 for eigenvalue
#  The estimated number of batches is 1540
#       119/1    1.07458    1.06986 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.9138116302996027 for eigenvalue
#  The estimated number of batches is 1537
#       120/1    1.07542    1.06992 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.8913354639104325 for eigenvalue
#  The estimated number of batches is 1535
#       121/1    1.06753    1.06989 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.854224859784216 for eigenvalue
#  The estimated number of batches is 1521
#       122/1    1.07878    1.06998 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.855262341223864 for eigenvalue
#  The estimated number of batches is 1537
#       123/1    1.07557    1.07003 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.8279821875245967 for eigenvalue
#  The estimated number of batches is 1530
#       124/1    1.06511    1.06999 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.796277884387337 for eigenvalue
#  The estimated number of batches is 1519
#       125/1    1.06722    1.06996 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.7579584682359424 for eigenvalue
#  The estimated number of batches is 1503
#       126/1    1.05619    1.06983 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7365025241119523 for eigenvalue
#  The estimated number of batches is 1500
#       127/1    1.06722    1.06981 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.695844198524886 for eigenvalue
#  The estimated number of batches is 1482
#       128/1    1.07205    1.06983 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.663734293694053 for eigenvalue
#  The estimated number of batches is 1470
#       129/1    1.06647    1.06980 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6263224979928257 for eigenvalue
#  The estimated number of batches is 1454
#       130/1    1.06913    1.06979 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.5939361338588958 for eigenvalue
#  The estimated number of batches is 1441
#       131/1    1.06988    1.06979 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.5613291612647555 for eigenvalue
#  The estimated number of batches is 1428
#       132/1    1.07827    1.06987 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.545807485041135 for eigenvalue
#  The estimated number of batches is 1429
#       133/1    1.07754    1.06993 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.534153700141813 for eigenvalue
#  The estimated number of batches is 1432
#       134/1    1.06937    1.06993 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.5086030771504113 for eigenvalue
#  The estimated number of batches is 1424
#       135/1    1.07704    1.06999 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.4848846471616266 for eigenvalue
#  The estimated number of batches is 1417
#       136/1    1.06414    1.06994 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.4469544396814538 for eigenvalue
#  The estimated number of batches is 1399
#       137/1    1.07313    1.06997 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.43538745369592 for eigenvalue
#  The estimated number of batches is 1401
#       138/1    1.06434    1.06992 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.4215639745857622 for eigenvalue
#  The estimated number of batches is 1402
#       139/1    1.07203    1.06994 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.40401251088378 for eigenvalue
#  The estimated number of batches is 1399
#       140/1    1.06277    1.06988 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.3692613037479826 for eigenvalue
#  The estimated number of batches is 1383
#       141/1    1.07301    1.06990 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.343597447843551 for eigenvalue
#  The estimated number of batches is 1373
#       142/1    1.07073    1.06991 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.31665798802433 for eigenvalue
#  The estimated number of batches is 1363
#       143/1    1.07066    1.06992 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.295625751789028 for eigenvalue
#  The estimated number of batches is 1356
#       144/1    1.07178    1.06993 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.2768029995464993 for eigenvalue
#  The estimated number of batches is 1352
#       145/1    1.07403    1.06997 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.272004328572189 for eigenvalue
#  The estimated number of batches is 1359
#       146/1    1.06649    1.06994 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.243527122312806 for eigenvalue
#  The estimated number of batches is 1346
#       147/1    1.06922    1.06993 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2565229361769874 for eigenvalue
#  The estimated number of batches is 1367
#       148/1    1.06226    1.06987 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2961082646527977 for eigenvalue
#  The estimated number of batches is 1411
#       149/1    1.06932    1.06987 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3159078905991244 for eigenvalue
#  The estimated number of batches is 1439
#       150/1    1.07309    1.06989 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.291193161866191 for eigenvalue
#  The estimated number of batches is 1429
#       151/1    1.07631    1.06994 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.271878016891244 for eigenvalue
#  The estimated number of batches is 1423
#       152/1    1.08100    1.07003 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2682002290084364 for eigenvalue
#  The estimated number of batches is 1430
#       153/1    1.06218    1.06997 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2478595374565398 for eigenvalue
#  The estimated number of batches is 1423
#       154/1    1.07385    1.07000 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2718720990040433 for eigenvalue
#  The estimated number of batches is 1455
#       155/1    1.06833    1.06998 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2508962958994987 for eigenvalue
#  The estimated number of batches is 1447
#       156/1    1.07634    1.07003 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.261818225527591 for eigenvalue
#  The estimated number of batches is 1467
#       157/1    1.06675    1.07001 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.237437618101979 for eigenvalue
#  The estimated number of batches is 1456
#       158/1    1.06681    1.06998 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2129207065537697 for eigenvalue
#  The estimated number of batches is 1445
#       159/1    1.06572    1.06995 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.210025671651969 for eigenvalue
#  The estimated number of batches is 1453
#       160/1    1.07057    1.06996 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2015229178735107 for eigenvalue
#  The estimated number of batches is 1455
#       161/1    1.06652    1.06993 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1859103868870013 for eigenvalue
#  The estimated number of batches is 1452
#       162/1    1.07736    1.06998 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.166962056944441 for eigenvalue
#  The estimated number of batches is 1445
#       163/1    1.07611    1.07003 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.18769644027401 for eigenvalue
#  The estimated number of batches is 1474
#       164/1    1.07610    1.07007 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1691650853689164 for eigenvalue
#  The estimated number of batches is 1467
#       165/1    1.06171    1.07001 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1681493088669725 for eigenvalue
#  The estimated number of batches is 1476
#       166/1    1.07506    1.07005 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1746829417709863 for eigenvalue
#  The estimated number of batches is 1492
#       167/1    1.06423    1.07001 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1660119054115152 for eigenvalue
#  The estimated number of batches is 1494
#       168/1    1.06727    1.06999 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.148537587686148 for eigenvalue
#  The estimated number of batches is 1488
#       169/1    1.07529    1.07002 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1414268268267946 for eigenvalue
#  The estimated number of batches is 1491
#       170/1    1.07005    1.07002 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1234576279237736 for eigenvalue
#  The estimated number of batches is 1484
#       171/1    1.07747    1.07007 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1107254989932187 for eigenvalue
#  The estimated number of batches is 1482
#       172/1    1.06700    1.07005 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.099368182134892 for eigenvalue
#  The estimated number of batches is 1481
#       173/1    1.06549    1.07002 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.095215504461575 for eigenvalue
#  The estimated number of batches is 1486
#       174/1    1.06800    1.07001 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0770119474671684 for eigenvalue
#  The estimated number of batches is 1479
#       175/1    1.08378    1.07010 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0662338956998423 for eigenvalue
#  The estimated number of batches is 1478
#       176/1    1.06380    1.07006 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.045513097495255 for eigenvalue
#  The estimated number of batches is 1467
#       177/1    1.07002    1.07006 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.025706260080176 for eigenvalue
#  The estimated number of batches is 1458
#       178/1    1.06646    1.07004 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0212272877660533 for eigenvalue
#  The estimated number of batches is 1463
#       179/1    1.06781    1.07002 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0116457090190534 for eigenvalue
#  The estimated number of batches is 1463
#       180/1    1.06418    1.06999 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0143227997472364 for eigenvalue
#  The estimated number of batches is 1474
#       181/1    1.06932    1.06998 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0202903275164728 for eigenvalue
#  The estimated number of batches is 1489
#       182/1    1.07452    1.07001 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.004882856042959 for eigenvalue
#  The estimated number of batches is 1483
#       183/1    1.06357    1.06997 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9846060766325917 for eigenvalue
#  The estimated number of batches is 1472
#       184/1    1.07459    1.07000 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9711624832592194 for eigenvalue
#  The estimated number of batches is 1468
#       185/1    1.06441    1.06996 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9523866649388424 for eigenvalue
#  The estimated number of batches is 1459
#       186/1    1.07175    1.06997 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.938441858195351 for eigenvalue
#  The estimated number of batches is 1454
#       187/1    1.07209    1.06999 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.922863560176624 for eigenvalue
#  The estimated number of batches is 1447
#       188/1    1.07494    1.07002 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9080200129287035 for eigenvalue
#  The estimated number of batches is 1441
#       189/1    1.06245    1.06997 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9019652897360038 for eigenvalue
#  The estimated number of batches is 1444
#       190/1    1.06901    1.06997 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8859917389069594 for eigenvalue
#  The estimated number of batches is 1436
#       191/1    1.06352    1.06993 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8675555351503204 for eigenvalue
#  The estimated number of batches is 1427
#       192/1    1.07260    1.06994 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.851806559918235 for eigenvalue
#  The estimated number of batches is 1419
#       193/1    1.06395    1.06991 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8320246696538227 for eigenvalue
#  The estimated number of batches is 1408
#       194/1    1.06427    1.06988 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8139515775825577 for eigenvalue
#  The estimated number of batches is 1398
#       195/1    1.07741    1.06992 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8164401336299107 for eigenvalue
#  The estimated number of batches is 1409
#       196/1    1.06518    1.06989 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.817293973172748 for eigenvalue
#  The estimated number of batches is 1417
#       197/1    1.06398    1.06986 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7996533627459774 for eigenvalue
#  The estimated number of batches is 1408
#       198/1    1.06366    1.06983 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7929666938487565 for eigenvalue
#  The estimated number of batches is 1409
#       199/1    1.07379    1.06985 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7876347505951884 for eigenvalue
#  The estimated number of batches is 1411
#       200/1    1.06009    1.06979 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7840230856448995 for eigenvalue
#  The estimated number of batches is 1416
#       201/1    1.07761    1.06984 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7746834257728072 for eigenvalue
#  The estimated number of batches is 1414
#       202/1    1.07777    1.06988 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7900243451149054 for eigenvalue
#  The estimated number of batches is 1437
#       203/1    1.05568    1.06980 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7717365049684752 for eigenvalue
#  The estimated number of batches is 1426
#       204/1    1.06889    1.06980 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.771035380157158 for eigenvalue
#  The estimated number of batches is 1433
#       205/1    1.06671    1.06978 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7565582457405804 for eigenvalue
#  The estimated number of batches is 1426
#       206/1    1.06781    1.06977 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.74053176869076 for eigenvalue
#  The estimated number of batches is 1417
#       207/1    1.07000    1.06977 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.729552621894756 for eigenvalue
#  The estimated number of batches is 1414
#       208/1    1.06463    1.06974 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7213942080633147 for eigenvalue
#  The estimated number of batches is 1413
#       209/1    1.06902    1.06974 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7101893512228585 for eigenvalue
#  The estimated number of batches is 1409
#       210/1    1.06703    1.06973 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.696125157362416 for eigenvalue
#  The estimated number of batches is 1402
#       211/1    1.07240    1.06974 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6820316740295387 for eigenvalue
#  The estimated number of batches is 1394
#       212/1    1.06375    1.06971 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.666651578345199 for eigenvalue
#  The estimated number of batches is 1386
#       213/1    1.07118    1.06972 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.656899960291049 for eigenvalue
#  The estimated number of batches is 1383
#       214/1    1.06260    1.06968 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.653721085926793 for eigenvalue
#  The estimated number of batches is 1387
#       215/1    1.07232    1.06969 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6532825404936147 for eigenvalue
#  The estimated number of batches is 1393
#       216/1    1.06371    1.06966 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6394156995848306 for eigenvalue
#  The estimated number of batches is 1386
#       217/1    1.07719    1.06970 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6424023940124175 for eigenvalue
#  The estimated number of batches is 1396
#       218/1    1.06365    1.06967 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6347770790878617 for eigenvalue
#  The estimated number of batches is 1395
#       219/1    1.06640    1.06965 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.668544749555374 for eigenvalue
#  The estimated number of batches is 1438
#       220/1    1.07410    1.06968 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.657734412733096 for eigenvalue
#  The estimated number of batches is 1433
#       221/1    1.06519    1.06965 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.667201047934446 for eigenvalue
#  The estimated number of batches is 1450
#       222/1    1.07381    1.06967 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.656022193018327 for eigenvalue
#  The estimated number of batches is 1445
#       223/1    1.06796    1.06967 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6418111138816984 for eigenvalue
#  The estimated number of batches is 1437
#       224/1    1.07578    1.06970 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.662076491294029 for eigenvalue
#  The estimated number of batches is 1466
#       225/1    1.06256    1.06966 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6521703519327167 for eigenvalue
#  The estimated number of batches is 1462
#       226/1    1.07119    1.06967 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6478639229352114 for eigenvalue
#  The estimated number of batches is 1465
#       227/1    1.06957    1.06967 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6356621341215534 for eigenvalue
#  The estimated number of batches is 1458
#       228/1    1.06554    1.06965 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.623219900750502 for eigenvalue
#  The estimated number of batches is 1452
#       229/1    1.07288    1.06966 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6416151813415194 for eigenvalue
#  The estimated number of batches is 1479
#       230/1    1.06113    1.06962 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6313218663860365 for eigenvalue
#  The estimated number of batches is 1475
#       231/1    1.06763    1.06961 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6196064424507974 for eigenvalue
#  The estimated number of batches is 1468
#       232/1    1.06520    1.06959 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.614892131110447 for eigenvalue
#  The estimated number of batches is 1470
#       233/1    1.06991    1.06959 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.604941979093233 for eigenvalue
#  The estimated number of batches is 1466
#       234/1    1.07395    1.06961 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5933956640010933 for eigenvalue
#  The estimated number of batches is 1460
#       235/1    1.06813    1.06961 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5849752202123124 for eigenvalue
#  The estimated number of batches is 1457
#       236/1    1.06316    1.06958 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.572786093510517 for eigenvalue
#  The estimated number of batches is 1450
#       237/1    1.07563    1.06961 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.573634860672882 for eigenvalue
#  The estimated number of batches is 1458
#       238/1    1.06728    1.06959 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.563087147806127 for eigenvalue
#  The estimated number of batches is 1453
#       239/1    1.07607    1.06962 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5621306609006735 for eigenvalue
#  The estimated number of batches is 1458
#       240/1    1.06368    1.06960 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.564770658952978 for eigenvalue
#  The estimated number of batches is 1468
#       241/1    1.07519    1.06962 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.552763901407505 for eigenvalue
#  The estimated number of batches is 1461
#       242/1    1.07513    1.06965 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5423713588190484 for eigenvalue
#  The estimated number of batches is 1455
#       243/1    1.06999    1.06965 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.538026590392631 for eigenvalue
#  The estimated number of batches is 1457
#       244/1    1.07049    1.06965 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5277034930366353 for eigenvalue
#  The estimated number of batches is 1452
#       245/1    1.07756    1.06969 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5235112566777365 for eigenvalue
#  The estimated number of batches is 1453
#       246/1    1.07754    1.06972 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5254189816611676 for eigenvalue
#  The estimated number of batches is 1462
#       247/1    1.06263    1.06969 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5313302264052777 for eigenvalue
#  The estimated number of batches is 1475
#       248/1    1.07639    1.06972 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.53633546764468 for eigenvalue
#  The estimated number of batches is 1487
#       249/1    1.07092    1.06973 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.528820695959566 for eigenvalue
#  The estimated number of batches is 1485
#       250/1    1.06835    1.06972 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5241636062105446 for eigenvalue
#  The estimated number of batches is 1486
#       251/1    1.06083    1.06968 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5381800720777044 for eigenvalue
#  The estimated number of batches is 1509
#       252/1    1.06684    1.06967 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.526214585792581 for eigenvalue
#  The estimated number of batches is 1501
#       253/1    1.06269    1.06964 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.515671073010392 for eigenvalue
#  The estimated number of batches is 1495
#       254/1    1.06854    1.06963 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5065198315249733 for eigenvalue
#  The estimated number of batches is 1491
#       255/1    1.07330    1.06965 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5063206585740523 for eigenvalue
#  The estimated number of batches is 1497
#       256/1    1.05908    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5028337312691913 for eigenvalue
#  The estimated number of batches is 1499
#       257/1    1.06973    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.491480849579506 for eigenvalue
#  The estimated number of batches is 1492
#       258/1    1.06959    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.481401443241508 for eigenvalue
#  The estimated number of batches is 1486
#       259/1    1.06677    1.06959 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4715486807145175 for eigenvalue
#  The estimated number of batches is 1480
#       260/1    1.07286    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4653507503660577 for eigenvalue
#  The estimated number of batches is 1479
#       261/1    1.07014    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4599871640221225 for eigenvalue
#  The estimated number of batches is 1479
#       262/1    1.06845    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4481284191542616 for eigenvalue
#  The estimated number of batches is 1471
#       263/1    1.06684    1.06959 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4373938423280004 for eigenvalue
#  The estimated number of batches is 1464
#       264/1    1.05621    1.06954 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4548733422607194 for eigenvalue
#  The estimated number of batches is 1491
#       265/1    1.06455    1.06952 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.456754746553698 for eigenvalue
#  The estimated number of batches is 1499
#       266/1    1.07244    1.06953 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.447467937439128 for eigenvalue
#  The estimated number of batches is 1494
#       267/1    1.07994    1.06957 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4400237685662267 for eigenvalue
#  The estimated number of batches is 1491
#       268/1    1.08055    1.06962 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.459793713961275 for eigenvalue
#  The estimated number of batches is 1521
#       269/1    1.06143    1.06958 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4491401343719312 for eigenvalue
#  The estimated number of batches is 1514
#       270/1    1.07121    1.06959 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.444037850667265 for eigenvalue
#  The estimated number of batches is 1514
#       271/1    1.06681    1.06958 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.435555290455932 for eigenvalue
#  The estimated number of batches is 1509
#       272/1    1.05776    1.06953 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4322046474399035 for eigenvalue
#  The estimated number of batches is 1511
#       273/1    1.07642    1.06956 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4291480996980783 for eigenvalue
#  The estimated number of batches is 1513
#       274/1    1.06001    1.06952 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4226030565351664 for eigenvalue
#  The estimated number of batches is 1511
#       275/1    1.06675    1.06951 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.413958439793111 for eigenvalue
#  The estimated number of batches is 1506
#       276/1    1.06918    1.06951 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4069364399212625 for eigenvalue
#  The estimated number of batches is 1504
#       277/1    1.07946    1.06955 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4141104029009743 for eigenvalue
#  The estimated number of batches is 1518
#       278/1    1.07727    1.06958 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.410234534647015 for eigenvalue
#  The estimated number of batches is 1519
#       279/1    1.06957    1.06958 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.409771023637475 for eigenvalue
#  The estimated number of batches is 1525
#       280/1    1.07016    1.06958 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4025609265969017 for eigenvalue
#  The estimated number of batches is 1521
#       281/1    1.07752    1.06961 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4003823455046125 for eigenvalue
#  The estimated number of batches is 1524
#       282/1    1.06942    1.06961 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.391520984410078 for eigenvalue
#  The estimated number of batches is 1519
#       283/1    1.07333    1.06962 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.386595947630165 for eigenvalue
#  The estimated number of batches is 1519
#       284/1    1.07122    1.06963 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.377382546280996 for eigenvalue
#  The estimated number of batches is 1513
#       285/1    1.06649    1.06962 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.376721518463497 for eigenvalue
#  The estimated number of batches is 1517
#       286/1    1.07377    1.06963 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3690649414803087 for eigenvalue
#  The estimated number of batches is 1513
#       287/1    1.06798    1.06963 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.359512495186965 for eigenvalue
#  The estimated number of batches is 1507
#       288/1    1.07537    1.06965 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.357840118696033 for eigenvalue
#  The estimated number of batches is 1510
#       289/1    1.07588    1.06967 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3538102234629252 for eigenvalue
#  The estimated number of batches is 1511
#       290/1    1.06558    1.06966 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.345421365746745 for eigenvalue
#  The estimated number of batches is 1506
#       291/1    1.06752    1.06965 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3368495628738857 for eigenvalue
#  The estimated number of batches is 1500
#       292/1    1.06656    1.06964 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3339060266920684 for eigenvalue
#  The estimated number of batches is 1502
#       293/1    1.06493    1.06962 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.332741546844629 for eigenvalue
#  The estimated number of batches is 1506
#       294/1    1.07199    1.06963 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3372932350888354 for eigenvalue
#  The estimated number of batches is 1517
#       295/1    1.06605    1.06962 +/- 0.00032
# ...
#  Triggers unsatisfied, max unc./thresh. is 1.0532407024698491 for eigenvalue
#  The estimated number of batches is 1469
#      1327/1    1.05636    1.06950 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0529246177652238 for eigenvalue
#  The estimated number of batches is 1470
#      1328/1    1.06642    1.06950 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0528143668244272 for eigenvalue
#  The estimated number of batches is 1470
#      1329/1    1.07636    1.06950 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0521548206256757 for eigenvalue
#  The estimated number of batches is 1470
#      1330/1    1.07426    1.06951 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0515081220974858 for eigenvalue
#  The estimated number of batches is 1469
#      1331/1    1.07234    1.06951 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0507585428172557 for eigenvalue
#  The estimated number of batches is 1468
#      1332/1    1.07050    1.06951 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.050134731822803 for eigenvalue
#  The estimated number of batches is 1467
#      1333/1    1.06619    1.06951 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0495954061142438 for eigenvalue
#  The estimated number of batches is 1467
#      1334/1    1.07386    1.06951 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0499559580397688 for eigenvalue
#  The estimated number of batches is 1469
#      1335/1    1.05997    1.06950 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.049418876835215 for eigenvalue
#  The estimated number of batches is 1469
#      1336/1    1.08247    1.06951 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0499640278425875 for eigenvalue
#  The estimated number of batches is 1471
#      1337/1    1.07105    1.06952 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0496834163562392 for eigenvalue
#  The estimated number of batches is 1472
#      1338/1    1.07819    1.06952 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0503905720286222 for eigenvalue
#  The estimated number of batches is 1475
#      1339/1    1.07512    1.06953 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0497486143519879 for eigenvalue
#  The estimated number of batches is 1474
#      1340/1    1.07804    1.06953 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.052285594354207 for eigenvalue
#  The estimated number of batches is 1482
#      1341/1    1.07826    1.06954 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0539615153549104 for eigenvalue
#  The estimated number of batches is 1488
#      1342/1    1.06665    1.06954 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0531638873302132 for eigenvalue
#  The estimated number of batches is 1487
#      1343/1    1.06572    1.06953 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0523623676616602 for eigenvalue
#  The estimated number of batches is 1486
#      1344/1    1.06919    1.06953 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0522401639712131 for eigenvalue
#  The estimated number of batches is 1486
#      1345/1    1.07258    1.06954 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.052352585046528 for eigenvalue
#  The estimated number of batches is 1488
#      1346/1    1.07402    1.06954 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0516112775526347 for eigenvalue
#  The estimated number of batches is 1487
#      1347/1    1.07964    1.06955 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0513960697314781 for eigenvalue
#  The estimated number of batches is 1487
#      1348/1    1.07541    1.06955 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.050641452758492 for eigenvalue
#  The estimated number of batches is 1486
#      1349/1    1.08232    1.06956 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0516738649820154 for eigenvalue
#  The estimated number of batches is 1490
#      1350/1    1.06433    1.06956 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0513637244230207 for eigenvalue
#  The estimated number of batches is 1491
#      1351/1    1.06480    1.06955 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.051789536444041 for eigenvalue
#  The estimated number of batches is 1493
#      1352/1    1.06371    1.06955 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0512699918001835 for eigenvalue
#  The estimated number of batches is 1493
#      1353/1    1.07340    1.06955 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.050499950263531 for eigenvalue
#  The estimated number of batches is 1492
#      1354/1    1.06379    1.06955 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0500501304259713 for eigenvalue
#  The estimated number of batches is 1491
#      1355/1    1.07020    1.06955 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0494695102338294 for eigenvalue
#  The estimated number of batches is 1491
#      1356/1    1.07842    1.06956 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0488216621393736 for eigenvalue
#  The estimated number of batches is 1490
#      1357/1    1.07589    1.06956 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0486800477775278 for eigenvalue
#  The estimated number of batches is 1491
#      1358/1    1.06422    1.06956 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0479294645314539 for eigenvalue
#  The estimated number of batches is 1490
#      1359/1    1.06782    1.06955 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.047589941147597 for eigenvalue
#  The estimated number of batches is 1490
#      1360/1    1.07474    1.06956 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0468219491456892 for eigenvalue
#  The estimated number of batches is 1489
#      1361/1    1.06690    1.06956 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0462158245864608 for eigenvalue
#  The estimated number of batches is 1488
#      1362/1    1.07006    1.06956 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0454236532237395 for eigenvalue
#  The estimated number of batches is 1487
#      1363/1    1.06713    1.06956 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0446814302856215 for eigenvalue
#  The estimated number of batches is 1486
#      1364/1    1.08035    1.06956 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.044408818380622 for eigenvalue
#  The estimated number of batches is 1487
#      1365/1    1.06766    1.06956 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0436251217529968 for eigenvalue
#  The estimated number of batches is 1485
#      1366/1    1.06729    1.06956 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0429048309207882 for eigenvalue
#  The estimated number of batches is 1484
#      1367/1    1.07672    1.06957 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0426661918532059 for eigenvalue
#  The estimated number of batches is 1485
#      1368/1    1.07183    1.06957 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0419370824740997 for eigenvalue
#  The estimated number of batches is 1484
#      1369/1    1.07608    1.06957 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0413929573324066 for eigenvalue
#  The estimated number of batches is 1483
#      1370/1    1.08460    1.06958 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0408266679436928 for eigenvalue
#  The estimated number of batches is 1483
#      1371/1    1.06812    1.06958 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0401538798842613 for eigenvalue
#  The estimated number of batches is 1482
#      1372/1    1.07420    1.06959 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.040513554963664 for eigenvalue
#  The estimated number of batches is 1484
#      1373/1    1.06966    1.06959 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0397751318436963 for eigenvalue
#  The estimated number of batches is 1483
#      1374/1    1.07734    1.06959 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0390294206025101 for eigenvalue
#  The estimated number of batches is 1482
#      1375/1    1.07558    1.06960 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0384115383314727 for eigenvalue
#  The estimated number of batches is 1482
#      1376/1    1.06333    1.06959 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0385998571921944 for eigenvalue
#  The estimated number of batches is 1483
#      1377/1    1.06554    1.06959 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0378080923488653 for eigenvalue
#  The estimated number of batches is 1482
#      1378/1    1.08647    1.06960 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.037621344891176 for eigenvalue
#  The estimated number of batches is 1483
#      1379/1    1.07055    1.06960 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0368924013263459 for eigenvalue
#  The estimated number of batches is 1482
#      1380/1    1.07268    1.06960 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0361230197927356 for eigenvalue
#  The estimated number of batches is 1481
#      1381/1    1.06413    1.06960 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0360403192211536 for eigenvalue
#  The estimated number of batches is 1481
#      1382/1    1.07918    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.036732502665314 for eigenvalue
#  The estimated number of batches is 1484
#      1383/1    1.07230    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0359846316751171 for eigenvalue
#  The estimated number of batches is 1483
#      1384/1    1.06883    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.035421799058055 for eigenvalue
#  The estimated number of batches is 1483
#      1385/1    1.07971    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0353644368581412 for eigenvalue
#  The estimated number of batches is 1484
#      1386/1    1.06085    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.035006250923098 for eigenvalue
#  The estimated number of batches is 1484
#      1387/1    1.07020    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0342654080101528 for eigenvalue
#  The estimated number of batches is 1483
#      1388/1    1.06096    1.06960 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0341265774735267 for eigenvalue
#  The estimated number of batches is 1483
#      1389/1    1.06884    1.06960 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.033376492579356 for eigenvalue
#  The estimated number of batches is 1482
#      1390/1    1.07270    1.06960 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0339557250341846 for eigenvalue
#  The estimated number of batches is 1485
#      1391/1    1.07687    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0333984662683227 for eigenvalue
#  The estimated number of batches is 1485
#      1392/1    1.08174    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.033329748212785 for eigenvalue
#  The estimated number of batches is 1485
#      1393/1    1.06770    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0331252261020016 for eigenvalue
#  The estimated number of batches is 1486
#      1394/1    1.06958    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0323787169478438 for eigenvalue
#  The estimated number of batches is 1485
#      1395/1    1.06982    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.031999731486091 for eigenvalue
#  The estimated number of batches is 1485
#      1396/1    1.07493    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0312648271873412 for eigenvalue
#  The estimated number of batches is 1484
#      1397/1    1.06785    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0305258779307218 for eigenvalue
#  The estimated number of batches is 1483
#      1398/1    1.07061    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.029810066058636 for eigenvalue
#  The estimated number of batches is 1482
#      1399/1    1.06085    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0308739153169126 for eigenvalue
#  The estimated number of batches is 1486
#      1400/1    1.06388    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0303393285947147 for eigenvalue
#  The estimated number of batches is 1486
#      1401/1    1.08726    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0309933334775825 for eigenvalue
#  The estimated number of batches is 1488
#      1402/1    1.06886    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0302836185707442 for eigenvalue
#  The estimated number of batches is 1487
#      1403/1    1.07775    1.06963 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0295625847247158 for eigenvalue
#  The estimated number of batches is 1486
#      1404/1    1.07676    1.06963 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0293124700175351 for eigenvalue
#  The estimated number of batches is 1487
#      1405/1    1.07224    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.02863723082859 for eigenvalue
#  The estimated number of batches is 1486
#      1406/1    1.06932    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.027959935261291 for eigenvalue
#  The estimated number of batches is 1485
#      1407/1    1.06207    1.06963 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0276372202168405 for eigenvalue
#  The estimated number of batches is 1485
#      1408/1    1.07704    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.029266684613502 for eigenvalue
#  The estimated number of batches is 1491
#      1409/1    1.07353    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.028534338330428 for eigenvalue
#  The estimated number of batches is 1490
#      1410/1    1.07483    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0278810407527394 for eigenvalue
#  The estimated number of batches is 1489
#      1411/1    1.06891    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.027166897704846 for eigenvalue
#  The estimated number of batches is 1488
#      1412/1    1.07715    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0270998119687422 for eigenvalue
#  The estimated number of batches is 1489
#      1413/1    1.07344    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.026722427085722 for eigenvalue
#  The estimated number of batches is 1489
#      1414/1    1.05910    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0274622671974385 for eigenvalue
#  The estimated number of batches is 1492
#      1415/1    1.07266    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0275955397741305 for eigenvalue
#  The estimated number of batches is 1494
#      1416/1    1.06515    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0275455544729515 for eigenvalue
#  The estimated number of batches is 1494
#      1417/1    1.07192    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0269033284359095 for eigenvalue
#  The estimated number of batches is 1494
#      1418/1    1.06790    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0261832843349807 for eigenvalue
#  The estimated number of batches is 1493
#      1419/1    1.07004    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0254824086853622 for eigenvalue
#  The estimated number of batches is 1492
#      1420/1    1.06836    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0248342817882092 for eigenvalue
#  The estimated number of batches is 1491
#      1421/1    1.06977    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0242785767758504 for eigenvalue
#  The estimated number of batches is 1490
#      1422/1    1.08746    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0258380058892687 for eigenvalue
#  The estimated number of batches is 1496
#      1423/1    1.06414    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.026454135902666 for eigenvalue
#  The estimated number of batches is 1499
