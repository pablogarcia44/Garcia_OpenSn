# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create Pyrex Tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
GT=[(8,2),(3,3),(5,5),(2,8)]
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))

PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %% [markdown]
# ### Create family pincell

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT :
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family
        else:
            A[ix][iy]=pincell_1_family[0]    

#print(A)           
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
print(model.geometry.get_all_material_cells().values())
# Out:
# dict_values([Cell
# 	ID             =	1
# 	Name           =	fuel_pincell_1_family
# 	Fill           =	Material 1
# 	Region         =	-1
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	3
# 	Name           =	clad_pincell_1_family
# 	Fill           =	Material 2
# 	Region         =	(2 -3)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	4
# 	Name           =	moderator_pincell_1_family
# 	Fill           =	Material 3
# 	Region         =	(4 -5 6 -7 3)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	2
# 	Name           =	gap_pincell_1_family
# 	Fill           =	Material 4
# 	Region         =	(1 -2)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	11
# 	Name           =	water_inner_pyrex_1_family
# 	Fill           =	Material 3
# 	Region         =	-22
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	12
# 	Name           =	inner_steel_pyrex_1_family
# 	Fill           =	Material 6
# 	Region         =	(22 -23)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	14
# 	Name           =	pyrex_pyrex_1_family
# 	Fill           =	Material 5
# 	Region         =	(24 -25)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	16
# 	Name           =	outer_steel_pyrex_1_family
# 	Fill           =	Material 6
# 	Region         =	(26 -27)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	17
# 	Name           =	guide_water_pyrex_1_family
# 	Fill           =	Material 3
# 	Region         =	(27 -20)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	18
# 	Name           =	guide_pyrex_1_family
# 	Fill           =	Material 2
# 	Region         =	(20 -21)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	19
# 	Name           =	water_ext_pyrex_1_family
# 	Fill           =	Material 3
# 	Region         =	(28 -29 30 -31 21)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	5
# 	Name           =	water_guide_1_family
# 	Fill           =	Material 3
# 	Region         =	-8
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	6
# 	Name           =	clad_guide_1_family
# 	Fill           =	Material 2
# 	Region         =	(8 -9)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	7
# 	Name           =	moderator_guide_1_family
# 	Fill           =	Material 3
# 	Region         =	(10 -11 12 -13 9)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	8
# 	Name           =	water_guide_instru_1_family
# 	Fill           =	Material 3
# 	Region         =	-14
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	9
# 	Name           =	clad_guide_instru_1_family
# 	Fill           =	Material 2
# 	Region         =	(14 -15)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	10
# 	Name           =	moderator_instru_1_family
# 	Fill           =	Material 3
# 	Region         =	(16 -17 18 -19 15)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	20
# 	Name           =	water_outside
# 	Fill           =	Material 3
# 	Region         =	None
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ])

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:28
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.05670
#         2/1    1.06651
#         3/1    1.06979
#         4/1    1.06567
#         5/1    1.06414
#         6/1    1.07242
#         7/1    1.06038
#         8/1    1.06695
#         9/1    1.07673
#        10/1    1.06903
#        11/1    1.07073
#        12/1    1.07247
#        13/1    1.07421
#        14/1    1.05830
#        15/1    1.07730
#        16/1    1.06795
#        17/1    1.06502
#        18/1    1.06967
#        19/1    1.06208
#        20/1    1.05569
#        21/1    1.06640
#        22/1    1.06743    1.06692 +/- 0.00052
#        23/1    1.06845    1.06743 +/- 0.00059
#        24/1    1.07075    1.06826 +/- 0.00093
#        25/1    1.06442    1.06749 +/- 0.00105
#        26/1    1.05269    1.06502 +/- 0.00261
#        27/1    1.06448    1.06495 +/- 0.00221
#        28/1    1.06204    1.06458 +/- 0.00195
#        29/1    1.06320    1.06443 +/- 0.00172
#        30/1    1.06055    1.06404 +/- 0.00159
#        31/1    1.06385    1.06403 +/- 0.00144
#        32/1    1.08220    1.06554 +/- 0.00200
#        33/1    1.06708    1.06566 +/- 0.00185
#        34/1    1.06482    1.06560 +/- 0.00171
#        35/1    1.07041    1.06592 +/- 0.00163
#        36/1    1.06913    1.06612 +/- 0.00153
#        37/1    1.06487    1.06605 +/- 0.00144
#        38/1    1.06856    1.06619 +/- 0.00137
#        39/1    1.06961    1.06637 +/- 0.00131
#        40/1    1.06315    1.06621 +/- 0.00125
#        41/1    1.06914    1.06635 +/- 0.00120
#        42/1    1.06904    1.06647 +/- 0.00115
#        43/1    1.06555    1.06643 +/- 0.00110
#        44/1    1.06932    1.06655 +/- 0.00106
#        45/1    1.06081    1.06632 +/- 0.00104
#        46/1    1.06361    1.06622 +/- 0.00100
#        47/1    1.06795    1.06628 +/- 0.00097
#        48/1    1.06126    1.06610 +/- 0.00095
#        49/1    1.06190    1.06596 +/- 0.00093
#        50/1    1.06468    1.06591 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 7.2652112946457965 for eigenvalue
#  The estimated number of batches is 1604
#  Creating state point statepoint.00050.h5...
#        51/1    1.07343    1.06616 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 6.920433359634314 for eigenvalue
#  The estimated number of batches is 1505
#        52/1    1.07332    1.06638 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 6.766445787046527 for eigenvalue
#  The estimated number of batches is 1486
#        53/1    1.06982    1.06648 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 6.596857571189153 for eigenvalue
#  The estimated number of batches is 1457
#        54/1    1.06844    1.06654 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.460530774385344 for eigenvalue
#  The estimated number of batches is 1440
#        55/1    1.06021    1.06636 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.775821063803692 for eigenvalue
#  The estimated number of batches is 1627
#        56/1    1.05751    1.06612 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.636541036947169 for eigenvalue
#  The estimated number of batches is 1606
#        57/1    1.06316    1.06604 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 6.523750059609717 for eigenvalue
#  The estimated number of batches is 1595
#        58/1    1.06650    1.06605 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 6.32347938805898 for eigenvalue
#  The estimated number of batches is 1540
#        59/1    1.06964    1.06614 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.177839439978692 for eigenvalue
#  The estimated number of batches is 1509
#        60/1    1.06739    1.06617 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 6.230114942713252 for eigenvalue
#  The estimated number of batches is 1573
#        61/1    1.06952    1.06625 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 6.028349605478902 for eigenvalue
#  The estimated number of batches is 1510
#        62/1    1.07314    1.06642 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.863258656240156 for eigenvalue
#  The estimated number of batches is 1464
#        63/1    1.06236    1.06632 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.723694805264203 for eigenvalue
#  The estimated number of batches is 1429
#        64/1    1.05864    1.06615 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.941428677381396 for eigenvalue
#  The estimated number of batches is 1574
#        65/1    1.07040    1.06624 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.903063011407185 for eigenvalue
#  The estimated number of batches is 1589
#        66/1    1.07492    1.06643 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 6.033698145942356 for eigenvalue
#  The estimated number of batches is 1695
#        67/1    1.06422    1.06638 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.9761528176938725 for eigenvalue
#  The estimated number of batches is 1699
#        68/1    1.06975    1.06645 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.811777963361118 for eigenvalue
#  The estimated number of batches is 1642
#        69/1    1.06663    1.06646 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.7105829212134545 for eigenvalue
#  The estimated number of batches is 1618
#        70/1    1.07828    1.06669 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.647267086662371 for eigenvalue
#  The estimated number of batches is 1615
#        71/1    1.06803    1.06672 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.5141110055309355 for eigenvalue
#  The estimated number of batches is 1571
#        72/1    1.06369    1.06666 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.427701308828611 for eigenvalue
#  The estimated number of batches is 1552
#        73/1    1.07900    1.06689 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.516459743951029 for eigenvalue
#  The estimated number of batches is 1633
#        74/1    1.05820    1.06673 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.472050752677297 for eigenvalue
#  The estimated number of batches is 1637
#        75/1    1.05985    1.06661 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.378267531300604 for eigenvalue
#  The estimated number of batches is 1611
#        76/1    1.06779    1.06663 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.288596813876234 for eigenvalue
#  The estimated number of batches is 1587
#        77/1    1.06224    1.06655 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.203171439049271 for eigenvalue
#  The estimated number of batches is 1564
#        78/1    1.06093    1.06646 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.111063612973619 for eigenvalue
#  The estimated number of batches is 1536
#        79/1    1.06756    1.06647 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.019277101505421 for eigenvalue
#  The estimated number of batches is 1507
#        80/1    1.07383    1.06660 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.9354541676015184 for eigenvalue
#  The estimated number of batches is 1482
#        81/1    1.07245    1.06669 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.849302740624367 for eigenvalue
#  The estimated number of batches is 1455
#        82/1    1.06164    1.06661 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.817819063873744 for eigenvalue
#  The estimated number of batches is 1460
#        83/1    1.06448    1.06658 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.7368023989108865 for eigenvalue
#  The estimated number of batches is 1434
#        84/1    1.07497    1.06671 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.679935416526358 for eigenvalue
#  The estimated number of batches is 1422
#        85/1    1.07297    1.06680 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.611590992993709 for eigenvalue
#  The estimated number of batches is 1403
#        86/1    1.06849    1.06683 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.554129731987384 for eigenvalue
#  The estimated number of batches is 1389
#        87/1    1.07323    1.06693 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.475523285164838 for eigenvalue
#  The estimated number of batches is 1363
#        88/1    1.05735    1.06679 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.413577815941302 for eigenvalue
#  The estimated number of batches is 1345
#        89/1    1.06774    1.06680 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.351484069289952 for eigenvalue
#  The estimated number of batches is 1327
#        90/1    1.07089    1.06686 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.27098618013619 for eigenvalue
#  The estimated number of batches is 1297
#        91/1    1.07184    1.06693 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.242065686432797 for eigenvalue
#  The estimated number of batches is 1298
#        92/1    1.07506    1.06704 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.282474225654802 for eigenvalue
#  The estimated number of batches is 1341
#        93/1    1.06381    1.06700 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.221158161257962 for eigenvalue
#  The estimated number of batches is 1321
#        94/1    1.05373    1.06682 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.183991558918894 for eigenvalue
#  The estimated number of batches is 1316
#        95/1    1.06649    1.06681 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.129698888603256 for eigenvalue
#  The estimated number of batches is 1300
#        96/1    1.05944    1.06672 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.106099915317755 for eigenvalue
#  The estimated number of batches is 1302
#        97/1    1.07106    1.06677 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.075884898353583 for eigenvalue
#  The estimated number of batches is 1300
#        98/1    1.06297    1.06672 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.054499955815669 for eigenvalue
#  The estimated number of batches is 1303
#        99/1    1.07083    1.06678 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.03619770934061 for eigenvalue
#  The estimated number of batches is 1307
#       100/1    1.05918    1.06668 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.02470666302024 for eigenvalue
#  The estimated number of batches is 1316
#       101/1    1.07151    1.06674 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.9882219435127313 for eigenvalue
#  The estimated number of batches is 1309
#       102/1    1.07079    1.06679 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.967742186117884 for eigenvalue
#  The estimated number of batches is 1311
#       103/1    1.06934    1.06682 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.936267488408177 for eigenvalue
#  The estimated number of batches is 1307
#       104/1    1.06127    1.06675 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.899961410495317 for eigenvalue
#  The estimated number of batches is 1298
#       105/1    1.06666    1.06675 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.8554271387793566 for eigenvalue
#  The estimated number of batches is 1284
#       106/1    1.07411    1.06684 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.836435923212443 for eigenvalue
#  The estimated number of batches is 1286
#       107/1    1.06641    1.06683 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.899442034189493 for eigenvalue
#  The estimated number of batches is 1343
#       108/1    1.07732    1.06695 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.8967032802034836 for eigenvalue
#  The estimated number of batches is 1357
#       109/1    1.06691    1.06695 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.849534110252447 for eigenvalue
#  The estimated number of batches is 1339
#       110/1    1.06586    1.06694 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.8389333022927588 for eigenvalue
#  The estimated number of batches is 1347
#       111/1    1.07240    1.06700 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7946021639283676 for eigenvalue
#  The estimated number of batches is 1331
#       112/1    1.06813    1.06701 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7681502494829986 for eigenvalue
#  The estimated number of batches is 1327
#       113/1    1.07056    1.06705 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.730310434692289 for eigenvalue
#  The estimated number of batches is 1315
#       114/1    1.06732    1.06705 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6908376924784294 for eigenvalue
#  The estimated number of batches is 1301
#       115/1    1.05532    1.06693 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.673121625993359 for eigenvalue
#  The estimated number of batches is 1302
#       116/1    1.06534    1.06691 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6373287953646734 for eigenvalue
#  The estimated number of batches is 1291
#       117/1    1.06733    1.06692 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6153253697350456 for eigenvalue
#  The estimated number of batches is 1288
#       118/1    1.06900    1.06694 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.628335453683197 for eigenvalue
#  The estimated number of batches is 1311
#       119/1    1.06102    1.06688 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.6170851023347304 for eigenvalue
#  The estimated number of batches is 1316
#       120/1    1.06484    1.06686 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.593242425085104 for eigenvalue
#  The estimated number of batches is 1312
#       121/1    1.06318    1.06682 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5686802664744186 for eigenvalue
#  The estimated number of batches is 1307
#       122/1    1.05945    1.06675 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.557019400597222 for eigenvalue
#  The estimated number of batches is 1311
#       123/1    1.06882    1.06677 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5265013260804694 for eigenvalue
#  The estimated number of batches is 1301
#       124/1    1.06936    1.06680 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.499716803700454 for eigenvalue
#  The estimated number of batches is 1294
#       125/1    1.06473    1.06678 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4731389420692795 for eigenvalue
#  The estimated number of batches is 1287
#       126/1    1.06918    1.06680 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.445254969124099 for eigenvalue
#  The estimated number of batches is 1279
#       127/1    1.07150    1.06684 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4079916280440203 for eigenvalue
#  The estimated number of batches is 1263
#       128/1    1.06683    1.06684 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.376877834313068 for eigenvalue
#  The estimated number of batches is 1252
#       129/1    1.06988    1.06687 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3446213400585165 for eigenvalue
#  The estimated number of batches is 1240
#       130/1    1.06600    1.06686 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3140020886005677 for eigenvalue
#  The estimated number of batches is 1229
#       131/1    1.07300    1.06692 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.3116142637848913 for eigenvalue
#  The estimated number of batches is 1238
#       132/1    1.06284    1.06688 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.3135185667979936 for eigenvalue
#  The estimated number of batches is 1250
#       133/1    1.07291    1.06693 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.3209081684390944 for eigenvalue
#  The estimated number of batches is 1267
#       134/1    1.06622    1.06693 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.310870122253398 for eigenvalue
#  The estimated number of batches is 1270
#       135/1    1.07068    1.06696 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2934839225101906 for eigenvalue
#  The estimated number of batches is 1268
#       136/1    1.06295    1.06693 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2664937857645318 for eigenvalue
#  The estimated number of batches is 1258
#       137/1    1.05938    1.06686 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2396110518895638 for eigenvalue
#  The estimated number of batches is 1248
#       138/1    1.07824    1.06696 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.264559205084442 for eigenvalue
#  The estimated number of batches is 1278
#       139/1    1.06849    1.06697 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2373205950306683 for eigenvalue
#  The estimated number of batches is 1268
#       140/1    1.07276    1.06702 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2121219455993018 for eigenvalue
#  The estimated number of batches is 1259
#       141/1    1.07120    1.06705 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2125435163923224 for eigenvalue
#  The estimated number of batches is 1269
#       142/1    1.07067    1.06708 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.186120042082974 for eigenvalue
#  The estimated number of batches is 1259
#       143/1    1.08056    1.06719 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2222550057215686 for eigenvalue
#  The estimated number of batches is 1298
#       144/1    1.06435    1.06717 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2015540742546795 for eigenvalue
#  The estimated number of batches is 1291
#       145/1    1.07608    1.06724 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.178748278906133 for eigenvalue
#  The estimated number of batches is 1284
#       146/1    1.06485    1.06722 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1561431694632516 for eigenvalue
#  The estimated number of batches is 1276
#       147/1    1.06931    1.06724 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1515630374532457 for eigenvalue
#  The estimated number of batches is 1282
#       148/1    1.06115    1.06719 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1237055395166395 for eigenvalue
#  The estimated number of batches is 1269
#       149/1    1.07238    1.06723 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.102128482066809 for eigenvalue
#  The estimated number of batches is 1262
#       150/1    1.05467    1.06713 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.090522847833846 for eigenvalue
#  The estimated number of batches is 1262
#       151/1    1.05580    1.06705 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0721677360798973 for eigenvalue
#  The estimated number of batches is 1257
#       152/1    1.07002    1.06707 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.046893463537879 for eigenvalue
#  The estimated number of batches is 1246
#       153/1    1.07662    1.06714 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0676121825968683 for eigenvalue
#  The estimated number of batches is 1272
#       154/1    1.07146    1.06717 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0826069829052303 for eigenvalue
#  The estimated number of batches is 1294
#       155/1    1.07519    1.06723 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0835286229554146 for eigenvalue
#  The estimated number of batches is 1304
#       156/1    1.06716    1.06723 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.061952335037045 for eigenvalue
#  The estimated number of batches is 1296
#       157/1    1.06498    1.06722 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.040454570762944 for eigenvalue
#  The estimated number of batches is 1287
#       158/1    1.06330    1.06719 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.028670766918934 for eigenvalue
#  The estimated number of batches is 1286
#       159/1    1.06822    1.06720 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0210330897818616 for eigenvalue
#  The estimated number of batches is 1289
#       160/1    1.06605    1.06719 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.010765207504867 for eigenvalue
#  The estimated number of batches is 1290
#       161/1    1.06021    1.06714 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.991010315496422 for eigenvalue
#  The estimated number of batches is 1282
#       162/1    1.07455    1.06719 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9738388166437892 for eigenvalue
#  The estimated number of batches is 1276
#       163/1    1.06992    1.06721 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9540838241331424 for eigenvalue
#  The estimated number of batches is 1268
#       164/1    1.06314    1.06718 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9427641338192627 for eigenvalue
#  The estimated number of batches is 1268
#       165/1    1.06133    1.06714 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.9262850043189057 for eigenvalue
#  The estimated number of batches is 1262
#       166/1    1.06293    1.06711 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.912744227080721 for eigenvalue
#  The estimated number of batches is 1259
#       167/1    1.06763    1.06712 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8935765927334414 for eigenvalue
#  The estimated number of batches is 1251
#       168/1    1.06143    1.06708 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.879295849900623 for eigenvalue
#  The estimated number of batches is 1247
#       169/1    1.06219    1.06704 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8610165130723435 for eigenvalue
#  The estimated number of batches is 1240
#       170/1    1.06599    1.06704 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8469972283139873 for eigenvalue
#  The estimated number of batches is 1236
#       171/1    1.07429    1.06709 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.826448745184312 for eigenvalue
#  The estimated number of batches is 1227
#       172/1    1.07460    1.06713 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.842298166622046 for eigenvalue
#  The estimated number of batches is 1248
#       173/1    1.07037    1.06716 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8278486362959914 for eigenvalue
#  The estimated number of batches is 1244
#       174/1    1.08058    1.06724 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8803563990129755 for eigenvalue
#  The estimated number of batches is 1298
#       175/1    1.06258    1.06721 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.866062488508927 for eigenvalue
#  The estimated number of batches is 1294
#       176/1    1.06650    1.06721 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8514816811418133 for eigenvalue
#  The estimated number of batches is 1289
#       177/1    1.06693    1.06721 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8334688524641716 for eigenvalue
#  The estimated number of batches is 1281
#       178/1    1.06691    1.06720 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8475347634519 for eigenvalue
#  The estimated number of batches is 1302
#       179/1    1.05666    1.06714 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.868978320717825 for eigenvalue
#  The estimated number of batches is 1329
#       180/1    1.05929    1.06709 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8947686609488583 for eigenvalue
#  The estimated number of batches is 1361
#       181/1    1.06348    1.06707 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.879736981181748 for eigenvalue
#  The estimated number of batches is 1356
#       182/1    1.06892    1.06708 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.861757162520993 for eigenvalue
#  The estimated number of batches is 1347
#       183/1    1.07216    1.06711 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.843169970529444 for eigenvalue
#  The estimated number of batches is 1338
#       184/1    1.05930    1.06706 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.82932024682429 for eigenvalue
#  The estimated number of batches is 1333
#       185/1    1.07299    1.06710 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.8126013147402253 for eigenvalue
#  The estimated number of batches is 1326
#       186/1    1.06996    1.06712 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7988891237375157 for eigenvalue
#  The estimated number of batches is 1321
#       187/1    1.06303    1.06709 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7836906802648427 for eigenvalue
#  The estimated number of batches is 1315
#       188/1    1.07663    1.06715 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7793850238431634 for eigenvalue
#  The estimated number of batches is 1318
#       189/1    1.07393    1.06719 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.770955964850567 for eigenvalue
#  The estimated number of batches is 1318
#       190/1    1.06368    1.06717 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.761745253845043 for eigenvalue
#  The estimated number of batches is 1317
#       191/1    1.06473    1.06715 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7710731283179553 for eigenvalue
#  The estimated number of batches is 1334
#       192/1    1.06627    1.06715 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7537274542011687 for eigenvalue
#  The estimated number of batches is 1325
#       193/1    1.07293    1.06718 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.746279969715314 for eigenvalue
#  The estimated number of batches is 1325
#       194/1    1.06337    1.06716 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.734237225597235 for eigenvalue
#  The estimated number of batches is 1321
#       195/1    1.06048    1.06712 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.744200954803417 for eigenvalue
#  The estimated number of batches is 1338
#       196/1    1.07006    1.06714 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7369549894605103 for eigenvalue
#  The estimated number of batches is 1339
#       197/1    1.07128    1.06716 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.720272056754548 for eigenvalue
#  The estimated number of batches is 1330
#       198/1    1.06132    1.06713 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7281941804798677 for eigenvalue
#  The estimated number of batches is 1345
#       199/1    1.07467    1.06717 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.7320252075125193 for eigenvalue
#  The estimated number of batches is 1357
#       200/1    1.07448    1.06721 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.734429852846126 for eigenvalue
#  The estimated number of batches is 1366
#       201/1    1.07077    1.06723 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7195134517551356 for eigenvalue
#  The estimated number of batches is 1359
#       202/1    1.05943    1.06719 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.70944997352874 for eigenvalue
#  The estimated number of batches is 1357
#       203/1    1.07102    1.06721 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6981465460825875 for eigenvalue
#  The estimated number of batches is 1353
#       204/1    1.05833    1.06716 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.702740963354887 for eigenvalue
#  The estimated number of batches is 1365
#       205/1    1.06819    1.06717 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6887598649761557 for eigenvalue
#  The estimated number of batches is 1358
#       206/1    1.06717    1.06717 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6744682172567074 for eigenvalue
#  The estimated number of batches is 1351
#       207/1    1.07362    1.06720 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.663210622666025 for eigenvalue
#  The estimated number of batches is 1347
#       208/1    1.07315    1.06723 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6557901673920896 for eigenvalue
#  The estimated number of batches is 1347
#       209/1    1.07320    1.06726 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6438241225927057 for eigenvalue
#  The estimated number of batches is 1342
#       210/1    1.07214    1.06729 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6335953074334366 for eigenvalue
#  The estimated number of batches is 1338
#       211/1    1.08089    1.06736 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.627238158452764 for eigenvalue
#  The estimated number of batches is 1339
#       212/1    1.06782    1.06736 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.622675244817714 for eigenvalue
#  The estimated number of batches is 1341
#       213/1    1.06676    1.06736 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.615808132808994 for eigenvalue
#  The estimated number of batches is 1341
#       214/1    1.06395    1.06734 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.601500853617945 for eigenvalue
#  The estimated number of batches is 1333
#       215/1    1.06494    1.06733 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.593973402326218 for eigenvalue
#  The estimated number of batches is 1333
#       216/1    1.05759    1.06728 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.599465839904208 for eigenvalue
#  The estimated number of batches is 1345
#       217/1    1.07312    1.06731 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6022683154786703 for eigenvalue
#  The estimated number of batches is 1355
#       218/1    1.06720    1.06731 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.586216336409286 for eigenvalue
#  The estimated number of batches is 1345
#       219/1    1.06187    1.06728 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5834974372005717 for eigenvalue
#  The estimated number of batches is 1349
#       220/1    1.05528    1.06722 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.583631252249967 for eigenvalue
#  The estimated number of batches is 1356
#       221/1    1.07389    1.06726 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5777004922007833 for eigenvalue
#  The estimated number of batches is 1356
#       222/1    1.06781    1.06726 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5666895491802997 for eigenvalue
#  The estimated number of batches is 1351
#       223/1    1.06758    1.06726 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5551791241274957 for eigenvalue
#  The estimated number of batches is 1346
#       224/1    1.05963    1.06722 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5448379842277458 for eigenvalue
#  The estimated number of batches is 1342
#       225/1    1.07159    1.06724 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5474968797304656 for eigenvalue
#  The estimated number of batches is 1351
#       226/1    1.06696    1.06724 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.537118060461654 for eigenvalue
#  The estimated number of batches is 1347
#       227/1    1.07923    1.06730 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5332196353822725 for eigenvalue
#  The estimated number of batches is 1349
#       228/1    1.07467    1.06734 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5306148188656232 for eigenvalue
#  The estimated number of batches is 1353
#       229/1    1.06146    1.06731 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5186073194721335 for eigenvalue
#  The estimated number of batches is 1346
#       230/1    1.06762    1.06731 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5111015667395313 for eigenvalue
#  The estimated number of batches is 1345
#       231/1    1.06009    1.06727 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.50243483596415 for eigenvalue
#  The estimated number of batches is 1342
#       232/1    1.07547    1.06731 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5110497918268417 for eigenvalue
#  The estimated number of batches is 1357
#       233/1    1.05789    1.06727 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5161255738624995 for eigenvalue
#  The estimated number of batches is 1369
#       234/1    1.06608    1.06726 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.508120333027008 for eigenvalue
#  The estimated number of batches is 1367
#       235/1    1.06453    1.06725 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.49705983651235 for eigenvalue
#  The estimated number of batches is 1361
#       236/1    1.06015    1.06722 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5163034450728925 for eigenvalue
#  The estimated number of batches is 1388
#       237/1    1.06336    1.06720 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5086696506244897 for eigenvalue
#  The estimated number of batches is 1386
#       238/1    1.06152    1.06717 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.5077493916402225 for eigenvalue
#  The estimated number of batches is 1391
#       239/1    1.07265    1.06720 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.498709766275801 for eigenvalue
#  The estimated number of batches is 1388
#       240/1    1.05620    1.06715 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.501031794013943 for eigenvalue
#  The estimated number of batches is 1397
#       241/1    1.06447    1.06714 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4935378627816793 for eigenvalue
#  The estimated number of batches is 1395
#       242/1    1.06884    1.06714 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4827624442193983 for eigenvalue
#  The estimated number of batches is 1389
#       243/1    1.05824    1.06710 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4912008863101813 for eigenvalue
#  The estimated number of batches is 1404
#       244/1    1.07006    1.06712 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.480802275146792 for eigenvalue
#  The estimated number of batches is 1399
#       245/1    1.06151    1.06709 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4728454945241656 for eigenvalue
#  The estimated number of batches is 1396
#       246/1    1.06827    1.06710 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4625170909185985 for eigenvalue
#  The estimated number of batches is 1391
#       247/1    1.07483    1.06713 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4530634589071227 for eigenvalue
#  The estimated number of batches is 1386
#       248/1    1.06197    1.06711 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4433142428097665 for eigenvalue
#  The estimated number of batches is 1382
#       249/1    1.05742    1.06707 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4391400059041835 for eigenvalue
#  The estimated number of batches is 1383
#       250/1    1.06751    1.06707 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.433561417077154 for eigenvalue
#  The estimated number of batches is 1383
#       251/1    1.06788    1.06707 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4284786054383596 for eigenvalue
#  The estimated number of batches is 1383
#       252/1    1.05803    1.06703 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4402576626516717 for eigenvalue
#  The estimated number of batches is 1402
#       253/1    1.06387    1.06702 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.445153883303356 for eigenvalue
#  The estimated number of batches is 1414
#       254/1    1.06772    1.06702 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4362582221499194 for eigenvalue
#  The estimated number of batches is 1409
#       255/1    1.06782    1.06703 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4304769906337476 for eigenvalue
#  The estimated number of batches is 1409
#       256/1    1.05962    1.06700 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4266590321470387 for eigenvalue
#  The estimated number of batches is 1410
#       257/1    1.05598    1.06695 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.417689002879375 for eigenvalue
#  The estimated number of batches is 1406
#       258/1    1.06769    1.06695 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.40749128718144 for eigenvalue
#  The estimated number of batches is 1400
#       259/1    1.05112    1.06689 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.429503508821864 for eigenvalue
#  The estimated number of batches is 1431
#       260/1    1.05611    1.06684 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.421107137996513 for eigenvalue
#  The estimated number of batches is 1427
#       261/1    1.05799    1.06680 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.430772622758476 for eigenvalue
#  The estimated number of batches is 1444
#       262/1    1.06967    1.06682 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.4200017714907096 for eigenvalue
#  The estimated number of batches is 1438
#       263/1    1.06182    1.06680 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4146013026235256 for eigenvalue
#  The estimated number of batches is 1437
#       264/1    1.06269    1.06678 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.4046023951583453 for eigenvalue
#  The estimated number of batches is 1431
#       265/1    1.06534    1.06677 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3961209648458786 for eigenvalue
#  The estimated number of batches is 1427
#       266/1    1.07192    1.06679 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3969011941651694 for eigenvalue
#  The estimated number of batches is 1434
#       267/1    1.05314    1.06674 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3896887321303426 for eigenvalue
#  The estimated number of batches is 1431
#       268/1    1.07245    1.06676 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.380092847610799 for eigenvalue
#  The estimated number of batches is 1425
#       269/1    1.06536    1.06676 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3712796590680765 for eigenvalue
#  The estimated number of batches is 1421
#       270/1    1.05853    1.06672 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3786408324011417 for eigenvalue
#  The estimated number of batches is 1435
#       271/1    1.06470    1.06671 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.370833758484534 for eigenvalue
#  The estimated number of batches is 1431
#       272/1    1.07108    1.06673 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.360567128782694 for eigenvalue
#  The estimated number of batches is 1425
#       273/1    1.06189    1.06671 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.355626678513978 for eigenvalue
#  The estimated number of batches is 1424
#       274/1    1.07362    1.06674 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3479090592456613 for eigenvalue
#  The estimated number of batches is 1421
#       275/1    1.07475    1.06677 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.344208360956635 for eigenvalue
#  The estimated number of batches is 1422
#       276/1    1.07911    1.06682 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3716428911875767 for eigenvalue
#  The estimated number of batches is 1460
#       277/1    1.08094    1.06687 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3792828221918145 for eigenvalue
#  The estimated number of batches is 1475
#       278/1    1.06035    1.06685 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3709843777854864 for eigenvalue
#  The estimated number of batches is 1471
#       279/1    1.06893    1.06686 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.367817535699045 for eigenvalue
#  The estimated number of batches is 1473
#       280/1    1.07056    1.06687 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.35828192936498 for eigenvalue
#  The estimated number of batches is 1466
#       281/1    1.06434    1.06686 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.350252622278128 for eigenvalue
#  The estimated number of batches is 1462
#       282/1    1.05984    1.06684 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.3455644561140416 for eigenvalue
#  The estimated number of batches is 1462
#       283/1    1.07014    1.06685 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.351164841365185 for eigenvalue
#  The estimated number of batches is 1474
#       284/1    1.06490    1.06684 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3430965468343947 for eigenvalue
#  The estimated number of batches is 1470
#       285/1    1.06389    1.06683 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3353446025659044 for eigenvalue
#  The estimated number of batches is 1466
#       286/1    1.07068    1.06684 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3275582756276165 for eigenvalue
#  The estimated number of batches is 1462
#       287/1    1.06842    1.06685 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.321482845430501 for eigenvalue
#  The estimated number of batches is 1459
#       288/1    1.06692    1.06685 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3131987923871327 for eigenvalue
#  The estimated number of batches is 1455
#       289/1    1.06367    1.06684 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.3061000585924165 for eigenvalue
#  The estimated number of batches is 1451
#       290/1    1.07084    1.06685 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.297768702107462 for eigenvalue
#  The estimated number of batches is 1446
#       291/1    1.07563    1.06689 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.290698871059045 for eigenvalue
#  The estimated number of batches is 1443
#       292/1    1.07202    1.06690 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.282068169931998 for eigenvalue
#  The estimated number of batches is 1437
#       293/1    1.06812    1.06691 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.27890289866448 for eigenvalue
#  The estimated number of batches is 1438
#       294/1    1.06058    1.06689 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.273556955646723 for eigenvalue
#  The estimated number of batches is 1437
#       295/1    1.06431    1.06688 +/- 0.00035
# ...
#  The estimated number of batches is 1405
#       609/1    1.06866    1.06698 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5326291184616858 for eigenvalue
#  The estimated number of batches is 1404
#       610/1    1.07543    1.06699 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5332552088354603 for eigenvalue
#  The estimated number of batches is 1408
#       611/1    1.06064    1.06698 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5318459904187027 for eigenvalue
#  The estimated number of batches is 1407
#       612/1    1.06582    1.06698 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.53048546039735 for eigenvalue
#  The estimated number of batches is 1407
#       613/1    1.06578    1.06698 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5291679669465006 for eigenvalue
#  The estimated number of batches is 1407
#       614/1    1.06684    1.06698 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5277399795089843 for eigenvalue
#  The estimated number of batches is 1407
#       615/1    1.06811    1.06698 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5257149355706785 for eigenvalue
#  The estimated number of batches is 1406
#       616/1    1.07787    1.06700 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5237986911741745 for eigenvalue
#  The estimated number of batches is 1404
#       617/1    1.06892    1.06700 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5239204020995356 for eigenvalue
#  The estimated number of batches is 1407
#       618/1    1.07501    1.06701 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5215292541309084 for eigenvalue
#  The estimated number of batches is 1405
#       619/1    1.06733    1.06701 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5189923214264975 for eigenvalue
#  The estimated number of batches is 1403
#       620/1    1.07101    1.06702 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5166189639442609 for eigenvalue
#  The estimated number of batches is 1401
#       621/1    1.07161    1.06703 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5164003752739514 for eigenvalue
#  The estimated number of batches is 1402
#       622/1    1.06362    1.06702 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5140209111064102 for eigenvalue
#  The estimated number of batches is 1400
#       623/1    1.07185    1.06703 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5128004382074887 for eigenvalue
#  The estimated number of batches is 1401
#       624/1    1.06736    1.06703 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5104303479047956 for eigenvalue
#  The estimated number of batches is 1398
#       625/1    1.06697    1.06703 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5096167551837245 for eigenvalue
#  The estimated number of batches is 1399
#       626/1    1.06792    1.06703 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5073100887069866 for eigenvalue
#  The estimated number of batches is 1397
#       627/1    1.06908    1.06704 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5048151034085553 for eigenvalue
#  The estimated number of batches is 1395
#       628/1    1.05996    1.06702 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5027573720880971 for eigenvalue
#  The estimated number of batches is 1394
#       629/1    1.05863    1.06701 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.5005065975763585 for eigenvalue
#  The estimated number of batches is 1392
#       630/1    1.06806    1.06701 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4984539219303497 for eigenvalue
#  The estimated number of batches is 1390
#       631/1    1.07020    1.06702 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.496109032264744 for eigenvalue
#  The estimated number of batches is 1388
#       632/1    1.08404    1.06705 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4976325970969357 for eigenvalue
#  The estimated number of batches is 1393
#       633/1    1.06768    1.06705 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4953148434174088 for eigenvalue
#  The estimated number of batches is 1391
#       634/1    1.07291    1.06706 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4926366829812625 for eigenvalue
#  The estimated number of batches is 1388
#       635/1    1.06863    1.06706 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.491444522332041 for eigenvalue
#  The estimated number of batches is 1389
#       636/1    1.07392    1.06707 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4912786171739618 for eigenvalue
#  The estimated number of batches is 1390
#       637/1    1.07238    1.06708 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4889084208500782 for eigenvalue
#  The estimated number of batches is 1388
#       638/1    1.07073    1.06708 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4866332592691855 for eigenvalue
#  The estimated number of batches is 1386
#       639/1    1.07561    1.06710 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4841688511387399 for eigenvalue
#  The estimated number of batches is 1384
#       640/1    1.06676    1.06710 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4819981830274098 for eigenvalue
#  The estimated number of batches is 1382
#       641/1    1.06784    1.06710 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4806973311604208 for eigenvalue
#  The estimated number of batches is 1382
#       642/1    1.07094    1.06710 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.478476136365676 for eigenvalue
#  The estimated number of batches is 1380
#       643/1    1.06625    1.06710 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4775832555174546 for eigenvalue
#  The estimated number of batches is 1381
#       644/1    1.06213    1.06710 +/- 0.00024
#  Triggers unsatisfied, max unc./thresh. is 1.4773303978342285 for eigenvalue
#  The estimated number of batches is 1382
#       645/1    1.06666    1.06709 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4749421354004157 for eigenvalue
#  The estimated number of batches is 1380
#       646/1    1.07170    1.06710 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4727228028276593 for eigenvalue
#  The estimated number of batches is 1378
#       647/1    1.07162    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.470846039514406 for eigenvalue
#  The estimated number of batches is 1377
#       648/1    1.06810    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4686148109746913 for eigenvalue
#  The estimated number of batches is 1375
#       649/1    1.06455    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4670487449244023 for eigenvalue
#  The estimated number of batches is 1374
#       650/1    1.06906    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4663551121536476 for eigenvalue
#  The estimated number of batches is 1375
#       651/1    1.08398    1.06714 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4680815538994472 for eigenvalue
#  The estimated number of batches is 1380
#       652/1    1.07538    1.06715 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4664976329685406 for eigenvalue
#  The estimated number of batches is 1380
#       653/1    1.06805    1.06715 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4652962262712632 for eigenvalue
#  The estimated number of batches is 1380
#       654/1    1.06831    1.06715 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4630249226290806 for eigenvalue
#  The estimated number of batches is 1378
#       655/1    1.05632    1.06714 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.471016131591499 for eigenvalue
#  The estimated number of batches is 1395
#       656/1    1.07124    1.06714 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4686311813762116 for eigenvalue
#  The estimated number of batches is 1392
#       657/1    1.06257    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4679072488067397 for eigenvalue
#  The estimated number of batches is 1393
#       658/1    1.06791    1.06714 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4665088003611528 for eigenvalue
#  The estimated number of batches is 1393
#       659/1    1.06854    1.06714 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4641994144345196 for eigenvalue
#  The estimated number of batches is 1390
#       660/1    1.06460    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4656999667727821 for eigenvalue
#  The estimated number of batches is 1395
#       661/1    1.05614    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.464131984143895 for eigenvalue
#  The estimated number of batches is 1395
#       662/1    1.07273    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.462070615816217 for eigenvalue
#  The estimated number of batches is 1393
#       663/1    1.06370    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.461458346483107 for eigenvalue
#  The estimated number of batches is 1394
#       664/1    1.06445    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4601271262944595 for eigenvalue
#  The estimated number of batches is 1393
#       665/1    1.06629    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4586489620859726 for eigenvalue
#  The estimated number of batches is 1393
#       666/1    1.07230    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4572857438249476 for eigenvalue
#  The estimated number of batches is 1392
#       667/1    1.07233    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.457280978593719 for eigenvalue
#  The estimated number of batches is 1395
#       668/1    1.06488    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4552407688365492 for eigenvalue
#  The estimated number of batches is 1393
#       669/1    1.06595    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4543728768808823 for eigenvalue
#  The estimated number of batches is 1393
#       670/1    1.06188    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4531113798499877 for eigenvalue
#  The estimated number of batches is 1393
#       671/1    1.06074    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4598860905736837 for eigenvalue
#  The estimated number of batches is 1408
#       672/1    1.06760    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4580387621282225 for eigenvalue
#  The estimated number of batches is 1407
#       673/1    1.05313    1.06709 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4591647454837269 for eigenvalue
#  The estimated number of batches is 1411
#       674/1    1.07031    1.06709 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4575146885755055 for eigenvalue
#  The estimated number of batches is 1410
#       675/1    1.07237    1.06710 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4557657229660725 for eigenvalue
#  The estimated number of batches is 1409
#       676/1    1.07321    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4550618555846633 for eigenvalue
#  The estimated number of batches is 1409
#       677/1    1.06752    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.456336508211175 for eigenvalue
#  The estimated number of batches is 1414
#       678/1    1.06888    1.06711 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4544685826982602 for eigenvalue
#  The estimated number of batches is 1412
#       679/1    1.06911    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.457003954665657 for eigenvalue
#  The estimated number of batches is 1419
#       680/1    1.06893    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4554014294909932 for eigenvalue
#  The estimated number of batches is 1419
#       681/1    1.07140    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.453470008709744 for eigenvalue
#  The estimated number of batches is 1417
#       682/1    1.07182    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4513101171658063 for eigenvalue
#  The estimated number of batches is 1415
#       683/1    1.06238    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4491790985722601 for eigenvalue
#  The estimated number of batches is 1413
#       684/1    1.06783    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.447120081757175 for eigenvalue
#  The estimated number of batches is 1411
#       685/1    1.06332    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4450884023144548 for eigenvalue
#  The estimated number of batches is 1409
#       686/1    1.06355    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4432486319857862 for eigenvalue
#  The estimated number of batches is 1408
#       687/1    1.07968    1.06713 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4450120908829172 for eigenvalue
#  The estimated number of batches is 1413
#       688/1    1.06956    1.06714 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4431959516590016 for eigenvalue
#  The estimated number of batches is 1412
#       689/1    1.06597    1.06714 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4425963083809756 for eigenvalue
#  The estimated number of batches is 1413
#       690/1    1.05835    1.06712 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4405497181256033 for eigenvalue
#  The estimated number of batches is 1411
#       691/1    1.05152    1.06710 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4432204810284084 for eigenvalue
#  The estimated number of batches is 1418
#       692/1    1.06464    1.06710 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4411264717580445 for eigenvalue
#  The estimated number of batches is 1416
#       693/1    1.06372    1.06709 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.441229715827055 for eigenvalue
#  The estimated number of batches is 1418
#       694/1    1.07167    1.06710 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4411739400667705 for eigenvalue
#  The estimated number of batches is 1420
#       695/1    1.06074    1.06709 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4414118258657982 for eigenvalue
#  The estimated number of batches is 1423
#       696/1    1.06518    1.06709 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.440274153933299 for eigenvalue
#  The estimated number of batches is 1423
#       697/1    1.06994    1.06709 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4385576061740977 for eigenvalue
#  The estimated number of batches is 1422
#       698/1    1.05344    1.06707 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4393253215228299 for eigenvalue
#  The estimated number of batches is 1425
#       699/1    1.06485    1.06707 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4404458385422803 for eigenvalue
#  The estimated number of batches is 1429
#       700/1    1.06545    1.06706 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4383974490196008 for eigenvalue
#  The estimated number of batches is 1427
#       701/1    1.06507    1.06706 +/- 0.00023
#  Triggers unsatisfied, max unc./thresh. is 1.4365217147831943 for eigenvalue
#  The estimated number of batches is 1426
#       702/1    1.06279    1.06705 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.434910043742235 for eigenvalue
#  The estimated number of batches is 1425
#       703/1    1.06990    1.06706 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4330094827225923 for eigenvalue
#  The estimated number of batches is 1423
#       704/1    1.06155    1.06705 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.4310673529452027 for eigenvalue
#  The estimated number of batches is 1421
#       705/1    1.06437    1.06705 +/- 0.00022
#  Triggers unsatisfied, max unc./thresh. is 1.431473459838476 for eigenvalue
#  The estimated number of batches is 1424
