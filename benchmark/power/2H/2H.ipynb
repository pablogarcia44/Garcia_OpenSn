# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600

B4C_mat = openmc.Material(name="B4C_mat")
B4C_mat.add_nuclide('B10',1.52689E-02, 'ao')
B4C_mat.add_nuclide('B11',6.14591E-02, 'ao')
B4C_mat.add_nuclide('C0',1.91820E-02, 'ao')
B4C_mat.set_density('g/cm3', 1.76  )
B4C_mat.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304,B4C_mat]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/endfb71/endfb-vii.1-hdf5/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create B4C tube

# %%
def B4C_pin(family):
    B4C_outer_radius = openmc.ZCylinder(r=0.373)
    clad_inner_radius = openmc.ZCylinder(r=0.386)
    clad_outer_radius = openmc.ZCylinder(r=0.484)
    tube_inner_radius = openmc.ZCylinder(r=0.561)
    tube_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    B4C_region = -B4C_outer_radius
    gap_region = +B4C_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    guide_region = - tube_outer_radius & + tube_inner_radius
    water_region = +left & -right & +bottom & -top & +tube_outer_radius | +clad_outer_radius & - tube_inner_radius

    B4C = openmc.Cell(name='B4C'+'_'+family)
    B4C.fill = B4C_mat
    B4C.region = B4C_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = SS304
    clad.region = clad_region
    guide = openmc.Cell(name='guide'+'_'+family)
    guide.fill = zirconium
    guide.region = guide_region
    
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(B4C,guide, gap, clad, moderator))
    return(u,B4C,gap,clad,moderator,guide)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
AICT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]

AICT_left=[]
AICT_full=[]
for X in AICT:
    AICT_left.append((X[0],X[1]))
    AICT_left.append((X[0],16-X[1]))
for X in AICT_left:
    AICT_full.append((X[0],X[1]))
    AICT_full.append((16-X[0],X[1]))    
AICT_full = list(set(AICT_full))

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
b4c_1_family=B4C_pin('b4c_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in AICT_full : 
            A[ix][iy]=b4c_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water


rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:14
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.78616
#         2/1    0.79160
#         3/1    0.79141
#         4/1    0.78677
#         5/1    0.79140
#         6/1    0.78251
#         7/1    0.78512
#         8/1    0.80048
#         9/1    0.78756
#        10/1    0.79164
#        11/1    0.77678
#        12/1    0.77697
#        13/1    0.79209
#        14/1    0.78468
#        15/1    0.79349
#        16/1    0.78502
#        17/1    0.79102
#        18/1    0.78889
#        19/1    0.79557
#        20/1    0.78808
#        21/1    0.78082
#        22/1    0.77723    0.77903 +/- 0.00179
#        23/1    0.79213    0.78339 +/- 0.00449
#        24/1    0.78125    0.78286 +/- 0.00322
#        25/1    0.78903    0.78409 +/- 0.00278
#        26/1    0.78496    0.78424 +/- 0.00228
#        27/1    0.79062    0.78515 +/- 0.00213
#        28/1    0.78498    0.78513 +/- 0.00184
#        29/1    0.79202    0.78589 +/- 0.00180
#        30/1    0.79177    0.78648 +/- 0.00171
#        31/1    0.79182    0.78697 +/- 0.00162
#        32/1    0.78096    0.78647 +/- 0.00156
#        33/1    0.78890    0.78665 +/- 0.00145
#        34/1    0.77719    0.78598 +/- 0.00150
#        35/1    0.78019    0.78559 +/- 0.00145
#        36/1    0.78998    0.78587 +/- 0.00139
#        37/1    0.78804    0.78599 +/- 0.00131
#        38/1    0.79497    0.78649 +/- 0.00133
#        39/1    0.79182    0.78677 +/- 0.00129
#        40/1    0.78247    0.78656 +/- 0.00124
#        41/1    0.78563    0.78651 +/- 0.00118
#        42/1    0.80058    0.78715 +/- 0.00130
#        43/1    0.79254    0.78739 +/- 0.00126
#        44/1    0.79202    0.78758 +/- 0.00122
#        45/1    0.79036    0.78769 +/- 0.00118
#        46/1    0.78218    0.78748 +/- 0.00115
#        47/1    0.78663    0.78745 +/- 0.00111
#        48/1    0.79621    0.78776 +/- 0.00111
#        49/1    0.79157    0.78789 +/- 0.00108
#        50/1    0.79595    0.78816 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 8.224458907047023 for eigenvalue
#  The estimated number of batches is 2050
#  Creating state point statepoint.00050.h5...
#        51/1    0.78572    0.78808 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 7.982465189961285 for eigenvalue
#  The estimated number of batches is 1996
#        52/1    0.79275    0.78823 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 7.6938842006604755 for eigenvalue
#  The estimated number of batches is 1915
#        53/1    0.78505    0.78813 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 7.609916392340887 for eigenvalue
#  The estimated number of batches is 1932
#        54/1    0.79199    0.78824 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 7.48630755300209 for eigenvalue
#  The estimated number of batches is 1926
#        55/1    0.78876    0.78826 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 7.2923887878403235 for eigenvalue
#  The estimated number of batches is 1882
#        56/1    0.79032    0.78832 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 7.069933152917082 for eigenvalue
#  The estimated number of batches is 1820
#        57/1    0.78743    0.78829 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 6.956634298425912 for eigenvalue
#  The estimated number of batches is 1811
#        58/1    0.78748    0.78827 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 6.796120362387682 for eigenvalue
#  The estimated number of batches is 1776
#        59/1    0.78792    0.78826 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.6133902901498605 for eigenvalue
#  The estimated number of batches is 1726
#        60/1    0.77816    0.78801 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 6.820913554773337 for eigenvalue
#  The estimated number of batches is 1881
#        61/1    0.79055    0.78807 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.740924051340103 for eigenvalue
#  The estimated number of batches is 1884
#        62/1    0.79038    0.78813 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 6.569529158543039 for eigenvalue
#  The estimated number of batches is 1833
#        63/1    0.78937    0.78816 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 6.429189195070255 for eigenvalue
#  The estimated number of batches is 1798
#        64/1    0.78291    0.78804 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.33756057378545 for eigenvalue
#  The estimated number of batches is 1788
#        65/1    0.78572    0.78798 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 6.27495686785907 for eigenvalue
#  The estimated number of batches is 1792
#        66/1    0.78825    0.78799 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 6.1571277590717015 for eigenvalue
#  The estimated number of batches is 1764
#        67/1    0.78701    0.78797 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 6.0344125925183105 for eigenvalue
#  The estimated number of batches is 1732
#        68/1    0.79062    0.78802 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.883937770709943 for eigenvalue
#  The estimated number of batches is 1682
#        69/1    0.78020    0.78787 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.835798864002924 for eigenvalue
#  The estimated number of batches is 1689
#        70/1    0.77705    0.78765 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.8192290918557 for eigenvalue
#  The estimated number of batches is 1714
#        71/1    0.78837    0.78766 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.6976147922524065 for eigenvalue
#  The estimated number of batches is 1676
#        72/1    0.78818    0.78767 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.595417650449948 for eigenvalue
#  The estimated number of batches is 1649
#        73/1    0.77960    0.78752 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.683186515377604 for eigenvalue
#  The estimated number of batches is 1732
#        74/1    0.78603    0.78749 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.643531378314326 for eigenvalue
#  The estimated number of batches is 1740
#        75/1    0.78510    0.78745 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.567622689939549 for eigenvalue
#  The estimated number of batches is 1725
#        76/1    0.78819    0.78746 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.456591124093517 for eigenvalue
#  The estimated number of batches is 1688
#        77/1    0.78599    0.78744 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.384153015398978 for eigenvalue
#  The estimated number of batches is 1673
#        78/1    0.77305    0.78719 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 5.601735640762664 for eigenvalue
#  The estimated number of batches is 1841
#        79/1    0.78273    0.78711 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.543049077637449 for eigenvalue
#  The estimated number of batches is 1833
#        80/1    0.78321    0.78705 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.470259916360095 for eigenvalue
#  The estimated number of batches is 1816
#        81/1    0.78451    0.78701 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.3969441571807915 for eigenvalue
#  The estimated number of batches is 1797
#        82/1    0.79067    0.78707 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.27364860338847 for eigenvalue
#  The estimated number of batches is 1745
#        83/1    0.78358    0.78701 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.215843884581309 for eigenvalue
#  The estimated number of batches is 1734
#        84/1    0.78120    0.78692 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 5.252910381180178 for eigenvalue
#  The estimated number of batches is 1786
#        85/1    0.79261    0.78701 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 5.14503024616051 for eigenvalue
#  The estimated number of batches is 1741
#        86/1    0.78858    0.78703 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.129357130247868 for eigenvalue
#  The estimated number of batches is 1757
#        87/1    0.78680    0.78703 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.062953298234254 for eigenvalue
#  The estimated number of batches is 1738
#        88/1    0.77921    0.78691 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.123396521239339 for eigenvalue
#  The estimated number of batches is 1805
#        89/1    0.79873    0.78708 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.295161093901045 for eigenvalue
#  The estimated number of batches is 1955
#        90/1    0.78472    0.78705 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.233699079095837 for eigenvalue
#  The estimated number of batches is 1938
#        91/1    0.78919    0.78708 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.155701457584873 for eigenvalue
#  The estimated number of batches is 1908
#        92/1    0.80016    0.78726 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.079934425415125 for eigenvalue
#  The estimated number of batches is 1879
#        93/1    0.79250    0.78733 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.0162168492056765 for eigenvalue
#  The estimated number of batches is 1857
#        94/1    0.78579    0.78731 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.952767439284898 for eigenvalue
#  The estimated number of batches is 1836
#        95/1    0.77866    0.78720 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.160941959243936 for eigenvalue
#  The estimated number of batches is 2018
#        96/1    0.79375    0.78728 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.082167247775985 for eigenvalue
#  The estimated number of batches is 1983
#        97/1    0.77776    0.78716 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.152848677521102 for eigenvalue
#  The estimated number of batches is 2065
#        98/1    0.79676    0.78728 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.079033728915327 for eigenvalue
#  The estimated number of batches is 2033
#        99/1    0.78592    0.78727 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.018713021837405 for eigenvalue
#  The estimated number of batches is 2010
#       100/1    0.78561    0.78725 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.97052064576381 for eigenvalue
#  The estimated number of batches is 1997
#       101/1    0.78650    0.78724 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.914531576631931 for eigenvalue
#  The estimated number of batches is 1977
#       102/1    0.79540    0.78734 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.04109357373895 for eigenvalue
#  The estimated number of batches is 2104
#       103/1    0.79024    0.78737 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.003588538398665 for eigenvalue
#  The estimated number of batches is 2098
#       104/1    0.77925    0.78727 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.965571935639284 for eigenvalue
#  The estimated number of batches is 2092
#       105/1    0.78135    0.78720 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.93506136603275 for eigenvalue
#  The estimated number of batches is 2091
#       106/1    0.78495    0.78718 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.909650711241019 for eigenvalue
#  The estimated number of batches is 2094
#       107/1    0.78794    0.78719 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.849953194483297 for eigenvalue
#  The estimated number of batches is 2067
#       108/1    0.79101    0.78723 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.804004542133859 for eigenvalue
#  The estimated number of batches is 2051
#       109/1    0.78604    0.78722 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.755445242175759 for eigenvalue
#  The estimated number of batches is 2033
#       110/1    0.78712    0.78722 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.7035102369967765 for eigenvalue
#  The estimated number of batches is 2012
#       111/1    0.78774    0.78722 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.650508039362526 for eigenvalue
#  The estimated number of batches is 1989
#       112/1    0.78253    0.78717 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.608769518311531 for eigenvalue
#  The estimated number of batches is 1975
#       113/1    0.79028    0.78720 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.549042259768213 for eigenvalue
#  The estimated number of batches is 1945
#       114/1    0.78117    0.78714 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.517457156600524 for eigenvalue
#  The estimated number of batches is 1939
#       115/1    0.78299    0.78710 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.501790403060857 for eigenvalue
#  The estimated number of batches is 1946
#       116/1    0.78438    0.78707 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.5138682676107065 for eigenvalue
#  The estimated number of batches is 1977
#       117/1    0.79322    0.78713 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.441296963545974 for eigenvalue
#  The estimated number of batches is 1934
#       118/1    0.79148    0.78718 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.386041066677703 for eigenvalue
#  The estimated number of batches is 1906
#       119/1    0.78929    0.78720 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.327811452660581 for eigenvalue
#  The estimated number of batches is 1875
#       120/1    0.79051    0.78723 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.303870949806328 for eigenvalue
#  The estimated number of batches is 1873
#       121/1    0.79285    0.78729 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.253099510686097 for eigenvalue
#  The estimated number of batches is 1847
#       122/1    0.79087    0.78732 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.2025104927096555 for eigenvalue
#  The estimated number of batches is 1822
#       123/1    0.78584    0.78731 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.158176654252989 for eigenvalue
#  The estimated number of batches is 1801
#       124/1    0.79743    0.78740 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.152571237711428 for eigenvalue
#  The estimated number of batches is 1814
#       125/1    0.79559    0.78748 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.110630159013378 for eigenvalue
#  The estimated number of batches is 1795
#       126/1    0.78166    0.78743 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.082482793050154 for eigenvalue
#  The estimated number of batches is 1787
#       127/1    0.78023    0.78736 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.1101086749692115 for eigenvalue
#  The estimated number of batches is 1828
#       128/1    0.78896    0.78737 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.072863010075688 for eigenvalue
#  The estimated number of batches is 1812
#       129/1    0.79201    0.78742 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.062609535484487 for eigenvalue
#  The estimated number of batches is 1820
#       130/1    0.79037    0.78744 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.069144672537901 for eigenvalue
#  The estimated number of batches is 1842
#       131/1    0.78823    0.78745 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 4.055816253567616 for eigenvalue
#  The estimated number of batches is 1846
#       132/1    0.78812    0.78746 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 4.022392435183465 for eigenvalue
#  The estimated number of batches is 1833
#       133/1    0.78857    0.78747 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.990980592586445 for eigenvalue
#  The estimated number of batches is 1820
#       134/1    0.79382    0.78752 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.946822068067596 for eigenvalue
#  The estimated number of batches is 1796
#       135/1    0.79322    0.78757 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.909902540344045 for eigenvalue
#  The estimated number of batches is 1779
#       136/1    0.77998    0.78751 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.8917456211421686 for eigenvalue
#  The estimated number of batches is 1777
#       137/1    0.79804    0.78760 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.8982030421216116 for eigenvalue
#  The estimated number of batches is 1798
#       138/1    0.78661    0.78759 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.8701751642374385 for eigenvalue
#  The estimated number of batches is 1788
#       139/1    0.79102    0.78762 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.824209808066768 for eigenvalue
#  The estimated number of batches is 1761
#       140/1    0.78777    0.78762 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.7951369318593913 for eigenvalue
#  The estimated number of batches is 1749
#       141/1    0.79107    0.78765 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.7635577296358336 for eigenvalue
#  The estimated number of batches is 1734
#       142/1    0.78855    0.78765 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.737063986808291 for eigenvalue
#  The estimated number of batches is 1724
#       143/1    0.77759    0.78757 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.719754353810731 for eigenvalue
#  The estimated number of batches is 1722
#       144/1    0.79326    0.78762 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6794971271995047 for eigenvalue
#  The estimated number of batches is 1699
#       145/1    0.78305    0.78758 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.658780944291111 for eigenvalue
#  The estimated number of batches is 1694
#       146/1    0.78553    0.78757 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.6297658972045386 for eigenvalue
#  The estimated number of batches is 1681
#       147/1    0.78370    0.78753 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.6457944833574034 for eigenvalue
#  The estimated number of batches is 1709
#       148/1    0.79895    0.78762 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.604993420515565 for eigenvalue
#  The estimated number of batches is 1684
#       149/1    0.79222    0.78766 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.580853616484331 for eigenvalue
#  The estimated number of batches is 1675
#       150/1    0.78807    0.78766 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5562022254344856 for eigenvalue
#  The estimated number of batches is 1665
#       151/1    0.78626    0.78765 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5343404822069773 for eigenvalue
#  The estimated number of batches is 1657
#       152/1    0.79360    0.78770 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.503393506763101 for eigenvalue
#  The estimated number of batches is 1641
#       153/1    0.78318    0.78766 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.4790706379560232 for eigenvalue
#  The estimated number of batches is 1630
#       154/1    0.78413    0.78764 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.4674212544991376 for eigenvalue
#  The estimated number of batches is 1632
#       155/1    0.78488    0.78762 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4658358231121094 for eigenvalue
#  The estimated number of batches is 1642
#       156/1    0.78288    0.78758 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4429520528706066 for eigenvalue
#  The estimated number of batches is 1633
#       157/1    0.78352    0.78755 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4300962086045694 for eigenvalue
#  The estimated number of batches is 1632
#       158/1    0.78975    0.78757 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4056377741664807 for eigenvalue
#  The estimated number of batches is 1621
#       159/1    0.78975    0.78758 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3847138797895835 for eigenvalue
#  The estimated number of batches is 1613
#       160/1    0.79280    0.78762 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3823965023442164 for eigenvalue
#  The estimated number of batches is 1622
#       161/1    0.79001    0.78764 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3635921432499885 for eigenvalue
#  The estimated number of batches is 1616
#       162/1    0.77891    0.78758 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3997883595866534 for eigenvalue
#  The estimated number of batches is 1662
#       163/1    0.78485    0.78756 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.381624481597883 for eigenvalue
#  The estimated number of batches is 1656
#       164/1    0.78791    0.78756 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3658736782376537 for eigenvalue
#  The estimated number of batches is 1652
#       165/1    0.78932    0.78757 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.334201369612874 for eigenvalue
#  The estimated number of batches is 1632
#       166/1    0.79999    0.78766 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.349394179775393 for eigenvalue
#  The estimated number of batches is 1658
#       167/1    0.77892    0.78760 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.334570580198904 for eigenvalue
#  The estimated number of batches is 1655
#       168/1    0.78103    0.78755 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.339387221515816 for eigenvalue
#  The estimated number of batches is 1671
#       169/1    0.78967    0.78757 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3230516442380145 for eigenvalue
#  The estimated number of batches is 1666
#       170/1    0.79464    0.78761 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2978624249571147 for eigenvalue
#  The estimated number of batches is 1652
#       171/1    0.79073    0.78764 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2740419923421795 for eigenvalue
#  The estimated number of batches is 1639
#       172/1    0.79230    0.78767 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2799617956594322 for eigenvalue
#  The estimated number of batches is 1656
#       173/1    0.78241    0.78763 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.267665619451821 for eigenvalue
#  The estimated number of batches is 1654
#       174/1    0.79576    0.78768 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.252542255109204 for eigenvalue
#  The estimated number of batches is 1650
#       175/1    0.78952    0.78770 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.238258371366475 for eigenvalue
#  The estimated number of batches is 1646
#       176/1    0.78534    0.78768 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.21821006988328 for eigenvalue
#  The estimated number of batches is 1636
#       177/1    0.79498    0.78773 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2188550347356775 for eigenvalue
#  The estimated number of batches is 1647
#       178/1    0.78501    0.78771 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.201360009169516 for eigenvalue
#  The estimated number of batches is 1640
#       179/1    0.77988    0.78766 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.21868485036557 for eigenvalue
#  The estimated number of batches is 1668
#       180/1    0.77600    0.78759 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.303311468941945 for eigenvalue
#  The estimated number of batches is 1766
#       181/1    0.78109    0.78755 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2946127447926647 for eigenvalue
#  The estimated number of batches is 1768
#       182/1    0.79581    0.78760 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.330858208697128 for eigenvalue
#  The estimated number of batches is 1818
#       183/1    0.78694    0.78759 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.3115948796388444 for eigenvalue
#  The estimated number of batches is 1808
#       184/1    0.78723    0.78759 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2960075922162635 for eigenvalue
#  The estimated number of batches is 1802
#       185/1    0.78809    0.78760 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.2780336074414653 for eigenvalue
#  The estimated number of batches is 1794
#       186/1    0.78920    0.78761 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.257573530191689 for eigenvalue
#  The estimated number of batches is 1782
#       187/1    0.78972    0.78762 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.2422185029190085 for eigenvalue
#  The estimated number of batches is 1776
#       188/1    0.78891    0.78763 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.224219886247205 for eigenvalue
#  The estimated number of batches is 1767
#       189/1    0.79235    0.78765 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.2098161913575938 for eigenvalue
#  The estimated number of batches is 1762
#       190/1    0.78246    0.78762 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1943721975598445 for eigenvalue
#  The estimated number of batches is 1755
#       191/1    0.78438    0.78760 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.184782672983793 for eigenvalue
#  The estimated number of batches is 1755
#       192/1    0.79499    0.78765 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.184224947870346 for eigenvalue
#  The estimated number of batches is 1764
#       193/1    0.78780    0.78765 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1704276618176404 for eigenvalue
#  The estimated number of batches is 1759
#       194/1    0.78211    0.78762 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1606688018735216 for eigenvalue
#  The estimated number of batches is 1759
#       195/1    0.79171    0.78764 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.1358990620045666 for eigenvalue
#  The estimated number of batches is 1741
#       196/1    0.79269    0.78767 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.116362247379592 for eigenvalue
#  The estimated number of batches is 1730
#       197/1    0.78116    0.78763 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.1050803289371127 for eigenvalue
#  The estimated number of batches is 1727
#       198/1    0.79361    0.78766 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.10804598872911 for eigenvalue
#  The estimated number of batches is 1740
#       199/1    0.78400    0.78764 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0951662628910115 for eigenvalue
#  The estimated number of batches is 1735
#       200/1    0.78864    0.78765 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.081549782774333 for eigenvalue
#  The estimated number of batches is 1730
#       201/1    0.78532    0.78764 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.084341222051502 for eigenvalue
#  The estimated number of batches is 1742
#       202/1    0.78430    0.78762 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.070108235501517 for eigenvalue
#  The estimated number of batches is 1736
#       203/1    0.79394    0.78765 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.054149216945832 for eigenvalue
#  The estimated number of batches is 1727
#       204/1    0.79269    0.78768 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.0448852262910173 for eigenvalue
#  The estimated number of batches is 1726
#       205/1    0.78853    0.78769 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.0433160185296857 for eigenvalue
#  The estimated number of batches is 1734
#       206/1    0.78921    0.78769 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.025563170572366 for eigenvalue
#  The estimated number of batches is 1723
#       207/1    0.78563    0.78768 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.0180565989831245 for eigenvalue
#  The estimated number of batches is 1724
#       208/1    0.78279    0.78766 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 3.010960940184155 for eigenvalue
#  The estimated number of batches is 1725
#       209/1    0.78841    0.78766 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.9959520724850965 for eigenvalue
#  The estimated number of batches is 1717
#       210/1    0.78816    0.78766 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.978358379534409 for eigenvalue
#  The estimated number of batches is 1706
#       211/1    0.78541    0.78765 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.964583212069809 for eigenvalue
#  The estimated number of batches is 1699
#       212/1    0.78509    0.78764 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.9489978627870195 for eigenvalue
#  The estimated number of batches is 1690
#       213/1    0.78611    0.78763 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.934818668189842 for eigenvalue
#  The estimated number of batches is 1683
#       214/1    0.78243    0.78760 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.920818432169038 for eigenvalue
#  The estimated number of batches is 1676
#       215/1    0.79199    0.78763 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.9246224407505297 for eigenvalue
#  The estimated number of batches is 1688
#       216/1    0.79115    0.78764 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9098376089834037 for eigenvalue
#  The estimated number of batches is 1680
#       217/1    0.79479    0.78768 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.9069251635458024 for eigenvalue
#  The estimated number of batches is 1685
#       218/1    0.78752    0.78768 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.894698041469192 for eigenvalue
#  The estimated number of batches is 1680
#       219/1    0.78001    0.78764 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.884165022315537 for eigenvalue
#  The estimated number of batches is 1676
#       220/1    0.79072    0.78766 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8672126401963283 for eigenvalue
#  The estimated number of batches is 1665
#       221/1    0.79603    0.78770 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8496115683741867 for eigenvalue
#  The estimated number of batches is 1653
#       222/1    0.78904    0.78770 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.837918770487364 for eigenvalue
#  The estimated number of batches is 1647
#       223/1    0.79087    0.78772 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8218206113487465 for eigenvalue
#  The estimated number of batches is 1637
#       224/1    0.78891    0.78773 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8082106811466834 for eigenvalue
#  The estimated number of batches is 1629
#       225/1    0.78132    0.78769 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8033039026623694 for eigenvalue
#  The estimated number of batches is 1631
#       226/1    0.78973    0.78770 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7888981970163016 for eigenvalue
#  The estimated number of batches is 1623
#       227/1    0.78593    0.78770 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.777853520081757 for eigenvalue
#  The estimated number of batches is 1618
#       228/1    0.79401    0.78773 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7660526552411935 for eigenvalue
#  The estimated number of batches is 1612
#       229/1    0.78565    0.78772 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7533946724037457 for eigenvalue
#  The estimated number of batches is 1605
#       230/1    0.79524    0.78775 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7544258380004876 for eigenvalue
#  The estimated number of batches is 1614
#       231/1    0.78123    0.78772 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.747816478650857 for eigenvalue
#  The estimated number of batches is 1614
#       232/1    0.78206    0.78769 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.735898460836109 for eigenvalue
#  The estimated number of batches is 1607
#       233/1    0.78794    0.78770 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7237363702028996 for eigenvalue
#  The estimated number of batches is 1601
#       234/1    0.78636    0.78769 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.711516403688384 for eigenvalue
#  The estimated number of batches is 1594
#       235/1    0.78406    0.78767 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.713187021850041 for eigenvalue
#  The estimated number of batches is 1603
#       236/1    0.78259    0.78765 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.72103291730254 for eigenvalue
#  The estimated number of batches is 1620
#       237/1    0.78392    0.78763 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7209040867235177 for eigenvalue
#  The estimated number of batches is 1627
#       238/1    0.79224    0.78765 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7100798565215176 for eigenvalue
#  The estimated number of batches is 1622
#       239/1    0.78507    0.78764 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7009341940618485 for eigenvalue
#  The estimated number of batches is 1618
#       240/1    0.78660    0.78764 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.689324337744218 for eigenvalue
#  The estimated number of batches is 1612
#       241/1    0.78073    0.78760 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.683295344970278 for eigenvalue
#  The estimated number of batches is 1612
#       242/1    0.78211    0.78758 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.674564399946361 for eigenvalue
#  The estimated number of batches is 1609
#       243/1    0.79430    0.78761 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6638262674240103 for eigenvalue
#  The estimated number of batches is 1603
#       244/1    0.78320    0.78759 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.652215265753967 for eigenvalue
#  The estimated number of batches is 1596
#       245/1    0.79340    0.78762 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6385380451454803 for eigenvalue
#  The estimated number of batches is 1587
#       246/1    0.79633    0.78766 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6335772755503633 for eigenvalue
#  The estimated number of batches is 1588
#       247/1    0.78854    0.78766 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.624020073045325 for eigenvalue
#  The estimated number of batches is 1584
#       248/1    0.79558    0.78769 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6116404846222454 for eigenvalue
#  The estimated number of batches is 1576
#       249/1    0.78951    0.78770 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.6021938423250064 for eigenvalue
#  The estimated number of batches is 1571
#       250/1    0.79322    0.78773 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.602221215657117 for eigenvalue
#  The estimated number of batches is 1578
#       251/1    0.78303    0.78771 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5948306547031743 for eigenvalue
#  The estimated number of batches is 1576
#       252/1    0.79243    0.78773 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.586451748563318 for eigenvalue
#  The estimated number of batches is 1573
#       253/1    0.78596    0.78772 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5785497205667576 for eigenvalue
#  The estimated number of batches is 1570
#       254/1    0.79634    0.78775 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5822489661481827 for eigenvalue
#  The estimated number of batches is 1581
#       255/1    0.78685    0.78775 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5723799651542443 for eigenvalue
#  The estimated number of batches is 1576
#       256/1    0.79058    0.78776 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5612432223606305 for eigenvalue
#  The estimated number of batches is 1569
#       257/1    0.78279    0.78774 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5580884647795723 for eigenvalue
#  The estimated number of batches is 1571
#       258/1    0.78810    0.78774 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5473639123625835 for eigenvalue
#  The estimated number of batches is 1565
#       259/1    0.79534    0.78778 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5427383752254076 for eigenvalue
#  The estimated number of batches is 1566
#       260/1    0.78427    0.78776 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.536437872656847 for eigenvalue
#  The estimated number of batches is 1565
#       261/1    0.78475    0.78775 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5262047073522202 for eigenvalue
#  The estimated number of batches is 1558
#       262/1    0.78398    0.78773 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5174040051242628 for eigenvalue
#  The estimated number of batches is 1554
#       263/1    0.79050    0.78774 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5082872292448495 for eigenvalue
#  The estimated number of batches is 1549
#       264/1    0.79009    0.78775 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4988404823287924 for eigenvalue
#  The estimated number of batches is 1544
#       265/1    0.77842    0.78772 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5218034050242424 for eigenvalue
#  The estimated number of batches is 1579
#       266/1    0.78220    0.78769 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.514256083443231 for eigenvalue
#  The estimated number of batches is 1576
#       267/1    0.79297    0.78771 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5050879813476614 for eigenvalue
#  The estimated number of batches is 1571
#       268/1    0.78816    0.78772 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4971722346763645 for eigenvalue
#  The estimated number of batches is 1567
#       269/1    0.78380    0.78770 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.487281625171543 for eigenvalue
#  The estimated number of batches is 1561
#       270/1    0.77918    0.78767 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4914504113876603 for eigenvalue
#  The estimated number of batches is 1572
#       271/1    0.78996    0.78768 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.482704049449702 for eigenvalue
#  The estimated number of batches is 1568
#       272/1    0.79238    0.78769 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4797050444846787 for eigenvalue
#  The estimated number of batches is 1570
#       273/1    0.79284    0.78771 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4707783336500513 for eigenvalue
#  The estimated number of batches is 1565
#       274/1    0.78707    0.78771 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4651400831309394 for eigenvalue
#  The estimated number of batches is 1564
#       275/1    0.79050    0.78772 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.456121425791993 for eigenvalue
#  The estimated number of batches is 1559
#       276/1    0.78366    0.78771 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.446872578698434 for eigenvalue
#  The estimated number of batches is 1553
#       277/1    0.78763    0.78771 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4395338215843463 for eigenvalue
#  The estimated number of batches is 1550
#       278/1    0.77684    0.78766 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.455797307495298 for eigenvalue
#  The estimated number of batches is 1576
#       279/1    0.78296    0.78765 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4478927099361147 for eigenvalue
#  The estimated number of batches is 1572
#       280/1    0.78081    0.78762 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.445990984443602 for eigenvalue
#  The estimated number of batches is 1576
#       281/1    0.78946    0.78763 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4382739708987793 for eigenvalue
#  The estimated number of batches is 1572
#       282/1    0.78887    0.78763 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4308231145862083 for eigenvalue
#  The estimated number of batches is 1569
#       283/1    0.78125    0.78761 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.429654540460598 for eigenvalue
#  The estimated number of batches is 1573
#       284/1    0.79334    0.78763 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.425659331676263 for eigenvalue
#  The estimated number of batches is 1574
#       285/1    0.78992    0.78764 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.425744961972785 for eigenvalue
#  The estimated number of batches is 1580
#       286/1    0.79410    0.78766 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4181221455376085 for eigenvalue
#  The estimated number of batches is 1576
#       287/1    0.78141    0.78764 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.411884158566157 for eigenvalue
#  The estimated number of batches is 1574
#       288/1    0.78859    0.78764 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4040172461416742 for eigenvalue
#  The estimated number of batches is 1569
#       289/1    0.78479    0.78763 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.3955707235554633 for eigenvalue
#  The estimated number of batches is 1564
#       290/1    0.78383    0.78762 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.3876836679636395 for eigenvalue
#  The estimated number of batches is 1560
#       291/1    0.78389    0.78760 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.380171056684299 for eigenvalue
#  The estimated number of batches is 1556
#       292/1    0.78552    0.78760 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.373010920419625 for eigenvalue
#  The estimated number of batches is 1552
#       293/1    0.78100    0.78757 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.366497191387328 for eigenvalue
#  The estimated number of batches is 1549
#       294/1    0.79157    0.78759 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.360162930609403 for eigenvalue
#  The estimated number of batches is 1547
#       295/1    0.79464    0.78761 +/- 0.00031
# ...
#  Triggers unsatisfied, max unc./thresh. is 1.3999571396201231 for eigenvalue
#  The estimated number of batches is 1385
#       717/1    0.79033    0.78778 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3980970300801503 for eigenvalue
#  The estimated number of batches is 1383
#       718/1    0.78860    0.78778 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3965975441843903 for eigenvalue
#  The estimated number of batches is 1382
#       719/1    0.78166    0.78777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.395810742653936 for eigenvalue
#  The estimated number of batches is 1382
#       720/1    0.78181    0.78776 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3939140887089383 for eigenvalue
#  The estimated number of batches is 1381
#       721/1    0.78847    0.78776 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.392450925168021 for eigenvalue
#  The estimated number of batches is 1380
#       722/1    0.78361    0.78776 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3911747214670842 for eigenvalue
#  The estimated number of batches is 1379
#       723/1    0.79028    0.78776 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3892546992595454 for eigenvalue
#  The estimated number of batches is 1377
#       724/1    0.79312    0.78777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.387387509337424 for eigenvalue
#  The estimated number of batches is 1376
#       725/1    0.78248    0.78776 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3869941865289004 for eigenvalue
#  The estimated number of batches is 1377
#       726/1    0.79508    0.78777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3853597025409856 for eigenvalue
#  The estimated number of batches is 1375
#       727/1    0.78464    0.78777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3834714459652497 for eigenvalue
#  The estimated number of batches is 1374
#       728/1    0.78610    0.78777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.381583580783987 for eigenvalue
#  The estimated number of batches is 1372
#       729/1    0.79309    0.78777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.380734682822058 for eigenvalue
#  The estimated number of batches is 1372
#       730/1    0.79214    0.78778 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.379190193552048 for eigenvalue
#  The estimated number of batches is 1371
#       731/1    0.80378    0.78780 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3881610628027528 for eigenvalue
#  The estimated number of batches is 1391
#       732/1    0.77854    0.78779 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3887119333086557 for eigenvalue
#  The estimated number of batches is 1394
#       733/1    0.78862    0.78779 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.388104801519345 for eigenvalue
#  The estimated number of batches is 1394
#       734/1    0.78789    0.78779 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3886630324547453 for eigenvalue
#  The estimated number of batches is 1397
#       735/1    0.79312    0.78780 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3866518277514976 for eigenvalue
#  The estimated number of batches is 1395
#       736/1    0.79113    0.78780 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3847171806289336 for eigenvalue
#  The estimated number of batches is 1393
#       737/1    0.78867    0.78780 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.382815531955071 for eigenvalue
#  The estimated number of batches is 1392
#       738/1    0.79478    0.78781 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3887980720016249 for eigenvalue
#  The estimated number of batches is 1405
#       739/1    0.78753    0.78781 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3868716071874898 for eigenvalue
#  The estimated number of batches is 1403
#       740/1    0.78842    0.78781 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3850727109833354 for eigenvalue
#  The estimated number of batches is 1402
#       741/1    0.79146    0.78782 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3836454496833617 for eigenvalue
#  The estimated number of batches is 1401
#       742/1    0.79253    0.78783 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.384171508397236 for eigenvalue
#  The estimated number of batches is 1404
#       743/1    0.78213    0.78782 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.38233844893983 for eigenvalue
#  The estimated number of batches is 1402
#       744/1    0.79042    0.78782 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3813424222512793 for eigenvalue
#  The estimated number of batches is 1402
#       745/1    0.79254    0.78783 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3803420085575102 for eigenvalue
#  The estimated number of batches is 1402
#       746/1    0.79147    0.78783 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3787811096640614 for eigenvalue
#  The estimated number of batches is 1401
#       747/1    0.78728    0.78783 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.3788775443151837 for eigenvalue
#  The estimated number of batches is 1403
#       748/1    0.79099    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.376967788959671 for eigenvalue
#  The estimated number of batches is 1401
#       749/1    0.79209    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3772084905543132 for eigenvalue
#  The estimated number of batches is 1403
#       750/1    0.79340    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3806203971562918 for eigenvalue
#  The estimated number of batches is 1412
#       751/1    0.78681    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3798925254641374 for eigenvalue
#  The estimated number of batches is 1412
#       752/1    0.78291    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3791010610716894 for eigenvalue
#  The estimated number of batches is 1413
#       753/1    0.78430    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3772844438233236 for eigenvalue
#  The estimated number of batches is 1411
#       754/1    0.79050    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.377289408797101 for eigenvalue
#  The estimated number of batches is 1413
#       755/1    0.78856    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3755782506961447 for eigenvalue
#  The estimated number of batches is 1411
#       756/1    0.78540    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3738975177041026 for eigenvalue
#  The estimated number of batches is 1410
#       757/1    0.79463    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3720268812510112 for eigenvalue
#  The estimated number of batches is 1408
#       758/1    0.77185    0.78783 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3762161677186215 for eigenvalue
#  The estimated number of batches is 1418
#       759/1    0.79453    0.78783 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3764192405656774 for eigenvalue
#  The estimated number of batches is 1421
#       760/1    0.78731    0.78783 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3746006664036607 for eigenvalue
#  The estimated number of batches is 1419
#       761/1    0.78687    0.78783 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3727795456273204 for eigenvalue
#  The estimated number of batches is 1417
#       762/1    0.79019    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3716321596390395 for eigenvalue
#  The estimated number of batches is 1416
#       763/1    0.79131    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3731245736485371 for eigenvalue
#  The estimated number of batches is 1421
#       764/1    0.78228    0.78783 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3742517623969754 for eigenvalue
#  The estimated number of batches is 1426
#       765/1    0.78840    0.78783 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.372951511422943 for eigenvalue
#  The estimated number of batches is 1425
#       766/1    0.79069    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3715354193962608 for eigenvalue
#  The estimated number of batches is 1424
#       767/1    0.78850    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.371437597281034 for eigenvalue
#  The estimated number of batches is 1425
#       768/1    0.78478    0.78783 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3699015492491697 for eigenvalue
#  The estimated number of batches is 1424
#       769/1    0.79726    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3703030369768021 for eigenvalue
#  The estimated number of batches is 1427
#       770/1    0.78486    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.36858740528302 for eigenvalue
#  The estimated number of batches is 1425
#       771/1    0.78287    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3670643683406545 for eigenvalue
#  The estimated number of batches is 1424
#       772/1    0.78518    0.78783 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3654834943918253 for eigenvalue
#  The estimated number of batches is 1423
#       773/1    0.79757    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.367029099424746 for eigenvalue
#  The estimated number of batches is 1428
#       774/1    0.78761    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3651996785244391 for eigenvalue
#  The estimated number of batches is 1426
#       775/1    0.79039    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3635002759493529 for eigenvalue
#  The estimated number of batches is 1424
#       776/1    0.78964    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3628091795407247 for eigenvalue
#  The estimated number of batches is 1425
#       777/1    0.78371    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3611060114389315 for eigenvalue
#  The estimated number of batches is 1423
#       778/1    0.78162    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3631226350952121 for eigenvalue
#  The estimated number of batches is 1429
#       779/1    0.79376    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3624921811402078 for eigenvalue
#  The estimated number of batches is 1429
#       780/1    0.78900    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3606772943943262 for eigenvalue
#  The estimated number of batches is 1428
#       781/1    0.78818    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3594326077775103 for eigenvalue
#  The estimated number of batches is 1427
#       782/1    0.79383    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3577241799151838 for eigenvalue
#  The estimated number of batches is 1425
#       783/1    0.77665    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3587943415706965 for eigenvalue
#  The estimated number of batches is 1429
#       784/1    0.79429    0.78785 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3572453169630743 for eigenvalue
#  The estimated number of batches is 1428
#       785/1    0.78498    0.78784 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.355619645862742 for eigenvalue
#  The estimated number of batches is 1426
#       786/1    0.79774    0.78786 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3554438339028065 for eigenvalue
#  The estimated number of batches is 1428
#       787/1    0.79023    0.78786 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3536544896467642 for eigenvalue
#  The estimated number of batches is 1426
#       788/1    0.79334    0.78787 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3521623046751265 for eigenvalue
#  The estimated number of batches is 1425
#       789/1    0.79428    0.78788 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3504087453994589 for eigenvalue
#  The estimated number of batches is 1423
#       790/1    0.80006    0.78789 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3555010687837532 for eigenvalue
#  The estimated number of batches is 1435
#       791/1    0.79676    0.78790 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3559057572190092 for eigenvalue
#  The estimated number of batches is 1438
#       792/1    0.78348    0.78790 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.354195102545639 for eigenvalue
#  The estimated number of batches is 1436
#       793/1    0.80017    0.78791 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3559592475142643 for eigenvalue
#  The estimated number of batches is 1442
#       794/1    0.78824    0.78791 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3542902770835814 for eigenvalue
#  The estimated number of batches is 1440
#       795/1    0.79043    0.78792 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3531168360704642 for eigenvalue
#  The estimated number of batches is 1439
#       796/1    0.78804    0.78792 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.351773904364391 for eigenvalue
#  The estimated number of batches is 1438
#       797/1    0.78097    0.78791 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.352404613581228 for eigenvalue
#  The estimated number of batches is 1442
#       798/1    0.79213    0.78791 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3506365328881462 for eigenvalue
#  The estimated number of batches is 1440
#       799/1    0.78983    0.78792 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.349299202602801 for eigenvalue
#  The estimated number of batches is 1439
#       800/1    0.78691    0.78792 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3476400337181471 for eigenvalue
#  The estimated number of batches is 1437
#       801/1    0.78912    0.78792 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.345956860810207 for eigenvalue
#  The estimated number of batches is 1435
#       802/1    0.79279    0.78792 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3446300687380426 for eigenvalue
#  The estimated number of batches is 1434
#       803/1    0.79445    0.78793 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3443100208609844 for eigenvalue
#  The estimated number of batches is 1436
#       804/1    0.78929    0.78793 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3428418754209988 for eigenvalue
#  The estimated number of batches is 1434
#       805/1    0.79042    0.78794 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3413534731611734 for eigenvalue
#  The estimated number of batches is 1433
#       806/1    0.79840    0.78795 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.343062998349748 for eigenvalue
#  The estimated number of batches is 1438
#       807/1    0.79215    0.78795 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3419571231570666 for eigenvalue
#  The estimated number of batches is 1438
#       808/1    0.79150    0.78796 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3402550929410617 for eigenvalue
#  The estimated number of batches is 1436
#       809/1    0.78105    0.78795 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3396589879615628 for eigenvalue
#  The estimated number of batches is 1437
#       810/1    0.79011    0.78795 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.337934768067839 for eigenvalue
#  The estimated number of batches is 1435
#       811/1    0.79247    0.78796 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3368728936628493 for eigenvalue
#  The estimated number of batches is 1434
#       812/1    0.79482    0.78797 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.337295584796217 for eigenvalue
#  The estimated number of batches is 1437
#       813/1    0.78447    0.78796 +/- 0.00018
#  Triggers unsatisfied, max unc./thresh. is 1.3357165128244277 for eigenvalue
#  The estimated number of batches is 1435
