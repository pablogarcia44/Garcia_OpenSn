# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600

AIC_mat = openmc.Material(name="AIC_mat")
AIC_mat.add_nuclide('Ag107',2.36159E-02, 'ao')
AIC_mat.add_nuclide('Ag109',2.19403E-02, 'ao')
AIC_mat.add_nuclide('Cd106',3.41523E-05, 'ao')
AIC_mat.add_nuclide('Cd108',2.43165E-05, 'ao')
AIC_mat.add_nuclide('Cd110',3.41250E-04, 'ao')
AIC_mat.add_nuclide('Cd111',3.49720E-04, 'ao')
AIC_mat.add_nuclide('Cd112',6.59276E-04, 'ao')
AIC_mat.add_nuclide('Cd113',3.33873E-04, 'ao')
AIC_mat.add_nuclide('Cd114',7.84957E-04, 'ao')
AIC_mat.add_nuclide('Cd116',2.04641E-04, 'ao')
AIC_mat.add_nuclide('In113',3.44262E-04, 'ao')
AIC_mat.add_nuclide('In115',7.68050E-03, 'ao')

AIC_mat.set_density('g/cm3', 10.2 )
AIC_mat.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304,AIC_mat]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/endfb71/endfb-vii.1-hdf5/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create AIC tube

# %%
def AIC_pin(family):
    AIC_outer_radius = openmc.ZCylinder(r=0.382)
    clad_inner_radius = openmc.ZCylinder(r=0.386)
    clad_outer_radius = openmc.ZCylinder(r=0.484)
    tube_inner_radius = openmc.ZCylinder(r=0.561)
    tube_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    AIC_region = -AIC_outer_radius
    gap_region = +AIC_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    guide_region = - tube_outer_radius & + tube_inner_radius
    water_region = +left & -right & +bottom & -top & +tube_outer_radius | +clad_outer_radius & - tube_inner_radius

    AIC = openmc.Cell(name='AIC'+'_'+family)
    AIC.fill = AIC_mat
    AIC.region = AIC_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = SS304
    clad.region = clad_region
    guide = openmc.Cell(name='guide'+'_'+family)
    guide.fill = zirconium
    guide.region = guide_region
    
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(AIC,guide, gap, clad, moderator))
    return(u,AIC,gap,clad,moderator,guide)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
AICT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]

AICT_left=[]
AICT_full=[]
for X in AICT:
    AICT_left.append((X[0],X[1]))
    AICT_left.append((X[0],16-X[1]))
for X in AICT_left:
    AICT_full.append((X[0],X[1]))
    AICT_full.append((16-X[0],X[1]))    
AICT_full = list(set(AICT_full))

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
aic_1_family=AIC_pin('aic_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in AICT_full : 
            A[ix][iy]=aic_1_family[0]  
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]            
        else:
            A[ix][iy]=pincell_1_family[0]  
            
         
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water


rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
tally_power = openmc.Tally(name='power')


# Instantiate a tally Mesh
mesh = openmc.RegularMesh()
mesh._dimension = [17, 17]
mesh._lower_left = [-10.71, -10.71]
mesh._upper_right = [+10.71, +10.71]


# Instantiate tally Filter
mesh_filter = openmc.MeshFilter(mesh)


tally_power.scores = ['fission', 'nu-fission', 'kappa-fission']
tally_power.filters = [mesh_filter]


tallies = openmc.Tallies([tally_power])
model.tallies=tallies

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-10 17:15:20
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading Ag107 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ag107.h5
#  Reading Ag109 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ag109.h5
#  Reading Cd106 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 600K
#  Reading Cd108 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd108.h5
#  Reading Cd110 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd110.h5
#  Reading Cd111 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd111.h5
#  Reading Cd112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd112.h5
#  Reading Cd113 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd113.h5
#  Reading Cd114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd114.h5
#  Reading Cd116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd116.h5
#  Reading In113 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/In113.h5
#  Reading In115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/In115.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.85077
#         2/1    0.84566
#         3/1    0.85172
#         4/1    0.85233
#         5/1    0.84672
#         6/1    0.85379
#         7/1    0.85183
#         8/1    0.84438
#         9/1    0.85276
#        10/1    0.85162
#        11/1    0.85488
#        12/1    0.85089
#        13/1    0.84567
#        14/1    0.84716
#        15/1    0.84252
#        16/1    0.84886
#        17/1    0.85016
#        18/1    0.84673
#        19/1    0.84345
#        20/1    0.84370
#        21/1    0.84606
#        22/1    0.84339    0.84472 +/- 0.00134
#        23/1    0.84476    0.84474 +/- 0.00077
#        24/1    0.84058    0.84370 +/- 0.00117
#        25/1    0.85022    0.84500 +/- 0.00159
#        26/1    0.85128    0.84605 +/- 0.00167
#        27/1    0.84912    0.84649 +/- 0.00148
#        28/1    0.85002    0.84693 +/- 0.00135
#        29/1    0.85145    0.84743 +/- 0.00129
#        30/1    0.84523    0.84721 +/- 0.00118
#        31/1    0.83896    0.84646 +/- 0.00130
#        32/1    0.83795    0.84575 +/- 0.00139
#        33/1    0.84621    0.84579 +/- 0.00127
#        34/1    0.84107    0.84545 +/- 0.00123
#        35/1    0.85257    0.84593 +/- 0.00124
#        36/1    0.84109    0.84562 +/- 0.00120
#        37/1    0.84612    0.84565 +/- 0.00112
#        38/1    0.84409    0.84557 +/- 0.00106
#        39/1    0.84157    0.84536 +/- 0.00103
#        40/1    0.84282    0.84523 +/- 0.00098
#        41/1    0.85030    0.84547 +/- 0.00097
#        42/1    0.84859    0.84561 +/- 0.00093
#        43/1    0.85035    0.84582 +/- 0.00091
#        44/1    0.85129    0.84605 +/- 0.00090
#        45/1    0.84810    0.84613 +/- 0.00087
#        46/1    0.84330    0.84602 +/- 0.00084
#        47/1    0.85560    0.84637 +/- 0.00089
#        48/1    0.84785    0.84643 +/- 0.00086
#        49/1    0.84842    0.84650 +/- 0.00083
#        50/1    0.84587    0.84647 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.76679762329554 for eigenvalue
#  The estimated number of batches is 1394
#  Creating state point statepoint.00050.h5...
#        51/1    0.83730    0.84618 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 6.78902936412793 for eigenvalue
#  The estimated number of batches is 1449
#        52/1    0.85208    0.84636 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 6.641227064072815 for eigenvalue
#  The estimated number of batches is 1432
#        53/1    0.84903    0.84644 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.509181749372418 for eigenvalue
#  The estimated number of batches is 1419
#        54/1    0.85112    0.84658 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 6.451455067445637 for eigenvalue
#  The estimated number of batches is 1436
#        55/1    0.84596    0.84656 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 6.3585677240489105 for eigenvalue
#  The estimated number of batches is 1436
#        56/1    0.84727    0.84658 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 6.457684025212171 for eigenvalue
#  The estimated number of batches is 1522
#        57/1    0.84444    0.84653 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 6.249437498868533 for eigenvalue
#  The estimated number of batches is 1466
#        58/1    0.84497    0.84648 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 6.113128363265887 for eigenvalue
#  The estimated number of batches is 1441
#        59/1    0.84537    0.84646 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.963344366364657 for eigenvalue
#  The estimated number of batches is 1407
#        60/1    0.84015    0.84630 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.847631455810393 for eigenvalue
#  The estimated number of batches is 1388
#        61/1    0.83438    0.84601 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 6.267001619155457 for eigenvalue
#  The estimated number of batches is 1631
#        62/1    0.84438    0.84597 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 6.171340011607221 for eigenvalue
#  The estimated number of batches is 1620
#        63/1    0.83850    0.84579 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 6.113622977319987 for eigenvalue
#  The estimated number of batches is 1628
#        64/1    0.84386    0.84575 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 6.004750001971872 for eigenvalue
#  The estimated number of batches is 1607
#        65/1    0.84922    0.84583 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.931489628860006 for eigenvalue
#  The estimated number of batches is 1604
#        66/1    0.84354    0.84578 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.801760421629494 for eigenvalue
#  The estimated number of batches is 1569
#        67/1    0.85447    0.84596 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.564356161579554 for eigenvalue
#  The estimated number of batches is 1476
#        68/1    0.85168    0.84608 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.503566415720479 for eigenvalue
#  The estimated number of batches is 1474
#        69/1    0.85119    0.84619 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.3742829985796465 for eigenvalue
#  The estimated number of batches is 1436
#        70/1    0.84859    0.84623 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.2462361189949105 for eigenvalue
#  The estimated number of batches is 1397
#        71/1    0.83771    0.84607 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.222867720116258 for eigenvalue
#  The estimated number of batches is 1412
#        72/1    0.83445    0.84584 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.174551070285804 for eigenvalue
#  The estimated number of batches is 1413
#        73/1    0.84783    0.84588 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.05815269387506 for eigenvalue
#  The estimated number of batches is 1377
#        74/1    0.84032    0.84578 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.044383336053341 for eigenvalue
#  The estimated number of batches is 1395
#        75/1    0.84233    0.84572 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.990837234236982 for eigenvalue
#  The estimated number of batches is 1390
#        76/1    0.85059    0.84580 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.90188373565373 for eigenvalue
#  The estimated number of batches is 1366
#        77/1    0.84902    0.84586 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.915561631181285 for eigenvalue
#  The estimated number of batches is 1398
#        78/1    0.84839    0.84590 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.911186780014446 for eigenvalue
#  The estimated number of batches is 1419
#        79/1    0.85175    0.84600 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.808034474327254 for eigenvalue
#  The estimated number of batches is 1384
#        80/1    0.84362    0.84596 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.716598455455698 for eigenvalue
#  The estimated number of batches is 1355
#        81/1    0.83615    0.84580 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.6889125350678595 for eigenvalue
#  The estimated number of batches is 1362
#        82/1    0.84303    0.84576 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.6476583263894895 for eigenvalue
#  The estimated number of batches is 1360
#        83/1    0.84409    0.84573 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.5880320673187756 for eigenvalue
#  The estimated number of batches is 1347
#        84/1    0.84426    0.84571 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.559204954129318 for eigenvalue
#  The estimated number of batches is 1351
#        85/1    0.84327    0.84567 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.503932783410436 for eigenvalue
#  The estimated number of batches is 1339
#        86/1    0.83804    0.84555 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.6257378157953095 for eigenvalue
#  The estimated number of batches is 1433
#        87/1    0.85175    0.84565 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.542758685787512 for eigenvalue
#  The estimated number of batches is 1403
#        88/1    0.84805    0.84568 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.504735991782282 for eigenvalue
#  The estimated number of batches is 1400
#        89/1    0.84172    0.84562 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.45782731364198 for eigenvalue
#  The estimated number of batches is 1392
#        90/1    0.84761    0.84565 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.429339080067716 for eigenvalue
#  The estimated number of batches is 1394
#        91/1    0.85049    0.84572 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.343805736159744 for eigenvalue
#  The estimated number of batches is 1360
#        92/1    0.83927    0.84563 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.297711085671877 for eigenvalue
#  The estimated number of batches is 1350
#        93/1    0.83948    0.84555 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.241264824814277 for eigenvalue
#  The estimated number of batches is 1334
#        94/1    0.85045    0.84561 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.2336414770330215 for eigenvalue
#  The estimated number of batches is 1347
#        95/1    0.84484    0.84560 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.214896920948364 for eigenvalue
#  The estimated number of batches is 1353
#        96/1    0.83935    0.84552 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.205206621309889 for eigenvalue
#  The estimated number of batches is 1364
#        97/1    0.84352    0.84550 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.245818818323567 for eigenvalue
#  The estimated number of batches is 1409
#        98/1    0.86495    0.84574 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.375781031007839 for eigenvalue
#  The estimated number of batches is 1514
#        99/1    0.84793    0.84577 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.346707101857456 for eigenvalue
#  The estimated number of batches is 1513
#       100/1    0.84639    0.84578 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.284924778957019 for eigenvalue
#  The estimated number of batches is 1489
#       101/1    0.85720    0.84592 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.428056861549662 for eigenvalue
#  The estimated number of batches is 1609
#       102/1    0.85598    0.84604 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.543651377853677 for eigenvalue
#  The estimated number of batches is 1713
#       103/1    0.84377    0.84602 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.479214913445261 for eigenvalue
#  The estimated number of batches is 1686
#       104/1    0.84984    0.84606 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.425210561973055 for eigenvalue
#  The estimated number of batches is 1665
#       105/1    0.84930    0.84610 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.372334380710241 for eigenvalue
#  The estimated number of batches is 1645
#       106/1    0.84887    0.84613 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.311109032962898 for eigenvalue
#  The estimated number of batches is 1619
#       107/1    0.84562    0.84613 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.271374761535908 for eigenvalue
#  The estimated number of batches is 1608
#       108/1    0.85418    0.84622 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.230316478892517 for eigenvalue
#  The estimated number of batches is 1595
#       109/1    0.84631    0.84622 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.175823222538441 for eigenvalue
#  The estimated number of batches is 1572
#       110/1    0.84226    0.84617 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.145279035966984 for eigenvalue
#  The estimated number of batches is 1567
#       111/1    0.85649    0.84629 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.177924581198974 for eigenvalue
#  The estimated number of batches is 1609
#       112/1    0.85377    0.84637 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.166213384288102 for eigenvalue
#  The estimated number of batches is 1617
#       113/1    0.85062    0.84642 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.113529214361489 for eigenvalue
#  The estimated number of batches is 1594
#       114/1    0.85297    0.84648 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.2031749640005645 for eigenvalue
#  The estimated number of batches is 1681
#       115/1    0.84765    0.84650 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.160924349374119 for eigenvalue
#  The estimated number of batches is 1665
#       116/1    0.84713    0.84650 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.119153323280512 for eigenvalue
#  The estimated number of batches is 1649
#       117/1    0.84054    0.84644 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.08098695332601 for eigenvalue
#  The estimated number of batches is 1636
#       118/1    0.84786    0.84646 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.04096617081148 for eigenvalue
#  The estimated number of batches is 1621
#       119/1    0.84677    0.84646 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.004590058836191 for eigenvalue
#  The estimated number of batches is 1608
#       120/1    0.85565    0.84655 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.979343195112303 for eigenvalue
#  The estimated number of batches is 1604
#       121/1    0.84386    0.84653 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9442029358373776 for eigenvalue
#  The estimated number of batches is 1592
#       122/1    0.85452    0.84660 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.034399927864803 for eigenvalue
#  The estimated number of batches is 1681
#       123/1    0.85290    0.84666 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.99239239622347 for eigenvalue
#  The estimated number of batches is 1662
#       124/1    0.84926    0.84669 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.955083243678043 for eigenvalue
#  The estimated number of batches is 1647
#       125/1    0.84927    0.84671 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9170748420181334 for eigenvalue
#  The estimated number of batches is 1632
#       126/1    0.84467    0.84669 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8814283144507074 for eigenvalue
#  The estimated number of batches is 1617
#       127/1    0.84909    0.84672 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.843065607983925 for eigenvalue
#  The estimated number of batches is 1601
#       128/1    0.83476    0.84661 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.870969684673377 for eigenvalue
#  The estimated number of batches is 1639
#       129/1    0.84726    0.84661 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.834579178039624 for eigenvalue
#  The estimated number of batches is 1623
#       130/1    0.84235    0.84657 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8024716320701266 for eigenvalue
#  The estimated number of batches is 1611
#       131/1    0.85485    0.84665 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.7994369412954283 for eigenvalue
#  The estimated number of batches is 1623
#       132/1    0.84475    0.84663 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7768751400459943 for eigenvalue
#  The estimated number of batches is 1618
#       133/1    0.84230    0.84659 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7614181633245773 for eigenvalue
#  The estimated number of batches is 1619
#       134/1    0.84986    0.84662 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7505361377616255 for eigenvalue
#  The estimated number of batches is 1624
#       135/1    0.85395    0.84669 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.717935729092076 for eigenvalue
#  The estimated number of batches is 1610
#       136/1    0.85042    0.84672 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.7279889088546927 for eigenvalue
#  The estimated number of batches is 1633
#       137/1    0.83820    0.84664 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.7033117000469096 for eigenvalue
#  The estimated number of batches is 1625
#       138/1    0.84253    0.84661 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.676615437204091 for eigenvalue
#  The estimated number of batches is 1616
#       139/1    0.84139    0.84657 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.659481952747285 for eigenvalue
#  The estimated number of batches is 1614
#       140/1    0.84211    0.84653 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6414585759529263 for eigenvalue
#  The estimated number of batches is 1612
#       141/1    0.85628    0.84661 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6802508155624745 for eigenvalue
#  The estimated number of batches is 1659
#       142/1    0.84983    0.84664 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.70147485968762 for eigenvalue
#  The estimated number of batches is 1692
#       143/1    0.84981    0.84666 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.671459653153906 for eigenvalue
#  The estimated number of batches is 1678
#       144/1    0.84963    0.84669 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6463521204324767 for eigenvalue
#  The estimated number of batches is 1669
#       145/1    0.85346    0.84674 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6178053238688714 for eigenvalue
#  The estimated number of batches is 1657
#       146/1    0.84600    0.84673 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5943506448084204 for eigenvalue
#  The estimated number of batches is 1648
#       147/1    0.84697    0.84674 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.565079149302398 for eigenvalue
#  The estimated number of batches is 1635
#       148/1    0.84251    0.84670 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.544567172496717 for eigenvalue
#  The estimated number of batches is 1629
#       149/1    0.84452    0.84669 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5208327644776602 for eigenvalue
#  The estimated number of batches is 1620
#       150/1    0.83877    0.84663 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.525219563575517 for eigenvalue
#  The estimated number of batches is 1636
#       151/1    0.85192    0.84667 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.51788450457366 for eigenvalue
#  The estimated number of batches is 1642
#       152/1    0.84633    0.84666 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.505004575337328 for eigenvalue
#  The estimated number of batches is 1642
#       153/1    0.85174    0.84670 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.490002732675928 for eigenvalue
#  The estimated number of batches is 1640
#       154/1    0.84776    0.84671 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.463793677543339 for eigenvalue
#  The estimated number of batches is 1628
#       155/1    0.84453    0.84669 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.440039753250903 for eigenvalue
#  The estimated number of batches is 1618
#       156/1    0.84675    0.84669 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.41472586415784 for eigenvalue
#  The estimated number of batches is 1606
#       157/1    0.84280    0.84666 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3948565941718165 for eigenvalue
#  The estimated number of batches is 1599
#       158/1    0.85024    0.84669 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.4126409904786605 for eigenvalue
#  The estimated number of batches is 1628
#       159/1    0.85414    0.84674 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3953724764562625 for eigenvalue
#  The estimated number of batches is 1623
#       160/1    0.84609    0.84674 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.371743149106742 for eigenvalue
#  The estimated number of batches is 1612
#       161/1    0.84723    0.84674 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3486934802239143 for eigenvalue
#  The estimated number of batches is 1602
#       162/1    0.84507    0.84673 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3264239985788318 for eigenvalue
#  The estimated number of batches is 1592
#       163/1    0.84885    0.84675 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3036094219664136 for eigenvalue
#  The estimated number of batches is 1581
#       164/1    0.84392    0.84673 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2833080803504595 for eigenvalue
#  The estimated number of batches is 1573
#       165/1    0.84888    0.84674 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.267123460359493 for eigenvalue
#  The estimated number of batches is 1568
#       166/1    0.85234    0.84678 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2431972702495275 for eigenvalue
#  The estimated number of batches is 1556
#       167/1    0.85299    0.84682 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.221208505165088 for eigenvalue
#  The estimated number of batches is 1546
#       168/1    0.84371    0.84680 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.202670863382278 for eigenvalue
#  The estimated number of batches is 1539
#       169/1    0.84429    0.84678 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1858797997761874 for eigenvalue
#  The estimated number of batches is 1533
#       170/1    0.85030    0.84681 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.162197698677318 for eigenvalue
#  The estimated number of batches is 1520
#       171/1    0.85367    0.84685 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1536657216458086 for eigenvalue
#  The estimated number of batches is 1522
#       172/1    0.84724    0.84686 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1353067860853607 for eigenvalue
#  The estimated number of batches is 1515
#       173/1    0.84774    0.84686 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1137561810755976 for eigenvalue
#  The estimated number of batches is 1504
#       174/1    0.85520    0.84692 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1009788726841347 for eigenvalue
#  The estimated number of batches is 1501
#       175/1    0.85253    0.84695 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0875694269918452 for eigenvalue
#  The estimated number of batches is 1498
#       176/1    0.85216    0.84699 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.072465518980389 for eigenvalue
#  The estimated number of batches is 1493
#       177/1    0.84548    0.84698 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.079651372922712 for eigenvalue
#  The estimated number of batches is 1510
#       178/1    0.84486    0.84696 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0669427232693387 for eigenvalue
#  The estimated number of batches is 1507
#       179/1    0.85262    0.84700 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.050461816009594 for eigenvalue
#  The estimated number of batches is 1500
#       180/1    0.84772    0.84700 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0481841542197974 for eigenvalue
#  The estimated number of batches is 1507
#       181/1    0.85371    0.84704 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0385010939091046 for eigenvalue
#  The estimated number of batches is 1507
#       182/1    0.84859    0.84705 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0218540587875355 for eigenvalue
#  The estimated number of batches is 1500
#       183/1    0.84733    0.84706 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0170274148477634 for eigenvalue
#  The estimated number of batches is 1504
#       184/1    0.85543    0.84711 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0226725653500313 for eigenvalue
#  The estimated number of batches is 1519
#       185/1    0.85067    0.84713 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.002556243938768 for eigenvalue
#  The estimated number of batches is 1508
#       186/1    0.84654    0.84712 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9862103005373353 for eigenvalue
#  The estimated number of batches is 1501
#       187/1    0.85014    0.84714 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9669130330271667 for eigenvalue
#  The estimated number of batches is 1491
#       188/1    0.84839    0.84715 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9487847858419736 for eigenvalue
#  The estimated number of batches is 1481
#       189/1    0.84974    0.84717 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9362460710099167 for eigenvalue
#  The estimated number of batches is 1478
#       190/1    0.84334    0.84714 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9259877382483137 for eigenvalue
#  The estimated number of batches is 1476
#       191/1    0.84069    0.84710 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9124161615039146 for eigenvalue
#  The estimated number of batches is 1471
#       192/1    0.84790    0.84711 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.896473778355849 for eigenvalue
#  The estimated number of batches is 1464
#       193/1    0.84360    0.84709 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8817979013578667 for eigenvalue
#  The estimated number of batches is 1457
#       194/1    0.85385    0.84713 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8660295591740548 for eigenvalue
#  The estimated number of batches is 1450
#       195/1    0.85373    0.84717 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8520294179409893 for eigenvalue
#  The estimated number of batches is 1444
#       196/1    0.84585    0.84716 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.846736845426287 for eigenvalue
#  The estimated number of batches is 1447
#       197/1    0.84791    0.84716 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.830336199848918 for eigenvalue
#  The estimated number of batches is 1438
#       198/1    0.84604    0.84716 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.814718754536514 for eigenvalue
#  The estimated number of batches is 1431
#       199/1    0.84653    0.84715 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8030372919791744 for eigenvalue
#  The estimated number of batches is 1427
#       200/1    0.84606    0.84715 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.78792715973967 for eigenvalue
#  The estimated number of batches is 1420
#       201/1    0.85343    0.84718 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8091490653352187 for eigenvalue
#  The estimated number of batches is 1449
#       202/1    0.85095    0.84720 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.831003602151436 for eigenvalue
#  The estimated number of batches is 1479
#       203/1    0.85130    0.84722 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.82834110559114 for eigenvalue
#  The estimated number of batches is 1484
#       204/1    0.84554    0.84722 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.815047357228539 for eigenvalue
#  The estimated number of batches is 1479
#       205/1    0.84485    0.84720 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.801670226843358 for eigenvalue
#  The estimated number of batches is 1473
#       206/1    0.84677    0.84720 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.7913005821532013 for eigenvalue
#  The estimated number of batches is 1470
#       207/1    0.84498    0.84719 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7831174812086488 for eigenvalue
#  The estimated number of batches is 1469
#       208/1    0.85014    0.84720 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7917835344119815 for eigenvalue
#  The estimated number of batches is 1486
#       209/1    0.83968    0.84716 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7888137438551133 for eigenvalue
#  The estimated number of batches is 1490
#       210/1    0.84362    0.84715 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.775576077285973 for eigenvalue
#  The estimated number of batches is 1484
#       211/1    0.84624    0.84714 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.761031102519546 for eigenvalue
#  The estimated number of batches is 1477
#       212/1    0.85501    0.84718 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.748574429927957 for eigenvalue
#  The estimated number of batches is 1471
#       213/1    0.85054    0.84720 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7409145152308323 for eigenvalue
#  The estimated number of batches is 1470
#       214/1    0.85186    0.84722 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.725626875578394 for eigenvalue
#  The estimated number of batches is 1462
#       215/1    0.85386    0.84726 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7151205668744076 for eigenvalue
#  The estimated number of batches is 1458
#       216/1    0.85199    0.84728 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7076212548642657 for eigenvalue
#  The estimated number of batches is 1457
#       217/1    0.84922    0.84729 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7036814359593366 for eigenvalue
#  The estimated number of batches is 1461
#       218/1    0.85457    0.84733 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.700051454491219 for eigenvalue
#  The estimated number of batches is 1464
#       219/1    0.85012    0.84734 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.68642158972118 for eigenvalue
#  The estimated number of batches is 1457
#       220/1    0.85477    0.84738 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.712003538158593 for eigenvalue
#  The estimated number of batches is 1491
#       221/1    0.84590    0.84737 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.698324615130298 for eigenvalue
#  The estimated number of batches is 1484
#       222/1    0.85993    0.84743 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.701222895487064 for eigenvalue
#  The estimated number of batches is 1494
#       223/1    0.85185    0.84746 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.707399341757044 for eigenvalue
#  The estimated number of batches is 1508
#       224/1    0.85073    0.84747 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6921188292168794 for eigenvalue
#  The estimated number of batches is 1499
#       225/1    0.85406    0.84750 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6784243799063194 for eigenvalue
#  The estimated number of batches is 1491
#       226/1    0.83766    0.84746 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6859434237858046 for eigenvalue
#  The estimated number of batches is 1507
#       227/1    0.84698    0.84745 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6750869734242175 for eigenvalue
#  The estimated number of batches is 1502
#       228/1    0.84753    0.84745 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6630941050414574 for eigenvalue
#  The estimated number of batches is 1496
#       229/1    0.83984    0.84742 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6572079789079606 for eigenvalue
#  The estimated number of batches is 1496
#       230/1    0.84749    0.84742 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.644147297290166 for eigenvalue
#  The estimated number of batches is 1489
#       231/1    0.84348    0.84740 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6385025471539887 for eigenvalue
#  The estimated number of batches is 1489
#       232/1    0.85627    0.84744 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6242950620213255 for eigenvalue
#  The estimated number of batches is 1481
#       233/1    0.83718    0.84739 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.634751337758607 for eigenvalue
#  The estimated number of batches is 1499
#       234/1    0.84986    0.84740 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.625009299067127 for eigenvalue
#  The estimated number of batches is 1495
#       235/1    0.84937    0.84741 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6135326509036383 for eigenvalue
#  The estimated number of batches is 1489
#       236/1    0.85482    0.84745 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6102919164541154 for eigenvalue
#  The estimated number of batches is 1492
#       237/1    0.84250    0.84743 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.622907698207753 for eigenvalue
#  The estimated number of batches is 1513
#       238/1    0.84705    0.84742 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.610705115540866 for eigenvalue
#  The estimated number of batches is 1506
#       239/1    0.85123    0.84744 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5980537786462405 for eigenvalue
#  The estimated number of batches is 1499
#       240/1    0.84710    0.84744 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.586847613635415 for eigenvalue
#  The estimated number of batches is 1493
#       241/1    0.85446    0.84747 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.575597919853417 for eigenvalue
#  The estimated number of batches is 1487
#       242/1    0.84352    0.84745 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.565359405077002 for eigenvalue
#  The estimated number of batches is 1481
#       243/1    0.84660    0.84745 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.553383543314632 for eigenvalue
#  The estimated number of batches is 1474
#       244/1    0.84834    0.84745 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.543421564667241 for eigenvalue
#  The estimated number of batches is 1470
#       245/1    0.84849    0.84746 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.533201712368916 for eigenvalue
#  The estimated number of batches is 1464
#       246/1    0.84786    0.84746 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.521845984914727 for eigenvalue
#  The estimated number of batches is 1458
#       247/1    0.84805    0.84746 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5123767745584815 for eigenvalue
#  The estimated number of batches is 1453
#       248/1    0.85228    0.84748 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.50780658356456 for eigenvalue
#  The estimated number of batches is 1454
#       249/1    0.84038    0.84745 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.497397411406141 for eigenvalue
#  The estimated number of batches is 1449
#       250/1    0.84768    0.84745 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4865862513165027 for eigenvalue
#  The estimated number of batches is 1443
#       251/1    0.85004    0.84747 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.478525461580472 for eigenvalue
#  The estimated number of batches is 1440
#       252/1    0.85006    0.84748 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.468653779081009 for eigenvalue
#  The estimated number of batches is 1434
#       253/1    0.84761    0.84748 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.459536243329227 for eigenvalue
#  The estimated number of batches is 1430
#       254/1    0.84544    0.84747 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.450651043466788 for eigenvalue
#  The estimated number of batches is 1426
#       255/1    0.85443    0.84750 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.452255890794349 for eigenvalue
#  The estimated number of batches is 1434
#       256/1    0.85765    0.84754 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.457050963936082 for eigenvalue
#  The estimated number of batches is 1445
#       257/1    0.84552    0.84753 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4468689792696385 for eigenvalue
#  The estimated number of batches is 1439
#       258/1    0.84061    0.84750 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4446869172847188 for eigenvalue
#  The estimated number of batches is 1443
#       259/1    0.84236    0.84748 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.435808843693909 for eigenvalue
#  The estimated number of batches is 1439
#       260/1    0.85076    0.84750 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4307988329586254 for eigenvalue
#  The estimated number of batches is 1439
#       261/1    0.84971    0.84750 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4208119114209268 for eigenvalue
#  The estimated number of batches is 1433
#       262/1    0.85078    0.84752 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4099042932257473 for eigenvalue
#  The estimated number of batches is 1426
#       263/1    0.85287    0.84754 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.406886102940835 for eigenvalue
#  The estimated number of batches is 1428
#       264/1    0.84592    0.84753 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3967841858266326 for eigenvalue
#  The estimated number of batches is 1422
#       265/1    0.83830    0.84750 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.389585159967814 for eigenvalue
#  The estimated number of batches is 1419
#       266/1    0.84316    0.84748 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3835540194642273 for eigenvalue
#  The estimated number of batches is 1418
#       267/1    0.86135    0.84753 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.381024877834018 for eigenvalue
#  The estimated number of batches is 1421
#       268/1    0.84787    0.84754 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3733936843152215 for eigenvalue
#  The estimated number of batches is 1417
#       269/1    0.84624    0.84753 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.363698754444422 for eigenvalue
#  The estimated number of batches is 1412
#       270/1    0.84761    0.84753 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3548932997901977 for eigenvalue
#  The estimated number of batches is 1407
#       271/1    0.85485    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.350506548481314 for eigenvalue
#  The estimated number of batches is 1407
#       272/1    0.84435    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3534976751776417 for eigenvalue
#  The estimated number of batches is 1416
#       273/1    0.85040    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3441941912549566 for eigenvalue
#  The estimated number of batches is 1411
#       274/1    0.84665    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.336099163546925 for eigenvalue
#  The estimated number of batches is 1407
#       275/1    0.84969    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3277485667217332 for eigenvalue
#  The estimated number of batches is 1402
#       276/1    0.84322    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3216970715263416 for eigenvalue
#  The estimated number of batches is 1400
#       277/1    0.85940    0.84759 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.327959004096825 for eigenvalue
#  The estimated number of batches is 1413
#       278/1    0.84157    0.84757 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3273212023284384 for eigenvalue
#  The estimated number of batches is 1418
#       279/1    0.84448    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.318686029698125 for eigenvalue
#  The estimated number of batches is 1413
#       280/1    0.84316    0.84754 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.309909276759913 for eigenvalue
#  The estimated number of batches is 1408
#       281/1    0.84070    0.84751 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.305644542938973 for eigenvalue
#  The estimated number of batches is 1408
#       282/1    0.84773    0.84751 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.297152460256028 for eigenvalue
#  The estimated number of batches is 1403
#       283/1    0.84626    0.84751 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.291375412152773 for eigenvalue
#  The estimated number of batches is 1401
#       284/1    0.85098    0.84752 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2832384455183536 for eigenvalue
#  The estimated number of batches is 1397
#       285/1    0.84561    0.84752 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.275437697318846 for eigenvalue
#  The estimated number of batches is 1393
#       286/1    0.85159    0.84753 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.268164922795173 for eigenvalue
#  The estimated number of batches is 1389
#       287/1    0.85903    0.84757 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2675453059664514 for eigenvalue
#  The estimated number of batches is 1393
#       288/1    0.84731    0.84757 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2597377252048245 for eigenvalue
# ...
#  Triggers unsatisfied, max unc./thresh. is 1.5721123611981551 for eigenvalue
#  The estimated number of batches is 1449
#       599/1    0.84632    0.84770 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5701368655870565 for eigenvalue
#  The estimated number of batches is 1448
#       600/1    0.84515    0.84770 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5681351094808833 for eigenvalue
#  The estimated number of batches is 1447
#       601/1    0.84286    0.84769 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.565621483758412 for eigenvalue
#  The estimated number of batches is 1445
#       602/1    0.85193    0.84770 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.563134620699418 for eigenvalue
#  The estimated number of batches is 1443
#       603/1    0.83919    0.84768 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5635724905164958 for eigenvalue
#  The estimated number of batches is 1446
#       604/1    0.85323    0.84769 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5607760326528064 for eigenvalue
#  The estimated number of batches is 1443
#       605/1    0.85368    0.84770 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5581390240897508 for eigenvalue
#  The estimated number of batches is 1441
#       606/1    0.84209    0.84769 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5562737740520163 for eigenvalue
#  The estimated number of batches is 1440
#       607/1    0.85411    0.84770 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5549024355202212 for eigenvalue
#  The estimated number of batches is 1440
#       608/1    0.84989    0.84771 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.552266478059045 for eigenvalue
#  The estimated number of batches is 1437
#       609/1    0.85157    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5498165554176493 for eigenvalue
#  The estimated number of batches is 1435
#       610/1    0.85550    0.84773 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.554949694726379 for eigenvalue
#  The estimated number of batches is 1447
#       611/1    0.84661    0.84773 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5526757191236664 for eigenvalue
#  The estimated number of batches is 1445
#       612/1    0.84347    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5507728244834424 for eigenvalue
#  The estimated number of batches is 1444
#       613/1    0.84830    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.548316150932261 for eigenvalue
#  The estimated number of batches is 1442
#       614/1    0.84309    0.84771 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.545958710274084 for eigenvalue
#  The estimated number of batches is 1440
#       615/1    0.85249    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5446355667949905 for eigenvalue
#  The estimated number of batches is 1440
#       616/1    0.85397    0.84773 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5419838335337472 for eigenvalue
#  The estimated number of batches is 1438
#       617/1    0.85308    0.84774 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5425206355814305 for eigenvalue
#  The estimated number of batches is 1441
#       618/1    0.84946    0.84774 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5398423098969038 for eigenvalue
#  The estimated number of batches is 1438
#       619/1    0.84743    0.84774 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5381421325961429 for eigenvalue
#  The estimated number of batches is 1438
#       620/1    0.84133    0.84773 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5357000334808473 for eigenvalue
#  The estimated number of batches is 1436
#       621/1    0.84603    0.84773 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5338458379814615 for eigenvalue
#  The estimated number of batches is 1434
#       622/1    0.84781    0.84773 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5315793021381652 for eigenvalue
#  The estimated number of batches is 1433
#       623/1    0.84563    0.84773 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5290963966828557 for eigenvalue
#  The estimated number of batches is 1430
#       624/1    0.84625    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.527611998819498 for eigenvalue
#  The estimated number of batches is 1430
#       625/1    0.84385    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.526811591002787 for eigenvalue
#  The estimated number of batches is 1431
#       626/1    0.84918    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5242414782710272 for eigenvalue
#  The estimated number of batches is 1428
#       627/1    0.84571    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5219370360075426 for eigenvalue
#  The estimated number of batches is 1426
#       628/1    0.85000    0.84772 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5205747929730777 for eigenvalue
#  The estimated number of batches is 1426
#       629/1    0.84413    0.84771 +/- 0.00021
#  Triggers unsatisfied, max unc./thresh. is 1.5187736207742906 for eigenvalue
#  The estimated number of batches is 1425
#       630/1    0.84409    0.84771 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5166668135566281 for eigenvalue
#  The estimated number of batches is 1424
#       631/1    0.84988    0.84771 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5141325600670328 for eigenvalue
#  The estimated number of batches is 1421
#       632/1    0.84993    0.84771 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5127012034313798 for eigenvalue
#  The estimated number of batches is 1421
#       633/1    0.84614    0.84771 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5103991982540137 for eigenvalue
#  The estimated number of batches is 1419
#       634/1    0.85391    0.84772 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5085678050423514 for eigenvalue
#  The estimated number of batches is 1418
#       635/1    0.85279    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5060128147370844 for eigenvalue
#  The estimated number of batches is 1415
#       636/1    0.84760    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.50491614438628 for eigenvalue
#  The estimated number of batches is 1416
#       637/1    0.85170    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.502954238756507 for eigenvalue
#  The estimated number of batches is 1414
#       638/1    0.84486    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.5007388870195322 for eigenvalue
#  The estimated number of batches is 1412
#       639/1    0.84957    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4983257391348825 for eigenvalue
#  The estimated number of batches is 1410
#       640/1    0.84967    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4967065513702298 for eigenvalue
#  The estimated number of batches is 1409
#       641/1    0.84448    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4944290721671185 for eigenvalue
#  The estimated number of batches is 1407
#       642/1    0.84036    0.84772 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4949111566599438 for eigenvalue
#  The estimated number of batches is 1411
#       643/1    0.85147    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4944375784739565 for eigenvalue
#  The estimated number of batches is 1412
#       644/1    0.84970    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4920146561188623 for eigenvalue
#  The estimated number of batches is 1410
#       645/1    0.84379    0.84772 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.490009252007896 for eigenvalue
#  The estimated number of batches is 1408
#       646/1    0.84672    0.84772 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.488291274022835 for eigenvalue
#  The estimated number of batches is 1407
#       647/1    0.84648    0.84772 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.486544802659165 for eigenvalue
#  The estimated number of batches is 1406
#       648/1    0.85177    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4870867302987574 for eigenvalue
#  The estimated number of batches is 1409
#       649/1    0.84955    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.486905694499106 for eigenvalue
#  The estimated number of batches is 1411
#       650/1    0.85285    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4847954447473308 for eigenvalue
#  The estimated number of batches is 1409
#       651/1    0.84855    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4824139162370806 for eigenvalue
#  The estimated number of batches is 1407
#       652/1    0.84479    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4800739880561191 for eigenvalue
#  The estimated number of batches is 1405
#       653/1    0.84194    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4782988679133913 for eigenvalue
#  The estimated number of batches is 1404
#       654/1    0.84791    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4761566313765235 for eigenvalue
#  The estimated number of batches is 1402
#       655/1    0.84772    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4740329413737019 for eigenvalue
#  The estimated number of batches is 1400
#       656/1    0.85061    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4748876724674596 for eigenvalue
#  The estimated number of batches is 1404
#       657/1    0.84957    0.84773 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.473824162648245 for eigenvalue
#  The estimated number of batches is 1404
#       658/1    0.84977    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4716100632149138 for eigenvalue
#  The estimated number of batches is 1402
#       659/1    0.84715    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4693428841035892 for eigenvalue
#  The estimated number of batches is 1400
#       660/1    0.85121    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.468066529829471 for eigenvalue
#  The estimated number of batches is 1400
#       661/1    0.84941    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4670465897776084 for eigenvalue
#  The estimated number of batches is 1400
#       662/1    0.85411    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.465776604565888 for eigenvalue
#  The estimated number of batches is 1400
#       663/1    0.84762    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4634974953099078 for eigenvalue
#  The estimated number of batches is 1398
#       664/1    0.84286    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4614970379944423 for eigenvalue
#  The estimated number of batches is 1396
#       665/1    0.84930    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4596879501170184 for eigenvalue
#  The estimated number of batches is 1395
#       666/1    0.84686    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.457623134987724 for eigenvalue
#  The estimated number of batches is 1393
#       667/1    0.85196    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4552637668127515 for eigenvalue
#  The estimated number of batches is 1391
#       668/1    0.84631    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.45323117476083 for eigenvalue
#  The estimated number of batches is 1389
#       669/1    0.84996    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.451260003866617 for eigenvalue
#  The estimated number of batches is 1387
#       670/1    0.85217    0.84776 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4505761260294878 for eigenvalue
#  The estimated number of batches is 1388
#       671/1    0.85287    0.84777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.448393645173903 for eigenvalue
#  The estimated number of batches is 1386
#       672/1    0.84305    0.84776 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4477385398904625 for eigenvalue
#  The estimated number of batches is 1387
#       673/1    0.83441    0.84774 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.447434250780343 for eigenvalue
#  The estimated number of batches is 1389
#       674/1    0.85895    0.84776 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4461976076713454 for eigenvalue
#  The estimated number of batches is 1388
#       675/1    0.84632    0.84776 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.444702607483727 for eigenvalue
#  The estimated number of batches is 1388
#       676/1    0.84752    0.84776 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4425670098183914 for eigenvalue
#  The estimated number of batches is 1386
#       677/1    0.84403    0.84775 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.440713843945495 for eigenvalue
#  The estimated number of batches is 1384
#       678/1    0.84715    0.84775 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.438547498096616 for eigenvalue
#  The estimated number of batches is 1382
#       679/1    0.85116    0.84775 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4376099687902528 for eigenvalue
#  The estimated number of batches is 1382
#       680/1    0.85964    0.84777 +/- 0.00020
#  Triggers unsatisfied, max unc./thresh. is 1.4354588136102497 for eigenvalue
#  The estimated number of batches is 1380
#       681/1    0.84734    0.84777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4332932010350428 for eigenvalue
#  The estimated number of batches is 1378
#       682/1    0.84531    0.84777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.433274761796572 for eigenvalue
#  The estimated number of batches is 1380
#       683/1    0.85561    0.84778 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4316325328974173 for eigenvalue
#  The estimated number of batches is 1379
#       684/1    0.84246    0.84777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.431388242408367 for eigenvalue
#  The estimated number of batches is 1381
#       685/1    0.84355    0.84777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4293051813111262 for eigenvalue
#  The estimated number of batches is 1379
#       686/1    0.85976    0.84778 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4359705626672263 for eigenvalue
#  The estimated number of batches is 1394
#       687/1    0.84170    0.84777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4378651818449788 for eigenvalue
#  The estimated number of batches is 1399
#       688/1    0.85281    0.84778 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4356559072924888 for eigenvalue
#  The estimated number of batches is 1397
#       689/1    0.85187    0.84779 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4334868930058582 for eigenvalue
#  The estimated number of batches is 1395
#       690/1    0.83872    0.84777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4326090221682888 for eigenvalue
#  The estimated number of batches is 1396
#       691/1    0.84930    0.84778 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.432527570692211 for eigenvalue
#  The estimated number of batches is 1397
#       692/1    0.84374    0.84777 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4316611183511054 for eigenvalue
#  The estimated number of batches is 1398
#       693/1    0.84240    0.84776 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4318750079434912 for eigenvalue
#  The estimated number of batches is 1400
#       694/1    0.84154    0.84775 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4298849147684034 for eigenvalue
#  The estimated number of batches is 1399
#       695/1    0.85056    0.84776 +/- 0.00019
#  Triggers unsatisfied, max unc./thresh. is 1.4291731441727251 for eigenvalue
#  The estimated number of batches is 1399
