# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600

AIC_mat = openmc.Material(name="AIC_mat")
AIC_mat.add_nuclide('Ag107',2.36159E-02, 'ao')
AIC_mat.add_nuclide('Ag109',2.19403E-02, 'ao')
AIC_mat.add_nuclide('Cd106',3.41523E-05, 'ao')
AIC_mat.add_nuclide('Cd108',2.43165E-05, 'ao')
AIC_mat.add_nuclide('Cd110',3.41250E-04, 'ao')
AIC_mat.add_nuclide('Cd111',3.49720E-04, 'ao')
AIC_mat.add_nuclide('Cd112',6.59276E-04, 'ao')
AIC_mat.add_nuclide('Cd113',3.33873E-04, 'ao')
AIC_mat.add_nuclide('Cd114',7.84957E-04, 'ao')
AIC_mat.add_nuclide('Cd116',2.04641E-04, 'ao')
AIC_mat.add_nuclide('In113',3.44262E-04, 'ao')
AIC_mat.add_nuclide('In115',7.68050E-03, 'ao')

AIC_mat.set_density('g/cm3', 10.2 )
AIC_mat.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304,AIC_mat]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/endfb71/endfb-vii.1-hdf5/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create AIC tube

# %%
def AIC_pin(family):
    AIC_outer_radius = openmc.ZCylinder(r=0.382)
    clad_inner_radius = openmc.ZCylinder(r=0.386)
    clad_outer_radius = openmc.ZCylinder(r=0.484)
    tube_inner_radius = openmc.ZCylinder(r=0.561)
    tube_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    AIC_region = -AIC_outer_radius
    gap_region = +AIC_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    guide_region = - tube_outer_radius & + tube_inner_radius
    water_region = +left & -right & +bottom & -top & +tube_outer_radius | +clad_outer_radius & - tube_inner_radius

    AIC = openmc.Cell(name='AIC'+'_'+family)
    AIC.fill = AIC_mat
    AIC.region = AIC_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = SS304
    clad.region = clad_region
    guide = openmc.Cell(name='guide'+'_'+family)
    guide.fill = zirconium
    guide.region = guide_region
    
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(AIC,guide, gap, clad, moderator))
    return(u,AIC,gap,clad,moderator,guide)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
AICT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]

AICT_left=[]
AICT_full=[]
for X in AICT:
    AICT_left.append((X[0],X[1]))
    AICT_left.append((X[0],16-X[1]))
for X in AICT_left:
    AICT_full.append((X[0],X[1]))
    AICT_full.append((16-X[0],X[1]))    
AICT_full = list(set(AICT_full))

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
aic_1_family=AIC_pin('aic_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in AICT_full : 
            A[ix][iy]=aic_1_family[0]  
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]            
        else:
            A[ix][iy]=pincell_1_family[0]  
            
         
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water


rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=476.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=2.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=10.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-13 18:05:11
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading Ag107 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ag107.h5
#  Reading Ag109 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ag109.h5
#  Reading Cd106 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 600K
#  Reading Cd108 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd108.h5
#  Reading Cd110 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd110.h5
#  Reading Cd111 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd111.h5
#  Reading Cd112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd112.h5
#  Reading Cd113 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd113.h5
#  Reading Cd114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd114.h5
#  Reading Cd116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cd116.h5
#  Reading In113 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/In113.h5
#  Reading In115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/In115.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.85077
#         2/1    0.84566
#         3/1    0.85172
#         4/1    0.85233
#         5/1    0.84672
#         6/1    0.85379
#         7/1    0.85183
#         8/1    0.84438
#         9/1    0.85276
#        10/1    0.85162
#        11/1    0.85488
#        12/1    0.85089
#        13/1    0.84567
#        14/1    0.84716
#        15/1    0.84252
#        16/1    0.84886
#        17/1    0.85016
#        18/1    0.84673
#        19/1    0.84345
#        20/1    0.84370
#        21/1    0.84606
#        22/1    0.84339    0.84472 +/- 0.00134
#        23/1    0.84476    0.84474 +/- 0.00077
#        24/1    0.84058    0.84370 +/- 0.00117
#        25/1    0.85022    0.84500 +/- 0.00159
#        26/1    0.85128    0.84605 +/- 0.00167
#        27/1    0.84912    0.84649 +/- 0.00148
#        28/1    0.85002    0.84693 +/- 0.00135
#        29/1    0.85145    0.84743 +/- 0.00129
#        30/1    0.84523    0.84721 +/- 0.00118
#        31/1    0.83896    0.84646 +/- 0.00130
#        32/1    0.83795    0.84575 +/- 0.00139
#        33/1    0.84621    0.84579 +/- 0.00127
#        34/1    0.84107    0.84545 +/- 0.00123
#        35/1    0.85257    0.84593 +/- 0.00124
#        36/1    0.84109    0.84562 +/- 0.00120
#        37/1    0.84612    0.84565 +/- 0.00112
#        38/1    0.84409    0.84557 +/- 0.00106
#        39/1    0.84157    0.84536 +/- 0.00103
#        40/1    0.84282    0.84523 +/- 0.00098
#        41/1    0.85030    0.84547 +/- 0.00097
#        42/1    0.84859    0.84561 +/- 0.00093
#        43/1    0.85035    0.84582 +/- 0.00091
#        44/1    0.85129    0.84605 +/- 0.00090
#        45/1    0.84810    0.84613 +/- 0.00087
#        46/1    0.84330    0.84602 +/- 0.00084
#        47/1    0.85560    0.84637 +/- 0.00089
#        48/1    0.84785    0.84643 +/- 0.00086
#        49/1    0.84842    0.84650 +/- 0.00083
#        50/1    0.84587    0.84647 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.766797623510213 for eigenvalue
#  The estimated number of batches is 1394
#  Creating state point statepoint.00050.h5...
#        51/1    0.83730    0.84618 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 6.789029364434788 for eigenvalue
#  The estimated number of batches is 1449
#        52/1    0.85208    0.84636 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 6.641227064679127 for eigenvalue
#  The estimated number of batches is 1432
#        53/1    0.84903    0.84644 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 6.509181749580388 for eigenvalue
#  The estimated number of batches is 1419
#        54/1    0.85112    0.84658 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 6.451455067519714 for eigenvalue
#  The estimated number of batches is 1436
#        55/1    0.84596    0.84656 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 6.358567724160222 for eigenvalue
#  The estimated number of batches is 1436
#        56/1    0.84727    0.84658 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 6.457684025126112 for eigenvalue
#  The estimated number of batches is 1522
#        57/1    0.84444    0.84653 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 6.249437499159345 for eigenvalue
#  The estimated number of batches is 1466
#        58/1    0.84497    0.84648 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 6.113128363669168 for eigenvalue
#  The estimated number of batches is 1441
#        59/1    0.84537    0.84646 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.963344366499183 for eigenvalue
#  The estimated number of batches is 1407
#        60/1    0.84015    0.84630 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.847631456034852 for eigenvalue
#  The estimated number of batches is 1388
#        61/1    0.83438    0.84601 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 6.26700161900224 for eigenvalue
#  The estimated number of batches is 1631
#        62/1    0.84438    0.84597 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 6.171340011851951 for eigenvalue
#  The estimated number of batches is 1620
#        63/1    0.83850    0.84579 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 6.113622977483056 for eigenvalue
#  The estimated number of batches is 1628
#        64/1    0.84386    0.84575 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 6.004750002049858 for eigenvalue
#  The estimated number of batches is 1607
#        65/1    0.84922    0.84583 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.931489628773793 for eigenvalue
#  The estimated number of batches is 1604
#        66/1    0.84354    0.84578 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.801760421891377 for eigenvalue
#  The estimated number of batches is 1569
#        67/1    0.85447    0.84596 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.564356161630266 for eigenvalue
#  The estimated number of batches is 1476
#        68/1    0.85168    0.84608 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.503566415667258 for eigenvalue
#  The estimated number of batches is 1474
#        69/1    0.85119    0.84619 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.37428299881705 for eigenvalue
#  The estimated number of batches is 1436
#        70/1    0.84859    0.84623 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.246236118819712 for eigenvalue
#  The estimated number of batches is 1397
#        71/1    0.83771    0.84607 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.2228677201642695 for eigenvalue
#  The estimated number of batches is 1412
#        72/1    0.83445    0.84584 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.1745510703774205 for eigenvalue
#  The estimated number of batches is 1413
#        73/1    0.84783    0.84588 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.058152694042805 for eigenvalue
#  The estimated number of batches is 1377
#        74/1    0.84032    0.84578 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.044383336102106 for eigenvalue
#  The estimated number of batches is 1395
#        75/1    0.84233    0.84572 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.990837234347413 for eigenvalue
#  The estimated number of batches is 1390
#        76/1    0.85059    0.84580 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.901883735859017 for eigenvalue
#  The estimated number of batches is 1366
#        77/1    0.84902    0.84586 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.915561631300687 for eigenvalue
#  The estimated number of batches is 1398
#        78/1    0.84839    0.84590 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.91118678005912 for eigenvalue
#  The estimated number of batches is 1419
#        79/1    0.85175    0.84600 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.808034474285656 for eigenvalue
#  The estimated number of batches is 1384
#        80/1    0.84362    0.84596 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.716598455597334 for eigenvalue
#  The estimated number of batches is 1355
#        81/1    0.83615    0.84580 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.68891253508819 for eigenvalue
#  The estimated number of batches is 1362
#        82/1    0.84303    0.84576 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.647658326429743 for eigenvalue
#  The estimated number of batches is 1360
#        83/1    0.84409    0.84573 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.588032067468655 for eigenvalue
#  The estimated number of batches is 1347
#        84/1    0.84426    0.84571 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.559204954149948 for eigenvalue
#  The estimated number of batches is 1351
#        85/1    0.84327    0.84567 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.503932783446019 for eigenvalue
#  The estimated number of batches is 1339
#        86/1    0.83804    0.84555 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.625737815949417 for eigenvalue
#  The estimated number of batches is 1433
#        87/1    0.85175    0.84565 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.54275868583176 for eigenvalue
#  The estimated number of batches is 1403
#        88/1    0.84805    0.84568 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.50473599198379 for eigenvalue
#  The estimated number of batches is 1400
#        89/1    0.84172    0.84562 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.457827313720304 for eigenvalue
#  The estimated number of batches is 1392
#        90/1    0.84761    0.84565 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.429339080161847 for eigenvalue
#  The estimated number of batches is 1394
#        91/1    0.85049    0.84572 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.343805736145649 for eigenvalue
#  The estimated number of batches is 1360
#        92/1    0.83927    0.84563 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.297711085812606 for eigenvalue
#  The estimated number of batches is 1350
#        93/1    0.83948    0.84555 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.241264824859877 for eigenvalue
#  The estimated number of batches is 1334
#        94/1    0.85045    0.84561 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.233641477031284 for eigenvalue
#  The estimated number of batches is 1347
#        95/1    0.84484    0.84560 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.214896920881328 for eigenvalue
#  The estimated number of batches is 1353
#        96/1    0.83935    0.84552 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.205206621358996 for eigenvalue
#  The estimated number of batches is 1364
#        97/1    0.84352    0.84550 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.245818818435862 for eigenvalue
#  The estimated number of batches is 1409
#        98/1    0.86495    0.84574 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.375781031122889 for eigenvalue
#  The estimated number of batches is 1514
#        99/1    0.84793    0.84577 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.3467071017222825 for eigenvalue
#  The estimated number of batches is 1513
#       100/1    0.84639    0.84578 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.284924778980791 for eigenvalue
#  The estimated number of batches is 1489
#       101/1    0.85720    0.84592 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.428056861490443 for eigenvalue
#  The estimated number of batches is 1609
#       102/1    0.85598    0.84604 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.543651377874389 for eigenvalue
#  The estimated number of batches is 1713
#       103/1    0.84377    0.84602 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.479214913285409 for eigenvalue
#  The estimated number of batches is 1686
#       104/1    0.84984    0.84606 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.425210562069879 for eigenvalue
#  The estimated number of batches is 1665
#       105/1    0.84930    0.84610 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.372334380724973 for eigenvalue
#  The estimated number of batches is 1645
#       106/1    0.84887    0.84613 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.311109032971353 for eigenvalue
#  The estimated number of batches is 1619
#       107/1    0.84562    0.84613 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.271374761704056 for eigenvalue
#  The estimated number of batches is 1608
#       108/1    0.85418    0.84622 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.230316478824025 for eigenvalue
#  The estimated number of batches is 1595
#       109/1    0.84631    0.84622 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.175823222530184 for eigenvalue
#  The estimated number of batches is 1572
#       110/1    0.84226    0.84617 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.1452790358320994 for eigenvalue
#  The estimated number of batches is 1567
#       111/1    0.85649    0.84629 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.17792458120483 for eigenvalue
#  The estimated number of batches is 1609
#       112/1    0.85377    0.84637 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.1662133841388735 for eigenvalue
#  The estimated number of batches is 1617
#       113/1    0.85062    0.84642 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.1135292145015985 for eigenvalue
#  The estimated number of batches is 1594
#       114/1    0.85297    0.84648 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.203174963931347 for eigenvalue
#  The estimated number of batches is 1681
#       115/1    0.84765    0.84650 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.160924349376039 for eigenvalue
#  The estimated number of batches is 1665
#       116/1    0.84713    0.84650 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.119153323446328 for eigenvalue
#  The estimated number of batches is 1649
#       117/1    0.84054    0.84644 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.080986953320436 for eigenvalue
#  The estimated number of batches is 1636
#       118/1    0.84786    0.84646 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.040966170949337 for eigenvalue
#  The estimated number of batches is 1621
#       119/1    0.84677    0.84646 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.004590058963108 for eigenvalue
#  The estimated number of batches is 1608
#       120/1    0.85565    0.84655 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.979343195174206 for eigenvalue
#  The estimated number of batches is 1604
#       121/1    0.84386    0.84653 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9442029359608823 for eigenvalue
#  The estimated number of batches is 1592
#       122/1    0.85452    0.84660 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.034399927999825 for eigenvalue
#  The estimated number of batches is 1681
#       123/1    0.85290    0.84666 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9923923964247954 for eigenvalue
#  The estimated number of batches is 1662
#       124/1    0.84926    0.84669 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9550832435417287 for eigenvalue
#  The estimated number of batches is 1647
#       125/1    0.84927    0.84671 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.917074841657103 for eigenvalue
#  The estimated number of batches is 1632
#       126/1    0.84467    0.84669 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8814283144876787 for eigenvalue
#  The estimated number of batches is 1617
#       127/1    0.84909    0.84672 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.843065607955471 for eigenvalue
#  The estimated number of batches is 1601
#       128/1    0.83476    0.84661 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8709696846956785 for eigenvalue
#  The estimated number of batches is 1639
#       129/1    0.84726    0.84661 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8345791779389082 for eigenvalue
#  The estimated number of batches is 1623
#       130/1    0.84235    0.84657 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.8024716319098792 for eigenvalue
#  The estimated number of batches is 1611
#       131/1    0.85485    0.84665 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.7994369412605495 for eigenvalue
#  The estimated number of batches is 1623
#       132/1    0.84475    0.84663 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.776875139898355 for eigenvalue
#  The estimated number of batches is 1618
#       133/1    0.84230    0.84659 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.761418163404709 for eigenvalue
#  The estimated number of batches is 1619
#       134/1    0.84986    0.84662 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7505361376979818 for eigenvalue
#  The estimated number of batches is 1624
#       135/1    0.85395    0.84669 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7179357290683988 for eigenvalue
#  The estimated number of batches is 1610
#       136/1    0.85042    0.84672 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.727988908931566 for eigenvalue
#  The estimated number of batches is 1633
#       137/1    0.83820    0.84664 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.703311700119044 for eigenvalue
#  The estimated number of batches is 1625
#       138/1    0.84253    0.84661 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.676615436988046 for eigenvalue
#  The estimated number of batches is 1616
#       139/1    0.84139    0.84657 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6594819526819182 for eigenvalue
#  The estimated number of batches is 1614
#       140/1    0.84211    0.84653 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6414585758977815 for eigenvalue
#  The estimated number of batches is 1612
#       141/1    0.85628    0.84661 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6802508155091154 for eigenvalue
#  The estimated number of batches is 1659
#       142/1    0.84983    0.84664 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.701474859809636 for eigenvalue
#  The estimated number of batches is 1692
#       143/1    0.84981    0.84666 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.671459653017083 for eigenvalue
#  The estimated number of batches is 1678
#       144/1    0.84963    0.84669 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6463521203805707 for eigenvalue
#  The estimated number of batches is 1669
#       145/1    0.85346    0.84674 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6178053238599066 for eigenvalue
#  The estimated number of batches is 1657
#       146/1    0.84600    0.84673 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.594350644671852 for eigenvalue
#  The estimated number of batches is 1648
#       147/1    0.84697    0.84674 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5650791492583935 for eigenvalue
#  The estimated number of batches is 1635
#       148/1    0.84251    0.84670 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.544567172449909 for eigenvalue
#  The estimated number of batches is 1629
#       149/1    0.84452    0.84669 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.52083276451729 for eigenvalue
#  The estimated number of batches is 1620
#       150/1    0.83877    0.84663 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5252195635345656 for eigenvalue
#  The estimated number of batches is 1636
#       151/1    0.85192    0.84667 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5178845044915903 for eigenvalue
#  The estimated number of batches is 1642
#       152/1    0.84633    0.84666 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.505004575285026 for eigenvalue
#  The estimated number of batches is 1642
#       153/1    0.85174    0.84670 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.4900027327419414 for eigenvalue
#  The estimated number of batches is 1640
#       154/1    0.84776    0.84671 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.463793677450436 for eigenvalue
#  The estimated number of batches is 1628
#       155/1    0.84453    0.84669 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4400397531917286 for eigenvalue
#  The estimated number of batches is 1618
#       156/1    0.84675    0.84669 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4147258641843132 for eigenvalue
#  The estimated number of batches is 1606
#       157/1    0.84280    0.84666 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3948565943109625 for eigenvalue
#  The estimated number of batches is 1599
#       158/1    0.85024    0.84669 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.4126409904444963 for eigenvalue
#  The estimated number of batches is 1628
#       159/1    0.85414    0.84674 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.395372476370065 for eigenvalue
#  The estimated number of batches is 1623
#       160/1    0.84609    0.84674 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3717431491656993 for eigenvalue
#  The estimated number of batches is 1612
#       161/1    0.84723    0.84674 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.348693480140589 for eigenvalue
#  The estimated number of batches is 1602
#       162/1    0.84507    0.84673 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.326423998532192 for eigenvalue
#  The estimated number of batches is 1592
#       163/1    0.84885    0.84675 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.3036094220092367 for eigenvalue
#  The estimated number of batches is 1581
#       164/1    0.84392    0.84673 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2833080804606785 for eigenvalue
#  The estimated number of batches is 1573
#       165/1    0.84888    0.84674 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2671234602004597 for eigenvalue
#  The estimated number of batches is 1568
#       166/1    0.85234    0.84678 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2431972703025536 for eigenvalue
#  The estimated number of batches is 1556
#       167/1    0.85299    0.84682 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.2212085051119415 for eigenvalue
#  The estimated number of batches is 1546
#       168/1    0.84371    0.84680 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.202670863362982 for eigenvalue
#  The estimated number of batches is 1539
#       169/1    0.84429    0.84678 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1858797997719783 for eigenvalue
#  The estimated number of batches is 1533
#       170/1    0.85030    0.84681 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1621976985245057 for eigenvalue
#  The estimated number of batches is 1520
#       171/1    0.85367    0.84685 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.153665721523369 for eigenvalue
#  The estimated number of batches is 1522
#       172/1    0.84724    0.84686 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.135306786079223 for eigenvalue
#  The estimated number of batches is 1515
#       173/1    0.84774    0.84686 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.113756180969831 for eigenvalue
#  The estimated number of batches is 1504
#       174/1    0.85520    0.84692 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.100978872743559 for eigenvalue
#  The estimated number of batches is 1501
#       175/1    0.85253    0.84695 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0875694270517773 for eigenvalue
#  The estimated number of batches is 1498
#       176/1    0.85216    0.84699 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0724655189696746 for eigenvalue
#  The estimated number of batches is 1493
#       177/1    0.84548    0.84698 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.079651372950351 for eigenvalue
#  The estimated number of batches is 1510
#       178/1    0.84486    0.84696 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0669427231574757 for eigenvalue
#  The estimated number of batches is 1507
#       179/1    0.85262    0.84700 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.05046181588251 for eigenvalue
#  The estimated number of batches is 1500
#       180/1    0.84772    0.84700 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0481841541275543 for eigenvalue
#  The estimated number of batches is 1507
#       181/1    0.85371    0.84704 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0385010939122092 for eigenvalue
#  The estimated number of batches is 1507
#       182/1    0.84859    0.84705 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.021854058819947 for eigenvalue
#  The estimated number of batches is 1500
#       183/1    0.84733    0.84706 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0170274150118734 for eigenvalue
#  The estimated number of batches is 1504
#       184/1    0.85543    0.84711 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0226725652966278 for eigenvalue
#  The estimated number of batches is 1519
#       185/1    0.85067    0.84713 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 3.0025562438198925 for eigenvalue
#  The estimated number of batches is 1508
#       186/1    0.84654    0.84712 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.986210300608852 for eigenvalue
#  The estimated number of batches is 1501
#       187/1    0.85014    0.84714 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.966913033099192 for eigenvalue
#  The estimated number of batches is 1491
#       188/1    0.84839    0.84715 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9487847858483844 for eigenvalue
#  The estimated number of batches is 1481
#       189/1    0.84974    0.84717 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9362460711950242 for eigenvalue
#  The estimated number of batches is 1478
#       190/1    0.84334    0.84714 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.9259877383242547 for eigenvalue
#  The estimated number of batches is 1476
#       191/1    0.84069    0.84710 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.912416161469109 for eigenvalue
#  The estimated number of batches is 1471
#       192/1    0.84790    0.84711 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8964737784326022 for eigenvalue
#  The estimated number of batches is 1464
#       193/1    0.84360    0.84709 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.881797901327945 for eigenvalue
#  The estimated number of batches is 1457
#       194/1    0.85385    0.84713 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8660295591939553 for eigenvalue
#  The estimated number of batches is 1450
#       195/1    0.85373    0.84717 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8520294179067003 for eigenvalue
#  The estimated number of batches is 1444
#       196/1    0.84585    0.84716 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8467368455542306 for eigenvalue
#  The estimated number of batches is 1447
#       197/1    0.84791    0.84716 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8303361998122294 for eigenvalue
#  The estimated number of batches is 1438
#       198/1    0.84604    0.84716 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.8147187545532897 for eigenvalue
#  The estimated number of batches is 1431
#       199/1    0.84653    0.84715 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.803037291987452 for eigenvalue
#  The estimated number of batches is 1427
#       200/1    0.84606    0.84715 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7879271597922703 for eigenvalue
#  The estimated number of batches is 1420
#       201/1    0.85343    0.84718 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.80914906534827 for eigenvalue
#  The estimated number of batches is 1449
#       202/1    0.85095    0.84720 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.831003602258595 for eigenvalue
#  The estimated number of batches is 1479
#       203/1    0.85130    0.84722 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.8283411056541405 for eigenvalue
#  The estimated number of batches is 1484
#       204/1    0.84554    0.84722 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.815047357237127 for eigenvalue
#  The estimated number of batches is 1479
#       205/1    0.84485    0.84720 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.801670226805705 for eigenvalue
#  The estimated number of batches is 1473
#       206/1    0.84677    0.84720 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.79130058211328 for eigenvalue
#  The estimated number of batches is 1470
#       207/1    0.84498    0.84719 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7831174812248967 for eigenvalue
#  The estimated number of batches is 1469
#       208/1    0.85014    0.84720 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.791783534268467 for eigenvalue
#  The estimated number of batches is 1486
#       209/1    0.83968    0.84716 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.788813743757706 for eigenvalue
#  The estimated number of batches is 1490
#       210/1    0.84362    0.84715 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7755760772306424 for eigenvalue
#  The estimated number of batches is 1484
#       211/1    0.84624    0.84714 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.761031102408903 for eigenvalue
#  The estimated number of batches is 1477
#       212/1    0.85501    0.84718 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.748574429874494 for eigenvalue
#  The estimated number of batches is 1471
#       213/1    0.85054    0.84720 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7409145151272174 for eigenvalue
#  The estimated number of batches is 1470
#       214/1    0.85186    0.84722 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7256268755732895 for eigenvalue
#  The estimated number of batches is 1462
#       215/1    0.85386    0.84726 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7151205668135443 for eigenvalue
#  The estimated number of batches is 1458
#       216/1    0.85199    0.84728 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7076212547617784 for eigenvalue
#  The estimated number of batches is 1457
#       217/1    0.84922    0.84729 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.703681435902263 for eigenvalue
#  The estimated number of batches is 1461
#       218/1    0.85457    0.84733 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7000514544826157 for eigenvalue
#  The estimated number of batches is 1464
#       219/1    0.85012    0.84734 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6864215897120047 for eigenvalue
#  The estimated number of batches is 1457
#       220/1    0.85477    0.84738 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.7120035382459755 for eigenvalue
#  The estimated number of batches is 1491
#       221/1    0.84590    0.84737 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6983246152639624 for eigenvalue
#  The estimated number of batches is 1484
#       222/1    0.85993    0.84743 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.7012228954819073 for eigenvalue
#  The estimated number of batches is 1494
#       223/1    0.85185    0.84746 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.70739934174346 for eigenvalue
#  The estimated number of batches is 1508
#       224/1    0.85073    0.84747 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6921188291675477 for eigenvalue
#  The estimated number of batches is 1499
#       225/1    0.85406    0.84750 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6784243799004 for eigenvalue
#  The estimated number of batches is 1491
#       226/1    0.83766    0.84746 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6859434237747157 for eigenvalue
#  The estimated number of batches is 1507
#       227/1    0.84698    0.84745 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6750869734678626 for eigenvalue
#  The estimated number of batches is 1502
#       228/1    0.84753    0.84745 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.663094104984004 for eigenvalue
#  The estimated number of batches is 1496
#       229/1    0.83984    0.84742 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.657207978944423 for eigenvalue
#  The estimated number of batches is 1496
#       230/1    0.84749    0.84742 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6441472972808993 for eigenvalue
#  The estimated number of batches is 1489
#       231/1    0.84348    0.84740 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.638502547185699 for eigenvalue
#  The estimated number of batches is 1489
#       232/1    0.85627    0.84744 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.624295062094337 for eigenvalue
#  The estimated number of batches is 1481
#       233/1    0.83718    0.84739 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6347513377968794 for eigenvalue
#  The estimated number of batches is 1499
#       234/1    0.84986    0.84740 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6250092991025142 for eigenvalue
#  The estimated number of batches is 1495
#       235/1    0.84937    0.84741 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.613532650947952 for eigenvalue
#  The estimated number of batches is 1489
#       236/1    0.85482    0.84745 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.61029191649742 for eigenvalue
#  The estimated number of batches is 1492
#       237/1    0.84250    0.84743 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.622907698206022 for eigenvalue
#  The estimated number of batches is 1513
#       238/1    0.84705    0.84742 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.6107051155401937 for eigenvalue
#  The estimated number of batches is 1506
#       239/1    0.85123    0.84744 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.598053778694318 for eigenvalue
#  The estimated number of batches is 1499
#       240/1    0.84710    0.84744 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.586847613550145 for eigenvalue
#  The estimated number of batches is 1493
#       241/1    0.85446    0.84747 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5755979198903547 for eigenvalue
#  The estimated number of batches is 1487
#       242/1    0.84352    0.84745 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.565359405234985 for eigenvalue
#  The estimated number of batches is 1481
#       243/1    0.84660    0.84745 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5533835433064076 for eigenvalue
#  The estimated number of batches is 1474
#       244/1    0.84834    0.84745 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5434215646661826 for eigenvalue
#  The estimated number of batches is 1470
#       245/1    0.84849    0.84746 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5332017124079007 for eigenvalue
#  The estimated number of batches is 1464
#       246/1    0.84786    0.84746 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5218459849090755 for eigenvalue
#  The estimated number of batches is 1458
#       247/1    0.84805    0.84746 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.5123767745955026 for eigenvalue
#  The estimated number of batches is 1453
#       248/1    0.85228    0.84748 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.507806583596494 for eigenvalue
#  The estimated number of batches is 1454
#       249/1    0.84038    0.84745 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.497397411398581 for eigenvalue
#  The estimated number of batches is 1449
#       250/1    0.84768    0.84745 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.486586251311018 for eigenvalue
#  The estimated number of batches is 1443
#       251/1    0.85004    0.84747 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4785254616147547 for eigenvalue
#  The estimated number of batches is 1440
#       252/1    0.85006    0.84748 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.468653779116334 for eigenvalue
#  The estimated number of batches is 1434
#       253/1    0.84761    0.84748 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4595362433556027 for eigenvalue
#  The estimated number of batches is 1430
#       254/1    0.84544    0.84747 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4506510434590956 for eigenvalue
#  The estimated number of batches is 1426
#       255/1    0.85443    0.84750 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4522558907487486 for eigenvalue
#  The estimated number of batches is 1434
#       256/1    0.85765    0.84754 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.45705096400216 for eigenvalue
#  The estimated number of batches is 1445
#       257/1    0.84552    0.84753 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4468689792208913 for eigenvalue
#  The estimated number of batches is 1439
#       258/1    0.84061    0.84750 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.444686917317827 for eigenvalue
#  The estimated number of batches is 1443
#       259/1    0.84236    0.84748 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4358088436836725 for eigenvalue
#  The estimated number of batches is 1439
#       260/1    0.85076    0.84750 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.430798832993771 for eigenvalue
#  The estimated number of batches is 1439
#       261/1    0.84971    0.84750 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4208119114496873 for eigenvalue
#  The estimated number of batches is 1433
#       262/1    0.85078    0.84752 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.4099042931801615 for eigenvalue
#  The estimated number of batches is 1426
#       263/1    0.85287    0.84754 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.406886102973228 for eigenvalue
#  The estimated number of batches is 1428
#       264/1    0.84592    0.84753 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3967841858220758 for eigenvalue
#  The estimated number of batches is 1422
#       265/1    0.83830    0.84750 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3895851600297155 for eigenvalue
#  The estimated number of batches is 1419
#       266/1    0.84316    0.84748 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.383554019450277 for eigenvalue
#  The estimated number of batches is 1418
#       267/1    0.86135    0.84753 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3810248777865817 for eigenvalue
#  The estimated number of batches is 1421
#       268/1    0.84787    0.84754 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3733936842701056 for eigenvalue
#  The estimated number of batches is 1417
#       269/1    0.84624    0.84753 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3636987544038566 for eigenvalue
#  The estimated number of batches is 1412
#       270/1    0.84761    0.84753 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.354893299716681 for eigenvalue
#  The estimated number of batches is 1407
#       271/1    0.85485    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3505065484713956 for eigenvalue
#  The estimated number of batches is 1407
#       272/1    0.84435    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.353497675167727 for eigenvalue
#  The estimated number of batches is 1416
#       273/1    0.85040    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3441941913099678 for eigenvalue
#  The estimated number of batches is 1411
#       274/1    0.84665    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.336099163607702 for eigenvalue
#  The estimated number of batches is 1407
#       275/1    0.84969    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.327748566745273 for eigenvalue
#  The estimated number of batches is 1402
#       276/1    0.84322    0.84755 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3216970715500884 for eigenvalue
#  The estimated number of batches is 1400
#       277/1    0.85940    0.84759 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3279590040923632 for eigenvalue
#  The estimated number of batches is 1413
#       278/1    0.84157    0.84757 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3273212023207517 for eigenvalue
#  The estimated number of batches is 1418
#       279/1    0.84448    0.84756 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.318686029632817 for eigenvalue
#  The estimated number of batches is 1413
#       280/1    0.84316    0.84754 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.3099092768435465 for eigenvalue
#  The estimated number of batches is 1408
#       281/1    0.84070    0.84751 +/- 0.00032
#  Triggers unsatisfied, max unc./thresh. is 2.305644542865961 for eigenvalue
#  The estimated number of batches is 1408
#       282/1    0.84773    0.84751 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.297152460303649 for eigenvalue
#  The estimated number of batches is 1403
#       283/1    0.84626    0.84751 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.291375412141783 for eigenvalue
#  The estimated number of batches is 1401
#       284/1    0.85098    0.84752 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.2832384454779624 for eigenvalue
#  The estimated number of batches is 1397
#       285/1    0.84561    0.84752 +/- 0.00031
#  Triggers unsatisfied, max unc./thresh. is 2.275437697274706 for eigenvalue
# ...
#      1242/1    0.84625    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0447304753861038 for eigenvalue
#  The estimated number of batches is 1354
#      1243/1    0.84306    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0438707571949166 for eigenvalue
#  The estimated number of batches is 1353
#      1244/1    0.84802    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0432049384072946 for eigenvalue
#  The estimated number of batches is 1353
#      1245/1    0.84621    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0423632324480558 for eigenvalue
#  The estimated number of batches is 1351
#      1246/1    0.84120    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0415400503772365 for eigenvalue
#  The estimated number of batches is 1350
#      1247/1    0.84852    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.040789073163475 for eigenvalue
#  The estimated number of batches is 1350
#      1248/1    0.86078    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0424847543545865 for eigenvalue
#  The estimated number of batches is 1355
#      1249/1    0.85009    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0416490698565524 for eigenvalue
#  The estimated number of batches is 1354
#      1250/1    0.84601    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.041732976968911 for eigenvalue
#  The estimated number of batches is 1355
#      1251/1    0.84986    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0409132289032748 for eigenvalue
#  The estimated number of batches is 1354
#      1252/1    0.84407    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0407347821364834 for eigenvalue
#  The estimated number of batches is 1355
#      1253/1    0.85250    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0398944765005633 for eigenvalue
#  The estimated number of batches is 1354
#      1254/1    0.85264    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0395849347299677 for eigenvalue
#  The estimated number of batches is 1354
#      1255/1    0.84438    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0389669405672974 for eigenvalue
#  The estimated number of batches is 1354
#      1256/1    0.84146    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0382892720406265 for eigenvalue
#  The estimated number of batches is 1353
#      1257/1    0.85418    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.037465530074854 for eigenvalue
#  The estimated number of batches is 1352
#      1258/1    0.84652    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0367075812566615 for eigenvalue
#  The estimated number of batches is 1351
#      1259/1    0.85426    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0359179469317514 for eigenvalue
#  The estimated number of batches is 1350
#      1260/1    0.85216    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0355159876169868 for eigenvalue
#  The estimated number of batches is 1350
#      1261/1    0.84981    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0349466812052075 for eigenvalue
#  The estimated number of batches is 1350
#      1262/1    0.84677    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0342113636807067 for eigenvalue
#  The estimated number of batches is 1349
#      1263/1    0.84526    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.033414039303785 for eigenvalue
#  The estimated number of batches is 1348
#      1264/1    0.85405    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.033048532277451 for eigenvalue
#  The estimated number of batches is 1348
#      1265/1    0.85186    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0325770536014596 for eigenvalue
#  The estimated number of batches is 1348
#      1266/1    0.84023    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0318717968307272 for eigenvalue
#  The estimated number of batches is 1347
#      1267/1    0.84299    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0310727630829917 for eigenvalue
#  The estimated number of batches is 1346
#      1268/1    0.84301    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0302735240059164 for eigenvalue
#  The estimated number of batches is 1345
#      1269/1    0.84808    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0294168604786753 for eigenvalue
#  The estimated number of batches is 1344
#      1270/1    0.85083    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0287839001297305 for eigenvalue
#  The estimated number of batches is 1343
#      1271/1    0.84222    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0289397105510174 for eigenvalue
#  The estimated number of batches is 1345
#      1272/1    0.84205    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0286536799256476 for eigenvalue
#  The estimated number of batches is 1345
#      1273/1    0.85137    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0281304369727577 for eigenvalue
#  The estimated number of batches is 1345
#      1274/1    0.84244    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0274942690065219 for eigenvalue
#  The estimated number of batches is 1344
#      1275/1    0.84263    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0272534988741506 for eigenvalue
#  The estimated number of batches is 1345
#      1276/1    0.84374    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.026474287609599 for eigenvalue
#  The estimated number of batches is 1344
#      1277/1    0.85066    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0256592897739023 for eigenvalue
#  The estimated number of batches is 1343
#      1278/1    0.85130    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.025174157543391 for eigenvalue
#  The estimated number of batches is 1343
#      1279/1    0.85057    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0243406623377003 for eigenvalue
#  The estimated number of batches is 1342
#      1280/1    0.84797    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.024803754102868 for eigenvalue
#  The estimated number of batches is 1344
#      1281/1    0.84238    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.024085586736619 for eigenvalue
#  The estimated number of batches is 1343
#      1282/1    0.85167    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.023978186882067 for eigenvalue
#  The estimated number of batches is 1344
#      1283/1    0.84772    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0231799280821914 for eigenvalue
#  The estimated number of batches is 1343
#      1284/1    0.84966    0.84793 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0223912487603695 for eigenvalue
#  The estimated number of batches is 1342
#      1285/1    0.85461    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0215568235472339 for eigenvalue
#  The estimated number of batches is 1341
#      1286/1    0.84820    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0207931611243877 for eigenvalue
#  The estimated number of batches is 1340
#      1287/1    0.84407    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.019964402791534 for eigenvalue
#  The estimated number of batches is 1339
#      1288/1    0.85059    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0195618413249101 for eigenvalue
#  The estimated number of batches is 1339
#      1289/1    0.85178    0.84794 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0190378695707807 for eigenvalue
#  The estimated number of batches is 1338
#      1290/1    0.85241    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0187057332425216 for eigenvalue
#  The estimated number of batches is 1338
#      1291/1    0.84827    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0179198321959733 for eigenvalue
#  The estimated number of batches is 1337
#      1292/1    0.85198    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0175151499343278 for eigenvalue
#  The estimated number of batches is 1337
#      1293/1    0.85257    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0167638238513497 for eigenvalue
#  The estimated number of batches is 1337
#      1294/1    0.84104    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0174705359421174 for eigenvalue
#  The estimated number of batches is 1339
#      1295/1    0.85016    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0167171509955375 for eigenvalue
#  The estimated number of batches is 1338
#      1296/1    0.85208    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.015965768014142 for eigenvalue
#  The estimated number of batches is 1338
#      1297/1    0.84886    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0155627763860708 for eigenvalue
#  The estimated number of batches is 1338
#      1298/1    0.84762    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.014863595631357 for eigenvalue
#  The estimated number of batches is 1337
#      1299/1    0.84444    0.84795 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0141829179593091 for eigenvalue
#  The estimated number of batches is 1336
#      1300/1    0.85921    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0143694218190313 for eigenvalue
#  The estimated number of batches is 1338
#      1301/1    0.84563    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0138560980354185 for eigenvalue
#  The estimated number of batches is 1337
#      1302/1    0.84646    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0131923160127043 for eigenvalue
#  The estimated number of batches is 1337
#      1303/1    0.85538    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.012808487863457 for eigenvalue
#  The estimated number of batches is 1337
#      1304/1    0.84903    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0121567079033713 for eigenvalue
#  The estimated number of batches is 1336
#      1305/1    0.84500    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0116866536315456 for eigenvalue
#  The estimated number of batches is 1336
#      1306/1    0.85359    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.011013908686151 for eigenvalue
#  The estimated number of batches is 1335
#      1307/1    0.85157    0.84797 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0105140371017824 for eigenvalue
#  The estimated number of batches is 1335
#      1308/1    0.84856    0.84797 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.010074989075581 for eigenvalue
#  The estimated number of batches is 1335
#      1309/1    0.84672    0.84797 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0092890664773866 for eigenvalue
#  The estimated number of batches is 1334
#      1310/1    0.84520    0.84796 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.009228300314155 for eigenvalue
#  The estimated number of batches is 1334
#      1311/1    0.85119    0.84797 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0084383365191416 for eigenvalue
#  The estimated number of batches is 1333
#      1312/1    0.85501    0.84797 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0084645833361385 for eigenvalue
#  The estimated number of batches is 1334
#      1313/1    0.85811    0.84798 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.008985590076876 for eigenvalue
#  The estimated number of batches is 1337
#      1314/1    0.84467    0.84798 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0083849110619802 for eigenvalue
#  The estimated number of batches is 1336
#      1315/1    0.85224    0.84798 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0077144131977798 for eigenvalue
#  The estimated number of batches is 1336
#      1316/1    0.85432    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0082416236108456 for eigenvalue
#  The estimated number of batches is 1338
#      1317/1    0.85146    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.007595841377239 for eigenvalue
#  The estimated number of batches is 1337
#      1318/1    0.83852    0.84798 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0070857215961289 for eigenvalue
#  The estimated number of batches is 1337
#      1319/1    0.84974    0.84798 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0064319731536726 for eigenvalue
#  The estimated number of batches is 1336
#      1320/1    0.85346    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0057451567613487 for eigenvalue
#  The estimated number of batches is 1335
#      1321/1    0.84846    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.00495386859867 for eigenvalue
#  The estimated number of batches is 1334
#      1322/1    0.84926    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0041828071809982 for eigenvalue
#  The estimated number of batches is 1333
#      1323/1    0.84380    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0034348483984452 for eigenvalue
#  The estimated number of batches is 1332
#      1324/1    0.84878    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0028118133193955 for eigenvalue
#  The estimated number of batches is 1332
#      1325/1    0.84836    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0021026666925665 for eigenvalue
#  The estimated number of batches is 1331
#      1326/1    0.84923    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0015335950814788 for eigenvalue
#  The estimated number of batches is 1331
#      1327/1    0.85247    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0014756694575528 for eigenvalue
#  The estimated number of batches is 1331
#      1328/1    0.84697    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0007005177985233 for eigenvalue
#  The estimated number of batches is 1330
#      1329/1    0.84545    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0005416520948696 for eigenvalue
#  The estimated number of batches is 1331
#      1330/1    0.85681    0.84799 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0004633102635012 for eigenvalue
#  The estimated number of batches is 1332
#      1331/1    0.85060    0.84800 +/- 0.00014
#  Triggers satisfied for batch 1331
#  Creating state point statepoint.01331.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.7421e+00 seconds
#    Reading cross sections          = 9.6653e+00 seconds
#  Total time in simulation          = 2.3332e+03 seconds
#    Time in transport only          = 2.2974e+03 seconds
#    Time in inactive batches        = 1.4543e+01 seconds
#    Time in active batches          = 2.3186e+03 seconds
#    Time synchronizing fission bank = 4.6121e+00 seconds
#      Sampling source sites         = 3.7810e+00 seconds
#      SEND/RECV source sites        = 8.2959e-01 seconds
#    Time accumulating tallies       = 2.8335e+01 seconds
#    Time writing statepoints        = 5.9011e-01 seconds
#  Total time for finalization       = 1.4756e+01 seconds
#  Total time elapsed                = 2.3579e+03 seconds
#  Calculation Rate (inactive)       = 68762.3 particles/second
#  Calculation Rate (active)         = 28270.9 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.84794 +/- 0.00012
#  k-effective (Track-length)  = 0.84800 +/- 0.00014
#  k-effective (Absorption)    = 0.84798 +/- 0.00013
#  Combined k-effective        = 0.84798 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
