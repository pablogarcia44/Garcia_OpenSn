# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %% [markdown]
# def instru(index_x,index_y):
#     clad_inner_radius = openmc.ZCylinder(r=0.559)
#     clad_outer_radius = openmc.ZCylinder(r=0.605)
#     pitch = 1.26
#     left = openmc.XPlane(-pitch/2, boundary_type='transmission')
#     right = openmc.XPlane(pitch/2, boundary_type='transmission')
#     bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
#     top = openmc.YPlane(pitch/2, boundary_type='transmission')
#     clad_region = +clad_inner_radius & -clad_outer_radius
#     water_region = +left & -right & +bottom & -top & +clad_outer_radius
#     water_guide_region= -clad_inner_radius
#     water_guide = openmc.Cell(name='water_guide'+'_'+str(index_x)+'_'+str(index_y))
#     water_guide.fill = water
#     water_guide.region = water_guide_region
#     clad = openmc.Cell(name='clad_guide'+'_'+str(index_x)+'_'+str(index_y))
#     clad.fill = zirconium
#     clad.region = clad_region
#     moderator = openmc.Cell(name='moderator'+'_'+str(index_x)+'_'+str(index_y))
#     moderator.fill = water
#     moderator.region = water_region
#     u = openmc.Universe(name='u_guide'+'_'+str(index_x)+'_'+str(index_y),cells=(water_guide, clad, moderator))
#     return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create Instrument Thimble

# %%
def instru(family):

    pitch = 1.26
    
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    instru_inner_radius = openmc.ZCylinder(0.258)
    instry_outer_radius= openmc.ZCylinder(0.382)
    
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission') 

    clad_region = +clad_inner_radius & -clad_outer_radius
    
    water_region = +left & -right & +bottom & -top & +clad_outer_radius | -instru_inner_radius | +instry_outer_radius & -clad_inner_radius
    
    instru_region = +instru_inner_radius & -instry_outer_radius

    water_cell = openmc.Cell(name='water_cell'+family)
    water_cell.fill = water
    water_cell.region = water_region
    
    clad_cell = openmc.Cell(name='clad_cell'+family)
    clad_cell.fill = zirconium
    clad_cell.region = clad_region
    
    instru_cell = openmc.Cell(name='instru_cell'+family)
    instru_cell.fill = SS304
    instru_cell.region = instru_region
    
    u = openmc.Universe(name='u_guide'+family,cells=(water_cell, clad_cell, instru_cell))
    
    return(u,water_cell,clad_cell,instru_cell)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]

PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
model.export_to_model_xml('model_2A_1_family.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=465.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=2.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=10.
#   warn(msg, IDWarning)

# %% [markdown]
# ### Create power tally

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=941.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=467.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=475.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-12 17:29:47
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.97047
#         2/1    0.97829
#         3/1    0.97525
#         4/1    0.97769
#         5/1    0.96897
#         6/1    0.97372
#         7/1    0.96925
#         8/1    0.98379
#         9/1    0.97302
#        10/1    0.96705
#        11/1    0.97690
#        12/1    0.97546
#        13/1    0.98041
#        14/1    0.98130
#        15/1    0.96905
#        16/1    0.97861
#        17/1    0.97785
#        18/1    0.98301
#        19/1    0.96335
#        20/1    0.97743
#        21/1    0.98793
#        22/1    0.97888    0.98341 +/- 0.00452
#        23/1    0.98663    0.98448 +/- 0.00282
#        24/1    0.97982    0.98332 +/- 0.00231
#        25/1    0.98372    0.98340 +/- 0.00179
#        26/1    0.98284    0.98331 +/- 0.00147
#        27/1    0.97879    0.98266 +/- 0.00140
#        28/1    0.96968    0.98104 +/- 0.00202
#        29/1    0.97496    0.98036 +/- 0.00191
#        30/1    0.97417    0.97974 +/- 0.00182
#        31/1    0.96656    0.97855 +/- 0.00203
#        32/1    0.97881    0.97857 +/- 0.00186
#        33/1    0.97221    0.97808 +/- 0.00178
#        34/1    0.97160    0.97762 +/- 0.00171
#        35/1    0.97518    0.97745 +/- 0.00160
#        36/1    0.96959    0.97696 +/- 0.00157
#        37/1    0.97385    0.97678 +/- 0.00149
#        38/1    0.97581    0.97672 +/- 0.00141
#        39/1    0.97634    0.97670 +/- 0.00133
#        40/1    0.98626    0.97718 +/- 0.00135
#        41/1    0.96854    0.97677 +/- 0.00135
#        42/1    0.97835    0.97684 +/- 0.00129
#        43/1    0.98441    0.97717 +/- 0.00127
#        44/1    0.96709    0.97675 +/- 0.00129
#        45/1    0.99378    0.97743 +/- 0.00141
#        46/1    0.97898    0.97749 +/- 0.00136
#        47/1    0.98889    0.97791 +/- 0.00137
#        48/1    0.98112    0.97803 +/- 0.00133
#        49/1    0.97151    0.97780 +/- 0.00130
#        50/1    0.98258    0.97796 +/- 0.00127
#  Triggers unsatisfied, max unc./thresh. is 7.228077663247914 for eigenvalue
#  The estimated number of batches is 1588
#  Creating state point statepoint.00050.h5...
#        51/1    0.98281    0.97812 +/- 0.00124
#  Triggers unsatisfied, max unc./thresh. is 7.1529824395228685 for eigenvalue
#  The estimated number of batches is 1607
#        52/1    0.97944    0.97816 +/- 0.00120
#  Triggers unsatisfied, max unc./thresh. is 7.059943010030704 for eigenvalue
#  The estimated number of batches is 1615
#        53/1    0.97889    0.97818 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 6.845246917929187 for eigenvalue
#  The estimated number of batches is 1567
#        54/1    0.97486    0.97809 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 6.6289980617060875 for eigenvalue
#  The estimated number of batches is 1515
#        55/1    0.96979    0.97785 +/- 0.00112
#  Triggers unsatisfied, max unc./thresh. is 6.545994895729481 for eigenvalue
#  The estimated number of batches is 1520
#        56/1    0.97635    0.97781 +/- 0.00109
#  Triggers unsatisfied, max unc./thresh. is 6.352732160035606 for eigenvalue
#  The estimated number of batches is 1473
#        57/1    0.97321    0.97768 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 6.62980155398963 for eigenvalue
#  The estimated number of batches is 1647
#        58/1    0.98406    0.97785 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 6.470922450812224 for eigenvalue
#  The estimated number of batches is 1612
#        59/1    0.97268    0.97772 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.418089183314948 for eigenvalue
#  The estimated number of batches is 1627
#        60/1    0.97313    0.97760 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 6.401046319987245 for eigenvalue
#  The estimated number of batches is 1659
#        61/1    0.98150    0.97770 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 6.261125245340287 for eigenvalue
#  The estimated number of batches is 1628
#        62/1    0.97957    0.97774 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.1389222255891855 for eigenvalue
#  The estimated number of batches is 1603
#        63/1    0.97977    0.97779 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.047762969781272 for eigenvalue
#  The estimated number of batches is 1593
#        64/1    0.97618    0.97775 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.849991375958169 for eigenvalue
#  The estimated number of batches is 1526
#        65/1    0.97399    0.97767 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 5.731564139540015 for eigenvalue
#  The estimated number of batches is 1499
#        66/1    0.98399    0.97781 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.707917435578777 for eigenvalue
#  The estimated number of batches is 1519
#        67/1    0.97995    0.97785 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.65026441710508 for eigenvalue
#  The estimated number of batches is 1521
#        68/1    0.96859    0.97766 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 5.622795848690395 for eigenvalue
#  The estimated number of batches is 1538
#        69/1    0.97660    0.97764 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.526833646404917 for eigenvalue
#  The estimated number of batches is 1517
#        70/1    0.97411    0.97757 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.415114843218537 for eigenvalue
#  The estimated number of batches is 1487
#        71/1    0.98244    0.97766 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.366514023234119 for eigenvalue
#  The estimated number of batches is 1489
#        72/1    0.97679    0.97765 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.313435210159324 for eigenvalue
#  The estimated number of batches is 1489
#        73/1    0.98365    0.97776 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.417897281052955 for eigenvalue
#  The estimated number of batches is 1576
#        74/1    0.96639    0.97755 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.328998439399718 for eigenvalue
#  The estimated number of batches is 1554
#        75/1    0.98102    0.97761 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.417535888998606 for eigenvalue
#  The estimated number of batches is 1635
#        76/1    0.97386    0.97755 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.351300119782035 for eigenvalue
#  The estimated number of batches is 1624
#        77/1    0.97219    0.97745 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.471992906747258 for eigenvalue
#  The estimated number of batches is 1727
#        78/1    0.97933    0.97748 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.419450533469013 for eigenvalue
#  The estimated number of batches is 1724
#        79/1    0.98270    0.97757 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.416719696124687 for eigenvalue
#  The estimated number of batches is 1752
#        80/1    0.97607    0.97755 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.306010862208926 for eigenvalue
#  The estimated number of batches is 1710
#        81/1    0.97419    0.97749 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.228746129764676 for eigenvalue
#  The estimated number of batches is 1688
#        82/1    0.97072    0.97738 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.286301971219365 for eigenvalue
#  The estimated number of batches is 1753
#        83/1    0.97153    0.97729 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.250527586763925 for eigenvalue
#  The estimated number of batches is 1757
#        84/1    0.97647    0.97728 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.171245974408192 for eigenvalue
#  The estimated number of batches is 1732
#        85/1    0.97363    0.97722 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.120002807697283 for eigenvalue
#  The estimated number of batches is 1724
#        86/1    0.98358    0.97732 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 5.045026813481878 for eigenvalue
#  The estimated number of batches is 1700
#        87/1    0.98031    0.97736 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.976227649451649 for eigenvalue
#  The estimated number of batches is 1680
#        88/1    0.97849    0.97738 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.912670495210363 for eigenvalue
#  The estimated number of batches is 1662
#        89/1    0.97104    0.97729 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.955927885067658 for eigenvalue
#  The estimated number of batches is 1715
#        90/1    0.97519    0.97726 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.907189169033056 for eigenvalue
#  The estimated number of batches is 1706
#        91/1    0.97314    0.97720 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.97287418577319 for eigenvalue
#  The estimated number of batches is 1776
#        92/1    0.97718    0.97720 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.919862927373944 for eigenvalue
#  The estimated number of batches is 1763
#        93/1    0.97595    0.97718 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.85050975905741 for eigenvalue
#  The estimated number of batches is 1738
#        94/1    0.97210    0.97711 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.759980688815006 for eigenvalue
#  The estimated number of batches is 1697
#        95/1    0.98571    0.97723 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.726148751428495 for eigenvalue
#  The estimated number of batches is 1696
#        96/1    0.97553    0.97721 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.717836404365909 for eigenvalue
#  The estimated number of batches is 1712
#        97/1    0.98011    0.97724 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.661257341147364 for eigenvalue
#  The estimated number of batches is 1694
#        98/1    0.97949    0.97727 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.605590438416875 for eigenvalue
#  The estimated number of batches is 1675
#        99/1    0.96820    0.97716 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.523096955948158 for eigenvalue
#  The estimated number of batches is 1637
#       100/1    0.96264    0.97698 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.428508560161148 for eigenvalue
#  The estimated number of batches is 1589
#       101/1    0.97229    0.97692 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.362201140644331 for eigenvalue
#  The estimated number of batches is 1562
#       102/1    0.97548    0.97690 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.3020310054453645 for eigenvalue
#  The estimated number of batches is 1538
#       103/1    0.97818    0.97692 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.254014369644643 for eigenvalue
#  The estimated number of batches is 1523
#       104/1    0.96787    0.97681 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.2527238398609395 for eigenvalue
#  The estimated number of batches is 1540
#       105/1    0.97991    0.97684 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.2081234655062385 for eigenvalue
#  The estimated number of batches is 1526
#       106/1    0.96761    0.97674 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.149166849877033 for eigenvalue
#  The estimated number of batches is 1501
#       107/1    0.97635    0.97673 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.115428647432662 for eigenvalue
#  The estimated number of batches is 1494
#       108/1    0.97648    0.97673 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.067316951526786 for eigenvalue
#  The estimated number of batches is 1476
#       109/1    0.97345    0.97669 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.017968335107021 for eigenvalue
#  The estimated number of batches is 1457
#       110/1    0.98046    0.97673 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.9771043973035365 for eigenvalue
#  The estimated number of batches is 1444
#       111/1    0.98220    0.97679 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.980510438791132 for eigenvalue
#  The estimated number of batches is 1462
#       112/1    0.97732    0.97680 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.942400325055737 for eigenvalue
#  The estimated number of batches is 1450
#       113/1    0.98315    0.97687 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.9175294081775496 for eigenvalue
#  The estimated number of batches is 1448
#       114/1    0.98130    0.97692 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.902569535463286 for eigenvalue
#  The estimated number of batches is 1452
#       115/1    0.97482    0.97689 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.8769750334878945 for eigenvalue
#  The estimated number of batches is 1448
#       116/1    0.97536    0.97688 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.856917835832872 for eigenvalue
#  The estimated number of batches is 1449
#       117/1    0.97133    0.97682 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.837981827686696 for eigenvalue
#  The estimated number of batches is 1449
#       118/1    0.97649    0.97682 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.8202674782664543 for eigenvalue
#  The estimated number of batches is 1451
#       119/1    0.96593    0.97671 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.846325943643883 for eigenvalue
#  The estimated number of batches is 1485
#       120/1    0.97320    0.97667 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.809580325592464 for eigenvalue
#  The estimated number of batches is 1472
#       121/1    0.97676    0.97667 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.776683687290655 for eigenvalue
#  The estimated number of batches is 1461
#       122/1    0.97955    0.97670 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.757753391104739 for eigenvalue
#  The estimated number of batches is 1461
#       123/1    0.97806    0.97671 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.722433239929998 for eigenvalue
#  The estimated number of batches is 1448
#       124/1    0.98264    0.97677 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.6943580007582324 for eigenvalue
#  The estimated number of batches is 1440
#       125/1    0.96306    0.97664 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7680883861417698 for eigenvalue
#  The estimated number of batches is 1511
#       126/1    0.98149    0.97669 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.7751221339580403 for eigenvalue
#  The estimated number of batches is 1531
#       127/1    0.98599    0.97677 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7851763956958253 for eigenvalue
#  The estimated number of batches is 1554
#       128/1    0.96638    0.97668 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7583119357768306 for eigenvalue
#  The estimated number of batches is 1546
#       129/1    0.98884    0.97679 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.740982942673713 for eigenvalue
#  The estimated number of batches is 1546
#       130/1    0.95900    0.97663 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7527128507988308 for eigenvalue
#  The estimated number of batches is 1570
#       131/1    0.97723    0.97663 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.719110369186713 for eigenvalue
#  The estimated number of batches is 1556
#       132/1    0.97639    0.97663 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7036052535266357 for eigenvalue
#  The estimated number of batches is 1557
#       133/1    0.97245    0.97659 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.6827955376626416 for eigenvalue
#  The estimated number of batches is 1553
#       134/1    0.98845    0.97670 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.741390912669825 for eigenvalue
#  The estimated number of batches is 1616
#       135/1    0.97987    0.97673 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.713927324137022 for eigenvalue
#  The estimated number of batches is 1607
#       136/1    0.97785    0.97673 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.6938753272151033 for eigenvalue
#  The estimated number of batches is 1603
#       137/1    0.98047    0.97677 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.688464494894775 for eigenvalue
#  The estimated number of batches is 1612
#       138/1    0.97252    0.97673 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.663109910809104 for eigenvalue
#  The estimated number of batches is 1604
#       139/1    0.96964    0.97667 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.627216148194006 for eigenvalue
#  The estimated number of batches is 1586
#       140/1    0.97328    0.97664 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5959350748313206 for eigenvalue
#  The estimated number of batches is 1572
#       141/1    0.97849    0.97666 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.5722735703009447 for eigenvalue
#  The estimated number of batches is 1565
#       142/1    0.97501    0.97664 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.541823407266754 for eigenvalue
#  The estimated number of batches is 1551
#       143/1    0.97089    0.97660 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5356392360295863 for eigenvalue
#  The estimated number of batches is 1558
#       144/1    0.97808    0.97661 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.5086661767640037 for eigenvalue
#  The estimated number of batches is 1547
#       145/1    0.98495    0.97668 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4969868520947744 for eigenvalue
#  The estimated number of batches is 1549
#       146/1    0.97002    0.97662 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.46826038208632 for eigenvalue
#  The estimated number of batches is 1536
#       147/1    0.97235    0.97659 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4827971560162876 for eigenvalue
#  The estimated number of batches is 1561
#       148/1    0.97190    0.97655 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.4549828489135086 for eigenvalue
#  The estimated number of batches is 1548
#       149/1    0.97189    0.97652 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4293196982841727 for eigenvalue
#  The estimated number of batches is 1538
#       150/1    0.97699    0.97652 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4032123269023065 for eigenvalue
#  The estimated number of batches is 1526
#       151/1    0.97772    0.97653 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4003625650744205 for eigenvalue
#  The estimated number of batches is 1535
#       152/1    0.98342    0.97658 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3772500504958893 for eigenvalue
#  The estimated number of batches is 1526
#       153/1    0.98110    0.97662 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3572092372749434 for eigenvalue
#  The estimated number of batches is 1520
#       154/1    0.98253    0.97666 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.369530867664905 for eigenvalue
#  The estimated number of batches is 1542
#       155/1    0.97755    0.97667 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3493271149261385 for eigenvalue
#  The estimated number of batches is 1535
#       156/1    0.97055    0.97662 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3258343866277613 for eigenvalue
#  The estimated number of batches is 1525
#       157/1    0.98152    0.97666 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.3043545759536843 for eigenvalue
#  The estimated number of batches is 1516
#       158/1    0.96984    0.97661 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.3032520116452617 for eigenvalue
#  The estimated number of batches is 1526
#       159/1    0.97453    0.97659 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.280937997278524 for eigenvalue
#  The estimated number of batches is 1517
#       160/1    0.97843    0.97661 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2654961721717877 for eigenvalue
#  The estimated number of batches is 1513
#       161/1    0.97077    0.97657 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.314740290255107 for eigenvalue
#  The estimated number of batches is 1570
#       162/1    0.97800    0.97658 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.301494698084715 for eigenvalue
#  The estimated number of batches is 1568
#       163/1    0.97673    0.97658 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.278704503601742 for eigenvalue
#  The estimated number of batches is 1558
#       164/1    0.97099    0.97654 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.255544353262756 for eigenvalue
#  The estimated number of batches is 1547
#       165/1    0.98048    0.97656 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2414681365895617 for eigenvalue
#  The estimated number of batches is 1544
#       166/1    0.96448    0.97648 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2150845706665745 for eigenvalue
#  The estimated number of batches is 1530
#       167/1    0.97583    0.97648 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1937318193554805 for eigenvalue
#  The estimated number of batches is 1520
#       168/1    0.97907    0.97650 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1781199555331847 for eigenvalue
#  The estimated number of batches is 1515
#       169/1    0.97479    0.97648 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.157947116068263 for eigenvalue
#  The estimated number of batches is 1506
#       170/1    0.98064    0.97651 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1375244740406583 for eigenvalue
#  The estimated number of batches is 1497
#       171/1    0.97995    0.97653 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.135698433706036 for eigenvalue
#  The estimated number of batches is 1505
#       172/1    0.98310    0.97658 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1282627737694564 for eigenvalue
#  The estimated number of batches is 1508
#       173/1    0.97657    0.97658 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.11003028426228 for eigenvalue
#  The estimated number of batches is 1500
#       174/1    0.97250    0.97655 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0989579350248984 for eigenvalue
#  The estimated number of batches is 1499
#       175/1    0.98364    0.97660 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.1457478687443836 for eigenvalue
#  The estimated number of batches is 1554
#       176/1    0.97615    0.97659 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.1251128554186094 for eigenvalue
#  The estimated number of batches is 1544
#       177/1    0.98144    0.97662 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.1063220899226973 for eigenvalue
#  The estimated number of batches is 1535
#       178/1    0.97543    0.97662 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0865631003670075 for eigenvalue
#  The estimated number of batches is 1526
#       179/1    0.97399    0.97660 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.130666376618174 for eigenvalue
#  The estimated number of batches is 1579
#       180/1    0.97042    0.97656 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1248745761727035 for eigenvalue
#  The estimated number of batches is 1583
#       181/1    0.98136    0.97659 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1070210968930683 for eigenvalue
#  The estimated number of batches is 1575
#       182/1    0.96267    0.97651 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.1093083400730874 for eigenvalue
#  The estimated number of batches is 1587
#       183/1    0.97551    0.97650 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0939406825723257 for eigenvalue
#  The estimated number of batches is 1581
#       184/1    0.97607    0.97650 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0760676599952284 for eigenvalue
#  The estimated number of batches is 1572
#       185/1    0.96524    0.97643 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0849432375525967 for eigenvalue
#  The estimated number of batches is 1591
#       186/1    0.97463    0.97642 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0656869225646033 for eigenvalue
#  The estimated number of batches is 1581
#       187/1    0.97536    0.97641 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.058830900228884 for eigenvalue
#  The estimated number of batches is 1583
#       188/1    0.97342    0.97639 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0455201634362123 for eigenvalue
#  The estimated number of batches is 1579
#       189/1    0.97494    0.97639 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0348593155285273 for eigenvalue
#  The estimated number of batches is 1577
#       190/1    0.97044    0.97635 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0160451933359536 for eigenvalue
#  The estimated number of batches is 1567
#       191/1    0.97193    0.97632 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.011935857189362 for eigenvalue
#  The estimated number of batches is 1572
#       192/1    0.98448    0.97637 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.998605197309043 for eigenvalue
#  The estimated number of batches is 1567
#       193/1    0.97480    0.97636 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.988533634079637 for eigenvalue
#  The estimated number of batches is 1566
#       194/1    0.97578    0.97636 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.97291293721519 for eigenvalue
#  The estimated number of batches is 1558
#       195/1    0.97454    0.97635 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9676376253846835 for eigenvalue
#  The estimated number of batches is 1562
#       196/1    0.97094    0.97632 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.974023465304578 for eigenvalue
#  The estimated number of batches is 1577
#       197/1    0.97672    0.97632 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9633020445553893 for eigenvalue
#  The estimated number of batches is 1575
#       198/1    0.96741    0.97627 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.952767432937485 for eigenvalue
#  The estimated number of batches is 1572
#       199/1    0.97147    0.97624 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9338384623014586 for eigenvalue
#  The estimated number of batches is 1561
#       200/1    0.97224    0.97622 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.916343385417801 for eigenvalue
#  The estimated number of batches is 1551
#       201/1    0.98039    0.97624 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9024187380020288 for eigenvalue
#  The estimated number of batches is 1545
#       202/1    0.97999    0.97626 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.888105287822324 for eigenvalue
#  The estimated number of batches is 1539
#       203/1    0.98432    0.97631 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.912774762080474 for eigenvalue
#  The estimated number of batches is 1573
#       204/1    0.97847    0.97632 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.898503642146398 for eigenvalue
#  The estimated number of batches is 1566
#       205/1    0.97251    0.97630 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.892005476740292 for eigenvalue
#  The estimated number of batches is 1568
#       206/1    0.97067    0.97627 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.874939725893977 for eigenvalue
#  The estimated number of batches is 1558
#       207/1    0.96551    0.97621 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9086687904803266 for eigenvalue
#  The estimated number of batches is 1603
#       208/1    0.98878    0.97628 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.920858582943609 for eigenvalue
#  The estimated number of batches is 1624
#       209/1    0.97780    0.97629 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.905804858333207 for eigenvalue
#  The estimated number of batches is 1616
#       210/1    0.96817    0.97624 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9062887099957297 for eigenvalue
#  The estimated number of batches is 1625
#       211/1    0.97997    0.97626 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.895464290843867 for eigenvalue
#  The estimated number of batches is 1622
#       212/1    0.98142    0.97629 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.881691011502711 for eigenvalue
#  The estimated number of batches is 1615
#       213/1    0.97282    0.97627 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8975516724052452 for eigenvalue
#  The estimated number of batches is 1641
#       214/1    0.97378    0.97626 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.881341221707774 for eigenvalue
#  The estimated number of batches is 1631
#       215/1    0.98074    0.97628 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.879280722595641 for eigenvalue
#  The estimated number of batches is 1637
#       216/1    0.98648    0.97634 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8665694351141573 for eigenvalue
#  The estimated number of batches is 1631
#       217/1    0.97332    0.97632 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8519550867575947 for eigenvalue
#  The estimated number of batches is 1623
#       218/1    0.96881    0.97628 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.838195291475492 for eigenvalue
#  The estimated number of batches is 1615
#       219/1    0.97524    0.97628 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.831630986905403 for eigenvalue
#  The estimated number of batches is 1616
#       220/1    0.97869    0.97629 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8210319368124543 for eigenvalue
#  The estimated number of batches is 1612
#       221/1    0.97753    0.97629 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.807058512035701 for eigenvalue
#  The estimated number of batches is 1604
#       222/1    0.97485    0.97629 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.793465613116854 for eigenvalue
#  The estimated number of batches is 1597
#       223/1    0.97209    0.97627 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7938554027501508 for eigenvalue
#  The estimated number of batches is 1605
#       224/1    0.97616    0.97627 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.807175674528003 for eigenvalue
#  The estimated number of batches is 1628
#       225/1    0.97250    0.97625 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7939463124422184 for eigenvalue
#  The estimated number of batches is 1621
#       226/1    0.98580    0.97629 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.793386111748928 for eigenvalue
#  The estimated number of batches is 1628
#       227/1    0.97965    0.97631 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7811462125512256 for eigenvalue
#  The estimated number of batches is 1622
#       228/1    0.97358    0.97630 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7678953951339813 for eigenvalue
#  The estimated number of batches is 1614
#       229/1    0.97945    0.97631 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.755181481843524 for eigenvalue
#  The estimated number of batches is 1607
#       230/1    0.97376    0.97630 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.74273848642642 for eigenvalue
#  The estimated number of batches is 1600
#       231/1    0.98030    0.97632 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7319171665234383 for eigenvalue
#  The estimated number of batches is 1595
#       232/1    0.98069    0.97634 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7361107872510417 for eigenvalue
#  The estimated number of batches is 1608
#       233/1    0.97310    0.97632 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.729867576880899 for eigenvalue
#  The estimated number of batches is 1608
#       234/1    0.98188    0.97635 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7182117435050563 for eigenvalue
#  The estimated number of batches is 1602
#       235/1    0.97933    0.97636 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7063227289525833 for eigenvalue
#  The estimated number of batches is 1595
#       236/1    0.98361    0.97640 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7005357005308803 for eigenvalue
#  The estimated number of batches is 1596
#       237/1    0.97346    0.97638 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6870681683457693 for eigenvalue
#  The estimated number of batches is 1587
#       238/1    0.97469    0.97638 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.676555516696425 for eigenvalue
#  The estimated number of batches is 1582
#       239/1    0.97717    0.97638 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.666018777366027 for eigenvalue
#  The estimated number of batches is 1577
#       240/1    0.98482    0.97642 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6786958123705533 for eigenvalue
#  The estimated number of batches is 1599
#       241/1    0.97772    0.97642 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.667588126915078 for eigenvalue
#  The estimated number of batches is 1593
#       242/1    0.98264    0.97645 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.65963502182695 for eigenvalue
#  The estimated number of batches is 1591
#       243/1    0.97917    0.97646 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.650993294836801 for eigenvalue
#  The estimated number of batches is 1588
#       244/1    0.96682    0.97642 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6508507970153916 for eigenvalue
#  The estimated number of batches is 1595
#       245/1    0.96931    0.97639 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6442624482666752 for eigenvalue
#  The estimated number of batches is 1594
#       246/1    0.97783    0.97640 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6394339898012276 for eigenvalue
#  The estimated number of batches is 1595
#       247/1    0.97350    0.97638 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.634451961454265 for eigenvalue
#  The estimated number of batches is 1596
#       248/1    0.97862    0.97639 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.623649468013021 for eigenvalue
#  The estimated number of batches is 1590
#       249/1    0.97260    0.97638 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.61212118289395 for eigenvalue
#  The estimated number of batches is 1583
#       250/1    0.97393    0.97637 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6000914314286234 for eigenvalue
#  The estimated number of batches is 1575
#       251/1    0.96700    0.97633 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.599845842944634 for eigenvalue
#  The estimated number of batches is 1582
#       252/1    0.97141    0.97630 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5892099562943898 for eigenvalue
#  The estimated number of batches is 1576
#       253/1    0.97050    0.97628 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5775916052026715 for eigenvalue
#  The estimated number of batches is 1569
#       254/1    0.97707    0.97628 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.567200123639645 for eigenvalue
#  The estimated number of batches is 1563
#       255/1    0.97865    0.97629 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5570300827576298 for eigenvalue
#  The estimated number of batches is 1557
#       256/1    0.98967    0.97635 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5541797122911403 for eigenvalue
#  The estimated number of batches is 1560
#       257/1    0.97915    0.97636 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5501004569340884 for eigenvalue
#  The estimated number of batches is 1562
#       258/1    0.98605    0.97640 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.543574020451774 for eigenvalue
#  The estimated number of batches is 1560
#       259/1    0.98047    0.97642 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.540451964757289 for eigenvalue
#  The estimated number of batches is 1563
#       260/1    0.98620    0.97646 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5494113154928195 for eigenvalue
#  The estimated number of batches is 1580
#       261/1    0.97443    0.97645 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5422603563125756 for eigenvalue
#  The estimated number of batches is 1578
#       262/1    0.97812    0.97646 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5323317182692344 for eigenvalue
#  The estimated number of batches is 1572
#       263/1    0.97129    0.97644 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.526768341324654 for eigenvalue
#  The estimated number of batches is 1572
#       264/1    0.96914    0.97641 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5150134237968036 for eigenvalue
#  The estimated number of batches is 1564
#       265/1    0.97759    0.97641 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5057990039582236 for eigenvalue
#  The estimated number of batches is 1559
#       266/1    0.96982    0.97639 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5011462853992357 for eigenvalue
#  The estimated number of batches is 1559
#       267/1    0.97917    0.97640 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.491588680984594 for eigenvalue
#  The estimated number of batches is 1554
#       268/1    0.97467    0.97639 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.484140455680908 for eigenvalue
#  The estimated number of batches is 1551
#       269/1    0.97922    0.97640 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4775411351788077 for eigenvalue
#  The estimated number of batches is 1549
#       270/1    0.97444    0.97639 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4692615294453764 for eigenvalue
#  The estimated number of batches is 1545
#       271/1    0.97907    0.97640 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.461286242026093 for eigenvalue
#  The estimated number of batches is 1541
#       272/1    0.98070    0.97642 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4527154056846694 for eigenvalue
#  The estimated number of batches is 1536
#       273/1    0.97958    0.97643 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4454714078495363 for eigenvalue
#  The estimated number of batches is 1534
#       274/1    0.97328    0.97642 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4396240417252617 for eigenvalue
#  The estimated number of batches is 1532
#       275/1    0.96243    0.97637 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4516997553927964 for eigenvalue
#  The estimated number of batches is 1553
#       276/1    0.98054    0.97638 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4433781910264325 for eigenvalue
#  The estimated number of batches is 1549
#       277/1    0.97137    0.97636 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.432949701222397 for eigenvalue
#  The estimated number of batches is 1542
#       278/1    0.96651    0.97632 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4429501109605356 for eigenvalue
#  The estimated number of batches is 1560
#       279/1    0.97861    0.97633 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.434396333808292 for eigenvalue
#  The estimated number of batches is 1555
#       280/1    0.97423    0.97633 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.424670720896212 for eigenvalue
#  The estimated number of batches is 1549
#       281/1    0.98361    0.97635 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.430331868179346 for eigenvalue
#  The estimated number of batches is 1562
#       282/1    0.97783    0.97636 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4219660323760874 for eigenvalue
#  The estimated number of batches is 1557
#       283/1    0.98365    0.97639 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.413912070186989 for eigenvalue
#  The estimated number of batches is 1553
#       284/1    0.97404    0.97638 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4089923059427476 for eigenvalue
#  The estimated number of batches is 1553
#       285/1    0.97396    0.97637 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.39967183908782 for eigenvalue
#  The estimated number of batches is 1546
#       286/1    0.98186    0.97639 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.3943951449066887 for eigenvalue
#  The estimated number of batches is 1546
#       287/1    0.97233    0.97637 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3897964687590076 for eigenvalue
#  The estimated number of batches is 1545
#       288/1    0.97611    0.97637 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.386632246165503 for eigenvalue
#  The estimated number of batches is 1547
#       289/1    0.97027    0.97635 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.380022251651414 for eigenvalue
#  The estimated number of batches is 1544
#       290/1    0.97528    0.97635 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3762532443017386 for eigenvalue
#  The estimated number of batches is 1545
#       291/1    0.97745    0.97635 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3680231624095227 for eigenvalue
#  The estimated number of batches is 1540
#       292/1    0.96899    0.97632 +/- 0.00034
# ...
#  The estimated number of batches is 1500
#      1229/1    0.97085    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1060933072155157 for eigenvalue
#  The estimated number of batches is 1500
#      1230/1    0.97261    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1051591563530816 for eigenvalue
#  The estimated number of batches is 1498
#      1231/1    0.98156    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1049774015912666 for eigenvalue
#  The estimated number of batches is 1499
#      1232/1    0.96721    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1055208812506152 for eigenvalue
#  The estimated number of batches is 1502
#      1233/1    0.98306    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1047328930063058 for eigenvalue
#  The estimated number of batches is 1501
#      1234/1    0.97052    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.106366409293636 for eigenvalue
#  The estimated number of batches is 1506
#      1235/1    0.96421    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1069377378848724 for eigenvalue
#  The estimated number of batches is 1509
#      1236/1    0.98376    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1069889780433193 for eigenvalue
#  The estimated number of batches is 1511
#      1237/1    0.96996    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.106106285796336 for eigenvalue
#  The estimated number of batches is 1509
#      1238/1    0.98181    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1069254839285623 for eigenvalue
#  The estimated number of batches is 1513
#      1239/1    0.97433    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1060670121330405 for eigenvalue
#  The estimated number of batches is 1512
#      1240/1    0.97773    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1052443264365523 for eigenvalue
#  The estimated number of batches is 1511
#      1241/1    0.96787    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1054112741781867 for eigenvalue
#  The estimated number of batches is 1512
#      1242/1    0.98660    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1045899043130614 for eigenvalue
#  The estimated number of batches is 1511
#      1243/1    0.97084    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1049210901859898 for eigenvalue
#  The estimated number of batches is 1514
#      1244/1    0.96976    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1042581326733734 for eigenvalue
#  The estimated number of batches is 1513
#      1245/1    0.98101    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1035786200460063 for eigenvalue
#  The estimated number of batches is 1512
#      1246/1    0.98058    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1026886250080925 for eigenvalue
#  The estimated number of batches is 1511
#      1247/1    0.97529    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.101907055990909 for eigenvalue
#  The estimated number of batches is 1510
#      1248/1    0.97801    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1011521730416178 for eigenvalue
#  The estimated number of batches is 1509
#      1249/1    0.96956    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.100237380442632 for eigenvalue
#  The estimated number of batches is 1508
#      1250/1    0.98301    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0998478201233495 for eigenvalue
#  The estimated number of batches is 1508
#      1251/1    0.98157    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.100967645031207 for eigenvalue
#  The estimated number of batches is 1513
#      1252/1    0.97856    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1001831280458527 for eigenvalue
#  The estimated number of batches is 1512
#      1253/1    0.97122    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0992879265148596 for eigenvalue
#  The estimated number of batches is 1510
#      1254/1    0.97474    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0986245696852213 for eigenvalue
#  The estimated number of batches is 1510
#      1255/1    0.97449    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0977420958931516 for eigenvalue
#  The estimated number of batches is 1509
#      1256/1    0.98053    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0977304884114654 for eigenvalue
#  The estimated number of batches is 1510
#      1257/1    0.97156    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0974186841801439 for eigenvalue
#  The estimated number of batches is 1510
#      1258/1    0.98105    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0969121641780208 for eigenvalue
#  The estimated number of batches is 1510
#      1259/1    0.97751    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0961782722506588 for eigenvalue
#  The estimated number of batches is 1509
#      1260/1    0.96644    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.096100710657983 for eigenvalue
#  The estimated number of batches is 1510
#      1261/1    0.98145    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0955987185981377 for eigenvalue
#  The estimated number of batches is 1510
#      1262/1    0.97280    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0965809992841569 for eigenvalue
#  The estimated number of batches is 1514
#      1263/1    0.97539    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0957297128673853 for eigenvalue
#  The estimated number of batches is 1513
#      1264/1    0.96923    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0966999303032792 for eigenvalue
#  The estimated number of batches is 1517
#      1265/1    0.96752    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.097296967836708 for eigenvalue
#  The estimated number of batches is 1520
#      1266/1    0.97598    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0965920262446183 for eigenvalue
#  The estimated number of batches is 1519
#      1267/1    0.98193    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0957927176524214 for eigenvalue
#  The estimated number of batches is 1518
#      1268/1    0.97817    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.095089860821077 for eigenvalue
#  The estimated number of batches is 1517
#      1269/1    0.97910    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0942306795966072 for eigenvalue
#  The estimated number of batches is 1516
#      1270/1    0.98213    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0940553628829495 for eigenvalue
#  The estimated number of batches is 1517
#      1271/1    0.97418    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0937709985380462 for eigenvalue
#  The estimated number of batches is 1517
#      1272/1    0.98132    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0929475262778114 for eigenvalue
#  The estimated number of batches is 1516
#      1273/1    0.96479    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0923352018359556 for eigenvalue
#  The estimated number of batches is 1516
#      1274/1    0.98386    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0934208369129905 for eigenvalue
#  The estimated number of batches is 1520
#      1275/1    0.97224    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0927466552536897 for eigenvalue
#  The estimated number of batches is 1519
#      1276/1    0.98067    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0921227586646307 for eigenvalue
#  The estimated number of batches is 1519
#      1277/1    0.96302    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0924858571870444 for eigenvalue
#  The estimated number of batches is 1521
#      1278/1    0.97880    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0918195139807767 for eigenvalue
#  The estimated number of batches is 1520
#      1279/1    0.97660    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0914415892376046 for eigenvalue
#  The estimated number of batches is 1520
#      1280/1    0.97260    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0907442471886386 for eigenvalue
#  The estimated number of batches is 1520
#      1281/1    0.97258    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0900604703244803 for eigenvalue
#  The estimated number of batches is 1519
#      1282/1    0.97709    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0892821148190306 for eigenvalue
#  The estimated number of batches is 1518
#      1283/1    0.96756    0.97595 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0893181188210421 for eigenvalue
#  The estimated number of batches is 1519
#      1284/1    0.98777    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.091535879082203 for eigenvalue
#  The estimated number of batches is 1526
#      1285/1    0.98005    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0914817772753178 for eigenvalue
#  The estimated number of batches is 1528
#      1286/1    0.97444    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.091105947128902 for eigenvalue
#  The estimated number of batches is 1528
#      1287/1    0.97482    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0902401772061598 for eigenvalue
#  The estimated number of batches is 1526
#      1288/1    0.97350    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0895713186477751 for eigenvalue
#  The estimated number of batches is 1526
#      1289/1    0.97688    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.089215380388483 for eigenvalue
#  The estimated number of batches is 1526
#      1290/1    0.98073    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0884871911791405 for eigenvalue
#  The estimated number of batches is 1525
#      1291/1    0.97877    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0879265205930502 for eigenvalue
#  The estimated number of batches is 1525
#      1292/1    0.98336    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0877346289276844 for eigenvalue
#  The estimated number of batches is 1525
#      1293/1    0.97638    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.086896762149428 for eigenvalue
#  The estimated number of batches is 1524
#      1294/1    0.97206    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0860746414237037 for eigenvalue
#  The estimated number of batches is 1523
#      1295/1    0.97558    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.085359775207979 for eigenvalue
#  The estimated number of batches is 1522
#      1296/1    0.97264    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0845143542410103 for eigenvalue
#  The estimated number of batches is 1521
#      1297/1    0.97351    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0848146492666833 for eigenvalue
#  The estimated number of batches is 1523
#      1298/1    0.96889    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0842434676056232 for eigenvalue
#  The estimated number of batches is 1523
#      1299/1    0.97892    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0834055512113 for eigenvalue
#  The estimated number of batches is 1522
#      1300/1    0.98267    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0829395131864914 for eigenvalue
#  The estimated number of batches is 1522
#      1301/1    0.97100    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0832927841609739 for eigenvalue
#  The estimated number of batches is 1524
#      1302/1    0.97221    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0826393299800043 for eigenvalue
#  The estimated number of batches is 1523
#      1303/1    0.97754    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0818014459140493 for eigenvalue
#  The estimated number of batches is 1522
#      1304/1    0.98122    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0809947125468515 for eigenvalue
#  The estimated number of batches is 1521
#      1305/1    0.98383    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0810815968139182 for eigenvalue
#  The estimated number of batches is 1522
#      1306/1    0.97811    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0815726711825824 for eigenvalue
#  The estimated number of batches is 1525
#      1307/1    0.97790    0.97598 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0808774607374674 for eigenvalue
#  The estimated number of batches is 1524
#      1308/1    0.97156    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0802811590931483 for eigenvalue
#  The estimated number of batches is 1524
#      1309/1    0.97046    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0795211715703206 for eigenvalue
#  The estimated number of batches is 1523
#      1310/1    0.96903    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0789824568743602 for eigenvalue
#  The estimated number of batches is 1522
#      1311/1    0.97184    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.078414576431992 for eigenvalue
#  The estimated number of batches is 1522
#      1312/1    0.98145    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.077754701918698 for eigenvalue
#  The estimated number of batches is 1521
#      1313/1    0.96765    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.077438742381405 for eigenvalue
#  The estimated number of batches is 1522
#      1314/1    0.98003    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.076823668313342 for eigenvalue
#  The estimated number of batches is 1521
#      1315/1    0.97904    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0760247248539487 for eigenvalue
#  The estimated number of batches is 1520
#      1316/1    0.98103    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0758631858368124 for eigenvalue
#  The estimated number of batches is 1521
#      1317/1    0.97908    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0758352524528256 for eigenvalue
#  The estimated number of batches is 1522
#      1318/1    0.97226    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0750463213428787 for eigenvalue
#  The estimated number of batches is 1521
#      1319/1    0.97053    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0759544009511681 for eigenvalue
#  The estimated number of batches is 1524
#      1320/1    0.97863    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0751362860985432 for eigenvalue
#  The estimated number of batches is 1523
#      1321/1    0.97581    0.97596 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0748751384290995 for eigenvalue
#  The estimated number of batches is 1524
#      1322/1    0.98301    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0741314023465032 for eigenvalue
#  The estimated number of batches is 1523
#      1323/1    0.97168    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0732854140386727 for eigenvalue
#  The estimated number of batches is 1521
#      1324/1    0.97706    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.072483072109089 for eigenvalue
#  The estimated number of batches is 1520
#      1325/1    0.97453    0.97597 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0717138068663674 for eigenvalue
#  The estimated number of batches is 1519
