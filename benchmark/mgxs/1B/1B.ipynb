# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )


zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)



water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.set_density('g/cm3', 0.661)
water.add_s_alpha_beta('c_H_in_H2O')


model.materials = openmc.Materials([uo2, zirconium, water]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
fuel_outer_radius = openmc.ZCylinder(r=0.418)
clad_outer_radius = openmc.ZCylinder(r=0.475)
pitch = 1.26
rod_height=1
left = openmc.XPlane(-pitch/2, boundary_type='reflective')
right = openmc.XPlane(pitch/2, boundary_type='reflective')
bottom = openmc.YPlane(-pitch/2, boundary_type='reflective')
top = openmc.YPlane(pitch/2, boundary_type='reflective')
fuel_region = -fuel_outer_radius
clad_region = +fuel_outer_radius & -clad_outer_radius
water_region = +left & -right & +bottom & -top & +clad_outer_radius
fuel = openmc.Cell(name='fuel')
fuel.fill = uo2
fuel.region = fuel_region
fuel.temperature = 600
clad = openmc.Cell(name='clad')
clad.fill = zirconium
clad.region = clad_region
clad.temperature = 600
moderator = openmc.Cell(name='moderator')
moderator.fill = water
moderator.region = water_region 
moderator.temperature = 600
root_universe = openmc.Universe(cells=(fuel, clad, moderator))
model.geometry = openmc.Geometry(root_universe)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch/2, -pitch/2, -rod_height/2, pitch/2, +pitch/2, rod_height/2]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 20000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
# choose_group=openmc.mgxs.GROUP_STRUCTURES['XMAS-172']
# name_group='XMAS172'
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix']
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Create power tally

# %% [markdown]
# ### Run OpenMC model

# %%
# statepoint_filename = model.run()
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=79.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=2.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=10.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-19 13:51:41
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.17136
#         2/1    1.18804
#         3/1    1.17683
#         4/1    1.18714
#         5/1    1.19290
#         6/1    1.18853
#         7/1    1.18988
#         8/1    1.16563
#         9/1    1.16906
#        10/1    1.20386
#        11/1    1.17678
#        12/1    1.17275
#        13/1    1.17571
#        14/1    1.18618
#        15/1    1.18296
#        16/1    1.15724
#        17/1    1.18684
#        18/1    1.18212
#        19/1    1.18733
#        20/1    1.17527
#        21/1    1.17735
#        22/1    1.19061    1.18398 +/- 0.00663
#        23/1    1.18390    1.18396 +/- 0.00383
#        24/1    1.17841    1.18257 +/- 0.00304
#        25/1    1.17054    1.18016 +/- 0.00337
#        26/1    1.18740    1.18137 +/- 0.00300
#        27/1    1.19320    1.18306 +/- 0.00305
#        28/1    1.18278    1.18302 +/- 0.00264
#        29/1    1.17203    1.18180 +/- 0.00263
#        30/1    1.18969    1.18259 +/- 0.00248
#        31/1    1.18109    1.18245 +/- 0.00225
#        32/1    1.16263    1.18080 +/- 0.00263
#        33/1    1.19130    1.18161 +/- 0.00255
#        34/1    1.18562    1.18190 +/- 0.00238
#        35/1    1.19388    1.18269 +/- 0.00236
#        36/1    1.17433    1.18217 +/- 0.00227
#        37/1    1.17639    1.18183 +/- 0.00216
#        38/1    1.19248    1.18242 +/- 0.00212
#        39/1    1.18259    1.18243 +/- 0.00200
#        40/1    1.18849    1.18274 +/- 0.00192
#        41/1    1.15905    1.18161 +/- 0.00215
#        42/1    1.17957    1.18152 +/- 0.00205
#        43/1    1.17563    1.18126 +/- 0.00198
#        44/1    1.17217    1.18088 +/- 0.00193
#        45/1    1.17396    1.18060 +/- 0.00187
#        46/1    1.16943    1.18017 +/- 0.00185
#        47/1    1.17613    1.18002 +/- 0.00179
#        48/1    1.17511    1.17985 +/- 0.00173
#        49/1    1.19556    1.18039 +/- 0.00175
#        50/1    1.19498    1.18088 +/- 0.00176
#  Triggers unsatisfied, max unc./thresh. is 8.771731579332412 for eigenvalue
#  The estimated number of batches is 2329
#  Creating state point statepoint.00050.h5...
#        51/1    1.17614    1.18072 +/- 0.00171
#  Triggers unsatisfied, max unc./thresh. is 8.684726396352122 for eigenvalue
#  The estimated number of batches is 2359
#        52/1    1.17852    1.18065 +/- 0.00166
#  Triggers unsatisfied, max unc./thresh. is 8.863953345002333 for eigenvalue
#  The estimated number of batches is 2535
#        53/1    1.18189    1.18069 +/- 0.00161
#  Triggers unsatisfied, max unc./thresh. is 8.763615127423426 for eigenvalue
#  The estimated number of batches is 2555
#        54/1    1.19676    1.18116 +/- 0.00163
#  Triggers unsatisfied, max unc./thresh. is 8.752539041726253 for eigenvalue
#  The estimated number of batches is 2625
#        55/1    1.19687    1.18161 +/- 0.00165
#  Triggers unsatisfied, max unc./thresh. is 8.77188517303197 for eigenvalue
#  The estimated number of batches is 2714
#        56/1    1.17495    1.18143 +/- 0.00161
#  Triggers unsatisfied, max unc./thresh. is 8.594897287990898 for eigenvalue
#  The estimated number of batches is 2680
#        57/1    1.19928    1.18191 +/- 0.00164
#  Triggers unsatisfied, max unc./thresh. is 8.672187613505086 for eigenvalue
#  The estimated number of batches is 2803
#        58/1    1.18941    1.18211 +/- 0.00161
#  Triggers unsatisfied, max unc./thresh. is 8.490608063453132 for eigenvalue
#  The estimated number of batches is 2760
#        59/1    1.18909    1.18229 +/- 0.00158
#  Triggers unsatisfied, max unc./thresh. is 8.292195823541029 for eigenvalue
#  The estimated number of batches is 2702
#        60/1    1.17041    1.18199 +/- 0.00156
#  Triggers unsatisfied, max unc./thresh. is 8.160242231023373 for eigenvalue
#  The estimated number of batches is 2684
#        61/1    1.18098    1.18197 +/- 0.00153
#  Triggers unsatisfied, max unc./thresh. is 8.105726839315208 for eigenvalue
#  The estimated number of batches is 2714
#        62/1    1.16963    1.18167 +/- 0.00152
#  Triggers unsatisfied, max unc./thresh. is 7.969015881303408 for eigenvalue
#  The estimated number of batches is 2688
#        63/1    1.18501    1.18175 +/- 0.00148
#  Triggers unsatisfied, max unc./thresh. is 8.014307005371995 for eigenvalue
#  The estimated number of batches is 2782
#        64/1    1.17896    1.18169 +/- 0.00145
#  Triggers unsatisfied, max unc./thresh. is 7.967321978191139 for eigenvalue
#  The estimated number of batches is 2814
#        65/1    1.17420    1.18152 +/- 0.00143
#  Triggers unsatisfied, max unc./thresh. is 7.841185327226089 for eigenvalue
#  The estimated number of batches is 2787
#        66/1    1.18742    1.18165 +/- 0.00140
#  Triggers unsatisfied, max unc./thresh. is 7.895197189183989 for eigenvalue
#  The estimated number of batches is 2888
#        67/1    1.18988    1.18182 +/- 0.00138
#  Triggers unsatisfied, max unc./thresh. is 7.791131463400169 for eigenvalue
#  The estimated number of batches is 2873
#        68/1    1.15443    1.18125 +/- 0.00147
#  Triggers unsatisfied, max unc./thresh. is 8.201438346224517 for eigenvalue
#  The estimated number of batches is 3249
#        69/1    1.18127    1.18125 +/- 0.00144
#  Triggers unsatisfied, max unc./thresh. is 8.221829956017368 for eigenvalue
#  The estimated number of batches is 3333
#        70/1    1.16329    1.18089 +/- 0.00146
#  Triggers unsatisfied, max unc./thresh. is 8.072232704403186 for eigenvalue
#  The estimated number of batches is 3279
#        71/1    1.18535    1.18098 +/- 0.00143
#  Triggers unsatisfied, max unc./thresh. is 7.884056983274225 for eigenvalue
#  The estimated number of batches is 3191
#        72/1    1.17370    1.18084 +/- 0.00141
#  Triggers unsatisfied, max unc./thresh. is 7.763096811876074 for eigenvalue
#  The estimated number of batches is 3154
#        73/1    1.16863    1.18061 +/- 0.00140
#  Triggers unsatisfied, max unc./thresh. is 7.9209057202838835 for eigenvalue
#  The estimated number of batches is 3346
#        74/1    1.19640    1.18090 +/- 0.00141
#  Triggers unsatisfied, max unc./thresh. is 7.806433626822358 for eigenvalue
#  The estimated number of batches is 3311
#        75/1    1.19832    1.18122 +/- 0.00142
#  Triggers unsatisfied, max unc./thresh. is 7.658869872273397 for eigenvalue
#  The estimated number of batches is 3247
#        76/1    1.16788    1.18098 +/- 0.00141
#  Triggers unsatisfied, max unc./thresh. is 7.713310735016186 for eigenvalue
#  The estimated number of batches is 3352
#        77/1    1.19074    1.18115 +/- 0.00140
#  Triggers unsatisfied, max unc./thresh. is 7.8331686429399365 for eigenvalue
#  The estimated number of batches is 3518
#        78/1    1.18628    1.18124 +/- 0.00137
#  Triggers unsatisfied, max unc./thresh. is 7.830778150438426 for eigenvalue
#  The estimated number of batches is 3577
#        79/1    1.18208    1.18125 +/- 0.00135
#  Triggers unsatisfied, max unc./thresh. is 7.8385512390049294 for eigenvalue
#  The estimated number of batches is 3646
#        80/1    1.17742    1.18119 +/- 0.00133
#  Triggers unsatisfied, max unc./thresh. is 8.129841015727381 for eigenvalue
#  The estimated number of batches is 3986
#        81/1    1.19414    1.18140 +/- 0.00133
#  Triggers unsatisfied, max unc./thresh. is 7.959507651058645 for eigenvalue
#  The estimated number of batches is 3885
#        82/1    1.19187    1.18157 +/- 0.00131
#  Triggers unsatisfied, max unc./thresh. is 7.83337057989073 for eigenvalue
#  The estimated number of batches is 3825
#        83/1    1.17264    1.18143 +/- 0.00130
#  Triggers unsatisfied, max unc./thresh. is 7.823268656218731 for eigenvalue
#  The estimated number of batches is 3876
#        84/1    1.17959    1.18140 +/- 0.00128
#  Triggers unsatisfied, max unc./thresh. is 7.70059570886684 for eigenvalue
#  The estimated number of batches is 3816
#        85/1    1.19754    1.18165 +/- 0.00129
#  Triggers unsatisfied, max unc./thresh. is 7.602185935437573 for eigenvalue
#  The estimated number of batches is 3777
#        86/1    1.18236    1.18166 +/- 0.00127
#  Triggers unsatisfied, max unc./thresh. is 7.515099205949467 for eigenvalue
#  The estimated number of batches is 3748
#        87/1    1.16827    1.18146 +/- 0.00126
#  Triggers unsatisfied, max unc./thresh. is 7.402737051459193 for eigenvalue
#  The estimated number of batches is 3692
#        88/1    1.20014    1.18174 +/- 0.00127
#  Triggers unsatisfied, max unc./thresh. is 7.4696133995641025 for eigenvalue
#  The estimated number of batches is 3815
#        89/1    1.18995    1.18185 +/- 0.00126
#  Triggers unsatisfied, max unc./thresh. is 7.329412353023214 for eigenvalue
#  The estimated number of batches is 3727
#        90/1    1.19851    1.18209 +/- 0.00127
#  Triggers unsatisfied, max unc./thresh. is 7.388725533223739 for eigenvalue
#  The estimated number of batches is 3842
#        91/1    1.18420    1.18212 +/- 0.00125
#  Triggers unsatisfied, max unc./thresh. is 7.312424496955679 for eigenvalue
#  The estimated number of batches is 3817
#        92/1    1.18408    1.18215 +/- 0.00123
#  Triggers unsatisfied, max unc./thresh. is 7.217987554675857 for eigenvalue
#  The estimated number of batches is 3772
#        93/1    1.19043    1.18226 +/- 0.00122
#  Triggers unsatisfied, max unc./thresh. is 7.106399672872412 for eigenvalue
#  The estimated number of batches is 3707
#        94/1    1.19368    1.18242 +/- 0.00121
#  Triggers unsatisfied, max unc./thresh. is 7.06377622220103 for eigenvalue
#  The estimated number of batches is 3713
#        95/1    1.17802    1.18236 +/- 0.00120
#  Triggers unsatisfied, max unc./thresh. is 6.981525652829975 for eigenvalue
#  The estimated number of batches is 3676
#        96/1    1.18667    1.18242 +/- 0.00118
#  Triggers unsatisfied, max unc./thresh. is 6.894273449987231 for eigenvalue
#  The estimated number of batches is 3633
#        97/1    1.17984    1.18238 +/- 0.00117
#  Triggers unsatisfied, max unc./thresh. is 6.850534655088096 for eigenvalue
#  The estimated number of batches is 3634
#        98/1    1.18978    1.18248 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 6.856598974002557 for eigenvalue
#  The estimated number of batches is 3688
#        99/1    1.18878    1.18256 +/- 0.00114
#  Triggers unsatisfied, max unc./thresh. is 6.993038936371934 for eigenvalue
#  The estimated number of batches is 3884
#       100/1    1.19054    1.18266 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 6.9307472318732035 for eigenvalue
#  The estimated number of batches is 3863
#       101/1    1.18572    1.18269 +/- 0.00112
#  Triggers unsatisfied, max unc./thresh. is 6.90237831004352 for eigenvalue
#  The estimated number of batches is 3880
#       102/1    1.18315    1.18270 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 6.809149122315445 for eigenvalue
#  The estimated number of batches is 3822
#       103/1    1.18197    1.18269 +/- 0.00109
#  Triggers unsatisfied, max unc./thresh. is 6.757180245373514 for eigenvalue
#  The estimated number of batches is 3810
#       104/1    1.16610    1.18249 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 6.692561992385435 for eigenvalue
#  The estimated number of batches is 3783
#       105/1    1.18503    1.18252 +/- 0.00109
#  Triggers unsatisfied, max unc./thresh. is 6.632641414815328 for eigenvalue
#  The estimated number of batches is 3760
#       106/1    1.17632    1.18245 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 6.5844660369091565 for eigenvalue
#  The estimated number of batches is 3749
#       107/1    1.19112    1.18255 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 6.516942418443753 for eigenvalue
#  The estimated number of batches is 3715
#       108/1    1.18465    1.18257 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 6.462184696619523 for eigenvalue
#  The estimated number of batches is 3695
#       109/1    1.18688    1.18262 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 6.389215236448382 for eigenvalue
#  The estimated number of batches is 3654
#       110/1    1.19441    1.18275 +/- 0.00104
#  Triggers unsatisfied, max unc./thresh. is 6.363027739480098 for eigenvalue
#  The estimated number of batches is 3664
#       111/1    1.17616    1.18268 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.3441855643469145 for eigenvalue
#  The estimated number of batches is 3683
#       112/1    1.20100    1.18288 +/- 0.00104
#  Triggers unsatisfied, max unc./thresh. is 6.304180339861143 for eigenvalue
#  The estimated number of batches is 3677
#       113/1    1.17996    1.18285 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.271076679805475 for eigenvalue
#  The estimated number of batches is 3678
#       114/1    1.19447    1.18297 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.218499298504715 for eigenvalue
#  The estimated number of batches is 3655
#       115/1    1.20364    1.18319 +/- 0.00104
#  Triggers unsatisfied, max unc./thresh. is 6.200255554811036 for eigenvalue
#  The estimated number of batches is 3673
#       116/1    1.17221    1.18308 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 6.11755307742167 for eigenvalue
#  The estimated number of batches is 3613
#       117/1    1.18343    1.18308 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 6.054157305187768 for eigenvalue
#  The estimated number of batches is 3576
#       118/1    1.17740    1.18302 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 5.985861197412553 for eigenvalue
#  The estimated number of batches is 3532
#       119/1    1.17466    1.18294 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.003343631413431 for eigenvalue
#  The estimated number of batches is 3588
#       120/1    1.17373    1.18285 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 5.962801040780443 for eigenvalue
#  The estimated number of batches is 3576
#       121/1    1.15960    1.18262 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 5.937848279917066 for eigenvalue
#  The estimated number of batches is 3582
#       122/1    1.18391    1.18263 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 5.882730748659884 for eigenvalue
#  The estimated number of batches is 3550
#       123/1    1.18503    1.18265 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 5.851578463277832 for eigenvalue
#  The estimated number of batches is 3547
#       124/1    1.19893    1.18281 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 5.819015917380722 for eigenvalue
#  The estimated number of batches is 3542
#       125/1    1.19523    1.18293 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 5.7944127494327144 for eigenvalue
#  The estimated number of batches is 3546
#       126/1    1.18216    1.18292 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 5.8047816176271 for eigenvalue
#  The estimated number of batches is 3592
#       127/1    1.19464    1.18303 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 5.770906098085271 for eigenvalue
#  The estimated number of batches is 3584
#       128/1    1.18567    1.18305 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 5.747612665490039 for eigenvalue
#  The estimated number of batches is 3588
#       129/1    1.16615    1.18290 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 5.783566309587478 for eigenvalue
#  The estimated number of batches is 3667
#       130/1    1.18165    1.18289 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 5.749767867075752 for eigenvalue
#  The estimated number of batches is 3657
#       131/1    1.18454    1.18290 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 5.701281701426251 for eigenvalue
#  The estimated number of batches is 3629
#       132/1    1.17447    1.18283 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 5.646432395067645 for eigenvalue
#  The estimated number of batches is 3591
#       133/1    1.18957    1.18289 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.599393263195893 for eigenvalue
#  The estimated number of batches is 3563
#       134/1    1.17010    1.18277 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.575456321090364 for eigenvalue
#  The estimated number of batches is 3564
#       135/1    1.17375    1.18269 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.540242198921392 for eigenvalue
#  The estimated number of batches is 3550
#       136/1    1.16611    1.18255 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.526366237056354 for eigenvalue
#  The estimated number of batches is 3563
#       137/1    1.19473    1.18266 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.501691010630835 for eigenvalue
#  The estimated number of batches is 3562
#       138/1    1.17293    1.18257 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.448790200129449 for eigenvalue
#  The estimated number of batches is 3524
#       139/1    1.18940    1.18263 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.420697003493307 for eigenvalue
#  The estimated number of batches is 3517
#       140/1    1.15988    1.18244 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.448862873838788 for eigenvalue
#  The estimated number of batches is 3583
#       141/1    1.16367    1.18229 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.526847635549255 for eigenvalue
#  The estimated number of batches is 3717
#       142/1    1.16807    1.18217 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.651587731048268 for eigenvalue
#  The estimated number of batches is 3917
#       143/1    1.17079    1.18208 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.632733580680787 for eigenvalue
#  The estimated number of batches is 3923
#       144/1    1.16692    1.18196 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.578424439609443 for eigenvalue
#  The estimated number of batches is 3879
#       145/1    1.17610    1.18191 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.6816785529634 for eigenvalue
#  The estimated number of batches is 4056
#       146/1    1.18108    1.18190 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.65014506717002 for eigenvalue
#  The estimated number of batches is 4043
#       147/1    1.17795    1.18187 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.630419357360079 for eigenvalue
#  The estimated number of batches is 4047
#       148/1    1.16585    1.18175 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.675816179455386 for eigenvalue
#  The estimated number of batches is 4144
#       149/1    1.18286    1.18175 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.642650663130492 for eigenvalue
#  The estimated number of batches is 4128
#       150/1    1.19127    1.18183 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.59999442765206 for eigenvalue
#  The estimated number of batches is 4097
#       151/1    1.18726    1.18187 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 5.554002244707491 for eigenvalue
#  The estimated number of batches is 4061
#       152/1    1.18223    1.18187 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.510792063317211 for eigenvalue
#  The estimated number of batches is 4029
#       153/1    1.18209    1.18187 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.521448194417826 for eigenvalue
#  The estimated number of batches is 4075
#       154/1    1.18977    1.18193 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 5.48303929438029 for eigenvalue
#  The estimated number of batches is 4049
#       155/1    1.18774    1.18197 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 5.535733774535701 for eigenvalue
#  The estimated number of batches is 4157
#       156/1    1.18817    1.18202 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.503122419326204 for eigenvalue
#  The estimated number of batches is 4139
#       157/1    1.16695    1.18191 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.4859097995543955 for eigenvalue
#  The estimated number of batches is 4144
#       158/1    1.17654    1.18187 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.4515161945890975 for eigenvalue
#  The estimated number of batches is 4122
#       159/1    1.17938    1.18185 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.415158106551922 for eigenvalue
#  The estimated number of batches is 4097
#       160/1    1.17204    1.18178 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 5.3859494547938525 for eigenvalue
#  The estimated number of batches is 4082
#       161/1    1.18700    1.18182 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.347613882123285 for eigenvalue
#  The estimated number of batches is 4053
#       162/1    1.18447    1.18184 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.303268180986149 for eigenvalue
#  The estimated number of batches is 4014
#       163/1    1.19311    1.18192 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.289012854945695 for eigenvalue
#  The estimated number of batches is 4021
#       164/1    1.16003    1.18177 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.254381736401564 for eigenvalue
#  The estimated number of batches is 3996
#       165/1    1.17235    1.18170 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.251747921211564 for eigenvalue
#  The estimated number of batches is 4020
#       166/1    1.16846    1.18161 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.243320581025898 for eigenvalue
#  The estimated number of batches is 4034
#       167/1    1.18490    1.18163 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.200151369543247 for eigenvalue
#  The estimated number of batches is 3996
#       168/1    1.19964    1.18175 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.297373513184485 for eigenvalue
#  The estimated number of batches is 4174
#       169/1    1.15902    1.18160 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.312401684006624 for eigenvalue
#  The estimated number of batches is 4226
#       170/1    1.17992    1.18159 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.282396868825788 for eigenvalue
#  The estimated number of batches is 4206
#       171/1    1.17455    1.18154 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.2916098008969445 for eigenvalue
#  The estimated number of batches is 4249
#       172/1    1.18310    1.18155 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.263106139522279 for eigenvalue
#  The estimated number of batches is 4231
#       173/1    1.16801    1.18147 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.311439968786334 for eigenvalue
#  The estimated number of batches is 4337
#       174/1    1.16112    1.18133 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.3190947825941395 for eigenvalue
#  The estimated number of batches is 4378
#       175/1    1.17139    1.18127 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.351640195383514 for eigenvalue
#  The estimated number of batches is 4460
#       176/1    1.18720    1.18131 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.332561432177534 for eigenvalue
#  The estimated number of batches is 4457
#       177/1    1.18571    1.18134 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.301095992681833 for eigenvalue
#  The estimated number of batches is 4432
#       178/1    1.18264    1.18134 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.263283035613306 for eigenvalue
#  The estimated number of batches is 4397
#       179/1    1.18419    1.18136 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.230227241623536 for eigenvalue
#  The estimated number of batches is 4370
#       180/1    1.18010    1.18135 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.200830452815726 for eigenvalue
#  The estimated number of batches is 4348
#       181/1    1.19162    1.18142 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.1732361975558 for eigenvalue
#  The estimated number of batches is 4329
#       182/1    1.18960    1.18147 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.1707625449416765 for eigenvalue
#  The estimated number of batches is 4352
#       183/1    1.17951    1.18146 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.1620482528477 for eigenvalue
#  The estimated number of batches is 4364
#       184/1    1.19095    1.18151 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.163499919502536 for eigenvalue
#  The estimated number of batches is 4393
#       185/1    1.18461    1.18153 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.155386181607057 for eigenvalue
#  The estimated number of batches is 4406
#       186/1    1.19473    1.18161 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.1254378041434725 for eigenvalue
#  The estimated number of batches is 4381
#       187/1    1.17252    1.18156 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.09377070820826 for eigenvalue
#  The estimated number of batches is 4354
#       188/1    1.19128    1.18162 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.064171793289338 for eigenvalue
#  The estimated number of batches is 4329
#       189/1    1.20140    1.18173 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.063779405807985 for eigenvalue
#  The estimated number of batches is 4354
#       190/1    1.17651    1.18170 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.0401116231440515 for eigenvalue
#  The estimated number of batches is 4339
#       191/1    1.17758    1.18168 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.057114685428784 for eigenvalue
#  The estimated number of batches is 4394
#       192/1    1.18247    1.18168 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.057331000306524 for eigenvalue
#  The estimated number of batches is 4420
#       193/1    1.19998    1.18179 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.029908911660722 for eigenvalue
#  The estimated number of batches is 4397
#       194/1    1.20230    1.18191 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.019678217399357 for eigenvalue
#  The estimated number of batches is 4405
#       195/1    1.18493    1.18192 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.9881126420498765 for eigenvalue
#  The estimated number of batches is 4375
#       196/1    1.16615    1.18183 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.971444978616526 for eigenvalue
#  The estimated number of batches is 4370
#       197/1    1.17214    1.18178 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.9546882803824515 for eigenvalue
#  The estimated number of batches is 4366
#       198/1    1.16956    1.18171 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.933063157522571 for eigenvalue
#  The estimated number of batches is 4352
#       199/1    1.19913    1.18181 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.918094512114921 for eigenvalue
#  The estimated number of batches is 4350
#       200/1    1.17388    1.18176 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.937211728811879 for eigenvalue
#  The estimated number of batches is 4408
#       201/1    1.17623    1.18173 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.926650306141674 for eigenvalue
#  The estimated number of batches is 4414
#       202/1    1.17620    1.18170 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.901236444507608 for eigenvalue
#  The estimated number of batches is 4393
#       203/1    1.17626    1.18167 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.880035899826691 for eigenvalue
#  The estimated number of batches is 4379
#       204/1    1.18294    1.18168 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.85800318282376 for eigenvalue
#  The estimated number of batches is 4363
#       205/1    1.17756    1.18166 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.848343692089464 for eigenvalue
#  The estimated number of batches is 4369
#       206/1    1.19227    1.18171 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.879986830911909 for eigenvalue
#  The estimated number of batches is 4450
#       207/1    1.17282    1.18167 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.853537499175074 for eigenvalue
#  The estimated number of batches is 4426
#       208/1    1.19196    1.18172 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.83218478435685 for eigenvalue
#  The estimated number of batches is 4410
#       209/1    1.18635    1.18175 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.803989080884832 for eigenvalue
#  The estimated number of batches is 4382
#       210/1    1.17700    1.18172 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.781841436839172 for eigenvalue
#  The estimated number of batches is 4365
#       211/1    1.16751    1.18165 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.760097758608173 for eigenvalue
#  The estimated number of batches is 4348
#       212/1    1.18353    1.18166 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.731164736488285 for eigenvalue
#  The estimated number of batches is 4318
#       213/1    1.20418    1.18177 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.72422225563507 for eigenvalue
#  The estimated number of batches is 4328
#       214/1    1.18068    1.18177 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.701388913986444 for eigenvalue
#  The estimated number of batches is 4308
#       215/1    1.18744    1.18180 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.693483106149973 for eigenvalue
#  The estimated number of batches is 4316
#       216/1    1.15238    1.18165 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.704001667862771 for eigenvalue
#  The estimated number of batches is 4358
#       217/1    1.18033    1.18164 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.679296656602723 for eigenvalue
#  The estimated number of batches is 4334
#       218/1    1.17497    1.18161 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.657564096910947 for eigenvalue
#  The estimated number of batches is 4316
#       219/1    1.15815    1.18149 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.644991400472392 for eigenvalue
#  The estimated number of batches is 4314
#       220/1    1.17392    1.18145 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.615843941099606 for eigenvalue
#  The estimated number of batches is 4282
#       221/1    1.17734    1.18143 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.629734653341001 for eigenvalue
#  The estimated number of batches is 4329
#       222/1    1.19375    1.18149 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.636936212535997 for eigenvalue
#  The estimated number of batches is 4364
#       223/1    1.15211    1.18135 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.653259506869666 for eigenvalue
#  The estimated number of batches is 4416
#       224/1    1.17607    1.18132 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.654933182631954 for eigenvalue
#  The estimated number of batches is 4441
#       225/1    1.18444    1.18134 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.634114647746593 for eigenvalue
#  The estimated number of batches is 4423
#       226/1    1.19641    1.18141 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.646782830473666 for eigenvalue
#  The estimated number of batches is 4469
#       227/1    1.19216    1.18146 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.620741530633903 for eigenvalue
#  The estimated number of batches is 4440
#       228/1    1.17440    1.18143 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.5988143060822795 for eigenvalue
#  The estimated number of batches is 4420
#       229/1    1.17867    1.18141 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.587453914511559 for eigenvalue
#  The estimated number of batches is 4419
#       230/1    1.18049    1.18141 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.565415879214301 for eigenvalue
#  The estimated number of batches is 4398
#       231/1    1.19233    1.18146 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.5533915690795785 for eigenvalue
#  The estimated number of batches is 4395
#       232/1    1.17614    1.18144 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.530786720828169 for eigenvalue
#  The estimated number of batches is 4372
#       233/1    1.20420    1.18154 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.516341640139461 for eigenvalue
#  The estimated number of batches is 4365
#       234/1    1.17746    1.18152 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.503175980225601 for eigenvalue
#  The estimated number of batches is 4360
#       235/1    1.17844    1.18151 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.485999324103391 for eigenvalue
#  The estimated number of batches is 4347
#       236/1    1.18013    1.18150 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.473905602182645 for eigenvalue
#  The estimated number of batches is 4344
#       237/1    1.18176    1.18150 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.471482748188746 for eigenvalue
#  The estimated number of batches is 4359
#       238/1    1.18598    1.18152 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.479781239677112 for eigenvalue
#  The estimated number of batches is 4395
#       239/1    1.17594    1.18150 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.457993636654612 for eigenvalue
#  The estimated number of batches is 4373
#       240/1    1.17797    1.18148 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.442585319525999 for eigenvalue
#  The estimated number of batches is 4363
#       241/1    1.16431    1.18141 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.4186211029332485 for eigenvalue
#  The estimated number of batches is 4335
#       242/1    1.17789    1.18139 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.398517723274912 for eigenvalue
#  The estimated number of batches is 4316
#       243/1    1.16644    1.18132 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.434618087148312 for eigenvalue
#  The estimated number of batches is 4406
#       244/1    1.18368    1.18133 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.443928313042369 for eigenvalue
#  The estimated number of batches is 4444
#       245/1    1.17506    1.18131 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.434421449552074 for eigenvalue
#  The estimated number of batches is 4445
#       246/1    1.18235    1.18131 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.415279302208912 for eigenvalue
#  The estimated number of batches is 4426
#       247/1    1.17963    1.18130 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.396129427867327 for eigenvalue
#  The estimated number of batches is 4407
#       248/1    1.18860    1.18133 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.377518898045687 for eigenvalue
#  The estimated number of batches is 4390
#       249/1    1.19147    1.18138 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.36544280293021 for eigenvalue
#  The estimated number of batches is 4385
#       250/1    1.20767    1.18149 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.395397864471941 for eigenvalue
#  The estimated number of batches is 4464
#       251/1    1.18401    1.18150 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.3802130720282575 for eigenvalue
#  The estimated number of batches is 4453
#       252/1    1.19482    1.18156 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.3645420682571885 for eigenvalue
#  The estimated number of batches is 4440
#       253/1    1.15489    1.18145 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.377038466781157 for eigenvalue
#  The estimated number of batches is 4484
#       254/1    1.17156    1.18140 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.3587123204236855 for eigenvalue
#  The estimated number of batches is 4466
#       255/1    1.19083    1.18144 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.341798688199956 for eigenvalue
#  The estimated number of batches is 4451
#       256/1    1.15935    1.18135 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.32451388840876 for eigenvalue
#  The estimated number of batches is 4434
#       257/1    1.17510    1.18132 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.3183629855667105 for eigenvalue
#  The estimated number of batches is 4440
#       258/1    1.20627    1.18143 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.315843582064467 for eigenvalue
#  The estimated number of batches is 4454
#       259/1    1.19328    1.18148 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.297559291864062 for eigenvalue
#  The estimated number of batches is 4435
#       260/1    1.19255    1.18153 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.2858301805717876 for eigenvalue
#  The estimated number of batches is 4429
#       261/1    1.17180    1.18148 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.268601834527045 for eigenvalue
#  The estimated number of batches is 4412
#       262/1    1.17578    1.18146 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.260299988777262 for eigenvalue
#  The estimated number of batches is 4413
#       263/1    1.18530    1.18148 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.247092973903598 for eigenvalue
#  The estimated number of batches is 4404
#       264/1    1.19532    1.18153 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.230567521791998 for eigenvalue
#  The estimated number of batches is 4388
#       265/1    1.18624    1.18155 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.2142124047914535 for eigenvalue
#  The estimated number of batches is 4372
#       266/1    1.17362    1.18152 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.215054270828938 for eigenvalue
#  The estimated number of batches is 4391
#       267/1    1.17059    1.18148 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.204907889086164 for eigenvalue
#  The estimated number of batches is 4388
#       268/1    1.17809    1.18146 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.189318428149253 for eigenvalue
#  The estimated number of batches is 4373
#       269/1    1.18494    1.18148 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.175329916434423 for eigenvalue
#  The estimated number of batches is 4361
#       270/1    1.17897    1.18147 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.165347464847237 for eigenvalue
#  The estimated number of batches is 4358
#       271/1    1.16823    1.18141 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.154380249610186 for eigenvalue
#  The estimated number of batches is 4352
#       272/1    1.17120    1.18137 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.149989667595302 for eigenvalue
#  The estimated number of batches is 4361
#       273/1    1.18053    1.18137 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.139305567335291 for eigenvalue
#  The estimated number of batches is 4355
#       274/1    1.18712    1.18139 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.14336198950137 for eigenvalue
#  The estimated number of batches is 4381
#       275/1    1.17166    1.18135 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.14156305062688 for eigenvalue
#  The estimated number of batches is 4394
#       276/1    1.18481    1.18137 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.12662896933093 for eigenvalue
#  The estimated number of batches is 4380
#       277/1    1.18314    1.18138 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.139951455914112 for eigenvalue
#  The estimated number of batches is 4425
#       278/1    1.17587    1.18135 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.129740632985254 for eigenvalue
#  The estimated number of batches is 4421
#       279/1    1.17064    1.18131 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.128192464753999 for eigenvalue
#  The estimated number of batches is 4434
#       280/1    1.19069    1.18135 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.1130820226534475 for eigenvalue
#  The estimated number of batches is 4419
#       281/1    1.17864    1.18134 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.099556462216987 for eigenvalue
#  The estimated number of batches is 4407
#       282/1    1.17892    1.18133 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.0878231180490125 for eigenvalue
#  The estimated number of batches is 4399
#       283/1    1.17651    1.18131 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.072125264433288 for eigenvalue
#  The estimated number of batches is 4382
#       284/1    1.17336    1.18128 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.067208012054742 for eigenvalue
#  The estimated number of batches is 4388
#       285/1    1.17731    1.18127 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.061276876086677 for eigenvalue
#  The estimated number of batches is 4391
#       286/1    1.15882    1.18118 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.100500038923226 for eigenvalue
#  The estimated number of batches is 4493
#       287/1    1.18202    1.18118 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.087872252331133 for eigenvalue
#  The estimated number of batches is 4482
#       288/1    1.17220    1.18115 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.072845329823785 for eigenvalue
#  The estimated number of batches is 4466
#       289/1    1.17349    1.18112 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.061427694349328 for eigenvalue
#  The estimated number of batches is 4458
#       290/1    1.18631    1.18114 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.049688666894837 for eigenvalue
#  The estimated number of batches is 4448
#       291/1    1.17175    1.18111 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.043698844525706 for eigenvalue
#  The estimated number of batches is 4452
#       292/1    1.18575    1.18112 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.03089028890934 for eigenvalue
#  The estimated number of batches is 4440
#       293/1    1.18767    1.18115 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.020045173098318 for eigenvalue
#  The estimated number of batches is 4432
#       294/1    1.17894    1.18114 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.009110130405357 for eigenvalue
#  The estimated number of batches is 4424
#       295/1    1.17085    1.18110 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.00890785237117 for eigenvalue
#  The estimated number of batches is 4440
#       296/1    1.18689    1.18112 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.993751627800536 for eigenvalue
#  The estimated number of batches is 4423
#       297/1    1.18550    1.18114 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.97956967845376 for eigenvalue
#  The estimated number of batches is 4407
#       298/1    1.17815    1.18113 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.966323704748173 for eigenvalue
# ...
#  Triggers unsatisfied, max unc./thresh. is 1.0657106613063483 for eigenvalue
#  The estimated number of batches is 4194
#      3696/1    1.17197    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0654197796369564 for eigenvalue
#  The estimated number of batches is 4193
#      3697/1    1.19055    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.065168933551558 for eigenvalue
#  The estimated number of batches is 4192
#      3698/1    1.18261    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0649180075636655 for eigenvalue
#  The estimated number of batches is 4192
#      3699/1    1.18337    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.064645615351134 for eigenvalue
#  The estimated number of batches is 4191
#      3700/1    1.19058    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0643621633239961 for eigenvalue
#  The estimated number of batches is 4189
#      3701/1    1.17887    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.064175028735857 for eigenvalue
#  The estimated number of batches is 4189
#      3702/1    1.17768    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0639934213199844 for eigenvalue
#  The estimated number of batches is 4189
#      3703/1    1.18017    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0637769979863336 for eigenvalue
#  The estimated number of batches is 4188
#      3704/1    1.16927    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0636060694567002 for eigenvalue
#  The estimated number of batches is 4188
#      3705/1    1.17839    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.063553231874431 for eigenvalue
#  The estimated number of batches is 4189
#      3706/1    1.18968    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0632678552178394 for eigenvalue
#  The estimated number of batches is 4188
#      3707/1    1.18486    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0629861783435446 for eigenvalue
#  The estimated number of batches is 4187
#      3708/1    1.18604    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0628298866306944 for eigenvalue
#  The estimated number of batches is 4186
#      3709/1    1.17960    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0625875695228837 for eigenvalue
#  The estimated number of batches is 4186
#      3710/1    1.17150    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0623458350714017 for eigenvalue
#  The estimated number of batches is 4185
#      3711/1    1.19058    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0620830928386344 for eigenvalue
#  The estimated number of batches is 4184
#      3712/1    1.19748    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0621261329530791 for eigenvalue
#  The estimated number of batches is 4185
#      3713/1    1.17312    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.061904955089228 for eigenvalue
#  The estimated number of batches is 4185
#      3714/1    1.16933    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0620021101010606 for eigenvalue
#  The estimated number of batches is 4187
#      3715/1    1.17227    1.18173 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0617330307154342 for eigenvalue
#  The estimated number of batches is 4186
#      3716/1    1.18525    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0614577141277588 for eigenvalue
#  The estimated number of batches is 4185
#      3717/1    1.18478    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0611768797863887 for eigenvalue
#  The estimated number of batches is 4184
#      3718/1    1.18832    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0609594885360911 for eigenvalue
#  The estimated number of batches is 4183
#      3719/1    1.18923    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060682798730148 for eigenvalue
#  The estimated number of batches is 4182
#      3720/1    1.16803    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060441122666233 for eigenvalue
#  The estimated number of batches is 4181
#      3721/1    1.20073    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.061605069507172 for eigenvalue
#  The estimated number of batches is 4192
#      3722/1    1.18053    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0613274325436481 for eigenvalue
#  The estimated number of batches is 4190
#      3723/1    1.19844    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0611215738654027 for eigenvalue
#  The estimated number of batches is 4190
#      3724/1    1.19319    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0612236177749974 for eigenvalue
#  The estimated number of batches is 4192
#      3725/1    1.19320    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0609471297672217 for eigenvalue
#  The estimated number of batches is 4191
#      3726/1    1.20473    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0607920198118483 for eigenvalue
#  The estimated number of batches is 4191
#      3727/1    1.18436    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0606213546189616 for eigenvalue
#  The estimated number of batches is 4191
#      3728/1    1.19082    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0605130774326077 for eigenvalue
#  The estimated number of batches is 4191
#      3729/1    1.20670    1.18177 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060866702477327 for eigenvalue
#  The estimated number of batches is 4195
#      3730/1    1.18168    1.18177 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0605847392002203 for eigenvalue
#  The estimated number of batches is 4194
#      3731/1    1.16811    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060777372616809 for eigenvalue
#  The estimated number of batches is 4196
#      3732/1    1.18486    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060501949677784 for eigenvalue
#  The estimated number of batches is 4195
#      3733/1    1.19860    1.18177 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060484142520579 for eigenvalue
#  The estimated number of batches is 4196
#      3734/1    1.18167    1.18177 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0602305840841222 for eigenvalue
#  The estimated number of batches is 4195
#      3735/1    1.17956    1.18177 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060243455204724 for eigenvalue
#  The estimated number of batches is 4197
#      3736/1    1.18572    1.18177 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0603407591034086 for eigenvalue
#  The estimated number of batches is 4198
#      3737/1    1.16395    1.18177 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060674927044583 for eigenvalue
#  The estimated number of batches is 4202
#      3738/1    1.17572    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.060389827473834 for eigenvalue
#  The estimated number of batches is 4201
#      3739/1    1.17975    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0601907457552486 for eigenvalue
#  The estimated number of batches is 4201
#      3740/1    1.18052    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0599395903864055 for eigenvalue
#  The estimated number of batches is 4200
#      3741/1    1.18617    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0597127652738705 for eigenvalue
#  The estimated number of batches is 4199
#      3742/1    1.17213    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0594377797385532 for eigenvalue
#  The estimated number of batches is 4198
#      3743/1    1.18566    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0592211770732036 for eigenvalue
#  The estimated number of batches is 4198
#      3744/1    1.19016    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0592022825158853 for eigenvalue
#  The estimated number of batches is 4198
#      3745/1    1.16919    1.18176 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0590116052108907 for eigenvalue
#  The estimated number of batches is 4198
#      3746/1    1.15835    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.058716059131869 for eigenvalue
#  The estimated number of batches is 4197
#      3747/1    1.16909    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0585925427433194 for eigenvalue
#  The estimated number of batches is 4197
#      3748/1    1.17929    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0583328113184762 for eigenvalue
#  The estimated number of batches is 4196
#      3749/1    1.18325    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.058094235605725 for eigenvalue
#  The estimated number of batches is 4195
#      3750/1    1.17767    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.057813760794549 for eigenvalue
#  The estimated number of batches is 4194
#      3751/1    1.18672    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0575432308625428 for eigenvalue
#  The estimated number of batches is 4193
#      3752/1    1.17397    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.057354120093767 for eigenvalue
#  The estimated number of batches is 4193
#      3753/1    1.18742    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0570788296552094 for eigenvalue
#  The estimated number of batches is 4192
#      3754/1    1.16853    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0570621927591375 for eigenvalue
#  The estimated number of batches is 4193
#      3755/1    1.17961    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.056916075806912 for eigenvalue
#  The estimated number of batches is 4193
#      3756/1    1.16800    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0568540280576495 for eigenvalue
#  The estimated number of batches is 4193
#      3757/1    1.18824    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.056825395882614 for eigenvalue
#  The estimated number of batches is 4194
#      3758/1    1.17216    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0568938212246095 for eigenvalue
#  The estimated number of batches is 4196
#      3759/1    1.17472    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.056699809278224 for eigenvalue
#  The estimated number of batches is 4196
#      3760/1    1.18112    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0564954832086957 for eigenvalue
#  The estimated number of batches is 4195
#      3761/1    1.18067    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0565045390752708 for eigenvalue
#  The estimated number of batches is 4196
#      3762/1    1.18725    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0563000348022609 for eigenvalue
#  The estimated number of batches is 4196
#      3763/1    1.18790    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0560753080333463 for eigenvalue
#  The estimated number of batches is 4195
#      3764/1    1.17415    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0561024314023033 for eigenvalue
#  The estimated number of batches is 4196
#      3765/1    1.17787    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0561991862950262 for eigenvalue
#  The estimated number of batches is 4198
#      3766/1    1.19109    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0559752009668768 for eigenvalue
#  The estimated number of batches is 4198
#      3767/1    1.18462    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0557090548698977 for eigenvalue
#  The estimated number of batches is 4197
#      3768/1    1.18188    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.055439579124387 for eigenvalue
#  The estimated number of batches is 4196
#      3769/1    1.17493    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0551732743386673 for eigenvalue
#  The estimated number of batches is 4195
#      3770/1    1.17560    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0548971562030989 for eigenvalue
#  The estimated number of batches is 4194
#      3771/1    1.18143    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.054618313876125 for eigenvalue
#  The estimated number of batches is 4192
#      3772/1    1.17596    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0545254225117109 for eigenvalue
#  The estimated number of batches is 4193
#      3773/1    1.18876    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0545460532379953 for eigenvalue
#  The estimated number of batches is 4194
#      3774/1    1.18605    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0542770759489992 for eigenvalue
#  The estimated number of batches is 4193
#      3775/1    1.17259    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0540117659261337 for eigenvalue
#  The estimated number of batches is 4192
#      3776/1    1.18446    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.053761805094407 for eigenvalue
#  The estimated number of batches is 4191
#      3777/1    1.19325    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.053553768220804 for eigenvalue
#  The estimated number of batches is 4191
#      3778/1    1.17255    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0532752323355665 for eigenvalue
#  The estimated number of batches is 4190
#      3779/1    1.18083    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.052992596089245 for eigenvalue
#  The estimated number of batches is 4188
#      3780/1    1.19080    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0527224667543356 for eigenvalue
#  The estimated number of batches is 4187
#      3781/1    1.19594    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0525335730487875 for eigenvalue
#  The estimated number of batches is 4187
#      3782/1    1.18030    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0523422489106111 for eigenvalue
#  The estimated number of batches is 4187
#      3783/1    1.18340    1.18175 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0520669990861735 for eigenvalue
#  The estimated number of batches is 4186
#      3784/1    1.16433    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.051909392123305 for eigenvalue
#  The estimated number of batches is 4185
#      3785/1    1.17108    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.051642993246541 for eigenvalue
#  The estimated number of batches is 4184
#      3786/1    1.17307    1.18174 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.051384932930416 for eigenvalue
#  The estimated number of batches is 4183
#      3787/1    1.17246    1.18173 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.051804169497742 for eigenvalue
#  The estimated number of batches is 4188
#      3788/1    1.18099    1.18173 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0516217911852856 for eigenvalue
#  The estimated number of batches is 4188
#      3789/1    1.16266    1.18173 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.052229347856719 for eigenvalue
#  The estimated number of batches is 4193
#      3790/1    1.18376    1.18173 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0519553779416164 for eigenvalue
#  The estimated number of batches is 4192
#      3791/1    1.18144    1.18173 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0517711139584693 for eigenvalue
#  The estimated number of batches is 4192
#      3792/1    1.17105    1.18173 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0515057490792 for eigenvalue
#  The estimated number of batches is 4191

# %% [markdown]
# ce_spfile = './statepoint_ce.h5'
# os.rename(statepoint_filename, ce_spfile)
# ce_sumfile = './summary_ce.h5'
# os.rename('summary.h5', ce_sumfile)
# sp = openmc.StatePoint(ce_spfile, autolink=False)
# su = openmc.Summary(ce_sumfile)
# sp.link_with_summary(su)

# %% [markdown]
# mgxs_lib.load_from_statepoint(sp)
# mgxs_file = mgxs_lib.create_mg_library(xs_type='macro', xsdata_names=['fuel', 'clad', 'moderator'])
# mgxs_file.xsdatas[0].temperatures=[565.]
# mgxs_file.xsdatas[1].temperatures=[565.]
# mgxs_file.xsdatas[2].temperatures=[565.]
# mgxs_file.export_to_hdf5('mgxs_order1.h5')
