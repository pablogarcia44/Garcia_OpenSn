# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600


zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600



water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.set_density('g/cm3', 0.661)
water.temperature=600
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.178E-03 )


model.materials = openmc.Materials([uo2, zirconium, water,helium])

#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
fuel_outer_radius = openmc.ZCylinder(r=0.4096)
clad_inner_radius = openmc.ZCylinder(r=0.418)
clad_outer_radius = openmc.ZCylinder(r=0.475)
pitch = 1.26
rod_height=1
left = openmc.XPlane(-pitch/2, boundary_type='reflective')
right = openmc.XPlane(pitch/2, boundary_type='reflective')
bottom = openmc.YPlane(-pitch/2, boundary_type='reflective')
top = openmc.YPlane(pitch/2, boundary_type='reflective')
fuel_region = -fuel_outer_radius
gap_region = +fuel_outer_radius & -clad_inner_radius
clad_region = +clad_inner_radius & -clad_outer_radius
water_region = +left & -right & +bottom & -top & +clad_outer_radius
fuel = openmc.Cell(name='fuel')
fuel.fill = uo2
fuel.region = fuel_region
gap = openmc.Cell(name='gap')
gap.region = gap_region
gap.fill = helium    
clad = openmc.Cell(name='clad')
clad.fill = zirconium
clad.region = clad_region
moderator = openmc.Cell(name='moderator')
moderator.fill = water
moderator.region = water_region 
root_universe = openmc.Universe(cells=(fuel ,gap, clad, moderator))
model.geometry = openmc.Geometry(root_universe)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch/2, -pitch/2, -rod_height/2, pitch/2, +pitch/2, rod_height/2]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 20000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
# choose_group=openmc.mgxs.GROUP_STRUCTURES['XMAS-172']
# name_group='XMAS172'
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix']
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Create power tally

# %% [markdown]
# ### Run OpenMC model

# %%
# statepoint_filename = model.run()
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=113.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=2.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=10.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-21 16:47:30
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.19255
#         2/1    1.17488
#         3/1    1.18266
#         4/1    1.19120
#         5/1    1.18311
#         6/1    1.19560
#         7/1    1.20070
#         8/1    1.19470
#         9/1    1.20607
#        10/1    1.18759
#        11/1    1.17796
#        12/1    1.17844
#        13/1    1.17381
#        14/1    1.18364
#        15/1    1.17389
#        16/1    1.17604
#        17/1    1.18713
#        18/1    1.18833
#        19/1    1.18561
#        20/1    1.17909
#        21/1    1.17168
#        22/1    1.16930    1.17049 +/- 0.00119
#        23/1    1.18335    1.17478 +/- 0.00434
#        24/1    1.16606    1.17260 +/- 0.00377
#        25/1    1.17524    1.17313 +/- 0.00296
#        26/1    1.17766    1.17388 +/- 0.00254
#        27/1    1.17553    1.17412 +/- 0.00216
#        28/1    1.18054    1.17492 +/- 0.00203
#        29/1    1.18351    1.17587 +/- 0.00203
#        30/1    1.17902    1.17619 +/- 0.00184
#        31/1    1.20111    1.17845 +/- 0.00281
#        32/1    1.18849    1.17929 +/- 0.00270
#        33/1    1.18185    1.17949 +/- 0.00249
#        34/1    1.19270    1.18043 +/- 0.00249
#        35/1    1.18342    1.18063 +/- 0.00233
#        36/1    1.18945    1.18118 +/- 0.00225
#        37/1    1.18273    1.18127 +/- 0.00211
#        38/1    1.17299    1.18081 +/- 0.00204
#        39/1    1.17519    1.18052 +/- 0.00196
#        40/1    1.19583    1.18128 +/- 0.00201
#        41/1    1.16275    1.18040 +/- 0.00210
#        42/1    1.18261    1.18050 +/- 0.00201
#        43/1    1.18724    1.18079 +/- 0.00194
#        44/1    1.18046    1.18078 +/- 0.00186
#        45/1    1.17373    1.18050 +/- 0.00180
#        46/1    1.19232    1.18095 +/- 0.00179
#        47/1    1.17662    1.18079 +/- 0.00173
#        48/1    1.18416    1.18091 +/- 0.00167
#        49/1    1.16364    1.18032 +/- 0.00172
#        50/1    1.20278    1.18107 +/- 0.00182
#  Triggers unsatisfied, max unc./thresh. is 13.77615880859447 for eigenvalue
#  The estimated number of batches is 5714
#  Creating state point statepoint.00050.h5...
#        51/1    1.17692    1.18093 +/- 0.00177
#  Triggers unsatisfied, max unc./thresh. is 13.374244112948217 for eigenvalue
#  The estimated number of batches is 5565
#        52/1    1.17737    1.18082 +/- 0.00172
#  Triggers unsatisfied, max unc./thresh. is 12.862847833941007 for eigenvalue
#  The estimated number of batches is 5315
#        53/1    1.17343    1.18060 +/- 0.00168
#  Triggers unsatisfied, max unc./thresh. is 12.479303247202374 for eigenvalue
#  The estimated number of batches is 5160
#        54/1    1.18478    1.18072 +/- 0.00163
#  Triggers unsatisfied, max unc./thresh. is 12.139116016999566 for eigenvalue
#  The estimated number of batches is 5031
#        55/1    1.19689    1.18118 +/- 0.00165
#  Triggers unsatisfied, max unc./thresh. is 12.070938421282657 for eigenvalue
#  The estimated number of batches is 5120
#        56/1    1.18217    1.18121 +/- 0.00161
#  Triggers unsatisfied, max unc./thresh. is 11.7559888647875 for eigenvalue
#  The estimated number of batches is 4996
#        57/1    1.17952    1.18116 +/- 0.00156
#  Triggers unsatisfied, max unc./thresh. is 11.467900202352919 for eigenvalue
#  The estimated number of batches is 4886
#        58/1    1.17436    1.18098 +/- 0.00153
#  Triggers unsatisfied, max unc./thresh. is 11.131985575802961 for eigenvalue
#  The estimated number of batches is 4730
#        59/1    1.18999    1.18122 +/- 0.00151
#  Triggers unsatisfied, max unc./thresh. is 11.012971009438477 for eigenvalue
#  The estimated number of batches is 4751
#        60/1    1.17715    1.18111 +/- 0.00147
#  Triggers unsatisfied, max unc./thresh. is 11.080013048819087 for eigenvalue
#  The estimated number of batches is 4931
#        61/1    1.17835    1.18105 +/- 0.00144
#  Triggers unsatisfied, max unc./thresh. is 10.841540172490504 for eigenvalue
#  The estimated number of batches is 4840
#        62/1    1.18547    1.18115 +/- 0.00141
#  Triggers unsatisfied, max unc./thresh. is 10.827037410520775 for eigenvalue
#  The estimated number of batches is 4944
#        63/1    1.15924    1.18064 +/- 0.00147
#  Triggers unsatisfied, max unc./thresh. is 10.823749021022113 for eigenvalue
#  The estimated number of batches is 5058
#        64/1    1.19451    1.18096 +/- 0.00147
#  Triggers unsatisfied, max unc./thresh. is 10.822829950942898 for eigenvalue
#  The estimated number of batches is 5174
#        65/1    1.17602    1.18085 +/- 0.00144
#  Triggers unsatisfied, max unc./thresh. is 10.656818002703506 for eigenvalue
#  The estimated number of batches is 5131
#        66/1    1.18446    1.18093 +/- 0.00141
#  Triggers unsatisfied, max unc./thresh. is 10.533145457133513 for eigenvalue
#  The estimated number of batches is 5124
#        67/1    1.19459    1.18122 +/- 0.00141
#  Triggers unsatisfied, max unc./thresh. is 10.286844778773368 for eigenvalue
#  The estimated number of batches is 4994
#        68/1    1.18210    1.18123 +/- 0.00138
#  Triggers unsatisfied, max unc./thresh. is 10.105768767632878 for eigenvalue
#  The estimated number of batches is 4923
#        69/1    1.19598    1.18154 +/- 0.00138
#  Triggers unsatisfied, max unc./thresh. is 9.957201842211278 for eigenvalue
#  The estimated number of batches is 4879
#        70/1    1.15741    1.18105 +/- 0.00144
#  Triggers unsatisfied, max unc./thresh. is 9.777118980051256 for eigenvalue
#  The estimated number of batches is 4800
#        71/1    1.18740    1.18118 +/- 0.00142
#  Triggers unsatisfied, max unc./thresh. is 9.565259497261357 for eigenvalue
#  The estimated number of batches is 4687
#        72/1    1.18086    1.18117 +/- 0.00139
#  Triggers unsatisfied, max unc./thresh. is 9.41969569458718 for eigenvalue
#  The estimated number of batches is 4634
#        73/1    1.18485    1.18124 +/- 0.00136
#  Triggers unsatisfied, max unc./thresh. is 9.318968313118413 for eigenvalue
#  The estimated number of batches is 4623
#        74/1    1.16972    1.18103 +/- 0.00136
#  Triggers unsatisfied, max unc./thresh. is 9.166817898661199 for eigenvalue
#  The estimated number of batches is 4558
#        75/1    1.18429    1.18109 +/- 0.00133
#  Triggers unsatisfied, max unc./thresh. is 9.021836984990381 for eigenvalue
#  The estimated number of batches is 4497
#        76/1    1.17482    1.18097 +/- 0.00131
#  Triggers unsatisfied, max unc./thresh. is 8.909227854175285 for eigenvalue
#  The estimated number of batches is 4465
#        77/1    1.18056    1.18097 +/- 0.00129
#  Triggers unsatisfied, max unc./thresh. is 8.75879897874617 for eigenvalue
#  The estimated number of batches is 4393
#        78/1    1.17839    1.18092 +/- 0.00127
#  Triggers unsatisfied, max unc./thresh. is 8.595095974714472 for eigenvalue
#  The estimated number of batches is 4305
#        79/1    1.18149    1.18093 +/- 0.00125
#  Triggers unsatisfied, max unc./thresh. is 8.442364327269809 for eigenvalue
#  The estimated number of batches is 4226
#        80/1    1.18423    1.18099 +/- 0.00123
#  Triggers unsatisfied, max unc./thresh. is 8.318419646631765 for eigenvalue
#  The estimated number of batches is 4172
#        81/1    1.18358    1.18103 +/- 0.00121
#  Triggers unsatisfied, max unc./thresh. is 8.207719914377783 for eigenvalue
#  The estimated number of batches is 4130
#        82/1    1.18218    1.18105 +/- 0.00119
#  Triggers unsatisfied, max unc./thresh. is 8.127883009375914 for eigenvalue
#  The estimated number of batches is 4116
#        83/1    1.17709    1.18099 +/- 0.00117
#  Triggers unsatisfied, max unc./thresh. is 8.090745364905256 for eigenvalue
#  The estimated number of batches is 4144
#        84/1    1.18323    1.18102 +/- 0.00115
#  Triggers unsatisfied, max unc./thresh. is 7.975185490195673 for eigenvalue
#  The estimated number of batches is 4091
#        85/1    1.17078    1.18086 +/- 0.00115
#  Triggers unsatisfied, max unc./thresh. is 7.885451155187991 for eigenvalue
#  The estimated number of batches is 4062
#        86/1    1.18306    1.18090 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 7.786450316167753 for eigenvalue
#  The estimated number of batches is 4022
#        87/1    1.18619    1.18098 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 7.692043779038437 for eigenvalue
#  The estimated number of batches is 3985
#        88/1    1.18949    1.18110 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 7.609682627249999 for eigenvalue
#  The estimated number of batches is 3958
#        89/1    1.18094    1.18110 +/- 0.00109
#  Triggers unsatisfied, max unc./thresh. is 7.529553256286768 for eigenvalue
#  The estimated number of batches is 3932
#        90/1    1.18337    1.18113 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 7.4312034606202575 for eigenvalue
#  The estimated number of batches is 3886
#        91/1    1.17148    1.18100 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 7.346259701542424 for eigenvalue
#  The estimated number of batches is 3852
#        92/1    1.16665    1.18080 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 7.41720448135683 for eigenvalue
#  The estimated number of batches is 3982
#        93/1    1.16638    1.18060 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 7.340934884224988 for eigenvalue
#  The estimated number of batches is 3954
#        94/1    1.18087    1.18060 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 7.266254137957873 for eigenvalue
#  The estimated number of batches is 3928
#        95/1    1.18070    1.18060 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 7.169198286906544 for eigenvalue
#  The estimated number of batches is 3875
#        96/1    1.17999    1.18060 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 7.101272374877223 for eigenvalue
#  The estimated number of batches is 3853
#        97/1    1.17801    1.18056 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 6.993049246458683 for eigenvalue
#  The estimated number of batches is 3786
#        98/1    1.18871    1.18067 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 6.907293412424737 for eigenvalue
#  The estimated number of batches is 3742
#        99/1    1.18329    1.18070 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 6.8764753357921045 for eigenvalue
#  The estimated number of batches is 3756
#       100/1    1.17658    1.18065 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 6.768189722677766 for eigenvalue
#  The estimated number of batches is 3685
#       101/1    1.17933    1.18063 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 6.762413681359799 for eigenvalue
#  The estimated number of batches is 3725
#       102/1    1.18566    1.18069 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 6.699025251190154 for eigenvalue
#  The estimated number of batches is 3700
#       103/1    1.18249    1.18071 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.680387560379651 for eigenvalue
#  The estimated number of batches is 3725
#       104/1    1.17672    1.18067 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 6.612472229537956 for eigenvalue
#  The estimated number of batches is 3693
#       105/1    1.19539    1.18084 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.678731967821745 for eigenvalue
#  The estimated number of batches is 3812
#       106/1    1.19721    1.18103 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 6.615355068785686 for eigenvalue
#  The estimated number of batches is 3784
#       107/1    1.18660    1.18109 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.545352574846755 for eigenvalue
#  The estimated number of batches is 3748
#       108/1    1.19036    1.18120 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 6.5664311519016865 for eigenvalue
#  The estimated number of batches is 3815
#       109/1    1.19774    1.18139 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 6.576197440575191 for eigenvalue
#  The estimated number of batches is 3869
#       110/1    1.18062    1.18138 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 6.525421134947726 for eigenvalue
#  The estimated number of batches is 3853
#       111/1    1.18365    1.18140 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 6.586483928791876 for eigenvalue
#  The estimated number of batches is 3968
#       112/1    1.19451    1.18154 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 6.528494068704851 for eigenvalue
#  The estimated number of batches is 3942
#       113/1    1.18543    1.18159 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.462830266135953 for eigenvalue
#  The estimated number of batches is 3905
#       114/1    1.19562    1.18174 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.396171524640828 for eigenvalue
#  The estimated number of batches is 3866
#       115/1    1.19475    1.18187 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.4688987578114645 for eigenvalue
#  The estimated number of batches is 3996
#       116/1    1.17629    1.18181 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.4317518155380595 for eigenvalue
#  The estimated number of batches is 3992
#       117/1    1.19142    1.18191 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 6.368300354240293 for eigenvalue
#  The estimated number of batches is 3954
#       118/1    1.18716    1.18197 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 6.418546990515432 for eigenvalue
#  The estimated number of batches is 4058
#       119/1    1.19046    1.18205 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 6.385052582157381 for eigenvalue
#  The estimated number of batches is 4057
#       120/1    1.17461    1.18198 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 6.309708692808681 for eigenvalue
#  The estimated number of batches is 4002
#       121/1    1.18715    1.18203 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 6.259406869444729 for eigenvalue
#  The estimated number of batches is 3978
#       122/1    1.18440    1.18205 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 6.218013174296641 for eigenvalue
#  The estimated number of batches is 3964
#       123/1    1.17880    1.18202 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 6.1570187350687275 for eigenvalue
#  The estimated number of batches is 3925
#       124/1    1.18235    1.18202 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.107259327538616 for eigenvalue
#  The estimated number of batches is 3900
#       125/1    1.18756    1.18208 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.07497686506892 for eigenvalue
#  The estimated number of batches is 3896
#       126/1    1.17187    1.18198 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.038153947707837 for eigenvalue
#  The estimated number of batches is 3885
#       127/1    1.16233    1.18180 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.09212781037774 for eigenvalue
#  The estimated number of batches is 3992
#       128/1    1.17633    1.18175 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 6.047621624235555 for eigenvalue
#  The estimated number of batches is 3970
#       129/1    1.19071    1.18183 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.008041379561821 for eigenvalue
#  The estimated number of batches is 3955
#       130/1    1.18879    1.18189 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.965241831609825 for eigenvalue
#  The estimated number of batches is 3935
#       131/1    1.18938    1.18196 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.921955898259068 for eigenvalue
#  The estimated number of batches is 3913
#       132/1    1.19185    1.18205 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.869577846225926 for eigenvalue
#  The estimated number of batches is 3879
#       133/1    1.16803    1.18192 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.8241954581539765 for eigenvalue
#  The estimated number of batches is 3854
#       134/1    1.17614    1.18187 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.777551075664274 for eigenvalue
#  The estimated number of batches is 3826
#       135/1    1.17729    1.18183 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.7624808744630736 for eigenvalue
#  The estimated number of batches is 3839
#       136/1    1.19050    1.18191 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.779162922165522 for eigenvalue
#  The estimated number of batches is 3895
#       137/1    1.17191    1.18182 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.729765037694911 for eigenvalue
#  The estimated number of batches is 3862
#       138/1    1.18261    1.18183 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.683662839476838 for eigenvalue
#  The estimated number of batches is 3832
#       139/1    1.18341    1.18184 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.647555852518906 for eigenvalue
#  The estimated number of batches is 3816
#       140/1    1.18294    1.18185 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.610872594172565 for eigenvalue
#  The estimated number of batches is 3798
#       141/1    1.19530    1.18196 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.565859456960499 for eigenvalue
#  The estimated number of batches is 3769
#       142/1    1.19693    1.18209 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.561418693077128 for eigenvalue
#  The estimated number of batches is 3794
#       143/1    1.19784    1.18221 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.621828866967358 for eigenvalue
#  The estimated number of batches is 3908
#       144/1    1.18767    1.18226 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.589721678457624 for eigenvalue
#  The estimated number of batches is 3895
#       145/1    1.19149    1.18233 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.55132846147788 for eigenvalue
#  The estimated number of batches is 3873
#       146/1    1.16355    1.18218 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.561730896848532 for eigenvalue
#  The estimated number of batches is 3918
#       147/1    1.19305    1.18227 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.581170408366893 for eigenvalue
#  The estimated number of batches is 3976
#       148/1    1.19636    1.18238 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.566469863092673 for eigenvalue
#  The estimated number of batches is 3987
#       149/1    1.17910    1.18235 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.498231088542225 for eigenvalue
#  The estimated number of batches is 3920
#       150/1    1.18091    1.18234 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.451894445362161 for eigenvalue
#  The estimated number of batches is 3885
#       151/1    1.16358    1.18220 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.446489061047962 for eigenvalue
#  The estimated number of batches is 3907
#       152/1    1.17983    1.18218 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.407738046248598 for eigenvalue
#  The estimated number of batches is 3881
#       153/1    1.18238    1.18218 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.369788722219872 for eigenvalue
#  The estimated number of batches is 3856
#       154/1    1.17799    1.18215 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.332851090992989 for eigenvalue
#  The estimated number of batches is 3831
#       155/1    1.17619    1.18211 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.295318595377285 for eigenvalue
#  The estimated number of batches is 3806
#       156/1    1.16753    1.18200 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.274811252316181 for eigenvalue
#  The estimated number of batches is 3805
#       157/1    1.16970    1.18191 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.309999268876144 for eigenvalue
#  The estimated number of batches is 3883
#       158/1    1.19326    1.18199 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.353788821084033 for eigenvalue
#  The estimated number of batches is 3976
#       159/1    1.17807    1.18196 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.32035738062701 for eigenvalue
#  The estimated number of batches is 3955
#       160/1    1.17620    1.18192 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.306824005416414 for eigenvalue
#  The estimated number of batches is 3963
#       161/1    1.19695    1.18203 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.268666906848593 for eigenvalue
#  The estimated number of batches is 3934
#       162/1    1.17453    1.18198 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.236831686031429 for eigenvalue
#  The estimated number of batches is 3915
#       163/1    1.17188    1.18191 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.194608278371557 for eigenvalue
#  The estimated number of batches is 3879
#       164/1    1.18281    1.18191 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.159399923268072 for eigenvalue
#  The estimated number of batches is 3854
#       165/1    1.17519    1.18187 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.143231892383709 for eigenvalue
#  The estimated number of batches is 3856
#       166/1    1.17545    1.18182 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.107909608758643 for eigenvalue
#  The estimated number of batches is 3830
#       167/1    1.17022    1.18174 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.122623589119236 for eigenvalue
#  The estimated number of batches is 3878
#       168/1    1.16076    1.18160 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.124983559316678 for eigenvalue
#  The estimated number of batches is 3908
#       169/1    1.18884    1.18165 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.1125875714114555 for eigenvalue
#  The estimated number of batches is 3915
#       170/1    1.18219    1.18165 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.082562562833784 for eigenvalue
#  The estimated number of batches is 3895
#       171/1    1.18016    1.18164 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.052677926161016 for eigenvalue
#  The estimated number of batches is 3875
#       172/1    1.19658    1.18174 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.032592916197279 for eigenvalue
#  The estimated number of batches is 3870
#       173/1    1.19086    1.18180 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 5.010581642395685 for eigenvalue
#  The estimated number of batches is 3862
#       174/1    1.17636    1.18177 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.983859759455114 for eigenvalue
#  The estimated number of batches is 3846
#       175/1    1.17101    1.18170 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.953101050216243 for eigenvalue
#  The estimated number of batches is 3823
#       176/1    1.16770    1.18161 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.9225731853831745 for eigenvalue
#  The estimated number of batches is 3801
#       177/1    1.17341    1.18155 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.899102421046566 for eigenvalue
#  The estimated number of batches is 3789
#       178/1    1.18752    1.18159 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.8669096468806305 for eigenvalue
#  The estimated number of batches is 3763
#       179/1    1.16933    1.18152 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.843613891958993 for eigenvalue
#  The estimated number of batches is 3751
#       180/1    1.18196    1.18152 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.811929989365468 for eigenvalue
#  The estimated number of batches is 3725
#       181/1    1.18832    1.18156 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.782955044665491 for eigenvalue
#  The estimated number of batches is 3704
#       182/1    1.19404    1.18164 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.786348122446047 for eigenvalue
#  The estimated number of batches is 3732
#       183/1    1.18165    1.18164 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.768270451628082 for eigenvalue
#  The estimated number of batches is 3727
#       184/1    1.18149    1.18164 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.743140905150283 for eigenvalue
#  The estimated number of batches is 3710
#       185/1    1.19872    1.18174 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.722589919628379 for eigenvalue
#  The estimated number of batches is 3700
#       186/1    1.16936    1.18167 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.696048301226463 for eigenvalue
#  The estimated number of batches is 3681
#       187/1    1.17281    1.18161 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.6731068726877565 for eigenvalue
#  The estimated number of batches is 3667
#       188/1    1.20299    1.18174 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.763401783984836 for eigenvalue
#  The estimated number of batches is 3832
#       189/1    1.18734    1.18177 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.756716159739529 for eigenvalue
#  The estimated number of batches is 3844
#       190/1    1.18322    1.18178 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.779132971570725 for eigenvalue
#  The estimated number of batches is 3903
#       191/1    1.18162    1.18178 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.751510556367019 for eigenvalue
#  The estimated number of batches is 3881
#       192/1    1.18296    1.18179 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.730914330557465 for eigenvalue
#  The estimated number of batches is 3870
#       193/1    1.18577    1.18181 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.704455258914149 for eigenvalue
#  The estimated number of batches is 3849
#       194/1    1.17341    1.18176 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.673754003470412 for eigenvalue
#  The estimated number of batches is 3821
#       195/1    1.18927    1.18180 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.649545443294636 for eigenvalue
#  The estimated number of batches is 3804
#       196/1    1.18935    1.18185 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.619743616718441 for eigenvalue
#  The estimated number of batches is 3777
#       197/1    1.19293    1.18191 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.586030399999197 for eigenvalue
#  The estimated number of batches is 3743
#       198/1    1.18595    1.18193 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.613565945760425 for eigenvalue
#  The estimated number of batches is 3809
#       199/1    1.16597    1.18184 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.653641852765491 for eigenvalue
#  The estimated number of batches is 3897
#       200/1    1.19310    1.18191 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.673475201149029 for eigenvalue
#  The estimated number of batches is 3952
#       201/1    1.17657    1.18188 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.6891278074593865 for eigenvalue
#  The estimated number of batches is 4000
#       202/1    1.18809    1.18191 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.672257807870485 for eigenvalue
#  The estimated number of batches is 3994
#       203/1    1.18670    1.18194 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.649470771118736 for eigenvalue
#  The estimated number of batches is 3977
#       204/1    1.18066    1.18193 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.6347355422218 for eigenvalue
#  The estimated number of batches is 3973
#       205/1    1.17500    1.18189 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.614413032431089 for eigenvalue
#  The estimated number of batches is 3960
#       206/1    1.17619    1.18186 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.616660046939325 for eigenvalue
#  The estimated number of batches is 3985
#       207/1    1.17006    1.18180 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.59583483439861 for eigenvalue
#  The estimated number of batches is 3970
#       208/1    1.17871    1.18178 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.5732829981907575 for eigenvalue
#  The estimated number of batches is 3953
#       209/1    1.18960    1.18182 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.577550925950293 for eigenvalue
#  The estimated number of batches is 3981
#       210/1    1.17917    1.18181 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.5765112499824525 for eigenvalue
#  The estimated number of batches is 4000
#       211/1    1.18550    1.18183 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.546252842544396 for eigenvalue
#  The estimated number of batches is 3968
#       212/1    1.17616    1.18180 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.533091509483139 for eigenvalue
#  The estimated number of batches is 3966
#       213/1    1.18722    1.18183 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.512704499182053 for eigenvalue
#  The estimated number of batches is 3951
#       214/1    1.18921    1.18187 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.480843399967792 for eigenvalue
#  The estimated number of batches is 3916
#       215/1    1.17544    1.18183 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.467611677409747 for eigenvalue
#  The estimated number of batches is 3913
#       216/1    1.17778    1.18181 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.453999811650009 for eigenvalue
#  The estimated number of batches is 3909
#       217/1    1.18730    1.18184 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.42865626703953 for eigenvalue
#  The estimated number of batches is 3884
#       218/1    1.19074    1.18188 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.40676155659615 for eigenvalue
#  The estimated number of batches is 3866
#       219/1    1.16725    1.18181 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.394288384481187 for eigenvalue
#  The estimated number of batches is 3863
#       220/1    1.17838    1.18179 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.380416548767676 for eigenvalue
#  The estimated number of batches is 3858
#       221/1    1.18634    1.18182 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.358838182336284 for eigenvalue
#  The estimated number of batches is 3839
#       222/1    1.19226    1.18187 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.345840698579652 for eigenvalue
#  The estimated number of batches is 3836
#       223/1    1.19598    1.18194 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.343456501824671 for eigenvalue
#  The estimated number of batches is 3850
#       224/1    1.18002    1.18193 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.322396845890334 for eigenvalue
#  The estimated number of batches is 3832
#       225/1    1.17134    1.18188 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.30538459502796 for eigenvalue
#  The estimated number of batches is 3820
#       226/1    1.19640    1.18195 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.302153130959598 for eigenvalue
#  The estimated number of batches is 3833
#       227/1    1.19098    1.18199 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.353039131193996 for eigenvalue
#  The estimated number of batches is 3943
#       228/1    1.18844    1.18202 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.339626263700818 for eigenvalue
#  The estimated number of batches is 3938
#       229/1    1.17736    1.18200 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.3222423293155074 for eigenvalue
#  The estimated number of batches is 3925
#       230/1    1.18352    1.18201 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.302057865071498 for eigenvalue
#  The estimated number of batches is 3907
#       231/1    1.18114    1.18200 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.285599695674246 for eigenvalue
#  The estimated number of batches is 3896
#       232/1    1.16731    1.18193 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.30503925612117 for eigenvalue
#  The estimated number of batches is 3950
#       233/1    1.17928    1.18192 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.294943670878363 for eigenvalue
#  The estimated number of batches is 3950
#       234/1    1.17502    1.18189 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.283793283102841 for eigenvalue
#  The estimated number of batches is 3948
#       235/1    1.18384    1.18190 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.277971830483501 for eigenvalue
#  The estimated number of batches is 3955
#       236/1    1.20129    1.18199 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.259536180498154 for eigenvalue
#  The estimated number of batches is 3940
#       237/1    1.17282    1.18195 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.265611367393844 for eigenvalue
#  The estimated number of batches is 3969
#       238/1    1.18670    1.18197 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.244489074132242 for eigenvalue
#  The estimated number of batches is 3948
#       239/1    1.20166    1.18206 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.227164457732268 for eigenvalue
#  The estimated number of batches is 3934
#       240/1    1.18706    1.18208 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.206762152633468 for eigenvalue
#  The estimated number of batches is 3914
#       241/1    1.16109    1.18199 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.198280671700555 for eigenvalue
#  The estimated number of batches is 3916
#       242/1    1.19954    1.18206 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.234710251224727 for eigenvalue
#  The estimated number of batches is 4002
#       243/1    1.18213    1.18206 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.219463943327707 for eigenvalue
#  The estimated number of batches is 3991
#       244/1    1.16915    1.18201 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.209053769214747 for eigenvalue
#  The estimated number of batches is 3989
#       245/1    1.17978    1.18200 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.189922926414494 for eigenvalue
#  The estimated number of batches is 3970
#       246/1    1.18480    1.18201 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.171778984089027 for eigenvalue
#  The estimated number of batches is 3954
#       247/1    1.17715    1.18199 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.1569231034246314 for eigenvalue
#  The estimated number of batches is 3943
#       248/1    1.17338    1.18195 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.177863831071697 for eigenvalue
#  The estimated number of batches is 4000
#       249/1    1.19910    1.18203 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.181101525305876 for eigenvalue
#  The estimated number of batches is 4024
#       250/1    1.19152    1.18207 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.177575122560066 for eigenvalue
#  The estimated number of batches is 4034
#       251/1    1.19154    1.18211 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.1589647411722614 for eigenvalue
#  The estimated number of batches is 4016
#       252/1    1.19554    1.18217 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.1402715350341275 for eigenvalue
#  The estimated number of batches is 3997
#       253/1    1.18198    1.18216 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.12084694023655 for eigenvalue
#  The estimated number of batches is 3977
#       254/1    1.17422    1.18213 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.111950811805906 for eigenvalue
#  The estimated number of batches is 3977
#       255/1    1.18286    1.18213 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.094649798595652 for eigenvalue
#  The estimated number of batches is 3961
#       256/1    1.16998    1.18208 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.126199545061979 for eigenvalue
#  The estimated number of batches is 4039
#       257/1    1.18331    1.18209 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.109130241591128 for eigenvalue
#  The estimated number of batches is 4022
#       258/1    1.20610    1.18219 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.150621233187353 for eigenvalue
#  The estimated number of batches is 4121
#       259/1    1.17693    1.18217 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.134146602896248 for eigenvalue
#  The estimated number of batches is 4105
#       260/1    1.17325    1.18213 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.121245438750359 for eigenvalue
#  The estimated number of batches is 4097
#       261/1    1.19099    1.18217 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.104922007623826 for eigenvalue
#  The estimated number of batches is 4081
#       262/1    1.17209    1.18212 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.102022320401352 for eigenvalue
#  The estimated number of batches is 4093
#       263/1    1.17800    1.18211 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.097297863429781 for eigenvalue
#  The estimated number of batches is 4100
#       264/1    1.18229    1.18211 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.085196916936531 for eigenvalue
#  The estimated number of batches is 4093
#       265/1    1.17177    1.18207 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.086051166567031 for eigenvalue
#  The estimated number of batches is 4111
#       266/1    1.17968    1.18206 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.069163513017278 for eigenvalue
#  The estimated number of batches is 4094
#       267/1    1.16528    1.18199 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.073848052077223 for eigenvalue
#  The estimated number of batches is 4120
#       268/1    1.18464    1.18200 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.060775088203476 for eigenvalue
#  The estimated number of batches is 4110
#       269/1    1.17934    1.18199 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.061049319267436 for eigenvalue
#  The estimated number of batches is 4127
#       270/1    1.19880    1.18206 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.082335225003529 for eigenvalue
#  The estimated number of batches is 4187
#       271/1    1.18715    1.18208 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.07064824327051 for eigenvalue
#  The estimated number of batches is 4180
#       272/1    1.20289    1.18216 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.085907115593895 for eigenvalue
#  The estimated number of batches is 4228
#       273/1    1.18271    1.18216 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.06973761011122 for eigenvalue
#  The estimated number of batches is 4211
#       274/1    1.18037    1.18215 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.0546671582179314 for eigenvalue
#  The estimated number of batches is 4196
#       275/1    1.16538    1.18209 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.05281647360594 for eigenvalue
#  The estimated number of batches is 4209
#       276/1    1.17677    1.18207 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.0350711915861925 for eigenvalue
#  The estimated number of batches is 4189
#       277/1    1.17254    1.18203 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.030855936499671 for eigenvalue
#  The estimated number of batches is 4196
#       278/1    1.18017    1.18202 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.018638715411137 for eigenvalue
#  The estimated number of batches is 4187
#       279/1    1.18385    1.18203 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.0020682860673995 for eigenvalue
#  The estimated number of batches is 4169
#       280/1    1.19733    1.18209 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.992415117741378 for eigenvalue
#  The estimated number of batches is 4165
#       281/1    1.16926    1.18204 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.9804952765425856 for eigenvalue
#  The estimated number of batches is 4156
#       282/1    1.20032    1.18211 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.9768478058952637 for eigenvalue
#  The estimated number of batches is 4164
#       283/1    1.17756    1.18209 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.963047419508533 for eigenvalue
#  The estimated number of batches is 4151
#       284/1    1.16704    1.18203 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.9653269128651876 for eigenvalue
#  The estimated number of batches is 4172
#       285/1    1.17625    1.18201 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.954117553537992 for eigenvalue
#  The estimated number of batches is 4164
#       286/1    1.17226    1.18198 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.943008120723349 for eigenvalue
#  The estimated number of batches is 4156
#       287/1    1.19065    1.18201 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.93012976498331 for eigenvalue
#  The estimated number of batches is 4145
#       288/1    1.17887    1.18200 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.9167549220283386 for eigenvalue
#  The estimated number of batches is 4132
#       289/1    1.17925    1.18199 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.904148248637261 for eigenvalue
#  The estimated number of batches is 4121
#       290/1    1.16400    1.18192 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.8928909359767956 for eigenvalue
#  The estimated number of batches is 4112
#       291/1    1.18504    1.18193 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.8860314930905537 for eigenvalue
#  The estimated number of batches is 4113
#       292/1    1.17401    1.18190 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8857443296607723 for eigenvalue
#  The estimated number of batches is 4127
#       293/1    1.17939    1.18189 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8723818344853838 for eigenvalue
#  The estimated number of batches is 4114
#       294/1    1.18506    1.18190 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.856666209904641 for eigenvalue
#  The estimated number of batches is 4096
#       295/1    1.18670    1.18192 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8480317942166584 for eigenvalue
#  The estimated number of batches is 4093
#       296/1    1.20145    1.18199 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8461232968465864 for eigenvalue
#  The estimated number of batches is 4103
#       297/1    1.18382    1.18200 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8337083853930385 for eigenvalue
#  The estimated number of batches is 4092
# ...
#      4154/1    1.18104    1.18229 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096998670619552 for eigenvalue
#  The estimated number of batches is 4235
#      4155/1    1.18654    1.18229 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096217188083694 for eigenvalue
#  The estimated number of batches is 4235
#      4156/1    1.17249    1.18229 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0098828507706634 for eigenvalue
#  The estimated number of batches is 4239
#      4157/1    1.16720    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099901317576732 for eigenvalue
#  The estimated number of batches is 4241
#      4158/1    1.17119    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097554765805727 for eigenvalue
#  The estimated number of batches is 4240
#      4159/1    1.17347    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099592154725816 for eigenvalue
#  The estimated number of batches is 4242
#      4160/1    1.18800    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0100236049227973 for eigenvalue
#  The estimated number of batches is 4244
#      4161/1    1.17483    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099551054321922 for eigenvalue
#  The estimated number of batches is 4244
#      4162/1    1.18806    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097508359227856 for eigenvalue
#  The estimated number of batches is 4244
#      4163/1    1.17209    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009515875751989 for eigenvalue
#  The estimated number of batches is 4243
#      4164/1    1.19888    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096562356316865 for eigenvalue
#  The estimated number of batches is 4245
#      4165/1    1.17956    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009414437328853 for eigenvalue
#  The estimated number of batches is 4244
#      4166/1    1.18127    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0091607682568169 for eigenvalue
#  The estimated number of batches is 4243
#      4167/1    1.18452    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0090256907452815 for eigenvalue
#  The estimated number of batches is 4243
#      4168/1    1.17932    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0088102207578864 for eigenvalue
#  The estimated number of batches is 4242
#      4169/1    1.14927    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0100246726837638 for eigenvalue
#  The estimated number of batches is 4253
#      4170/1    1.20549    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0098415812139379 for eigenvalue
#  The estimated number of batches is 4253
#      4171/1    1.18034    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0095993689396514 for eigenvalue
#  The estimated number of batches is 4252
#      4172/1    1.16948    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0093519801367206 for eigenvalue
#  The estimated number of batches is 4251
#      4173/1    1.18796    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0091482095469118 for eigenvalue
#  The estimated number of batches is 4250
#      4174/1    1.18269    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.008917279028522 for eigenvalue
#  The estimated number of batches is 4249
#      4175/1    1.17913    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0087705428602014 for eigenvalue
#  The estimated number of batches is 4249
#      4176/1    1.17810    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.00859750769585 for eigenvalue
#  The estimated number of batches is 4248
#      4177/1    1.18937    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0083772742336483 for eigenvalue
#  The estimated number of batches is 4247
#      4178/1    1.18128    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0081703908829027 for eigenvalue
#  The estimated number of batches is 4247
#      4179/1    1.19948    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0080827851417031 for eigenvalue
#  The estimated number of batches is 4247
#      4180/1    1.19416    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0078454374187165 for eigenvalue
#  The estimated number of batches is 4246
#      4181/1    1.18310    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0076875813364297 for eigenvalue
#  The estimated number of batches is 4246
#      4182/1    1.17750    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0074604602829178 for eigenvalue
#  The estimated number of batches is 4245
#      4183/1    1.18109    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0073631687428117 for eigenvalue
#  The estimated number of batches is 4245
#      4184/1    1.18089    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.007183328229344 for eigenvalue
#  The estimated number of batches is 4245
#      4185/1    1.17734    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0069766824104796 for eigenvalue
#  The estimated number of batches is 4244
#      4186/1    1.16872    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.00676690963137 for eigenvalue
#  The estimated number of batches is 4243
#      4187/1    1.18303    1.18228 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0065310560740897 for eigenvalue
#  The estimated number of batches is 4242
#      4188/1    1.17336    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.006292813414464 for eigenvalue
#  The estimated number of batches is 4241
#      4189/1    1.17536    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0060810337479864 for eigenvalue
#  The estimated number of batches is 4240
#      4190/1    1.17380    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0059244221538082 for eigenvalue
#  The estimated number of batches is 4240
#      4191/1    1.17211    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0057035510875596 for eigenvalue
#  The estimated number of batches is 4239
#      4192/1    1.17490    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0054838957767203 for eigenvalue
#  The estimated number of batches is 4238
#      4193/1    1.18217    1.18227 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.005296231726453 for eigenvalue
#  The estimated number of batches is 4238
#      4194/1    1.17659    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.005228765991609 for eigenvalue
#  The estimated number of batches is 4238
#      4195/1    1.18082    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0049827029720995 for eigenvalue
#  The estimated number of batches is 4237
#      4196/1    1.18218    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0053139120582786 for eigenvalue
#  The estimated number of batches is 4241
#      4197/1    1.18614    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0051230796137867 for eigenvalue
#  The estimated number of batches is 4240
#      4198/1    1.16728    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.005367803219228 for eigenvalue
#  The estimated number of batches is 4243
#      4199/1    1.17811    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0051442542999058 for eigenvalue
#  The estimated number of batches is 4243
#      4200/1    1.19015    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0049015361797402 for eigenvalue
#  The estimated number of batches is 4242
#      4201/1    1.17588    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0050801529160658 for eigenvalue
#  The estimated number of batches is 4244
#      4202/1    1.17767    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0048540042673817 for eigenvalue
#  The estimated number of batches is 4243
#      4203/1    1.19034    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0046136341101195 for eigenvalue
#  The estimated number of batches is 4242
#      4204/1    1.16078    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0043740204591387 for eigenvalue
#  The estimated number of batches is 4241
#      4205/1    1.19419    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0043753740588233 for eigenvalue
#  The estimated number of batches is 4242
#      4206/1    1.16071    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.004386329813278 for eigenvalue
#  The estimated number of batches is 4243
#      4207/1    1.17698    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0041618357993025 for eigenvalue
#  The estimated number of batches is 4242
#      4208/1    1.19340    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0042306935310423 for eigenvalue
#  The estimated number of batches is 4244
#      4209/1    1.18257    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0039991784357816 for eigenvalue
#  The estimated number of batches is 4243
#      4210/1    1.16093    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0038451041367051 for eigenvalue
#  The estimated number of batches is 4243
#      4211/1    1.20237    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0036345778742333 for eigenvalue
#  The estimated number of batches is 4242
#      4212/1    1.19767    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0038718512707927 for eigenvalue
#  The estimated number of batches is 4245
#      4213/1    1.19929    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0040323579568247 for eigenvalue
#  The estimated number of batches is 4247
#      4214/1    1.18275    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0037859735664376 for eigenvalue
#  The estimated number of batches is 4246
#      4215/1    1.16820    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0036867138094547 for eigenvalue
#  The estimated number of batches is 4246
#      4216/1    1.18351    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.00345293126136 for eigenvalue
#  The estimated number of batches is 4246
#      4217/1    1.18046    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.003290599661985 for eigenvalue
#  The estimated number of batches is 4245
#      4218/1    1.18071    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0031328518035225 for eigenvalue
#  The estimated number of batches is 4245
#      4219/1    1.15507    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0031431932049917 for eigenvalue
#  The estimated number of batches is 4246
#      4220/1    1.17945    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.002906613115284 for eigenvalue
#  The estimated number of batches is 4245
#      4221/1    1.20343    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0030657099556972 for eigenvalue
#  The estimated number of batches is 4247
#      4222/1    1.18061    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0030646777468197 for eigenvalue
#  The estimated number of batches is 4248
#      4223/1    1.17031    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0029381612373005 for eigenvalue
#  The estimated number of batches is 4248
#      4224/1    1.17759    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.002709735975269 for eigenvalue
#  The estimated number of batches is 4247
#      4225/1    1.17791    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0026517157740844 for eigenvalue
#  The estimated number of batches is 4248
#      4226/1    1.18292    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0025667744544735 for eigenvalue
#  The estimated number of batches is 4248
#      4227/1    1.15929    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0027402124021427 for eigenvalue
#  The estimated number of batches is 4251
#      4228/1    1.17605    1.18224 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0025081281219848 for eigenvalue
#  The estimated number of batches is 4250
#      4229/1    1.18815    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0023126770792161 for eigenvalue
#  The estimated number of batches is 4249
#      4230/1    1.18715    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0022675469752578 for eigenvalue
#  The estimated number of batches is 4250
#      4231/1    1.18283    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0020299250207259 for eigenvalue
#  The estimated number of batches is 4249
#      4232/1    1.17632    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0018229395365317 for eigenvalue
#  The estimated number of batches is 4248
#      4233/1    1.18731    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0016602629685663 for eigenvalue
#  The estimated number of batches is 4248
#      4234/1    1.17529    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0014224686332471 for eigenvalue
#  The estimated number of batches is 4246
#      4235/1    1.18815    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0012192076375674 for eigenvalue
#  The estimated number of batches is 4246
#      4236/1    1.18640    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.001078554300709 for eigenvalue
#  The estimated number of batches is 4246
#      4237/1    1.19008    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000991004491773 for eigenvalue
#  The estimated number of batches is 4246
#      4238/1    1.18893    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000807273301318 for eigenvalue
#  The estimated number of batches is 4245
#      4239/1    1.18759    1.18225 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0005830937519204 for eigenvalue
#  The estimated number of batches is 4244
#      4240/1    1.20475    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0003555954934993 for eigenvalue
#  The estimated number of batches is 4244
#      4241/1    1.20368    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000345881527386 for eigenvalue
#  The estimated number of batches is 4244
#      4242/1    1.18887    1.18226 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000142752520662 for eigenvalue
#  The estimated number of batches is 4244
#      4243/1    1.18319    1.18226 +/- 0.00016
#  Triggers satisfied for batch 4243
#  Creating state point statepoint.04243.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.3972e+00 seconds
#    Reading cross sections          = 9.3174e+00 seconds
#  Total time in simulation          = 1.0409e+04 seconds
#    Time in transport only          = 9.9022e+03 seconds
#    Time in inactive batches        = 1.6661e+01 seconds
#    Time in active batches          = 1.0392e+04 seconds
#    Time synchronizing fission bank = 1.2747e+01 seconds
#      Sampling source sites         = 1.1029e+01 seconds
#      SEND/RECV source sites        = 1.7124e+00 seconds
#    Time accumulating tallies       = 4.8516e+02 seconds
#    Time writing statepoints        = 3.6300e-01 seconds
#  Total time for finalization       = 9.6448e+00 seconds
#  Total time elapsed                = 1.0428e+04 seconds
#  Calculation Rate (inactive)       = 24008.3 particles/second
#  Calculation Rate (active)         = 8127.52 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18214 +/- 0.00014
#  k-effective (Track-length)  = 1.18226 +/- 0.00016
#  k-effective (Absorption)    = 1.18221 +/- 0.00011
#  Combined k-effective        = 1.18220 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# ce_spfile = './statepoint_ce.h5'
# os.rename(statepoint_filename, ce_spfile)
# ce_sumfile = './summary_ce.h5'
# os.rename('summary.h5', ce_sumfile)
# sp = openmc.StatePoint(ce_spfile, autolink=False)
# su = openmc.Summary(ce_sumfile)
# sp.link_with_summary(su)

# %% [markdown]
# mgxs_lib.load_from_statepoint(sp)
# mgxs_file = mgxs_lib.create_mg_library(xs_type='macro', xsdata_names=['fuel', 'clad', 'moderator'])
# mgxs_file.xsdatas[0].temperatures=[565.]
# mgxs_file.xsdatas[1].temperatures=[565.]
# mgxs_file.xsdatas[2].temperatures=[565.]
# mgxs_file.export_to_hdf5('mgxs_order1.h5')
