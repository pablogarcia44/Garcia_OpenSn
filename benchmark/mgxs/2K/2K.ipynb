# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2_low = openmc.Material(name='uo2_low')
uo2_low.add_nuclide('U234', 6.11864E-06, 'ao')
uo2_low.add_nuclide('U235', 7.18132E-04, 'ao')
uo2_low.add_nuclide('U236', 3.29861E-06, 'ao')
uo2_low.add_nuclide('U238', 2.21546E-02, 'ao')
uo2_low.add_nuclide('O16', 4.57642E-02, 'ao')
uo2_low.set_density('g/cm3', 10.257 )
uo2_low.temperature=600

uo2_high = openmc.Material(name='uo2_high')
uo2_high.add_nuclide('U234', 7.21203E-06, 'ao')
uo2_high.add_nuclide('U235', 8.33952E-04, 'ao')
uo2_high.add_nuclide('U236', 3.82913E-06, 'ao')
uo2_high.add_nuclide('U238', 2.20384E-02, 'ao')
uo2_high.add_nuclide('O16', 4.57669E-02, 'ao')
uo2_high.set_density('g/cm3', 10.257 )
uo2_high.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2_high,uo2_low, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell_high(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2_high
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %%
def pincell_low(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2_low
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, gap, clad, moderator))
    return(u,fuel,gap,clad,moderator)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]
F_low=[(8,7),(7,8),(0,0),(1,0),(0,1),(2,0),(0,2),(1,1)]



PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

F_low_left=[]
F_low_full=[]
for X in F_low:
    F_low_left.append((X[0],X[1]))
    F_low_left.append((X[0],16-X[1]))
for X in F_low_left:
    F_low_full.append((X[0],X[1]))
    F_low_full.append((16-X[0],X[1]))    
F_low_full = list(set(F_low_full))

print(F_low_full)
# Out:
# [(14, 16), (0, 2), (8, 9), (9, 8), (1, 0), (0, 14), (16, 1), (16, 16), (1, 15), (14, 0), (0, 1), (16, 0), (0, 16), (2, 16), (15, 1), (15, 16), (16, 15), (0, 0), (8, 7), (1, 1), (2, 0), (16, 2), (15, 0), (0, 15), (1, 16), (16, 14), (7, 8), (15, 15)]

# %%
pincell_low_1_family=pincell_low('pincell_low_1_family')
pincell_high_1_family=pincell_high('pincell_high_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=4e-2 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in F_low_full:
            A[ix][iy]=pincell_low_1_family[0]
        else:
            A[ix][iy]=pincell_high_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=628.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=2.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=10.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.02062
#         2/1    1.02054
#         3/1    1.02031
#         4/1    1.01636
#         5/1    1.02178
#         6/1    1.01978
#         7/1    1.02728
#         8/1    1.02495
#         9/1    1.01699
#        10/1    1.01931
#        11/1    1.01777
#        12/1    1.01396
#        13/1    1.02442
#        14/1    1.01509
#        15/1    1.02574
#        16/1    1.01535
#        17/1    1.01969
#        18/1    1.01169
#        19/1    1.02092
#        20/1    1.02981
#        21/1    1.01484
#        22/1    1.01598    1.01541 +/- 0.00057
#        23/1    1.02165    1.01749 +/- 0.00211
#        24/1    1.02955    1.02050 +/- 0.00336
#        25/1    1.02017    1.02044 +/- 0.00261
#        26/1    1.02906    1.02187 +/- 0.00257
#        27/1    1.02412    1.02219 +/- 0.00219
#        28/1    1.01902    1.02180 +/- 0.00194
#        29/1    1.03190    1.02292 +/- 0.00205
#        30/1    1.02441    1.02307 +/- 0.00184
#        31/1    1.02619    1.02335 +/- 0.00169
#        32/1    1.01160    1.02237 +/- 0.00182
#        33/1    1.02204    1.02235 +/- 0.00168
#        34/1    1.02471    1.02252 +/- 0.00156
#        35/1    1.02319    1.02256 +/- 0.00146
#        36/1    1.01404    1.02203 +/- 0.00146
#        37/1    1.02207    1.02203 +/- 0.00137
#        38/1    1.01865    1.02184 +/- 0.00131
#        39/1    1.02177    1.02184 +/- 0.00124
#        40/1    1.01381    1.02144 +/- 0.00124
#        41/1    1.02886    1.02179 +/- 0.00123
#        42/1    1.01798    1.02162 +/- 0.00119
#        43/1    1.01965    1.02153 +/- 0.00114
#        44/1    1.03618    1.02214 +/- 0.00125
#        45/1    1.01685    1.02193 +/- 0.00122
#        46/1    1.00740    1.02137 +/- 0.00130
#        47/1    1.01942    1.02130 +/- 0.00125
#        48/1    1.02439    1.02141 +/- 0.00121
#        49/1    1.02118    1.02140 +/- 0.00117
#        50/1    1.01996    1.02135 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 8.394127913952168 for eigenvalue
#  The estimated number of batches is 2134
#  Creating state point statepoint.00050.h5...
#        51/1    1.01471    1.02114 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 8.234461602643348 for eigenvalue
#  The estimated number of batches is 2122
#        52/1    1.02062    1.02112 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 7.960956318339408 for eigenvalue
#  The estimated number of batches is 2049
#        53/1    1.01892    1.02106 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 7.7945213759523 for eigenvalue
#  The estimated number of batches is 2025
#        54/1    1.02338    1.02113 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 7.695519933084671 for eigenvalue
#  The estimated number of batches is 2034
#        55/1    1.02157    1.02114 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 7.468974536925062 for eigenvalue
#  The estimated number of batches is 1973
#        56/1    1.02970    1.02138 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 3.459810351972033 for eigenvalue
#  The estimated number of batches is 1397
#       136/1    1.01996    1.02006 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4325113123235087 for eigenvalue
#  The estimated number of batches is 1387
#       137/1    1.01851    1.02004 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.4142595062582815 for eigenvalue
#  The estimated number of batches is 1384
#       138/1    1.02639    1.02010 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.386130882623301 for eigenvalue
#  The estimated number of batches is 1373
#       139/1    1.01727    1.02007 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.356867379935348 for eigenvalue
#  The estimated number of batches is 1361
#       140/1    1.02495    1.02012 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.3287546846273983 for eigenvalue
#  The estimated number of batches is 1350
#       141/1    1.02224    1.02013 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.301623254301486 for eigenvalue
#  The estimated number of batches is 1339
#       142/1    1.02359    1.02016 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2904946849526655 for eigenvalue
#  The estimated number of batches is 1341
#       143/1    1.02169    1.02017 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2625668285698186 for eigenvalue
#  The estimated number of batches is 1330
#       144/1    1.02422    1.02021 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2545636766126673 for eigenvalue
#  The estimated number of batches is 1334
#       145/1    1.01810    1.02019 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2299652728448085 for eigenvalue
#  The estimated number of batches is 1325
#       146/1    1.02575    1.02023 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.21697858645676 for eigenvalue
#  The estimated number of batches is 1324
#       147/1    1.01757    1.02021 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2101531903020244 for eigenvalue
#  The estimated number of batches is 1329
#       148/1    1.01974    1.02021 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.2202229603517534 for eigenvalue
#  The estimated number of batches is 1348
#       149/1    1.02248    1.02023 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.199723635831568 for eigenvalue
#  The estimated number of batches is 1341
#       150/1    1.02773    1.02028 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1784485508375644 for eigenvalue
#  The estimated number of batches is 1334
#       151/1    1.01309    1.02023 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.173739251000265 for eigenvalue
#  The estimated number of batches is 1340
#       152/1    1.02299    1.02025 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.152860266084876 for eigenvalue
#  The estimated number of batches is 1333
#       153/1    1.01652    1.02022 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1309353571604603 for eigenvalue
#  The estimated number of batches is 1324
#       154/1    1.02079    1.02023 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1071586209767204 for eigenvalue
#  The estimated number of batches is 1314
#  The estimated number of batches is 1537
#      1154/1    1.01929    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1571452920584162 for eigenvalue
#  The estimated number of batches is 1539
#      1155/1    1.03211    1.01990 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.158143973056536 for eigenvalue
#  The estimated number of batches is 1543
#      1156/1    1.01924    1.01990 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1571242761410818 for eigenvalue
#  The estimated number of batches is 1542
#      1157/1    1.02456    1.01990 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1588020444635259 for eigenvalue
#  The estimated number of batches is 1547
#      1158/1    1.02911    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.15792828602599 for eigenvalue
#  The estimated number of batches is 1546
#      1159/1    1.02771    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1576374684414372 for eigenvalue
#  The estimated number of batches is 1547
#      1160/1    1.01420    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1567462250728624 for eigenvalue
#  The estimated number of batches is 1546
#      1161/1    1.01961    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1558322615970107 for eigenvalue
#  The estimated number of batches is 1545
#      1162/1    1.00885    1.01990 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.155447659196957 for eigenvalue
#  The estimated number of batches is 1545
#      1163/1    1.01522    1.01990 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1552774742317116 for eigenvalue
#  The estimated number of batches is 1546
#      1164/1    1.02289    1.01990 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1546058860720727 for eigenvalue
#  The estimated number of batches is 1546
#      1165/1    1.00698    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.15463702877661 for eigenvalue
#  The estimated number of batches is 1547
#      1166/1    1.01709    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1536343743858586 for eigenvalue
#  The estimated number of batches is 1546
#      1167/1    1.01673    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1534441309765575 for eigenvalue
#  The estimated number of batches is 1547
#      1168/1    1.02464    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1525592973602399 for eigenvalue
#  The estimated number of batches is 1545
#      1169/1    1.01212    1.01988 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1515785851253222 for eigenvalue
#  The estimated number of batches is 1544
#      1170/1    1.02340    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.150670594449798 for eigenvalue
#  The estimated number of batches is 1543
#      1171/1    1.02560    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1497735506096325 for eigenvalue
#  The estimated number of batches is 1542
#      1172/1    1.01895    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1487652676413243 for eigenvalue
#  The estimated number of batches is 1541
#      1173/1    1.02280    1.01989 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.147964805831526 for eigenvalue
#  The estimated number of batches is 1540
#      1174/1    1.03252    1.01990 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1476257941934127 for eigenvalue
#  The estimated number of batches is 1540
#      1175/1    1.02994    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1479515052906035 for eigenvalue
#  The estimated number of batches is 1543
#      1176/1    1.02248    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1472112355330748 for eigenvalue
#  The estimated number of batches is 1542
#      1177/1    1.01829    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1463207784811036 for eigenvalue
#  The estimated number of batches is 1541
#      1178/1    1.02521    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.145752822039552 for eigenvalue
#  The estimated number of batches is 1541
#      1179/1    1.02153    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.145256661670463 for eigenvalue
#  The estimated number of batches is 1541
#      1180/1    1.02126    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.144277030469073 for eigenvalue
#  The estimated number of batches is 1539
#      1181/1    1.02322    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1436958822171073 for eigenvalue
#  The estimated number of batches is 1539
#      1182/1    1.01916    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.142727136634535 for eigenvalue
#  The estimated number of batches is 1538
#      1183/1    1.01583    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.141729205454057 for eigenvalue
#  The estimated number of batches is 1537
#      1184/1    1.02217    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1408726036672217 for eigenvalue
#  The estimated number of batches is 1536
#      1185/1    1.01742    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1398840232912413 for eigenvalue
#  The estimated number of batches is 1534
#      1186/1    1.00633    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1413325439899573 for eigenvalue
#  The estimated number of batches is 1539
#      1187/1    1.02569    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.140758716811668 for eigenvalue
#  The estimated number of batches is 1539
#      1188/1    1.02042    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1397957262788236 for eigenvalue
#  The estimated number of batches is 1538
#      1189/1    1.01691    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.138830755514704 for eigenvalue
#  The estimated number of batches is 1537
#      1190/1    1.01399    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.137858427845799 for eigenvalue
#  The estimated number of batches is 1535
#      1191/1    1.02726    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.137178687506312 for eigenvalue
#  The estimated number of batches is 1535
#      1192/1    1.01229    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1374710431520476 for eigenvalue
#  The estimated number of batches is 1537
#      1193/1    1.02605    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1366712192929909 for eigenvalue
#  The estimated number of batches is 1536
#      1194/1    1.02305    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.135759174890715 for eigenvalue
#  The estimated number of batches is 1535
#      1195/1    1.01474    1.01991 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1348780757255688 for eigenvalue
#  The estimated number of batches is 1534
#      1196/1    1.02707    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1364069406765291 for eigenvalue
#  The estimated number of batches is 1539
#      1197/1    1.02241    1.01992 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.1355125553480896 for eigenvalue
#  The estimated number of batches is 1538
#      1198/1    1.01707    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1347507194757174 for eigenvalue
#  The estimated number of batches is 1537
#      1199/1    1.01590    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1337818525798435 for eigenvalue
#  The estimated number of batches is 1536
#      1200/1    1.02231    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1329110021425035 for eigenvalue
#  The estimated number of batches is 1535
#      1201/1    1.01996    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1336361936502024 for eigenvalue
#  The estimated number of batches is 1538
#      1202/1    1.01613    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.132668157329179 for eigenvalue
#  The estimated number of batches is 1537
#      1203/1    1.01026    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1332642303342841 for eigenvalue
#  The estimated number of batches is 1540
#      1204/1    1.02189    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1323092081248465 for eigenvalue
#  The estimated number of batches is 1539
#      1205/1    1.02484    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1314719975222476 for eigenvalue
#  The estimated number of batches is 1538
#      1206/1    1.02887    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1306582649243313 for eigenvalue
#  The estimated number of batches is 1537
#      1207/1    1.02933    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1297417855044565 for eigenvalue
#  The estimated number of batches is 1535
#      1208/1    1.02253    1.01993 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1294247134281652 for eigenvalue
#  The estimated number of batches is 1536
#      1209/1    1.02272    1.01993 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1287965723317093 for eigenvalue
#  The estimated number of batches is 1536
#      1210/1    1.01267    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1281992456002512 for eigenvalue
#  The estimated number of batches is 1535
#      1211/1    1.00895    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1275334838916635 for eigenvalue
#  The estimated number of batches is 1535
#      1212/1    1.00719    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1267491825851073 for eigenvalue
#  The estimated number of batches is 1534
#      1213/1    1.02184    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1264477803872666 for eigenvalue
#  The estimated number of batches is 1534
#      1214/1    1.01990    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1255132352727046 for eigenvalue
#  The estimated number of batches is 1533
#      1215/1    1.02361    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1248402302493972 for eigenvalue
#  The estimated number of batches is 1532
#      1216/1    1.02406    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1239683672091947 for eigenvalue
#  The estimated number of batches is 1531
#      1217/1    1.02246    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1231162560769086 for eigenvalue
#  The estimated number of batches is 1530
#      1218/1    1.01609    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1225589501807296 for eigenvalue
#  The estimated number of batches is 1530
#      1219/1    1.02310    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1218717346412077 for eigenvalue
#  The estimated number of batches is 1530
#      1220/1    1.02354    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.121333851695739 for eigenvalue
#  The estimated number of batches is 1529
#      1221/1    1.03616    1.01993 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1219757981925125 for eigenvalue
#  The estimated number of batches is 1532
#      1222/1    1.02862    1.01994 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1214084670905684 for eigenvalue
#  The estimated number of batches is 1532
#      1223/1    1.01750    1.01993 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1206178526563417 for eigenvalue
#  The estimated number of batches is 1531
#      1224/1    1.01644    1.01993 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.119867476436315 for eigenvalue
#  The estimated number of batches is 1530
#      1225/1    1.01193    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1189350228120334 for eigenvalue
#  The estimated number of batches is 1529
#      1226/1    1.01318    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1179860973323783 for eigenvalue
#  The estimated number of batches is 1528
#      1227/1    1.01724    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.117345970196167 for eigenvalue
#  The estimated number of batches is 1527
#      1228/1    1.00645    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1181712394443022 for eigenvalue
#  The estimated number of batches is 1531
#      1229/1    1.01687    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1172444695143988 for eigenvalue
#  The estimated number of batches is 1530
#      1230/1    1.02440    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1166107328439905 for eigenvalue
#  The estimated number of batches is 1529
#      1231/1    1.02136    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1157001928139303 for eigenvalue
#  The estimated number of batches is 1528
#      1232/1    1.02639    1.01991 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.115329181526796 for eigenvalue
#  The estimated number of batches is 1528
#      1233/1    1.02355    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.114835084060499 for eigenvalue
#  The estimated number of batches is 1528
#      1234/1    1.02404    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1139245529475263 for eigenvalue
#  The estimated number of batches is 1527
#      1235/1    1.01683    1.01992 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1130653464042939 for eigenvalue
#  The estimated number of batches is 1526
#      1236/1    1.00487    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.113699985786148 for eigenvalue
#  The estimated number of batches is 1529
#      1237/1    1.01736    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1137966089502647 for eigenvalue
#  The estimated number of batches is 1530
#      1238/1    1.01643    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.112949264975796 for eigenvalue
#  The estimated number of batches is 1529
#      1239/1    1.01727    1.01990 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.1124399264659854 for eigenvalue
#  The estimated number of batches is 1529
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sp_file = model.run()
#
# File /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/model/model.py:711, in Model.run(self, particles, threads, geometry_debug, restart_file, tracks, output, cwd, openmc_exec, mpi_args, event_based, export_model_xml, **export_kwargs)
#     709     else:
#     710         self.export_to_xml(**export_kwargs)
# --> 711     openmc.run(particles, threads, geometry_debug, restart_file,
#     712                tracks, output, Path('.'), openmc_exec, mpi_args,
#     713                event_based)
#     715 # Get output directory and return the last statepoint written
#     716 if self.settings.output and 'path' in self.settings.output:
#
# File /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/executor.py:314, in run(particles, threads, geometry_debug, restart_file, tracks, output, cwd, openmc_exec, mpi_args, event_based, path_input)
#     261 """Run an OpenMC simulation.
#     262
#     263 Parameters
#    (...)
#     305
#     306 """
#     308 args = _process_CLI_arguments(
#     309     volume=False, geometry_debug=geometry_debug, particles=particles,
#     310     restart_file=restart_file, threads=threads, tracks=tracks,
#     311     event_based=event_based, openmc_exec=openmc_exec, mpi_args=mpi_args,
#     312     path_input=path_input)
# --> 314 _run(args, output, cwd)
#
# File /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/executor.py:125, in _run(args, output, cwd)
#     122     error_msg = 'OpenMC aborted unexpectedly.'
#     123 error_msg = ' '.join(error_msg.split())
# --> 125 raise RuntimeError(error_msg)
#
# RuntimeError: OpenMC aborted unexpectedly.
