# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create pyrex tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8),(8,2),(3,3),(5,5),(2,8)]


PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %% [markdown]
# ### Define assembly

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0] 
            
            
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=476.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=2.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=10.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-12 17:29:54
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.97132
#         2/1    0.97888
#         3/1    0.97923
#         4/1    0.96887
#         5/1    0.97566
#         6/1    0.97782
#         7/1    0.97584
#         8/1    0.97608
#         9/1    0.97702
#        10/1    0.97489
#        11/1    0.96868
#        12/1    0.97575
#        13/1    0.97427
#        14/1    0.97767
#        15/1    0.97660
#        16/1    0.97192
#        17/1    0.98379
#        18/1    0.97646
#        19/1    0.97435
#        20/1    0.97133
#        21/1    0.97162
#        22/1    0.97510    0.97336 +/- 0.00174
#        23/1    0.97619    0.97430 +/- 0.00138
#        24/1    0.97291    0.97396 +/- 0.00103
#        25/1    0.97412    0.97399 +/- 0.00080
#        26/1    0.97305    0.97383 +/- 0.00067
#        27/1    0.97727    0.97432 +/- 0.00075
#        28/1    0.97584    0.97451 +/- 0.00068
#        29/1    0.96835    0.97383 +/- 0.00091
#        30/1    0.97333    0.97378 +/- 0.00081
#        31/1    0.97311    0.97372 +/- 0.00074
#        32/1    0.97461    0.97379 +/- 0.00068
#        33/1    0.96728    0.97329 +/- 0.00080
#        34/1    0.97191    0.97319 +/- 0.00075
#        35/1    0.97672    0.97343 +/- 0.00073
#        36/1    0.97079    0.97326 +/- 0.00071
#        37/1    0.96916    0.97302 +/- 0.00071
#        38/1    0.97439    0.97310 +/- 0.00067
#        39/1    0.97052    0.97296 +/- 0.00065
#        40/1    0.97889    0.97326 +/- 0.00068
#        41/1    0.97244    0.97322 +/- 0.00065
#        42/1    0.97046    0.97309 +/- 0.00063
#        43/1    0.97589    0.97321 +/- 0.00062
#        44/1    0.97477    0.97328 +/- 0.00059
#        45/1    0.97702    0.97343 +/- 0.00059
#        46/1    0.97782    0.97360 +/- 0.00059
#        47/1    0.98258    0.97393 +/- 0.00066
#        48/1    0.97566    0.97399 +/- 0.00064
#        49/1    0.97348    0.97397 +/- 0.00062
#        50/1    0.97601    0.97404 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 5.646145696262819 for eigenvalue
#  The estimated number of batches is 977
#  Creating state point statepoint.00050.h5...
#        51/1    0.97057    0.97393 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 5.637677038679246 for eigenvalue
#  The estimated number of batches is 1006
#        52/1    0.96473    0.97364 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.706513607084874 for eigenvalue
#  The estimated number of batches is 1063
#        53/1    0.97390    0.97365 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.612959108057364 for eigenvalue
#  The estimated number of batches is 1060
#        54/1    0.98214    0.97390 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.518523851263381 for eigenvalue
#  The estimated number of batches is 1056
#        55/1    0.97696    0.97399 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 5.2374722215949365 for eigenvalue
#  The estimated number of batches is 981
#        56/1    0.97587    0.97404 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.256418132339388 for eigenvalue
#  The estimated number of batches is 1015
#        57/1    0.97807    0.97415 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 5.136849061587196 for eigenvalue
#  The estimated number of batches is 997
#        58/1    0.97405    0.97415 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.993998657405017 for eigenvalue
#  The estimated number of batches is 968
#        59/1    0.96769    0.97398 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.999370584098458 for eigenvalue
#  The estimated number of batches is 995
#        60/1    0.97925    0.97411 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.876978792299296 for eigenvalue
#  The estimated number of batches is 972
#        61/1    0.97920    0.97424 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.695287881904081 for eigenvalue
#  The estimated number of batches is 924
#        62/1    0.98531    0.97450 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.205013802991843 for eigenvalue
#  The estimated number of batches is 1158
#        63/1    0.98412    0.97472 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.013386681866812 for eigenvalue
#  The estimated number of batches is 1101
#        64/1    0.97858    0.97481 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.9299303943504285 for eigenvalue
#  The estimated number of batches is 1090
#        65/1    0.97547    0.97483 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.798571693827401 for eigenvalue
#  The estimated number of batches is 1057
#        66/1    0.97330    0.97479 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.7210366417055765 for eigenvalue
#  The estimated number of batches is 1046
#        67/1    0.97465    0.97479 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.629552087075951 for eigenvalue
#  The estimated number of batches is 1028
#        68/1    0.96930    0.97468 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.6943141157292665 for eigenvalue
#  The estimated number of batches is 1078
#        69/1    0.98128    0.97481 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.8507699867175464 for eigenvalue
#  The estimated number of batches is 1173
#        70/1    0.97779    0.97487 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.87371140926026 for eigenvalue
#  The estimated number of batches is 1208
#        71/1    0.97469    0.97487 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.8089659819491475 for eigenvalue
#  The estimated number of batches is 1200
#        72/1    0.98365    0.97504 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.889133901157892 for eigenvalue
#  The estimated number of batches is 1263
#        73/1    0.97564    0.97505 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.793600091334354 for eigenvalue
#  The estimated number of batches is 1238
#        74/1    0.97691    0.97508 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.713587850460946 for eigenvalue
#  The estimated number of batches is 1220
#        75/1    0.98527    0.97527 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.67713295115147 for eigenvalue
#  The estimated number of batches is 1224
#        76/1    0.97111    0.97519 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.59744377075934 for eigenvalue
#  The estimated number of batches is 1204
#        77/1    0.97493    0.97519 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.58281763592481 for eigenvalue
#  The estimated number of batches is 1218
#        78/1    0.98244    0.97531 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.489942934272429 for eigenvalue
#  The estimated number of batches is 1190
#        79/1    0.97192    0.97526 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.489632050207379 for eigenvalue
#  The estimated number of batches is 1210
#        80/1    0.97171    0.97520 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.424336213954989 for eigenvalue
#  The estimated number of batches is 1195
#        81/1    0.97364    0.97517 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.354780194155279 for eigenvalue
#  The estimated number of batches is 1177
#        82/1    0.97978    0.97525 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.328983272976528 for eigenvalue
#  The estimated number of batches is 1182
#        83/1    0.97388    0.97522 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.264855673922608 for eigenvalue
#  The estimated number of batches is 1166
#        84/1    0.98934    0.97544 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.393985096488431 for eigenvalue
#  The estimated number of batches is 1256
#        85/1    0.96978    0.97536 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.373427353232782 for eigenvalue
#  The estimated number of batches is 1264
#        86/1    0.97267    0.97532 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.325654049867589 for eigenvalue
#  The estimated number of batches is 1255
#        87/1    0.97165    0.97526 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.266661479228281 for eigenvalue
#  The estimated number of batches is 1240
#        88/1    0.98034    0.97534 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.213498067358552 for eigenvalue
#  The estimated number of batches is 1228
#        89/1    0.97595    0.97535 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.187956206652117 for eigenvalue
#  The estimated number of batches is 1231
#        90/1    0.97596    0.97535 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.136432570985582 for eigenvalue
#  The estimated number of batches is 1218
#        91/1    0.98204    0.97545 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.253330173070033 for eigenvalue
#  The estimated number of batches is 1305
#        92/1    0.97387    0.97543 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.212685000408854 for eigenvalue
#  The estimated number of batches is 1298
#        93/1    0.96475    0.97528 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.16566630943299 for eigenvalue
#  The estimated number of batches is 1287
#        94/1    0.97389    0.97526 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.120473562344375 for eigenvalue
#  The estimated number of batches is 1277
#        95/1    0.97179    0.97521 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.071778722223533 for eigenvalue
#  The estimated number of batches is 1264
#        96/1    0.97678    0.97524 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.013922025874288 for eigenvalue
#  The estimated number of batches is 1245
#        97/1    0.97135    0.97519 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9759801096017635 for eigenvalue
#  The estimated number of batches is 1238
#        98/1    0.98758    0.97534 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.076665289107788 for eigenvalue
#  The estimated number of batches is 1317
#        99/1    0.97546    0.97535 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.024686927602965 for eigenvalue
#  The estimated number of batches is 1300
#       100/1    0.97495    0.97534 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9763816053532115 for eigenvalue
#  The estimated number of batches is 1285
#       101/1    0.98315    0.97544 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9305689733094167 for eigenvalue
#  The estimated number of batches is 1272
#       102/1    0.97106    0.97538 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9512011655940342 for eigenvalue
#  The estimated number of batches is 1301
#       103/1    0.97016    0.97532 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.92828706786563 for eigenvalue
#  The estimated number of batches is 1301
#       104/1    0.97137    0.97527 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.885295324672416 for eigenvalue
#  The estimated number of batches is 1289
#       105/1    0.97991    0.97533 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.874397158364295 for eigenvalue
#  The estimated number of batches is 1296
#       106/1    0.98806    0.97548 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.913457218204868 for eigenvalue
#  The estimated number of batches is 1338
#       107/1    0.97257    0.97544 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9023412082942137 for eigenvalue
#  The estimated number of batches is 1345
#       108/1    0.97202    0.97540 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.932730314471929 for eigenvalue
#  The estimated number of batches is 1382
#       109/1    0.98000    0.97546 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8899812063526733 for eigenvalue
#  The estimated number of batches is 1367
#       110/1    0.96721    0.97536 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.9366129292040406 for eigenvalue
#  The estimated number of batches is 1415
#       111/1    0.98677    0.97549 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.9079904282963804 for eigenvalue
#  The estimated number of batches is 1410
#       112/1    0.99178    0.97567 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.024062188157015 for eigenvalue
#  The estimated number of batches is 1510
#       113/1    0.96987    0.97560 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.9814833540597387 for eigenvalue
#  The estimated number of batches is 1495
#       114/1    0.97250    0.97557 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.9400455065450757 for eigenvalue
#  The estimated number of batches is 1480
#       115/1    0.96687    0.97548 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.9403909223864035 for eigenvalue
#  The estimated number of batches is 1496
#       116/1    0.98069    0.97553 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.909412217715121 for eigenvalue
#  The estimated number of batches is 1488
#       117/1    0.97089    0.97549 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.8751608316355965 for eigenvalue
#  The estimated number of batches is 1477
#       118/1    0.97404    0.97547 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.841703369764437 for eigenvalue
#  The estimated number of batches is 1467
#       119/1    0.96599    0.97538 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.828942741449962 for eigenvalue
#  The estimated number of batches is 1472
#       120/1    0.97607    0.97538 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.7921590477309466 for eigenvalue
#  The estimated number of batches is 1459
#       121/1    0.97957    0.97542 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.8126502776113824 for eigenvalue
#  The estimated number of batches is 1489
#       122/1    0.97054    0.97538 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.791943557360678 for eigenvalue
#  The estimated number of batches is 1487
#       123/1    0.96639    0.97529 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.817080951806283 for eigenvalue
#  The estimated number of batches is 1521
#       124/1    0.97722    0.97531 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.7872497697333234 for eigenvalue
#  The estimated number of batches is 1512
#       125/1    0.98523    0.97540 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8365887206535634 for eigenvalue
#  The estimated number of batches is 1566
#       126/1    0.97481    0.97540 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.831427115806374 for eigenvalue
#  The estimated number of batches is 1577
#       127/1    0.97062    0.97535 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.807965073847276 for eigenvalue
#  The estimated number of batches is 1572
#       128/1    0.98174    0.97541 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.825414990453544 for eigenvalue
#  The estimated number of batches is 1601
#       129/1    0.97281    0.97539 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.791906848618664 for eigenvalue
#  The estimated number of batches is 1588
#       130/1    0.97539    0.97539 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7637656077033927 for eigenvalue
#  The estimated number of batches is 1579
#       131/1    0.98002    0.97543 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.731353984747865 for eigenvalue
#  The estimated number of batches is 1566
#       132/1    0.97296    0.97541 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.6995663553431144 for eigenvalue
#  The estimated number of batches is 1553
#       133/1    0.97555    0.97541 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.670135909521446 for eigenvalue
#  The estimated number of batches is 1543
#       134/1    0.96827    0.97535 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.658600214175582 for eigenvalue
#  The estimated number of batches is 1546
#       135/1    0.97428    0.97534 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6634030064512135 for eigenvalue
#  The estimated number of batches is 1564
#       136/1    0.96917    0.97528 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.640908312410574 for eigenvalue
#  The estimated number of batches is 1558
#       137/1    0.97672    0.97529 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.6649753909208123 for eigenvalue
#  The estimated number of batches is 1592
#       138/1    0.98903    0.97541 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6482916783394757 for eigenvalue
#  The estimated number of batches is 1591
#       139/1    0.97606    0.97542 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6162074294514017 for eigenvalue
#  The estimated number of batches is 1577
#       140/1    0.97339    0.97540 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.585395363948816 for eigenvalue
#  The estimated number of batches is 1563
#       141/1    0.97609    0.97541 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.5720462714355703 for eigenvalue
#  The estimated number of batches is 1564
#       142/1    0.97529    0.97540 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.5470580454649476 for eigenvalue
#  The estimated number of batches is 1555
#       143/1    0.97458    0.97540 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5205978470115245 for eigenvalue
#  The estimated number of batches is 1545
#       144/1    0.98582    0.97548 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.616938406068304 for eigenvalue
#  The estimated number of batches is 1643
#       145/1    0.96977    0.97544 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.6151846519083843 for eigenvalue
#  The estimated number of batches is 1654
#       146/1    0.97835    0.97546 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.601445929543258 for eigenvalue
#  The estimated number of batches is 1655
#       147/1    0.98109    0.97550 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.574817610854309 for eigenvalue
#  The estimated number of batches is 1643
#       148/1    0.97635    0.97551 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.559847223953386 for eigenvalue
#  The estimated number of batches is 1643
#       149/1    0.97231    0.97549 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5349974940822846 for eigenvalue
#  The estimated number of batches is 1633
#       150/1    0.98146    0.97553 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.505969310937337 for eigenvalue
#  The estimated number of batches is 1618
#       151/1    0.97303    0.97551 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.4799076798117174 for eigenvalue
#  The estimated number of batches is 1607
#       152/1    0.99131    0.97563 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5041132369174424 for eigenvalue
#  The estimated number of batches is 1641
#       153/1    0.97956    0.97566 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.5221636321684073 for eigenvalue
#  The estimated number of batches is 1670
#       154/1    0.97541    0.97566 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.5058992220299534 for eigenvalue
#  The estimated number of batches is 1668
#       155/1    0.97131    0.97563 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.4806617637486843 for eigenvalue
#  The estimated number of batches is 1656
#       156/1    0.97651    0.97563 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.460354705667252 for eigenvalue
#  The estimated number of batches is 1649
#       157/1    0.97151    0.97560 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4354096838217125 for eigenvalue
#  The estimated number of batches is 1637
#       158/1    0.97305    0.97559 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4112293164445924 for eigenvalue
#  The estimated number of batches is 1626
#       159/1    0.97478    0.97558 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.4036252926776194 for eigenvalue
#  The estimated number of batches is 1631
#       160/1    0.98078    0.97562 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.3884555570593795 for eigenvalue
#  The estimated number of batches is 1628
#       161/1    0.98280    0.97567 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.36643948053144 for eigenvalue
#  The estimated number of batches is 1618
#       162/1    0.98139    0.97571 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3434870661178393 for eigenvalue
#  The estimated number of batches is 1608
#       163/1    0.96956    0.97566 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.338107098239311 for eigenvalue
#  The estimated number of batches is 1614
#       164/1    0.97865    0.97569 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3445709097865013 for eigenvalue
#  The estimated number of batches is 1631
#       165/1    0.97796    0.97570 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.320845045306553 for eigenvalue
#  The estimated number of batches is 1620
#       166/1    0.98488    0.97576 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.315931634496744 for eigenvalue
#  The estimated number of batches is 1626
#       167/1    0.98039    0.97580 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3076837804041235 for eigenvalue
#  The estimated number of batches is 1629
#       168/1    0.97633    0.97580 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.285520094228161 for eigenvalue
#  The estimated number of batches is 1618
#       169/1    0.97933    0.97582 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.26281544222856 for eigenvalue
#  The estimated number of batches is 1607
#       170/1    0.96836    0.97577 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2461506475279958 for eigenvalue
#  The estimated number of batches is 1601
#       171/1    0.97121    0.97574 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.226488144937254 for eigenvalue
#  The estimated number of batches is 1592
#       172/1    0.97968    0.97577 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2093546942106674 for eigenvalue
#  The estimated number of batches is 1586
#       173/1    0.97756    0.97578 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1890915625504563 for eigenvalue
#  The estimated number of batches is 1577
#       174/1    0.98324    0.97583 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1804054500698977 for eigenvalue
#  The estimated number of batches is 1578
#       175/1    0.97045    0.97579 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.16562037646636 for eigenvalue
#  The estimated number of batches is 1574
#       176/1    0.96891    0.97575 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1560889527245823 for eigenvalue
#  The estimated number of batches is 1574
#       177/1    0.97140    0.97572 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.136300250455146 for eigenvalue
#  The estimated number of batches is 1565
#       178/1    0.97929    0.97575 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1183075640142115 for eigenvalue
#  The estimated number of batches is 1557
#       179/1    0.96487    0.97568 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1794343821669115 for eigenvalue
#  The estimated number of batches is 1628
#       180/1    0.97371    0.97566 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.161631882625408 for eigenvalue
#  The estimated number of batches is 1620
#       181/1    0.97870    0.97568 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1460442327370144 for eigenvalue
#  The estimated number of batches is 1614
#       182/1    0.98217    0.97572 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.126361176992574 for eigenvalue
#  The estimated number of batches is 1604
#       183/1    0.97299    0.97571 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1142826633404948 for eigenvalue
#  The estimated number of batches is 1601
#       184/1    0.97479    0.97570 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1021208322879246 for eigenvalue
#  The estimated number of batches is 1599
#       185/1    0.97788    0.97571 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0852968940677665 for eigenvalue
#  The estimated number of batches is 1591
#       186/1    0.97940    0.97574 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.080800854202595 for eigenvalue
#  The estimated number of batches is 1596
#       187/1    0.98142    0.97577 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0608049533720534 for eigenvalue
#  The estimated number of batches is 1585
#       188/1    0.97887    0.97579 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.050890736346225 for eigenvalue
#  The estimated number of batches is 1584
#       189/1    0.98985    0.97587 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0437996727684897 for eigenvalue
#  The estimated number of batches is 1586
#       190/1    0.97538    0.97587 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.026090848147987 for eigenvalue
#  The estimated number of batches is 1577
#       191/1    0.98116    0.97590 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.019288677179818 for eigenvalue
#  The estimated number of batches is 1579
#       192/1    0.96704    0.97585 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.011363336637821 for eigenvalue
#  The estimated number of batches is 1580
#       193/1    0.97832    0.97586 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.99363495081304 for eigenvalue
#  The estimated number of batches is 1571
#       194/1    0.98311    0.97590 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9911141024625163 for eigenvalue
#  The estimated number of batches is 1577
#       195/1    0.97263    0.97589 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.985321642032314 for eigenvalue
#  The estimated number of batches is 1580
#       196/1    0.97799    0.97590 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.981035869844591 for eigenvalue
#  The estimated number of batches is 1585
#       197/1    0.97305    0.97588 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9708100699395095 for eigenvalue
#  The estimated number of batches is 1583
#       198/1    0.96598    0.97583 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9607886368941587 for eigenvalue
#  The estimated number of batches is 1581
#       199/1    0.97566    0.97583 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9496924142561323 for eigenvalue
#  The estimated number of batches is 1578
#       200/1    0.97801    0.97584 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.934667376887691 for eigenvalue
#  The estimated number of batches is 1571
#       201/1    0.97135    0.97581 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9202294395585287 for eigenvalue
#  The estimated number of batches is 1564
#       202/1    0.96657    0.97576 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9147672931517086 for eigenvalue
#  The estimated number of batches is 1567
#       203/1    0.97935    0.97578 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9037466873015654 for eigenvalue
#  The estimated number of batches is 1564
#       204/1    0.97371    0.97577 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8887044304948866 for eigenvalue
#  The estimated number of batches is 1556
#       205/1    0.97845    0.97578 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.876343670792493 for eigenvalue
#  The estimated number of batches is 1551
#       206/1    0.96812    0.97574 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8719511049970037 for eigenvalue
#  The estimated number of batches is 1555
#       207/1    0.96878    0.97571 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8853275119914636 for eigenvalue
#  The estimated number of batches is 1577
#       208/1    0.97964    0.97573 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.869990443476087 for eigenvalue
#  The estimated number of batches is 1569
#       209/1    0.99077    0.97581 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8790742250115433 for eigenvalue
#  The estimated number of batches is 1587
#       210/1    0.97602    0.97581 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.864808198764839 for eigenvalue
#  The estimated number of batches is 1580
#       211/1    0.97487    0.97580 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.853269490510517 for eigenvalue
#  The estimated number of batches is 1575
#       212/1    0.98145    0.97583 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8396958979348943 for eigenvalue
#  The estimated number of batches is 1569
#       213/1    0.98476    0.97588 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.832190766425104 for eigenvalue
#  The estimated number of batches is 1569
#       214/1    0.97471    0.97587 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8181037598508007 for eigenvalue
#  The estimated number of batches is 1561
#       215/1    0.96820    0.97583 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8234840826740757 for eigenvalue
#  The estimated number of batches is 1575
#       216/1    0.97550    0.97583 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8113849118978944 for eigenvalue
#  The estimated number of batches is 1570
#       217/1    0.97592    0.97583 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.799433023151519 for eigenvalue
#  The estimated number of batches is 1564
#       218/1    0.97699    0.97584 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7845735257168807 for eigenvalue
#  The estimated number of batches is 1556
#       219/1    0.97286    0.97582 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7732404150683383 for eigenvalue
#  The estimated number of batches is 1551
#       220/1    0.97500    0.97582 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.758898347293464 for eigenvalue
#  The estimated number of batches is 1543
#       221/1    0.97699    0.97582 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7448217203704286 for eigenvalue
#  The estimated number of batches is 1535
#       222/1    0.97031    0.97580 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7424984514327373 for eigenvalue
#  The estimated number of batches is 1540
#       223/1    0.96968    0.97577 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7296672402165005 for eigenvalue
#  The estimated number of batches is 1533
#       224/1    0.97846    0.97578 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7156012691057003 for eigenvalue
#  The estimated number of batches is 1525
#       225/1    0.97521    0.97578 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.7082647063221064 for eigenvalue
#  The estimated number of batches is 1524
#       226/1    0.97844    0.97579 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.694789845979119 for eigenvalue
#  The estimated number of batches is 1516
#       227/1    0.97676    0.97580 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6910450744992525 for eigenvalue
#  The estimated number of batches is 1520
#       228/1    0.97863    0.97581 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6774045417714394 for eigenvalue
#  The estimated number of batches is 1512
#       229/1    0.97553    0.97581 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6690709750108925 for eigenvalue
#  The estimated number of batches is 1509
#       230/1    0.97162    0.97579 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.657359505631896 for eigenvalue
#  The estimated number of batches is 1503
#       231/1    0.97496    0.97578 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.656835464189801 for eigenvalue
#  The estimated number of batches is 1510
#       232/1    0.97590    0.97578 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6446995064343204 for eigenvalue
#  The estimated number of batches is 1503
#       233/1    0.96894    0.97575 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.661406800821277 for eigenvalue
#  The estimated number of batches is 1529
#       234/1    0.98054    0.97577 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6500305099237615 for eigenvalue
#  The estimated number of batches is 1523
#       235/1    0.97573    0.97577 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.63742673905746 for eigenvalue
#  The estimated number of batches is 1516
#       236/1    0.96901    0.97574 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.635543837758119 for eigenvalue
#  The estimated number of batches is 1521
#       237/1    0.98478    0.97578 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6346368281663612 for eigenvalue
#  The estimated number of batches is 1527
#       238/1    0.97598    0.97579 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6227056000184077 for eigenvalue
#  The estimated number of batches is 1520
#       239/1    0.98293    0.97582 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6103444024436984 for eigenvalue
#  The estimated number of batches is 1513
#       240/1    0.97586    0.97582 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5979337340749358 for eigenvalue
#  The estimated number of batches is 1505
#       241/1    0.97727    0.97582 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5997814389067675 for eigenvalue
#  The estimated number of batches is 1514
#       242/1    0.98648    0.97587 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.60448708379148 for eigenvalue
#  The estimated number of batches is 1526
#       243/1    0.97818    0.97588 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5926169019162204 for eigenvalue
#  The estimated number of batches is 1519
#       244/1    0.96411    0.97583 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5941902892094872 for eigenvalue
#  The estimated number of batches is 1528
#       245/1    0.97511    0.97583 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.583085260247495 for eigenvalue
#  The estimated number of batches is 1522
#       246/1    0.97425    0.97582 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.573136196488224 for eigenvalue
#  The estimated number of batches is 1517
#       247/1    0.99126    0.97589 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5673991482739926 for eigenvalue
#  The estimated number of batches is 1517
#       248/1    0.97491    0.97588 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.556244069406578 for eigenvalue
#  The estimated number of batches is 1510
#       249/1    0.96754    0.97585 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.549377822244107 for eigenvalue
#  The estimated number of batches is 1509
#       250/1    0.97514    0.97584 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5380272802364465 for eigenvalue
#  The estimated number of batches is 1502
#       251/1    0.97870    0.97586 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.529861323578762 for eigenvalue
#  The estimated number of batches is 1499
#       252/1    0.98587    0.97590 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.519107746155934 for eigenvalue
#  The estimated number of batches is 1493
#       253/1    0.97772    0.97591 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.509254769334704 for eigenvalue
#  The estimated number of batches is 1488
#       254/1    0.98081    0.97593 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.500656154882698 for eigenvalue
#  The estimated number of batches is 1484
#       255/1    0.97205    0.97591 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4921867017627526 for eigenvalue
#  The estimated number of batches is 1480
#       256/1    0.97078    0.97589 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.481696027060423 for eigenvalue
#  The estimated number of batches is 1474
#       257/1    0.97246    0.97588 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4727181989197415 for eigenvalue
#  The estimated number of batches is 1470
#       258/1    0.97055    0.97585 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4807745211791117 for eigenvalue
#  The estimated number of batches is 1485
#       259/1    0.98727    0.97590 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.4777827815215443 for eigenvalue
#  The estimated number of batches is 1488
#       260/1    0.97638    0.97590 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.467941835318987 for eigenvalue
#  The estimated number of batches is 1482
#       261/1    0.97267    0.97589 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4632342118390285 for eigenvalue
#  The estimated number of batches is 1483
#       262/1    0.97527    0.97589 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.454159649318561 for eigenvalue
#  The estimated number of batches is 1478
#       263/1    0.96980    0.97586 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4560030389537255 for eigenvalue
#  The estimated number of batches is 1486
#       264/1    0.98086    0.97588 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4481142825217694 for eigenvalue
#  The estimated number of batches is 1483
#       265/1    0.97496    0.97588 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.44144466600325 for eigenvalue
#  The estimated number of batches is 1481
#       266/1    0.98284    0.97591 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4355447995412924 for eigenvalue
#  The estimated number of batches is 1480
#       267/1    0.97355    0.97590 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.426186302627492 for eigenvalue
#  The estimated number of batches is 1474
#       268/1    0.97649    0.97590 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.4187864823554777 for eigenvalue
#  The estimated number of batches is 1471
#       269/1    0.97898    0.97591 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.431034678086786 for eigenvalue
#  The estimated number of batches is 1492
#       270/1    0.97188    0.97590 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4436892436163276 for eigenvalue
#  The estimated number of batches is 1513
#       271/1    0.96723    0.97586 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.436814510090574 for eigenvalue
#  The estimated number of batches is 1511
#       272/1    0.97225    0.97585 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4306829120322435 for eigenvalue
#  The estimated number of batches is 1509
#       273/1    0.97059    0.97583 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.423005408725332 for eigenvalue
#  The estimated number of batches is 1506
#       274/1    0.96675    0.97579 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4198494079061086 for eigenvalue
#  The estimated number of batches is 1508
#       275/1    0.97203    0.97578 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4103033294384173 for eigenvalue
#  The estimated number of batches is 1502
#       276/1    0.96975    0.97575 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4011694175541596 for eigenvalue
#  The estimated number of batches is 1496
#       277/1    0.98262    0.97578 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3925530155350074 for eigenvalue
#  The estimated number of batches is 1492
#       278/1    0.97441    0.97577 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3836425343428242 for eigenvalue
#  The estimated number of batches is 1486
#       279/1    0.98384    0.97581 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.37638666658504 for eigenvalue
#  The estimated number of batches is 1483
#       280/1    0.97014    0.97578 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3781764436907156 for eigenvalue
#  The estimated number of batches is 1491
#       281/1    0.97452    0.97578 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3822338323277674 for eigenvalue
#  The estimated number of batches is 1502
#       282/1    0.97386    0.97577 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3731646445225 for eigenvalue
#  The estimated number of batches is 1496
#       283/1    0.98434    0.97580 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3640073932163705 for eigenvalue
#  The estimated number of batches is 1490
#       284/1    0.98517    0.97584 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.379910685776947 for eigenvalue
#  The estimated number of batches is 1516
#       285/1    0.97471    0.97584 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3722399569105406 for eigenvalue
#  The estimated number of batches is 1512
#       286/1    0.97611    0.97584 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3685231283102848 for eigenvalue
#  The estimated number of batches is 1513
#       287/1    0.98466    0.97587 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.3612105478428824 for eigenvalue
#  The estimated number of batches is 1509
#       288/1    0.97669    0.97587 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3552415031869436 for eigenvalue
#  The estimated number of batches is 1507
#       289/1    0.97510    0.97587 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3466322207696555 for eigenvalue
#  The estimated number of batches is 1502
#       290/1    0.97935    0.97588 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3405589587970903 for eigenvalue
#  The estimated number of batches is 1500
#       291/1    0.97904    0.97589 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.336350242211297 for eigenvalue
#  The estimated number of batches is 1500
#       292/1    0.97722    0.97590 +/- 0.00033
# ...
#      1457/1    0.97144    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0283018069038379 for eigenvalue
#  The estimated number of batches is 1540
#      1458/1    0.97609    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0276166619432516 for eigenvalue
#  The estimated number of batches is 1539
#      1459/1    0.98058    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0268773614716322 for eigenvalue
#  The estimated number of batches is 1538
#      1460/1    0.97640    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0261935287993698 for eigenvalue
#  The estimated number of batches is 1537
#      1461/1    0.98527    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0258019962160383 for eigenvalue
#  The estimated number of batches is 1537
#      1462/1    0.97751    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0251223773397289 for eigenvalue
#  The estimated number of batches is 1536
#      1463/1    0.97081    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0246509689660597 for eigenvalue
#  The estimated number of batches is 1536
#      1464/1    0.97474    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0239368631377967 for eigenvalue
#  The estimated number of batches is 1534
#      1465/1    0.98372    0.97584 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.024200821904223 for eigenvalue
#  The estimated number of batches is 1536
#      1466/1    0.97062    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0266188321531122 for eigenvalue
#  The estimated number of batches is 1545
#      1467/1    0.97624    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.025897226982437 for eigenvalue
#  The estimated number of batches is 1543
#      1468/1    0.97631    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0251745535908514 for eigenvalue
#  The estimated number of batches is 1542
#      1469/1    0.97622    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0244556126663795 for eigenvalue
#  The estimated number of batches is 1541
#      1470/1    0.97074    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0237362038992255 for eigenvalue
#  The estimated number of batches is 1540
#      1471/1    0.97199    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0235502151508202 for eigenvalue
#  The estimated number of batches is 1541
#      1472/1    0.97998    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.023865934183655 for eigenvalue
#  The estimated number of batches is 1543
#      1473/1    0.97112    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.023346208758297 for eigenvalue
#  The estimated number of batches is 1542
#      1474/1    0.97568    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.022704622096455 for eigenvalue
#  The estimated number of batches is 1541
#      1475/1    0.98051    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.022289853653572 for eigenvalue
#  The estimated number of batches is 1541
#      1476/1    0.97499    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0216519282319765 for eigenvalue
#  The estimated number of batches is 1540
#      1477/1    0.98100    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.020944136082401 for eigenvalue
#  The estimated number of batches is 1539
#      1478/1    0.98060    0.97584 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0204409118045275 for eigenvalue
#  The estimated number of batches is 1539
#      1479/1    0.97798    0.97584 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.020229477796836 for eigenvalue
#  The estimated number of batches is 1539
#      1480/1    0.96636    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0195688281490864 for eigenvalue
#  The estimated number of batches is 1538
#      1481/1    0.96741    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.01897763976991 for eigenvalue
#  The estimated number of batches is 1537
#      1482/1    0.96750    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.019889404188157 for eigenvalue
#  The estimated number of batches is 1541
#      1483/1    0.97328    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0193951373833077 for eigenvalue
#  The estimated number of batches is 1541
#      1484/1    0.98391    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0187915505719192 for eigenvalue
#  The estimated number of batches is 1540
#      1485/1    0.97005    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0181282227889228 for eigenvalue
#  The estimated number of batches is 1539
#      1486/1    0.97963    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0173811240235622 for eigenvalue
#  The estimated number of batches is 1538
#      1487/1    0.97377    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0168565199889297 for eigenvalue
#  The estimated number of batches is 1537
#      1488/1    0.96866    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0162246205137995 for eigenvalue
#  The estimated number of batches is 1537
#      1489/1    0.97429    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0158092474728682 for eigenvalue
#  The estimated number of batches is 1536
#      1490/1    0.96775    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0157856623526622 for eigenvalue
#  The estimated number of batches is 1537
#      1491/1    0.97881    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0151316971713207 for eigenvalue
#  The estimated number of batches is 1536
#      1492/1    0.96624    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0157030272396714 for eigenvalue
#  The estimated number of batches is 1539
#      1493/1    0.97557    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0150412280293195 for eigenvalue
#  The estimated number of batches is 1538
#      1494/1    0.97198    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0155477271601183 for eigenvalue
#  The estimated number of batches is 1541
#      1495/1    0.97476    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0148793011125825 for eigenvalue
#  The estimated number of batches is 1540
#      1496/1    0.97584    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0142242266740027 for eigenvalue
#  The estimated number of batches is 1539
#      1497/1    0.97383    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0135426932694402 for eigenvalue
#  The estimated number of batches is 1538
#      1498/1    0.97108    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.013814519838398 for eigenvalue
#  The estimated number of batches is 1540
#      1499/1    0.96968    0.97579 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0133508201223465 for eigenvalue
#  The estimated number of batches is 1539
#      1500/1    0.97871    0.97579 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0126605322382949 for eigenvalue
#  The estimated number of batches is 1538
#      1501/1    0.97468    0.97579 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.011951356781273 for eigenvalue
#  The estimated number of batches is 1537
#      1502/1    0.97154    0.97579 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0112892219630785 for eigenvalue
#  The estimated number of batches is 1536
#      1503/1    0.97712    0.97579 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0114796916638076 for eigenvalue
#  The estimated number of batches is 1538
#      1504/1    0.98441    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0120481008449735 for eigenvalue
#  The estimated number of batches is 1540
#      1505/1    0.97003    0.97579 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0114874208382545 for eigenvalue
#  The estimated number of batches is 1540
#      1506/1    0.98548    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0118856944205552 for eigenvalue
#  The estimated number of batches is 1542
#      1507/1    0.98805    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0112793236046747 for eigenvalue
#  The estimated number of batches is 1541
#      1508/1    0.96897    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0108995508870084 for eigenvalue
#  The estimated number of batches is 1541
#      1509/1    0.97160    0.97580 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0102714614612789 for eigenvalue
#  The estimated number of batches is 1540
#      1510/1    0.98478    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0096696199798754 for eigenvalue
#  The estimated number of batches is 1539
#      1511/1    0.98358    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0091880783328755 for eigenvalue
#  The estimated number of batches is 1539
#      1512/1    0.97829    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.008498206047095 for eigenvalue
#  The estimated number of batches is 1538
#      1513/1    0.97258    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0079443009815154 for eigenvalue
#  The estimated number of batches is 1537
#      1514/1    0.98498    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0075910951851044 for eigenvalue
#  The estimated number of batches is 1537
#      1515/1    0.98262    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0069422214810142 for eigenvalue
#  The estimated number of batches is 1536
#      1516/1    0.98096    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.006763640161207 for eigenvalue
#  The estimated number of batches is 1537
#      1517/1    0.97229    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.006171095844263 for eigenvalue
#  The estimated number of batches is 1536
#      1518/1    0.97227    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0055187651533533 for eigenvalue
#  The estimated number of batches is 1535
#      1519/1    0.97779    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0049278167460938 for eigenvalue
#  The estimated number of batches is 1534
#      1520/1    0.96910    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0044799445034778 for eigenvalue
#  The estimated number of batches is 1534
#      1521/1    0.97474    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0038740218321087 for eigenvalue
#  The estimated number of batches is 1533
#      1522/1    0.97233    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0033254743071007 for eigenvalue
#  The estimated number of batches is 1533
#      1523/1    0.97847    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.002845510688834 for eigenvalue
#  The estimated number of batches is 1532
#      1524/1    0.97323    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0022352095268443 for eigenvalue
#  The estimated number of batches is 1531
#      1525/1    0.99080    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0044726969196345 for eigenvalue
#  The estimated number of batches is 1539
#      1526/1    0.97397    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0041528998317948 for eigenvalue
#  The estimated number of batches is 1539
#      1527/1    0.97651    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0036112413404419 for eigenvalue
#  The estimated number of batches is 1538
#      1528/1    0.97213    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0030433454142957 for eigenvalue
#  The estimated number of batches is 1538
#      1529/1    0.97597    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0023883119238872 for eigenvalue
#  The estimated number of batches is 1537
#      1530/1    0.98281    0.97583 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0016940162195613 for eigenvalue
#  The estimated number of batches is 1536
#      1531/1    0.96790    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0015989569181152 for eigenvalue
#  The estimated number of batches is 1536
#      1532/1    0.96256    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0029281520507403 for eigenvalue
#  The estimated number of batches is 1541
#      1533/1    0.98692    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0031933144307164 for eigenvalue
#  The estimated number of batches is 1543
#      1534/1    0.98412    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0032838068064345 for eigenvalue
#  The estimated number of batches is 1544
#      1535/1    0.97048    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0029730463324225 for eigenvalue
#  The estimated number of batches is 1545
#      1536/1    0.97253    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0024003088983944 for eigenvalue
#  The estimated number of batches is 1544
#      1537/1    0.97064    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0022744247505517 for eigenvalue
#  The estimated number of batches is 1544
#      1538/1    0.97624    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.001603937797596 for eigenvalue
#  The estimated number of batches is 1543
#      1539/1    0.97554    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.00186600490988 for eigenvalue
#  The estimated number of batches is 1545
#      1540/1    0.98272    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0011633012864738 for eigenvalue
#  The estimated number of batches is 1544
#      1541/1    0.97154    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0007600419633034 for eigenvalue
#  The estimated number of batches is 1544
#      1542/1    0.96487    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0010047404146412 for eigenvalue
#  The estimated number of batches is 1546
#      1543/1    0.98199    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0009663462546314 for eigenvalue
#  The estimated number of batches is 1546
#      1544/1    0.97814    0.97582 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0003595234069984 for eigenvalue
#  The estimated number of batches is 1546
#      1545/1    0.97475    0.97581 +/- 0.00014
#  Triggers unsatisfied, max unc./thresh. is 1.0002167780559401 for eigenvalue
#  The estimated number of batches is 1546
#      1546/1    0.97532    0.97581 +/- 0.00014
#  Triggers satisfied for batch 1546
#  Creating state point statepoint.01546.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.0085e+01 seconds
#    Reading cross sections          = 1.9901e+01 seconds
#  Total time in simulation          = 2.3938e+04 seconds
#    Time in transport only          = 2.3721e+04 seconds
#    Time in inactive batches        = 7.4094e+01 seconds
#    Time in active batches          = 2.3864e+04 seconds
#    Time synchronizing fission bank = 1.0896e+01 seconds
#      Sampling source sites         = 8.6156e+00 seconds
#      SEND/RECV source sites        = 2.2782e+00 seconds
#    Time accumulating tallies       = 1.9903e+02 seconds
#    Time writing statepoints        = 2.1825e+00 seconds
#  Total time for finalization       = 1.2431e+01 seconds
#  Total time elapsed                = 2.3971e+04 seconds
#  Calculation Rate (inactive)       = 13496.3 particles/second
#  Calculation Rate (active)         = 3197.29 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.97575 +/- 0.00013
#  k-effective (Track-length)  = 0.97581 +/- 0.00014
#  k-effective (Absorption)    = 0.97588 +/- 0.00012
#  Combined k-effective        = 0.97584 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
