# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)

water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.661)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.178E-03 )


model.materials = openmc.Materials([uo2, zirconium, water,helium]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
GT=[(5,2),(8,2),(3,3),(2,5),(5,5),(8,5),(2,8),(5,8)]
IT=[(8,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))
print(np.array(GT_full)+(1,1))
# Out:
# [[ 4 14]
#  [12  3]
#  [12  6]
#  [12  9]
#  [ 3  6]
#  [12 15]
#  [ 3 12]
#  [12 12]
#  [ 3  9]
#  [ 4  4]
#  [ 9  3]
#  [ 9  6]
#  [ 9 12]
#  [ 9 15]
#  [14 14]
#  [15  6]
#  [15 12]
#  [ 6  3]
#  [15  9]
#  [ 6  6]
#  [ 6 12]
#  [ 6  9]
#  [ 6 15]
#  [14  4]]

# %% [markdown]
# ### Create family pincell

# %%
pincell_1_family=pincell('pincell')
guide_1_family=guide('guide')
instru_1_family=instru('instru')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly


size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT :
            A[ix][iy]=instru_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]    

# print(A)           
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=758.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=360.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=368.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-09 14:46:41
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.17762
#         2/1    1.17864
#         3/1    1.18974
#         4/1    1.18141
#         5/1    1.19237
#         6/1    1.18129
#         7/1    1.19379
#         8/1    1.18852
#         9/1    1.19209
#        10/1    1.18415
#        11/1    1.18307
#        12/1    1.17635
#        13/1    1.17895
#        14/1    1.17946
#        15/1    1.17387
#        16/1    1.18499
#        17/1    1.18483
#        18/1    1.18518
#        19/1    1.18419
#        20/1    1.18518
#        21/1    1.19565
#        22/1    1.18220    1.18893 +/- 0.00673
#        23/1    1.17908    1.18564 +/- 0.00509
#        24/1    1.18894    1.18647 +/- 0.00369
#        25/1    1.18357    1.18589 +/- 0.00292
#        26/1    1.19082    1.18671 +/- 0.00252
#        27/1    1.18200    1.18604 +/- 0.00223
#        28/1    1.17877    1.18513 +/- 0.00214
#        29/1    1.17469    1.18397 +/- 0.00221
#        30/1    1.18301    1.18387 +/- 0.00198
#        31/1    1.19365    1.18476 +/- 0.00200
#        32/1    1.19055    1.18525 +/- 0.00189
#        33/1    1.17551    1.18450 +/- 0.00189
#        34/1    1.17780    1.18402 +/- 0.00182
#        35/1    1.17425    1.18337 +/- 0.00181
#        36/1    1.19342    1.18400 +/- 0.00181
#        37/1    1.17725    1.18360 +/- 0.00174
#        38/1    1.19453    1.18421 +/- 0.00175
#        39/1    1.18967    1.18449 +/- 0.00168
#        40/1    1.18556    1.18455 +/- 0.00160
#        41/1    1.18976    1.18480 +/- 0.00154
#        42/1    1.17745    1.18446 +/- 0.00150
#        43/1    1.18289    1.18439 +/- 0.00144
#        44/1    1.18492    1.18442 +/- 0.00138
#        45/1    1.17806    1.18416 +/- 0.00135
#        46/1    1.17965    1.18399 +/- 0.00131
#        47/1    1.17535    1.18367 +/- 0.00130
#        48/1    1.17857    1.18349 +/- 0.00126
#        49/1    1.17230    1.18310 +/- 0.00128
#        50/1    1.18725    1.18324 +/- 0.00124
#  Triggers unsatisfied, max unc./thresh. is 5.92108241561959 for eigenvalue
#  The estimated number of batches is 1072
#  Creating state point statepoint.00050.h5...
#        51/1    1.19204    1.18352 +/- 0.00123
#  Triggers unsatisfied, max unc./thresh. is 5.698192982999785 for eigenvalue
#  The estimated number of batches is 1027
#        52/1    1.18009    1.18342 +/- 0.00120
#  Triggers unsatisfied, max unc./thresh. is 5.888667796337809 for eigenvalue
#  The estimated number of batches is 1130
#        53/1    1.16603    1.18289 +/- 0.00128
#  Triggers unsatisfied, max unc./thresh. is 5.856429262918677 for eigenvalue
#  The estimated number of batches is 1152
#        54/1    1.18036    1.18281 +/- 0.00124
#  Triggers unsatisfied, max unc./thresh. is 5.6805749434757775 for eigenvalue
#  The estimated number of batches is 1118
#        55/1    1.18789    1.18296 +/- 0.00121
#  Triggers unsatisfied, max unc./thresh. is 5.502093416664782 for eigenvalue
#  The estimated number of batches is 1080
#        56/1    1.18070    1.18290 +/- 0.00118
#  Triggers unsatisfied, max unc./thresh. is 5.406958795183168 for eigenvalue
#  The estimated number of batches is 1073
#        57/1    1.17861    1.18278 +/- 0.00115
#  Triggers unsatisfied, max unc./thresh. is 5.272940735346495 for eigenvalue
#  The estimated number of batches is 1049
#        58/1    1.18773    1.18291 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 5.43003192244862 for eigenvalue
#  The estimated number of batches is 1141
#        59/1    1.18774    1.18303 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 5.273843970229745 for eigenvalue
#  The estimated number of batches is 1105
#        60/1    1.18424    1.18306 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 5.195652654469465 for eigenvalue
#  The estimated number of batches is 1100
#        61/1    1.18703    1.18316 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 5.119574635498848 for eigenvalue
#  The estimated number of batches is 1095
#        62/1    1.18285    1.18315 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 5.010663302458778 for eigenvalue
#  The estimated number of batches is 1075
#        63/1    1.18156    1.18312 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 4.898548051599973 for eigenvalue
#  The estimated number of batches is 1052
#        64/1    1.17537    1.18294 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 5.090261669302779 for eigenvalue
#  The estimated number of batches is 1161
#        65/1    1.18048    1.18289 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 5.241910021199837 for eigenvalue
#  The estimated number of batches is 1257
#        66/1    1.18214    1.18287 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 5.225284148784323 for eigenvalue
#  The estimated number of batches is 1276
#        67/1    1.19097    1.18304 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.113223498016092 for eigenvalue
#  The estimated number of batches is 1249
#        68/1    1.19130    1.18321 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.0329867900724805 for eigenvalue
#  The estimated number of batches is 1236
#        69/1    1.18797    1.18331 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 4.958423643632148 for eigenvalue
#  The estimated number of batches is 1225
#        70/1    1.19310    1.18351 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.08578785657152 for eigenvalue
#  The estimated number of batches is 1314
#        71/1    1.19311    1.18370 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.102694493937488 for eigenvalue
#  The estimated number of batches is 1348
#        72/1    1.19011    1.18382 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.005465902171337 for eigenvalue
#  The estimated number of batches is 1323
#        73/1    1.17365    1.18363 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 4.891423262759221 for eigenvalue
#  The estimated number of batches is 1289
#        74/1    1.19320    1.18380 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 4.81821942404422 for eigenvalue
#  The estimated number of batches is 1274
#        75/1    1.18111    1.18376 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.7241913286994475 for eigenvalue
#  The estimated number of batches is 1248
#        76/1    1.17488    1.18360 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.667218991340495 for eigenvalue
#  The estimated number of batches is 1240
#        77/1    1.17028    1.18336 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 4.651825450405724 for eigenvalue
#  The estimated number of batches is 1254
#        78/1    1.18316    1.18336 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.55881401964577 for eigenvalue
#  The estimated number of batches is 1226
#        79/1    1.17508    1.18322 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.501150103376522 for eigenvalue
#  The estimated number of batches is 1216
#        80/1    1.18207    1.18320 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 4.437200014636549 for eigenvalue
#  The estimated number of batches is 1202
#        81/1    1.19046    1.18332 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.377296353945599 for eigenvalue
#  The estimated number of batches is 1189
#        82/1    1.20001    1.18359 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 4.516329380637112 for eigenvalue
#  The estimated number of batches is 1285
#        83/1    1.18047    1.18354 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.44404178711537 for eigenvalue
#  The estimated number of batches is 1265
#        84/1    1.18720    1.18360 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.379780579442395 for eigenvalue
#  The estimated number of batches is 1248
#        85/1    1.19220    1.18373 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.365659464333445 for eigenvalue
#  The estimated number of batches is 1259
#        86/1    1.19360    1.18388 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.344786523992926 for eigenvalue
#  The estimated number of batches is 1266
#        87/1    1.18989    1.18397 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.298225934739058 for eigenvalue
#  The estimated number of batches is 1258
#        88/1    1.18675    1.18401 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 4.238796787502678 for eigenvalue
#  The estimated number of batches is 1242
#        89/1    1.18311    1.18400 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.284932421328434 for eigenvalue
#  The estimated number of batches is 1287
#        90/1    1.17414    1.18385 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.236220174634634 for eigenvalue
#  The estimated number of batches is 1277
#        91/1    1.18029    1.18380 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 4.326660155706733 for eigenvalue
#  The estimated number of batches is 1350
#        92/1    1.17457    1.18368 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.311942150194585 for eigenvalue
#  The estimated number of batches is 1359
#        93/1    1.17417    1.18355 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.253670909753702 for eigenvalue
#  The estimated number of batches is 1341
#        94/1    1.17893    1.18348 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 4.2093705351753155 for eigenvalue
#  The estimated number of batches is 1332
#        95/1    1.18181    1.18346 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.180396336325619 for eigenvalue
#  The estimated number of batches is 1331
#        96/1    1.19702    1.18364 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 4.114841964256211 for eigenvalue
#  The estimated number of batches is 1307
#        97/1    1.18868    1.18371 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.142593445071403 for eigenvalue
#  The estimated number of batches is 1342
#        98/1    1.19091    1.18380 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.107596759430704 for eigenvalue
#  The estimated number of batches is 1337
#        99/1    1.18006    1.18375 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.048926720899637 for eigenvalue
#  The estimated number of batches is 1316
#       100/1    1.19400    1.18388 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.002538917664457 for eigenvalue
#  The estimated number of batches is 1302
#       101/1    1.18087    1.18384 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 3.9857470682028318 for eigenvalue
#  The estimated number of batches is 1307
#       102/1    1.18510    1.18386 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 3.955053153669129 for eigenvalue
#  The estimated number of batches is 1303
#       103/1    1.17106    1.18370 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.030870575032758 for eigenvalue
#  The estimated number of batches is 1369
#       104/1    1.19338    1.18382 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.306133533270533 for eigenvalue
#  The estimated number of batches is 1578
#       105/1    1.18827    1.18387 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.285992511904871 for eigenvalue
#  The estimated number of batches is 1582
#       106/1    1.18759    1.18391 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.232899049659345 for eigenvalue
#  The estimated number of batches is 1561
#       107/1    1.18504    1.18393 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.188331430713106 for eigenvalue
#  The estimated number of batches is 1547
#       108/1    1.17951    1.18388 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.23764321459721 for eigenvalue
#  The estimated number of batches is 1601
#       109/1    1.19014    1.18395 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.215417210534059 for eigenvalue
#  The estimated number of batches is 1602
#       110/1    1.16890    1.18378 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.36967264724325 for eigenvalue
#  The estimated number of batches is 1739
#       111/1    1.17905    1.18373 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.3269754384666665 for eigenvalue
#  The estimated number of batches is 1724
#       112/1    1.18462    1.18374 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.281372377685035 for eigenvalue
#  The estimated number of batches is 1707
#       113/1    1.19077    1.18381 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.2845429747182235 for eigenvalue
#  The estimated number of batches is 1728
#       114/1    1.18095    1.18378 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.2930484776481315 for eigenvalue
#  The estimated number of batches is 1753
#       115/1    1.18144    1.18376 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.2680492915367685 for eigenvalue
#  The estimated number of batches is 1751
#       116/1    1.18615    1.18378 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.232087715302871 for eigenvalue
#  The estimated number of batches is 1740
#       117/1    1.18655    1.18381 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.194753648501202 for eigenvalue
#  The estimated number of batches is 1727
#       118/1    1.18184    1.18379 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.171726198124989 for eigenvalue
#  The estimated number of batches is 1726
#       119/1    1.18715    1.18382 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.227592313253452 for eigenvalue
#  The estimated number of batches is 1790
#       120/1    1.17584    1.18375 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.193502695838208 for eigenvalue
#  The estimated number of batches is 1779
#       121/1    1.17891    1.18370 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.148351738565057 for eigenvalue
#  The estimated number of batches is 1759
#       122/1    1.20008    1.18386 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.267539959664946 for eigenvalue
#  The estimated number of batches is 1878
#       123/1    1.19136    1.18393 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.249638594221472 for eigenvalue
#  The estimated number of batches is 1881
#       124/1    1.19584    1.18405 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.2141542397998775 for eigenvalue
#  The estimated number of batches is 1867
#       125/1    1.17773    1.18398 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.183946088692514 for eigenvalue
#  The estimated number of batches is 1859
#       126/1    1.18377    1.18398 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.147697285648406 for eigenvalue
#  The estimated number of batches is 1844
#       127/1    1.18216    1.18397 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.1126605457520755 for eigenvalue
#  The estimated number of batches is 1830
#       128/1    1.18364    1.18396 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.076636987742207 for eigenvalue
#  The estimated number of batches is 1815
#       129/1    1.18639    1.18399 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.103051235053552 for eigenvalue
#  The estimated number of batches is 1856
#       130/1    1.18171    1.18396 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.080879012847531 for eigenvalue
#  The estimated number of batches is 1852
#       131/1    1.18790    1.18400 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.044948896500683 for eigenvalue
#  The estimated number of batches is 1837
#       132/1    1.17246    1.18390 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.065707975665132 for eigenvalue
#  The estimated number of batches is 1872
#       133/1    1.18335    1.18389 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.028618467082802 for eigenvalue
#  The estimated number of batches is 1854
#       134/1    1.18633    1.18391 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.004928989015525 for eigenvalue
#  The estimated number of batches is 1849
#       135/1    1.17627    1.18385 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.9816496872093454 for eigenvalue
#  The estimated number of batches is 1844
#       136/1    1.19178    1.18392 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.035250174405661 for eigenvalue
#  The estimated number of batches is 1909
#       137/1    1.18248    1.18390 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.006485822709152 for eigenvalue
#  The estimated number of batches is 1899
#       138/1    1.18193    1.18389 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.9733587763673115 for eigenvalue
#  The estimated number of batches is 1883
#       139/1    1.18166    1.18387 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.966650894132338 for eigenvalue
#  The estimated number of batches is 1893
#       140/1    1.17863    1.18382 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.9335968346568375 for eigenvalue
#  The estimated number of batches is 1877
#       141/1    1.18689    1.18385 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.901894329437878 for eigenvalue
#  The estimated number of batches is 1863
#       142/1    1.18302    1.18384 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.86676282289633 for eigenvalue
#  The estimated number of batches is 1845
#       143/1    1.18251    1.18383 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.8357214374436612 for eigenvalue
#  The estimated number of batches is 1830
#       144/1    1.17289    1.18374 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.8090647388206516 for eigenvalue
#  The estimated number of batches is 1820
#       145/1    1.18382    1.18374 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.7802922981760108 for eigenvalue
#  The estimated number of batches is 1807
#       146/1    1.17398    1.18367 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.7570113829653597 for eigenvalue
#  The estimated number of batches is 1799
#       147/1    1.17689    1.18361 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.7616211280875342 for eigenvalue
#  The estimated number of batches is 1818
#       148/1    1.17531    1.18355 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.732961739615901 for eigenvalue
#  The estimated number of batches is 1804
#       149/1    1.18170    1.18353 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.7045850773172764 for eigenvalue
#  The estimated number of batches is 1791
#       150/1    1.18692    1.18356 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.7191537346348036 for eigenvalue
#  The estimated number of batches is 1819
#       151/1    1.18082    1.18354 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7008952220447604 for eigenvalue
#  The estimated number of batches is 1815
#       152/1    1.17676    1.18349 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.672444670940004 for eigenvalue
#  The estimated number of batches is 1801
#       153/1    1.17931    1.18346 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6570557802125983 for eigenvalue
#  The estimated number of batches is 1799
#       154/1    1.18713    1.18348 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.659374778637219 for eigenvalue
#  The estimated number of batches is 1815
#       155/1    1.19643    1.18358 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.637166872167987 for eigenvalue
#  The estimated number of batches is 1806
#       156/1    1.17638    1.18353 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6764414106090015 for eigenvalue
#  The estimated number of batches is 1859
#       157/1    1.16502    1.18339 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.7290308661186486 for eigenvalue
#  The estimated number of batches is 1926
#       158/1    1.18299    1.18339 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.7002043393395407 for eigenvalue
#  The estimated number of batches is 1910
#       159/1    1.17805    1.18335 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6753717683948652 for eigenvalue
#  The estimated number of batches is 1898
#       160/1    1.18976    1.18340 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6522840321734207 for eigenvalue
#  The estimated number of batches is 1888
#       161/1    1.18299    1.18339 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.630431068447368 for eigenvalue
#  The estimated number of batches is 1879
#       162/1    1.18264    1.18339 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.6108469663116853 for eigenvalue
#  The estimated number of batches is 1872
#       163/1    1.18622    1.18341 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.584570123186929 for eigenvalue
#  The estimated number of batches is 1858
#       164/1    1.18670    1.18343 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5632642839622113 for eigenvalue
#  The estimated number of batches is 1849
#       165/1    1.17834    1.18340 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5552830374931164 for eigenvalue
#  The estimated number of batches is 1853
#       166/1    1.18322    1.18339 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.531375607389346 for eigenvalue
#  The estimated number of batches is 1841
#       167/1    1.17249    1.18332 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.511082442970926 for eigenvalue
#  The estimated number of batches is 1833
#       168/1    1.18684    1.18334 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5028043524235386 for eigenvalue
#  The estimated number of batches is 1836
#       169/1    1.18823    1.18338 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.480883012990065 for eigenvalue
#  The estimated number of batches is 1826
#       170/1    1.19731    1.18347 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4706422920069957 for eigenvalue
#  The estimated number of batches is 1827
#       171/1    1.18816    1.18350 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.454205601834456 for eigenvalue
#  The estimated number of batches is 1822
#       172/1    1.18711    1.18352 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4311872229507867 for eigenvalue
#  The estimated number of batches is 1810
#       173/1    1.18769    1.18355 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.412001572126815 for eigenvalue
#  The estimated number of batches is 1802
#       174/1    1.18078    1.18353 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3921604592121586 for eigenvalue
#  The estimated number of batches is 1793
#       175/1    1.18661    1.18355 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3709574344283446 for eigenvalue
#  The estimated number of batches is 1782
#       176/1    1.17715    1.18351 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.362291488698116 for eigenvalue
#  The estimated number of batches is 1784
#       177/1    1.18111    1.18350 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.345042679303637 for eigenvalue
#  The estimated number of batches is 1777
#       178/1    1.18272    1.18349 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3295632321942823 for eigenvalue
#  The estimated number of batches is 1772
#       179/1    1.18161    1.18348 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.327005238033638 for eigenvalue
#  The estimated number of batches is 1780
#       180/1    1.18435    1.18349 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3075168729108446 for eigenvalue
#  The estimated number of batches is 1771
#       181/1    1.17896    1.18346 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2873774734929495 for eigenvalue
#  The estimated number of batches is 1760
#       182/1    1.18970    1.18350 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2786068613685946 for eigenvalue
#  The estimated number of batches is 1762
#       183/1    1.17513    1.18344 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2744960451023553 for eigenvalue
#  The estimated number of batches is 1768
#       184/1    1.18567    1.18346 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.286235054433766 for eigenvalue
#  The estimated number of batches is 1792
#       185/1    1.18001    1.18344 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2671402287251503 for eigenvalue
#  The estimated number of batches is 1782
#       186/1    1.18778    1.18346 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2557128723635267 for eigenvalue
#  The estimated number of batches is 1780
#       187/1    1.19151    1.18351 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2373890441620223 for eigenvalue
#  The estimated number of batches is 1771
#       188/1    1.18699    1.18353 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2203932672515303 for eigenvalue
#  The estimated number of batches is 1763
#       189/1    1.18459    1.18354 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.201587885346268 for eigenvalue
#  The estimated number of batches is 1753
#       190/1    1.18173    1.18353 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1823795499363356 for eigenvalue
#  The estimated number of batches is 1742
#       191/1    1.19283    1.18358 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.166610661947073 for eigenvalue
#  The estimated number of batches is 1735
#       192/1    1.18709    1.18360 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1516572261663343 for eigenvalue
#  The estimated number of batches is 1729
#       193/1    1.19660    1.18368 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1972314998994773 for eigenvalue
#  The estimated number of batches is 1789
#       194/1    1.18402    1.18368 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1798969449730854 for eigenvalue
#  The estimated number of batches is 1780
#       195/1    1.18537    1.18369 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1694562388053305 for eigenvalue
#  The estimated number of batches is 1778
#       196/1    1.19398    1.18375 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.18704454273094 for eigenvalue
#  The estimated number of batches is 1808
#       197/1    1.19320    1.18380 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1713833859139537 for eigenvalue
#  The estimated number of batches is 1801
#       198/1    1.18338    1.18380 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1536415651543233 for eigenvalue
#  The estimated number of batches is 1791
#       199/1    1.18254    1.18379 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.179262465350299 for eigenvalue
#  The estimated number of batches is 1830
#       200/1    1.18730    1.18381 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1627766849538297 for eigenvalue
#  The estimated number of batches is 1821
#       201/1    1.17545    1.18377 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1459901165175292 for eigenvalue
#  The estimated number of batches is 1812
#       202/1    1.19122    1.18381 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1357656630905324 for eigenvalue
#  The estimated number of batches is 1810
#       203/1    1.20452    1.18392 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.194240860918224 for eigenvalue
#  The estimated number of batches is 1888
#       204/1    1.18285    1.18391 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.178476729084832 for eigenvalue
#  The estimated number of batches is 1879
#       205/1    1.18053    1.18390 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.164063703613301 for eigenvalue
#  The estimated number of batches is 1873
#       206/1    1.17542    1.18385 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.146454386616512 for eigenvalue
#  The estimated number of batches is 1862
#       207/1    1.18920    1.18388 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1306181544267626 for eigenvalue
#  The estimated number of batches is 1853
#       208/1    1.18078    1.18386 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.1304648597989213 for eigenvalue
#  The estimated number of batches is 1863
#       209/1    1.19060    1.18390 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.11502974145134 for eigenvalue
#  The estimated number of batches is 1854
#       210/1    1.18269    1.18389 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0986062735592226 for eigenvalue
#  The estimated number of batches is 1845
#       211/1    1.17974    1.18387 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.09048383086382 for eigenvalue
#  The estimated number of batches is 1845
#       212/1    1.17428    1.18382 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0736984290383162 for eigenvalue
#  The estimated number of batches is 1834
#       213/1    1.18184    1.18381 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0573644856755235 for eigenvalue
#  The estimated number of batches is 1825
#       214/1    1.18702    1.18383 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.075122317097858 for eigenvalue
#  The estimated number of batches is 1855
#       215/1    1.16922    1.18375 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0965438998538195 for eigenvalue
#  The estimated number of batches is 1890
#       216/1    1.18110    1.18374 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.080273025725021 for eigenvalue
#  The estimated number of batches is 1880
#       217/1    1.19743    1.18381 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1375873448436025 for eigenvalue
#  The estimated number of batches is 1960
#       218/1    1.17679    1.18377 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.121605206271165 for eigenvalue
#  The estimated number of batches is 1950
#       219/1    1.19291    1.18382 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.11051358597733 for eigenvalue
#  The estimated number of batches is 1946
#       220/1    1.19193    1.18386 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.1006707898830315 for eigenvalue
#  The estimated number of batches is 1943
#       221/1    1.17871    1.18383 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0866172945964756 for eigenvalue
#  The estimated number of batches is 1935
#       222/1    1.19821    1.18390 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0782418796618116 for eigenvalue
#  The estimated number of batches is 1935
#       223/1    1.19305    1.18395 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.065863353978788 for eigenvalue
#  The estimated number of batches is 1929
#       224/1    1.19383    1.18400 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0543962725485656 for eigenvalue
#  The estimated number of batches is 1924
#       225/1    1.18819    1.18402 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.051881488650556 for eigenvalue
#  The estimated number of batches is 1930
#       226/1    1.19263    1.18406 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0486207913768997 for eigenvalue
#  The estimated number of batches is 1935
#       227/1    1.17757    1.18403 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.039986847515129 for eigenvalue
#  The estimated number of batches is 1933
#       228/1    1.18241    1.18402 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0279103874434465 for eigenvalue
#  The estimated number of batches is 1927
#       229/1    1.17607    1.18398 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0128122685496743 for eigenvalue
#  The estimated number of batches is 1918
#       230/1    1.18316    1.18398 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0040969719098176 for eigenvalue
#  The estimated number of batches is 1916
#       231/1    1.19158    1.18401 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0010031353390154 for eigenvalue
#  The estimated number of batches is 1921
#       232/1    1.17829    1.18399 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9981175461749734 for eigenvalue
#  The estimated number of batches is 1926
#       233/1    1.17905    1.18396 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9834813315658066 for eigenvalue
#  The estimated number of batches is 1916
#       234/1    1.18738    1.18398 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.974261413130209 for eigenvalue
#  The estimated number of batches is 1914
#       235/1    1.19967    1.18405 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.0003261411279776 for eigenvalue
#  The estimated number of batches is 1956
#       236/1    1.18883    1.18408 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9865357670442894 for eigenvalue
#  The estimated number of batches is 1947
#       237/1    1.17537    1.18404 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9752674195837536 for eigenvalue
#  The estimated number of batches is 1941
#       238/1    1.17855    1.18401 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9688102599868564 for eigenvalue
#  The estimated number of batches is 1942
#       239/1    1.17324    1.18396 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.973154999795292 for eigenvalue
#  The estimated number of batches is 1956
#       240/1    1.16852    1.18389 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9874129990064926 for eigenvalue
#  The estimated number of batches is 1984
#       241/1    1.18864    1.18391 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9865827566536107 for eigenvalue
#  The estimated number of batches is 1992
#       242/1    1.18363    1.18391 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.978686667789004 for eigenvalue
#  The estimated number of batches is 1990
#       243/1    1.18124    1.18390 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9652108015258714 for eigenvalue
#  The estimated number of batches is 1981
#       244/1    1.18888    1.18392 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9523981453720958 for eigenvalue
#  The estimated number of batches is 1973
#       245/1    1.18857    1.18394 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.941100774769868 for eigenvalue
#  The estimated number of batches is 1967
#       246/1    1.19030    1.18397 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.930134367393839 for eigenvalue
#  The estimated number of batches is 1961
#       247/1    1.18907    1.18399 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.919115562333696 for eigenvalue
#  The estimated number of batches is 1955
#       248/1    1.18099    1.18398 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.91307408708753 for eigenvalue
#  The estimated number of batches is 1955
#       249/1    1.17834    1.18395 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.920473314656071 for eigenvalue
#  The estimated number of batches is 1974
#       250/1    1.18598    1.18396 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.90806976492525 for eigenvalue
#  The estimated number of batches is 1966
#       251/1    1.18160    1.18395 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8953929745824736 for eigenvalue
#  The estimated number of batches is 1957
#       252/1    1.17739    1.18392 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8889022206531183 for eigenvalue
#  The estimated number of batches is 1957
#       253/1    1.18477    1.18393 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8765644404529436 for eigenvalue
#  The estimated number of batches is 1948
#       254/1    1.17884    1.18391 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.865599881223836 for eigenvalue
#  The estimated number of batches is 1942
#       255/1    1.18409    1.18391 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8537864025062514 for eigenvalue
#  The estimated number of batches is 1934
#       256/1    1.17292    1.18386 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.840781356960943 for eigenvalue
#  The estimated number of batches is 1925
#       257/1    1.18122    1.18385 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8286126129582474 for eigenvalue
#  The estimated number of batches is 1917
#       258/1    1.18361    1.18385 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8186143258176024 for eigenvalue
#  The estimated number of batches is 1911
#       259/1    1.18835    1.18387 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.8070043092233226 for eigenvalue
#  The estimated number of batches is 1904
#       260/1    1.18207    1.18386 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7959811298103228 for eigenvalue
#  The estimated number of batches is 1897
#       261/1    1.17382    1.18382 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7900908740096306 for eigenvalue
#  The estimated number of batches is 1897
#       262/1    1.17560    1.18378 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7784381857506006 for eigenvalue
#  The estimated number of batches is 1889
#       263/1    1.19038    1.18381 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7671936428001227 for eigenvalue
#  The estimated number of batches is 1881
#       264/1    1.18201    1.18380 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.75730799817786 for eigenvalue
#  The estimated number of batches is 1876
#       265/1    1.17636    1.18377 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.7514161075957335 for eigenvalue
#  The estimated number of batches is 1875
#       266/1    1.18475    1.18378 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.740332968621032 for eigenvalue
#  The estimated number of batches is 1868
#       267/1    1.18390    1.18378 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.735074338910975 for eigenvalue
#  The estimated number of batches is 1868
#       268/1    1.19063    1.18381 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.724504666605083 for eigenvalue
#  The estimated number of batches is 1861
#       269/1    1.19025    1.18383 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.715565511421011 for eigenvalue
#  The estimated number of batches is 1857
#       270/1    1.18900    1.18385 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.7067272771471167 for eigenvalue
#  The estimated number of batches is 1852
#       271/1    1.17297    1.18381 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.703289917359016 for eigenvalue
#  The estimated number of batches is 1855
#       272/1    1.17752    1.18378 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.692231664762396 for eigenvalue
#  The estimated number of batches is 1847
#       273/1    1.18297    1.18378 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.681518727788767 for eigenvalue
#  The estimated number of batches is 1840
#       274/1    1.18705    1.18379 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6725407728564625 for eigenvalue
#  The estimated number of batches is 1835
#       275/1    1.18221    1.18379 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.662142548158374 for eigenvalue
#  The estimated number of batches is 1828
#       276/1    1.19043    1.18381 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6526580510302757 for eigenvalue
#  The estimated number of batches is 1822
#       277/1    1.18299    1.18381 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6638827894233184 for eigenvalue
#  The estimated number of batches is 1844
#       278/1    1.18387    1.18381 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.653960609613681 for eigenvalue
#  The estimated number of batches is 1838
#       279/1    1.19194    1.18384 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6565744123732062 for eigenvalue
#  The estimated number of batches is 1848
#       280/1    1.17833    1.18382 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.661474212428849 for eigenvalue
#  The estimated number of batches is 1862
#       281/1    1.18436    1.18382 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6629734893824595 for eigenvalue
#  The estimated number of batches is 1871
#       282/1    1.18271    1.18382 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.653250778298691 for eigenvalue
#  The estimated number of batches is 1865
#       283/1    1.17373    1.18378 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6456050097075976 for eigenvalue
#  The estimated number of batches is 1861
#       284/1    1.17457    1.18375 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.64316451741868 for eigenvalue
#  The estimated number of batches is 1865
#       285/1    1.18873    1.18376 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.636849561501066 for eigenvalue
#  The estimated number of batches is 1863
#       286/1    1.18675    1.18378 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.6272617445461006 for eigenvalue
#  The estimated number of batches is 1857
#       287/1    1.18493    1.18378 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6291097567763617 for eigenvalue
#  The estimated number of batches is 1866
#       288/1    1.18258    1.18378 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.619620520069181 for eigenvalue
#  The estimated number of batches is 1860
#       289/1    1.18734    1.18379 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6101998589572037 for eigenvalue
#  The estimated number of batches is 1853
#       290/1    1.17819    1.18377 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.6003320409466184 for eigenvalue
#  The estimated number of batches is 1846
#       291/1    1.17726    1.18374 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.592949661236672 for eigenvalue
#  The estimated number of batches is 1843
#       292/1    1.18363    1.18374 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.583397803656946 for eigenvalue
#  The estimated number of batches is 1836
#       293/1    1.17798    1.18372 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.579561890547814 for eigenvalue
#  The estimated number of batches is 1837
#       294/1    1.18752    1.18374 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.579873256986139 for eigenvalue
#  The estimated number of batches is 1844
#       295/1    1.18410    1.18374 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.578654481397557 for eigenvalue
#  The estimated number of batches is 1849
#       296/1    1.18679    1.18375 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.569306622118591 for eigenvalue
#  The estimated number of batches is 1842
#       297/1    1.19399    1.18379 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.5634850414149604 for eigenvalue
# ...
#      1587/1    1.17793    1.18370 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.028926119332696 for eigenvalue
#  The estimated number of batches is 1679
#      1588/1    1.16898    1.18369 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0283701717137639 for eigenvalue
#  The estimated number of batches is 1679
#      1589/1    1.18124    1.18369 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0277570736585782 for eigenvalue
#  The estimated number of batches is 1678
#      1590/1    1.19976    1.18370 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.028234739536706 for eigenvalue
#  The estimated number of batches is 1680
#      1591/1    1.18611    1.18370 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0276106291113731 for eigenvalue
#  The estimated number of batches is 1679
#      1592/1    1.18372    1.18370 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0271160770712182 for eigenvalue
#  The estimated number of batches is 1679
#      1593/1    1.19113    1.18371 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0279419864162591 for eigenvalue
#  The estimated number of batches is 1683
#      1594/1    1.18986    1.18371 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.027380668717242 for eigenvalue
#  The estimated number of batches is 1682
#      1595/1    1.18353    1.18371 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0268558079763994 for eigenvalue
#  The estimated number of batches is 1681
#      1596/1    1.18701    1.18372 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0268941550449457 for eigenvalue
#  The estimated number of batches is 1682
#      1597/1    1.18555    1.18372 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0262774984964838 for eigenvalue
#  The estimated number of batches is 1681
#      1598/1    1.19010    1.18372 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0256529107715802 for eigenvalue
#  The estimated number of batches is 1680
#      1599/1    1.17589    1.18372 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.02533239222103 for eigenvalue
#  The estimated number of batches is 1681
#      1600/1    1.18539    1.18372 +/- 0.00017
#  Triggers unsatisfied, max unc./thresh. is 1.0247970872066519 for eigenvalue
#  The estimated number of batches is 1680
#      1601/1    1.18675    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0249948511283073 for eigenvalue
#  The estimated number of batches is 1682
#      1602/1    1.18946    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.024527030939199 for eigenvalue
#  The estimated number of batches is 1681
#      1603/1    1.18695    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023891163333863 for eigenvalue
#  The estimated number of batches is 1680
#      1604/1    1.17855    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0233165531365538 for eigenvalue
#  The estimated number of batches is 1679
#      1605/1    1.18933    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0229532243488977 for eigenvalue
#  The estimated number of batches is 1679
#      1606/1    1.18559    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0226282421558544 for eigenvalue
#  The estimated number of batches is 1679
#      1607/1    1.17777    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0223828141261302 for eigenvalue
#  The estimated number of batches is 1679
#      1608/1    1.18393    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0219314839610607 for eigenvalue
#  The estimated number of batches is 1679
#      1609/1    1.18285    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0220515014724416 for eigenvalue
#  The estimated number of batches is 1680
#      1610/1    1.17331    1.18371 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214502276523916 for eigenvalue
#  The estimated number of batches is 1679
#      1611/1    1.18441    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0208400878869834 for eigenvalue
#  The estimated number of batches is 1679
#      1612/1    1.18855    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0205448448577417 for eigenvalue
#  The estimated number of batches is 1679
#      1613/1    1.19494    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0199348635752001 for eigenvalue
#  The estimated number of batches is 1678
#      1614/1    1.17938    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.019610797912502 for eigenvalue
#  The estimated number of batches is 1678
#      1615/1    1.18743    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0194128714339614 for eigenvalue
#  The estimated number of batches is 1678
#      1616/1    1.18631    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0204036656610196 for eigenvalue
#  The estimated number of batches is 1682
#      1617/1    1.18995    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0200169193002706 for eigenvalue
#  The estimated number of batches is 1682
#      1618/1    1.18131    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0194324412732902 for eigenvalue
#  The estimated number of batches is 1681
#      1619/1    1.18929    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0188516071978226 for eigenvalue
#  The estimated number of batches is 1680
#      1620/1    1.17926    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0183471052616622 for eigenvalue
#  The estimated number of batches is 1680
#      1621/1    1.18079    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0177472608023368 for eigenvalue
#  The estimated number of batches is 1679
#      1622/1    1.18714    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0175594608118919 for eigenvalue
#  The estimated number of batches is 1679
#      1623/1    1.19156    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0175049966999996 for eigenvalue
#  The estimated number of batches is 1680
#      1624/1    1.18775    1.18374 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0170315205100278 for eigenvalue
#  The estimated number of batches is 1680
#      1625/1    1.17688    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0174819085820412 for eigenvalue
#  The estimated number of batches is 1682
#      1626/1    1.17681    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.016829135744362 for eigenvalue
#  The estimated number of batches is 1681
#      1627/1    1.19072    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.016412437826094 for eigenvalue
#  The estimated number of batches is 1681
#      1628/1    1.17330    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0161890704046281 for eigenvalue
#  The estimated number of batches is 1681
#      1629/1    1.17553    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0155550849668402 for eigenvalue
#  The estimated number of batches is 1680
#      1630/1    1.19238    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0150785805114284 for eigenvalue
#  The estimated number of batches is 1679
#      1631/1    1.18586    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.014540399810827 for eigenvalue
#  The estimated number of batches is 1679
#      1632/1    1.18544    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0140927983126746 for eigenvalue
#  The estimated number of batches is 1678
#      1633/1    1.18050    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0134622234602662 for eigenvalue
#  The estimated number of batches is 1677
#      1634/1    1.17567    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0134480660171177 for eigenvalue
#  The estimated number of batches is 1678
#      1635/1    1.18391    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.013134038175128 for eigenvalue
#  The estimated number of batches is 1678
#      1636/1    1.18048    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0127214665865867 for eigenvalue
#  The estimated number of batches is 1678
#      1637/1    1.18093    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0120851408975247 for eigenvalue
#  The estimated number of batches is 1677
#      1638/1    1.17981    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011712511558952 for eigenvalue
#  The estimated number of batches is 1677
#      1639/1    1.18982    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0138406714668589 for eigenvalue
#  The estimated number of batches is 1685
#      1640/1    1.18546    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0135461576430354 for eigenvalue
#  The estimated number of batches is 1685
#      1641/1    1.17914    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0130793513064718 for eigenvalue
#  The estimated number of batches is 1684
#      1642/1    1.17715    1.18371 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0130103589426855 for eigenvalue
#  The estimated number of batches is 1685
#      1643/1    1.18130    1.18371 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.012410422806251 for eigenvalue
#  The estimated number of batches is 1684
#      1644/1    1.18850    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0118176382278465 for eigenvalue
#  The estimated number of batches is 1683
#      1645/1    1.19184    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0112220409543708 for eigenvalue
#  The estimated number of batches is 1682
#      1646/1    1.18312    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01063519741283 for eigenvalue
#  The estimated number of batches is 1681
#      1647/1    1.18815    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0101298245482264 for eigenvalue
#  The estimated number of batches is 1681
#      1648/1    1.18324    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096272685202057 for eigenvalue
#  The estimated number of batches is 1680
#      1649/1    1.17827    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0092787804434622 for eigenvalue
#  The estimated number of batches is 1680
#      1650/1    1.17963    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099127216629928 for eigenvalue
#  The estimated number of batches is 1683
#      1651/1    1.17968    1.18371 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0099784020593239 for eigenvalue
#  The estimated number of batches is 1684
#      1652/1    1.17657    1.18371 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0093674870622658 for eigenvalue
#  The estimated number of batches is 1683
#      1653/1    1.18421    1.18371 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0087780748409758 for eigenvalue
#  The estimated number of batches is 1682
#      1654/1    1.19997    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.008340767792536 for eigenvalue
#  The estimated number of batches is 1682
#      1655/1    1.19336    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0077391158705968 for eigenvalue
#  The estimated number of batches is 1681
#      1656/1    1.19115    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.007457785566016 for eigenvalue
#  The estimated number of batches is 1681
#      1657/1    1.18051    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0068532026922292 for eigenvalue
#  The estimated number of batches is 1680
#      1658/1    1.18311    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0062354324001916 for eigenvalue
#  The estimated number of batches is 1679
#      1659/1    1.18476    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0056459979231331 for eigenvalue
#  The estimated number of batches is 1678
#      1660/1    1.18715    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0056603535639523 for eigenvalue
#  The estimated number of batches is 1679
#      1661/1    1.18056    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0052865994217943 for eigenvalue
#  The estimated number of batches is 1679
#      1662/1    1.18039    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0046757747217416 for eigenvalue
#  The estimated number of batches is 1678
#      1663/1    1.17642    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.004431559949559 for eigenvalue
#  The estimated number of batches is 1678
#      1664/1    1.18171    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0039541081752592 for eigenvalue
#  The estimated number of batches is 1678
#      1665/1    1.18369    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0033462949778855 for eigenvalue
#  The estimated number of batches is 1677
#      1666/1    1.17752    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0027815061345955 for eigenvalue
#  The estimated number of batches is 1676
#      1667/1    1.17835    1.18371 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0025933637757882 for eigenvalue
#  The estimated number of batches is 1676
#      1668/1    1.19165    1.18372 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0032125365996938 for eigenvalue
#  The estimated number of batches is 1679
#      1669/1    1.19405    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.002633739866864 for eigenvalue
#  The estimated number of batches is 1678
#      1670/1    1.18526    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0020713769469158 for eigenvalue
#  The estimated number of batches is 1677
#      1671/1    1.18188    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.001919140388103 for eigenvalue
#  The estimated number of batches is 1678
#      1672/1    1.18979    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.001328385007211 for eigenvalue
#  The estimated number of batches is 1677
#      1673/1    1.18334    1.18373 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0007836733186737 for eigenvalue
#  The estimated number of batches is 1676
#      1674/1    1.19416    1.18374 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0002111194376404 for eigenvalue
#  The estimated number of batches is 1675
#      1675/1    1.18532    1.18374 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0001191266147933 for eigenvalue
#  The estimated number of batches is 1676
#      1676/1    1.18958    1.18374 +/- 0.00016
#  Triggers satisfied for batch 1676
#  Creating state point statepoint.01676.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.9071e+01 seconds
#    Reading cross sections          = 4.8221e+01 seconds
#  Total time in simulation          = 4.5203e+04 seconds
#    Time in transport only          = 4.4894e+04 seconds
#    Time in inactive batches        = 3.4380e+02 seconds
#    Time in active batches          = 4.4859e+04 seconds
#    Time synchronizing fission bank = 2.0454e+01 seconds
#      Sampling source sites         = 1.5159e+01 seconds
#      SEND/RECV source sites        = 5.2930e+00 seconds
#    Time accumulating tallies       = 2.7144e+02 seconds
#    Time writing statepoints        = 7.7021e+00 seconds
#  Total time for finalization       = 5.6905e+01 seconds
#  Total time elapsed                = 4.5311e+04 seconds
#  Calculation Rate (inactive)       = 2908.67 particles/second
#  Calculation Rate (active)         = 1845.79 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18368 +/- 0.00014
#  k-effective (Track-length)  = 1.18374 +/- 0.00016
#  k-effective (Absorption)    = 1.18362 +/- 0.00011
#  Combined k-effective        = 1.18365 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
