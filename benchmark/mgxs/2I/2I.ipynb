# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %% [markdown]
# def instru(index_x,index_y):
#     clad_inner_radius = openmc.ZCylinder(r=0.559)
#     clad_outer_radius = openmc.ZCylinder(r=0.605)
#     pitch = 1.26
#     left = openmc.XPlane(-pitch/2, boundary_type='transmission')
#     right = openmc.XPlane(pitch/2, boundary_type='transmission')
#     bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
#     top = openmc.YPlane(pitch/2, boundary_type='transmission')
#     clad_region = +clad_inner_radius & -clad_outer_radius
#     water_region = +left & -right & +bottom & -top & +clad_outer_radius
#     water_guide_region= -clad_inner_radius
#     water_guide = openmc.Cell(name='water_guide'+'_'+str(index_x)+'_'+str(index_y))
#     water_guide.fill = water
#     water_guide.region = water_guide_region
#     clad = openmc.Cell(name='clad_guide'+'_'+str(index_x)+'_'+str(index_y))
#     clad.fill = zirconium
#     clad.region = clad_region
#     moderator = openmc.Cell(name='moderator'+'_'+str(index_x)+'_'+str(index_y))
#     moderator.fill = water
#     moderator.region = water_region
#     u = openmc.Universe(name='u_guide'+'_'+str(index_x)+'_'+str(index_y),cells=(water_guide, clad, moderator))
#     return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create Instrument Thimble

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    instru_inner_radius = openmc.ZCylinder(0.258)
    instry_outer_radius= openmc.ZCylinder(0.382)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission') 

    
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius | -instru_inner_radius | +instry_outer_radius & -clad_inner_radius
    instru_region = +instru_inner_radius & -instry_outer_radius

    water_cell = openmc.Cell(name='water_cell'+family)
    water_cell.fill = water
    water_cell.region = water_region
    clad_cell = openmc.Cell(name='clad_cell'+family)
    clad_cell.fill = zirconium
    clad_cell.region = clad_region
    instru_cell = openmc.Cell(name='instru_cell'+family)
    instru_cell.fill = SS304
    instru_cell.region = instru_region
    
    u = openmc.Universe(name='u_guide'+family,cells=(water_cell, clad_cell, instru_cell))
    return(u,water_cell,clad_cell,instru_cell)

# %% [markdown]
# ### Mappping

# %%
GT=[(8,2),(3,3),(5,5),(2,8),(5,2),(2,5),(8,5),(5,8)]
IT=[(8,8)]


GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)
   

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT:
            A[ix][iy]=instru_1_family[0]           
        else:
            A[ix][iy]=pincell_1_family[0]
            
          
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')



root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %% [markdown]
# mgxs_lib = openmc.mgxs.Library(model.geometry)
# groups = openmc.mgxs.EnergyGroups(choose_group)
# mgxs_lib.energy_groups = groups
# mgxs_lib.scatter_format = "legendre"
# mgxs_lib.legendre_order = 3
# mgxs_lib.mgxs_types = ['total', 'absorption', 'fission', 'nu-fission', 'chi', 'scatter matrix', 'nu-scatter matrix', 'inverse-velocity']
# mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
# mgxs_lib.by_nuclide = False
# mgxs_lib.domain_type = 'cell'
# mgxs_lib.domains = model.geometry.get_all_material_cells().values()
# mgxs_lib.build_library()
# tallies = openmc.Tallies()
# mgxs_lib.add_to_tallies_file(tallies, merge=True)
# model.tallies = tallies
#
# #model.export_to_xml()
# model.export_to_model_xml('model_2A_1_family.xml')

# %% [markdown]
# ### Create power tally

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1474.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1076.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1084.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-09 14:46:07
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.18836
#         2/1    1.18519
#         3/1    1.18092
#         4/1    1.17476
#         5/1    1.18234
#         6/1    1.17652
#         7/1    1.18125
#         8/1    1.18323
#         9/1    1.17643
#        10/1    1.17805
#        11/1    1.17264
#        12/1    1.18587
#        13/1    1.17773
#        14/1    1.17787
#        15/1    1.18693
#        16/1    1.18307
#        17/1    1.18189
#        18/1    1.18463
#        19/1    1.18337
#        20/1    1.18182
#        21/1    1.17841
#        22/1    1.17968    1.17905 +/- 0.00064
#        23/1    1.17869    1.17893 +/- 0.00039
#        24/1    1.18049    1.17932 +/- 0.00048
#        25/1    1.19052    1.18156 +/- 0.00227
#        26/1    1.18964    1.18291 +/- 0.00229
#        27/1    1.18506    1.18321 +/- 0.00196
#        28/1    1.17266    1.18189 +/- 0.00215
#        29/1    1.17743    1.18140 +/- 0.00196
#        30/1    1.18668    1.18193 +/- 0.00183
#        31/1    1.18273    1.18200 +/- 0.00166
#        32/1    1.18521    1.18227 +/- 0.00154
#        33/1    1.17322    1.18157 +/- 0.00158
#        34/1    1.17807    1.18132 +/- 0.00148
#        35/1    1.18767    1.18174 +/- 0.00144
#        36/1    1.18193    1.18176 +/- 0.00135
#        37/1    1.18147    1.18174 +/- 0.00127
#        38/1    1.17948    1.18161 +/- 0.00120
#        39/1    1.18536    1.18181 +/- 0.00115
#        40/1    1.18594    1.18202 +/- 0.00111
#        41/1    1.15825    1.18089 +/- 0.00155
#        42/1    1.18569    1.18110 +/- 0.00149
#        43/1    1.17968    1.18104 +/- 0.00143
#        44/1    1.18455    1.18119 +/- 0.00138
#        45/1    1.17999    1.18114 +/- 0.00132
#        46/1    1.18075    1.18113 +/- 0.00127
#        47/1    1.18426    1.18124 +/- 0.00123
#        48/1    1.17257    1.18093 +/- 0.00122
#        49/1    1.18083    1.18093 +/- 0.00118
#        50/1    1.16471    1.18039 +/- 0.00126
#  Triggers unsatisfied, max unc./thresh. is 6.090345075884498 for eigenvalue
#  The estimated number of batches is 1133
#  Creating state point statepoint.00050.h5...
#        51/1    1.17574    1.18024 +/- 0.00123
#  Triggers unsatisfied, max unc./thresh. is 5.933368505035755 for eigenvalue
#  The estimated number of batches is 1112
#        52/1    1.18135    1.18027 +/- 0.00119
#  Triggers unsatisfied, max unc./thresh. is 5.838327467441867 for eigenvalue
#  The estimated number of batches is 1111
#        53/1    1.17516    1.18012 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 5.717704503752999 for eigenvalue
#  The estimated number of batches is 1099
#        54/1    1.18188    1.18017 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 5.503975934562671 for eigenvalue
#  The estimated number of batches is 1050
#        55/1    1.18034    1.18017 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 5.616209184360792 for eigenvalue
#  The estimated number of batches is 1124
#        56/1    1.18408    1.18028 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 5.380772588716598 for eigenvalue
#  The estimated number of batches is 1063
#        57/1    1.18946    1.18053 +/- 0.00107
#  Triggers unsatisfied, max unc./thresh. is 5.284067859214263 for eigenvalue
#  The estimated number of batches is 1054
#        58/1    1.18537    1.18066 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 5.135217382930463 for eigenvalue
#  The estimated number of batches is 1023
#        59/1    1.17733    1.18057 +/- 0.00103
#  Triggers unsatisfied, max unc./thresh. is 5.026742591323257 for eigenvalue
#  The estimated number of batches is 1006
#        60/1    1.17425    1.18041 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 4.9858357479545345 for eigenvalue
#  The estimated number of batches is 1015
#        61/1    1.17512    1.18029 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 4.95812473690638 for eigenvalue
#  The estimated number of batches is 1028
#        62/1    1.18313    1.18035 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 4.83003352580934 for eigenvalue
#  The estimated number of batches is 1000
#        63/1    1.18501    1.18046 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 4.9065374349769835 for eigenvalue
#  The estimated number of batches is 1056
#        64/1    1.17911    1.18043 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 4.82883236638906 for eigenvalue
#  The estimated number of batches is 1046
#        65/1    1.18588    1.18055 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 4.884801238997328 for eigenvalue
#  The estimated number of batches is 1094
#        66/1    1.17983    1.18054 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.840171183265935 for eigenvalue
#  The estimated number of batches is 1098
#        67/1    1.17849    1.18049 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 4.743476344083847 for eigenvalue
#  The estimated number of batches is 1078
#        68/1    1.17405    1.18036 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.681193203789475 for eigenvalue
#  The estimated number of batches is 1072
#        69/1    1.18602    1.18047 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.794007011348264 for eigenvalue
#  The estimated number of batches is 1147
#        70/1    1.18294    1.18052 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.7067969807220384 for eigenvalue
#  The estimated number of batches is 1128
#        71/1    1.19515    1.18081 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.865957625943907 for eigenvalue
#  The estimated number of batches is 1228
#        72/1    1.18510    1.18089 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.8543433456125085 for eigenvalue
#  The estimated number of batches is 1246
#        73/1    1.16615    1.18061 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 4.755652199000696 for eigenvalue
#  The estimated number of batches is 1219
#        74/1    1.17286    1.18047 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 4.680048449537859 for eigenvalue
#  The estimated number of batches is 1203
#        75/1    1.18150    1.18049 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.598576462978795 for eigenvalue
#  The estimated number of batches is 1184
#        76/1    1.18069    1.18049 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 4.524065531014739 for eigenvalue
#  The estimated number of batches is 1167
#        77/1    1.18522    1.18058 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.4972207878417185 for eigenvalue
#  The estimated number of batches is 1173
#        78/1    1.18206    1.18060 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.427557076410458 for eigenvalue
#  The estimated number of batches is 1157
#        79/1    1.17991    1.18059 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 4.358439079553463 for eigenvalue
#  The estimated number of batches is 1141
#        80/1    1.17436    1.18049 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.291626799699997 for eigenvalue
#  The estimated number of batches is 1126
#        81/1    1.17431    1.18038 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.321033276945578 for eigenvalue
#  The estimated number of batches is 1159
#        82/1    1.18558    1.18047 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.243634209931814 for eigenvalue
#  The estimated number of batches is 1137
#        83/1    1.17823    1.18043 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.22804296497692 for eigenvalue
#  The estimated number of batches is 1147
#        84/1    1.18137    1.18045 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.253526619263842 for eigenvalue
#  The estimated number of batches is 1178
#        85/1    1.17303    1.18033 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.337319300675691 for eigenvalue
#  The estimated number of batches is 1243
#        86/1    1.17974    1.18032 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.366758903036195 for eigenvalue
#  The estimated number of batches is 1279
#        87/1    1.17733    1.18028 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.319386372942588 for eigenvalue
#  The estimated number of batches is 1271
#        88/1    1.18555    1.18036 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.289645086975187 for eigenvalue
#  The estimated number of batches is 1272
#        89/1    1.17944    1.18034 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.26682100975194 for eigenvalue
#  The estimated number of batches is 1277
#        90/1    1.17653    1.18029 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.380654289629401 for eigenvalue
#  The estimated number of batches is 1364
#        91/1    1.17599    1.18023 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.328101885700223 for eigenvalue
#  The estimated number of batches is 1351
#        92/1    1.17353    1.18014 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.300828384031844 for eigenvalue
#  The estimated number of batches is 1352
#        93/1    1.18531    1.18021 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.244815794783622 for eigenvalue
#  The estimated number of batches is 1336
#        94/1    1.19084    1.18035 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.300674009260804 for eigenvalue
#  The estimated number of batches is 1389
#        95/1    1.18057    1.18035 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.289362848907651 for eigenvalue
#  The estimated number of batches is 1400
#        96/1    1.17789    1.18032 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.232461300552613 for eigenvalue
#  The estimated number of batches is 1382
#        97/1    1.17698    1.18028 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.179506213731807 for eigenvalue
#  The estimated number of batches is 1366
#        98/1    1.18628    1.18035 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.124254660696869 for eigenvalue
#  The estimated number of batches is 1347
#        99/1    1.18127    1.18037 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.073017000545878 for eigenvalue
#  The estimated number of batches is 1331
#       100/1    1.17928    1.18035 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.0213313365806 for eigenvalue
#  The estimated number of batches is 1314
#       101/1    1.18183    1.18037 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.9754370500762435 for eigenvalue
#  The estimated number of batches is 1301
#       102/1    1.17911    1.18036 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.9331665873094153 for eigenvalue
#  The estimated number of batches is 1289
#       103/1    1.17740    1.18032 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.89801216073247 for eigenvalue
#  The estimated number of batches is 1282
#       104/1    1.17597    1.18027 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.9113871039012795 for eigenvalue
#  The estimated number of batches is 1306
#       105/1    1.17900    1.18025 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.9024800657009133 for eigenvalue
#  The estimated number of batches is 1315
#       106/1    1.17591    1.18020 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.859769577656639 for eigenvalue
#  The estimated number of batches is 1302
#       107/1    1.18913    1.18031 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.825961315588021 for eigenvalue
#  The estimated number of batches is 1294
#       108/1    1.19743    1.18050 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.056535197162595 for eigenvalue
#  The estimated number of batches is 1469
#       109/1    1.19062    1.18061 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.0059427325183945 for eigenvalue
#  The estimated number of batches is 1449
#       110/1    1.16934    1.18049 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.13164442815631 for eigenvalue
#  The estimated number of batches is 1557
#       111/1    1.17553    1.18043 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.115357849387806 for eigenvalue
#  The estimated number of batches is 1562
#       112/1    1.18999    1.18054 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.067089984456084 for eigenvalue
#  The estimated number of batches is 1542
#       113/1    1.18060    1.18054 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.032409516638906 for eigenvalue
#  The estimated number of batches is 1533
#       114/1    1.18666    1.18060 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.024688625593503 for eigenvalue
#  The estimated number of batches is 1543
#       115/1    1.17510    1.18055 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.076375027168207 for eigenvalue
#  The estimated number of batches is 1599
#       116/1    1.17632    1.18050 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.04171806683501 for eigenvalue
#  The estimated number of batches is 1589
#       117/1    1.17699    1.18047 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.003771582038636 for eigenvalue
#  The estimated number of batches is 1575
#       118/1    1.17379    1.18040 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.006149015452343 for eigenvalue
#  The estimated number of batches is 1593
#       119/1    1.18063    1.18040 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.9664861704678187 for eigenvalue
#  The estimated number of batches is 1578
#       120/1    1.17905    1.18039 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.927135367812541 for eigenvalue
#  The estimated number of batches is 1563
#       121/1    1.17711    1.18035 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.910933307860486 for eigenvalue
#  The estimated number of batches is 1565
#       122/1    1.17308    1.18028 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.909143700153722 for eigenvalue
#  The estimated number of batches is 1579
#       123/1    1.18801    1.18036 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.8700937127615576 for eigenvalue
#  The estimated number of batches is 1563
#       124/1    1.18203    1.18037 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.850938967783029 for eigenvalue
#  The estimated number of batches is 1563
#       125/1    1.17855    1.18036 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.816485677535575 for eigenvalue
#  The estimated number of batches is 1550
#       126/1    1.18529    1.18040 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.801034186166376 for eigenvalue
#  The estimated number of batches is 1552
#       127/1    1.18284    1.18043 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7836242025569446 for eigenvalue
#  The estimated number of batches is 1552
#       128/1    1.17699    1.18039 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7522258538795117 for eigenvalue
#  The estimated number of batches is 1541
#       129/1    1.17940    1.18038 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.717841607418714 for eigenvalue
#  The estimated number of batches is 1527
#       130/1    1.19258    1.18050 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.7994794729045824 for eigenvalue
#  The estimated number of batches is 1608
#       131/1    1.18049    1.18050 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.764285271417913 for eigenvalue
#  The estimated number of batches is 1593
#       132/1    1.17201    1.18042 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.739755926021926 for eigenvalue
#  The estimated number of batches is 1587
#       133/1    1.17116    1.18034 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.730408494922698 for eigenvalue
#  The estimated number of batches is 1593
#       134/1    1.18817    1.18041 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.7005136116411554 for eigenvalue
#  The estimated number of batches is 1582
#       135/1    1.17851    1.18039 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.6690736551734457 for eigenvalue
#  The estimated number of batches is 1569
#       136/1    1.18311    1.18041 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.636924803876758 for eigenvalue
#  The estimated number of batches is 1555
#       137/1    1.16598    1.18029 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.6203202071600744 for eigenvalue
#  The estimated number of batches is 1554
#       138/1    1.18064    1.18029 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.589321656012649 for eigenvalue
#  The estimated number of batches is 1541
#       139/1    1.15799    1.18011 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.6121232865136217 for eigenvalue
#  The estimated number of batches is 1573
#       140/1    1.18597    1.18015 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.619284887635335 for eigenvalue
#  The estimated number of batches is 1592
#       141/1    1.18129    1.18016 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.6045996711282284 for eigenvalue
#  The estimated number of batches is 1593
#       142/1    1.18518    1.18021 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.5731596001953956 for eigenvalue
#  The estimated number of batches is 1578
#       143/1    1.18238    1.18022 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.545014217271621 for eigenvalue
#  The estimated number of batches is 1566
#       144/1    1.18641    1.18027 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.515084231255668 for eigenvalue
#  The estimated number of batches is 1553
#       145/1    1.17523    1.18023 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.493214479700926 for eigenvalue
#  The estimated number of batches is 1546
#       146/1    1.18343    1.18026 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.4733513635235815 for eigenvalue
#  The estimated number of batches is 1541
#       147/1    1.17286    1.18020 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5143787805748294 for eigenvalue
#  The estimated number of batches is 1589
#       148/1    1.17621    1.18017 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4917856650542833 for eigenvalue
#  The estimated number of batches is 1581
#       149/1    1.19090    1.18025 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4746289654982094 for eigenvalue
#  The estimated number of batches is 1578
#       150/1    1.18647    1.18030 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.44870944035268 for eigenvalue
#  The estimated number of batches is 1567
#       151/1    1.18413    1.18033 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4249172238691226 for eigenvalue
#  The estimated number of batches is 1557
#       152/1    1.17441    1.18028 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.4153033900151524 for eigenvalue
#  The estimated number of batches is 1560
#       153/1    1.18652    1.18033 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3947473048848362 for eigenvalue
#  The estimated number of batches is 1553
#       154/1    1.18055    1.18033 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.3732022113191324 for eigenvalue
#  The estimated number of batches is 1545
#       155/1    1.17750    1.18031 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.351576991775737 for eigenvalue
#  The estimated number of batches is 1537
#       156/1    1.18148    1.18032 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3313122897977916 for eigenvalue
#  The estimated number of batches is 1530
#       157/1    1.17116    1.18025 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3112621334833197 for eigenvalue
#  The estimated number of batches is 1523
#       158/1    1.18675    1.18030 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.3116125900730946 for eigenvalue
#  The estimated number of batches is 1534
#       159/1    1.17681    1.18027 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.2906879296644576 for eigenvalue
#  The estimated number of batches is 1526
#       160/1    1.18178    1.18029 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2668796520352785 for eigenvalue
#  The estimated number of batches is 1515
#       161/1    1.18348    1.18031 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2452242197296375 for eigenvalue
#  The estimated number of batches is 1505
#       162/1    1.17244    1.18025 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.2270182614139253 for eigenvalue
#  The estimated number of batches is 1499
#       163/1    1.17860    1.18024 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.2089530097680976 for eigenvalue
#  The estimated number of batches is 1493
#       164/1    1.17972    1.18024 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.1891935370584337 for eigenvalue
#  The estimated number of batches is 1485
#       165/1    1.19536    1.18034 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.207538197643476 for eigenvalue
#  The estimated number of batches is 1512
#       166/1    1.18036    1.18034 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.1920623073886665 for eigenvalue
#  The estimated number of batches is 1508
#       167/1    1.18756    1.18039 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.17671864883354 for eigenvalue
#  The estimated number of batches is 1504
#       168/1    1.17922    1.18038 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.1759251929699985 for eigenvalue
#  The estimated number of batches is 1513
#       169/1    1.17931    1.18038 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.169406634578798 for eigenvalue
#  The estimated number of batches is 1517
#       170/1    1.18723    1.18042 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.149674136306228 for eigenvalue
#  The estimated number of batches is 1509
#       171/1    1.17143    1.18036 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.14351568367655 for eigenvalue
#  The estimated number of batches is 1513
#       172/1    1.17354    1.18032 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1241052467696333 for eigenvalue
#  The estimated number of batches is 1504
#       173/1    1.18205    1.18033 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1129134358204373 for eigenvalue
#  The estimated number of batches is 1503
#       174/1    1.18341    1.18035 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.1147218602669255 for eigenvalue
#  The estimated number of batches is 1515
#       175/1    1.17465    1.18031 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.0985995709719547 for eigenvalue
#  The estimated number of batches is 1509
#       176/1    1.18412    1.18034 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.08788581943908 for eigenvalue
#  The estimated number of batches is 1508
#       177/1    1.17041    1.18027 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.0705969669952644 for eigenvalue
#  The estimated number of batches is 1501
#       178/1    1.18896    1.18033 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.0582477864110458 for eigenvalue
#  The estimated number of batches is 1498
#       179/1    1.17462    1.18029 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.0427024133106904 for eigenvalue
#  The estimated number of batches is 1493
#       180/1    1.18252    1.18031 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.0449894254976995 for eigenvalue
#  The estimated number of batches is 1504
#       181/1    1.18552    1.18034 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.024433871147482 for eigenvalue
#  The estimated number of batches is 1493
#       182/1    1.18463    1.18036 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.007447476377717 for eigenvalue
#  The estimated number of batches is 1486
#       183/1    1.17569    1.18034 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.0060461027682175 for eigenvalue
#  The estimated number of batches is 1493
#       184/1    1.18989    1.18039 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.9901670983340827 for eigenvalue
#  The estimated number of batches is 1487
#       185/1    1.17133    1.18034 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.9730657057290655 for eigenvalue
#  The estimated number of batches is 1479
#       186/1    1.17086    1.18028 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.9726913187537103 for eigenvalue
#  The estimated number of batches is 1487
#       187/1    1.19191    1.18035 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.957055988919515 for eigenvalue
#  The estimated number of batches is 1481
#       188/1    1.18246    1.18036 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.9397121049842587 for eigenvalue
#  The estimated number of batches is 1472
#       189/1    1.17477    1.18033 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.9277949680516118 for eigenvalue
#  The estimated number of batches is 1469
#       190/1    1.17741    1.18031 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 2.932114340730359 for eigenvalue
#  The estimated number of batches is 1482
#       191/1    1.17819    1.18030 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9760860736027093 for eigenvalue
#  The estimated number of batches is 1535
#       192/1    1.18561    1.18033 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.9597450712378333 for eigenvalue
#  The estimated number of batches is 1527
#       193/1    1.18279    1.18035 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.996803284315776 for eigenvalue
#  The estimated number of batches is 1574
#       194/1    1.18207    1.18036 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 2.986949961560408 for eigenvalue
#  The estimated number of batches is 1573
#       195/1    1.17787    1.18034 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9694655290340926 for eigenvalue
#  The estimated number of batches is 1564
#       196/1    1.18456    1.18037 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.950394840837474 for eigenvalue
#  The estimated number of batches is 1553
#       197/1    1.18711    1.18040 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.9333996890663108 for eigenvalue
#  The estimated number of batches is 1544
#       198/1    1.18931    1.18045 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.915377729144375 for eigenvalue
#  The estimated number of batches is 1533
#       199/1    1.17945    1.18045 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.909383713872228 for eigenvalue
#  The estimated number of batches is 1536
#       200/1    1.18558    1.18048 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.898744396463902 for eigenvalue
#  The estimated number of batches is 1533
#       201/1    1.18818    1.18052 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.8864129462402945 for eigenvalue
#  The estimated number of batches is 1528
#       202/1    1.17090    1.18047 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 2.871555580735278 for eigenvalue
#  The estimated number of batches is 1521
#       203/1    1.18167    1.18047 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.860041094341482 for eigenvalue
#  The estimated number of batches is 1517
#       204/1    1.18149    1.18048 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.845772331541184 for eigenvalue
#  The estimated number of batches is 1511
#       205/1    1.19009    1.18053 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8311074905974674 for eigenvalue
#  The estimated number of batches is 1503
#       206/1    1.17700    1.18051 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.829803444641923 for eigenvalue
#  The estimated number of batches is 1510
#       207/1    1.18412    1.18053 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8120692397500555 for eigenvalue
#  The estimated number of batches is 1499
#       208/1    1.18832    1.18057 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.8059182902643967 for eigenvalue
#  The estimated number of batches is 1501
#       209/1    1.18425    1.18059 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 2.790494854530397 for eigenvalue
#  The estimated number of batches is 1492
#       210/1    1.17770    1.18058 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.802436568076235 for eigenvalue
#  The estimated number of batches is 1513
#       211/1    1.17613    1.18055 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7873433333152944 for eigenvalue
#  The estimated number of batches is 1504
#       212/1    1.17751    1.18054 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.771967968392878 for eigenvalue
#  The estimated number of batches is 1496
#       213/1    1.18834    1.18058 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7826342118525025 for eigenvalue
#  The estimated number of batches is 1515
#       214/1    1.17067    1.18053 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7697501446172037 for eigenvalue
#  The estimated number of batches is 1509
#       215/1    1.18577    1.18055 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.755044344308585 for eigenvalue
#  The estimated number of batches is 1501
#       216/1    1.17520    1.18053 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7653911020407715 for eigenvalue
#  The estimated number of batches is 1519
#       217/1    1.17795    1.18051 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.752052254965886 for eigenvalue
#  The estimated number of batches is 1513
#       218/1    1.20033    1.18061 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.75432216515441 for eigenvalue
#  The estimated number of batches is 1523
#       219/1    1.17003    1.18056 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7414230535709967 for eigenvalue
#  The estimated number of batches is 1516
#       220/1    1.18193    1.18057 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7326747169558545 for eigenvalue
#  The estimated number of batches is 1514
#       221/1    1.19178    1.18062 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.726713082939969 for eigenvalue
#  The estimated number of batches is 1515
#       222/1    1.17328    1.18059 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.714003943212657 for eigenvalue
#  The estimated number of batches is 1508
#       223/1    1.18466    1.18061 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.706120290001116 for eigenvalue
#  The estimated number of batches is 1507
#       224/1    1.19007    1.18065 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.7002639765330745 for eigenvalue
#  The estimated number of batches is 1508
#       225/1    1.18697    1.18068 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.6855630852697026 for eigenvalue
#  The estimated number of batches is 1499
#       226/1    1.18759    1.18072 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.6864731066481595 for eigenvalue
#  The estimated number of batches is 1507
#       227/1    1.17818    1.18071 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.677203429590177 for eigenvalue
#  The estimated number of batches is 1504
#       228/1    1.18952    1.18075 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 2.6690178291495523 for eigenvalue
#  The estimated number of batches is 1502
#       229/1    1.17943    1.18074 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6561600025897363 for eigenvalue
#  The estimated number of batches is 1495
#       230/1    1.18603    1.18077 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6529644059890463 for eigenvalue
#  The estimated number of batches is 1499
#       231/1    1.18282    1.18078 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.649133852885186 for eigenvalue
#  The estimated number of batches is 1501
#       232/1    1.18260    1.18079 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6401599442497075 for eigenvalue
#  The estimated number of batches is 1498
#       233/1    1.17942    1.18078 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6314521445953774 for eigenvalue
#  The estimated number of batches is 1495
#       234/1    1.17347    1.18074 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6205352536171787 for eigenvalue
#  The estimated number of batches is 1490
#       235/1    1.17919    1.18074 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.607634139722195 for eigenvalue
#  The estimated number of batches is 1482
#       236/1    1.17408    1.18071 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6035286272836937 for eigenvalue
#  The estimated number of batches is 1485
#       237/1    1.19845    1.18079 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6145897636957396 for eigenvalue
#  The estimated number of batches is 1504
#       238/1    1.18085    1.18079 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.6094326535529504 for eigenvalue
#  The estimated number of batches is 1505
#       239/1    1.17799    1.18078 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.613657904167247 for eigenvalue
#  The estimated number of batches is 1517
#       240/1    1.18415    1.18079 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6016365480087993 for eigenvalue
#  The estimated number of batches is 1510
#       241/1    1.18820    1.18082 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6020226498811843 for eigenvalue
#  The estimated number of batches is 1517
#       242/1    1.18700    1.18085 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.607643818552967 for eigenvalue
#  The estimated number of batches is 1530
#       243/1    1.18582    1.18087 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.599413214199159 for eigenvalue
#  The estimated number of batches is 1527
#       244/1    1.18655    1.18090 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6081287481855626 for eigenvalue
#  The estimated number of batches is 1544
#       245/1    1.18266    1.18091 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.616460430047341 for eigenvalue
#  The estimated number of batches is 1561
#       246/1    1.18227    1.18091 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.6045778790557184 for eigenvalue
#  The estimated number of batches is 1554
#       247/1    1.17162    1.18087 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.603237726055763 for eigenvalue
#  The estimated number of batches is 1559
#       248/1    1.17208    1.18083 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.5936462776744613 for eigenvalue
#  The estimated number of batches is 1554
#       249/1    1.16893    1.18078 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.5821520372791507 for eigenvalue
#  The estimated number of batches is 1547
#       250/1    1.17609    1.18076 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.5743879788008472 for eigenvalue
#  The estimated number of batches is 1545
#       251/1    1.18196    1.18077 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5837151294985574 for eigenvalue
#  The estimated number of batches is 1563
#       252/1    1.17764    1.18075 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.59681647281541 for eigenvalue
#  The estimated number of batches is 1585
#       253/1    1.18595    1.18078 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.585495912977971 for eigenvalue
#  The estimated number of batches is 1578
#       254/1    1.19042    1.18082 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5786723007840457 for eigenvalue
#  The estimated number of batches is 1576
#       255/1    1.17495    1.18079 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5704215700427078 for eigenvalue
#  The estimated number of batches is 1573
#       256/1    1.18469    1.18081 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5628622219415833 for eigenvalue
#  The estimated number of batches is 1571
#       257/1    1.18135    1.18081 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.5538380180403366 for eigenvalue
#  The estimated number of batches is 1566
#       258/1    1.17950    1.18081 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.54889142336391 for eigenvalue
#  The estimated number of batches is 1567
#       259/1    1.19224    1.18085 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.544634108871941 for eigenvalue
#  The estimated number of batches is 1568
#       260/1    1.17359    1.18082 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.53969873633822 for eigenvalue
#  The estimated number of batches is 1569
#       261/1    1.17678    1.18081 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.529969063371484 for eigenvalue
#  The estimated number of batches is 1563
#       262/1    1.17632    1.18079 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.518915670773685 for eigenvalue
#  The estimated number of batches is 1556
#       263/1    1.17963    1.18078 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5088188566275953 for eigenvalue
#  The estimated number of batches is 1550
#       264/1    1.18354    1.18079 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4989800116647363 for eigenvalue
#  The estimated number of batches is 1544
#       265/1    1.16614    1.18073 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.500886819486656 for eigenvalue
#  The estimated number of batches is 1553
#       266/1    1.17375    1.18071 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5034651868691444 for eigenvalue
#  The estimated number of batches is 1562
#       267/1    1.18959    1.18074 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.5054873276111436 for eigenvalue
#  The estimated number of batches is 1571
#       268/1    1.17763    1.18073 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4956361261864672 for eigenvalue
#  The estimated number of batches is 1565
#       269/1    1.19303    1.18078 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4877084419473334 for eigenvalue
#  The estimated number of batches is 1561
#       270/1    1.18148    1.18078 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.478665109857937 for eigenvalue
#  The estimated number of batches is 1556
#       271/1    1.18564    1.18080 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.469633898312733 for eigenvalue
#  The estimated number of batches is 1551
#       272/1    1.18146    1.18080 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4600063935615544 for eigenvalue
#  The estimated number of batches is 1546
#       273/1    1.17663    1.18079 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.4574475935865747 for eigenvalue
#  The estimated number of batches is 1548
#       274/1    1.18467    1.18080 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4628985570222732 for eigenvalue
#  The estimated number of batches is 1561
#       275/1    1.17539    1.18078 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4538195492338053 for eigenvalue
#  The estimated number of batches is 1556
#       276/1    1.18431    1.18080 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4450902214268497 for eigenvalue
#  The estimated number of batches is 1551
#       277/1    1.18769    1.18082 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4365135105539193 for eigenvalue
#  The estimated number of batches is 1546
#       278/1    1.17638    1.18080 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.428281435425478 for eigenvalue
#  The estimated number of batches is 1542
#       279/1    1.18760    1.18083 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4224036991155398 for eigenvalue
#  The estimated number of batches is 1540
#       280/1    1.18061    1.18083 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4128217008474295 for eigenvalue
#  The estimated number of batches is 1534
#       281/1    1.18891    1.18086 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4168788417207225 for eigenvalue
#  The estimated number of batches is 1545
#       282/1    1.17111    1.18082 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4072043861468284 for eigenvalue
#  The estimated number of batches is 1539
#       283/1    1.17067    1.18079 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.409259115822413 for eigenvalue
#  The estimated number of batches is 1547
#       284/1    1.18615    1.18081 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.4008616120696638 for eigenvalue
#  The estimated number of batches is 1542
#       285/1    1.18494    1.18082 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.396902443756064 for eigenvalue
#  The estimated number of batches is 1543
#       286/1    1.17730    1.18081 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3917204037778172 for eigenvalue
#  The estimated number of batches is 1542
#       287/1    1.18656    1.18083 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3850630321262623 for eigenvalue
#  The estimated number of batches is 1539
#       288/1    1.18506    1.18085 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3762946842953103 for eigenvalue
#  The estimated number of batches is 1534
#       289/1    1.17577    1.18083 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3672256186613305 for eigenvalue
#  The estimated number of batches is 1528
#       290/1    1.18054    1.18083 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.358826631743805 for eigenvalue
#  The estimated number of batches is 1523
#       291/1    1.18819    1.18085 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.3684495382614155 for eigenvalue
#  The estimated number of batches is 1541
#       292/1    1.17763    1.18084 +/- 0.00039
# ...
#  The estimated number of batches is 1665
#      1572/1    1.17493    1.18076 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0293520569430812 for eigenvalue
#  The estimated number of batches is 1665
#      1573/1    1.18972    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0291253066869561 for eigenvalue
#  The estimated number of batches is 1665
#      1574/1    1.18073    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0286473644629923 for eigenvalue
#  The estimated number of batches is 1665
#      1575/1    1.17827    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028953644809597 for eigenvalue
#  The estimated number of batches is 1667
#      1576/1    1.17735    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.028473321319281 for eigenvalue
#  The estimated number of batches is 1666
#      1577/1    1.17934    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0278179477539042 for eigenvalue
#  The estimated number of batches is 1665
#      1578/1    1.18145    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0273112458680491 for eigenvalue
#  The estimated number of batches is 1665
#      1579/1    1.18061    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0266538139361412 for eigenvalue
#  The estimated number of batches is 1664
#      1580/1    1.19064    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.026879869057657 for eigenvalue
#  The estimated number of batches is 1665
#      1581/1    1.17337    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0267294377367189 for eigenvalue
#  The estimated number of batches is 1666
#      1582/1    1.18888    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0261797078861672 for eigenvalue
#  The estimated number of batches is 1665
#      1583/1    1.18102    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0260850416343315 for eigenvalue
#  The estimated number of batches is 1666
#      1584/1    1.16996    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.025500334678771 for eigenvalue
#  The estimated number of batches is 1665
#      1585/1    1.18305    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0248609871668324 for eigenvalue
#  The estimated number of batches is 1664
#      1586/1    1.18222    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0242396668160567 for eigenvalue
#  The estimated number of batches is 1663
#      1587/1    1.18310    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0237762830875086 for eigenvalue
#  The estimated number of batches is 1663
#      1588/1    1.18795    1.18077 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0240445230170006 for eigenvalue
#  The estimated number of batches is 1665
#      1589/1    1.18483    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023408374918868 for eigenvalue
#  The estimated number of batches is 1664
#      1590/1    1.18030    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0228818558183015 for eigenvalue
#  The estimated number of batches is 1663
#      1591/1    1.18201    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0224994886938852 for eigenvalue
#  The estimated number of batches is 1663
#      1592/1    1.18051    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0218596059068794 for eigenvalue
#  The estimated number of batches is 1662
#      1593/1    1.18897    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214933805252298 for eigenvalue
#  The estimated number of batches is 1662
#      1594/1    1.18187    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0219406749144968 for eigenvalue
#  The estimated number of batches is 1664
#      1595/1    1.18139    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0215713900393797 for eigenvalue
#  The estimated number of batches is 1664
#      1596/1    1.17779    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0215160081659969 for eigenvalue
#  The estimated number of batches is 1665
#      1597/1    1.18354    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0208828018117393 for eigenvalue
#  The estimated number of batches is 1664
#      1598/1    1.18419    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0203582016919635 for eigenvalue
#  The estimated number of batches is 1663
#      1599/1    1.18256    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0201624621539425 for eigenvalue
#  The estimated number of batches is 1664
#      1600/1    1.18105    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01957313705613 for eigenvalue
#  The estimated number of batches is 1663
#      1601/1    1.17821    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0190313297247142 for eigenvalue
#  The estimated number of batches is 1662
#      1602/1    1.18776    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0202433131293067 for eigenvalue
#  The estimated number of batches is 1667
#      1603/1    1.19321    1.18080 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0196410525314725 for eigenvalue
#  The estimated number of batches is 1666
#      1604/1    1.18096    1.18080 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0190872924433152 for eigenvalue
#  The estimated number of batches is 1666
#      1605/1    1.16697    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0194037711853772 for eigenvalue
#  The estimated number of batches is 1668
#      1606/1    1.17859    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0187512193226766 for eigenvalue
#  The estimated number of batches is 1667
#      1607/1    1.18526    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0181289641627984 for eigenvalue
#  The estimated number of batches is 1666
#      1608/1    1.17980    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0177359867117202 for eigenvalue
#  The estimated number of batches is 1665
#      1609/1    1.17810    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0171871540047084 for eigenvalue
#  The estimated number of batches is 1665
#      1610/1    1.17804    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0165362916783793 for eigenvalue
#  The estimated number of batches is 1664
#      1611/1    1.17599    1.18078 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0159353680311245 for eigenvalue
#  The estimated number of batches is 1663
#      1612/1    1.19940    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01828943927525 for eigenvalue
#  The estimated number of batches is 1671
#      1613/1    1.17564    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017673788490561 for eigenvalue
#  The estimated number of batches is 1670
#      1614/1    1.18492    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01705817036713 for eigenvalue
#  The estimated number of batches is 1669
#      1615/1    1.17510    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0167380830723263 for eigenvalue
#  The estimated number of batches is 1669
#      1616/1    1.18052    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0161450739954487 for eigenvalue
#  The estimated number of batches is 1668
#      1617/1    1.18537    1.18079 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.015865271047409 for eigenvalue
#  The estimated number of batches is 1669
#      1618/1    1.18937    1.18080 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0159171773732079 for eigenvalue
#  The estimated number of batches is 1670
#      1619/1    1.18937    1.18080 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0157517795089612 for eigenvalue
#  The estimated number of batches is 1670
#      1620/1    1.19129    1.18081 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0154666673844 for eigenvalue
#  The estimated number of batches is 1670
#      1621/1    1.18116    1.18081 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.014847376522567 for eigenvalue
#  The estimated number of batches is 1669
#      1622/1    1.18246    1.18081 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0142698053658843 for eigenvalue
#  The estimated number of batches is 1669
#      1623/1    1.18419    1.18081 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0136724455217103 for eigenvalue
#  The estimated number of batches is 1668
#      1624/1    1.18437    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0135271898972982 for eigenvalue
#  The estimated number of batches is 1668
#      1625/1    1.17974    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0134222555271035 for eigenvalue
#  The estimated number of batches is 1669
#      1626/1    1.18505    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0128517597371487 for eigenvalue
#  The estimated number of batches is 1668
#      1627/1    1.17260    1.18081 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0121995969592217 for eigenvalue
#  The estimated number of batches is 1667
#      1628/1    1.18866    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.012877447520295 for eigenvalue
#  The estimated number of batches is 1670
#      1629/1    1.18716    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.012334159269571 for eigenvalue
#  The estimated number of batches is 1669
#      1630/1    1.17518    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011714847021687 for eigenvalue
#  The estimated number of batches is 1668
#      1631/1    1.17886    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0113764554797047 for eigenvalue
#  The estimated number of batches is 1668
#      1632/1    1.18006    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0107583275560177 for eigenvalue
#  The estimated number of batches is 1667
#      1633/1    1.18078    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0113488114834075 for eigenvalue
#  The estimated number of batches is 1670
#      1634/1    1.17387    1.18081 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0114655262003 for eigenvalue
#  The estimated number of batches is 1672
#      1635/1    1.18084    1.18081 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.010845868785635 for eigenvalue
#  The estimated number of batches is 1671
#      1636/1    1.19167    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0102481138931108 for eigenvalue
#  The estimated number of batches is 1670
#      1637/1    1.18376    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0102367524260973 for eigenvalue
#  The estimated number of batches is 1671
#      1638/1    1.18043    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0096331622398937 for eigenvalue
#  The estimated number of batches is 1670
#      1639/1    1.19318    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009593198212086 for eigenvalue
#  The estimated number of batches is 1671
#      1640/1    1.17852    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009160759266007 for eigenvalue
#  The estimated number of batches is 1670
#      1641/1    1.18613    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0088470088538077 for eigenvalue
#  The estimated number of batches is 1670
#      1642/1    1.17717    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.008339666482982 for eigenvalue
#  The estimated number of batches is 1670
#      1643/1    1.16909    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0077074029719597 for eigenvalue
#  The estimated number of batches is 1669
#      1644/1    1.18659    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0074966536139065 for eigenvalue
#  The estimated number of batches is 1669
#      1645/1    1.17780    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0068932924285015 for eigenvalue
#  The estimated number of batches is 1668
#      1646/1    1.18101    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0062834670649772 for eigenvalue
#  The estimated number of batches is 1667
#      1647/1    1.18709    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0064995464111939 for eigenvalue
#  The estimated number of batches is 1669
#      1648/1    1.17882    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0060999050685646 for eigenvalue
#  The estimated number of batches is 1668
#      1649/1    1.18775    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0055233804762058 for eigenvalue
#  The estimated number of batches is 1668
#      1650/1    1.18137    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0049554717929061 for eigenvalue
#  The estimated number of batches is 1667
#      1651/1    1.18365    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0055033460537544 for eigenvalue
#  The estimated number of batches is 1670
#      1652/1    1.17868    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0049261785036003 for eigenvalue
#  The estimated number of batches is 1669
#      1653/1    1.17505    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0042982401259302 for eigenvalue
#  The estimated number of batches is 1668
#      1654/1    1.18332    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0037092838676258 for eigenvalue
#  The estimated number of batches is 1667
#      1655/1    1.17575    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0030804733071792 for eigenvalue
#  The estimated number of batches is 1666
#      1656/1    1.18150    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0024871060520937 for eigenvalue
#  The estimated number of batches is 1665
#      1657/1    1.17809    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0018640127558012 for eigenvalue
#  The estimated number of batches is 1664
#      1658/1    1.17809    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0012920920042474 for eigenvalue
#  The estimated number of batches is 1663
#      1659/1    1.19045    1.18083 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0007596890956083 for eigenvalue
#  The estimated number of batches is 1662
#      1660/1    1.17154    1.18082 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000185202306368 for eigenvalue
#  The estimated number of batches is 1661
#      1661/1    1.17237    1.18082 +/- 0.00016
#  Triggers satisfied for batch 1661
#  Creating state point statepoint.01661.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.6445e+01 seconds
#    Reading cross sections          = 6.5957e+01 seconds
#  Total time in simulation          = 4.4779e+04 seconds
#    Time in transport only          = 4.4467e+04 seconds
#    Time in inactive batches        = 3.1416e+02 seconds
#    Time in active batches          = 4.4464e+04 seconds
#    Time synchronizing fission bank = 2.1045e+01 seconds
#      Sampling source sites         = 1.5219e+01 seconds
#      SEND/RECV source sites        = 5.8241e+00 seconds
#    Time accumulating tallies       = 2.7311e+02 seconds
#    Time writing statepoints        = 8.9842e+00 seconds
#  Total time for finalization       = 1.1358e+02 seconds
#  Total time elapsed                = 4.4960e+04 seconds
#  Calculation Rate (inactive)       = 3183.08 particles/second
#  Calculation Rate (active)         = 1845.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18075 +/- 0.00014
#  k-effective (Track-length)  = 1.18082 +/- 0.00016
#  k-effective (Absorption)    = 1.18066 +/- 0.00011
#  Combined k-effective        = 1.18070 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
