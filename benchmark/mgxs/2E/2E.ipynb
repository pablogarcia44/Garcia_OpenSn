# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)
zirconium.temperature=600


water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.17860E-03)

pyrex_mat = openmc.Material(name="pyrex_mat")
pyrex_mat.add_nuclide('B10',9.63266E-04, 'ao')
pyrex_mat.add_nuclide('B11',3.90172E-03, 'ao')
pyrex_mat.add_nuclide('O16',4.67761E-02, 'ao')
pyrex_mat.add_nuclide('Si28',1.81980E-02, 'ao')
pyrex_mat.add_nuclide('Si29',9.24474E-04, 'ao')
pyrex_mat.add_nuclide('Si30',6.10133E-04, 'ao')
pyrex_mat.set_density('g/cm3', 2.25 )
pyrex_mat.temperature=600


SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,pyrex_mat,SS304]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_guide'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_guide'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create Pyrex Tube

# %%
def pyrex_pin(family):
    guide_inner_radius = openmc.ZCylinder(r=0.559)
    guide_outer_radius = openmc.ZCylinder(r=0.605)
    Inner_Tube_Inner_Radius= openmc.ZCylinder(r=0.214)
    Inner_Tube_Outer_Radius= openmc.ZCylinder(r= 0.231)
    Pyrex_Inner_Radius= openmc.ZCylinder(r= 0.241)
    Pyrex_Outer_Radius= openmc.ZCylinder(r= 0.427)
    Cladding_Inner_Radius= openmc.ZCylinder(r= 0.437)
    Cladding_Outer_Radius= openmc.ZCylinder(r= 0.484)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    pyrex_region= +Pyrex_Inner_Radius & -Pyrex_Outer_Radius
    water_region = +left & -right & +bottom & -top & +guide_outer_radius | +Cladding_Outer_Radius & -guide_inner_radius 
    guide_region = +guide_inner_radius & -guide_outer_radius
    steel_region = +Cladding_Inner_Radius & -Cladding_Outer_Radius | +Inner_Tube_Inner_Radius & -Inner_Tube_Outer_Radius
    gap_region = +Inner_Tube_Outer_Radius & -Pyrex_Inner_Radius |  +Pyrex_Outer_Radius & - Cladding_Inner_Radius | -Inner_Tube_Inner_Radius
     
    steel_cell = openmc.Cell(name='steel_cell'+'_'+family)
    steel_cell.fill = SS304
    steel_cell.region = steel_region    
    gap_cell = openmc.Cell(name='gap_cell'+'_'+family)
    gap_cell.region = gap_region 
    gap_cell.fill = helium
    pyrex_cell = openmc.Cell(name='pyrex_cell'+'_'+family)
    pyrex_cell.fill = pyrex_mat
    pyrex_cell.region = pyrex_region     
    water_cell = openmc.Cell(name='water_cell'+'_'+family)
    water_cell.fill = water
    water_cell.region = water_region
    guide_cell = openmc.Cell(name='guide_cell'+'_'+family)
    guide_cell.fill = zirconium
    guide_cell.region = guide_region
    
    
    u = openmc.Universe(name='u_pyrex'+'_'+family,cells=(steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell))
    return(u,steel_cell,gap_cell,pyrex_cell,guide_cell,water_cell)

# %% [markdown]
# ### Mappping

# %%
GT=[(8,2),(3,3),(5,5),(2,8)]
IT=[(8,8)]
PT=[(5,2),(2,5),(8,5),(5,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))

PT_left=[]
PT_full=[]
for X in PT:
    PT_left.append((X[0],X[1]))
    PT_left.append((X[0],16-X[1]))
for X in PT_left:
    PT_full.append((X[0],X[1]))
    PT_full.append((16-X[0],X[1]))    
PT_full = list(set(PT_full))

# %% [markdown]
# ### Create family pincell

# %%
pincell_1_family=pincell('pincell_1_family')
guide_1_family=guide('guide_1_family')
instru_1_family=instru('instru_1_family')
pyrex_1_family=pyrex_pin('pyrex_1_family')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly
size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT :
            A[ix][iy]=instru_1_family[0]
        elif (ix,iy) in PT_full :
            A[ix][iy]=pyrex_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]    

#print(A)           
            
            
print(A)
        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)
# Out:
# [[Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	9
#   	Name           =	u_guide_instru_1_family
#   	Geom           =	CSG
#   	Cells          =	[23, 24, 25]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	8
#   	Name           =	u_guide_guide_1_family
#   	Geom           =	CSG
#   	Cells          =	[20, 21, 22]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	10
#   	Name           =	u_pyrex_pyrex_1_family
#   	Geom           =	CSG
#   	Cells          =	[26, 27, 28, 30, 29]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]
#  [Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]
#   Universe
#   	ID             =	7
#   	Name           =	u_pincell_1_family
#   	Geom           =	CSG
#   	Cells          =	[16, 18, 19, 17]  ]]

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
print(model.geometry.get_all_material_cells().values())
# Out:
# dict_values([Cell
# 	ID             =	16
# 	Name           =	fuel_pincell_1_family
# 	Fill           =	Material 7
# 	Region         =	-32
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	18
# 	Name           =	clad_pincell_1_family
# 	Fill           =	Material 8
# 	Region         =	(33 -34)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	19
# 	Name           =	moderator_pincell_1_family
# 	Fill           =	Material 9
# 	Region         =	(35 -36 37 -38 34)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	17
# 	Name           =	gap_pincell_1_family
# 	Fill           =	Material 10
# 	Region         =	(32 -33)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	26
# 	Name           =	steel_cell_pyrex_1_family
# 	Fill           =	Material 12
# 	Region         =	((57 -58) | (53 -54))
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	27
# 	Name           =	gap_cell_pyrex_1_family
# 	Fill           =	Material 10
# 	Region         =	((54 -55) | (56 -57) | -53)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	28
# 	Name           =	pyrex_cell_pyrex_1_family
# 	Fill           =	Material 11
# 	Region         =	(55 -56)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	30
# 	Name           =	guide_cell_pyrex_1_family
# 	Fill           =	Material 8
# 	Region         =	(51 -52)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	29
# 	Name           =	water_cell_pyrex_1_family
# 	Fill           =	Material 9
# 	Region         =	((59 -60 61 -62 52) | (58 -51))
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	20
# 	Name           =	water_guide_1_family
# 	Fill           =	Material 9
# 	Region         =	-39
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	21
# 	Name           =	clad_guide_1_family
# 	Fill           =	Material 8
# 	Region         =	(39 -40)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	22
# 	Name           =	moderator_guide_1_family
# 	Fill           =	Material 9
# 	Region         =	(41 -42 43 -44 40)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	23
# 	Name           =	water_guide_instru_1_family
# 	Fill           =	Material 9
# 	Region         =	-45
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	24
# 	Name           =	clad_guide_instru_1_family
# 	Fill           =	Material 8
# 	Region         =	(45 -46)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	25
# 	Name           =	moderator_instru_1_family
# 	Fill           =	Material 9
# 	Region         =	(47 -48 49 -50 46)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	31
# 	Name           =	water_outside
# 	Fill           =	Material 9
# 	Region         =	None
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ])

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=590.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=2.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=10.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-08-12 17:29:27
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.07602
#         2/1    1.07152
#         3/1    1.06804
#         4/1    1.07296
#         5/1    1.06657
#         6/1    1.06666
#         7/1    1.06398
#         8/1    1.07986
#         9/1    1.07038
#        10/1    1.07422
#        11/1    1.07271
#        12/1    1.06256
#        13/1    1.07582
#        14/1    1.07430
#        15/1    1.07732
#        16/1    1.06107
#        17/1    1.07039
#        18/1    1.06101
#        19/1    1.07697
#        20/1    1.07646
#        21/1    1.07469
#        22/1    1.07714    1.07591 +/- 0.00122
#        23/1    1.07436    1.07540 +/- 0.00088
#        24/1    1.08104    1.07681 +/- 0.00154
#        25/1    1.06703    1.07485 +/- 0.00229
#        26/1    1.07074    1.07417 +/- 0.00199
#        27/1    1.05731    1.07176 +/- 0.00294
#        28/1    1.06857    1.07136 +/- 0.00258
#        29/1    1.06860    1.07105 +/- 0.00229
#        30/1    1.07467    1.07142 +/- 0.00208
#        31/1    1.06423    1.07076 +/- 0.00199
#        32/1    1.06653    1.07041 +/- 0.00185
#        33/1    1.06950    1.07034 +/- 0.00171
#        34/1    1.07037    1.07034 +/- 0.00158
#        35/1    1.07113    1.07040 +/- 0.00147
#        36/1    1.07827    1.07089 +/- 0.00146
#        37/1    1.06552    1.07057 +/- 0.00141
#        38/1    1.06558    1.07029 +/- 0.00136
#        39/1    1.06852    1.07020 +/- 0.00129
#        40/1    1.06448    1.06991 +/- 0.00125
#        41/1    1.05939    1.06941 +/- 0.00129
#        42/1    1.07300    1.06958 +/- 0.00124
#        43/1    1.06946    1.06957 +/- 0.00119
#        44/1    1.07473    1.06979 +/- 0.00116
#        45/1    1.06295    1.06951 +/- 0.00114
#        46/1    1.07045    1.06955 +/- 0.00110
#        47/1    1.07336    1.06969 +/- 0.00107
#        48/1    1.06816    1.06964 +/- 0.00103
#        49/1    1.06669    1.06953 +/- 0.00100
#        50/1    1.07137    1.06959 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 5.6528330097182655 for eigenvalue
#  The estimated number of batches is 979
#  Creating state point statepoint.00050.h5...
#        51/1    1.07351    1.06972 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.84838802966269 for eigenvalue
#  The estimated number of batches is 1081
#        52/1    1.06699    1.06964 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.636733733705295 for eigenvalue
#  The estimated number of batches is 1037
#        53/1    1.06476    1.06949 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.454844796612296 for eigenvalue
#  The estimated number of batches is 1002
#        54/1    1.06696    1.06941 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 5.319863507887914 for eigenvalue
#  The estimated number of batches is 983
#        55/1    1.06972    1.06942 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.23944373020164 for eigenvalue
#  The estimated number of batches is 981
#        56/1    1.07107    1.06947 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.081849709364534 for eigenvalue
#  The estimated number of batches is 950
#        57/1    1.07537    1.06963 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.0512287676284275 for eigenvalue
#  The estimated number of batches is 965
#        58/1    1.07660    1.06981 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.249115879263888 for eigenvalue
#  The estimated number of batches is 1068
#        59/1    1.06718    1.06974 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.210087337010864 for eigenvalue
#  The estimated number of batches is 1079
#        60/1    1.07623    1.06991 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.42402344046736 for eigenvalue
#  The estimated number of batches is 1197
#        61/1    1.06829    1.06987 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.3064068421072825 for eigenvalue
#  The estimated number of batches is 1175
#        62/1    1.07520    1.06999 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.4573862352776965 for eigenvalue
#  The estimated number of batches is 1271
#        63/1    1.07997    1.07023 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.44225656464428 for eigenvalue
#  The estimated number of batches is 1294
#        64/1    1.07255    1.07028 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.362961898265573 for eigenvalue
#  The estimated number of batches is 1286
#        65/1    1.07414    1.07036 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 5.266055631706179 for eigenvalue
#  The estimated number of batches is 1268
#        66/1    1.06992    1.07035 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 5.149591825320919 for eigenvalue
#  The estimated number of batches is 1240
#        67/1    1.06889    1.07032 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 5.043732152872784 for eigenvalue
#  The estimated number of batches is 1216
#        68/1    1.07075    1.07033 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.984677654208631 for eigenvalue
#  The estimated number of batches is 1213
#        69/1    1.06715    1.07027 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 5.083871948882057 for eigenvalue
#  The estimated number of batches is 1287
#        70/1    1.06518    1.07017 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 5.019369184697774 for eigenvalue
#  The estimated number of batches is 1280
#        71/1    1.07037    1.07017 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.9620391903564105 for eigenvalue
#  The estimated number of batches is 1276
#        72/1    1.06224    1.07002 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 5.180528915497267 for eigenvalue
#  The estimated number of batches is 1416
#        73/1    1.07172    1.07005 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 5.0905189747016895 for eigenvalue
#  The estimated number of batches is 1394
#        74/1    1.07377    1.07012 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 5.07889972600056 for eigenvalue
#  The estimated number of batches is 1413
#        75/1    1.07370    1.07018 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 5.066287938633635 for eigenvalue
#  The estimated number of batches is 1432
#        76/1    1.06307    1.07006 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.915559489018189 for eigenvalue
#  The estimated number of batches is 1374
#        77/1    1.07825    1.07020 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.872685184526989 for eigenvalue
#  The estimated number of batches is 1374
#        78/1    1.06358    1.07009 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.830122527006092 for eigenvalue
#  The estimated number of batches is 1374
#        79/1    1.06450    1.06999 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.765269623210487 for eigenvalue
#  The estimated number of batches is 1360
#        80/1    1.06219    1.06986 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.730832759356915 for eigenvalue
#  The estimated number of batches is 1363
#        81/1    1.07988    1.07003 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.799959646862009 for eigenvalue
#  The estimated number of batches is 1426
#        82/1    1.07648    1.07013 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.7389731527453645 for eigenvalue
#  The estimated number of batches is 1413
#        83/1    1.06747    1.07009 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.675758953564358 for eigenvalue
#  The estimated number of batches is 1398
#        84/1    1.05875    1.06991 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.597976596880692 for eigenvalue
#  The estimated number of batches is 1374
#        85/1    1.07591    1.07000 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.580929572882523 for eigenvalue
#  The estimated number of batches is 1385
#        86/1    1.06335    1.06990 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.562498064718974 for eigenvalue
#  The estimated number of batches is 1394
#        87/1    1.06956    1.06990 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.481024873063331 for eigenvalue
#  The estimated number of batches is 1366
#        88/1    1.07334    1.06995 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.498867556704453 for eigenvalue
#  The estimated number of batches is 1397
#        89/1    1.07046    1.06995 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.436701825665334 for eigenvalue
#  The estimated number of batches is 1379
#        90/1    1.07218    1.06999 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.371329841233215 for eigenvalue
#  The estimated number of batches is 1358
#        91/1    1.06883    1.06997 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.435280364284379 for eigenvalue
#  The estimated number of batches is 1417
#        92/1    1.07290    1.07001 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.379481127023862 for eigenvalue
#  The estimated number of batches is 1401
#        93/1    1.06659    1.06996 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.351311474830768 for eigenvalue
#  The estimated number of batches is 1403
#        94/1    1.06576    1.06991 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.400698467243496 for eigenvalue
#  The estimated number of batches is 1454
#        95/1    1.06730    1.06987 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.424152241838882 for eigenvalue
#  The estimated number of batches is 1488
#        96/1    1.06212    1.06977 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.425976246551715 for eigenvalue
#  The estimated number of batches is 1509
#        97/1    1.07848    1.06988 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.516547275904173 for eigenvalue
#  The estimated number of batches is 1591
#        98/1    1.06608    1.06983 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.451508520005482 for eigenvalue
#  The estimated number of batches is 1566
#        99/1    1.07077    1.06985 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.399766199807263 for eigenvalue
#  The estimated number of batches is 1550
#       100/1    1.06217    1.06975 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.385408341938568 for eigenvalue
#  The estimated number of batches is 1559
#       101/1    1.07405    1.06980 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.340200132040128 for eigenvalue
#  The estimated number of batches is 1546
#       102/1    1.06984    1.06980 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 4.287249522035955 for eigenvalue
#  The estimated number of batches is 1528
#       103/1    1.06926    1.06980 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.234596333273666 for eigenvalue
#  The estimated number of batches is 1509
#       104/1    1.06896    1.06979 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.1837748794605 for eigenvalue
#  The estimated number of batches is 1491
#       105/1    1.08038    1.06991 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.37042163808425 for eigenvalue
#  The estimated number of batches is 1644
#       106/1    1.07151    1.06993 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 4.335887446958577 for eigenvalue
#  The estimated number of batches is 1637
#       107/1    1.07187    1.06995 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.312260174203639 for eigenvalue
#  The estimated number of batches is 1638
#       108/1    1.06467    1.06989 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 4.288147193604421 for eigenvalue
#  The estimated number of batches is 1639
#       109/1    1.06644    1.06985 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.233523728057648 for eigenvalue
#  The estimated number of batches is 1616
#       110/1    1.06614    1.06981 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 4.185349869720006 for eigenvalue
#  The estimated number of batches is 1597
#       111/1    1.07270    1.06984 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.153108693037634 for eigenvalue
#  The estimated number of batches is 1590
#       112/1    1.06861    1.06983 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.110877025841324 for eigenvalue
#  The estimated number of batches is 1575
#       113/1    1.06519    1.06978 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 4.070887388267907 for eigenvalue
#  The estimated number of batches is 1562
#       114/1    1.07282    1.06981 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 4.032393470863739 for eigenvalue
#  The estimated number of batches is 1549
#       115/1    1.06930    1.06981 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.9898198368295996 for eigenvalue
#  The estimated number of batches is 1533
#       116/1    1.05957    1.06970 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.955123046635168 for eigenvalue
#  The estimated number of batches is 1522
#       117/1    1.07530    1.06976 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.9224580531873863 for eigenvalue
#  The estimated number of batches is 1513
#       118/1    1.07499    1.06981 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.937520797710782 for eigenvalue
#  The estimated number of batches is 1540
#       119/1    1.07458    1.06986 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.9138116300356875 for eigenvalue
#  The estimated number of batches is 1537
#       120/1    1.07542    1.06992 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.891335463740192 for eigenvalue
#  The estimated number of batches is 1535
#       121/1    1.06753    1.06989 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.8542248597713513 for eigenvalue
#  The estimated number of batches is 1521
#       122/1    1.07878    1.06998 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.8552623413342135 for eigenvalue
#  The estimated number of batches is 1537
#       123/1    1.07557    1.07003 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.827982187761851 for eigenvalue
#  The estimated number of batches is 1530
#       124/1    1.06511    1.06999 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.796277884410499 for eigenvalue
#  The estimated number of batches is 1519
#       125/1    1.06722    1.06996 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.757958468475789 for eigenvalue
#  The estimated number of batches is 1503
#       126/1    1.05619    1.06983 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.7365025240924488 for eigenvalue
#  The estimated number of batches is 1500
#       127/1    1.06722    1.06981 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.695844198432944 for eigenvalue
#  The estimated number of batches is 1482
#       128/1    1.07205    1.06983 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.6637342937253585 for eigenvalue
#  The estimated number of batches is 1470
#       129/1    1.06647    1.06980 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.626322497900919 for eigenvalue
#  The estimated number of batches is 1454
#       130/1    1.06913    1.06979 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.5939361338574254 for eigenvalue
#  The estimated number of batches is 1441
#       131/1    1.06988    1.06979 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.561329161159004 for eigenvalue
#  The estimated number of batches is 1428
#       132/1    1.07827    1.06987 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.545807484882338 for eigenvalue
#  The estimated number of batches is 1429
#       133/1    1.07754    1.06993 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.534153700051549 for eigenvalue
#  The estimated number of batches is 1432
#       134/1    1.06937    1.06993 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.508603077239921 for eigenvalue
#  The estimated number of batches is 1424
#       135/1    1.07704    1.06999 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.484884647169706 for eigenvalue
#  The estimated number of batches is 1417
#       136/1    1.06414    1.06994 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.446954439667596 for eigenvalue
#  The estimated number of batches is 1399
#       137/1    1.07313    1.06997 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.43538745355934 for eigenvalue
#  The estimated number of batches is 1401
#       138/1    1.06434    1.06992 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.4215639746087967 for eigenvalue
#  The estimated number of batches is 1402
#       139/1    1.07203    1.06994 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.4040125109097104 for eigenvalue
#  The estimated number of batches is 1399
#       140/1    1.06277    1.06988 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.3692613038493064 for eigenvalue
#  The estimated number of batches is 1383
#       141/1    1.07301    1.06990 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.343597448032517 for eigenvalue
#  The estimated number of batches is 1373
#       142/1    1.07073    1.06991 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.316657987966222 for eigenvalue
#  The estimated number of batches is 1363
#       143/1    1.07066    1.06992 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.295625751828538 for eigenvalue
#  The estimated number of batches is 1356
#       144/1    1.07178    1.06993 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.2768029995600068 for eigenvalue
#  The estimated number of batches is 1352
#       145/1    1.07403    1.06997 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.2720043286513567 for eigenvalue
#  The estimated number of batches is 1359
#       146/1    1.06649    1.06994 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.24352712217088 for eigenvalue
#  The estimated number of batches is 1346
#       147/1    1.06922    1.06993 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.256522936098592 for eigenvalue
#  The estimated number of batches is 1367
#       148/1    1.06226    1.06987 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.296108264577644 for eigenvalue
#  The estimated number of batches is 1411
#       149/1    1.06932    1.06987 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.3159078906612973 for eigenvalue
#  The estimated number of batches is 1439
#       150/1    1.07309    1.06989 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2911931618000936 for eigenvalue
#  The estimated number of batches is 1429
#       151/1    1.07631    1.06994 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.271878016768136 for eigenvalue
#  The estimated number of batches is 1423
#       152/1    1.08100    1.07003 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2682002290807675 for eigenvalue
#  The estimated number of batches is 1430
#       153/1    1.06218    1.06997 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.247859537527012 for eigenvalue
#  The estimated number of batches is 1423
#       154/1    1.07385    1.07000 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2718720989492107 for eigenvalue
#  The estimated number of batches is 1455
#       155/1    1.06833    1.06998 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.2508962960292607 for eigenvalue
#  The estimated number of batches is 1447
#       156/1    1.07634    1.07003 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.261818225460718 for eigenvalue
#  The estimated number of batches is 1467
#       157/1    1.06675    1.07001 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2374376179646034 for eigenvalue
#  The estimated number of batches is 1456
#       158/1    1.06681    1.06998 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.212920706612586 for eigenvalue
#  The estimated number of batches is 1445
#       159/1    1.06572    1.06995 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2100256717098197 for eigenvalue
#  The estimated number of batches is 1453
#       160/1    1.07057    1.06996 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.2015229178671865 for eigenvalue
#  The estimated number of batches is 1455
#       161/1    1.06652    1.06993 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1859103870064494 for eigenvalue
#  The estimated number of batches is 1452
#       162/1    1.07736    1.06998 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.166962057002096 for eigenvalue
#  The estimated number of batches is 1445
#       163/1    1.07611    1.07003 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.187696440267685 for eigenvalue
#  The estimated number of batches is 1474
#       164/1    1.07610    1.07007 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.169165085275977 for eigenvalue
#  The estimated number of batches is 1467
#       165/1    1.06171    1.07001 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.168149308918606 for eigenvalue
#  The estimated number of batches is 1476
#       166/1    1.07506    1.07005 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1746829419069984 for eigenvalue
#  The estimated number of batches is 1492
#       167/1    1.06423    1.07001 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1660119052294164 for eigenvalue
#  The estimated number of batches is 1494
#       168/1    1.06727    1.06999 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.148537587679756 for eigenvalue
#  The estimated number of batches is 1488
#       169/1    1.07529    1.07002 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.1414268269205103 for eigenvalue
#  The estimated number of batches is 1491
#       170/1    1.07005    1.07002 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.123457627830381 for eigenvalue
#  The estimated number of batches is 1484
#       171/1    1.07747    1.07007 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.1107254990616746 for eigenvalue
#  The estimated number of batches is 1482
#       172/1    1.06700    1.07005 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.099368182010799 for eigenvalue
#  The estimated number of batches is 1481
#       173/1    1.06549    1.07002 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0952155044393868 for eigenvalue
#  The estimated number of batches is 1486
#       174/1    1.06800    1.07001 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0770119473391757 for eigenvalue
#  The estimated number of batches is 1479
#       175/1    1.08378    1.07010 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0662338957800213 for eigenvalue
#  The estimated number of batches is 1478
#       176/1    1.06380    1.07006 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.045513097439172 for eigenvalue
#  The estimated number of batches is 1467
#       177/1    1.07002    1.07006 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0257062601226674 for eigenvalue
#  The estimated number of batches is 1458
#       178/1    1.06646    1.07004 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.0212272878357926 for eigenvalue
#  The estimated number of batches is 1463
#       179/1    1.06781    1.07002 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 3.011645709103046 for eigenvalue
#  The estimated number of batches is 1463
#       180/1    1.06418    1.06999 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.014322799734477 for eigenvalue
#  The estimated number of batches is 1474
#       181/1    1.06932    1.06998 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.0202903275516126 for eigenvalue
#  The estimated number of batches is 1489
#       182/1    1.07452    1.07001 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 3.004882855978978 for eigenvalue
#  The estimated number of batches is 1483
#       183/1    1.06357    1.06997 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9846060764737543 for eigenvalue
#  The estimated number of batches is 1472
#       184/1    1.07459    1.07000 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9711624833256294 for eigenvalue
#  The estimated number of batches is 1468
#       185/1    1.06441    1.06996 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.9523866647681603 for eigenvalue
#  The estimated number of batches is 1459
#       186/1    1.07175    1.06997 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9384418582176317 for eigenvalue
#  The estimated number of batches is 1454
#       187/1    1.07209    1.06999 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.922863560167978 for eigenvalue
#  The estimated number of batches is 1447
#       188/1    1.07494    1.07002 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.908020012936338 for eigenvalue
#  The estimated number of batches is 1441
#       189/1    1.06245    1.06997 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.9019652897053008 for eigenvalue
#  The estimated number of batches is 1444
#       190/1    1.06901    1.06997 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.885991738955767 for eigenvalue
#  The estimated number of batches is 1436
#       191/1    1.06352    1.06993 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.867555535311332 for eigenvalue
#  The estimated number of batches is 1427
#       192/1    1.07260    1.06994 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.851806559930626 for eigenvalue
#  The estimated number of batches is 1419
#       193/1    1.06395    1.06991 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8320246696752283 for eigenvalue
#  The estimated number of batches is 1408
#       194/1    1.06427    1.06988 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8139515776020114 for eigenvalue
#  The estimated number of batches is 1398
#       195/1    1.07741    1.06992 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8164401334176934 for eigenvalue
#  The estimated number of batches is 1409
#       196/1    1.06518    1.06989 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.8172939729542303 for eigenvalue
#  The estimated number of batches is 1417
#       197/1    1.06398    1.06986 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7996533628365934 for eigenvalue
#  The estimated number of batches is 1408
#       198/1    1.06366    1.06983 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.792966693863258 for eigenvalue
#  The estimated number of batches is 1409
#       199/1    1.07379    1.06985 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.787634750617405 for eigenvalue
#  The estimated number of batches is 1411
#       200/1    1.06009    1.06979 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.784023085804642 for eigenvalue
#  The estimated number of batches is 1416
#       201/1    1.07761    1.06984 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7746834257251374 for eigenvalue
#  The estimated number of batches is 1414
#       202/1    1.07777    1.06988 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7900243451345994 for eigenvalue
#  The estimated number of batches is 1437
#       203/1    1.05568    1.06980 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7717365048508884 for eigenvalue
#  The estimated number of batches is 1426
#       204/1    1.06889    1.06980 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.771035380248007 for eigenvalue
#  The estimated number of batches is 1433
#       205/1    1.06671    1.06978 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7565582456082085 for eigenvalue
#  The estimated number of batches is 1426
#       206/1    1.06781    1.06977 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.740531768781013 for eigenvalue
#  The estimated number of batches is 1417
#       207/1    1.07000    1.06977 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7295526218288586 for eigenvalue
#  The estimated number of batches is 1414
#       208/1    1.06463    1.06974 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.721394208071965 for eigenvalue
#  The estimated number of batches is 1413
#       209/1    1.06902    1.06974 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.710189351369618 for eigenvalue
#  The estimated number of batches is 1409
#       210/1    1.06703    1.06973 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.696125157232667 for eigenvalue
#  The estimated number of batches is 1402
#       211/1    1.07240    1.06974 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.682031673969179 for eigenvalue
#  The estimated number of batches is 1394
#       212/1    1.06375    1.06971 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6666515784234486 for eigenvalue
#  The estimated number of batches is 1386
#       213/1    1.07118    1.06972 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.656899960368579 for eigenvalue
#  The estimated number of batches is 1383
#       214/1    1.06260    1.06968 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6537210859378764 for eigenvalue
#  The estimated number of batches is 1387
#       215/1    1.07232    1.06969 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6532825406384757 for eigenvalue
#  The estimated number of batches is 1393
#       216/1    1.06371    1.06966 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6394156996620377 for eigenvalue
#  The estimated number of batches is 1386
#       217/1    1.07719    1.06970 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.642402394088796 for eigenvalue
#  The estimated number of batches is 1396
#       218/1    1.06365    1.06967 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6347770791634564 for eigenvalue
#  The estimated number of batches is 1395
#       219/1    1.06640    1.06965 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6685447494989707 for eigenvalue
#  The estimated number of batches is 1438
#       220/1    1.07410    1.06968 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.657734412611672 for eigenvalue
#  The estimated number of batches is 1433
#       221/1    1.06519    1.06965 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6672010478779065 for eigenvalue
#  The estimated number of batches is 1450
#       222/1    1.07381    1.06967 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6560221928972982 for eigenvalue
#  The estimated number of batches is 1445
#       223/1    1.06796    1.06967 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6418111138256104 for eigenvalue
#  The estimated number of batches is 1437
#       224/1    1.07578    1.06970 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6620764914294783 for eigenvalue
#  The estimated number of batches is 1466
#       225/1    1.06256    1.06966 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6521703519384143 for eigenvalue
#  The estimated number of batches is 1462
#       226/1    1.07119    1.06967 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6478639230684626 for eigenvalue
#  The estimated number of batches is 1465
#       227/1    1.06957    1.06967 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.6356621341281077 for eigenvalue
#  The estimated number of batches is 1458
#       228/1    1.06554    1.06965 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6232199008202257 for eigenvalue
#  The estimated number of batches is 1452
#       229/1    1.07288    1.06966 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.641615181410604 for eigenvalue
#  The estimated number of batches is 1479
#       230/1    1.06113    1.06962 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.631321866500407 for eigenvalue
#  The estimated number of batches is 1475
#       231/1    1.06763    1.06961 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6196064423971386 for eigenvalue
#  The estimated number of batches is 1468
#       232/1    1.06520    1.06959 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.6148921311022297 for eigenvalue
#  The estimated number of batches is 1470
#       233/1    1.06991    1.06959 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.604941979025042 for eigenvalue
#  The estimated number of batches is 1466
#       234/1    1.07395    1.06961 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.593395663949054 for eigenvalue
#  The estimated number of batches is 1460
#       235/1    1.06813    1.06961 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5849752200459966 for eigenvalue
#  The estimated number of batches is 1457
#       236/1    1.06316    1.06958 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.5727860935581717 for eigenvalue
#  The estimated number of batches is 1450
#       237/1    1.07563    1.06961 +/- 0.00036
#  Triggers unsatisfied, max unc./thresh. is 2.573634860679419 for eigenvalue
#  The estimated number of batches is 1458
#       238/1    1.06728    1.06959 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.563087147801163 for eigenvalue
#  The estimated number of batches is 1453
#       239/1    1.07607    1.06962 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5621306608987653 for eigenvalue
#  The estimated number of batches is 1458
#       240/1    1.06368    1.06960 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.564770658894664 for eigenvalue
#  The estimated number of batches is 1468
#       241/1    1.07519    1.06962 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5527639015292922 for eigenvalue
#  The estimated number of batches is 1461
#       242/1    1.07513    1.06965 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5423713588824506 for eigenvalue
#  The estimated number of batches is 1455
#       243/1    1.06999    1.06965 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.538026590402641 for eigenvalue
#  The estimated number of batches is 1457
#       244/1    1.07049    1.06965 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.527703493094409 for eigenvalue
#  The estimated number of batches is 1452
#       245/1    1.07756    1.06969 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5235112567425197 for eigenvalue
#  The estimated number of batches is 1453
#       246/1    1.07754    1.06972 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5254189816659545 for eigenvalue
#  The estimated number of batches is 1462
#       247/1    1.06263    1.06969 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.531330226420027 for eigenvalue
#  The estimated number of batches is 1475
#       248/1    1.07639    1.06972 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5363354676106686 for eigenvalue
#  The estimated number of batches is 1487
#       249/1    1.07092    1.06973 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.528820695970342 for eigenvalue
#  The estimated number of batches is 1485
#       250/1    1.06835    1.06972 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.524163606330149 for eigenvalue
#  The estimated number of batches is 1486
#       251/1    1.06083    1.06968 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.5381800720295953 for eigenvalue
#  The estimated number of batches is 1509
#       252/1    1.06684    1.06967 +/- 0.00035
#  Triggers unsatisfied, max unc./thresh. is 2.526214585949047 for eigenvalue
#  The estimated number of batches is 1501
#       253/1    1.06269    1.06964 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5156710730637397 for eigenvalue
#  The estimated number of batches is 1495
#       254/1    1.06854    1.06963 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5065198314668224 for eigenvalue
#  The estimated number of batches is 1491
#       255/1    1.07330    1.06965 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.506320658643279 for eigenvalue
#  The estimated number of batches is 1497
#       256/1    1.05908    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.5028337313369264 for eigenvalue
#  The estimated number of batches is 1499
#       257/1    1.06973    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4914808495518623 for eigenvalue
#  The estimated number of batches is 1492
#       258/1    1.06959    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4814014433837492 for eigenvalue
#  The estimated number of batches is 1486
#       259/1    1.06677    1.06959 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4715486807611966 for eigenvalue
#  The estimated number of batches is 1480
#       260/1    1.07286    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.465350750263267 for eigenvalue
#  The estimated number of batches is 1479
#       261/1    1.07014    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4599871640625524 for eigenvalue
#  The estimated number of batches is 1479
#       262/1    1.06845    1.06961 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4481284191945782 for eigenvalue
#  The estimated number of batches is 1471
#       263/1    1.06684    1.06959 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.437393842321648 for eigenvalue
#  The estimated number of batches is 1464
#       264/1    1.05621    1.06954 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.454873342302866 for eigenvalue
#  The estimated number of batches is 1491
#       265/1    1.06455    1.06952 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4567547464044006 for eigenvalue
#  The estimated number of batches is 1499
#       266/1    1.07244    1.06953 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4474679373412727 for eigenvalue
#  The estimated number of batches is 1494
#       267/1    1.07994    1.06957 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.44002376856524 for eigenvalue
#  The estimated number of batches is 1491
#       268/1    1.08055    1.06962 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4597937139599377 for eigenvalue
#  The estimated number of batches is 1521
#       269/1    1.06143    1.06958 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.449140134465525 for eigenvalue
#  The estimated number of batches is 1514
#       270/1    1.07121    1.06959 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4440378507131553 for eigenvalue
#  The estimated number of batches is 1514
#       271/1    1.06681    1.06958 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.435555290455123 for eigenvalue
#  The estimated number of batches is 1509
#       272/1    1.05776    1.06953 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4322046474825814 for eigenvalue
#  The estimated number of batches is 1511
#       273/1    1.07642    1.06956 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4291480997920494 for eigenvalue
#  The estimated number of batches is 1513
#       274/1    1.06001    1.06952 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4226030565845433 for eigenvalue
#  The estimated number of batches is 1511
#       275/1    1.06675    1.06951 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4139584397583818 for eigenvalue
#  The estimated number of batches is 1506
#       276/1    1.06918    1.06951 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.406936439886896 for eigenvalue
#  The estimated number of batches is 1504
#       277/1    1.07946    1.06955 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4141104029083205 for eigenvalue
#  The estimated number of batches is 1518
#       278/1    1.07727    1.06958 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.4102345345320026 for eigenvalue
#  The estimated number of batches is 1519
#       279/1    1.06957    1.06958 +/- 0.00034
#  Triggers unsatisfied, max unc./thresh. is 2.409771023691437 for eigenvalue
#  The estimated number of batches is 1525
#       280/1    1.07016    1.06958 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.4025609266897168 for eigenvalue
#  The estimated number of batches is 1521
#       281/1    1.07752    1.06961 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.400382345564621 for eigenvalue
#  The estimated number of batches is 1524
#       282/1    1.06942    1.06961 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3915209843417875 for eigenvalue
#  The estimated number of batches is 1519
#       283/1    1.07333    1.06962 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.386595947566184 for eigenvalue
#  The estimated number of batches is 1519
#       284/1    1.07122    1.06963 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.377382546336355 for eigenvalue
#  The estimated number of batches is 1513
#       285/1    1.06649    1.06962 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.376721518400556 for eigenvalue
#  The estimated number of batches is 1517
#       286/1    1.07377    1.06963 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.369064941418391 for eigenvalue
#  The estimated number of batches is 1513
#       287/1    1.06798    1.06963 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3595124952051116 for eigenvalue
#  The estimated number of batches is 1507
#       288/1    1.07537    1.06965 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.357840118746892 for eigenvalue
#  The estimated number of batches is 1510
#       289/1    1.07588    1.06967 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3538102234720624 for eigenvalue
#  The estimated number of batches is 1511
#       290/1    1.06558    1.06966 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3454213657164527 for eigenvalue
#  The estimated number of batches is 1506
#       291/1    1.06752    1.06965 +/- 0.00033
#  Triggers unsatisfied, max unc./thresh. is 2.3368495630362744 for eigenvalue
#  The estimated number of batches is 1500
#       292/1    1.06656    1.06964 +/- 0.00032
# ...
#      1396/1    1.07493    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.031264827155917 for eigenvalue
#  The estimated number of batches is 1484
#      1397/1    1.06785    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0305258779605375 for eigenvalue
#  The estimated number of batches is 1483
#      1398/1    1.07061    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0298100660817606 for eigenvalue
#  The estimated number of batches is 1482
#      1399/1    1.06085    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0308739153366504 for eigenvalue
#  The estimated number of batches is 1486
#      1400/1    1.06388    1.06961 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0303393286352147 for eigenvalue
#  The estimated number of batches is 1486
#      1401/1    1.08726    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0309933334712857 for eigenvalue
#  The estimated number of batches is 1488
#      1402/1    1.06886    1.06962 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0302836185753939 for eigenvalue
#  The estimated number of batches is 1487
#      1403/1    1.07775    1.06963 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0295625846874061 for eigenvalue
#  The estimated number of batches is 1486
#      1404/1    1.07676    1.06963 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0293124700376606 for eigenvalue
#  The estimated number of batches is 1487
#      1405/1    1.07224    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0286372308334193 for eigenvalue
#  The estimated number of batches is 1486
#      1406/1    1.06932    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0279599353040512 for eigenvalue
#  The estimated number of batches is 1485
#      1407/1    1.06207    1.06963 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0276372201854442 for eigenvalue
#  The estimated number of batches is 1485
#      1408/1    1.07704    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0292666846034002 for eigenvalue
#  The estimated number of batches is 1491
#      1409/1    1.07353    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0285343382945709 for eigenvalue
#  The estimated number of batches is 1490
#      1410/1    1.07483    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0278810406987486 for eigenvalue
#  The estimated number of batches is 1489
#      1411/1    1.06891    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0271668977030175 for eigenvalue
#  The estimated number of batches is 1488
#      1412/1    1.07715    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0270998119350063 for eigenvalue
#  The estimated number of batches is 1489
#      1413/1    1.07344    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0267224271302815 for eigenvalue
#  The estimated number of batches is 1489
#      1414/1    1.05910    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.027462267201731 for eigenvalue
#  The estimated number of batches is 1492
#      1415/1    1.07266    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0275955397938965 for eigenvalue
#  The estimated number of batches is 1494
#      1416/1    1.06515    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.027545554502867 for eigenvalue
#  The estimated number of batches is 1494
#      1417/1    1.07192    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0269033284158031 for eigenvalue
#  The estimated number of batches is 1494
#      1418/1    1.06790    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0261832843835383 for eigenvalue
#  The estimated number of batches is 1493
#      1419/1    1.07004    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0254824086989835 for eigenvalue
#  The estimated number of batches is 1492
#      1420/1    1.06836    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0248342818186587 for eigenvalue
#  The estimated number of batches is 1491
#      1421/1    1.06977    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.024278576722613 for eigenvalue
#  The estimated number of batches is 1490
#      1422/1    1.08746    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0258380059149954 for eigenvalue
#  The estimated number of batches is 1496
#      1423/1    1.06414    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0264541358788308 for eigenvalue
#  The estimated number of batches is 1499
#      1424/1    1.06951    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0257128843943346 for eigenvalue
#  The estimated number of batches is 1498
#      1425/1    1.07576    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0250125474952303 for eigenvalue
#  The estimated number of batches is 1497
#      1426/1    1.07113    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.024300788426116 for eigenvalue
#  The estimated number of batches is 1496
#      1427/1    1.06686    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0235929233943266 for eigenvalue
#  The estimated number of batches is 1495
#      1428/1    1.06288    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0238282772489784 for eigenvalue
#  The estimated number of batches is 1496
#      1429/1    1.07606    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0238802650748644 for eigenvalue
#  The estimated number of batches is 1498
#      1430/1    1.07517    1.06966 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.023215625363457 for eigenvalue
#  The estimated number of batches is 1497
#      1431/1    1.06492    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0235480374293826 for eigenvalue
#  The estimated number of batches is 1499
#      1432/1    1.06195    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0235918839709202 for eigenvalue
#  The estimated number of batches is 1500
#      1433/1    1.06568    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0229447632288509 for eigenvalue
#  The estimated number of batches is 1499
#      1434/1    1.07188    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0222541922518262 for eigenvalue
#  The estimated number of batches is 1498
#      1435/1    1.08051    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0216036816182523 for eigenvalue
#  The estimated number of batches is 1497
#      1436/1    1.06911    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0209329032996213 for eigenvalue
#  The estimated number of batches is 1496
#      1437/1    1.06242    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.020153737063322 for eigenvalue
#  The estimated number of batches is 1495
#      1438/1    1.06576    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.019413062381051 for eigenvalue
#  The estimated number of batches is 1494
#      1439/1    1.06604    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0186778322335257 for eigenvalue
#  The estimated number of batches is 1493
#      1440/1    1.06662    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0180586879331923 for eigenvalue
#  The estimated number of batches is 1492
#      1441/1    1.07879    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0177371459913067 for eigenvalue
#  The estimated number of batches is 1492
#      1442/1    1.06167    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0186041876051495 for eigenvalue
#  The estimated number of batches is 1496
#      1443/1    1.07435    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0179729583018244 for eigenvalue
#  The estimated number of batches is 1495
#      1444/1    1.06515    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0173118185441385 for eigenvalue
#  The estimated number of batches is 1494
#      1445/1    1.06541    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.016600331052513 for eigenvalue
#  The estimated number of batches is 1493
#      1446/1    1.06502    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.015889100126117 for eigenvalue
#  The estimated number of batches is 1492
#      1447/1    1.06448    1.06963 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0151670017141678 for eigenvalue
#  The estimated number of batches is 1491
#      1448/1    1.07366    1.06963 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0151766792967112 for eigenvalue
#  The estimated number of batches is 1492
#      1449/1    1.07340    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0145518188750737 for eigenvalue
#  The estimated number of batches is 1491
#      1450/1    1.06715    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0138898393705353 for eigenvalue
#  The estimated number of batches is 1491
#      1451/1    1.07605    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0138919692559631 for eigenvalue
#  The estimated number of batches is 1492
#      1452/1    1.07444    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0132790171388666 for eigenvalue
#  The estimated number of batches is 1491
#      1453/1    1.06510    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0126379942219212 for eigenvalue
#  The estimated number of batches is 1490
#      1454/1    1.06236    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0121388406194534 for eigenvalue
#  The estimated number of batches is 1490
#      1455/1    1.07615    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.011713545607417 for eigenvalue
#  The estimated number of batches is 1489
#      1456/1    1.06731    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0110297989431867 for eigenvalue
#  The estimated number of batches is 1488
#      1457/1    1.07801    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0103631638545583 for eigenvalue
#  The estimated number of batches is 1487
#      1458/1    1.07266    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0097781200786116 for eigenvalue
#  The estimated number of batches is 1487
#      1459/1    1.07693    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.009196894890631 for eigenvalue
#  The estimated number of batches is 1486
#      1460/1    1.06595    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0086213290160608 for eigenvalue
#  The estimated number of batches is 1485
#      1461/1    1.05742    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.008372939584108 for eigenvalue
#  The estimated number of batches is 1486
#      1462/1    1.07157    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0077122898778865 for eigenvalue
#  The estimated number of batches is 1485
#      1463/1    1.06713    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0070158987375786 for eigenvalue
#  The estimated number of batches is 1484
#      1464/1    1.08059    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0083581253440534 for eigenvalue
#  The estimated number of batches is 1489
#      1465/1    1.07373    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0078484041536624 for eigenvalue
#  The estimated number of batches is 1488
#      1466/1    1.07488    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0078856273690635 for eigenvalue
#  The estimated number of batches is 1489
#      1467/1    1.06538    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0088907496505786 for eigenvalue
#  The estimated number of batches is 1493
#      1468/1    1.06999    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0085669085389337 for eigenvalue
#  The estimated number of batches is 1493
#      1469/1    1.07104    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0079881166631948 for eigenvalue
#  The estimated number of batches is 1493
#      1470/1    1.07036    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0076926652634801 for eigenvalue
#  The estimated number of batches is 1493
#      1471/1    1.07230    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.007567509671393 for eigenvalue
#  The estimated number of batches is 1494
#      1472/1    1.06341    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0069253496020598 for eigenvalue
#  The estimated number of batches is 1493
#      1473/1    1.07445    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.006752484709595 for eigenvalue
#  The estimated number of batches is 1493
#      1474/1    1.07092    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0060464762561778 for eigenvalue
#  The estimated number of batches is 1492
#      1475/1    1.06849    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0054012935847991 for eigenvalue
#  The estimated number of batches is 1491
#      1476/1    1.07150    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0051660059995962 for eigenvalue
#  The estimated number of batches is 1492
#      1477/1    1.06775    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0047930721706204 for eigenvalue
#  The estimated number of batches is 1492
#      1478/1    1.07078    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0041412223697321 for eigenvalue
#  The estimated number of batches is 1491
#      1479/1    1.07421    1.06966 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.003466859267027 for eigenvalue
#  The estimated number of batches is 1490
#      1480/1    1.06369    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0028202765522076 for eigenvalue
#  The estimated number of batches is 1489
#      1481/1    1.06667    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0021713387989215 for eigenvalue
#  The estimated number of batches is 1488
#      1482/1    1.06047    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0016904644047748 for eigenvalue
#  The estimated number of batches is 1487
#      1483/1    1.07153    1.06965 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0010125049656358 for eigenvalue
#  The estimated number of batches is 1486
#      1484/1    1.06555    1.06964 +/- 0.00015
#  Triggers unsatisfied, max unc./thresh. is 1.0003383069136886 for eigenvalue
#  The estimated number of batches is 1485
#      1485/1    1.07180    1.06964 +/- 0.00015
#  Triggers satisfied for batch 1485
#  Creating state point statepoint.01485.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 8.3852e+00 seconds
#    Reading cross sections          = 8.3079e+00 seconds
#  Total time in simulation          = 2.3472e+04 seconds
#    Time in transport only          = 2.3247e+04 seconds
#    Time in inactive batches        = 1.6504e+01 seconds
#    Time in active batches          = 2.3456e+04 seconds
#    Time synchronizing fission bank = 1.0281e+01 seconds
#      Sampling source sites         = 8.1682e+00 seconds
#      SEND/RECV source sites        = 2.1111e+00 seconds
#    Time accumulating tallies       = 2.0723e+02 seconds
#    Time writing statepoints        = 2.7490e+00 seconds
#  Total time for finalization       = 1.1096e+02 seconds
#  Total time elapsed                = 2.3592e+04 seconds
#  Calculation Rate (inactive)       = 60592.5 particles/second
#  Calculation Rate (active)         = 3122.91 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.06967 +/- 0.00013
#  k-effective (Track-length)  = 1.06964 +/- 0.00015
#  k-effective (Absorption)    = 1.06952 +/- 0.00012
#  Combined k-effective        = 1.06958 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
