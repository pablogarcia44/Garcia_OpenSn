# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob
import re

# %% [markdown]
# ### Import Output datas

# %%
# pb_num_list=['2A_1_family','2A_6_families','2A_72_families','2A_36_families']
pb_num_list=['2A','2B','2C','2D','2E','2F','2G','2H','2I','2J','2K','2L','2M','2N','2O','2P']

# %%
def load_mgxs(pb_num):
    sm_file_path='/Users/pablogarcia44/repo/Garcia_OpenSn/benchmark/'+pb_num+'/sm_'+pb_num+'.h5'
    sp_file_path='/Users/pablogarcia44/repo/Garcia_OpenSn/benchmark/'+pb_num+'/sp_'+pb_num+'.h5'
    model_file_path='/Users/pablogarcia44/repo/Garcia_OpenSn/benchmark/'+pb_num+'/model_'+pb_num+'.xml'
    sm=openmc.Summary(sm_file_path)
    sp = openmc.StatePoint(sp_file_path)
    sp.link_with_summary(sm)
    model=openmc.model.Model
    model=openmc.model.Model.from_model_xml(model_file_path)
    mgxs_lib = openmc.mgxs.Library(model.geometry)
    groups = openmc.mgxs.EnergyGroups(openmc.mgxs.GROUP_STRUCTURES['SHEM-361'])
    mgxs_lib.energy_groups = groups
    mgxs_lib.scatter_format = "legendre"
    mgxs_lib.legendre_order = 3
    mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
    mgxs_lib.by_nuclide = False
    mgxs_lib.domain_type = 'cell'
    mgxs_lib.domains = model.geometry.get_all_material_cells().values() 
    all_cell_order=[]
    for cell in (mgxs_lib.domains):
        all_cell_order.append(cell.name)
    print(mgxs_lib.domains)
    mgxs_lib.build_library()
    mgxs_lib.load_from_statepoint(sp)
    return(mgxs_lib,all_cell_order)

# %%
import_dict={}
for pb_num in pb_num_list:
        import_dict[pb_num]=[load_mgxs(pb_num)[0],load_mgxs(pb_num)[1]]
print(import_dict)
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=13.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=14.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=15.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=16.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=76.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=77.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=78.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=79.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=80.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=81.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=82.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=83.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=84.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=85.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=86.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=87.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=88.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=89.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=90.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=91.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=92.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=93.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=94.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=95.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=96.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=97.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=98.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=99.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=100.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Lattice instance already exists with id=22.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=23.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=19.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=20.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=21.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=37.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=38.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=39.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=40.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=41.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=42.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=43.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=44.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=45.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=46.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=47.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=48.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=24.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1158.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=760.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=769.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=768.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=773.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1129.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1112.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1113.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1120.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1125.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)
# [Cell
# 	ID             =	37
# 	Name           =	fuel_pincell
# 	Fill           =	Material 13
# 	Region         =	-76
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	38
# 	Name           =	gap_pincell
# 	Fill           =	Material 16
# 	Region         =	(76 -77)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	39
# 	Name           =	clad_pincell
# 	Fill           =	Material 14
# 	Region         =	(77 -78)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	40
# 	Name           =	moderator_pincell
# 	Fill           =	Material 15
# 	Region         =	(79 -80 81 -82 78)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	41
# 	Name           =	water_guide
# 	Fill           =	Material 15
# 	Region         =	-83
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	42
# 	Name           =	clad_guide
# 	Fill           =	Material 14
# 	Region         =	(83 -84)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	43
# 	Name           =	moderator_guide
# 	Fill           =	Material 15
# 	Region         =	(85 -86 87 -88 84)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	44
# 	Name           =	water_instru
# 	Fill           =	Material 15
# 	Region         =	-89
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	45
# 	Name           =	clad_instru
# 	Fill           =	Material 14
# 	Region         =	(89 -90)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	46
# 	Name           =	moderator_instru
# 	Fill           =	Material 15
# 	Region         =	(91 -92 93 -94 90)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	47
# 	Name           =	water_outside
# 	Fill           =	Material 15
# 	Region         =	None
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ]
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=13.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=14.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=15.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=16.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=76.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=77.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=78.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=79.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=80.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=81.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=82.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=83.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=84.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=85.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=86.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=87.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=88.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=89.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=90.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=91.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=92.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=93.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=94.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=95.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=96.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=97.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=98.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=99.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=100.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Lattice instance already exists with id=22.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=23.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=19.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=20.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=21.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=37.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=38.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=39.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=40.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=41.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=42.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=43.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=44.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=45.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=46.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=47.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=48.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=24.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1158.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=760.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=769.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=768.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=773.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1129.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1112.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1113.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1120.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1125.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)
# [Cell
# 	ID             =	37
# 	Name           =	fuel_pincell
# 	Fill           =	Material 13
# 	Region         =	-76
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	38
# 	Name           =	gap_pincell
# 	Fill           =	Material 16
# 	Region         =	(76 -77)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	39
# 	Name           =	clad_pincell
# 	Fill           =	Material 14
# 	Region         =	(77 -78)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	40
# 	Name           =	moderator_pincell
# 	Fill           =	Material 15
# 	Region         =	(79 -80 81 -82 78)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	41
# 	Name           =	water_guide
# 	Fill           =	Material 15
# 	Region         =	-83
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	42
# 	Name           =	clad_guide
# 	Fill           =	Material 14
# 	Region         =	(83 -84)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	43
# 	Name           =	moderator_guide
# 	Fill           =	Material 15
# 	Region         =	(85 -86 87 -88 84)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	44
# 	Name           =	water_instru
# 	Fill           =	Material 15
# 	Region         =	-89
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	45
# 	Name           =	clad_instru
# 	Fill           =	Material 14
# 	Region         =	(89 -90)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	46
# 	Name           =	moderator_instru
# 	Fill           =	Material 15
# 	Region         =	(91 -92 93 -94 90)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	47
# 	Name           =	water_outside
# 	Fill           =	Material 15
# 	Region         =	None
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ]
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=26.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=27.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=28.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=29.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=30.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=31.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=32.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=33.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=34.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=35.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=36.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=37.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=38.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=39.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=40.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=41.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=42.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=43.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=44.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=45.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=46.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=47.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=48.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=49.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=50.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Lattice instance already exists with id=10.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=11.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=7.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=8.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=9.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=13.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=14.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=15.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=16.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=17.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=18.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=19.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=20.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=21.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=22.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=23.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=24.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=12.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=758.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=360.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=369.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=368.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=373.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=738.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=721.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=722.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=729.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=734.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)
# [Cell
# 	ID             =	13
# 	Name           =	fuel_pincell
# 	Fill           =	Material 5
# 	Region         =	-26
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	14
# 	Name           =	gap_pincell
# 	Fill           =	Material 8
# 	Region         =	(26 -27)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	15
# 	Name           =	clad_pincell
# 	Fill           =	Material 6
# 	Region         =	(27 -28)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	16
# 	Name           =	moderator_pincell
# 	Fill           =	Material 7
# 	Region         =	(29 -30 31 -32 28)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	17
# 	Name           =	water_guide
# 	Fill           =	Material 7
# 	Region         =	-33
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	18
# 	Name           =	clad_guide
# 	Fill           =	Material 6
# 	Region         =	(33 -34)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	19
# 	Name           =	moderator_guide
# 	Fill           =	Material 7
# 	Region         =	(35 -36 37 -38 34)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	20
# 	Name           =	water_instru
# 	Fill           =	Material 7
# 	Region         =	-39
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	21
# 	Name           =	clad_instru
# 	Fill           =	Material 6
# 	Region         =	(39 -40)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	22
# 	Name           =	moderator_instru
# 	Fill           =	Material 7
# 	Region         =	(41 -42 43 -44 40)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	23
# 	Name           =	water_outside
# 	Fill           =	Material 7
# 	Region         =	None
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ]
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=26.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=27.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=28.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=29.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=30.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=31.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=32.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=33.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=34.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=35.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=36.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=37.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=38.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=39.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=40.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=41.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=42.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=43.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=44.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=45.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=46.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=47.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=48.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=49.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=50.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Lattice instance already exists with id=10.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=11.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=7.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=8.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=9.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=13.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=14.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=15.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=16.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=17.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=18.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=19.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=20.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=21.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=22.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=23.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=24.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=12.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=758.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=360.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=369.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=368.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=373.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=738.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=721.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=722.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=729.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=734.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)
# [Cell
# 	ID             =	13
# 	Name           =	fuel_pincell
# 	Fill           =	Material 5
# 	Region         =	-26
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	14
# 	Name           =	gap_pincell
# 	Fill           =	Material 8
# 	Region         =	(26 -27)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	15
# 	Name           =	clad_pincell
# 	Fill           =	Material 6
# 	Region         =	(27 -28)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	16
# 	Name           =	moderator_pincell
# 	Fill           =	Material 7
# 	Region         =	(29 -30 31 -32 28)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	17
# 	Name           =	water_guide
# 	Fill           =	Material 7
# 	Region         =	-33
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	18
# 	Name           =	clad_guide
# 	Fill           =	Material 6
# 	Region         =	(33 -34)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	19
# 	Name           =	moderator_guide
# 	Fill           =	Material 7
# 	Region         =	(35 -36 37 -38 34)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	20
# 	Name           =	water_instru
# 	Fill           =	Material 7
# 	Region         =	-39
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	21
# 	Name           =	clad_instru
# 	Fill           =	Material 6
# 	Region         =	(39 -40)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	22
# 	Name           =	moderator_instru
# 	Fill           =	Material 7
# 	Region         =	(41 -42 43 -44 40)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	23
# 	Name           =	water_outside
# 	Fill           =	Material 7
# 	Region         =	None
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ]
# ...
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=46.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=47.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=48.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=49.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=50.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=51.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=52.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=53.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=54.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=55.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=56.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=57.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=58.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=59.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=60.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=61.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=62.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=63.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=64.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Lattice instance already exists with id=12.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=13.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=8.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=11.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=9.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=10.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=17.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=18.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=19.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=20.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=21.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=22.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=23.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=24.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=25.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=26.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=27.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=28.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=29.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=30.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=31.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=32.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=14.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1104.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=554.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=563.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=562.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=567.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1070.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1053.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1054.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1061.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1066.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)
# [Cell
# 	ID             =	17
# 	Name           =	fuel_pincell
# 	Fill           =	Material 6
# 	Region         =	-33
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	18
# 	Name           =	gap_pincell
# 	Fill           =	Material 10
# 	Region         =	(33 -34)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	19
# 	Name           =	clad_pincell
# 	Fill           =	Material 8
# 	Region         =	(34 -35)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	20
# 	Name           =	moderator_pincell
# 	Fill           =	Material 9
# 	Region         =	(36 -37 38 -39 35)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	27
# 	Name           =	fuel_gado
# 	Fill           =	Material 7
# 	Region         =	-52
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	28
# 	Name           =	gap_gado
# 	Fill           =	Material 10
# 	Region         =	(52 -53)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	29
# 	Name           =	clad_gado
# 	Fill           =	Material 8
# 	Region         =	(53 -54)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	30
# 	Name           =	moderator_gado
# 	Fill           =	Material 9
# 	Region         =	(55 -56 57 -58 54)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	21
# 	Name           =	water_guide
# 	Fill           =	Material 9
# 	Region         =	-40
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	22
# 	Name           =	clad_guide
# 	Fill           =	Material 8
# 	Region         =	(40 -41)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	23
# 	Name           =	moderator_guide
# 	Fill           =	Material 9
# 	Region         =	(42 -43 44 -45 41)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	24
# 	Name           =	water_instru
# 	Fill           =	Material 9
# 	Region         =	-46
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	25
# 	Name           =	clad_instru
# 	Fill           =	Material 8
# 	Region         =	(46 -47)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	26
# 	Name           =	moderator_instru
# 	Fill           =	Material 9
# 	Region         =	(48 -49 50 -51 47)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	31
# 	Name           =	water_outside
# 	Fill           =	Material 9
# 	Region         =	None
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ]
# {'2A': [<openmc.mgxs.library.Library object at 0x16462e6f0>, ['fuel_pincell', 'gap_pincell', 'clad_pincell', 'moderator_pincell', 'water_guide', 'clad_guide', 'moderator_guide', 'water_instru', 'clad_instru', 'moderator_instru', 'water_outside']], '2B': [<openmc.mgxs.library.Library object at 0x166141550>, ['fuel_pincell', 'gap_pincell', 'clad_pincell', 'moderator_pincell', 'water_guide', 'clad_guide', 'moderator_guide', 'water_instru', 'clad_instru', 'moderator_instru', 'water_outside']], '2C': [<openmc.mgxs.library.Library object at 0x164589490>, ['fuel_pincell', 'gap_pincell', 'clad_pincell', 'moderator_pincell', 'water_guide', 'clad_guide', 'moderator_guide', 'water_instru', 'clad_instru', 'moderator_instru', 'water_outside']], '2D': [<openmc.mgxs.library.Library object at 0x16405fa10>, ['fuel_pincell', 'gap_pincell', 'clad_pincell', 'moderator_pincell', 'water_guide', 'clad_guide', 'moderator_guide', 'water_instru', 'clad_instru', 'moderator_instru', 'water_outside']], '2E': [<openmc.mgxs.library.Library object at 0x16462baa0>, ['fuel_pincell_1_family', 'gap_pincell_1_family', 'clad_pincell_1_family', 'moderator_pincell_1_family', 'water_inner_pyrex_1_family', 'inner_steel_pyrex_1_family', 'pyrex_pyrex_1_family', 'outer_steel_pyrex_1_family', 'guide_water_pyrex_1_family', 'guide_pyrex_1_family', 'water_ext_pyrex_1_family', 'water_guide_1_family', 'clad_guide_1_family', 'moderator_guide_1_family', 'water_guide_instru_1_family', 'clad_guide_instru_1_family', 'moderator_instru_1_family', 'water_outside']], '2F': [<openmc.mgxs.library.Library object at 0x165e6c140>, ['fuel_pincell_1_family', 'gap_pincell_1_family', 'clad_pincell_1_family', 'moderator_pincell_1_family', 'water_inner_pyrex_1_family', 'inner_steel_pyrex_1_family', 'pyrex_pyrex_1_family', 'outer_steel_pyrex_1_family', 'guide_water_pyrex_1_family', 'guide_pyrex_1_family', 'water_ext_pyrex_1_family', 'water_instru_1_family', 'clad_instru_1_family', 'moderator_instru_1_family', 'water_outside']], '2G': [<openmc.mgxs.library.Library object at 0x1660fbe30>, ['fuel_pincell_1_family', 'gap_pincell_1_family', 'clad_pincell_1_family', 'moderator_pincell_1_family', 'AIC_aic_1_family', 'gap_aic_1_family', 'clad_aic_1_family', 'guide_aic_1_family', 'moderator_aic_1_family', 'water_guide_instru_1_family', 'clad_guide_instru_1_family', 'moderator_instru_1_family', 'water_outside']], '2H': [<openmc.mgxs.library.Library object at 0x165fa4140>, ['fuel_pincell_1_family', 'gap_pincell_1_family', 'clad_pincell_1_family', 'moderator_pincell_1_family', 'B4C_b4c_1_family', 'gap_b4c_1_family', 'clad_b4c_1_family', 'guide_b4c_1_family', 'moderator_b4c_1_family', 'water_guide_instru_1_family', 'clad_guide_instru_1_family', 'moderator_instru_1_family', 'water_outside']], '2I': [<openmc.mgxs.library.Library object at 0x16464ec00>, ['fuel_pincell_1_family', 'gap_pincell_1_family', 'clad_pincell_1_family', 'moderator_pincell_1_family', 'water_guide_1_family', 'clad_guide_1_family', 'moderator_guide_1_family', 'water_cellinstru_1_family', 'clad_cellinstru_1_family', 'instru_cellinstru_1_family', 'water_outside']], '2J': [<openmc.mgxs.library.Library object at 0x164644800>, ['fuel_pincell_1_family', 'gap_pincell_1_family', 'clad_pincell_1_family', 'moderator_pincell_1_family', 'water_inner_pyrex_1_family', 'inner_steel_pyrex_1_family', 'pyrex_pyrex_1_family', 'outer_steel_pyrex_1_family', 'guide_water_pyrex_1_family', 'guide_pyrex_1_family', 'water_ext_pyrex_1_family', 'water_cellinstru_1_family', 'clad_cellinstru_1_family', 'instru_cellinstru_1_family', 'water_outside']], '2K': [<openmc.mgxs.library.Library object at 0x1640dc1d0>, ['fuel_pincell_low_1_family', 'gap_pincell_low_1_family', 'clad_pincell_low_1_family', 'moderator_pincell_low_1_family', 'fuel_pincell_high_1_family', 'gap_pincell_high_1_family', 'clad_pincell_high_1_family', 'moderator_pincell_high_1_family', 'water_inner_pyrex_1_family', 'inner_steel_pyrex_1_family', 'pyrex_pyrex_1_family', 'outer_steel_pyrex_1_family', 'guide_wat ...

# %% [markdown]
# print(import_dict['2A_1_family'][1])

# %% [markdown]
# ### Post Processing

# %% [markdown]
# def cell_domain(cell,mgxs_lib):
#     for k in range(len(mgxs_lib.domains)):
#         if mgxs_lib.domains[k].name==cell:
#             return(mgxs_lib.domains[k].id)

# %% [markdown]
# def mgxs_value(cell,reaction,mgxs_lib):
#     cell_name=cell
#     cell=cell_domain(cell_name,mgxs_lib)
#     mgxs_plot = mgxs_lib.get_mgxs(cell,reaction)
#     mgxs=mgxs_plot.get_pandas_dataframe(xs_type='macro')['mean'].values
#     return(mgxs)

# %% [markdown]
# def rd_max(mgxs1,mgxs2):
#     avg=0
#     index=0
#     rd_max=0
#     for i in range (171):
#         rd1=0
#         rd2=0
#         if mgxs1[i]!=0:
#             rd1=abs(mgxs1[i]-mgxs2[i])/mgxs1[i]
#         if mgxs2[i]!=0:
#             rd2=abs(mgxs1[i]-mgxs2[i])/mgxs2[i]
#         if rd1>rd_max or rd1>rd_max:
#             rd_max=max(rd1,rd2)
#             index=i
#     return(100*rd_max,index)

# %% [markdown]
# fuel_fission=mgxs_value('fuel_3_5','fission',import_dict['2A_72_families'][0])
# print(fuel_fission)

# %% [markdown]
# choose_group=openmc.mgxs.GROUP_STRUCTURES['XMAS-172']
# name_group='XMAS172'
#
# mgxs1 =mgxs_value('fuel_3_5','fission',import_dict['2A_72_families'][0])
# mgxs2 =mgxs_value('fuel_8_7','fission',import_dict['2A_72_families'][0])
# mgxs3 =mgxs_value('fuel_0_0','fission',import_dict['2A_72_families'][0])
#
#
# fig, ax = plt.subplots()
# ax.step(choose_group[:-1], np.flip(mgxs1), where='post', label='fuel_3_5,fission')
# ax.step(choose_group[:-1], np.flip(mgxs2), where='post', label='fuel_8_7,fission')
# ax.step(choose_group[:-1], np.flip(mgxs3), where='post', label='fuel_0_0,fission')
#
# ax.set_xscale('log')
# ax.set_xlabel('Energy [eV]')
# ax.set_ylabel('MGXS [cm-1]')
# ax.grid()
# # bbox = ax.get_position()
# # ax.text(bbox.x1 - 0.05, bbox.y0 - 0.05, reaction_plot, fontsize=15, color='red', ha='right')
# ax.legend()
# plt.show()

# %%
#pb_load_mgxs('1A')[0].create_mg_library(xs_type='macro', xsdata_names=load_mgxs('1A')[1]).export_to_hdf5('mgxs_1A.h5')
for pb_num in pb_num_list:
    import_dict[pb_num][0].create_mg_library(xs_type='macro', xsdata_names=import_dict[pb_num][1]).export_to_hdf5('mgxs_'+pb_num+'.h5')
