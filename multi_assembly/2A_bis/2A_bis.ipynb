# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)

water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.178E-03 )


model.materials = openmc.Materials([uo2, zirconium, water,helium]) 
#Perso path
#model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel_2B'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap_2B'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad_2B'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator_2B'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_2B'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_2B'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator_2B'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water_2B'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad_2B'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator_2B'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
GT=[(5,2),(8,2),(3,3),(2,5),(5,5),(8,5),(2,8),(5,8)]
IT=[(8,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))
print(np.array(GT_full)+(1,1))
# Out:
# [[ 4 14]
#  [12  3]
#  [12  6]
#  [12  9]
#  [ 3  6]
#  [12 15]
#  [ 3 12]
#  [12 12]
#  [ 3  9]
#  [ 4  4]
#  [ 9  3]
#  [ 9  6]
#  [ 9 12]
#  [ 9 15]
#  [14 14]
#  [15  6]
#  [15 12]
#  [ 6  3]
#  [15  9]
#  [ 6  6]
#  [ 6 12]
#  [ 6  9]
#  [ 6 15]
#  [14  4]]

# %% [markdown]
# ### Create family pincell

# %%
pincell_1_family=pincell('pincell')
guide_1_family=guide('guide')
instru_1_family=instru('instru')

# %% [markdown]
# ### Define assembly

# %%
assembly = openmc.RectLattice()
pitch=1.26

dr=0.04 # cm of water that is outside assembly


size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
assembly.pitch = (pitch,pitch)

assembly.lower_left = (-size/2*pitch, -size/2*pitch)


A= np.empty((size, size), dtype=openmc.universe.Universe)

for ix in range(size):
    for iy in range(size):
        if (ix,iy) in GT_full : 
            A[ix][iy]=guide_1_family[0]
        elif (ix,iy) in IT :
            A[ix][iy]=instru_1_family[0]
        else:
            A[ix][iy]=pincell_1_family[0]    

# print(A)           
            
            

        
assembly.universes = A

moderator_outside = openmc.Cell(name='water_outside')
moderator_outside.fill = water
all_water = openmc.Universe()
all_water.add_cell(moderator_outside)
assembly.outer=all_water

rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size/2*pitch+dr), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size/2*pitch+dr), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=assembly)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z

model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (500, 500)
# plot.width = (pitch_assembly+dr, pitch_assembly+dr)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plots.append(plot)
# model.plots=openmc.Plots(plots)
# #plot.to_ipython_image(openmc_exec='openmc', cwd='/Users/pablogarcia44/repo/perso/openmc/17x17_assembly/vera')

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1600.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1202.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=1210.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-09-13 10:34:13
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.18525
#         2/1    1.16918
#         3/1    1.19073
#         4/1    1.18023
#         5/1    1.19174
#         6/1    1.17791
#         7/1    1.18214
#         8/1    1.17111
#         9/1    1.16951
#        10/1    1.17587
#        11/1    1.17971
#        12/1    1.18004
#        13/1    1.17751
#        14/1    1.18875
#        15/1    1.18739
#        16/1    1.18654
#        17/1    1.17501
#        18/1    1.18500
#        19/1    1.17354
#        20/1    1.17789
#        21/1    1.17750
#        22/1    1.17925    1.17838 +/- 0.00087
#        23/1    1.18153    1.17943 +/- 0.00117
#        24/1    1.17454    1.17821 +/- 0.00148
#        25/1    1.18528    1.17962 +/- 0.00182
#        26/1    1.18155    1.17994 +/- 0.00152
#        27/1    1.18180    1.18021 +/- 0.00131
#        28/1    1.18239    1.18048 +/- 0.00117
#        29/1    1.18456    1.18093 +/- 0.00113
#        30/1    1.17469    1.18031 +/- 0.00118
#        31/1    1.18706    1.18092 +/- 0.00123
#        32/1    1.18717    1.18144 +/- 0.00124
#        33/1    1.17273    1.18077 +/- 0.00132
#        34/1    1.18557    1.18112 +/- 0.00127
#        35/1    1.18100    1.18111 +/- 0.00119
#        36/1    1.18515    1.18136 +/- 0.00114
#        37/1    1.16919    1.18064 +/- 0.00129
#        38/1    1.18433    1.18085 +/- 0.00123
#        39/1    1.18775    1.18121 +/- 0.00122
#        40/1    1.17423    1.18086 +/- 0.00121
#        41/1    1.18750    1.18118 +/- 0.00119
#        42/1    1.20195    1.18212 +/- 0.00148
#        43/1    1.17564    1.18184 +/- 0.00144
#        44/1    1.17754    1.18166 +/- 0.00139
#        45/1    1.18384    1.18175 +/- 0.00134
#        46/1    1.17806    1.18161 +/- 0.00129
#        47/1    1.18574    1.18176 +/- 0.00125
#        48/1    1.18297    1.18180 +/- 0.00121
#        49/1    1.18538    1.18193 +/- 0.00117
#        50/1    1.18842    1.18214 +/- 0.00115
#  Triggers unsatisfied, max unc./thresh. is 8.490961961440608 for eigenvalue
#  The estimated number of batches is 2183
#  Creating state point statepoint.00050.h5...
#        51/1    1.16686    1.18165 +/- 0.00122
#  Triggers unsatisfied, max unc./thresh. is 8.181508711739724 for eigenvalue
#  The estimated number of batches is 2096
#        52/1    1.18327    1.18170 +/- 0.00118
#  Triggers unsatisfied, max unc./thresh. is 7.8902488380436475 for eigenvalue
#  The estimated number of batches is 2013
#        53/1    1.18218    1.18172 +/- 0.00114
#  Triggers unsatisfied, max unc./thresh. is 7.98204739182902 for eigenvalue
#  The estimated number of batches is 2123
#        54/1    1.16966    1.18136 +/- 0.00117
#  Triggers unsatisfied, max unc./thresh. is 7.62694386198012 for eigenvalue
#  The estimated number of batches is 1998
#        55/1    1.16795    1.18098 +/- 0.00119
#  Triggers unsatisfied, max unc./thresh. is 7.483122609903255 for eigenvalue
#  The estimated number of batches is 1980
#        56/1    1.17885    1.18092 +/- 0.00116
#  Triggers unsatisfied, max unc./thresh. is 7.405136292372786 for eigenvalue
#  The estimated number of batches is 1995
#        57/1    1.18172    1.18094 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 7.253963793679787 for eigenvalue
#  The estimated number of batches is 1967
#        58/1    1.18427    1.18103 +/- 0.00110
#  Triggers unsatisfied, max unc./thresh. is 7.115585004667549 for eigenvalue
#  The estimated number of batches is 1944
#        59/1    1.16807    1.18070 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 7.49354685005099 for eigenvalue
#  The estimated number of batches is 2210
#        60/1    1.17024    1.18043 +/- 0.00113
#  Triggers unsatisfied, max unc./thresh. is 7.6441845539948705 for eigenvalue
#  The estimated number of batches is 2358
#        61/1    1.17407    1.18028 +/- 0.00111
#  Triggers unsatisfied, max unc./thresh. is 7.5075918601501765 for eigenvalue
#  The estimated number of batches is 2331
#        62/1    1.17904    1.18025 +/- 0.00108
#  Triggers unsatisfied, max unc./thresh. is 7.319819328577 for eigenvalue
#  The estimated number of batches is 2271
#        63/1    1.17644    1.18016 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 7.306807044459278 for eigenvalue
#  The estimated number of batches is 2316
#        64/1    1.17672    1.18008 +/- 0.00104
#  Triggers unsatisfied, max unc./thresh. is 7.151841829096194 for eigenvalue
#  The estimated number of batches is 2271
#        65/1    1.17643    1.18000 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 6.997304496248591 for eigenvalue
#  The estimated number of batches is 2224
#        66/1    1.18243    1.18005 +/- 0.00100
#  Triggers unsatisfied, max unc./thresh. is 6.834881516584567 for eigenvalue
#  The estimated number of batches is 2169
#        67/1    1.18027    1.18006 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 6.693317271903197 for eigenvalue
#  The estimated number of batches is 2126
#        68/1    1.17538    1.17996 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 6.597448472565852 for eigenvalue
#  The estimated number of batches is 2110
#        69/1    1.17971    1.17996 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 6.469287631877369 for eigenvalue
#  The estimated number of batches is 2071
#        70/1    1.17888    1.17994 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 6.33903729891719 for eigenvalue
#  The estimated number of batches is 2030
#        71/1    1.18492    1.18003 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 6.32620017644373 for eigenvalue
#  The estimated number of batches is 2062
#        72/1    1.18088    1.18005 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 6.296914773160955 for eigenvalue
#  The estimated number of batches is 2082
#        73/1    1.18946    1.18023 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 6.298565044794038 for eigenvalue
#  The estimated number of batches is 2123
#        74/1    1.18448    1.18031 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 6.184133279433083 for eigenvalue
#  The estimated number of batches is 2086
#        75/1    1.17889    1.18028 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 6.070269331588533 for eigenvalue
#  The estimated number of batches is 2047
#        76/1    1.17598    1.18020 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 6.038837978187033 for eigenvalue
#  The estimated number of batches is 2063
#        77/1    1.17257    1.18007 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 5.962160955462599 for eigenvalue
#  The estimated number of batches is 2047
#        78/1    1.18162    1.18010 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 6.068371033900784 for eigenvalue
#  The estimated number of batches is 2156
#        79/1    1.16813    1.17989 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 6.018557543148136 for eigenvalue
#  The estimated number of batches is 2158
#        80/1    1.17289    1.17978 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.997574676091988 for eigenvalue
#  The estimated number of batches is 2179
#        81/1    1.18342    1.17984 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.901750340335055 for eigenvalue
#  The estimated number of batches is 2145
#        82/1    1.19632    1.18010 +/- 0.00086
#  Triggers unsatisfied, max unc./thresh. is 5.865453693359196 for eigenvalue
#  The estimated number of batches is 2154
#        83/1    1.18023    1.18010 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 5.771446280668787 for eigenvalue
#  The estimated number of batches is 2119
#        84/1    1.18466    1.18018 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.673943263174723 for eigenvalue
#  The estimated number of batches is 2081
#        85/1    1.17637    1.18012 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.613634877339431 for eigenvalue
#  The estimated number of batches is 2069
#        86/1    1.18454    1.18018 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.519562476137733 for eigenvalue
#  The estimated number of batches is 2031
#        87/1    1.17819    1.18015 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.438830332043167 for eigenvalue
#  The estimated number of batches is 2002
#        88/1    1.16673    1.17996 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.389221636962284 for eigenvalue
#  The estimated number of batches is 1995
#        89/1    1.18382    1.18001 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.342029451919709 for eigenvalue
#  The estimated number of batches is 1990
#        90/1    1.18300    1.18006 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.280520842483045 for eigenvalue
#  The estimated number of batches is 1972
#        91/1    1.16010    1.17977 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 5.389067514152097 for eigenvalue
#  The estimated number of batches is 2082
#        92/1    1.17604    1.17972 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 5.358484605504709 for eigenvalue
#  The estimated number of batches is 2088
#        93/1    1.17873    1.17971 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 5.392266361400868 for eigenvalue
#  The estimated number of batches is 2143
#        94/1    1.17663    1.17967 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.326967349694095 for eigenvalue
#  The estimated number of batches is 2120
#        95/1    1.16882    1.17952 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 5.272042927740836 for eigenvalue
#  The estimated number of batches is 2105
#        96/1    1.18215    1.17956 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.219235967397826 for eigenvalue
#  The estimated number of batches is 2091
#        97/1    1.18666    1.17965 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 5.15286887881198 for eigenvalue
#  The estimated number of batches is 2065
#        98/1    1.18350    1.17970 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 5.080536417603569 for eigenvalue
#  The estimated number of batches is 2034
#        99/1    1.17798    1.17968 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 5.020853436255613 for eigenvalue
#  The estimated number of batches is 2012
#       100/1    1.17275    1.17959 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.972736741280375 for eigenvalue
#  The estimated number of batches is 1999
#       101/1    1.18421    1.17965 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.956789065745117 for eigenvalue
#  The estimated number of batches is 2011
#       102/1    1.18572    1.17972 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.9167789577764704 for eigenvalue
#  The estimated number of batches is 2003
#       103/1    1.17856    1.17971 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.868313400209384 for eigenvalue
#  The estimated number of batches is 1988
#       104/1    1.17708    1.17968 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.813080668414848 for eigenvalue
#  The estimated number of batches is 1966
#       105/1    1.18158    1.17970 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.75702692702233 for eigenvalue
#  The estimated number of batches is 1944
#       106/1    1.18458    1.17976 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.704436128273161 for eigenvalue
#  The estimated number of batches is 1924
#       107/1    1.17143    1.17966 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.745343322839026 for eigenvalue
#  The estimated number of batches is 1980
#       108/1    1.17943    1.17966 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.6962810945763325 for eigenvalue
#  The estimated number of batches is 1961
#       109/1    1.18042    1.17967 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.659113948246834 for eigenvalue
#  The estimated number of batches is 1952
#       110/1    1.18776    1.17976 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.640574594806128 for eigenvalue
#  The estimated number of batches is 1959
#       111/1    1.16486    1.17959 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.7277907508511 for eigenvalue
#  The estimated number of batches is 2055
#       112/1    1.18084    1.17961 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.674254376993803 for eigenvalue
#  The estimated number of batches is 2031
#       113/1    1.18267    1.17964 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.626157174206279 for eigenvalue
#  The estimated number of batches is 2011
#       114/1    1.17827    1.17962 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.593797694233817 for eigenvalue
#  The estimated number of batches is 2004
#       115/1    1.17973    1.17962 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.557269497426273 for eigenvalue
#  The estimated number of batches is 1994
#       116/1    1.18715    1.17970 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.501837467457124 for eigenvalue
#  The estimated number of batches is 1966
#       117/1    1.18382    1.17975 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.458589663397082 for eigenvalue
#  The estimated number of batches is 1949
#       118/1    1.18010    1.17975 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.41811907639807 for eigenvalue
#  The estimated number of batches is 1933
#       119/1    1.17331    1.17968 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.3834742793777925 for eigenvalue
#  The estimated number of batches is 1923
#       120/1    1.17750    1.17966 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 4.349337474238644 for eigenvalue
#  The estimated number of batches is 1912
#       121/1    1.17879    1.17965 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 4.342345799509438 for eigenvalue
#  The estimated number of batches is 1925
#       122/1    1.17562    1.17961 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.342834461322031 for eigenvalue
#  The estimated number of batches is 1944
#       123/1    1.18319    1.17965 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 4.299808277288048 for eigenvalue
#  The estimated number of batches is 1925
#       124/1    1.17886    1.17964 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.313769894711537 for eigenvalue
#  The estimated number of batches is 1956
#       125/1    1.17721    1.17962 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 4.3468196379042565 for eigenvalue
#  The estimated number of batches is 2004
#       126/1    1.18576    1.17968 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.336792942362984 for eigenvalue
#  The estimated number of batches is 2014
#       127/1    1.17520    1.17963 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.303070627846923 for eigenvalue
#  The estimated number of batches is 2002
#       128/1    1.18247    1.17966 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.262927980577719 for eigenvalue
#  The estimated number of batches is 1983
#       129/1    1.18374    1.17970 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.235138439743945 for eigenvalue
#  The estimated number of batches is 1976
#       130/1    1.18080    1.17971 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.198154249549081 for eigenvalue
#  The estimated number of batches is 1959
#       131/1    1.18732    1.17978 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.216475837406008 for eigenvalue
#  The estimated number of batches is 1994
#       132/1    1.18415    1.17982 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.18332818350953 for eigenvalue
#  The estimated number of batches is 1981
#       133/1    1.18099    1.17983 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.1669119630435505 for eigenvalue
#  The estimated number of batches is 1983
#       134/1    1.18305    1.17985 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.132267887139379 for eigenvalue
#  The estimated number of batches is 1967
#       135/1    1.17540    1.17982 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.18174306681929 for eigenvalue
#  The estimated number of batches is 2032
#       136/1    1.18940    1.17990 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.17044967249243 for eigenvalue
#  The estimated number of batches is 2038
#       137/1    1.17274    1.17984 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 4.134512795183247 for eigenvalue
#  The estimated number of batches is 2021
#       138/1    1.16712    1.17973 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.103345919336017 for eigenvalue
#  The estimated number of batches is 2007
#       139/1    1.18551    1.17978 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 4.070738188407832 for eigenvalue
#  The estimated number of batches is 1992
#       140/1    1.20438    1.17998 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 4.1229104742565665 for eigenvalue
#  The estimated number of batches is 2060
#       141/1    1.17805    1.17997 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.104049462858922 for eigenvalue
#  The estimated number of batches is 2059
#       142/1    1.18182    1.17998 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 4.072331375183662 for eigenvalue
#  The estimated number of batches is 2044
#       143/1    1.18637    1.18003 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.040237500574046 for eigenvalue
#  The estimated number of batches is 2028
#       144/1    1.17424    1.17999 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.025368764164549 for eigenvalue
#  The estimated number of batches is 2030
#       145/1    1.18862    1.18006 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 4.004276751978143 for eigenvalue
#  The estimated number of batches is 2025
#       146/1    1.18288    1.18008 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.9746401940443206 for eigenvalue
#  The estimated number of batches is 2011
#       147/1    1.18135    1.18009 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.942011253563413 for eigenvalue
#  The estimated number of batches is 1994
#       148/1    1.18606    1.18014 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.9307390153914112 for eigenvalue
#  The estimated number of batches is 1998
#       149/1    1.17731    1.18011 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.904393151339626 for eigenvalue
#  The estimated number of batches is 1987
#       150/1    1.18049    1.18012 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.8844111479296655 for eigenvalue
#  The estimated number of batches is 1982
#       151/1    1.17441    1.18007 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.8814979434727386 for eigenvalue
#  The estimated number of batches is 1994
#       152/1    1.17726    1.18005 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.860347633426354 for eigenvalue
#  The estimated number of batches is 1988
#       153/1    1.18355    1.18008 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8268905509731517 for eigenvalue
#  The estimated number of batches is 1968
#       154/1    1.17541    1.18004 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.810212790619197 for eigenvalue
#  The estimated number of batches is 1966
#       155/1    1.18234    1.18006 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.786076244497605 for eigenvalue
#  The estimated number of batches is 1956
#       156/1    1.17127    1.18000 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.8336889350448495 for eigenvalue
#  The estimated number of batches is 2019
#       157/1    1.16384    1.17988 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.8635294435692544 for eigenvalue
#  The estimated number of batches is 2065
#       158/1    1.18217    1.17989 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.837592508455435 for eigenvalue
#  The estimated number of batches is 2053
#       159/1    1.18040    1.17990 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.8134501561012244 for eigenvalue
#  The estimated number of batches is 2042
#       160/1    1.16934    1.17982 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.8375481846023423 for eigenvalue
#  The estimated number of batches is 2082
#       161/1    1.17950    1.17982 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.8136466477428845 for eigenvalue
#  The estimated number of batches is 2071
#       162/1    1.17619    1.17979 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.793174683362123 for eigenvalue
#  The estimated number of batches is 2064
#       163/1    1.18962    1.17986 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.7800727317673473 for eigenvalue
#  The estimated number of batches is 2064
#       164/1    1.18375    1.17989 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.751576837339974 for eigenvalue
#  The estimated number of batches is 2047
#       165/1    1.17340    1.17985 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.7305778326822114 for eigenvalue
#  The estimated number of batches is 2038
#       166/1    1.18369    1.17987 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.7070652102870065 for eigenvalue
#  The estimated number of batches is 2027
#       167/1    1.18562    1.17991 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.7715771927334494 for eigenvalue
#  The estimated number of batches is 2112
#       168/1    1.18744    1.17996 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.7469732899331754 for eigenvalue
#  The estimated number of batches is 2098
#       169/1    1.17921    1.17996 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.7346552948654477 for eigenvalue
#  The estimated number of batches is 2099
#       170/1    1.18714    1.18000 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.7154191251744524 for eigenvalue
#  The estimated number of batches is 2091
#       171/1    1.19203    1.18008 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.766735242089064 for eigenvalue
#  The estimated number of batches is 2163
#       172/1    1.19039    1.18015 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.7699223761818184 for eigenvalue
#  The estimated number of batches is 2181
#       173/1    1.17842    1.18014 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.788932080711401 for eigenvalue
#  The estimated number of batches is 2217
#       174/1    1.18828    1.18019 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.803678969975313 for eigenvalue
#  The estimated number of batches is 2249
#       175/1    1.17447    1.18016 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.8320932125443647 for eigenvalue
#  The estimated number of batches is 2297
#       176/1    1.18557    1.18019 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8207075707080724 for eigenvalue
#  The estimated number of batches is 2298
#       177/1    1.17384    1.18015 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.8242305836289914 for eigenvalue
#  The estimated number of batches is 2317
#       178/1    1.18073    1.18015 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.7967507205420707 for eigenvalue
#  The estimated number of batches is 2298
#       179/1    1.18006    1.18015 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.7692278531072834 for eigenvalue
#  The estimated number of batches is 2279
#       180/1    1.18366    1.18018 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.7481463700370163 for eigenvalue
#  The estimated number of batches is 2268
#       181/1    1.18316    1.18019 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.7325757875926526 for eigenvalue
#  The estimated number of batches is 2264
#       182/1    1.17322    1.18015 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.7100447092327884 for eigenvalue
#  The estimated number of batches is 2250
#       183/1    1.17250    1.18010 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.6955082034132696 for eigenvalue
#  The estimated number of batches is 2247
#       184/1    1.17222    1.18006 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.6800511610891764 for eigenvalue
#  The estimated number of batches is 2242
#       185/1    1.17525    1.18003 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.659446128020831 for eigenvalue
#  The estimated number of batches is 2230
#       186/1    1.18328    1.18005 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.6343272362749675 for eigenvalue
#  The estimated number of batches is 2213
#       187/1    1.19117    1.18011 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.6197175562143302 for eigenvalue
#  The estimated number of batches is 2209
#       188/1    1.18764    1.18016 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.609082413454216 for eigenvalue
#  The estimated number of batches is 2209
#       189/1    1.18098    1.18016 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.5858979041988346 for eigenvalue
#  The estimated number of batches is 2194
#       190/1    1.19145    1.18023 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.58402716693217 for eigenvalue
#  The estimated number of batches is 2204
#       191/1    1.18836    1.18028 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.572164597680644 for eigenvalue
#  The estimated number of batches is 2203
#       192/1    1.18182    1.18029 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.5787050115827594 for eigenvalue
#  The estimated number of batches is 2223
#       193/1    1.17437    1.18025 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.5736406486978494 for eigenvalue
#  The estimated number of batches is 2230
#       194/1    1.17595    1.18023 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.556390206982894 for eigenvalue
#  The estimated number of batches is 2221
#       195/1    1.18515    1.18026 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.5367019630868897 for eigenvalue
#  The estimated number of batches is 2209
#       196/1    1.17931    1.18025 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.5160863680143715 for eigenvalue
#  The estimated number of batches is 2196
#       197/1    1.17590    1.18023 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.5048463326870847 for eigenvalue
#  The estimated number of batches is 2195
#       198/1    1.17976    1.18022 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.4891524708572517 for eigenvalue
#  The estimated number of batches is 2188
#       199/1    1.18376    1.18024 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.488761532692647 for eigenvalue
#  The estimated number of batches is 2199
#       200/1    1.18181    1.18025 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.4697097129190047 for eigenvalue
#  The estimated number of batches is 2187
#       201/1    1.17627    1.18023 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.4536239235982165 for eigenvalue
#  The estimated number of batches is 2179
#       202/1    1.18073    1.18023 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.433044983610442 for eigenvalue
#  The estimated number of batches is 2166
#       203/1    1.18125    1.18024 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.417991049816316 for eigenvalue
#  The estimated number of batches is 2158
#       204/1    1.19083    1.18030 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.4113994599837283 for eigenvalue
#  The estimated number of batches is 2162
#       205/1    1.17668    1.18028 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.391576278102094 for eigenvalue
#  The estimated number of batches is 2149
#       206/1    1.18381    1.18029 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.373825907984137 for eigenvalue
#  The estimated number of batches is 2138
#       207/1    1.18213    1.18030 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.369690690057514 for eigenvalue
#  The estimated number of batches is 2144
#       208/1    1.18405    1.18032 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.370799779732733 for eigenvalue
#  The estimated number of batches is 2157
#       209/1    1.17328    1.18029 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.3582520900051076 for eigenvalue
#  The estimated number of batches is 2152
#       210/1    1.18722    1.18032 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.340956190630049 for eigenvalue
#  The estimated number of batches is 2141
#       211/1    1.18439    1.18034 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.3209124954313833 for eigenvalue
#  The estimated number of batches is 2127
#       212/1    1.16918    1.18029 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.3071375024684975 for eigenvalue
#  The estimated number of batches is 2120
#       213/1    1.18606    1.18032 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.3133878208906085 for eigenvalue
#  The estimated number of batches is 2139
#       214/1    1.16737    1.18025 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.301217213076507 for eigenvalue
#  The estimated number of batches is 2135
#       215/1    1.17313    1.18021 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.316439032536472 for eigenvalue
#  The estimated number of batches is 2165
#       216/1    1.17305    1.18018 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.305643795740627 for eigenvalue
#  The estimated number of batches is 2162
#       217/1    1.17979    1.18017 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.301174665843485 for eigenvalue
#  The estimated number of batches is 2167
#       218/1    1.19422    1.18025 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.3155094235315503 for eigenvalue
#  The estimated number of batches is 2197
#       219/1    1.18645    1.18028 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.2979696672669436 for eigenvalue
#  The estimated number of batches is 2185
#       220/1    1.16934    1.18022 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.282994004339061 for eigenvalue
#  The estimated number of batches is 2176
#       221/1    1.18125    1.18023 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.268657126017143 for eigenvalue
#  The estimated number of batches is 2168
#       222/1    1.18012    1.18023 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.252641577228888 for eigenvalue
#  The estimated number of batches is 2158
#       223/1    1.18331    1.18024 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.2448489683417985 for eigenvalue
#  The estimated number of batches is 2158
#       224/1    1.18555    1.18027 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.230409944870971 for eigenvalue
#  The estimated number of batches is 2149
#       225/1    1.18900    1.18031 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.2212889801753186 for eigenvalue
#  The estimated number of batches is 2148
#       226/1    1.18967    1.18036 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.2185562664328002 for eigenvalue
#  The estimated number of batches is 2154
#       227/1    1.17731    1.18034 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.2027807046477252 for eigenvalue
#  The estimated number of batches is 2144
#       228/1    1.18169    1.18035 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.201578211504868 for eigenvalue
#  The estimated number of batches is 2153
#       229/1    1.17178    1.18031 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1881777685773285 for eigenvalue
#  The estimated number of batches is 2145
#       230/1    1.18461    1.18033 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1814438614119798 for eigenvalue
#  The estimated number of batches is 2146
#       231/1    1.19671    1.18040 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.219331388153678 for eigenvalue
#  The estimated number of batches is 2207
#       232/1    1.18090    1.18041 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.210507527041527 for eigenvalue
#  The estimated number of batches is 2206
#       233/1    1.17948    1.18040 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.194439453229861 for eigenvalue
#  The estimated number of batches is 2194
#       234/1    1.17954    1.18040 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1814876150442997 for eigenvalue
#  The estimated number of batches is 2187
#       235/1    1.17350    1.18037 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1682762095815726 for eigenvalue
#  The estimated number of batches is 2179
#       236/1    1.19637    1.18044 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.155882048136777 for eigenvalue
#  The estimated number of batches is 2172
#       237/1    1.19018    1.18049 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1548374092872065 for eigenvalue
#  The estimated number of batches is 2180
#       238/1    1.18502    1.18051 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.145459855703502 for eigenvalue
#  The estimated number of batches is 2177
#       239/1    1.18585    1.18053 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.131626556126699 for eigenvalue
#  The estimated number of batches is 2168
#       240/1    1.18107    1.18053 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.1238239337753737 for eigenvalue
#  The estimated number of batches is 2167
#       241/1    1.17937    1.18053 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.114773034764906 for eigenvalue
#  The estimated number of batches is 2165
#       242/1    1.18419    1.18054 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.1128888478736707 for eigenvalue
#  The estimated number of batches is 2172
#       243/1    1.18941    1.18058 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.105564230165094 for eigenvalue
#  The estimated number of batches is 2171
#       244/1    1.18352    1.18060 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0939089550949643 for eigenvalue
#  The estimated number of batches is 2165
#       245/1    1.18868    1.18063 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0819835937022253 for eigenvalue
#  The estimated number of batches is 2158
#       246/1    1.18351    1.18065 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.075628304680497 for eigenvalue
#  The estimated number of batches is 2158
#       247/1    1.19169    1.18069 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0685903537592805 for eigenvalue
#  The estimated number of batches is 2158
#       248/1    1.18062    1.18069 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0533341840508412 for eigenvalue
#  The estimated number of batches is 2146
#       249/1    1.18145    1.18070 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.04403185608021 for eigenvalue
#  The estimated number of batches is 2142
#       250/1    1.17828    1.18069 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0328708740029615 for eigenvalue
#  The estimated number of batches is 2136
#       251/1    1.18242    1.18069 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.0233003113138843 for eigenvalue
#  The estimated number of batches is 2132
#       252/1    1.17993    1.18069 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.010576353297382 for eigenvalue
#  The estimated number of batches is 2123
#       253/1    1.18130    1.18069 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 3.0053846646924773 for eigenvalue
#  The estimated number of batches is 2125
#       254/1    1.18054    1.18069 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.993882515804774 for eigenvalue
#  The estimated number of batches is 2118
#       255/1    1.18676    1.18072 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9844769011114707 for eigenvalue
#  The estimated number of batches is 2114
#       256/1    1.17640    1.18070 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9706166427850045 for eigenvalue
#  The estimated number of batches is 2103
#       257/1    1.18940    1.18074 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.975167273640745 for eigenvalue
#  The estimated number of batches is 2118
#       258/1    1.17834    1.18073 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9611552426671004 for eigenvalue
#  The estimated number of batches is 2107
#       259/1    1.18808    1.18076 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.951185659165202 for eigenvalue
#  The estimated number of batches is 2102
#       260/1    1.19213    1.18081 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9446656428845066 for eigenvalue
#  The estimated number of batches is 2102
#       261/1    1.18364    1.18082 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9339758421018702 for eigenvalue
#  The estimated number of batches is 2095
#       262/1    1.18241    1.18082 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.922425209727995 for eigenvalue
#  The estimated number of batches is 2087
#       263/1    1.17993    1.18082 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9156907443962004 for eigenvalue
#  The estimated number of batches is 2086
#       264/1    1.17982    1.18082 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9051638648755853 for eigenvalue
#  The estimated number of batches is 2080
#       265/1    1.17634    1.18080 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.893150832515548 for eigenvalue
#  The estimated number of batches is 2071
#       266/1    1.17797    1.18079 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8809168669490535 for eigenvalue
#  The estimated number of batches is 2062
#       267/1    1.18605    1.18081 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8731138885341467 for eigenvalue
#  The estimated number of batches is 2059
#       268/1    1.18624    1.18083 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8629670576804696 for eigenvalue
#  The estimated number of batches is 2053
#       269/1    1.17882    1.18082 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.857287760364422 for eigenvalue
#  The estimated number of batches is 2053
#       270/1    1.18840    1.18085 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.846380339014999 for eigenvalue
#  The estimated number of batches is 2046
#       271/1    1.18147    1.18085 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8467445199901675 for eigenvalue
#  The estimated number of batches is 2055
#       272/1    1.17765    1.18084 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.835323640529302 for eigenvalue
#  The estimated number of batches is 2046
#       273/1    1.18565    1.18086 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8407024620001184 for eigenvalue
#  The estimated number of batches is 2062
#       274/1    1.17339    1.18083 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.833266278417574 for eigenvalue
#  The estimated number of batches is 2059
#       275/1    1.18621    1.18085 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.822800910589501 for eigenvalue
#  The estimated number of batches is 2052
#       276/1    1.17029    1.18081 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.814766157589063 for eigenvalue
#  The estimated number of batches is 2049
#       277/1    1.18792    1.18084 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.816594909318152 for eigenvalue
#  The estimated number of batches is 2059
#       278/1    1.17399    1.18081 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8053671517393663 for eigenvalue
#  The estimated number of batches is 2051
#       279/1    1.18906    1.18084 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.8030169205079436 for eigenvalue
#  The estimated number of batches is 2055
#       280/1    1.18297    1.18085 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.791204379491433 for eigenvalue
#  The estimated number of batches is 2046
#       281/1    1.17169    1.18082 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.782624459025729 for eigenvalue
#  The estimated number of batches is 2041
#       282/1    1.17719    1.18080 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.787831216822384 for eigenvalue
#  The estimated number of batches is 2057
#       283/1    1.18276    1.18081 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7781960766388503 for eigenvalue
#  The estimated number of batches is 2050
#       284/1    1.17248    1.18078 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7707481663410185 for eigenvalue
#  The estimated number of batches is 2047
#       285/1    1.17976    1.18078 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7640534995037886 for eigenvalue
#  The estimated number of batches is 2045
#       286/1    1.17829    1.18077 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.755644468591493 for eigenvalue
#  The estimated number of batches is 2040
#       287/1    1.17539    1.18075 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.74477329505263 for eigenvalue
#  The estimated number of batches is 2032
#       288/1    1.17172    1.18071 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7349247588374492 for eigenvalue
#  The estimated number of batches is 2025
#       289/1    1.18691    1.18074 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.732808289706493 for eigenvalue
#  The estimated number of batches is 2029
#       290/1    1.17641    1.18072 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7212358343952223 for eigenvalue
#  The estimated number of batches is 2020
#       291/1    1.18620    1.18074 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.7134889740261143 for eigenvalue
#  The estimated number of batches is 2016
#       292/1    1.17482    1.18072 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.706999921076689 for eigenvalue
#  The estimated number of batches is 2014
#       293/1    1.18985    1.18075 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.70604720804282 for eigenvalue
#  The estimated number of batches is 2020
#       294/1    1.18802    1.18078 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.695660163816448 for eigenvalue
#  The estimated number of batches is 2012
#       295/1    1.18875    1.18081 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6866471433122823 for eigenvalue
#  The estimated number of batches is 2005
#       296/1    1.16998    1.18077 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.678991701633057 for eigenvalue
#  The estimated number of batches is 2001
#       297/1    1.17138    1.18073 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6850491948536943 for eigenvalue
# ...
#      1573/1    1.16660    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0337502564777705 for eigenvalue
#  The estimated number of batches is 1680
#      1574/1    1.18219    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0331412204821862 for eigenvalue
#  The estimated number of batches is 1679
#      1575/1    1.18593    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0324938695014043 for eigenvalue
#  The estimated number of batches is 1678
#      1576/1    1.17471    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0323299596346203 for eigenvalue
#  The estimated number of batches is 1679
#      1577/1    1.18356    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0319337623757217 for eigenvalue
#  The estimated number of batches is 1679
#      1578/1    1.17961    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0314069285699745 for eigenvalue
#  The estimated number of batches is 1678
#      1579/1    1.17629    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0307310839425903 for eigenvalue
#  The estimated number of batches is 1677
#      1580/1    1.18284    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0303238734958584 for eigenvalue
#  The estimated number of batches is 1677
#      1581/1    1.18425    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0296740547725856 for eigenvalue
#  The estimated number of batches is 1676
#      1582/1    1.16939    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0289949158415455 for eigenvalue
#  The estimated number of batches is 1674
#      1583/1    1.18006    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0284190907659836 for eigenvalue
#  The estimated number of batches is 1674
#      1584/1    1.18172    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.027790644662657 for eigenvalue
#  The estimated number of batches is 1673
#      1585/1    1.17679    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0274002308561037 for eigenvalue
#  The estimated number of batches is 1672
#      1586/1    1.17895    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0268245381700587 for eigenvalue
#  The estimated number of batches is 1672
#      1587/1    1.19171    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0266836939125787 for eigenvalue
#  The estimated number of batches is 1672
#      1588/1    1.18493    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0263812448754746 for eigenvalue
#  The estimated number of batches is 1672
#      1589/1    1.17525    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0259122864890318 for eigenvalue
#  The estimated number of batches is 1672
#      1590/1    1.17413    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0261505670575863 for eigenvalue
#  The estimated number of batches is 1674
#      1591/1    1.19542    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.025960729171348 for eigenvalue
#  The estimated number of batches is 1674
#      1592/1    1.19599    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0263800627345756 for eigenvalue
#  The estimated number of batches is 1677
#      1593/1    1.18154    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0257639602227309 for eigenvalue
#  The estimated number of batches is 1676
#      1594/1    1.18177    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0252171511310297 for eigenvalue
#  The estimated number of batches is 1675
#      1595/1    1.18090    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0246719533495898 for eigenvalue
#  The estimated number of batches is 1674
#      1596/1    1.17261    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0241027979857433 for eigenvalue
#  The estimated number of batches is 1673
#      1597/1    1.18651    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0235753921377349 for eigenvalue
#  The estimated number of batches is 1673
#      1598/1    1.18396    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0236415483774943 for eigenvalue
#  The estimated number of batches is 1674
#      1599/1    1.17271    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0236680119576405 for eigenvalue
#  The estimated number of batches is 1675
#      1600/1    1.18868    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0233285175653009 for eigenvalue
#  The estimated number of batches is 1675
#      1601/1    1.18334    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0227673778759052 for eigenvalue
#  The estimated number of batches is 1674
#      1602/1    1.17248    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0225687966311694 for eigenvalue
#  The estimated number of batches is 1675
#      1603/1    1.17636    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0219097229708791 for eigenvalue
#  The estimated number of batches is 1674
#      1604/1    1.17664    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0212520482962053 for eigenvalue
#  The estimated number of batches is 1673
#      1605/1    1.17944    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0206420477097542 for eigenvalue
#  The estimated number of batches is 1672
#      1606/1    1.16996    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0200784837636172 for eigenvalue
#  The estimated number of batches is 1671
#      1607/1    1.17657    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0204219131672243 for eigenvalue
#  The estimated number of batches is 1673
#      1608/1    1.18174    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0198002195332923 for eigenvalue
#  The estimated number of batches is 1672
#      1609/1    1.17282    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.020520459860687 for eigenvalue
#  The estimated number of batches is 1675
#      1610/1    1.17228    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0201656158619374 for eigenvalue
#  The estimated number of batches is 1675
#      1611/1    1.16997    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01994132073528 for eigenvalue
#  The estimated number of batches is 1676
#      1612/1    1.18597    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0193090547841683 for eigenvalue
#  The estimated number of batches is 1675
#      1613/1    1.17804    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0188992671660286 for eigenvalue
#  The estimated number of batches is 1674
#      1614/1    1.18087    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0182966574988428 for eigenvalue
#  The estimated number of batches is 1673
#      1615/1    1.17905    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017670662090439 for eigenvalue
#  The estimated number of batches is 1672
#      1616/1    1.18020    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.017041600552641 for eigenvalue
#  The estimated number of batches is 1671
#      1617/1    1.18338    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0171857063950231 for eigenvalue
#  The estimated number of batches is 1673
#      1618/1    1.18071    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.016564157496986 for eigenvalue
#  The estimated number of batches is 1672
#      1619/1    1.18272    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0159908670397642 for eigenvalue
#  The estimated number of batches is 1671
#      1620/1    1.18648    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0153893921935808 for eigenvalue
#  The estimated number of batches is 1670
#      1621/1    1.17732    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0147968416398991 for eigenvalue
#  The estimated number of batches is 1669
#      1622/1    1.17582    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0141571466405894 for eigenvalue
#  The estimated number of batches is 1668
#      1623/1    1.17513    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0135115223452593 for eigenvalue
#  The estimated number of batches is 1667
#      1624/1    1.18141    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0130824011527273 for eigenvalue
#  The estimated number of batches is 1667
#      1625/1    1.17365    1.18090 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0125127472353472 for eigenvalue
#  The estimated number of batches is 1666
#      1626/1    1.17750    1.18090 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0118655531073788 for eigenvalue
#  The estimated number of batches is 1665
#      1627/1    1.19530    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01127921575163 for eigenvalue
#  The estimated number of batches is 1664
#      1628/1    1.18253    1.18091 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0107430028880684 for eigenvalue
#  The estimated number of batches is 1663
#      1629/1    1.19189    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0115402486219645 for eigenvalue
#  The estimated number of batches is 1667
#      1630/1    1.18621    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0110052050815181 for eigenvalue
#  The estimated number of batches is 1666
#      1631/1    1.17799    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.010412690155428 for eigenvalue
#  The estimated number of batches is 1665
#      1632/1    1.18356    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009806023392841 for eigenvalue
#  The estimated number of batches is 1664
#      1633/1    1.18553    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.009634570608612 for eigenvalue
#  The estimated number of batches is 1665
#      1634/1    1.18254    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0090285439946416 for eigenvalue
#  The estimated number of batches is 1664
#      1635/1    1.17325    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0083669987077144 for eigenvalue
#  The estimated number of batches is 1663
#      1636/1    1.18916    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0079330999998741 for eigenvalue
#  The estimated number of batches is 1662
#      1637/1    1.17996    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0073099429608556 for eigenvalue
#  The estimated number of batches is 1661
#      1638/1    1.17107    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0075016384289803 for eigenvalue
#  The estimated number of batches is 1663
#      1639/1    1.18844    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0069306220159646 for eigenvalue
#  The estimated number of batches is 1662
#      1640/1    1.18107    1.18092 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0064407557632784 for eigenvalue
#  The estimated number of batches is 1661
#      1641/1    1.18723    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0061385997007248 for eigenvalue
#  The estimated number of batches is 1661
#      1642/1    1.19618    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0057030717386304 for eigenvalue
#  The estimated number of batches is 1661
#      1643/1    1.18446    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0056687149716228 for eigenvalue
#  The estimated number of batches is 1662
#      1644/1    1.18938    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.005428256396888 for eigenvalue
#  The estimated number of batches is 1662
#      1645/1    1.17510    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0049873563943306 for eigenvalue
#  The estimated number of batches is 1662
#      1646/1    1.17621    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0043751079354755 for eigenvalue
#  The estimated number of batches is 1661
#      1647/1    1.18453    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.003877778214523 for eigenvalue
#  The estimated number of batches is 1660
#      1648/1    1.18545    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0032979897325898 for eigenvalue
#  The estimated number of batches is 1659
#      1649/1    1.18181    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.002730256821986 for eigenvalue
#  The estimated number of batches is 1658
#      1650/1    1.17101    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0024975558168499 for eigenvalue
#  The estimated number of batches is 1659
#      1651/1    1.17642    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0021760606712748 for eigenvalue
#  The estimated number of batches is 1659
#      1652/1    1.18154    1.18093 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0018353026069327 for eigenvalue
#  The estimated number of batches is 1658
#      1653/1    1.19072    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0012992560595892 for eigenvalue
#  The estimated number of batches is 1658
#      1654/1    1.18493    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0006930746630036 for eigenvalue
#  The estimated number of batches is 1657
#      1655/1    1.17356    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.002232634643054 for eigenvalue
#  The estimated number of batches is 1663
#      1656/1    1.18520    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0016303450967616 for eigenvalue
#  The estimated number of batches is 1662
#      1657/1    1.18792    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.001434634876888 for eigenvalue
#  The estimated number of batches is 1662
#      1658/1    1.18260    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000827722517718 for eigenvalue
#  The estimated number of batches is 1661
#      1659/1    1.17647    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000215891591229 for eigenvalue
#  The estimated number of batches is 1660
#      1660/1    1.18505    1.18095 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0004333680043993 for eigenvalue
#  The estimated number of batches is 1662
#      1661/1    1.16849    1.18094 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0000425712157595 for eigenvalue
#  The estimated number of batches is 1662
#      1662/1    1.17810    1.18094 +/- 0.00016
#  Triggers satisfied for batch 1662
#  Creating state point statepoint.01662.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.4775e+00 seconds
#    Reading cross sections          = 9.3108e+00 seconds
#  Total time in simulation          = 2.4996e+03 seconds
#    Time in transport only          = 2.4577e+03 seconds
#    Time in inactive batches        = 3.9381e+01 seconds
#    Time in active batches          = 2.4602e+03 seconds
#    Time synchronizing fission bank = 5.4548e+00 seconds
#      Sampling source sites         = 4.5019e+00 seconds
#      SEND/RECV source sites        = 9.5135e-01 seconds
#    Time accumulating tallies       = 3.3078e+01 seconds
#    Time writing statepoints        = 5.5488e-01 seconds
#  Total time for finalization       = 1.0064e+01 seconds
#  Total time elapsed                = 2.5194e+03 seconds
#  Calculation Rate (inactive)       = 25393.3 particles/second
#  Calculation Rate (active)         = 33370.7 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18088 +/- 0.00014
#  k-effective (Track-length)  = 1.18094 +/- 0.00016
#  k-effective (Absorption)    = 1.18072 +/- 0.00011
#  Combined k-effective        = 1.18079 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
