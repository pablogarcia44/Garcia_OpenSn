# %% [markdown]
# # 3x3 assembly inputfile that:

# %% [markdown]
# ### Import module/Set up XS path/Create openMC model/Clean directory

# %%
import sys
import os 
import openmc
import numpy as np
import matplotlib.pyplot as plt
import openmc.mgxs as mgxs
import pandas as pd
from IPython.display import Image
import glob

# %% [markdown]
# ### Pablo environnement

# %%
model=openmc.Model()

clean_file_list = ["model.xml", "materials.xml", "geometry.xml","plots.xml","geometry.xml","settings.xml","tallies.out","summary.h5","statepoint.50.h5"]
for file in clean_file_list :
    path_file = os.path.join(os.getcwd(), file)
    if os.path.exists(path_file):
        os.remove(path_file)

# %% [markdown]
# ### Define Materials

# %%
uo2 = openmc.Material(name='uo2')
uo2.add_nuclide('U234', 6.11864E-06, 'ao')
uo2.add_nuclide('U235', 7.18132E-04, 'ao')
uo2.add_nuclide('U236', 3.29861E-06, 'ao')
uo2.add_nuclide('U238', 2.21546E-02, 'ao')
uo2.add_nuclide('O16', 4.57642E-02, 'ao')
uo2.set_density('g/cm3', 10.257 )
uo2.temperature=600

zirconium = openmc.Material(name="zirconium")
zirconium.add_nuclide('Zr90', 2.18865E-02, 'ao')
zirconium.add_nuclide('Zr91', 4.77292E-03, 'ao')
zirconium.add_nuclide('Zr92', 7.29551E-03, 'ao')
zirconium.add_nuclide('Zr94', 7.39335E-03, 'ao')
zirconium.add_nuclide('Zr96', 1.19110E-03, 'ao')
zirconium.add_nuclide('Sn112',4.68066E-06, 'ao')
zirconium.add_nuclide('Sn114', 3.18478E-06, 'ao')
zirconium.add_nuclide('Sn115', 1.64064E-06, 'ao')
zirconium.add_nuclide('Sn116', 7.01616E-05, 'ao')
zirconium.add_nuclide('Sn117', 3.70592E-05, 'ao')
zirconium.add_nuclide('Sn118', 1.16872E-04, 'ao')
zirconium.add_nuclide('Sn119', 4.14504E-05, 'ao')
zirconium.add_nuclide('Sn120', 1.57212E-04, 'ao')
zirconium.add_nuclide('Sn122', 2.23417E-05, 'ao')
zirconium.add_nuclide('Sn124', 2.79392E-05, 'ao')
zirconium.add_nuclide('Fe54', 8.68307E-06, 'ao')
zirconium.add_nuclide('Fe56', 1.36306E-04, 'ao')
zirconium.add_nuclide('Fe57', 3.14789E-06, 'ao')
zirconium.add_nuclide('Fe58', 4.18926E-07, 'ao')
zirconium.add_nuclide('Cr50', 3.30121E-06, 'ao')
zirconium.add_nuclide('Cr52', 6.36606E-05, 'ao')
zirconium.add_nuclide('Cr53', 7.21860E-06, 'ao')
zirconium.add_nuclide('Cr54', 1.79686E-06, 'ao')
zirconium.add_nuclide('Hf174', 3.54138E-09, 'ao')
zirconium.add_nuclide('Hf176', 1.16423E-07, 'ao')
zirconium.add_nuclide('Hf177', 4.11686E-07, 'ao')
zirconium.add_nuclide('Hf178', 6.03806E-07, 'ao')
zirconium.add_nuclide('Hf179', 3.01460E-07, 'ao')
zirconium.add_nuclide('Hf180', 7.76449E-07, 'ao')
zirconium.set_density('g/cm3',  6.56)

water = openmc.Material(name="water")
water.add_nuclide('H1',4.96224E-02, 'ao')
water.add_nuclide('O16', 2.48112E-02, 'ao')
water.add_nuclide('B10', 1.07070E-05, 'ao')
water.add_nuclide('B11', 4.30971E-05, 'ao')
water.temperature=600
water.set_density('g/cm3', 0.743)
water.add_s_alpha_beta('c_H_in_H2O')

helium = openmc.Material(name="helium")
helium.add_nuclide('He4',1, 'ao')
helium.temperature=600
helium.set_density('g/cm3', 0.178E-03 )

SS304 = openmc.Material(name="SS304")
SS304.add_nuclide('C0',3.20895E-04, 'ao')
SS304.add_nuclide('Si28',1.58197E-03, 'ao')
SS304.add_nuclide('Si29',8.03653E-05, 'ao')
SS304.add_nuclide('Si30',5.30394E-05, 'ao')
SS304.add_nuclide('P31',6.99938E-05, 'ao')
SS304.add_nuclide('Cr50',7.64915E-04, 'ao')
SS304.add_nuclide('Cr52',1.47506E-02, 'ao')
SS304.add_nuclide('Cr53',1.67260E-03, 'ao')
SS304.add_nuclide('Cr54',4.16346E-04, 'ao')
SS304.add_nuclide('Mn55',1.75387E-03, 'ao')
SS304.add_nuclide('Fe54',3.44776E-03, 'ao')
SS304.add_nuclide('Fe56',5.41225E-02, 'ao')
SS304.add_nuclide('Fe57',1.24992E-03, 'ao')
SS304.add_nuclide('Fe58',1.66342E-04, 'ao')
SS304.add_nuclide('Ni58',5.30854E-03, 'ao')
SS304.add_nuclide('Ni60',2.04484E-03, 'ao')
SS304.add_nuclide('Ni61',8.88879E-05, 'ao')
SS304.add_nuclide('Ni62',2.83413E-04, 'ao')
SS304.add_nuclide('Ni64',7.21770E-05, 'ao')
SS304.set_density('g/cm3', 8.00 )
SS304.temperature=600

B4C_mat = openmc.Material(name="B4C_mat")
B4C_mat.add_nuclide('B10',1.52689E-02, 'ao')
B4C_mat.add_nuclide('B11',6.14591E-02, 'ao')
B4C_mat.add_nuclide('C0',1.91820E-02, 'ao')
B4C_mat.set_density('g/cm3', 1.76  )
B4C_mat.temperature=600


model.materials = openmc.Materials([uo2, zirconium, water,helium,SS304,B4C_mat]) 
#Perso path
# model.materials.cross_sections = '/home/pablo/internship/xs_for_input/cross_sections.xml'
#Mac path
model.materials.cross_sections = '/Users/pablogarcia44/repo/endfb-vii.1-hdf5/cross_sections.xml'

# %% [markdown]
# ### Create pincell

# %%
def B4C_pin(family):
    B4C_outer_radius = openmc.ZCylinder(r=0.373)
    clad_inner_radius = openmc.ZCylinder(r=0.386)
    clad_outer_radius = openmc.ZCylinder(r=0.484)
    tube_inner_radius = openmc.ZCylinder(r=0.561)
    tube_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    
    B4C_region = -B4C_outer_radius
    gap_region = +B4C_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    guide_region = - tube_outer_radius & + tube_inner_radius
    water_region = +left & -right & +bottom & -top & +tube_outer_radius | +clad_outer_radius & - tube_inner_radius

    B4C = openmc.Cell(name='B4C'+'_'+family)
    B4C.fill = B4C_mat
    B4C.region = B4C_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = SS304
    clad.region = clad_region
    guide = openmc.Cell(name='guide'+'_'+family)
    guide.fill = zirconium
    guide.region = guide_region
    
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(B4C,guide, gap, clad, moderator))
    return(u,B4C,gap,clad,moderator,guide)

# %%
def pincell(family):
    fuel_outer_radius = openmc.ZCylinder(r=0.4096)
    clad_inner_radius = openmc.ZCylinder(r=0.418)
    clad_outer_radius = openmc.ZCylinder(r=0.475)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    fuel_region = -fuel_outer_radius
    gap_region = +fuel_outer_radius & -clad_inner_radius
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    fuel = openmc.Cell(name='fuel'+'_'+family)
    fuel.fill = uo2
    fuel.region = fuel_region
    gap = openmc.Cell(name='gap'+'_'+family)
    gap.region = gap_region
    gap.fill = helium     
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family,cells=(fuel, clad, moderator,gap))
    return(u,fuel,clad,moderator,gap)

# %%
def pincell_side(family):
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')
    water_region = +left & -right & +bottom & -top 
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u'+'_'+family)
    u.add_cell(moderator)
    return(u,moderator)

# %% [markdown]
# ### Create guide tube

# %%
def guide(family):
    clad_inner_radius = openmc.ZCylinder(r=0.561)
    clad_outer_radius = openmc.ZCylinder(r=0.602)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Create instrumentation tube

# %%
def instru(family):
    clad_inner_radius = openmc.ZCylinder(r=0.559)
    clad_outer_radius = openmc.ZCylinder(r=0.605)
    pitch = 1.26
    left = openmc.XPlane(-pitch/2, boundary_type='transmission')
    right = openmc.XPlane(pitch/2, boundary_type='transmission')
    bottom = openmc.YPlane(-pitch/2, boundary_type='transmission')
    top = openmc.YPlane(pitch/2, boundary_type='transmission')       
    clad_region = +clad_inner_radius & -clad_outer_radius
    water_region = +left & -right & +bottom & -top & +clad_outer_radius
    water_guide_region= -clad_inner_radius
    water_guide = openmc.Cell(name='water'+'_'+family)
    water_guide.fill = water
    water_guide.region = water_guide_region
    clad = openmc.Cell(name='clad'+'_'+family)
    clad.fill = zirconium
    clad.region = clad_region
    moderator = openmc.Cell(name='moderator'+'_'+family)
    moderator.fill = water
    moderator.region = water_region 
    u = openmc.Universe(name='u_guide'+'_'+family,cells=(water_guide, clad, moderator))
    return(u,water_guide,water_guide,clad,moderator)

# %% [markdown]
# ### Mappping

# %%
GT=[(5,2),(8,2),(3,3),(2,5),(5,5),(8,5),(2,8),(5,8)]
IT=[(8,8)]

GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))
print(GT_full)
# Out:
# [(3, 13), (11, 2), (11, 5), (11, 8), (2, 5), (11, 14), (2, 11), (11, 11), (2, 8), (3, 3), (8, 2), (8, 5), (8, 11), (8, 14), (13, 13), (14, 5), (14, 11), (5, 2), (14, 8), (5, 5), (5, 11), (5, 8), (5, 14), (13, 3)]

# %% [markdown]
# ### Create family pincell

# %% [markdown]
# ### Define assembly

# %%
pitch=1.26
dr=0.04
size=19
def create_assembly_b4c(family):
    pincell_fam=pincell(family+'_'+'pincell')
    guide_fam=B4C_pin(family+'_'+'guide')
    instru_fam=instru(family+'_'+'instru')
    side_fam=pincell_side(family+'_'+'outside')
    
    
    assembly = openmc.RectLattice()
    assembly.pitch = (pitch,pitch)
    assembly.lower_left = (-size/2*pitch, -size/2*pitch)
    


    A= np.empty((size, size), dtype=openmc.universe.Universe)

    for ix in range(size):
        for iy in range(size):
            if (ix-1,iy-1) in GT_full : 
                A[ix][iy]=guide_fam[0]
            elif ix==0 or ix==18 or iy==0 or iy==18:
                A[ix][iy]=side_fam[0]
            elif (ix-1,iy-1) in IT :
                A[ix][iy]=instru_fam[0]
            else:
                A[ix][iy]=pincell_fam[0]    
        
    assembly.universes = A

    
    rod_height=385.1
    
    
    assembly_cell= openmc.Cell(name='assembly_cell', fill=assembly)

    assembly_universe = openmc.Universe(name='assembly_universe')
    assembly_universe.add_cell(assembly_cell)
    print(assembly_universe)
    min_x = openmc.XPlane(x0=-((size-2)*pitch/2+dr), boundary_type='reflective')
    max_x = openmc.XPlane(x0=+((size-2)*pitch/2+dr), boundary_type='reflective')
    min_y = openmc.YPlane(y0=-((size-2)*pitch/2+dr), boundary_type='reflective')
    max_y = openmc.YPlane(y0=+((size-2)*pitch/2+dr), boundary_type='reflective')
    min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
    max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')
    root_cell = openmc.Cell(name='root cell', fill=assembly_universe)
    root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z
    root_universe = openmc.Universe(name='root universe')
    root_universe.add_cell(root_cell)
    return(root_universe,pincell_fam,guide_fam,instru_fam,assembly_cell)

# %%
pitch=1.26
dr=0.04
size=19
def create_assembly(family):
    pincell_fam=pincell(family+'_'+'pincell')
    guide_fam=guide(family+'_'+'guide')
    instru_fam=instru(family+'_'+'instru')
    side_fam=pincell_side(family+'_'+'outside')
    
    
    assembly = openmc.RectLattice()
    assembly.pitch = (pitch,pitch)
    assembly.lower_left = (-size/2*pitch, -size/2*pitch)
    


    A= np.empty((size, size), dtype=openmc.universe.Universe)

    for ix in range(size):
        for iy in range(size):
            if (ix-1,iy-1) in GT_full : 
                A[ix][iy]=guide_fam[0]
            elif ix==0 or ix==18 or iy==0 or iy==18:
                A[ix][iy]=side_fam[0]
            elif (ix-1,iy-1) in IT :
                A[ix][iy]=instru_fam[0]
            else:
                A[ix][iy]=pincell_fam[0]    
        
    assembly.universes = A

    
    rod_height=385.1
    
    
    assembly_cell= openmc.Cell(name='assembly_cell', fill=assembly)

    assembly_universe = openmc.Universe(name='assembly_universe')
    assembly_universe.add_cell(assembly_cell)
    print(assembly_universe)
    min_x = openmc.XPlane(x0=-((size-2)*pitch/2+dr), boundary_type='reflective')
    max_x = openmc.XPlane(x0=+((size-2)*pitch/2+dr), boundary_type='reflective')
    min_y = openmc.YPlane(y0=-((size-2)*pitch/2+dr), boundary_type='reflective')
    max_y = openmc.YPlane(y0=+((size-2)*pitch/2+dr), boundary_type='reflective')
    min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
    max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')
    root_cell = openmc.Cell(name='root cell', fill=assembly_universe)
    root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z
    root_universe = openmc.Universe(name='root universe')
    root_universe.add_cell(root_cell)
    return(root_universe,pincell_fam,guide_fam,instru_fam,assembly_cell)

# %% [markdown]
# # dr=0.04
# # min_x = openmc.XPlane(x0=-((size-2)*pitch/2+dr), boundary_type='reflective')
# # max_x = openmc.XPlane(x0=+((size-2)*pitch/2+dr), boundary_type='reflective')
# # min_y = openmc.YPlane(y0=-((size-2)*pitch/2+dr), boundary_type='reflective')
# # max_y = openmc.YPlane(y0=+((size-2)*pitch/2+dr), boundary_type='reflective')
# # min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
# # max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')
#
# # root_cell = openmc.Cell(name='root cell', fill=create_assembly('C')[0])
# # root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z
# # root_universe = openmc.Universe(name='root universe')
# # root_universe.add_cell(root_cell)
#
# model.geometry.root_universe = create_assembly('C')[0]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (1000, 1000)
# plot.width = (pitch*20, pitch*20)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()

# %%
assembly_C=create_assembly('C')
assembly_E=create_assembly('E')
assembly_M=create_assembly_b4c('M')
# Out:
# Universe
# 	ID             =	75
# 	Name           =	assembly_universe
# 	Geom           =	CSG
# 	Cells          =	[138]
#
# Universe
# 	ID             =	82
# 	Name           =	assembly_universe
# 	Geom           =	CSG
# 	Cells          =	[151]
#
# Universe
# 	ID             =	89
# 	Name           =	assembly_universe
# 	Geom           =	CSG
# 	Cells          =	[166]

# %%
C_full=[(0,0),(2,2),(2,0),(0,2)]
E_full=[(1,0),(0,1),(1,2),(2,1)]
M_full=[(1,1)]

# %%
pitch=1.26

dr=0.04 # cm of water that is outside assembly


size=17 #size of the assembly 
pitch_assembly=size*pitch+2*dr 
core = openmc.RectLattice()

size_core=3
core.pitch = (pitch_assembly,pitch_assembly)

core.lower_left = (-size_core/2*pitch_assembly, -size_core/2*pitch_assembly)


A= np.empty((size_core, size_core), dtype=openmc.universe.Universe)

for ix in range(size_core):
    for iy in range(size_core):
        if (ix,iy) in C_full : 
            A[ix][iy]=assembly_C[0]
        elif (ix,iy) in E_full :
            A[ix][iy]=assembly_E[0]
        elif (ix,iy) in M_full :
            A[ix][iy]=assembly_M[0] 

      
core.universes = A




rod_height=385.1
# 1/4 assembly
min_x = openmc.XPlane(x0=-(size_core/2*pitch_assembly), boundary_type='reflective')
max_x = openmc.XPlane(x0=0, boundary_type='reflective')
min_y = openmc.YPlane(y0=0, boundary_type='reflective')
max_y = openmc.YPlane(y0=+(size_core/2*pitch_assembly), boundary_type='reflective')
min_z = openmc.ZPlane(z0=-rod_height/2, boundary_type='reflective')
max_z = openmc.ZPlane(z0=+rod_height/2, boundary_type='reflective')


root_cell = openmc.Cell(name='root cell', fill=core)
root_cell.region = +min_x & -max_x & +min_y & -max_y & +min_z & -max_z



model.geometry.root_universe = openmc.Universe(name='root universe')
model.geometry.root_universe.add_cell(root_cell)

# %% [markdown]
# ### Plot

# %% [markdown]
# model.materials.export_to_xml()
# model.geometry.export_to_xml()
# plot = openmc.Plot.from_geometry(model.geometry)
# plot.pixels = (1000, 1000)
# plot.width = (pitch_assembly*3, pitch_assembly*3)
# plot.origin = (0., 0., 0)
# plot.color_by = 'cell'
# plot.to_ipython_image()
# # print(model.geometry.get_all_material_cells().values())

# %% [markdown]
# ### Choose settings

# %%
bounds = [-pitch_assembly/2, 0, -10, 0, +pitch_assembly/2, 10]
uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable=True)
source = openmc.IndependentSource(space=uniform_dist)
source.time = openmc.stats.Uniform(0, 1e-6)
settings = openmc.Settings()
settings.source = source
settings = openmc.Settings()
settings.source = source
settings.batches = 50
settings.inactive = 20
settings.particles = 50000
settings.keff_trigger = {'type':'std_dev','threshold':0.00010}
settings.trigger_active = True
settings.trigger_max_batches = 50000
settings.output = {'tallies':True}
settings.temperature['method'] = 'interpolation'
model.settings = settings

# %% [markdown]
# ### Define and choose energy group

# %%
choose_group=openmc.mgxs.GROUP_STRUCTURES['SHEM-361']
name_group='SHEM-361'
print(choose_group)
# Out:
# [0.00000e+00 2.49990e-03 4.55602e-03 7.14526e-03 1.04505e-02 1.48300e-02
#  2.00104e-02 2.49394e-02 2.92989e-02 3.43998e-02 4.02999e-02 4.73019e-02
#  5.54982e-02 6.51999e-02 7.64969e-02 8.97968e-02 1.04298e-01 1.19995e-01
#  1.37999e-01 1.61895e-01 1.90005e-01 2.09610e-01 2.31192e-01 2.54997e-01
#  2.79989e-01 3.05012e-01 3.25008e-01 3.52994e-01 3.90001e-01 4.31579e-01
#  4.75017e-01 5.20011e-01 5.54990e-01 5.94993e-01 6.24999e-01 7.19999e-01
#  8.00371e-01 8.80024e-01 9.19978e-01 9.44022e-01 9.63960e-01 9.81959e-01
#  9.96501e-01 1.00904e+00 1.02101e+00 1.03499e+00 1.07799e+00 1.09198e+00
#  1.10395e+00 1.11605e+00 1.12997e+00 1.14797e+00 1.16999e+00 1.21397e+00
#  1.25094e+00 1.29304e+00 1.33095e+00 1.38098e+00 1.41001e+00 1.44397e+00
#  1.51998e+00 1.58803e+00 1.66895e+00 1.77997e+00 1.90008e+00 1.98992e+00
#  2.07010e+00 2.15695e+00 2.21709e+00 2.27299e+00 2.33006e+00 2.46994e+00
#  2.55000e+00 2.59009e+00 2.62005e+00 2.64004e+00 2.70012e+00 2.71990e+00
#  2.74092e+00 2.77512e+00 2.88405e+00 3.14211e+00 3.54307e+00 3.71209e+00
#  3.88217e+00 4.00000e+00 4.21983e+00 4.30981e+00 4.41980e+00 4.76785e+00
#  4.93323e+00 5.10997e+00 5.21008e+00 5.32011e+00 5.38003e+00 5.41025e+00
#  5.48817e+00 5.53004e+00 5.61979e+00 5.72015e+00 5.80021e+00 5.96014e+00
#  6.05991e+00 6.16011e+00 6.28016e+00 6.35978e+00 6.43206e+00 6.48178e+00
#  6.51492e+00 6.53907e+00 6.55609e+00 6.57184e+00 6.58829e+00 6.60611e+00
#  6.63126e+00 6.71668e+00 6.74225e+00 6.75981e+00 6.77605e+00 6.79165e+00
#  6.81070e+00 6.83526e+00 6.87021e+00 6.91778e+00 6.99429e+00 7.13987e+00
#  7.38015e+00 7.60035e+00 7.73994e+00 7.83965e+00 7.97008e+00 8.13027e+00
#  8.30032e+00 8.52407e+00 8.67369e+00 8.80038e+00 8.97995e+00 9.14031e+00
#  9.50002e+00 1.05793e+01 1.08038e+01 1.10529e+01 1.12694e+01 1.15894e+01
#  1.17094e+01 1.18153e+01 1.19795e+01 1.21302e+01 1.23086e+01 1.24721e+01
#  1.26000e+01 1.33297e+01 1.35460e+01 1.40496e+01 1.42505e+01 1.44702e+01
#  1.45952e+01 1.47301e+01 1.48662e+01 1.57792e+01 1.60498e+01 1.65501e+01
#  1.68305e+01 1.74457e+01 1.75648e+01 1.77590e+01 1.79591e+01 1.90848e+01
#  1.91997e+01 1.93927e+01 1.95974e+01 2.00734e+01 2.02751e+01 2.04175e+01
#  2.05199e+01 2.06021e+01 2.06847e+01 2.07676e+01 2.09763e+01 2.10604e+01
#  2.11448e+01 2.12296e+01 2.13360e+01 2.14859e+01 2.17018e+01 2.20011e+01
#  2.21557e+01 2.23788e+01 2.25356e+01 2.46578e+01 2.78852e+01 3.16930e+01
#  3.30855e+01 3.45392e+01 3.56980e+01 3.60568e+01 3.64191e+01 3.68588e+01
#  3.73038e+01 3.77919e+01 3.87874e+01 3.97295e+01 4.12270e+01 4.21441e+01
#  4.31246e+01 4.41721e+01 4.52904e+01 4.62053e+01 4.75173e+01 4.92591e+01
#  5.17847e+01 5.29895e+01 5.40600e+01 5.70595e+01 5.99250e+01 6.23083e+01
#  6.36306e+01 6.45923e+01 6.50460e+01 6.55029e+01 6.58312e+01 6.61612e+01
#  6.64929e+01 6.68261e+01 6.90682e+01 7.18869e+01 7.35595e+01 7.63322e+01
#  7.93679e+01 8.39393e+01 8.87741e+01 9.33256e+01 9.73287e+01 1.00594e+02
#  1.01098e+02 1.01605e+02 1.02115e+02 1.03038e+02 1.05646e+02 1.10288e+02
#  1.12854e+02 1.15480e+02 1.16524e+02 1.17577e+02 1.20554e+02 1.26229e+02
#  1.32701e+02 1.39504e+02 1.46657e+02 1.54176e+02 1.63056e+02 1.67519e+02
#  1.75229e+02 1.83295e+02 1.84952e+02 1.86251e+02 1.87559e+02 1.88877e+02
#  1.90204e+02 1.93078e+02 1.95996e+02 2.00958e+02 2.12108e+02 2.24325e+02
#  2.35590e+02 2.41796e+02 2.56748e+02 2.68297e+02 2.76468e+02 2.84888e+02
#  2.88327e+02 2.95922e+02 3.19928e+02 3.35323e+02 3.53575e+02 3.71703e+02
#  3.90760e+02 4.19094e+02 4.53999e+02 5.01746e+02 5.39204e+02 5.77146e+02
#  5.92941e+02 6.00099e+02 6.12834e+02 6.46837e+02 6.77287e+02 7.48517e+02
#  8.32218e+02 9.09681e+02 9.82494e+02 1.06432e+03 1.13467e+03 1.34358e+03
#  1.58620e+03 1.81183e+03 2.08410e+03 2.39729e+03 2.70024e+03 2.99618e+03
#  3.48107e+03 4.09735e+03 5.00451e+03 6.11252e+03 7.46585e+03 9.11881e+03
#  1.11377e+04 1.36037e+04 1.48997e+04 1.62005e+04 1.85847e+04 2.26994e+04
#  2.49991e+04 2.61001e+04 2.73944e+04 2.92810e+04 3.34596e+04 3.69786e+04
#  4.08677e+04 4.99159e+04 5.51656e+04 6.73794e+04 8.22974e+04 9.46645e+04
#  1.15624e+05 1.22773e+05 1.40000e+05 1.64999e+05 1.95008e+05 2.30014e+05
#  2.67826e+05 3.20646e+05 3.83884e+05 4.12501e+05 4.56021e+05 4.94002e+05
#  5.78443e+05 7.06511e+05 8.60006e+05 9.51119e+05 1.05115e+06 1.16205e+06
#  1.28696e+06 1.33694e+06 1.40577e+06 1.63654e+06 1.90139e+06 2.23130e+06
#  2.72531e+06 3.32871e+06 4.06569e+06 4.96585e+06 6.06530e+06 6.70319e+06
#  7.40817e+06 8.18730e+06 9.04836e+06 9.99999e+06 1.16183e+07 1.38403e+07
#  1.49182e+07 1.96403e+07]

# %%
print(choose_group[360-20])
# Out:
# 1051150.0

# %% [markdown]
# ### Create MGXS tallies for mgxs directory

# %%
mgxs_lib = openmc.mgxs.Library(model.geometry)
groups = openmc.mgxs.EnergyGroups(choose_group)
mgxs_lib.energy_groups = groups
mgxs_lib.scatter_format = "legendre"
mgxs_lib.legendre_order = 3
mgxs_lib.mgxs_types = ['total', 'absorption', 'nu-fission', 'fission' ,'chi', 'consistent nu-scatter matrix', 'multiplicity matrix','kappa-fission']
#mgxs_lib.tally_trigger =openmc.Trigger('std_dev', 1e-2)
mgxs_lib.by_nuclide = False
mgxs_lib.domain_type = 'cell'
mgxs_lib.domains = model.geometry.get_all_material_cells().values()
mgxs_lib.build_library()
tallies = openmc.Tallies()
mgxs_lib.add_to_tallies_file(tallies, merge=True)
model.tallies = tallies

#model.export_to_xml()
# model.export_to_model_xml('model_1_gap.xml')
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mgxs/library.py:401: RuntimeWarning: The P0 correction will be ignored since the scattering order 3 is greater than zero
#   warn(msg, RuntimeWarning)

# %% [markdown]
# ### Run OpenMC model

# %%
print(model.geometry.get_all_material_cells().values())
# Out:
# dict_values([Cell
# 	ID             =	137
# 	Name           =	moderator_C_outside
# 	Fill           =	Material 21
# 	Region         =	(308 -309 310 -311)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	127
# 	Name           =	fuel_C_pincell
# 	Fill           =	Material 19
# 	Region         =	-289
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	129
# 	Name           =	clad_C_pincell
# 	Fill           =	Material 20
# 	Region         =	(290 -291)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	130
# 	Name           =	moderator_C_pincell
# 	Fill           =	Material 21
# 	Region         =	(292 -293 294 -295 291)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	128
# 	Name           =	gap_C_pincell
# 	Fill           =	Material 22
# 	Region         =	(289 -290)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	131
# 	Name           =	water_C_guide
# 	Fill           =	Material 21
# 	Region         =	-296
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	132
# 	Name           =	clad_C_guide
# 	Fill           =	Material 20
# 	Region         =	(296 -297)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	133
# 	Name           =	moderator_C_guide
# 	Fill           =	Material 21
# 	Region         =	(298 -299 300 -301 297)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	134
# 	Name           =	water_C_instru
# 	Fill           =	Material 21
# 	Region         =	-302
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	135
# 	Name           =	clad_C_instru
# 	Fill           =	Material 20
# 	Region         =	(302 -303)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	136
# 	Name           =	moderator_C_instru
# 	Fill           =	Material 21
# 	Region         =	(304 -305 306 -307 303)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	150
# 	Name           =	moderator_E_outside
# 	Fill           =	Material 21
# 	Region         =	(337 -338 339 -340)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	140
# 	Name           =	fuel_E_pincell
# 	Fill           =	Material 19
# 	Region         =	-318
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	142
# 	Name           =	clad_E_pincell
# 	Fill           =	Material 20
# 	Region         =	(319 -320)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	143
# 	Name           =	moderator_E_pincell
# 	Fill           =	Material 21
# 	Region         =	(321 -322 323 -324 320)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	141
# 	Name           =	gap_E_pincell
# 	Fill           =	Material 22
# 	Region         =	(318 -319)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	144
# 	Name           =	water_E_guide
# 	Fill           =	Material 21
# 	Region         =	-325
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	145
# 	Name           =	clad_E_guide
# 	Fill           =	Material 20
# 	Region         =	(325 -326)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	146
# 	Name           =	moderator_E_guide
# 	Fill           =	Material 21
# 	Region         =	(327 -328 329 -330 326)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	147
# 	Name           =	water_E_instru
# 	Fill           =	Material 21
# 	Region         =	-331
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	148
# 	Name           =	clad_E_instru
# 	Fill           =	Material 20
# 	Region         =	(331 -332)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	149
# 	Name           =	moderator_E_instru
# 	Fill           =	Material 21
# 	Region         =	(333 -334 335 -336 332)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	165
# 	Name           =	moderator_M_outside
# 	Fill           =	Material 21
# 	Region         =	(369 -370 371 -372)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	153
# 	Name           =	fuel_M_pincell
# 	Fill           =	Material 19
# 	Region         =	-347
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	155
# 	Name           =	clad_M_pincell
# 	Fill           =	Material 20
# 	Region         =	(348 -349)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	156
# 	Name           =	moderator_M_pincell
# 	Fill           =	Material 21
# 	Region         =	(350 -351 352 -353 349)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	154
# 	Name           =	gap_M_pincell
# 	Fill           =	Material 22
# 	Region         =	(347 -348)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	157
# 	Name           =	B4C_M_guide
# 	Fill           =	Material 24
# 	Region         =	-354
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	160
# 	Name           =	guide_M_guide
# 	Fill           =	Material 20
# 	Region         =	(-358 357)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	158
# 	Name           =	gap_M_guide
# 	Fill           =	Material 22
# 	Region         =	(354 -355)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	159
# 	Name           =	clad_M_guide
# 	Fill           =	Material 23
# 	Region         =	(355 -356)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	161
# 	Name           =	moderator_M_guide
# 	Fill           =	Material 21
# 	Region         =	((359 -360 361 -362 358) | (356 -357))
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	162
# 	Name           =	water_M_instru
# 	Fill           =	Material 21
# 	Region         =	-363
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	163
# 	Name           =	clad_M_instru
# 	Fill           =	Material 20
# 	Region         =	(363 -364)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# , Cell
# 	ID             =	164
# 	Name           =	moderator_M_instru
# 	Fill           =	Material 21
# 	Region         =	(365 -366 367 -368 364)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None
# ])

# %%
sp_file = model.run()
# Out:
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=5248.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=3938.
#   warn(msg, IDWarning)
# /opt/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=3946.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0
#        Date/Time | 2024-09-13 09:58:01
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  Reading cross sections XML file...
#  Reading U234 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U234.h5
#  Reading U235 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U236 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U236.h5
#  Reading U238 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading Sn112 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn112.h5
#  Reading Sn114 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn114.h5
#  Reading Sn115 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn115.h5
#  Reading Sn116 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn116.h5
#  Reading Sn117 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn117.h5
#  Reading Sn118 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn118.h5
#  Reading Sn119 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn119.h5
#  Reading Sn120 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn120.h5
#  Reading Sn122 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn122.h5
#  Reading Sn124 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Sn124.h5
#  Reading Fe54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe54.h5
#  Reading Fe56 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe56.h5
#  Reading Fe57 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe57.h5
#  Reading Fe58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Fe58.h5
#  Reading Cr50 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr50.h5
#  Reading Cr52 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr52.h5
#  Reading Cr53 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr53.h5
#  Reading Cr54 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Cr54.h5
#  Reading Hf174 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf174.h5
#  Reading Hf176 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf176.h5
#  Reading Hf177 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf177.h5
#  Reading Hf178 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf178.h5
#  Reading Hf179 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf179.h5
#  Reading Hf180 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Hf180.h5
#  Reading H1 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading He4 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/He4.h5
#  Reading C0 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/C0.h5
#  Reading Si28 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si28.h5
#  Reading Si29 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si29.h5
#  Reading Si30 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Si30.h5
#  Reading P31 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/P31.h5
#  Reading Mn55 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Mn55.h5
#  Reading Ni58 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni58.h5
#  Reading Ni60 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni60.h5
#  Reading Ni61 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni61.h5
#  Reading Ni62 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni62.h5
#  Reading Ni64 from /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/Ni64.h5
#  Reading c_H_in_H2O from
#  /Users/pablogarcia44/repo/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 600 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.98611
#         2/1    1.07402
#         3/1    1.12265
#         4/1    1.13551
#         5/1    1.12724
#         6/1    1.13534
#         7/1    1.13698
#         8/1    1.14895
#         9/1    1.14905
#        10/1    1.14767
#        11/1    1.15017
#        12/1    1.14830
#        13/1    1.13586
#        14/1    1.14773
#        15/1    1.14968
#        16/1    1.14906
#        17/1    1.16222
#        18/1    1.14359
#        19/1    1.14019
#        20/1    1.15468
#        21/1    1.15730
#        22/1    1.14762    1.15246 +/- 0.00484
#        23/1    1.14991    1.15161 +/- 0.00292
#        24/1    1.15145    1.15157 +/- 0.00207
#        25/1    1.15346    1.15195 +/- 0.00164
#        26/1    1.14176    1.15025 +/- 0.00216
#        27/1    1.14315    1.14924 +/- 0.00209
#        28/1    1.14878    1.14918 +/- 0.00181
#        29/1    1.15014    1.14929 +/- 0.00160
#        30/1    1.14834    1.14919 +/- 0.00144
#        31/1    1.14789    1.14907 +/- 0.00130
#        32/1    1.14378    1.14863 +/- 0.00127
#        33/1    1.14754    1.14855 +/- 0.00117
#        34/1    1.14466    1.14827 +/- 0.00112
#        35/1    1.13781    1.14757 +/- 0.00125
#        36/1    1.14197    1.14722 +/- 0.00122
#        37/1    1.14255    1.14695 +/- 0.00118
#        38/1    1.13491    1.14628 +/- 0.00130
#        39/1    1.13956    1.14593 +/- 0.00128
#        40/1    1.13991    1.14563 +/- 0.00125
#        41/1    1.14329    1.14551 +/- 0.00119
#        42/1    1.14860    1.14565 +/- 0.00115
#        43/1    1.15221    1.14594 +/- 0.00113
#        44/1    1.13286    1.14539 +/- 0.00121
#        45/1    1.15158    1.14564 +/- 0.00119
#        46/1    1.14742    1.14571 +/- 0.00115
#        47/1    1.15146    1.14592 +/- 0.00112
#        48/1    1.13839    1.14565 +/- 0.00111
#        49/1    1.14417    1.14560 +/- 0.00108
#        50/1    1.14068    1.14544 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 6.4620698477353145 for eigenvalue
#  The estimated number of batches is 1273
#  Creating state point statepoint.00050.h5...
#        51/1    1.15134    1.14563 +/- 0.00104
#  Triggers unsatisfied, max unc./thresh. is 6.313621181237885 for eigenvalue
#  The estimated number of batches is 1256
#        52/1    1.15421    1.14590 +/- 0.00104
#  Triggers unsatisfied, max unc./thresh. is 6.185563772379578 for eigenvalue
#  The estimated number of batches is 1245
#        53/1    1.15168    1.14607 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 5.9646728803465185 for eigenvalue
#  The estimated number of batches is 1195
#        54/1    1.13730    1.14581 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 5.831729048420592 for eigenvalue
#  The estimated number of batches is 1177
#        55/1    1.15300    1.14602 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 5.899670338006737 for eigenvalue
#  The estimated number of batches is 1239
#        56/1    1.13787    1.14579 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 5.799241063721165 for eigenvalue
#  The estimated number of batches is 1231
#        57/1    1.13643    1.14554 +/- 0.00102
#  Triggers unsatisfied, max unc./thresh. is 5.6960438422777235 for eigenvalue
#  The estimated number of batches is 1221
#        58/1    1.13115    1.14516 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 5.668806504278559 for eigenvalue
#  The estimated number of batches is 1242
#        59/1    1.15330    1.14537 +/- 0.00105
#  Triggers unsatisfied, max unc./thresh. is 5.810843725999 for eigenvalue
#  The estimated number of batches is 1337
#        60/1    1.15959    1.14573 +/- 0.00109
#  Triggers unsatisfied, max unc./thresh. is 5.657107545913213 for eigenvalue
#  The estimated number of batches is 1301
#        61/1    1.14182    1.14563 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 5.6671813078994 for eigenvalue
#  The estimated number of batches is 1337
#        62/1    1.15486    1.14585 +/- 0.00106
#  Triggers unsatisfied, max unc./thresh. is 5.754708330438857 for eigenvalue
#  The estimated number of batches is 1411
#        63/1    1.14448    1.14582 +/- 0.00104
#  Triggers unsatisfied, max unc./thresh. is 5.681482695734925 for eigenvalue
#  The estimated number of batches is 1409
#        64/1    1.14598    1.14582 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 5.647937412069923 for eigenvalue
#  The estimated number of batches is 1424
#        65/1    1.13215    1.14552 +/- 0.00104
#  Triggers unsatisfied, max unc./thresh. is 5.897046499338597 for eigenvalue
#  The estimated number of batches is 1585
#        66/1    1.14585    1.14553 +/- 0.00101
#  Triggers unsatisfied, max unc./thresh. is 5.7852696243773485 for eigenvalue
#  The estimated number of batches is 1560
#        67/1    1.14945    1.14561 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 5.816944842610427 for eigenvalue
#  The estimated number of batches is 1611
#        68/1    1.14295    1.14555 +/- 0.00098
#  Triggers unsatisfied, max unc./thresh. is 5.726215424492044 for eigenvalue
#  The estimated number of batches is 1594
#        69/1    1.13797    1.14540 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 5.667037382315882 for eigenvalue
#  The estimated number of batches is 1594
#        70/1    1.15489    1.14559 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 5.535316576928863 for eigenvalue
#  The estimated number of batches is 1552
#        71/1    1.13168    1.14532 +/- 0.00099
#  Triggers unsatisfied, max unc./thresh. is 5.501353252392878 for eigenvalue
#  The estimated number of batches is 1564
#        72/1    1.14287    1.14527 +/- 0.00097
#  Triggers unsatisfied, max unc./thresh. is 5.395397582011672 for eigenvalue
#  The estimated number of batches is 1534
#        73/1    1.14375    1.14524 +/- 0.00095
#  Triggers unsatisfied, max unc./thresh. is 5.353628520415927 for eigenvalue
#  The estimated number of batches is 1540
#        74/1    1.15712    1.14546 +/- 0.00096
#  Triggers unsatisfied, max unc./thresh. is 5.254189190043783 for eigenvalue
#  The estimated number of batches is 1511
#        75/1    1.14841    1.14551 +/- 0.00094
#  Triggers unsatisfied, max unc./thresh. is 5.150518732163572 for eigenvalue
#  The estimated number of batches is 1480
#        76/1    1.14915    1.14558 +/- 0.00093
#  Triggers unsatisfied, max unc./thresh. is 5.05411095322079 for eigenvalue
#  The estimated number of batches is 1451
#        77/1    1.15429    1.14573 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 4.963891038338616 for eigenvalue
#  The estimated number of batches is 1425
#        78/1    1.14782    1.14577 +/- 0.00091
#  Triggers unsatisfied, max unc./thresh. is 5.100004000227296 for eigenvalue
#  The estimated number of batches is 1529
#        79/1    1.15932    1.14600 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.021880890068756 for eigenvalue
#  The estimated number of batches is 1508
#        80/1    1.13807    1.14587 +/- 0.00092
#  Triggers unsatisfied, max unc./thresh. is 5.035886843404065 for eigenvalue
#  The estimated number of batches is 1542
#        81/1    1.14176    1.14580 +/- 0.00090
#  Triggers unsatisfied, max unc./thresh. is 5.0350302564158005 for eigenvalue
#  The estimated number of batches is 1567
#        82/1    1.15188    1.14590 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 4.990850395045162 for eigenvalue
#  The estimated number of batches is 1565
#        83/1    1.15364    1.14602 +/- 0.00089
#  Triggers unsatisfied, max unc./thresh. is 5.055566703083587 for eigenvalue
#  The estimated number of batches is 1631
#        84/1    1.14029    1.14593 +/- 0.00088
#  Triggers unsatisfied, max unc./thresh. is 4.993041870926585 for eigenvalue
#  The estimated number of batches is 1616
#        85/1    1.14935    1.14598 +/- 0.00087
#  Triggers unsatisfied, max unc./thresh. is 4.907346063482782 for eigenvalue
#  The estimated number of batches is 1586
#        86/1    1.14509    1.14597 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.857407486743597 for eigenvalue
#  The estimated number of batches is 1578
#        87/1    1.15265    1.14607 +/- 0.00085
#  Triggers unsatisfied, max unc./thresh. is 4.780054975901392 for eigenvalue
#  The estimated number of batches is 1551
#        88/1    1.13911    1.14597 +/- 0.00084
#  Triggers unsatisfied, max unc./thresh. is 4.783448761204872 for eigenvalue
#  The estimated number of batches is 1576
#        89/1    1.14989    1.14602 +/- 0.00083
#  Triggers unsatisfied, max unc./thresh. is 4.76520235183157 for eigenvalue
#  The estimated number of batches is 1587
#        90/1    1.14320    1.14598 +/- 0.00082
#  Triggers unsatisfied, max unc./thresh. is 4.711893782610218 for eigenvalue
#  The estimated number of batches is 1575
#        91/1    1.15321    1.14608 +/- 0.00081
#  Triggers unsatisfied, max unc./thresh. is 4.700337939570994 for eigenvalue
#  The estimated number of batches is 1589
#        92/1    1.14684    1.14609 +/- 0.00080
#  Triggers unsatisfied, max unc./thresh. is 4.743654753579947 for eigenvalue
#  The estimated number of batches is 1641
#        93/1    1.14625    1.14610 +/- 0.00079
#  Triggers unsatisfied, max unc./thresh. is 4.790645316470015 for eigenvalue
#  The estimated number of batches is 1696
#        94/1    1.15041    1.14615 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.8031382418879245 for eigenvalue
#  The estimated number of batches is 1728
#        95/1    1.15311    1.14625 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.7293660418966565 for eigenvalue
#  The estimated number of batches is 1698
#        96/1    1.15630    1.14638 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.683733178154826 for eigenvalue
#  The estimated number of batches is 1688
#        97/1    1.15520    1.14649 +/- 0.00078
#  Triggers unsatisfied, max unc./thresh. is 4.614146307360683 for eigenvalue
#  The estimated number of batches is 1660
#        98/1    1.14619    1.14649 +/- 0.00077
#  Triggers unsatisfied, max unc./thresh. is 4.556143517431597 for eigenvalue
#  The estimated number of batches is 1640
#        99/1    1.14912    1.14652 +/- 0.00076
#  Triggers unsatisfied, max unc./thresh. is 4.510698554931676 for eigenvalue
#  The estimated number of batches is 1628
#       100/1    1.14763    1.14654 +/- 0.00075
#  Triggers unsatisfied, max unc./thresh. is 4.488863103639635 for eigenvalue
#  The estimated number of batches is 1632
#       101/1    1.14961    1.14658 +/- 0.00074
#  Triggers unsatisfied, max unc./thresh. is 4.476496180621514 for eigenvalue
#  The estimated number of batches is 1644
#       102/1    1.15261    1.14665 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.486762051550094 for eigenvalue
#  The estimated number of batches is 1671
#       103/1    1.14753    1.14666 +/- 0.00073
#  Triggers unsatisfied, max unc./thresh. is 4.449099423900396 for eigenvalue
#  The estimated number of batches is 1663
#       104/1    1.14555    1.14665 +/- 0.00072
#  Triggers unsatisfied, max unc./thresh. is 4.400581690420586 for eigenvalue
#  The estimated number of batches is 1647
#       105/1    1.14679    1.14665 +/- 0.00071
#  Triggers unsatisfied, max unc./thresh. is 4.344633199618487 for eigenvalue
#  The estimated number of batches is 1625
#       106/1    1.14473    1.14663 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.300962891200558 for eigenvalue
#  The estimated number of batches is 1611
#       107/1    1.14068    1.14656 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.2677379119446535 for eigenvalue
#  The estimated number of batches is 1605
#       108/1    1.13658    1.14644 +/- 0.00070
#  Triggers unsatisfied, max unc./thresh. is 4.228733033047549 for eigenvalue
#  The estimated number of batches is 1594
#       109/1    1.14739    1.14645 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.183190537402319 for eigenvalue
#  The estimated number of batches is 1578
#       110/1    1.14668    1.14646 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.133523642316431 for eigenvalue
#  The estimated number of batches is 1558
#       111/1    1.15361    1.14654 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.085376913605871 for eigenvalue
#  The estimated number of batches is 1539
#       112/1    1.15918    1.14667 +/- 0.00069
#  Triggers unsatisfied, max unc./thresh. is 4.089801309306464 for eigenvalue
#  The estimated number of batches is 1559
#       113/1    1.14817    1.14669 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.06595145366502 for eigenvalue
#  The estimated number of batches is 1558
#       114/1    1.15360    1.14676 +/- 0.00068
#  Triggers unsatisfied, max unc./thresh. is 4.059564485845624 for eigenvalue
#  The estimated number of batches is 1570
#       115/1    1.14177    1.14671 +/- 0.00067
#  Triggers unsatisfied, max unc./thresh. is 4.019617304221029 for eigenvalue
#  The estimated number of batches is 1555
#       116/1    1.14835    1.14673 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 3.9746864418821235 for eigenvalue
#  The estimated number of batches is 1537
#       117/1    1.14200    1.14668 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 3.9273533277908013 for eigenvalue
#  The estimated number of batches is 1517
#       118/1    1.13811    1.14659 +/- 0.00066
#  Triggers unsatisfied, max unc./thresh. is 3.9152977323599885 for eigenvalue
#  The estimated number of batches is 1523
#       119/1    1.14422    1.14657 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.879827484174827 for eigenvalue
#  The estimated number of batches is 1511
#       120/1    1.14266    1.14653 +/- 0.00065
#  Triggers unsatisfied, max unc./thresh. is 3.843156410901234 for eigenvalue
#  The estimated number of batches is 1497
#       121/1    1.14355    1.14650 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.80928894070997 for eigenvalue
#  The estimated number of batches is 1486
#       122/1    1.14049    1.14644 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.807244359859673 for eigenvalue
#  The estimated number of batches is 1499
#       123/1    1.14797    1.14645 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.7984907111887014 for eigenvalue
#  The estimated number of batches is 1507
#       124/1    1.13853    1.14638 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.7709596126371587 for eigenvalue
#  The estimated number of batches is 1499
#       125/1    1.15937    1.14650 +/- 0.00064
#  Triggers unsatisfied, max unc./thresh. is 3.7464558526164096 for eigenvalue
#  The estimated number of batches is 1494
#       126/1    1.15096    1.14654 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.752829874712905 for eigenvalue
#  The estimated number of batches is 1513
#       127/1    1.14961    1.14657 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.7702939141621297 for eigenvalue
#  The estimated number of batches is 1542
#       128/1    1.13497    1.14647 +/- 0.00063
#  Triggers unsatisfied, max unc./thresh. is 3.741854816014873 for eigenvalue
#  The estimated number of batches is 1533
#       129/1    1.14431    1.14645 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.706250713041284 for eigenvalue
#  The estimated number of batches is 1518
#       130/1    1.14800    1.14646 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.6681216563748857 for eigenvalue
#  The estimated number of batches is 1501
#       131/1    1.14999    1.14649 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.6277928516466487 for eigenvalue
#  The estimated number of batches is 1481
#       132/1    1.15785    1.14659 +/- 0.00062
#  Triggers unsatisfied, max unc./thresh. is 3.6018830879906285 for eigenvalue
#  The estimated number of batches is 1474
#       133/1    1.14728    1.14660 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.5662686535292982 for eigenvalue
#  The estimated number of batches is 1458
#       134/1    1.15332    1.14666 +/- 0.00061
#  Triggers unsatisfied, max unc./thresh. is 3.5704662252959753 for eigenvalue
#  The estimated number of batches is 1474
#       135/1    1.14693    1.14666 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.5460760428191964 for eigenvalue
#  The estimated number of batches is 1467
#       136/1    1.15109    1.14670 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.5174434475946126 for eigenvalue
#  The estimated number of batches is 1456
#       137/1    1.14384    1.14667 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.5091600972037487 for eigenvalue
#  The estimated number of batches is 1461
#       138/1    1.14487    1.14666 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.4802881800084813 for eigenvalue
#  The estimated number of batches is 1450
#       139/1    1.13878    1.14659 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.4918539848890613 for eigenvalue
#  The estimated number of batches is 1471
#       140/1    1.15006    1.14662 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.474629140519214 for eigenvalue
#  The estimated number of batches is 1469
#       141/1    1.14927    1.14664 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.443832504082322 for eigenvalue
#  The estimated number of batches is 1456
#       142/1    1.13910    1.14658 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.4585985921461058 for eigenvalue
#  The estimated number of batches is 1480
#       143/1    1.16636    1.14674 +/- 0.00060
#  Triggers unsatisfied, max unc./thresh. is 3.5083526731350427 for eigenvalue
#  The estimated number of batches is 1534
#       144/1    1.14265    1.14671 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.4872287151956054 for eigenvalue
#  The estimated number of batches is 1528
#       145/1    1.15775    1.14680 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.4592554156898077 for eigenvalue
#  The estimated number of batches is 1516
#       146/1    1.15337    1.14685 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.448901059355794 for eigenvalue
#  The estimated number of batches is 1519
#       147/1    1.13848    1.14678 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.4444352999087604 for eigenvalue
#  The estimated number of batches is 1527
#       148/1    1.14734    1.14679 +/- 0.00059
#  Triggers unsatisfied, max unc./thresh. is 3.4195455248495072 for eigenvalue
#  The estimated number of batches is 1517
#       149/1    1.14304    1.14676 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.3963223338223454 for eigenvalue
#  The estimated number of batches is 1509
#       150/1    1.15874    1.14685 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.544644063723023 for eigenvalue
#  The estimated number of batches is 1654
#       151/1    1.15388    1.14690 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.5369061726380098 for eigenvalue
#  The estimated number of batches is 1659
#       152/1    1.15312    1.14695 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.5705691719963375 for eigenvalue
#  The estimated number of batches is 1703
#       153/1    1.15278    1.14700 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.545805727243259 for eigenvalue
#  The estimated number of batches is 1693
#       154/1    1.13595    1.14691 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.5175823772769745 for eigenvalue
#  The estimated number of batches is 1679
#       155/1    1.15994    1.14701 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.5302818107254743 for eigenvalue
#  The estimated number of batches is 1703
#       156/1    1.14461    1.14699 +/- 0.00058
#  Triggers unsatisfied, max unc./thresh. is 3.5925721348912347 for eigenvalue
#  The estimated number of batches is 1776
#       157/1    1.14854    1.14700 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5788747844849196 for eigenvalue
#  The estimated number of batches is 1775
#       158/1    1.14082    1.14696 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5785275651703516 for eigenvalue
#  The estimated number of batches is 1788
#       159/1    1.14421    1.14694 +/- 0.00057
#  Triggers unsatisfied, max unc./thresh. is 3.5583349004309346 for eigenvalue
#  The estimated number of batches is 1780
#       160/1    1.14689    1.14694 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5548630793389284 for eigenvalue
#  The estimated number of batches is 1790
#       161/1    1.14641    1.14693 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5437731157518666 for eigenvalue
#  The estimated number of batches is 1791
#       162/1    1.14307    1.14691 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.5215417095190986 for eigenvalue
#  The estimated number of batches is 1781
#       163/1    1.15505    1.14696 +/- 0.00056
#  Triggers unsatisfied, max unc./thresh. is 3.520462694149713 for eigenvalue
#  The estimated number of batches is 1793
#       164/1    1.14483    1.14695 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.510187950614825 for eigenvalue
#  The estimated number of batches is 1795
#       165/1    1.14852    1.14696 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.4875367379624738 for eigenvalue
#  The estimated number of batches is 1784
#       166/1    1.15237    1.14700 +/- 0.00055
#  Triggers unsatisfied, max unc./thresh. is 3.4637737888590157 for eigenvalue
#  The estimated number of batches is 1772
#       167/1    1.15025    1.14702 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4409081609231387 for eigenvalue
#  The estimated number of batches is 1761
#       168/1    1.14119    1.14698 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.4466122275113453 for eigenvalue
#  The estimated number of batches is 1779
#       169/1    1.14793    1.14699 +/- 0.00054
#  Triggers unsatisfied, max unc./thresh. is 3.426869774091164 for eigenvalue
#  The estimated number of batches is 1770
#       170/1    1.15040    1.14701 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.40405304481134 for eigenvalue
#  The estimated number of batches is 1759
#       171/1    1.14541    1.14700 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3865479722127256 for eigenvalue
#  The estimated number of batches is 1752
#       172/1    1.14534    1.14699 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.391516862961052 for eigenvalue
#  The estimated number of batches is 1769
#       173/1    1.15390    1.14703 +/- 0.00053
#  Triggers unsatisfied, max unc./thresh. is 3.3678953257412316 for eigenvalue
#  The estimated number of batches is 1756
#       174/1    1.15333    1.14707 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3525871261231734 for eigenvalue
#  The estimated number of batches is 1751
#       175/1    1.14357    1.14705 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.3306693120655435 for eigenvalue
#  The estimated number of batches is 1740
#       176/1    1.14173    1.14702 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.312382765825626 for eigenvalue
#  The estimated number of batches is 1732
#       177/1    1.15082    1.14704 +/- 0.00052
#  Triggers unsatisfied, max unc./thresh. is 3.307356577270338 for eigenvalue
#  The estimated number of batches is 1738
#       178/1    1.15186    1.14707 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2850002176494852 for eigenvalue
#  The estimated number of batches is 1726
#       179/1    1.15297    1.14711 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2749645630112045 for eigenvalue
#  The estimated number of batches is 1726
#       180/1    1.14676    1.14711 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.2729453000052176 for eigenvalue
#  The estimated number of batches is 1734
#       181/1    1.14440    1.14709 +/- 0.00051
#  Triggers unsatisfied, max unc./thresh. is 3.264278498724355 for eigenvalue
#  The estimated number of batches is 1736
#       182/1    1.15468    1.14714 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2719322647940183 for eigenvalue
#  The estimated number of batches is 1755
#       183/1    1.14022    1.14709 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.266697645934048 for eigenvalue
#  The estimated number of batches is 1760
#       184/1    1.14544    1.14708 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2507093424357985 for eigenvalue
#  The estimated number of batches is 1754
#       185/1    1.15284    1.14712 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.2457190079612763 for eigenvalue
#  The estimated number of batches is 1759
#       186/1    1.14514    1.14711 +/- 0.00050
#  Triggers unsatisfied, max unc./thresh. is 3.251567507585969 for eigenvalue
#  The estimated number of batches is 1776
#       187/1    1.14910    1.14712 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2340740253900964 for eigenvalue
#  The estimated number of batches is 1767
#       188/1    1.14632    1.14711 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.215903382781716 for eigenvalue
#  The estimated number of batches is 1758
#       189/1    1.15058    1.14714 +/- 0.00049
#  Triggers unsatisfied, max unc./thresh. is 3.2026191235324477 for eigenvalue
#  The estimated number of batches is 1754
#       190/1    1.14496    1.14712 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1847660550968206 for eigenvalue
#  The estimated number of batches is 1745
#       191/1    1.14927    1.14713 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.165072829773523 for eigenvalue
#  The estimated number of batches is 1734
#       192/1    1.14057    1.14710 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.150349828512338 for eigenvalue
#  The estimated number of batches is 1728
#       193/1    1.14256    1.14707 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.1370727406318535 for eigenvalue
#  The estimated number of batches is 1723
#       194/1    1.14618    1.14707 +/- 0.00048
#  Triggers unsatisfied, max unc./thresh. is 3.119681292410807 for eigenvalue
#  The estimated number of batches is 1714
#       195/1    1.14069    1.14703 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1301485005525325 for eigenvalue
#  The estimated number of batches is 1735
#       196/1    1.15034    1.14705 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.115631802212037 for eigenvalue
#  The estimated number of batches is 1729
#       197/1    1.15811    1.14711 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.1300974263981263 for eigenvalue
#  The estimated number of batches is 1755
#       198/1    1.15492    1.14715 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.112097521300199 for eigenvalue
#  The estimated number of batches is 1744
#       199/1    1.14194    1.14713 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.101180415327309 for eigenvalue
#  The estimated number of batches is 1742
#       200/1    1.14742    1.14713 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0845422909008153 for eigenvalue
#  The estimated number of batches is 1733
#       201/1    1.14788    1.14713 +/- 0.00047
#  Triggers unsatisfied, max unc./thresh. is 3.0739423119212046 for eigenvalue
#  The estimated number of batches is 1731
#       202/1    1.14525    1.14712 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0766762588793117 for eigenvalue
#  The estimated number of batches is 1743
#       203/1    1.14135    1.14709 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.060679536509358 for eigenvalue
#  The estimated number of batches is 1735
#       204/1    1.14402    1.14707 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.062653197517625 for eigenvalue
#  The estimated number of batches is 1746
#       205/1    1.15581    1.14712 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.072972432782736 for eigenvalue
#  The estimated number of batches is 1767
#       206/1    1.14653    1.14712 +/- 0.00046
#  Triggers unsatisfied, max unc./thresh. is 3.0681337228949905 for eigenvalue
#  The estimated number of batches is 1771
#       207/1    1.14890    1.14713 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.05307968306018 for eigenvalue
#  The estimated number of batches is 1764
#       208/1    1.14663    1.14712 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0472213974341926 for eigenvalue
#  The estimated number of batches is 1766
#       209/1    1.15243    1.14715 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0559297305444066 for eigenvalue
#  The estimated number of batches is 1786
#       210/1    1.14759    1.14715 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.050086390158042 for eigenvalue
#  The estimated number of batches is 1788
#       211/1    1.15108    1.14717 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.035575775921777 for eigenvalue
#  The estimated number of batches is 1781
#       212/1    1.13303    1.14710 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0610555609897747 for eigenvalue
#  The estimated number of batches is 1820
#       213/1    1.15065    1.14712 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.0659517246818067 for eigenvalue
#  The estimated number of batches is 1835
#       214/1    1.15230    1.14715 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.050354239512421 for eigenvalue
#  The estimated number of batches is 1826
#       215/1    1.15536    1.14719 +/- 0.00045
#  Triggers unsatisfied, max unc./thresh. is 3.037412124167472 for eigenvalue
#  The estimated number of batches is 1820
#       216/1    1.14927    1.14720 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0227373512598654 for eigenvalue
#  The estimated number of batches is 1811
#       217/1    1.14698    1.14720 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 3.0131042327387756 for eigenvalue
#  The estimated number of batches is 1809
#       218/1    1.14290    1.14718 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9966828971589554 for eigenvalue
#  The estimated number of batches is 1799
#       219/1    1.15313    1.14721 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.986615969611834 for eigenvalue
#  The estimated number of batches is 1796
#       220/1    1.15346    1.14724 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9753553660026912 for eigenvalue
#  The estimated number of batches is 1791
#       221/1    1.14345    1.14722 +/- 0.00044
#  Triggers unsatisfied, max unc./thresh. is 2.9618944177143316 for eigenvalue
#  The estimated number of batches is 1784
#       222/1    1.14714    1.14722 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9465558139743693 for eigenvalue
#  The estimated number of batches is 1774
#       223/1    1.14779    1.14722 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9308489392194383 for eigenvalue
#  The estimated number of batches is 1764
#       224/1    1.15793    1.14727 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.940255382726994 for eigenvalue
#  The estimated number of batches is 1784
#       225/1    1.15133    1.14729 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9247066357649363 for eigenvalue
#  The estimated number of batches is 1774
#       226/1    1.15186    1.14731 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9124756209258 for eigenvalue
#  The estimated number of batches is 1768
#       227/1    1.13593    1.14726 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9471880249436286 for eigenvalue
#  The estimated number of batches is 1818
#       228/1    1.15593    1.14730 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9371776376692718 for eigenvalue
#  The estimated number of batches is 1815
#       229/1    1.14939    1.14731 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.92328536221304 for eigenvalue
#  The estimated number of batches is 1807
#       230/1    1.16173    1.14738 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9130916264292046 for eigenvalue
#  The estimated number of batches is 1803
#       231/1    1.15012    1.14739 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.9056662085689853 for eigenvalue
#  The estimated number of batches is 1802
#       232/1    1.15210    1.14742 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.894014448639645 for eigenvalue
#  The estimated number of batches is 1796
#       233/1    1.15790    1.14746 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.8884804824688803 for eigenvalue
#  The estimated number of batches is 1798
#       234/1    1.15574    1.14750 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.95293851556953 for eigenvalue
#  The estimated number of batches is 1887
#       235/1    1.14566    1.14749 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.956399877765626 for eigenvalue
#  The estimated number of batches is 1900
#       236/1    1.15871    1.14755 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.959089034469098 for eigenvalue
#  The estimated number of batches is 1912
#       237/1    1.14753    1.14755 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.946374160925701 for eigenvalue
#  The estimated number of batches is 1904
#       238/1    1.15021    1.14756 +/- 0.00043
#  Triggers unsatisfied, max unc./thresh. is 2.936892310900175 for eigenvalue
#  The estimated number of batches is 1901
#       239/1    1.14153    1.14753 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.929181551293285 for eigenvalue
#  The estimated number of batches is 1900
#       240/1    1.15165    1.14755 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.9164877015731085 for eigenvalue
#  The estimated number of batches is 1892
#       241/1    1.14552    1.14754 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.906878445413014 for eigenvalue
#  The estimated number of batches is 1888
#       242/1    1.14950    1.14755 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.891100409161864 for eigenvalue
#  The estimated number of batches is 1876
#       243/1    1.14394    1.14753 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8917712655678676 for eigenvalue
#  The estimated number of batches is 1885
#       244/1    1.14263    1.14751 +/- 0.00042
#  Triggers unsatisfied, max unc./thresh. is 2.8816505839418998 for eigenvalue
#  The estimated number of batches is 1881
#       245/1    1.15084    1.14753 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8706864688126728 for eigenvalue
#  The estimated number of batches is 1875
#       246/1    1.13924    1.14749 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.857763064126941 for eigenvalue
#  The estimated number of batches is 1866
#       247/1    1.15657    1.14753 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8470257612094976 for eigenvalue
#  The estimated number of batches is 1860
#       248/1    1.14529    1.14752 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8363623659895976 for eigenvalue
#  The estimated number of batches is 1855
#       249/1    1.14693    1.14752 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8359133405182044 for eigenvalue
#  The estimated number of batches is 1862
#       250/1    1.15071    1.14753 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8249737063167806 for eigenvalue
#  The estimated number of batches is 1856
#       251/1    1.13566    1.14748 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.810077252767162 for eigenvalue
#  The estimated number of batches is 1845
#       252/1    1.14351    1.14746 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7994697527333856 for eigenvalue
#  The estimated number of batches is 1839
#       253/1    1.15831    1.14751 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8169801392484795 for eigenvalue
#  The estimated number of batches is 1869
#       254/1    1.13945    1.14747 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.8080667114837756 for eigenvalue
#  The estimated number of batches is 1866
#       255/1    1.15248    1.14750 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7997543369376507 for eigenvalue
#  The estimated number of batches is 1863
#       256/1    1.14319    1.14748 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7837519414019654 for eigenvalue
#  The estimated number of batches is 1849
#       257/1    1.14033    1.14745 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7736088608728506 for eigenvalue
#  The estimated number of batches is 1844
#       258/1    1.14305    1.14743 +/- 0.00041
#  Triggers unsatisfied, max unc./thresh. is 2.7593099199042004 for eigenvalue
#  The estimated number of batches is 1833
#       259/1    1.14725    1.14743 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7597592578164387 for eigenvalue
#  The estimated number of batches is 1841
#       260/1    1.15705    1.14747 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7473857418896164 for eigenvalue
#  The estimated number of batches is 1832
#       261/1    1.14367    1.14745 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7410399813001436 for eigenvalue
#  The estimated number of batches is 1831
#       262/1    1.15233    1.14747 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7436532625362893 for eigenvalue
#  The estimated number of batches is 1842
#       263/1    1.15234    1.14749 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7308349483223426 for eigenvalue
#  The estimated number of batches is 1833
#       264/1    1.14623    1.14749 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7210395881643277 for eigenvalue
#  The estimated number of batches is 1827
#       265/1    1.14184    1.14746 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.7123125728302617 for eigenvalue
#  The estimated number of batches is 1823
#       266/1    1.14173    1.14744 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.6991966154015605 for eigenvalue
#  The estimated number of batches is 1813
#       267/1    1.14470    1.14743 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.694757184353946 for eigenvalue
#  The estimated number of batches is 1814
#       268/1    1.15423    1.14746 +/- 0.00040
#  Triggers unsatisfied, max unc./thresh. is 2.691178956066023 for eigenvalue
#  The estimated number of batches is 1817
#       269/1    1.14157    1.14743 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6850122053232424 for eigenvalue
#  The estimated number of batches is 1816
#       270/1    1.14028    1.14741 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.670296243837066 for eigenvalue
#  The estimated number of batches is 1803
#       271/1    1.14672    1.14740 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6629818229031654 for eigenvalue
#  The estimated number of batches is 1800
#       272/1    1.14080    1.14738 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.660297648125451 for eigenvalue
#  The estimated number of batches is 1804
#       273/1    1.14656    1.14737 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.651095448423983 for eigenvalue
#  The estimated number of batches is 1799
#       274/1    1.15236    1.14739 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.642945375015251 for eigenvalue
#  The estimated number of batches is 1795
#       275/1    1.14355    1.14738 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.63510524127092 for eigenvalue
#  The estimated number of batches is 1791
#       276/1    1.15828    1.14742 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.627456465261026 for eigenvalue
#  The estimated number of batches is 1788
#       277/1    1.14378    1.14741 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.617110760937257 for eigenvalue
#  The estimated number of batches is 1781
#       278/1    1.14407    1.14739 +/- 0.00039
#  Triggers unsatisfied, max unc./thresh. is 2.6105195665794088 for eigenvalue
#  The estimated number of batches is 1779
#       279/1    1.14592    1.14739 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6129355933728955 for eigenvalue
#  The estimated number of batches is 1789
#       280/1    1.14428    1.14738 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6083413445828887 for eigenvalue
#  The estimated number of batches is 1789
#       281/1    1.14915    1.14738 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5981845366025396 for eigenvalue
#  The estimated number of batches is 1782
#       282/1    1.14254    1.14736 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.59479785729886 for eigenvalue
#  The estimated number of batches is 1785
#       283/1    1.14347    1.14735 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.6098177720991647 for eigenvalue
#  The estimated number of batches is 1812
#       284/1    1.14298    1.14733 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.600896384055826 for eigenvalue
#  The estimated number of batches is 1806
#       285/1    1.15210    1.14735 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.593615726721764 for eigenvalue
#  The estimated number of batches is 1803
#       286/1    1.14763    1.14735 +/- 0.00038
#  Triggers unsatisfied, max unc./thresh. is 2.5882165405546202 for eigenvalue
#  The estimated number of batches is 1802
#       287/1    1.14978    1.14736 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5866372727348867 for eigenvalue
#  The estimated number of batches is 1807
#       288/1    1.14368    1.14735 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.577284672382916 for eigenvalue
#  The estimated number of batches is 1801
#       289/1    1.14724    1.14735 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.571510005481964 for eigenvalue
#  The estimated number of batches is 1799
#       290/1    1.14764    1.14735 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.565239917083084 for eigenvalue
#  The estimated number of batches is 1797
#       291/1    1.14718    1.14735 +/- 0.00037
#  Triggers unsatisfied, max unc./thresh. is 2.5551720622094076 for eigenvalue
#  The estimated number of batches is 1790
#       292/1    1.14642    1.14734 +/- 0.00037
# ...
#      1536/1    1.15285    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0298792408048807 for eigenvalue
#  The estimated number of batches is 1628
#      1537/1    1.14368    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.029206090304311 for eigenvalue
#  The estimated number of batches is 1627
#      1538/1    1.15228    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0284686019347007 for eigenvalue
#  The estimated number of batches is 1626
#      1539/1    1.15137    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0278050784358268 for eigenvalue
#  The estimated number of batches is 1625
#      1540/1    1.14260    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0272292807915429 for eigenvalue
#  The estimated number of batches is 1624
#      1541/1    1.16095    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0267054276310401 for eigenvalue
#  The estimated number of batches is 1624
#      1542/1    1.14400    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0261625525450822 for eigenvalue
#  The estimated number of batches is 1623
#      1543/1    1.14639    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0260800726433907 for eigenvalue
#  The estimated number of batches is 1624
#      1544/1    1.15322    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.025981110868887 for eigenvalue
#  The estimated number of batches is 1625
#      1545/1    1.14889    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.025300662905457 for eigenvalue
#  The estimated number of batches is 1624
#      1546/1    1.14494    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0246412162609098 for eigenvalue
#  The estimated number of batches is 1623
#      1547/1    1.14446    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0239243578733075 for eigenvalue
#  The estimated number of batches is 1621
#      1548/1    1.13508    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0236708396825358 for eigenvalue
#  The estimated number of batches is 1622
#      1549/1    1.15358    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0230927985799312 for eigenvalue
#  The estimated number of batches is 1621
#      1550/1    1.14976    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0225948444726127 for eigenvalue
#  The estimated number of batches is 1620
#      1551/1    1.15239    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0219610553207032 for eigenvalue
#  The estimated number of batches is 1619
#      1552/1    1.14569    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.021449338054569 for eigenvalue
#  The estimated number of batches is 1619
#      1553/1    1.15386    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0208035453172217 for eigenvalue
#  The estimated number of batches is 1618
#      1554/1    1.15247    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0201826463456654 for eigenvalue
#  The estimated number of batches is 1617
#      1555/1    1.14777    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.019710560784953 for eigenvalue
#  The estimated number of batches is 1617
#      1556/1    1.13441    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0217777021570142 for eigenvalue
#  The estimated number of batches is 1624
#      1557/1    1.15066    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0211139235396913 for eigenvalue
#  The estimated number of batches is 1623
#      1558/1    1.12896    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023895582914347 for eigenvalue
#  The estimated number of batches is 1633
#      1559/1    1.15004    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.023526123539309 for eigenvalue
#  The estimated number of batches is 1633
#      1560/1    1.15068    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0235540515714074 for eigenvalue
#  The estimated number of batches is 1634
#      1561/1    1.14103    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0228912276302395 for eigenvalue
#  The estimated number of batches is 1633
#      1562/1    1.14911    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0223849564520682 for eigenvalue
#  The estimated number of batches is 1632
#      1563/1    1.16423    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0229055050009912 for eigenvalue
#  The estimated number of batches is 1635
#      1564/1    1.14661    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0221633434658592 for eigenvalue
#  The estimated number of batches is 1634
#      1565/1    1.13431    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0214301661011327 for eigenvalue
#  The estimated number of batches is 1632
#      1566/1    1.14963    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0209284204409876 for eigenvalue
#  The estimated number of batches is 1632
#      1567/1    1.15039    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.021661751700071 for eigenvalue
#  The estimated number of batches is 1635
#      1568/1    1.14388    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0216553212878419 for eigenvalue
#  The estimated number of batches is 1636
#      1569/1    1.14663    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0210028939320763 for eigenvalue
#  The estimated number of batches is 1635
#      1570/1    1.14293    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0210783747777352 for eigenvalue
#  The estimated number of batches is 1637
#      1571/1    1.15161    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0205502233478776 for eigenvalue
#  The estimated number of batches is 1636
#      1572/1    1.15070    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0198188692700687 for eigenvalue
#  The estimated number of batches is 1635
#      1573/1    1.13646    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0198547125393187 for eigenvalue
#  The estimated number of batches is 1636
#      1574/1    1.15081    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0192916454120298 for eigenvalue
#  The estimated number of batches is 1635
#      1575/1    1.14302    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0190245902326278 for eigenvalue
#  The estimated number of batches is 1635
#      1576/1    1.14730    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0185542342877747 for eigenvalue
#  The estimated number of batches is 1635
#      1577/1    1.13937    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0180928957870432 for eigenvalue
#  The estimated number of batches is 1634
#      1578/1    1.15563    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0178322492100786 for eigenvalue
#  The estimated number of batches is 1635
#      1579/1    1.15258    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0181906064610966 for eigenvalue
#  The estimated number of batches is 1637
#      1580/1    1.14773    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0175926995888764 for eigenvalue
#  The estimated number of batches is 1636
#      1581/1    1.14975    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0169026723162942 for eigenvalue
#  The estimated number of batches is 1635
#      1582/1    1.15039    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0163607114648046 for eigenvalue
#  The estimated number of batches is 1634
#      1583/1    1.14346    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0159267792937412 for eigenvalue
#  The estimated number of batches is 1634
#      1584/1    1.14524    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0164458086757358 for eigenvalue
#  The estimated number of batches is 1636
#      1585/1    1.15237    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0159747206334646 for eigenvalue
#  The estimated number of batches is 1636
#      1586/1    1.14587    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0154503526793293 for eigenvalue
#  The estimated number of batches is 1635
#      1587/1    1.14479    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0147818710649752 for eigenvalue
#  The estimated number of batches is 1634
#      1588/1    1.14599    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.014255103655872 for eigenvalue
#  The estimated number of batches is 1634
#      1589/1    1.14695    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0139993375861263 for eigenvalue
#  The estimated number of batches is 1634
#      1590/1    1.14835    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0134575562139185 for eigenvalue
#  The estimated number of batches is 1633
#      1591/1    1.15210    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0133849016512946 for eigenvalue
#  The estimated number of batches is 1634
#      1592/1    1.15083    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.012781197799592 for eigenvalue
#  The estimated number of batches is 1633
#      1593/1    1.13875    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.012401589392318 for eigenvalue
#  The estimated number of batches is 1633
#      1594/1    1.14910    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0118902602968711 for eigenvalue
#  The estimated number of batches is 1632
#      1595/1    1.15297    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0113765660655272 for eigenvalue
#  The estimated number of batches is 1632
#      1596/1    1.13535    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.011459890519373 for eigenvalue
#  The estimated number of batches is 1633
#      1597/1    1.14448    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.01109591505223 for eigenvalue
#  The estimated number of batches is 1633
#      1598/1    1.14673    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0107077612995214 for eigenvalue
#  The estimated number of batches is 1632
#      1599/1    1.14740    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.010082490479225 for eigenvalue
#  The estimated number of batches is 1632
#      1600/1    1.15415    1.14743 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0102325275989066 for eigenvalue
#  The estimated number of batches is 1633
#      1601/1    1.15540    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0097039873300906 for eigenvalue
#  The estimated number of batches is 1632
#      1602/1    1.14964    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0090512400953902 for eigenvalue
#  The estimated number of batches is 1631
#      1603/1    1.13992    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0087264607083617 for eigenvalue
#  The estimated number of batches is 1631
#      1604/1    1.15533    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0090807411858715 for eigenvalue
#  The estimated number of batches is 1633
#      1605/1    1.13916    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0084759632439657 for eigenvalue
#  The estimated number of batches is 1632
#      1606/1    1.15801    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0079767459953146 for eigenvalue
#  The estimated number of batches is 1632
#      1607/1    1.14693    1.14744 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0073312280953568 for eigenvalue
#  The estimated number of batches is 1631
#      1608/1    1.16067    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0070881554272026 for eigenvalue
#  The estimated number of batches is 1631
#      1609/1    1.14898    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0065704111940073 for eigenvalue
#  The estimated number of batches is 1630
#      1610/1    1.14669    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0059948617757373 for eigenvalue
#  The estimated number of batches is 1630
#      1611/1    1.15002    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0055142299472914 for eigenvalue
#  The estimated number of batches is 1629
#      1612/1    1.15331    1.14746 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0049353055126022 for eigenvalue
#  The estimated number of batches is 1628
#      1613/1    1.14557    1.14746 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0046291406129002 for eigenvalue
#  The estimated number of batches is 1628
#      1614/1    1.15400    1.14746 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0040555706280487 for eigenvalue
#  The estimated number of batches is 1627
#      1615/1    1.14462    1.14746 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0034839722240214 for eigenvalue
#  The estimated number of batches is 1627
#      1616/1    1.14147    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0029043115776195 for eigenvalue
#  The estimated number of batches is 1626
#      1617/1    1.13787    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0026040028240502 for eigenvalue
#  The estimated number of batches is 1626
#      1618/1    1.14336    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0020148131490023 for eigenvalue
#  The estimated number of batches is 1625
#      1619/1    1.14816    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0014141327489143 for eigenvalue
#  The estimated number of batches is 1624
#      1620/1    1.15712    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.00110003496253 for eigenvalue
#  The estimated number of batches is 1624
#      1621/1    1.13761    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0008623295289367 for eigenvalue
#  The estimated number of batches is 1624
#      1622/1    1.15464    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0010726054138783 for eigenvalue
#  The estimated number of batches is 1626
#      1623/1    1.14465    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.000471898495299 for eigenvalue
#  The estimated number of batches is 1625
#      1624/1    1.14567    1.14745 +/- 0.00016
#  Triggers unsatisfied, max unc./thresh. is 1.0004407746021389 for eigenvalue
#  The estimated number of batches is 1626
#      1625/1    1.14977    1.14745 +/- 0.00016
#  Triggers satisfied for batch 1625
#  Creating state point statepoint.01625.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 8.2488e+00 seconds
#    Reading cross sections          = 8.1377e+00 seconds
#  Total time in simulation          = 2.5880e+03 seconds
#    Time in transport only          = 2.4910e+03 seconds
#    Time in inactive batches        = 1.6646e+01 seconds
#    Time in active batches          = 2.5713e+03 seconds
#    Time synchronizing fission bank = 4.8365e+00 seconds
#      Sampling source sites         = 3.9821e+00 seconds
#      SEND/RECV source sites        = 8.5292e-01 seconds
#    Time accumulating tallies       = 8.8187e+01 seconds
#    Time writing statepoints        = 1.4688e+00 seconds
#  Total time for finalization       = 7.2672e+01 seconds
#  Total time elapsed                = 2.6692e+03 seconds
#  Calculation Rate (inactive)       = 60072.9 particles/second
#  Calculation Rate (active)         = 31209.8 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.14751 +/- 0.00013
#  k-effective (Track-length)  = 1.14745 +/- 0.00016
#  k-effective (Absorption)    = 1.14722 +/- 0.00011
#  Combined k-effective        = 1.14732 +/- 0.00010
#  Leakage Fraction            = 0.00000 +/- 0.00000
